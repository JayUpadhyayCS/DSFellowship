# %%
# %matplotlib inline
import os
import glob
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import imagesc as imagesc
# Standardize the data attributes for the Iris dataset.
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# global figure parameters
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (8, 5),
          'figure.dpi': 300,
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %%
# south InSAR
# load lon, lat information
lon_south=pd.read_csv('InSAR_data_south/longitude.csv')
lat_south=pd.read_csv('InSAR_data_south/latitude.csv')
# load one file

z_south=pd.read_csv('InSAR_data_south/displacement/CSV/20190122.csv')


# change columns and index names into lon and lat
z_south.columns=lon_south.columns
z_south.index=lat_south.columns[:-1]
#standardized_x=preprocessing.scale(z_south)
#print(standardized_x)
min=-80
max=0
#need to standardize data
ax=sns.heatmap(z_south, xticklabels=200, yticklabels=200,vmin=min, vmax=max,\
    cbar_kws={'label': 'Displacement (cm)'})
ax.invert_yaxis()
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.tight_layout()
#plt.savefig('InSAR_south.tiff', transparent=True)
plt.show()

# %%
z_south
# Out:
#          -120.9486  -120.9466  -120.9446  -120.9426  -120.9406  -120.9386  \
# 34.1347        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1367        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1387        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1407        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1427        NaN        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 37.6236        NaN        NaN        NaN        NaN        NaN        NaN
# 37.6256        NaN        NaN        NaN        NaN        NaN        NaN
# 37.6276        NaN        NaN        NaN        NaN        NaN        NaN
# 37.6296        NaN        NaN        NaN        NaN        NaN        NaN
# 37.6316        NaN        NaN        NaN        NaN        NaN        NaN
#
#          -120.9366  -120.9346  -120.9326  -120.9306  ...  -117.6594  \
# 34.1347        NaN        NaN        NaN        NaN  ...        NaN
# 34.1367        NaN        NaN        NaN        NaN  ...        NaN
# 34.1387        NaN        NaN        NaN        NaN  ...        NaN
# 34.1407        NaN        NaN        NaN        NaN  ...        NaN
# 34.1427        NaN        NaN        NaN        NaN  ...        NaN
# ...            ...        ...        ...        ...  ...        ...
# 37.6236        NaN        NaN        NaN        NaN  ...     7.5449
# 37.6256        NaN        NaN        NaN        NaN  ...     8.2231
# 37.6276        NaN        NaN        NaN        NaN  ...     8.4665
# 37.6296        NaN        NaN        NaN        NaN  ...     9.9062
# 37.6316        NaN        NaN        NaN        NaN  ...     9.5569
#
#          -117.6574  -117.6554  -117.6534  -117.6514  -117.6494  -117.6474  \
# 34.1347        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1367        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1387        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1407        NaN        NaN        NaN        NaN        NaN        NaN
# 34.1427        NaN        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 37.6236     8.0000     7.0169     7.3686     7.7291     9.0865     9.0584
# 37.6256     8.2312     7.1434     7.9037     8.6615     8.6396     7.8872
# 37.6276     7.9957     7.0966     8.1436     8.2300     8.7078     9.8128
# 37.6296     9.5421     8.9162     9.5183    10.3850    10.1290     8.7485
# 37.6316     9.1591     9.1025     9.3158     9.1843     9.1719     8.8576
#
#          -117.6454  -117.6434  -117.6414
# 34.1347        NaN        NaN        NaN
# 34.1367        NaN        NaN        NaN
# 34.1387        NaN        NaN        NaN
# 34.1407        NaN        NaN        NaN
# 34.1427        NaN        NaN        NaN
# ...            ...        ...        ...
# 37.6236     7.6645     8.9126     8.8353
# 37.6256     7.2073     9.3050     8.3278
# 37.6276     9.3035     8.5370     8.3947
# 37.6296     9.7053     9.2602    10.2190
# 37.6316     9.6473     9.3772     8.8725
#
# [1749 rows x 1655 columns]
