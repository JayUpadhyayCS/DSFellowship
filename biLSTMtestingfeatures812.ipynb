# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D, GRU # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
from keras import metrics
from keras.utils import plot_model
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# c:\Python\Python310\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
#df=df.iloc[200000:200050]
df=df.iloc[200300:205000]
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 35.7111          0.0     -9.7682     1.32970      2.5644
#           35.7131          0.0     -9.7499     1.03440      2.3852
#           35.7151          0.0     -9.7651     0.91867      2.1549
#           35.7171          0.0     -9.7098     1.06820      2.2616
#           35.7191          0.0     -9.7055     1.18930      2.2306
# ...                        ...         ...         ...         ...
# -120.4027 36.7274          0.0     -7.2276     0.73694      2.6327
#           36.7294          0.0     -7.3210     0.70109      2.4708
#           36.7314          0.0     -7.2388     0.46256      2.4291
#           36.7334          0.0     -7.2526     0.31420      2.0908
#           36.7394          0.0     -7.1203    -0.03439      2.3198
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 35.7111     -2.05550    0.206280    -1.92500    0.070012
#           35.7131     -2.17930    0.114360    -1.97630    0.061350
#           35.7151     -2.24280    0.047868    -2.09290   -0.009276
#           35.7171     -2.23340    0.121860    -2.03820    0.117630
#           35.7191     -2.20010    0.197790    -1.92230    0.277210
# ...                        ...         ...         ...         ...
# -120.4027 36.7274     -0.37212    4.126900    -0.77547    1.426300
#           36.7294     -0.53777    3.980700    -0.90438    1.269800
#           36.7314     -0.72740    3.727700    -1.12300    0.910640
#           36.7334     -1.04390    3.479200    -1.13890    0.931990
#           36.7394     -0.72105    3.620500    -1.04990    0.924510
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 35.7111      -1.3901     0.91577  ...     -5.1163    -2.91050
#           35.7131      -1.3482     0.95156  ...     -4.6685    -2.42550
#           35.7151      -1.3706     0.94827  ...     -3.9746    -1.69430
#           35.7171      -1.2118     1.12510  ...     -3.4391    -1.10440
#           35.7191      -1.0178     1.30990  ...     -2.8703    -0.48555
# ...                        ...         ...  ...         ...         ...
# -120.4027 36.7274       3.9578    -0.83484  ...     -4.7423    -1.76260
#           36.7294       3.9292    -0.64295  ...     -4.2087    -1.23680
#           36.7314       3.6537    -0.98271  ...     -4.7961    -1.85590
#           36.7334       3.3421    -1.11060  ...     -5.8926    -2.96370
#           36.7394       3.2634    -1.40170  ...     -5.4141    -2.53130
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 35.7111      -4.1619     -4.1025     -6.0477     -6.6512
#           35.7131      -3.7174     -3.6452     -5.5758     -6.2420
#           35.7151      -3.0357     -2.9414     -4.9009     -5.6663
#           35.7171      -2.5180     -2.4014     -4.3470     -4.9772
#           35.7191      -1.9774     -1.8200     -3.7522     -4.2980
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -2.7142     -3.0876     -6.2273     -5.2793
#           36.7294      -2.1775     -2.5592     -5.7036     -4.6893
#           36.7314      -2.7951     -3.1822     -6.3403     -5.3780
#           36.7334      -3.8852     -4.2657     -7.4344     -6.3047
#           36.7394      -3.4532     -3.8240     -6.9644     -6.0637
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 35.7111      -4.1006    -2.63540   -2.323500    -2.11000
#           35.7131      -3.6871    -2.20480   -1.915800    -1.67590
#           35.7151      -3.1530    -1.63350   -1.375200    -1.13320
#           35.7171      -2.4672    -1.01710   -0.752770    -0.46676
#           35.7191      -1.7318    -0.27899   -0.004492     0.32665
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -4.3728    -2.39470   -2.996500    -1.00440
#           36.7294      -3.7768    -1.82260   -2.465400    -0.46636
#           36.7314      -4.5069    -2.61010   -3.247500    -1.26730
#           36.7334      -5.4811    -3.60360   -4.232500    -2.30970
#           36.7394      -5.2230    -3.37850   -4.017800    -2.04980
#
# [4700 rows x 110 columns]

# %%
df2=pd.read_csv('InSAR_data_south/displacement/groundwater.csv')
df2=df2.set_index([df2.columns[0],df2.columns[1]])
df2.columns=pd.to_datetime(df2.columns, format='%Y-%m-%d')
df2=df2.dropna(axis=0, how='all')#drop full nan rows
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != df2.columns[y]: #if column is misssing insert it
        df2.insert(loc=y,column=df.columns[y],value=np.nan*11286,allow_duplicates=False)
df2.index[0]
type(df2.index[0])
# Out:
# tuple

# %%
df2.index.size
# Out:
# 11286

# %%
for x in range(df2.index.size): #for each row
    curr=np.nan
    for y in range(df2.columns.size): #for each value in the row
        n=0
        while np.isnan(curr): # if saved value is empty
            curr=df2.iloc[x].values[n] #look for next actual value
            n+=1
        if np.isnan(df2.iloc[x].values[y]):#if data is nan then replace with previous curr value
            df2.iat[x,y]=curr
            #df2.iloc[x].values[y]=curr
        else:
            curr= df2.iloc[x].values[y]
                

df2
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    81.000000   81.000000  ...   75.653992   75.813688
# -120.8926 36.7114    72.248964   72.248964  ...   75.200000   75.200000
# -120.8846 36.6994    72.248964   72.248964  ...   75.200000   75.200000
# -120.8746 36.6874    72.248964   72.248964  ...   75.200000   75.200000
# -120.1368 35.6991   141.123387  141.123387  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091  ...   16.978182   17.000000
# -119.0271 36.3793    17.409091   17.409091  ...   16.978182   17.000000
# -119.0571 36.4493    17.409091   17.409091  ...   16.978182   17.000000
# -119.0211 36.3993    17.409091   17.409091  ...   16.978182   17.000000
# -119.0111 36.3873    17.409091   17.409091  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0        76.0        76.0
# -120.8926 36.7114    75.200000        75.2        75.2        75.2
# -120.8846 36.6994    75.200000        75.2        75.2        75.2
# -120.8746 36.6874    75.200000        75.2        75.2        75.2
# -120.1368 35.6991   151.000000       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.000000        17.0        17.0        17.0
# -119.0271 36.3793    17.000000        17.0        17.0        17.0
# -119.0571 36.4493    17.000000        17.0        17.0        17.0
# -119.0211 36.3993    17.000000        17.0        17.0        17.0
# -119.0111 36.3873    17.000000        17.0        17.0        17.0
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316         76.0        76.0        76.0        76.0
# -120.8926 36.7114         75.2        75.2        75.2        75.2
# -120.8846 36.6994         75.2        75.2        75.2        75.2
# -120.8746 36.6874         75.2        75.2        75.2        75.2
# -120.1368 35.6991        151.0       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933         17.0        17.0        17.0        17.0
# -119.0271 36.3793         17.0        17.0        17.0        17.0
# -119.0571 36.4493         17.0        17.0        17.0        17.0
# -119.0211 36.3993         17.0        17.0        17.0        17.0
# -119.0111 36.3873         17.0        17.0        17.0        17.0
#
# [11286 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10
# 1 2 3 4 5 6 7 ...
# w/ timestep of 2
# [[1,2][2,3][3,4]

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping2(datain,datain2, timestep):
    #print(arr)
    cnt=0
    for row in range(len(datain2.index)): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()

        if datain2.index[row] not in datain.index:
            #print("Not found", cnt)
            continue
        
        print("found", row)
        arr=datain.loc[datain2.index[row]].to_numpy().flatten() # flatten row
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        arr2=datain2.iloc[row].to_numpy().flatten()
        #arr2=np.where(np.isnan(arr2), ma.array(arr2, mask=np.isnan(arr2)).mean(), arr2) 
        arr3=np.concatenate((arr,arr2)).reshape(2,110)
        
        
        for mth in range(0, len(datain2.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr3[:,X_start:X_end]
                Y_comb=arr3[0][Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr3[:,X_start:X_end])
                Y_comb=np.append(Y_comb, arr3[:1,Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 2))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %%
# print(df2.index.values[0])
# #arr=df.loc[df.index[0]]
# if df2.index.values in df.index.values:
#     print(True)
train, test = train_test_split(df, test_size=0.2, random_state=64, shuffle=False)
#train2, test2 = train_test_split(df2, test_size=0.2, random_state=64, shuffle=False)
X_train, Y_train=shaping2(datain=train,datain2=df2, timestep= timestep )
X_test, Y_test=shaping2(datain=test,datain2=df2, timestep= timestep )
# Out:
# found 75
# found 837
# found 1212
# found 1397
# found 1755
# found 1934
# found 2320
# found 2516
# found 3107
# found 3713
# found 3921
# found 4345
# found 4561
# found 5002
# found 5668
# found 5890
# found 6550
# found 7203
# found 7419
# found 7846
# found 8059
# found 8472
# found 8674
# found 9075
# found 9267
# found 1026
# found 1575
# found 2910

# %%
X_train.shape
# Out:
# (2275, 10, 2)

# %%
X_train
# Out:
# array([[[ 0.0000e+00, -6.4321e+00],
#         [ 1.9649e+00,  2.4831e+00],
#         [-5.7245e-01,  4.0556e+00],
#         ...,
#         [ 4.1450e+02,  4.1450e+02],
#         [ 4.1450e+02,  4.1450e+02],
#         [ 4.1450e+02,  4.1450e+02]],
#
#        [[-6.4321e+00,  1.9649e+00],
#         [ 2.4831e+00, -5.7245e-01],
#         [ 4.0556e+00,  8.6928e-01],
#         ...,
#         [ 4.1450e+02,  4.1450e+02],
#         [ 4.1450e+02,  4.1450e+02],
#         [ 4.1450e+02,  4.1450e+02]],
#
#        [[ 1.9649e+00,  2.4831e+00],
#         [-5.7245e-01,  4.0556e+00],
#         [ 8.6928e-01,  2.1553e+00],
#         ...,
#         [ 4.1450e+02,  4.1450e+02],
#         [ 4.1450e+02,  4.1450e+02],
#         [ 4.1450e+02,  4.1450e+02]],
#
#        ...,
#
#        [[ 7.4951e-01,  3.8853e-01],
#         [-9.3312e-02,  1.5819e+00],
#         [-2.3359e-01, -6.8539e+00],
#         ...,
#         [ 1.6500e+02,  1.6500e+02],
#         [ 1.6500e+02,  1.6500e+02],
#         [ 1.6500e+02,  1.6500e+02]],
#
#        [[ 3.8853e-01, -9.3312e-02],
#         [ 1.5819e+00, -2.3359e-01],
#         [-6.8539e+00,  2.3760e-01],
#         ...,
#         [ 1.6500e+02,  1.6500e+02],
#         [ 1.6500e+02,  1.6500e+02],
#         [ 1.6500e+02,  1.6500e+02]],
#
#        [[-9.3312e-02,  1.5819e+00],
#         [-2.3359e-01, -6.8539e+00],
#         [ 2.3760e-01,  2.1932e+00],
#         ...,
#         [ 1.6500e+02,  1.6500e+02],
#         [ 1.6500e+02,  1.6500e+02],
#         [ 1.6500e+02,  1.6500e+02]]])

# %%
X_train[0]
# Out:
# array([[  0.     ,  -6.4321 ],
#        [  1.9649 ,   2.4831 ],
#        [ -0.57245,   4.0556 ],
#        [  0.86928,   2.1553 ],
#        [  3.2699 ,   2.4434 ],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ]])

# %%
X_train[1]
# Out:
# array([[ -6.4321 ,   1.9649 ],
#        [  2.4831 ,  -0.57245],
#        [  4.0556 ,   0.86928],
#        [  2.1553 ,   3.2699 ],
#        [  2.4434 ,   0.45162],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ],
#        [414.5    , 414.5    ]])

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model2 = Sequential(name="biLSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'accuracy'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 910/910 - 10s - loss: 17.2793 - mean_squared_error: 17.2793 - accuracy: 0.0000e+00 - 10s/epoch - 11ms/step
# Epoch 2/250
# 910/910 - 6s - loss: 12.4043 - mean_squared_error: 12.4043 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 3/250
# 910/910 - 6s - loss: 8.9931 - mean_squared_error: 8.9931 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 4/250
# 910/910 - 6s - loss: 8.7424 - mean_squared_error: 8.7424 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 5/250
# 910/910 - 6s - loss: 8.2813 - mean_squared_error: 8.2813 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 6/250
# 910/910 - 6s - loss: 8.1500 - mean_squared_error: 8.1500 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 7/250
# 910/910 - 6s - loss: 7.8919 - mean_squared_error: 7.8919 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 8/250
# 910/910 - 6s - loss: 7.8043 - mean_squared_error: 7.8043 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 9/250
# 910/910 - 6s - loss: 7.8102 - mean_squared_error: 7.8102 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 10/250
# 910/910 - 6s - loss: 7.5532 - mean_squared_error: 7.5532 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 11/250
# 910/910 - 6s - loss: 7.1163 - mean_squared_error: 7.1163 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 12/250
# 910/910 - 6s - loss: 7.0486 - mean_squared_error: 7.0486 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 13/250
# 910/910 - 6s - loss: 6.8811 - mean_squared_error: 6.8811 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 14/250
# 910/910 - 6s - loss: 7.1033 - mean_squared_error: 7.1033 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 15/250
# 910/910 - 6s - loss: 6.9589 - mean_squared_error: 6.9589 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 16/250
# 910/910 - 6s - loss: 6.5743 - mean_squared_error: 6.5743 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 17/250
# 910/910 - 6s - loss: 6.4476 - mean_squared_error: 6.4476 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 18/250
# 910/910 - 6s - loss: 6.4575 - mean_squared_error: 6.4575 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 19/250
# 910/910 - 6s - loss: 38.8693 - mean_squared_error: 38.8694 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 20/250
# 910/910 - 6s - loss: 6.0752 - mean_squared_error: 6.0752 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 21/250
# 910/910 - 6s - loss: 5.8350 - mean_squared_error: 5.8350 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 22/250
# 910/910 - 5s - loss: 5.9364 - mean_squared_error: 5.9364 - accuracy: 0.0000e+00 - 5s/epoch - 6ms/step
# Epoch 23/250
# 910/910 - 6s - loss: 5.7337 - mean_squared_error: 5.7337 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 24/250
# 910/910 - 6s - loss: 5.7626 - mean_squared_error: 5.7626 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 25/250
# 910/910 - 6s - loss: 5.6656 - mean_squared_error: 5.6656 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 26/250
# 910/910 - 6s - loss: 5.5248 - mean_squared_error: 5.5248 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 27/250
# 910/910 - 6s - loss: 5.5709 - mean_squared_error: 5.5709 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 28/250
# 910/910 - 6s - loss: 5.3197 - mean_squared_error: 5.3197 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 29/250
# 910/910 - 6s - loss: 5.3875 - mean_squared_error: 5.3875 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 30/250
# 910/910 - 5s - loss: 5.5188 - mean_squared_error: 5.5188 - accuracy: 0.0000e+00 - 5s/epoch - 6ms/step
# Epoch 31/250
# 910/910 - 6s - loss: 5.5916 - mean_squared_error: 5.5916 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 32/250
# 910/910 - 6s - loss: 5.6767 - mean_squared_error: 5.6767 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 33/250
# 910/910 - 6s - loss: 5.2608 - mean_squared_error: 5.2608 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 34/250
# 910/910 - 6s - loss: 5.0751 - mean_squared_error: 5.0751 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 35/250
# 910/910 - 6s - loss: 5.0428 - mean_squared_error: 5.0428 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 36/250
# 910/910 - 6s - loss: 4.9192 - mean_squared_error: 4.9192 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 37/250
# 910/910 - 6s - loss: 5.0107 - mean_squared_error: 5.0107 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 38/250
# 910/910 - 6s - loss: 4.8504 - mean_squared_error: 4.8504 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 39/250
# 910/910 - 6s - loss: 4.6399 - mean_squared_error: 4.6399 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 40/250
# 910/910 - 6s - loss: 13.0279 - mean_squared_error: 13.0279 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 41/250
# 910/910 - 6s - loss: 6.0791 - mean_squared_error: 6.0790 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 42/250
# 910/910 - 7s - loss: 5.4647 - mean_squared_error: 5.4647 - accuracy: 0.0000e+00 - 7s/epoch - 8ms/step
# Epoch 43/250
# 910/910 - 7s - loss: 5.5966 - mean_squared_error: 5.5966 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 44/250
# 910/910 - 7s - loss: 5.1974 - mean_squared_error: 5.1974 - accuracy: 0.0000e+00 - 7s/epoch - 8ms/step
# Epoch 45/250
# 910/910 - 6s - loss: 4.9006 - mean_squared_error: 4.9006 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 46/250
# 910/910 - 6s - loss: 4.8210 - mean_squared_error: 4.8210 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 47/250
# 910/910 - 6s - loss: 4.7369 - mean_squared_error: 4.7369 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 48/250
# 910/910 - 6s - loss: 4.6324 - mean_squared_error: 4.6324 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 49/250
# 910/910 - 6s - loss: 8.2290 - mean_squared_error: 8.2290 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 50/250
# 910/910 - 7s - loss: 6.9798 - mean_squared_error: 6.9798 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 51/250
# 910/910 - 7s - loss: 5.8981 - mean_squared_error: 5.8981 - accuracy: 0.0000e+00 - 7s/epoch - 8ms/step
# Epoch 52/250
# 910/910 - 6s - loss: 5.4281 - mean_squared_error: 5.4281 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 53/250
# 910/910 - 6s - loss: 5.2887 - mean_squared_error: 5.2887 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 54/250
# 910/910 - 6s - loss: 5.5657 - mean_squared_error: 5.5657 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 55/250
# 910/910 - 7s - loss: 5.0422 - mean_squared_error: 5.0422 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 56/250
# 910/910 - 6s - loss: 5.3508 - mean_squared_error: 5.3508 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 57/250
# 910/910 - 6s - loss: 4.7446 - mean_squared_error: 4.7446 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 58/250
# 910/910 - 6s - loss: 4.8398 - mean_squared_error: 4.8398 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 59/250
# 910/910 - 6s - loss: 4.5471 - mean_squared_error: 4.5471 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 60/250
# 910/910 - 6s - loss: 4.9115 - mean_squared_error: 4.9115 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 61/250
# 910/910 - 6s - loss: 4.6598 - mean_squared_error: 4.6598 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 62/250
# 910/910 - 6s - loss: 4.3846 - mean_squared_error: 4.3846 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 63/250
# 910/910 - 6s - loss: 4.6084 - mean_squared_error: 4.6084 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 64/250
# 910/910 - 6s - loss: 4.4206 - mean_squared_error: 4.4206 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 65/250
# 910/910 - 6s - loss: 6.3453 - mean_squared_error: 6.3453 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 66/250
# 910/910 - 6s - loss: 4.8690 - mean_squared_error: 4.8690 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 67/250
# 910/910 - 6s - loss: 4.3782 - mean_squared_error: 4.3782 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 68/250
# 910/910 - 6s - loss: 4.0553 - mean_squared_error: 4.0553 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 69/250
# 910/910 - 6s - loss: 4.2463 - mean_squared_error: 4.2463 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 70/250
# 910/910 - 6s - loss: 4.1540 - mean_squared_error: 4.1540 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 71/250
# 910/910 - 6s - loss: 4.0680 - mean_squared_error: 4.0680 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 72/250
# 910/910 - 6s - loss: 4.0059 - mean_squared_error: 4.0059 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 73/250
# 910/910 - 6s - loss: 3.9794 - mean_squared_error: 3.9794 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 74/250
# 910/910 - 7s - loss: 3.7494 - mean_squared_error: 3.7494 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 75/250
# 910/910 - 6s - loss: 4.1603 - mean_squared_error: 4.1603 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 76/250
# 910/910 - 7s - loss: 3.8418 - mean_squared_error: 3.8418 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 77/250
# 910/910 - 7s - loss: 3.5783 - mean_squared_error: 3.5783 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 78/250
# 910/910 - 7s - loss: 3.4910 - mean_squared_error: 3.4910 - accuracy: 0.0000e+00 - 7s/epoch - 8ms/step
# Epoch 79/250
# 910/910 - 6s - loss: 3.6369 - mean_squared_error: 3.6369 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 80/250
# 910/910 - 6s - loss: 3.3688 - mean_squared_error: 3.3688 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 81/250
# 910/910 - 6s - loss: 3.4025 - mean_squared_error: 3.4025 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 82/250
# 910/910 - 6s - loss: 3.2728 - mean_squared_error: 3.2728 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 83/250
# 910/910 - 6s - loss: 3.4742 - mean_squared_error: 3.4742 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 84/250
# 910/910 - 6s - loss: 3.2135 - mean_squared_error: 3.2135 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 85/250
# 910/910 - 6s - loss: 3.1496 - mean_squared_error: 3.1496 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 86/250
# 910/910 - 6s - loss: 3.0546 - mean_squared_error: 3.0546 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 87/250
# 910/910 - 6s - loss: 2.9694 - mean_squared_error: 2.9694 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 88/250
# 910/910 - 6s - loss: 2.9893 - mean_squared_error: 2.9893 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 89/250
# 910/910 - 6s - loss: 3.0061 - mean_squared_error: 3.0061 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 90/250
# 910/910 - 6s - loss: 3.2594 - mean_squared_error: 3.2594 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 91/250
# 910/910 - 6s - loss: 2.8891 - mean_squared_error: 2.8891 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 92/250
# 910/910 - 6s - loss: 2.8035 - mean_squared_error: 2.8035 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 93/250
# 910/910 - 6s - loss: 2.8467 - mean_squared_error: 2.8467 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 94/250
# 910/910 - 6s - loss: 2.8483 - mean_squared_error: 2.8483 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 95/250
# 910/910 - 6s - loss: 2.5903 - mean_squared_error: 2.5903 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 96/250
# 910/910 - 6s - loss: 2.6627 - mean_squared_error: 2.6627 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 97/250
# 910/910 - 6s - loss: 2.6522 - mean_squared_error: 2.6522 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 98/250
# 910/910 - 7s - loss: 2.5772 - mean_squared_error: 2.5772 - accuracy: 0.0000e+00 - 7s/epoch - 8ms/step
# Epoch 99/250
# 910/910 - 7s - loss: 2.4529 - mean_squared_error: 2.4528 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 100/250
# 910/910 - 8s - loss: 2.4539 - mean_squared_error: 2.4539 - accuracy: 0.0000e+00 - val_loss: 3.8125 - val_mean_squared_error: 3.8125 - val_accuracy: 0.0000e+00 - 8s/epoch - 9ms/step
# Epoch 101/250
# 910/910 - 6s - loss: 2.5128 - mean_squared_error: 2.5128 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 102/250
# 910/910 - 6s - loss: 2.4547 - mean_squared_error: 2.4547 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 103/250
# 910/910 - 6s - loss: 2.2720 - mean_squared_error: 2.2720 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 104/250
# 910/910 - 6s - loss: 2.4356 - mean_squared_error: 2.4356 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 105/250
# 910/910 - 6s - loss: 2.3119 - mean_squared_error: 2.3119 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 106/250
# 910/910 - 6s - loss: 2.3351 - mean_squared_error: 2.3351 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 107/250
# 910/910 - 6s - loss: 2.2939 - mean_squared_error: 2.2939 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 108/250
# 910/910 - 7s - loss: 2.1530 - mean_squared_error: 2.1530 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 109/250
# 910/910 - 6s - loss: 2.2130 - mean_squared_error: 2.2130 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 110/250
# 910/910 - 6s - loss: 2.4667 - mean_squared_error: 2.4667 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 111/250
# 910/910 - 6s - loss: 2.1409 - mean_squared_error: 2.1409 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 112/250
# 910/910 - 6s - loss: 2.0032 - mean_squared_error: 2.0032 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 113/250
# 910/910 - 6s - loss: 2.0334 - mean_squared_error: 2.0334 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 114/250
# 910/910 - 6s - loss: 2.0245 - mean_squared_error: 2.0245 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 115/250
# 910/910 - 6s - loss: 2.1776 - mean_squared_error: 2.1776 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 116/250
# 910/910 - 6s - loss: 1.9323 - mean_squared_error: 1.9323 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 117/250
# 910/910 - 6s - loss: 2.0084 - mean_squared_error: 2.0084 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 118/250
# 910/910 - 6s - loss: 1.9421 - mean_squared_error: 1.9421 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 119/250
# 910/910 - 6s - loss: 1.7924 - mean_squared_error: 1.7924 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 120/250
# 910/910 - 6s - loss: 2.1154 - mean_squared_error: 2.1154 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 121/250
# 910/910 - 6s - loss: 2.0887 - mean_squared_error: 2.0887 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 122/250
# 910/910 - 7s - loss: 1.8025 - mean_squared_error: 1.8025 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 123/250
# 910/910 - 6s - loss: 1.6465 - mean_squared_error: 1.6465 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 124/250
# 910/910 - 6s - loss: 2.3470 - mean_squared_error: 2.3470 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 125/250
# 910/910 - 6s - loss: 1.8813 - mean_squared_error: 1.8813 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 126/250
# 910/910 - 6s - loss: 1.6330 - mean_squared_error: 1.6330 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 127/250
# 910/910 - 6s - loss: 1.9209 - mean_squared_error: 1.9209 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 128/250
# 910/910 - 7s - loss: 1.6498 - mean_squared_error: 1.6498 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 129/250
# 910/910 - 6s - loss: 1.6800 - mean_squared_error: 1.6800 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 130/250
# 910/910 - 6s - loss: 1.7314 - mean_squared_error: 1.7314 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 131/250
# 910/910 - 7s - loss: 1.9006 - mean_squared_error: 1.9006 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 132/250
# 910/910 - 6s - loss: 1.6835 - mean_squared_error: 1.6835 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 133/250
# 910/910 - 6s - loss: 1.9953 - mean_squared_error: 1.9953 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 134/250
# 910/910 - 6s - loss: 2.0614 - mean_squared_error: 2.0614 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 135/250
# 910/910 - 6s - loss: 1.5302 - mean_squared_error: 1.5302 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 136/250
# 910/910 - 7s - loss: 1.5053 - mean_squared_error: 1.5053 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 137/250
# 910/910 - 6s - loss: 1.6111 - mean_squared_error: 1.6111 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 138/250
# 910/910 - 7s - loss: 1.6380 - mean_squared_error: 1.6380 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 139/250
# 910/910 - 6s - loss: 1.8039 - mean_squared_error: 1.8039 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 140/250
# 910/910 - 6s - loss: 1.8673 - mean_squared_error: 1.8673 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 141/250
# 910/910 - 6s - loss: 1.4594 - mean_squared_error: 1.4594 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 142/250
# 910/910 - 6s - loss: 1.6109 - mean_squared_error: 1.6109 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 143/250
# 910/910 - 6s - loss: 1.4611 - mean_squared_error: 1.4611 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 144/250
# 910/910 - 6s - loss: 1.7264 - mean_squared_error: 1.7264 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 145/250
# 910/910 - 6s - loss: 1.7327 - mean_squared_error: 1.7327 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 146/250
# 910/910 - 6s - loss: 1.5661 - mean_squared_error: 1.5661 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 147/250
# 910/910 - 6s - loss: 1.7869 - mean_squared_error: 1.7869 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 148/250
# 910/910 - 6s - loss: 1.3139 - mean_squared_error: 1.3139 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 149/250
# 910/910 - 6s - loss: 1.5205 - mean_squared_error: 1.5205 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 150/250
# 910/910 - 6s - loss: 1.4986 - mean_squared_error: 1.4986 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 151/250
# 910/910 - 6s - loss: 1.4209 - mean_squared_error: 1.4209 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 152/250
# 910/910 - 6s - loss: 1.2960 - mean_squared_error: 1.2960 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 153/250
# 910/910 - 6s - loss: 1.5740 - mean_squared_error: 1.5740 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 154/250
# 910/910 - 6s - loss: 1.3551 - mean_squared_error: 1.3551 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 155/250
# 910/910 - 6s - loss: 1.6226 - mean_squared_error: 1.6226 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 156/250
# 910/910 - 6s - loss: 1.5082 - mean_squared_error: 1.5082 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 157/250
# 910/910 - 6s - loss: 1.6457 - mean_squared_error: 1.6457 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 158/250
# 910/910 - 6s - loss: 1.2623 - mean_squared_error: 1.2623 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 159/250
# 910/910 - 6s - loss: 1.1803 - mean_squared_error: 1.1803 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 160/250
# 910/910 - 6s - loss: 1.3225 - mean_squared_error: 1.3225 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 161/250
# 910/910 - 6s - loss: 1.6486 - mean_squared_error: 1.6486 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 162/250
# 910/910 - 6s - loss: 1.3708 - mean_squared_error: 1.3708 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 163/250
# 910/910 - 6s - loss: 1.2061 - mean_squared_error: 1.2061 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 164/250
# 910/910 - 6s - loss: 1.6103 - mean_squared_error: 1.6103 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 165/250
# 910/910 - 6s - loss: 1.2341 - mean_squared_error: 1.2341 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 166/250
# 910/910 - 6s - loss: 1.2100 - mean_squared_error: 1.2100 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 167/250
# 910/910 - 6s - loss: 1.2691 - mean_squared_error: 1.2691 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 168/250
# 910/910 - 6s - loss: 1.3414 - mean_squared_error: 1.3414 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 169/250
# 910/910 - 6s - loss: 1.4729 - mean_squared_error: 1.4729 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 170/250
# 910/910 - 7s - loss: 1.3473 - mean_squared_error: 1.3473 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 171/250
# 910/910 - 7s - loss: 1.0951 - mean_squared_error: 1.0951 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 172/250
# 910/910 - 6s - loss: 1.1886 - mean_squared_error: 1.1886 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 173/250
# 910/910 - 6s - loss: 1.4664 - mean_squared_error: 1.4664 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 174/250
# 910/910 - 6s - loss: 1.0915 - mean_squared_error: 1.0915 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 175/250
# 910/910 - 6s - loss: 1.1947 - mean_squared_error: 1.1947 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 176/250
# 910/910 - 6s - loss: 1.1869 - mean_squared_error: 1.1869 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 177/250
# 910/910 - 6s - loss: 1.1402 - mean_squared_error: 1.1402 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 178/250
# 910/910 - 6s - loss: 1.1425 - mean_squared_error: 1.1425 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 179/250
# 910/910 - 6s - loss: 1.1500 - mean_squared_error: 1.1500 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 180/250
# 910/910 - 6s - loss: 2.9482 - mean_squared_error: 2.9482 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 181/250
# 910/910 - 6s - loss: 1.7078 - mean_squared_error: 1.7078 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 182/250
# 910/910 - 6s - loss: 1.3319 - mean_squared_error: 1.3319 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 183/250
# 910/910 - 6s - loss: 1.2422 - mean_squared_error: 1.2422 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 184/250
# 910/910 - 6s - loss: 1.3052 - mean_squared_error: 1.3052 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 185/250
# 910/910 - 6s - loss: 1.3128 - mean_squared_error: 1.3128 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 186/250
# 910/910 - 6s - loss: 1.1685 - mean_squared_error: 1.1685 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 187/250
# 910/910 - 6s - loss: 1.2326 - mean_squared_error: 1.2326 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 188/250
# 910/910 - 6s - loss: 1.1976 - mean_squared_error: 1.1976 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 189/250
# 910/910 - 6s - loss: 1.1387 - mean_squared_error: 1.1387 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 190/250
# 910/910 - 6s - loss: 1.1071 - mean_squared_error: 1.1071 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 191/250
# 910/910 - 6s - loss: 1.5273 - mean_squared_error: 1.5273 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 192/250
# 910/910 - 6s - loss: 1.1880 - mean_squared_error: 1.1880 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 193/250
# 910/910 - 6s - loss: 1.1502 - mean_squared_error: 1.1502 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 194/250
# 910/910 - 6s - loss: 1.1270 - mean_squared_error: 1.1270 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 195/250
# 910/910 - 6s - loss: 1.1359 - mean_squared_error: 1.1359 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 196/250
# 910/910 - 6s - loss: 1.0671 - mean_squared_error: 1.0671 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 197/250
# 910/910 - 6s - loss: 1.1225 - mean_squared_error: 1.1225 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 198/250
# 910/910 - 6s - loss: 1.0397 - mean_squared_error: 1.0397 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 199/250
# 910/910 - 6s - loss: 1.0725 - mean_squared_error: 1.0725 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 200/250
# 910/910 - 6s - loss: 0.9666 - mean_squared_error: 0.9666 - accuracy: 0.0000e+00 - val_loss: 3.1769 - val_mean_squared_error: 3.1769 - val_accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 201/250
# 910/910 - 6s - loss: 1.0972 - mean_squared_error: 1.0972 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 202/250
# 910/910 - 6s - loss: 1.2220 - mean_squared_error: 1.2220 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 203/250
# 910/910 - 6s - loss: 1.0241 - mean_squared_error: 1.0241 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 204/250
# 910/910 - 6s - loss: 1.1501 - mean_squared_error: 1.1501 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 205/250
# 910/910 - 6s - loss: 1.1596 - mean_squared_error: 1.1596 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 206/250
# 910/910 - 6s - loss: 1.2758 - mean_squared_error: 1.2758 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 207/250
# 910/910 - 6s - loss: 0.9538 - mean_squared_error: 0.9538 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 208/250
# 910/910 - 6s - loss: 0.9220 - mean_squared_error: 0.9220 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 209/250
# 910/910 - 6s - loss: 1.0214 - mean_squared_error: 1.0214 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 210/250
# 910/910 - 5s - loss: 0.9906 - mean_squared_error: 0.9906 - accuracy: 0.0000e+00 - 5s/epoch - 6ms/step
# Epoch 211/250
# 910/910 - 6s - loss: 1.1574 - mean_squared_error: 1.1574 - accuracy: 0.0000e+00 - 6s/epoch - 6ms/step
# Epoch 212/250
# 910/910 - 6s - loss: 0.9632 - mean_squared_error: 0.9632 - accuracy: 0.0000e+00 - 6s/epoch - 7ms/step
# Epoch 213/250
# 910/910 - 7s - loss: 1.1269 - mean_squared_error: 1.1269 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 214/250
# 910/910 - 7s - loss: 0.9430 - mean_squared_error: 0.9430 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 215/250
# 910/910 - 7s - loss: 0.9248 - mean_squared_error: 0.9248 - accuracy: 0.0000e+00 - 7s/epoch - 8ms/step
# Epoch 216/250
# 910/910 - 7s - loss: 1.1618 - mean_squared_error: 1.1618 - accuracy: 0.0000e+00 - 7s/epoch - 8ms/step
# Epoch 217/250
# 910/910 - 7s - loss: 0.9246 - mean_squared_error: 0.9246 - accuracy: 0.0000e+00 - 7s/epoch - 7ms/step
# Epoch 218/250

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")

# %%
from keras.utils import plot_model,model_to_dot
plot_model(model2, show_shapes=True, to_file='plotmodelbilstm0810.png')

# %%
model_to_dot(model2,show_shapes=True)

# %%
model2
