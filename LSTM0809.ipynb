# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# c:\Python\Python310\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
df=df.iloc[200000:205000]
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 35.0489          0.0    -15.8150    -3.78100         NaN
#           35.0609          0.0    -14.8850    -3.91760         NaN
#           35.0629          0.0    -14.5760    -3.74700         NaN
#           35.0649          0.0    -14.7640    -3.88940         NaN
#           35.0669          0.0    -14.4410    -3.83180         NaN
# ...                        ...         ...         ...         ...
# -120.4027 36.7274          0.0     -7.2276     0.73694      2.6327
#           36.7294          0.0     -7.3210     0.70109      2.4708
#           36.7314          0.0     -7.2388     0.46256      2.4291
#           36.7334          0.0     -7.2526     0.31420      2.0908
#           36.7394          0.0     -7.1203    -0.03439      2.3198
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 35.0489     -3.81260     -3.4671    -7.75040    -3.56890
#           35.0609     -3.91700     -3.2592    -7.92540    -3.72760
#           35.0629     -3.68630     -2.8954    -7.46720    -3.42460
#           35.0649     -3.80730     -3.1875    -7.69430    -3.64120
#           35.0669     -3.79350     -3.2384    -7.74860    -3.69970
# ...                        ...         ...         ...         ...
# -120.4027 36.7274     -0.37212      4.1269    -0.77547     1.42630
#           36.7294     -0.53777      3.9807    -0.90438     1.26980
#           36.7314     -0.72740      3.7277    -1.12300     0.91064
#           36.7334     -1.04390      3.4792    -1.13890     0.93199
#           36.7394     -0.72105      3.6205    -1.04990     0.92451
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 35.0489      -4.4897    -1.66720  ...    -10.3170     -7.5373
#           35.0609      -4.8079    -2.08030  ...    -11.7620     -8.9301
#           35.0629      -4.4473    -1.83730  ...    -13.1510    -10.2660
#           35.0649      -4.7031    -2.02100  ...    -13.0580    -10.2560
#           35.0669      -4.7355    -1.97580  ...    -13.5610    -10.7640
# ...                        ...         ...  ...         ...         ...
# -120.4027 36.7274       3.9578    -0.83484  ...     -4.7423     -1.7626
#           36.7294       3.9292    -0.64295  ...     -4.2087     -1.2368
#           36.7314       3.6537    -0.98271  ...     -4.7961     -1.8559
#           36.7334       3.3421    -1.11060  ...     -5.8926     -2.9637
#           36.7394       3.2634    -1.40170  ...     -5.4141     -2.5313
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 35.0489      -8.7209    -11.2120    -10.7480    -13.2020
#           35.0609     -10.2470    -12.6600    -12.4420    -14.9950
#           35.0629     -11.6180    -14.0450    -13.8780    -16.5090
#           35.0649     -11.5870    -14.0190    -13.8640    -16.4920
#           35.0669     -12.1090    -14.5200    -14.3170    -16.9960
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -2.7142     -3.0876     -6.2273     -5.2793
#           36.7294      -2.1775     -2.5592     -5.7036     -4.6893
#           36.7314      -2.7951     -3.1822     -6.3403     -5.3780
#           36.7334      -3.8852     -4.2657     -7.4344     -6.3047
#           36.7394      -3.4532     -3.8240     -6.9644     -6.0637
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 35.0489      -9.2688     -6.4277     -7.5077    -7.91640
#           35.0609     -10.4110     -7.9618     -8.9148    -9.43790
#           35.0629     -11.8270     -9.3040    -10.4320   -10.78100
#           35.0649     -11.8730     -9.2702    -10.3670   -10.75000
#           35.0669     -12.2140     -9.7466    -10.6810   -11.29000
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -4.3728     -2.3947     -2.9965    -1.00440
#           36.7294      -3.7768     -1.8226     -2.4654    -0.46636
#           36.7314      -4.5069     -2.6101     -3.2475    -1.26730
#           36.7334      -5.4811     -3.6036     -4.2325    -2.30970
#           36.7394      -5.2230     -3.3785     -4.0178    -2.04980
#
# [5000 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    for row in range(0,len(datain.index),1750): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model = Sequential(name="LSTM-Model") # Model
model.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))

model.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))
#model.add(LSTM(units=50, activation='relu'), name='Hidden-LSTM-Encoder-Layer') # Encoder Layer
model.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
model.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %% [markdown]
# ##### Train model

# %%
history = model.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 109/109 - 3s - loss: 34.5712 - mean_squared_error: 34.5712 - mean_absolute_error: 4.7175 - 3s/epoch - 27ms/step
# Epoch 2/250
# 109/109 - 1s - loss: 18.6372 - mean_squared_error: 18.6372 - mean_absolute_error: 3.3506 - 712ms/epoch - 7ms/step
# Epoch 3/250
# 109/109 - 1s - loss: 14.9785 - mean_squared_error: 14.9785 - mean_absolute_error: 3.0188 - 701ms/epoch - 6ms/step
# Epoch 4/250
# 109/109 - 1s - loss: 13.1982 - mean_squared_error: 13.1982 - mean_absolute_error: 2.8255 - 711ms/epoch - 7ms/step
# Epoch 5/250
# 109/109 - 1s - loss: 12.5936 - mean_squared_error: 12.5936 - mean_absolute_error: 2.7720 - 693ms/epoch - 6ms/step
# Epoch 6/250
# 109/109 - 1s - loss: 12.0015 - mean_squared_error: 12.0015 - mean_absolute_error: 2.7215 - 714ms/epoch - 7ms/step
# Epoch 7/250
# 109/109 - 1s - loss: 11.3257 - mean_squared_error: 11.3257 - mean_absolute_error: 2.6290 - 689ms/epoch - 6ms/step
# Epoch 8/250
# 109/109 - 1s - loss: 11.0044 - mean_squared_error: 11.0044 - mean_absolute_error: 2.6073 - 737ms/epoch - 7ms/step
# Epoch 9/250
# 109/109 - 1s - loss: 10.4478 - mean_squared_error: 10.4478 - mean_absolute_error: 2.5204 - 750ms/epoch - 7ms/step
# Epoch 10/250
# 109/109 - 1s - loss: 10.2262 - mean_squared_error: 10.2261 - mean_absolute_error: 2.4983 - 751ms/epoch - 7ms/step
# Epoch 11/250
# 109/109 - 1s - loss: 9.9699 - mean_squared_error: 9.9699 - mean_absolute_error: 2.4644 - 733ms/epoch - 7ms/step
# Epoch 12/250
# 109/109 - 1s - loss: 10.0114 - mean_squared_error: 10.0114 - mean_absolute_error: 2.4689 - 823ms/epoch - 8ms/step
# Epoch 13/250
# 109/109 - 1s - loss: 9.7189 - mean_squared_error: 9.7189 - mean_absolute_error: 2.4321 - 815ms/epoch - 7ms/step
# Epoch 14/250
# 109/109 - 1s - loss: 9.4375 - mean_squared_error: 9.4375 - mean_absolute_error: 2.3887 - 737ms/epoch - 7ms/step
# Epoch 15/250
# 109/109 - 1s - loss: 9.3872 - mean_squared_error: 9.3872 - mean_absolute_error: 2.3776 - 736ms/epoch - 7ms/step
# Epoch 16/250
# 109/109 - 1s - loss: 9.1835 - mean_squared_error: 9.1835 - mean_absolute_error: 2.3480 - 814ms/epoch - 7ms/step
# Epoch 17/250
# 109/109 - 1s - loss: 9.1899 - mean_squared_error: 9.1899 - mean_absolute_error: 2.3470 - 690ms/epoch - 6ms/step
# Epoch 18/250
# 109/109 - 1s - loss: 8.8727 - mean_squared_error: 8.8727 - mean_absolute_error: 2.3085 - 683ms/epoch - 6ms/step
# Epoch 19/250
# 109/109 - 1s - loss: 8.5396 - mean_squared_error: 8.5396 - mean_absolute_error: 2.2503 - 661ms/epoch - 6ms/step
# Epoch 20/250
# 109/109 - 1s - loss: 8.5919 - mean_squared_error: 8.5919 - mean_absolute_error: 2.2590 - 682ms/epoch - 6ms/step
# Epoch 21/250
# 109/109 - 1s - loss: 8.2788 - mean_squared_error: 8.2788 - mean_absolute_error: 2.2055 - 690ms/epoch - 6ms/step
# Epoch 22/250
# 109/109 - 1s - loss: 8.0344 - mean_squared_error: 8.0344 - mean_absolute_error: 2.1670 - 679ms/epoch - 6ms/step
# Epoch 23/250
# 109/109 - 1s - loss: 7.6868 - mean_squared_error: 7.6868 - mean_absolute_error: 2.1135 - 657ms/epoch - 6ms/step
# Epoch 24/250
# 109/109 - 1s - loss: 7.5104 - mean_squared_error: 7.5104 - mean_absolute_error: 2.0736 - 653ms/epoch - 6ms/step
# Epoch 25/250
# 109/109 - 1s - loss: 7.0910 - mean_squared_error: 7.0910 - mean_absolute_error: 2.0072 - 678ms/epoch - 6ms/step
# Epoch 26/250
# 109/109 - 1s - loss: 7.0670 - mean_squared_error: 7.0670 - mean_absolute_error: 1.9916 - 669ms/epoch - 6ms/step
# Epoch 27/250
# 109/109 - 1s - loss: 6.7288 - mean_squared_error: 6.7288 - mean_absolute_error: 1.9294 - 645ms/epoch - 6ms/step
# Epoch 28/250
# 109/109 - 1s - loss: 6.4672 - mean_squared_error: 6.4672 - mean_absolute_error: 1.8900 - 706ms/epoch - 6ms/step
# Epoch 29/250
# 109/109 - 1s - loss: 6.1834 - mean_squared_error: 6.1834 - mean_absolute_error: 1.8372 - 696ms/epoch - 6ms/step
# Epoch 30/250
# 109/109 - 1s - loss: 6.0920 - mean_squared_error: 6.0920 - mean_absolute_error: 1.8107 - 695ms/epoch - 6ms/step
# Epoch 31/250
# 109/109 - 1s - loss: 6.0692 - mean_squared_error: 6.0692 - mean_absolute_error: 1.7965 - 643ms/epoch - 6ms/step
# Epoch 32/250
# 109/109 - 1s - loss: 5.9107 - mean_squared_error: 5.9107 - mean_absolute_error: 1.7772 - 632ms/epoch - 6ms/step
# Epoch 33/250
# 109/109 - 1s - loss: 5.7646 - mean_squared_error: 5.7646 - mean_absolute_error: 1.7551 - 678ms/epoch - 6ms/step
# Epoch 34/250
# 109/109 - 1s - loss: 5.7490 - mean_squared_error: 5.7490 - mean_absolute_error: 1.7225 - 638ms/epoch - 6ms/step
# Epoch 35/250
# 109/109 - 1s - loss: 5.5044 - mean_squared_error: 5.5044 - mean_absolute_error: 1.6799 - 639ms/epoch - 6ms/step
# Epoch 36/250
# 109/109 - 1s - loss: 5.2623 - mean_squared_error: 5.2623 - mean_absolute_error: 1.6353 - 632ms/epoch - 6ms/step
# Epoch 37/250
# 109/109 - 1s - loss: 5.3335 - mean_squared_error: 5.3335 - mean_absolute_error: 1.6569 - 630ms/epoch - 6ms/step
# Epoch 38/250
# 109/109 - 1s - loss: 5.0719 - mean_squared_error: 5.0719 - mean_absolute_error: 1.5867 - 641ms/epoch - 6ms/step
# Epoch 39/250
# 109/109 - 1s - loss: 5.0334 - mean_squared_error: 5.0334 - mean_absolute_error: 1.5838 - 637ms/epoch - 6ms/step
# Epoch 40/250
# 109/109 - 1s - loss: 5.1262 - mean_squared_error: 5.1262 - mean_absolute_error: 1.6128 - 656ms/epoch - 6ms/step
# Epoch 41/250
# 109/109 - 1s - loss: 4.7898 - mean_squared_error: 4.7898 - mean_absolute_error: 1.5257 - 646ms/epoch - 6ms/step
# Epoch 42/250
# 109/109 - 1s - loss: 4.9148 - mean_squared_error: 4.9148 - mean_absolute_error: 1.5490 - 640ms/epoch - 6ms/step
# Epoch 43/250
# 109/109 - 1s - loss: 4.8682 - mean_squared_error: 4.8682 - mean_absolute_error: 1.5410 - 662ms/epoch - 6ms/step
# Epoch 44/250
# 109/109 - 1s - loss: 4.7230 - mean_squared_error: 4.7230 - mean_absolute_error: 1.4994 - 652ms/epoch - 6ms/step
# Epoch 45/250
# 109/109 - 1s - loss: 4.7697 - mean_squared_error: 4.7697 - mean_absolute_error: 1.5160 - 675ms/epoch - 6ms/step
# Epoch 46/250
# 109/109 - 1s - loss: 4.6113 - mean_squared_error: 4.6113 - mean_absolute_error: 1.4743 - 658ms/epoch - 6ms/step
# Epoch 47/250
# 109/109 - 1s - loss: 4.5296 - mean_squared_error: 4.5296 - mean_absolute_error: 1.4481 - 638ms/epoch - 6ms/step
# Epoch 48/250
# 109/109 - 1s - loss: 4.4792 - mean_squared_error: 4.4792 - mean_absolute_error: 1.4419 - 639ms/epoch - 6ms/step
# Epoch 49/250
# 109/109 - 1s - loss: 4.5605 - mean_squared_error: 4.5605 - mean_absolute_error: 1.4677 - 638ms/epoch - 6ms/step
# Epoch 50/250
# 109/109 - 1s - loss: 4.6122 - mean_squared_error: 4.6122 - mean_absolute_error: 1.4766 - 661ms/epoch - 6ms/step
# Epoch 51/250
# 109/109 - 1s - loss: 4.4059 - mean_squared_error: 4.4059 - mean_absolute_error: 1.4348 - 633ms/epoch - 6ms/step
# Epoch 52/250
# 109/109 - 1s - loss: 4.3043 - mean_squared_error: 4.3043 - mean_absolute_error: 1.3858 - 666ms/epoch - 6ms/step
# Epoch 53/250
# 109/109 - 1s - loss: 4.3406 - mean_squared_error: 4.3406 - mean_absolute_error: 1.4136 - 657ms/epoch - 6ms/step
# Epoch 54/250
# 109/109 - 1s - loss: 4.2554 - mean_squared_error: 4.2554 - mean_absolute_error: 1.3870 - 641ms/epoch - 6ms/step
# Epoch 55/250
# 109/109 - 1s - loss: 4.1929 - mean_squared_error: 4.1929 - mean_absolute_error: 1.3697 - 633ms/epoch - 6ms/step
# Epoch 56/250
# 109/109 - 1s - loss: 4.1996 - mean_squared_error: 4.1996 - mean_absolute_error: 1.3766 - 630ms/epoch - 6ms/step
# Epoch 57/250
# 109/109 - 1s - loss: 4.3435 - mean_squared_error: 4.3435 - mean_absolute_error: 1.4133 - 635ms/epoch - 6ms/step
# Epoch 58/250
# 109/109 - 1s - loss: 4.2294 - mean_squared_error: 4.2294 - mean_absolute_error: 1.3925 - 634ms/epoch - 6ms/step
# Epoch 59/250
# 109/109 - 1s - loss: 4.2941 - mean_squared_error: 4.2941 - mean_absolute_error: 1.3892 - 659ms/epoch - 6ms/step
# Epoch 60/250
# 109/109 - 1s - loss: 4.2139 - mean_squared_error: 4.2139 - mean_absolute_error: 1.3750 - 650ms/epoch - 6ms/step
# Epoch 61/250
# 109/109 - 1s - loss: 3.9594 - mean_squared_error: 3.9594 - mean_absolute_error: 1.3016 - 701ms/epoch - 6ms/step
# Epoch 62/250
# 109/109 - 1s - loss: 3.8843 - mean_squared_error: 3.8843 - mean_absolute_error: 1.2879 - 737ms/epoch - 7ms/step
# Epoch 63/250
# 109/109 - 1s - loss: 4.0979 - mean_squared_error: 4.0979 - mean_absolute_error: 1.3301 - 750ms/epoch - 7ms/step
# Epoch 64/250
# 109/109 - 1s - loss: 4.0506 - mean_squared_error: 4.0506 - mean_absolute_error: 1.3212 - 688ms/epoch - 6ms/step
# Epoch 65/250
# 109/109 - 1s - loss: 3.9299 - mean_squared_error: 3.9299 - mean_absolute_error: 1.3074 - 645ms/epoch - 6ms/step
# Epoch 66/250
# 109/109 - 1s - loss: 3.8098 - mean_squared_error: 3.8098 - mean_absolute_error: 1.2648 - 695ms/epoch - 6ms/step
# Epoch 67/250
# 109/109 - 1s - loss: 3.7728 - mean_squared_error: 3.7728 - mean_absolute_error: 1.2463 - 646ms/epoch - 6ms/step
# Epoch 68/250
# 109/109 - 1s - loss: 3.8532 - mean_squared_error: 3.8531 - mean_absolute_error: 1.2572 - 679ms/epoch - 6ms/step
# Epoch 69/250
# 109/109 - 1s - loss: 3.7242 - mean_squared_error: 3.7242 - mean_absolute_error: 1.2321 - 685ms/epoch - 6ms/step
# Epoch 70/250
# 109/109 - 1s - loss: 3.8417 - mean_squared_error: 3.8417 - mean_absolute_error: 1.2775 - 685ms/epoch - 6ms/step
# Epoch 71/250
# 109/109 - 1s - loss: 3.6705 - mean_squared_error: 3.6705 - mean_absolute_error: 1.2266 - 685ms/epoch - 6ms/step
# Epoch 72/250
# 109/109 - 1s - loss: 3.7669 - mean_squared_error: 3.7669 - mean_absolute_error: 1.2559 - 678ms/epoch - 6ms/step
# Epoch 73/250
# 109/109 - 1s - loss: 3.5792 - mean_squared_error: 3.5792 - mean_absolute_error: 1.1892 - 672ms/epoch - 6ms/step
# Epoch 74/250
# 109/109 - 1s - loss: 3.6752 - mean_squared_error: 3.6752 - mean_absolute_error: 1.2160 - 679ms/epoch - 6ms/step
# Epoch 75/250
# 109/109 - 1s - loss: 3.7333 - mean_squared_error: 3.7333 - mean_absolute_error: 1.2438 - 659ms/epoch - 6ms/step
# Epoch 76/250
# 109/109 - 1s - loss: 3.6525 - mean_squared_error: 3.6525 - mean_absolute_error: 1.2259 - 743ms/epoch - 7ms/step
# Epoch 77/250
# 109/109 - 1s - loss: 3.6203 - mean_squared_error: 3.6203 - mean_absolute_error: 1.2227 - 717ms/epoch - 7ms/step
# Epoch 78/250
# 109/109 - 1s - loss: 3.6024 - mean_squared_error: 3.6024 - mean_absolute_error: 1.2188 - 667ms/epoch - 6ms/step
# Epoch 79/250
# 109/109 - 1s - loss: 3.4942 - mean_squared_error: 3.4942 - mean_absolute_error: 1.1740 - 721ms/epoch - 7ms/step
# Epoch 80/250
# 109/109 - 1s - loss: 3.4975 - mean_squared_error: 3.4975 - mean_absolute_error: 1.1766 - 684ms/epoch - 6ms/step
# Epoch 81/250
# 109/109 - 1s - loss: 3.4750 - mean_squared_error: 3.4750 - mean_absolute_error: 1.1622 - 664ms/epoch - 6ms/step
# Epoch 82/250
# 109/109 - 1s - loss: 3.6148 - mean_squared_error: 3.6148 - mean_absolute_error: 1.2304 - 739ms/epoch - 7ms/step
# Epoch 83/250
# 109/109 - 1s - loss: 3.4512 - mean_squared_error: 3.4512 - mean_absolute_error: 1.1591 - 792ms/epoch - 7ms/step
# Epoch 84/250
# 109/109 - 1s - loss: 3.4991 - mean_squared_error: 3.4991 - mean_absolute_error: 1.1693 - 778ms/epoch - 7ms/step
# Epoch 85/250
# 109/109 - 1s - loss: 3.3885 - mean_squared_error: 3.3885 - mean_absolute_error: 1.1391 - 739ms/epoch - 7ms/step
# Epoch 86/250
# 109/109 - 1s - loss: 3.4361 - mean_squared_error: 3.4361 - mean_absolute_error: 1.1500 - 702ms/epoch - 6ms/step
# Epoch 87/250
# 109/109 - 1s - loss: 3.3931 - mean_squared_error: 3.3931 - mean_absolute_error: 1.1403 - 702ms/epoch - 6ms/step
# Epoch 88/250
# 109/109 - 1s - loss: 3.4156 - mean_squared_error: 3.4156 - mean_absolute_error: 1.1542 - 695ms/epoch - 6ms/step
# Epoch 89/250
# 109/109 - 1s - loss: 3.4215 - mean_squared_error: 3.4215 - mean_absolute_error: 1.1667 - 686ms/epoch - 6ms/step
# Epoch 90/250
# 109/109 - 1s - loss: 3.3838 - mean_squared_error: 3.3838 - mean_absolute_error: 1.1373 - 702ms/epoch - 6ms/step
# Epoch 91/250
# 109/109 - 1s - loss: 3.3180 - mean_squared_error: 3.3180 - mean_absolute_error: 1.1160 - 705ms/epoch - 6ms/step
# Epoch 92/250
# 109/109 - 1s - loss: 3.2266 - mean_squared_error: 3.2266 - mean_absolute_error: 1.0783 - 703ms/epoch - 6ms/step
# Epoch 93/250
# 109/109 - 1s - loss: 3.5025 - mean_squared_error: 3.5025 - mean_absolute_error: 1.1672 - 692ms/epoch - 6ms/step
# Epoch 94/250
# 109/109 - 1s - loss: 3.2877 - mean_squared_error: 3.2877 - mean_absolute_error: 1.1122 - 703ms/epoch - 6ms/step
# Epoch 95/250
# 109/109 - 1s - loss: 3.2228 - mean_squared_error: 3.2228 - mean_absolute_error: 1.0933 - 715ms/epoch - 7ms/step
# Epoch 96/250
# 109/109 - 1s - loss: 3.1814 - mean_squared_error: 3.1814 - mean_absolute_error: 1.0675 - 708ms/epoch - 6ms/step
# Epoch 97/250
# 109/109 - 1s - loss: 3.2526 - mean_squared_error: 3.2526 - mean_absolute_error: 1.0909 - 691ms/epoch - 6ms/step
# Epoch 98/250
# 109/109 - 1s - loss: 3.2229 - mean_squared_error: 3.2229 - mean_absolute_error: 1.1047 - 701ms/epoch - 6ms/step
# Epoch 99/250
# 109/109 - 1s - loss: 3.2312 - mean_squared_error: 3.2312 - mean_absolute_error: 1.0977 - 696ms/epoch - 6ms/step
# Epoch 100/250
# 109/109 - 2s - loss: 3.1368 - mean_squared_error: 3.1368 - mean_absolute_error: 1.0642 - val_loss: 36.1211 - val_mean_squared_error: 36.1211 - val_mean_absolute_error: 5.2618 - 2s/epoch - 14ms/step
# Epoch 101/250
# 109/109 - 1s - loss: 3.1395 - mean_squared_error: 3.1395 - mean_absolute_error: 1.0500 - 709ms/epoch - 7ms/step
# Epoch 102/250
# 109/109 - 1s - loss: 3.2011 - mean_squared_error: 3.2011 - mean_absolute_error: 1.0830 - 700ms/epoch - 6ms/step
# Epoch 103/250
# 109/109 - 1s - loss: 3.1495 - mean_squared_error: 3.1495 - mean_absolute_error: 1.0702 - 697ms/epoch - 6ms/step
# Epoch 104/250
# 109/109 - 1s - loss: 3.1283 - mean_squared_error: 3.1283 - mean_absolute_error: 1.0640 - 705ms/epoch - 6ms/step
# Epoch 105/250
# 109/109 - 1s - loss: 3.1092 - mean_squared_error: 3.1092 - mean_absolute_error: 1.0579 - 693ms/epoch - 6ms/step
# Epoch 106/250
# 109/109 - 1s - loss: 3.0972 - mean_squared_error: 3.0972 - mean_absolute_error: 1.0439 - 714ms/epoch - 7ms/step
# Epoch 107/250
# 109/109 - 1s - loss: 3.0936 - mean_squared_error: 3.0936 - mean_absolute_error: 1.0420 - 719ms/epoch - 7ms/step
# Epoch 108/250
# 109/109 - 1s - loss: 3.0307 - mean_squared_error: 3.0307 - mean_absolute_error: 1.0233 - 706ms/epoch - 6ms/step
# Epoch 109/250
# 109/109 - 1s - loss: 3.1612 - mean_squared_error: 3.1612 - mean_absolute_error: 1.0770 - 705ms/epoch - 6ms/step
# Epoch 110/250
# 109/109 - 1s - loss: 3.0113 - mean_squared_error: 3.0113 - mean_absolute_error: 1.0225 - 719ms/epoch - 7ms/step
# Epoch 111/250
# 109/109 - 1s - loss: 3.0104 - mean_squared_error: 3.0104 - mean_absolute_error: 1.0300 - 710ms/epoch - 7ms/step
# Epoch 112/250
# 109/109 - 1s - loss: 3.0224 - mean_squared_error: 3.0224 - mean_absolute_error: 1.0275 - 710ms/epoch - 7ms/step
# Epoch 113/250
# 109/109 - 1s - loss: 3.0321 - mean_squared_error: 3.0321 - mean_absolute_error: 1.0263 - 716ms/epoch - 7ms/step
# Epoch 114/250
# 109/109 - 1s - loss: 3.0262 - mean_squared_error: 3.0262 - mean_absolute_error: 1.0215 - 704ms/epoch - 6ms/step
# Epoch 115/250
# 109/109 - 1s - loss: 2.9723 - mean_squared_error: 2.9723 - mean_absolute_error: 1.0134 - 715ms/epoch - 7ms/step
# Epoch 116/250
# 109/109 - 1s - loss: 2.9880 - mean_squared_error: 2.9880 - mean_absolute_error: 1.0010 - 720ms/epoch - 7ms/step
# Epoch 117/250
# 109/109 - 1s - loss: 2.9500 - mean_squared_error: 2.9500 - mean_absolute_error: 0.9983 - 720ms/epoch - 7ms/step
# Epoch 118/250
# 109/109 - 1s - loss: 2.9044 - mean_squared_error: 2.9044 - mean_absolute_error: 0.9840 - 724ms/epoch - 7ms/step
# Epoch 119/250
# 109/109 - 1s - loss: 2.9619 - mean_squared_error: 2.9619 - mean_absolute_error: 1.0178 - 719ms/epoch - 7ms/step
# Epoch 120/250
# 109/109 - 1s - loss: 2.9188 - mean_squared_error: 2.9188 - mean_absolute_error: 1.0105 - 709ms/epoch - 7ms/step
# Epoch 121/250
# 109/109 - 1s - loss: 2.9606 - mean_squared_error: 2.9606 - mean_absolute_error: 1.0157 - 696ms/epoch - 6ms/step
# Epoch 122/250
# 109/109 - 1s - loss: 2.8816 - mean_squared_error: 2.8816 - mean_absolute_error: 0.9727 - 708ms/epoch - 6ms/step
# Epoch 123/250
# 109/109 - 1s - loss: 2.9433 - mean_squared_error: 2.9433 - mean_absolute_error: 0.9996 - 716ms/epoch - 7ms/step
# Epoch 124/250
# 109/109 - 1s - loss: 2.8723 - mean_squared_error: 2.8723 - mean_absolute_error: 0.9767 - 699ms/epoch - 6ms/step
# Epoch 125/250
# 109/109 - 1s - loss: 2.8544 - mean_squared_error: 2.8544 - mean_absolute_error: 0.9793 - 701ms/epoch - 6ms/step
# Epoch 126/250
# 109/109 - 1s - loss: 2.9050 - mean_squared_error: 2.9050 - mean_absolute_error: 0.9990 - 703ms/epoch - 6ms/step
# Epoch 127/250
# 109/109 - 1s - loss: 3.0042 - mean_squared_error: 3.0042 - mean_absolute_error: 1.0109 - 703ms/epoch - 6ms/step
# Epoch 128/250
# 109/109 - 1s - loss: 2.8494 - mean_squared_error: 2.8494 - mean_absolute_error: 0.9547 - 713ms/epoch - 7ms/step
# Epoch 129/250
# 109/109 - 1s - loss: 2.8122 - mean_squared_error: 2.8122 - mean_absolute_error: 0.9324 - 702ms/epoch - 6ms/step
# Epoch 130/250
# 109/109 - 1s - loss: 2.8534 - mean_squared_error: 2.8534 - mean_absolute_error: 0.9651 - 728ms/epoch - 7ms/step
# Epoch 131/250
# 109/109 - 1s - loss: 2.8163 - mean_squared_error: 2.8163 - mean_absolute_error: 0.9483 - 698ms/epoch - 6ms/step
# Epoch 132/250
# 109/109 - 1s - loss: 2.8435 - mean_squared_error: 2.8435 - mean_absolute_error: 0.9753 - 712ms/epoch - 7ms/step
# Epoch 133/250
# 109/109 - 1s - loss: 2.7812 - mean_squared_error: 2.7812 - mean_absolute_error: 0.9378 - 718ms/epoch - 7ms/step
# Epoch 134/250
# 109/109 - 1s - loss: 2.7441 - mean_squared_error: 2.7441 - mean_absolute_error: 0.9355 - 727ms/epoch - 7ms/step
# Epoch 135/250
# 109/109 - 1s - loss: 2.7821 - mean_squared_error: 2.7821 - mean_absolute_error: 0.9460 - 744ms/epoch - 7ms/step
# Epoch 136/250
# 109/109 - 1s - loss: 2.7872 - mean_squared_error: 2.7872 - mean_absolute_error: 0.9722 - 728ms/epoch - 7ms/step
# Epoch 137/250
# 109/109 - 1s - loss: 2.8100 - mean_squared_error: 2.8100 - mean_absolute_error: 0.9658 - 713ms/epoch - 7ms/step
# Epoch 138/250
# 109/109 - 1s - loss: 2.7741 - mean_squared_error: 2.7741 - mean_absolute_error: 0.9426 - 716ms/epoch - 7ms/step
# Epoch 139/250
# 109/109 - 1s - loss: 2.8210 - mean_squared_error: 2.8210 - mean_absolute_error: 0.9637 - 713ms/epoch - 7ms/step
# Epoch 140/250
# 109/109 - 1s - loss: 2.7394 - mean_squared_error: 2.7394 - mean_absolute_error: 0.9355 - 707ms/epoch - 6ms/step
# Epoch 141/250
# 109/109 - 1s - loss: 2.7214 - mean_squared_error: 2.7214 - mean_absolute_error: 0.9232 - 711ms/epoch - 7ms/step
# Epoch 142/250
# 109/109 - 1s - loss: 2.8171 - mean_squared_error: 2.8171 - mean_absolute_error: 0.9761 - 711ms/epoch - 7ms/step
# Epoch 143/250
# 109/109 - 1s - loss: 2.7315 - mean_squared_error: 2.7315 - mean_absolute_error: 0.9353 - 701ms/epoch - 6ms/step
# Epoch 144/250
# 109/109 - 1s - loss: 2.7049 - mean_squared_error: 2.7049 - mean_absolute_error: 0.9207 - 719ms/epoch - 7ms/step
# Epoch 145/250
# 109/109 - 1s - loss: 2.7200 - mean_squared_error: 2.7200 - mean_absolute_error: 0.9206 - 710ms/epoch - 7ms/step
# Epoch 146/250
# 109/109 - 1s - loss: 2.7512 - mean_squared_error: 2.7512 - mean_absolute_error: 0.9483 - 708ms/epoch - 6ms/step
# Epoch 147/250
# 109/109 - 1s - loss: 2.6542 - mean_squared_error: 2.6542 - mean_absolute_error: 0.8944 - 756ms/epoch - 7ms/step
# Epoch 148/250
# 109/109 - 1s - loss: 2.6481 - mean_squared_error: 2.6481 - mean_absolute_error: 0.9191 - 699ms/epoch - 6ms/step
# Epoch 149/250
# 109/109 - 1s - loss: 2.6804 - mean_squared_error: 2.6804 - mean_absolute_error: 0.9129 - 733ms/epoch - 7ms/step
# Epoch 150/250
# 109/109 - 1s - loss: 2.6312 - mean_squared_error: 2.6312 - mean_absolute_error: 0.9020 - 726ms/epoch - 7ms/step
# Epoch 151/250
# 109/109 - 1s - loss: 2.7099 - mean_squared_error: 2.7099 - mean_absolute_error: 0.9193 - 727ms/epoch - 7ms/step
# Epoch 152/250
# 109/109 - 1s - loss: 2.5980 - mean_squared_error: 2.5980 - mean_absolute_error: 0.8899 - 728ms/epoch - 7ms/step
# Epoch 153/250
# 109/109 - 1s - loss: 2.7447 - mean_squared_error: 2.7447 - mean_absolute_error: 0.9362 - 719ms/epoch - 7ms/step
# Epoch 154/250
# 109/109 - 1s - loss: 2.6455 - mean_squared_error: 2.6455 - mean_absolute_error: 0.9054 - 742ms/epoch - 7ms/step
# Epoch 155/250
# 109/109 - 1s - loss: 2.5817 - mean_squared_error: 2.5817 - mean_absolute_error: 0.8696 - 717ms/epoch - 7ms/step
# Epoch 156/250
# 109/109 - 1s - loss: 2.6441 - mean_squared_error: 2.6441 - mean_absolute_error: 0.8965 - 749ms/epoch - 7ms/step
# Epoch 157/250
# 109/109 - 1s - loss: 2.6080 - mean_squared_error: 2.6080 - mean_absolute_error: 0.8854 - 837ms/epoch - 8ms/step
# Epoch 158/250
# 109/109 - 1s - loss: 2.5973 - mean_squared_error: 2.5973 - mean_absolute_error: 0.8977 - 893ms/epoch - 8ms/step
# Epoch 159/250
# 109/109 - 1s - loss: 2.6132 - mean_squared_error: 2.6132 - mean_absolute_error: 0.8921 - 834ms/epoch - 8ms/step
# Epoch 160/250
# 109/109 - 1s - loss: 2.6988 - mean_squared_error: 2.6988 - mean_absolute_error: 0.9338 - 760ms/epoch - 7ms/step
# Epoch 161/250
# 109/109 - 1s - loss: 2.6234 - mean_squared_error: 2.6234 - mean_absolute_error: 0.9101 - 809ms/epoch - 7ms/step
# Epoch 162/250
# 109/109 - 1s - loss: 2.6452 - mean_squared_error: 2.6452 - mean_absolute_error: 0.8988 - 798ms/epoch - 7ms/step
# Epoch 163/250
# 109/109 - 1s - loss: 2.5663 - mean_squared_error: 2.5663 - mean_absolute_error: 0.8857 - 1s/epoch - 11ms/step
# Epoch 164/250
# 109/109 - 1s - loss: 2.6210 - mean_squared_error: 2.6210 - mean_absolute_error: 0.9011 - 1s/epoch - 12ms/step
# Epoch 165/250
# 109/109 - 1s - loss: 2.6050 - mean_squared_error: 2.6050 - mean_absolute_error: 0.9117 - 1s/epoch - 11ms/step
# Epoch 166/250
# 109/109 - 1s - loss: 2.6787 - mean_squared_error: 2.6787 - mean_absolute_error: 0.9329 - 1s/epoch - 11ms/step
# Epoch 167/250
# 109/109 - 1s - loss: 2.6271 - mean_squared_error: 2.6271 - mean_absolute_error: 0.9093 - 1s/epoch - 13ms/step
# Epoch 168/250
# 109/109 - 1s - loss: 2.5389 - mean_squared_error: 2.5389 - mean_absolute_error: 0.8897 - 1s/epoch - 11ms/step
# Epoch 169/250
# 109/109 - 1s - loss: 2.5406 - mean_squared_error: 2.5406 - mean_absolute_error: 0.8737 - 1s/epoch - 11ms/step
# Epoch 170/250
# 109/109 - 1s - loss: 2.5205 - mean_squared_error: 2.5205 - mean_absolute_error: 0.8666 - 1s/epoch - 9ms/step
# Epoch 171/250
# 109/109 - 1s - loss: 2.4790 - mean_squared_error: 2.4790 - mean_absolute_error: 0.8572 - 1s/epoch - 12ms/step
# Epoch 172/250
# 109/109 - 1s - loss: 2.5695 - mean_squared_error: 2.5695 - mean_absolute_error: 0.8941 - 1s/epoch - 12ms/step
# Epoch 173/250
# 109/109 - 1s - loss: 2.5806 - mean_squared_error: 2.5806 - mean_absolute_error: 0.9027 - 1s/epoch - 10ms/step
# Epoch 174/250
# 109/109 - 1s - loss: 2.4970 - mean_squared_error: 2.4970 - mean_absolute_error: 0.8514 - 1s/epoch - 10ms/step
# Epoch 175/250
# 109/109 - 1s - loss: 2.5068 - mean_squared_error: 2.5068 - mean_absolute_error: 0.8613 - 1s/epoch - 11ms/step
# Epoch 176/250
# 109/109 - 1s - loss: 2.5354 - mean_squared_error: 2.5354 - mean_absolute_error: 0.8900 - 1s/epoch - 11ms/step
# Epoch 177/250
# 109/109 - 1s - loss: 2.4547 - mean_squared_error: 2.4547 - mean_absolute_error: 0.8334 - 1s/epoch - 10ms/step
# Epoch 178/250
# 109/109 - 1s - loss: 2.4827 - mean_squared_error: 2.4827 - mean_absolute_error: 0.8496 - 1s/epoch - 10ms/step
# Epoch 179/250
# 109/109 - 1s - loss: 2.4649 - mean_squared_error: 2.4649 - mean_absolute_error: 0.8637 - 1s/epoch - 12ms/step
# Epoch 180/250
# 109/109 - 1s - loss: 2.4809 - mean_squared_error: 2.4809 - mean_absolute_error: 0.8675 - 1s/epoch - 11ms/step
# Epoch 181/250
# 109/109 - 1s - loss: 2.4770 - mean_squared_error: 2.4770 - mean_absolute_error: 0.8620 - 1s/epoch - 11ms/step
# Epoch 182/250
# 109/109 - 1s - loss: 2.4314 - mean_squared_error: 2.4314 - mean_absolute_error: 0.8485 - 1s/epoch - 10ms/step
# Epoch 183/250
# 109/109 - 1s - loss: 2.4975 - mean_squared_error: 2.4975 - mean_absolute_error: 0.8723 - 1s/epoch - 10ms/step
# Epoch 184/250
# 109/109 - 1s - loss: 2.3980 - mean_squared_error: 2.3980 - mean_absolute_error: 0.8352 - 1s/epoch - 11ms/step
# Epoch 185/250
# 109/109 - 1s - loss: 2.4494 - mean_squared_error: 2.4494 - mean_absolute_error: 0.8425 - 1s/epoch - 13ms/step
# Epoch 186/250
# 109/109 - 1s - loss: 2.3980 - mean_squared_error: 2.3980 - mean_absolute_error: 0.8288 - 1s/epoch - 10ms/step
# Epoch 187/250
# 109/109 - 1s - loss: 2.3875 - mean_squared_error: 2.3875 - mean_absolute_error: 0.8216 - 1s/epoch - 12ms/step
# Epoch 188/250
# 109/109 - 1s - loss: 2.4363 - mean_squared_error: 2.4363 - mean_absolute_error: 0.8556 - 1s/epoch - 13ms/step
# Epoch 189/250
# 109/109 - 1s - loss: 2.4945 - mean_squared_error: 2.4945 - mean_absolute_error: 0.8857 - 1s/epoch - 12ms/step
# Epoch 190/250
# 109/109 - 1s - loss: 2.3916 - mean_squared_error: 2.3916 - mean_absolute_error: 0.8153 - 1s/epoch - 10ms/step
# Epoch 191/250
# 109/109 - 1s - loss: 2.3752 - mean_squared_error: 2.3752 - mean_absolute_error: 0.8183 - 1s/epoch - 10ms/step
# Epoch 192/250
# 109/109 - 1s - loss: 2.4453 - mean_squared_error: 2.4453 - mean_absolute_error: 0.8475 - 1s/epoch - 11ms/step
# Epoch 193/250
# 109/109 - 1s - loss: 2.3315 - mean_squared_error: 2.3315 - mean_absolute_error: 0.8022 - 1s/epoch - 10ms/step
# Epoch 194/250
# 109/109 - 1s - loss: 2.5582 - mean_squared_error: 2.5582 - mean_absolute_error: 0.8932 - 1s/epoch - 10ms/step
# Epoch 195/250
# 109/109 - 1s - loss: 2.4464 - mean_squared_error: 2.4464 - mean_absolute_error: 0.8879 - 1s/epoch - 12ms/step
# Epoch 196/250
# 109/109 - 1s - loss: 2.4026 - mean_squared_error: 2.4026 - mean_absolute_error: 0.8581 - 1s/epoch - 12ms/step
# Epoch 197/250
# 109/109 - 2s - loss: 2.4062 - mean_squared_error: 2.4062 - mean_absolute_error: 0.8475 - 2s/epoch - 16ms/step
# Epoch 198/250
# 109/109 - 1s - loss: 2.4632 - mean_squared_error: 2.4632 - mean_absolute_error: 0.8736 - 1s/epoch - 14ms/step
# Epoch 199/250
# 109/109 - 1s - loss: 2.3685 - mean_squared_error: 2.3685 - mean_absolute_error: 0.8264 - 1s/epoch - 12ms/step
# Epoch 200/250
# 109/109 - 1s - loss: 2.4022 - mean_squared_error: 2.4022 - mean_absolute_error: 0.8282 - val_loss: 38.0523 - val_mean_squared_error: 38.0523 - val_mean_absolute_error: 5.4915 - 1s/epoch - 13ms/step
# Epoch 201/250
# 109/109 - 1s - loss: 2.3755 - mean_squared_error: 2.3755 - mean_absolute_error: 0.8390 - 1s/epoch - 11ms/step
# Epoch 202/250
# 109/109 - 1s - loss: 2.3566 - mean_squared_error: 2.3566 - mean_absolute_error: 0.8224 - 1s/epoch - 11ms/step
# Epoch 203/250
# 109/109 - 1s - loss: 2.3580 - mean_squared_error: 2.3580 - mean_absolute_error: 0.8336 - 1s/epoch - 11ms/step
# Epoch 204/250
# 109/109 - 1s - loss: 2.2886 - mean_squared_error: 2.2886 - mean_absolute_error: 0.7984 - 1s/epoch - 10ms/step
# Epoch 205/250
# 109/109 - 1s - loss: 2.3416 - mean_squared_error: 2.3416 - mean_absolute_error: 0.8071 - 1s/epoch - 10ms/step
# Epoch 206/250
# 109/109 - 1s - loss: 2.4206 - mean_squared_error: 2.4206 - mean_absolute_error: 0.8643 - 1s/epoch - 10ms/step
# Epoch 207/250
# 109/109 - 1s - loss: 2.2995 - mean_squared_error: 2.2995 - mean_absolute_error: 0.8280 - 1s/epoch - 10ms/step
# Epoch 208/250
# 109/109 - 1s - loss: 2.3425 - mean_squared_error: 2.3425 - mean_absolute_error: 0.8391 - 1s/epoch - 11ms/step
# Epoch 209/250
# 109/109 - 1s - loss: 2.3882 - mean_squared_error: 2.3882 - mean_absolute_error: 0.8400 - 1s/epoch - 10ms/step
# Epoch 210/250
# 109/109 - 1s - loss: 2.3188 - mean_squared_error: 2.3188 - mean_absolute_error: 0.8175 - 1s/epoch - 10ms/step
# Epoch 211/250
# 109/109 - 1s - loss: 2.2979 - mean_squared_error: 2.2979 - mean_absolute_error: 0.8080 - 1s/epoch - 12ms/step
# Epoch 212/250
# 109/109 - 1s - loss: 2.3011 - mean_squared_error: 2.3011 - mean_absolute_error: 0.8039 - 1s/epoch - 11ms/step
# Epoch 213/250
# 109/109 - 1s - loss: 2.3761 - mean_squared_error: 2.3761 - mean_absolute_error: 0.8455 - 1s/epoch - 11ms/step
# Epoch 214/250
# 109/109 - 1s - loss: 2.2752 - mean_squared_error: 2.2752 - mean_absolute_error: 0.8076 - 1s/epoch - 10ms/step
# Epoch 215/250
# 109/109 - 1s - loss: 2.2357 - mean_squared_error: 2.2357 - mean_absolute_error: 0.7666 - 1s/epoch - 11ms/step
# Epoch 216/250
# 109/109 - 1s - loss: 2.2388 - mean_squared_error: 2.2388 - mean_absolute_error: 0.7655 - 1s/epoch - 11ms/step
# Epoch 217/250
# 109/109 - 1s - loss: 2.2285 - mean_squared_error: 2.2285 - mean_absolute_error: 0.7874 - 1s/epoch - 10ms/step
# Epoch 218/250
# 109/109 - 1s - loss: 2.2614 - mean_squared_error: 2.2614 - mean_absolute_error: 0.8045 - 1s/epoch - 10ms/step
# Epoch 219/250
# 109/109 - 1s - loss: 2.3036 - mean_squared_error: 2.3036 - mean_absolute_error: 0.8210 - 1s/epoch - 10ms/step
# Epoch 220/250
# 109/109 - 1s - loss: 2.2098 - mean_squared_error: 2.2098 - mean_absolute_error: 0.7733 - 1s/epoch - 11ms/step
# Epoch 221/250
# 109/109 - 1s - loss: 2.2204 - mean_squared_error: 2.2204 - mean_absolute_error: 0.7807 - 1s/epoch - 11ms/step
# Epoch 222/250
# 109/109 - 1s - loss: 2.2024 - mean_squared_error: 2.2024 - mean_absolute_error: 0.7726 - 1s/epoch - 11ms/step
# Epoch 223/250
# 109/109 - 1s - loss: 2.2334 - mean_squared_error: 2.2334 - mean_absolute_error: 0.7835 - 1s/epoch - 10ms/step
# Epoch 224/250
# 109/109 - 1s - loss: 2.2240 - mean_squared_error: 2.2240 - mean_absolute_error: 0.7854 - 1s/epoch - 10ms/step
# Epoch 225/250
# 109/109 - 1s - loss: 2.2625 - mean_squared_error: 2.2625 - mean_absolute_error: 0.8125 - 1s/epoch - 11ms/step
# Epoch 226/250
# 109/109 - 1s - loss: 2.2180 - mean_squared_error: 2.2180 - mean_absolute_error: 0.7739 - 1s/epoch - 10ms/step
# Epoch 227/250
# 109/109 - 1s - loss: 2.2279 - mean_squared_error: 2.2279 - mean_absolute_error: 0.7680 - 1s/epoch - 10ms/step
# Epoch 228/250
# 109/109 - 1s - loss: 2.2680 - mean_squared_error: 2.2680 - mean_absolute_error: 0.7968 - 1s/epoch - 11ms/step
# Epoch 229/250
# 109/109 - 1s - loss: 2.2181 - mean_squared_error: 2.2181 - mean_absolute_error: 0.7946 - 1s/epoch - 11ms/step
# Epoch 230/250
# 109/109 - 1s - loss: 2.2796 - mean_squared_error: 2.2796 - mean_absolute_error: 0.8102 - 1s/epoch - 10ms/step
# Epoch 231/250
# 109/109 - 1s - loss: 2.2371 - mean_squared_error: 2.2371 - mean_absolute_error: 0.7787 - 1s/epoch - 10ms/step
# Epoch 232/250
# 109/109 - 1s - loss: 2.1744 - mean_squared_error: 2.1744 - mean_absolute_error: 0.7715 - 1s/epoch - 10ms/step
# Epoch 233/250
# 109/109 - 1s - loss: 2.1658 - mean_squared_error: 2.1658 - mean_absolute_error: 0.7728 - 1s/epoch - 10ms/step
# Epoch 234/250
# 109/109 - 1s - loss: 2.1683 - mean_squared_error: 2.1683 - mean_absolute_error: 0.7573 - 1s/epoch - 10ms/step
# Epoch 235/250
# 109/109 - 1s - loss: 2.1877 - mean_squared_error: 2.1877 - mean_absolute_error: 0.7695 - 1s/epoch - 12ms/step
# Epoch 236/250
# 109/109 - 1s - loss: 2.1746 - mean_squared_error: 2.1746 - mean_absolute_error: 0.7693 - 1s/epoch - 10ms/step
# Epoch 237/250
# 109/109 - 1s - loss: 2.2638 - mean_squared_error: 2.2638 - mean_absolute_error: 0.8071 - 1s/epoch - 11ms/step
# Epoch 238/250
# 109/109 - 1s - loss: 2.2107 - mean_squared_error: 2.2107 - mean_absolute_error: 0.7946 - 1s/epoch - 12ms/step
# Epoch 239/250
# 109/109 - 1s - loss: 2.1604 - mean_squared_error: 2.1604 - mean_absolute_error: 0.7658 - 1s/epoch - 11ms/step
# Epoch 240/250
# 109/109 - 1s - loss: 2.2339 - mean_squared_error: 2.2339 - mean_absolute_error: 0.8017 - 1s/epoch - 10ms/step
# Epoch 241/250
# 109/109 - 1s - loss: 2.2206 - mean_squared_error: 2.2206 - mean_absolute_error: 0.7916 - 1s/epoch - 11ms/step
# Epoch 242/250
# 109/109 - 1s - loss: 2.1921 - mean_squared_error: 2.1921 - mean_absolute_error: 0.7751 - 1s/epoch - 11ms/step
# Epoch 243/250
# 109/109 - 1s - loss: 2.1093 - mean_squared_error: 2.1093 - mean_absolute_error: 0.7364 - 1s/epoch - 10ms/step
# Epoch 244/250
# 109/109 - 1s - loss: 2.1234 - mean_squared_error: 2.1234 - mean_absolute_error: 0.7414 - 1s/epoch - 10ms/step
# Epoch 245/250
# 109/109 - 1s - loss: 2.1088 - mean_squared_error: 2.1088 - mean_absolute_error: 0.7430 - 1s/epoch - 12ms/step
# Epoch 246/250
# 109/109 - 1s - loss: 2.1734 - mean_squared_error: 2.1734 - mean_absolute_error: 0.7743 - 1s/epoch - 13ms/step
# Epoch 247/250
# 109/109 - 1s - loss: 2.1660 - mean_squared_error: 2.1660 - mean_absolute_error: 0.7798 - 1s/epoch - 12ms/step
# Epoch 248/250
# 109/109 - 1s - loss: 2.2030 - mean_squared_error: 2.2030 - mean_absolute_error: 0.7815 - 1s/epoch - 12ms/step
# Epoch 249/250
# 109/109 - 1s - loss: 2.1894 - mean_squared_error: 2.1894 - mean_absolute_error: 0.7779 - 1s/epoch - 11ms/step
# Epoch 250/250
# 109/109 - 1s - loss: 2.1087 - mean_squared_error: 2.1087 - mean_absolute_error: 0.7470 - 1s/epoch - 11ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model.get_weights()[0]
trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking_1 (Masking)         (None, 10, 1)             0
#
#  Input-Layer (InputLayer)    multiple                  0
#
#  lstm_2 (LSTM)               (None, 10, 64)            16896
#
#  lstm_3 (LSTM)               (None, 10, 64)            33024
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            65
#  ed)
#
# =================================================================
# Total params: 49,985
# Trainable params: 49,985
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 2.1087350845336914
# Final mean_squared_error : 2.108734369277954
# Final mean_absolute_error : 0.7469801902770996
# Final val_loss : 38.05230712890625
# Final val_mean_squared_error : 38.052303314208984
# Final val_mean_absolute_error : 5.4915289878845215
#
# -------------------- Evaluation on Test Data --------------------
# 3/3 [==============================] - 5s 11ms/step - loss: 18.8018 - mean_squared_error: 18.8018 - mean_absolute_error: 3.6734
