# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D, GRU # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
from keras import metrics
from keras.utils import plot_model
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.3
# numpy: 1.23.0
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
df=df.iloc[200000:200050]
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 35.0489          0.0     -15.815     -3.7810         NaN
#           35.0609          0.0     -14.885     -3.9176         NaN
#           35.0629          0.0     -14.576     -3.7470         NaN
#           35.0649          0.0     -14.764     -3.8894         NaN
#           35.0669          0.0     -14.441     -3.8318         NaN
#           35.0709          0.0     -14.603     -3.8847         NaN
#           35.0749          0.0     -14.436     -3.6920         NaN
#           35.0769          0.0     -14.349     -3.7917         NaN
#           35.0829          0.0     -14.771     -3.8066         NaN
#           35.0849          0.0     -14.704     -3.8728         NaN
#           35.0869          0.0     -14.768     -3.8326         NaN
#           35.0889          0.0     -14.732     -3.8834         NaN
#           35.0929          0.0     -14.811     -3.8586         NaN
#           35.0949          0.0     -14.623     -3.7967         NaN
#           35.0989          0.0     -14.379     -3.8719         NaN
#           35.1029          0.0     -14.441     -3.9758         NaN
#           35.1049          0.0     -14.364     -4.0365         NaN
#           35.1090          0.0     -14.449     -3.9585         NaN
#           35.1110          0.0     -14.436     -3.8910         NaN
#           35.1130          0.0     -14.299     -3.9369         NaN
#           35.1150          0.0     -14.448     -3.9877         NaN
#           35.1170          0.0     -14.474     -3.8994         NaN
#           35.1210          0.0     -14.455     -3.8412         NaN
#           35.1230          0.0     -14.301     -3.8297         NaN
#           35.1250          0.0     -14.278     -3.9499         NaN
#           35.1270          0.0     -14.253     -3.8588         NaN
#           35.1290          0.0     -14.125     -3.7033         NaN
#           35.1310          0.0     -14.690     -3.6251         NaN
#           35.1330          0.0     -14.283     -3.6226         NaN
#           35.1350          0.0     -14.392     -3.5769         NaN
#           35.1370          0.0     -14.325     -3.5559         NaN
#           35.1390          0.0     -14.443     -3.6761   -0.288270
#           35.1410          0.0     -14.298     -3.4663   -0.051774
#           35.1430          0.0     -14.011     -3.3115    0.202570
#           35.1450          0.0     -14.194     -3.5789   -0.144540
#           35.1470          0.0     -14.115     -3.5730   -0.141100
#           35.1490          0.0     -13.955     -3.5790   -0.025921
#           35.1510          0.0     -13.948     -3.5282    0.077265
#           35.1530          0.0     -14.082     -3.6449   -0.019226
#           35.1590          0.0     -13.767     -3.5871    0.164490
#           35.1610          0.0     -13.605     -3.6694    0.075292
#           35.1630          0.0     -13.577     -3.6511    0.116520
#           35.1670          0.0     -13.443     -3.5750    0.011602
#           35.1690          0.0     -13.334     -3.5268   -0.042380
#           35.1730          0.0     -13.361     -3.4013   -0.011563
#           35.1750          0.0     -13.394     -3.4206   -0.074809
#           35.1770          0.0     -13.431     -3.4260   -0.149470
#           35.1790          0.0     -13.485     -3.4171   -0.096078
#           35.1810          0.0     -13.528     -3.4013   -0.077661
#           35.1830          0.0     -13.415     -3.3164   -0.040116
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 35.0489      -3.8126     -3.4671     -7.7504     -3.5689
#           35.0609      -3.9170     -3.2592     -7.9254     -3.7276
#           35.0629      -3.6863     -2.8954     -7.4672     -3.4246
#           35.0649      -3.8073     -3.1875     -7.6943     -3.6412
#           35.0669      -3.7935     -3.2384     -7.7486     -3.6997
#           35.0709      -3.8408     -3.2930     -7.7741     -3.6741
#           35.0749      -3.6901     -3.2090     -7.5250     -3.4785
#           35.0769      -3.7959     -3.2784     -7.6299     -3.5939
#           35.0829      -3.6599     -3.5229     -7.8566     -3.6808
#           35.0849      -3.7636     -3.5067     -7.9267     -3.8083
#           35.0869      -3.7162     -3.5126     -7.8951     -3.6664
#           35.0889      -3.8549     -3.5867     -7.9549     -3.7083
#           35.0929      -3.7951     -3.4225     -7.8363     -3.6528
#           35.0949      -3.7586     -3.2944     -7.7452     -3.7273
#           35.0989      -3.8442     -3.4111     -7.9270     -3.8991
#           35.1029      -3.8973     -3.4028     -7.9092     -3.7671
#           35.1049      -3.9477     -3.4052     -7.9590     -3.8146
#           35.1090      -3.7463     -3.0723     -7.6809     -3.5488
#           35.1110      -3.8184     -3.1933     -7.6781     -3.6246
#           35.1130      -4.0038     -3.2738     -7.8994     -4.0099
#           35.1150      -4.0764     -3.2966     -7.8845     -4.0251
#           35.1170      -3.9483     -3.1790     -7.6358     -3.8275
#           35.1210      -3.8481     -3.2096     -7.5416     -3.8277
#           35.1230      -3.9265     -3.1724     -7.5145     -3.7189
#           35.1250      -4.1180     -3.5162     -7.9711     -4.0960
#           35.1270      -3.9819     -3.3519     -7.7327     -3.9070
#           35.1290      -3.9534     -3.2919     -7.5444     -3.7556
#           35.1310      -3.8074     -3.1519     -7.4047     -3.6174
#           35.1330      -3.8944     -3.1985     -7.5473     -3.6572
#           35.1350      -4.0194     -3.2438     -7.4402     -3.6552
#           35.1370      -4.0337     -3.2838     -7.4065     -3.6889
#           35.1390      -4.0673     -3.2625     -7.5307     -3.7635
#           35.1410      -3.9996     -3.3576     -7.4929     -3.8035
#           35.1430      -3.7099     -3.1659     -7.1048     -3.4851
#           35.1450      -4.0805     -3.4489     -7.4502     -3.7684
#           35.1470      -4.1158     -3.4558     -7.4638     -3.7827
#           35.1490      -4.0768     -3.4201     -7.3495     -3.7378
#           35.1510      -3.9516     -3.3432     -7.2333     -3.6932
#           35.1530      -3.9648     -3.2347     -7.1752     -3.5582
#           35.1590      -3.9890     -3.2998     -7.0840     -3.6441
#           35.1610      -4.0754     -3.4155     -7.1158     -3.6800
#           35.1630      -4.0064     -3.2873     -6.8954     -3.5549
#           35.1670      -3.9826     -3.1985     -6.8887     -3.6199
#           35.1690      -3.9617     -3.2137     -6.8996     -3.5650
#           35.1730      -3.9319     -3.2305     -6.9242     -3.5535
#           35.1750      -3.9659     -3.1860     -6.8450     -3.5049
#           35.1770      -4.0649     -3.2954     -6.9732     -3.6241
#           35.1790      -4.0898     -3.2533     -6.9061     -3.5850
#           35.1810      -4.1941     -3.3511     -7.0207     -3.6751
#           35.1830      -4.1276     -3.3073     -7.0223     -3.6406
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 35.0489      -4.4897     -1.6672  ...    -10.3170     -7.5373
#           35.0609      -4.8079     -2.0803  ...    -11.7620     -8.9301
#           35.0629      -4.4473     -1.8373  ...    -13.1510    -10.2660
#           35.0649      -4.7031     -2.0210  ...    -13.0580    -10.2560
#           35.0669      -4.7355     -1.9758  ...    -13.5610    -10.7640
#           35.0709      -4.7198     -2.0756  ...    -10.9370     -8.1093
#           35.0749      -4.4866     -1.8382  ...    -11.2140     -8.5165
#           35.0769      -4.6122     -2.0007  ...     -9.7603     -7.1025
#           35.0829      -4.8392     -2.2243  ...    -10.0590     -7.4460
#           35.0849      -4.9544     -2.3774  ...    -11.3940     -8.7501
#           35.0869      -4.8532     -2.2418  ...     -9.9010     -7.2649
#           35.0889      -4.9765     -2.3457  ...    -10.9650     -8.3301
#           35.0929      -4.9067     -2.2670  ...    -11.0340     -8.4121
#           35.0949      -4.9731     -2.3576  ...     -9.6836     -7.0600
#           35.0989      -5.1603     -2.5179  ...    -12.5340     -9.8930
#           35.1029      -5.1324     -2.4326  ...    -10.3140     -7.6713
#           35.1049      -5.1684     -2.4906  ...    -10.4070     -7.7540
#           35.1090      -4.9969     -2.2489  ...    -10.2940     -7.6247
#           35.1110      -5.0924     -2.3661  ...    -12.7160    -10.0940
#           35.1130      -5.4715     -2.6375  ...    -11.9400     -9.3576
#           35.1150      -5.4933     -2.6111  ...    -10.9800     -8.3292
#           35.1170      -5.3247     -2.3504  ...    -10.2120     -7.5697
#           35.1210      -5.3221     -2.2503  ...    -10.7010     -8.0494
#           35.1230      -5.3049     -2.2216  ...    -10.7580     -8.1216
#           35.1250      -5.7405     -2.6707  ...    -11.3260     -8.6358
#           35.1270      -5.5552     -2.4938  ...    -10.5450     -7.8564
#           35.1290      -5.4772     -2.3650  ...    -10.9830     -8.3177
#           35.1310      -5.3800     -2.2929  ...    -10.6590     -7.9541
#           35.1330      -5.3658     -2.3242  ...    -10.6890     -7.9763
#           35.1350      -5.3575     -2.1894  ...    -10.3050     -7.6365
#           35.1370      -5.3705     -2.1779  ...    -10.0560     -7.4600
#           35.1390      -5.3703     -2.3001  ...     -8.9291     -6.3454
#           35.1410      -5.4029     -2.2280  ...    -10.0470     -7.5036
#           35.1430      -5.1416     -1.8428  ...    -11.1420     -8.6165
#           35.1450      -5.3701     -2.1093  ...    -10.7310     -8.2378
#           35.1470      -5.3394     -2.0994  ...    -10.6080     -8.1327
#           35.1490      -5.2440     -1.9558  ...    -11.2270     -8.7979
#           35.1510      -5.1612     -1.9289  ...    -11.1870     -8.7799
#           35.1530      -5.0363     -1.7980  ...    -11.3600     -8.9341
#           35.1590      -5.1459     -1.8511  ...    -11.2720     -8.9364
#           35.1610      -5.1739     -1.9242  ...    -10.8400     -8.4679
#           35.1630      -5.0303     -1.7545  ...     -9.5251     -7.1756
#           35.1670      -5.0039     -1.7600  ...     -9.3547     -7.0470
#           35.1690      -4.9562     -1.7621  ...     -9.3524     -7.1232
#           35.1730      -4.9983     -1.8131  ...    -11.2550     -9.0943
#           35.1750      -4.9189     -1.7744  ...    -10.2580     -8.1144
#           35.1770      -5.0549     -1.9141  ...    -10.6800     -8.5555
#           35.1790      -5.0753     -1.8829  ...    -10.4090     -8.2711
#           35.1810      -5.2325     -2.0128  ...    -11.7990     -9.6553
#           35.1830      -5.2423     -2.0158  ...    -11.4540     -9.3179
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 35.0489      -8.7209    -11.2120     -10.748     -13.202
#           35.0609     -10.2470    -12.6600     -12.442     -14.995
#           35.0629     -11.6180    -14.0450     -13.878     -16.509
#           35.0649     -11.5870    -14.0190     -13.864     -16.492
#           35.0669     -12.1090    -14.5200     -14.317     -16.996
#           35.0709      -9.4112    -11.8580     -11.642     -14.406
#           35.0749      -9.7208    -12.1450     -11.932     -14.716
#           35.0769      -8.2148    -10.6750     -10.468     -13.193
#           35.0829      -8.4619    -10.9330     -11.044     -13.950
#           35.0849      -9.7760    -12.2770     -12.371     -15.275
#           35.0869      -8.1889    -10.7490     -10.682     -13.680
#           35.0889      -9.3011    -11.8190     -12.070     -14.986
#           35.0929      -9.3914    -11.8720     -12.035     -14.957
#           35.0949      -8.0490    -10.5110     -10.720     -13.693
#           35.0989     -10.7980    -13.3100     -13.458     -16.525
#           35.1029      -8.6041    -11.1050     -11.275     -14.270
#           35.1049      -8.6778    -11.1750     -11.375     -14.391
#           35.1090      -8.6033    -11.0750     -11.214     -14.240
#           35.1110     -11.0670    -13.5210     -13.750     -16.771
#           35.1130     -10.3450    -12.7410     -13.058     -16.126
#           35.1150      -9.3060    -11.7440     -12.030     -15.124
#           35.1170      -8.5796    -10.9870     -11.233     -14.347
#           35.1210      -9.0779    -11.4770     -11.639     -14.781
#           35.1230      -9.1723    -11.5410     -11.976     -15.239
#           35.1250      -9.6865    -12.0500     -12.346     -15.662
#           35.1270      -8.9486    -11.2940     -11.666     -14.944
#           35.1290      -9.4562    -11.7580     -12.129     -15.410
#           35.1310      -9.0604    -11.3680     -11.668     -15.004
#           35.1330      -9.0388    -11.3680     -11.794     -15.162
#           35.1350      -8.7001    -11.0120     -11.330     -14.804
#           35.1370      -8.4979    -10.7860     -11.206     -14.619
#           35.1390      -7.3099     -9.6381     -10.037     -13.353
#           35.1410      -8.4456    -10.7740     -11.213     -14.567
#           35.1430      -9.5545    -11.8690     -12.264     -15.689
#           35.1450      -9.1484    -11.4760     -11.887     -15.334
#           35.1470      -9.0069    -11.3530     -11.783     -15.271
#           35.1490      -9.6217    -11.9800     -12.343     -15.902
#           35.1510      -9.5850    -11.9510     -12.349     -15.934
#           35.1530      -9.7290    -12.1170     -12.652     -16.242
#           35.1590      -9.7126    -12.0700     -12.427     -16.070
#           35.1610      -9.2483    -11.6050     -11.958     -15.615
#           35.1630      -7.9521    -10.2870     -10.597     -14.271
#           35.1670      -7.7516    -10.1060     -10.430     -14.217
#           35.1690      -7.7530    -10.1050     -10.370     -14.189
#           35.1730      -9.6335    -12.0060     -12.301     -16.250
#           35.1750      -8.6099    -10.9970     -11.294     -15.276
#           35.1770      -9.0287    -11.4260     -11.728     -15.759
#           35.1790      -8.7865    -11.1800     -11.507     -15.542
#           35.1810     -10.2120    -12.5950     -12.959     -17.045
#           35.1830      -9.8489    -12.2400     -12.648     -16.753
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 35.0489      -9.2688     -6.4277     -7.5077     -7.9164
#           35.0609     -10.4110     -7.9618     -8.9148     -9.4379
#           35.0629     -11.8270     -9.3040    -10.4320    -10.7810
#           35.0649     -11.8730     -9.2702    -10.3670    -10.7500
#           35.0669     -12.2140     -9.7466    -10.6810    -11.2900
#           35.0709      -9.5667     -7.0678     -8.0277     -8.6295
#           35.0749      -9.8545     -7.3709     -8.2817     -9.0185
#           35.0769      -8.3133     -5.7919     -6.6786     -7.3299
#           35.0829      -9.1779     -6.4862     -7.6583     -8.1460
#           35.0849     -10.4580     -7.7987     -9.0093     -9.7158
#           35.0869      -8.8467     -6.1655     -7.3720     -8.0073
#           35.0889     -10.1570     -7.4995     -8.5678     -9.1857
#           35.0929     -10.2390     -7.5220     -8.6975     -9.2105
#           35.0949      -8.9214     -6.2287     -7.4081     -7.8165
#           35.0989     -11.7450     -9.0567    -10.1720    -10.5220
#           35.1029      -9.6502     -6.8497     -8.0212     -8.3743
#           35.1049      -9.6673     -6.8598     -8.1123     -8.3904
#           35.1090      -9.7070     -6.8044     -8.0533     -8.3519
#           35.1110     -12.1450     -9.3200    -10.5090    -10.8070
#           35.1130     -11.2630     -8.5360     -9.7064    -10.1140
#           35.1150     -10.3980     -7.5417     -8.8310     -9.1571
#           35.1170      -9.5060     -6.8424     -7.9977     -8.4065
#           35.1210      -9.8057     -7.1761     -8.2989     -8.8531
#           35.1230     -10.2220     -7.4652     -8.7137     -9.3839
#           35.1250     -10.6160     -7.9257     -9.1173     -9.7058
#           35.1270      -9.9307     -7.2042     -8.3521     -9.1294
#           35.1290     -10.3850     -7.6435     -8.7742     -9.5525
#           35.1310      -9.8345     -7.1289     -8.2670     -9.1127
#           35.1330     -10.0940     -7.2943     -8.5318     -9.2181
#           35.1350      -9.5985     -6.9140     -8.0162     -8.9987
#           35.1370      -9.3647     -6.7302     -7.8080     -8.7708
#           35.1390      -8.1627     -5.5769     -6.4934     -7.3895
#           35.1410      -9.3752     -6.7967     -7.8105     -8.7338
#           35.1430     -10.3750     -7.7743     -8.8705     -9.6745
#           35.1450      -9.9933     -7.4382     -8.4890     -9.3248
#           35.1470      -9.9194     -7.3945     -8.4278     -9.1948
#           35.1490     -10.4190     -7.9663     -8.9046     -9.6795
#           35.1510     -10.3910     -7.9863     -8.8437     -9.5909
#           35.1530     -10.6490     -8.2617     -9.0709     -9.7760
#           35.1590     -10.4130     -8.0042     -8.9052     -9.5305
#           35.1610      -9.9210     -7.5848     -8.3997     -9.0417
#           35.1630      -8.6224     -6.2704     -7.0988     -7.7395
#           35.1670      -8.5516     -6.1858     -7.0075     -7.6300
#           35.1690      -8.6138     -6.2124     -7.0347     -7.6369
#           35.1730     -10.6080     -8.1306     -9.0502     -9.5633
#           35.1750      -9.6004     -7.1682     -8.0131     -8.6160
#           35.1770     -10.0290     -7.5728     -8.4068     -9.0334
#           35.1790      -9.7738     -7.3118     -8.1923     -8.8056
#           35.1810     -11.2430     -8.7627     -9.6290    -10.2950
#           35.1830     -10.9250     -8.4514     -9.3315     -9.9838
#
# [50 rows x 110 columns]

# %%
df2=pd.read_csv('InSAR_data_south/displacement/groundwater.csv')
df2=df2.set_index([df2.columns[0],df2.columns[1]])
df2.columns=pd.to_datetime(df2.columns, format='%Y-%m-%d')
df2=df2.dropna(axis=0, how='all')#drop full nan rows
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != df2.columns[y]: #if column is misssing insert it
        df2.insert(loc=y,column=df.columns[y],value=np.nan*11286,allow_duplicates=False)
df2
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316          NaN         NaN  ...   75.653992   75.813688
# -120.8926 36.7114          NaN         NaN  ...         NaN         NaN
# -120.8846 36.6994          NaN         NaN  ...         NaN         NaN
# -120.8746 36.6874          NaN         NaN  ...         NaN         NaN
# -120.1368 35.6991          NaN         NaN  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933          NaN         NaN  ...   16.978182   17.000000
# -119.0271 36.3793          NaN         NaN  ...   16.978182   17.000000
# -119.0571 36.4493          NaN         NaN  ...   16.978182   17.000000
# -119.0211 36.3993          NaN         NaN  ...   16.978182   17.000000
# -119.0111 36.3873          NaN         NaN  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
# [11286 rows x 110 columns]

# %%
df2.index.size
# Out:
# 11286

# %%
for x in range(df2.index.size): #for each row
    curr=np.nan
    for y in range(df2.columns.size): #for each value in the row
        n=0
        while np.isnan(curr): # if saved value is empty
            curr=df2.iloc[x].values[n] #look for next actual value
            n+=1
        if np.isnan(df2.iloc[x].values[y]):#if data is nan then replace with previous curr value
            df2.iat[x,y]=curr
            #df2.iloc[x].values[y]=curr
        else:
            curr= df2.iloc[x].values[y]
                

df2
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    81.000000   81.000000  ...   75.653992   75.813688
# -120.8926 36.7114    72.248964   72.248964  ...   75.200000   75.200000
# -120.8846 36.6994    72.248964   72.248964  ...   75.200000   75.200000
# -120.8746 36.6874    72.248964   72.248964  ...   75.200000   75.200000
# -120.1368 35.6991   141.123387  141.123387  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091  ...   16.978182   17.000000
# -119.0271 36.3793    17.409091   17.409091  ...   16.978182   17.000000
# -119.0571 36.4493    17.409091   17.409091  ...   16.978182   17.000000
# -119.0211 36.3993    17.409091   17.409091  ...   16.978182   17.000000
# -119.0111 36.3873    17.409091   17.409091  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0        76.0        76.0
# -120.8926 36.7114    75.200000        75.2        75.2        75.2
# -120.8846 36.6994    75.200000        75.2        75.2        75.2
# -120.8746 36.6874    75.200000        75.2        75.2        75.2
# -120.1368 35.6991   151.000000       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.000000        17.0        17.0        17.0
# -119.0271 36.3793    17.000000        17.0        17.0        17.0
# -119.0571 36.4493    17.000000        17.0        17.0        17.0
# -119.0211 36.3993    17.000000        17.0        17.0        17.0
# -119.0111 36.3873    17.000000        17.0        17.0        17.0
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316         76.0        76.0        76.0        76.0
# -120.8926 36.7114         75.2        75.2        75.2        75.2
# -120.8846 36.6994         75.2        75.2        75.2        75.2
# -120.8746 36.6874         75.2        75.2        75.2        75.2
# -120.1368 35.6991        151.0       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933         17.0        17.0        17.0        17.0
# -119.0271 36.3793         17.0        17.0        17.0        17.0
# -119.0571 36.4493         17.0        17.0        17.0        17.0
# -119.0211 36.3993         17.0        17.0        17.0        17.0
# -119.0111 36.3873         17.0        17.0        17.0        17.0
#
# [11286 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10
# 1 2 3 4 5 6 7 ...
# w/ timestep of 2
# [[1,2][2,3][3,4]

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    for row in range(len(datain.index)): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
train, test = train_test_split(df, test_size=0.2, random_state=64)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)

# %%
X_train[0]
# Out:
# array([[  0.        ],
#        [-14.349     ],
#        [ -3.7917    ],
#        [ -6.13439574],
#        [ -3.7959    ],
#        [ -3.2784    ],
#        [ -7.6299    ],
#        [ -3.5939    ],
#        [ -4.6122    ],
#        [ -2.0007    ]])

# %%
Y_train[0]
# Out:
# array([[-14.835 ],
#        [ -4.9789],
#        [ -8.3433],
#        [ -6.4837],
#        [ -2.683 ],
#        [ -7.6971],
#        [ -5.2953],
#        [ -8.3121],
#        [ -5.591 ],
#        [ -2.2111]])

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model2 = Sequential(name="biLSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(GRU(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(GRU(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError', metrics.RootMeanSquaredError()], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 1456/1456 - 23s - loss: 6.6650 - mean_squared_error: 6.6650 - mean_absolute_error: 1.9839 - root_mean_squared_error: 2.5817 - 23s/epoch - 16ms/step
# Epoch 2/250
# 1456/1456 - 16s - loss: 5.0183 - mean_squared_error: 5.0183 - mean_absolute_error: 1.7514 - root_mean_squared_error: 2.2402 - 16s/epoch - 11ms/step
# Epoch 3/250
# 1456/1456 - 20s - loss: 4.1142 - mean_squared_error: 4.1143 - mean_absolute_error: 1.6021 - root_mean_squared_error: 2.0284 - 20s/epoch - 14ms/step
# Epoch 4/250
# 1456/1456 - 23s - loss: 3.1392 - mean_squared_error: 3.1392 - mean_absolute_error: 1.3865 - root_mean_squared_error: 1.7718 - 23s/epoch - 16ms/step
# Epoch 5/250
# 1456/1456 - 19s - loss: 2.1384 - mean_squared_error: 2.1384 - mean_absolute_error: 1.1304 - root_mean_squared_error: 1.4623 - 19s/epoch - 13ms/step
# Epoch 6/250
# 1456/1456 - 19s - loss: 1.4571 - mean_squared_error: 1.4571 - mean_absolute_error: 0.9158 - root_mean_squared_error: 1.2071 - 19s/epoch - 13ms/step
# Epoch 7/250
# 1456/1456 - 19s - loss: 1.0178 - mean_squared_error: 1.0178 - mean_absolute_error: 0.7634 - root_mean_squared_error: 1.0089 - 19s/epoch - 13ms/step
# Epoch 8/250
# 1456/1456 - 18s - loss: 0.7644 - mean_squared_error: 0.7644 - mean_absolute_error: 0.6607 - root_mean_squared_error: 0.8743 - 18s/epoch - 12ms/step
# Epoch 9/250
# 1456/1456 - 20s - loss: 0.5869 - mean_squared_error: 0.5869 - mean_absolute_error: 0.5791 - root_mean_squared_error: 0.7661 - 20s/epoch - 14ms/step
# Epoch 10/250
# 1456/1456 - 20s - loss: 0.5061 - mean_squared_error: 0.5061 - mean_absolute_error: 0.5348 - root_mean_squared_error: 0.7114 - 20s/epoch - 14ms/step
# Epoch 11/250
# 1456/1456 - 15s - loss: 0.3814 - mean_squared_error: 0.3814 - mean_absolute_error: 0.4677 - root_mean_squared_error: 0.6176 - 15s/epoch - 10ms/step
# Epoch 12/250
# 1456/1456 - 15s - loss: 0.3468 - mean_squared_error: 0.3468 - mean_absolute_error: 0.4463 - root_mean_squared_error: 0.5889 - 15s/epoch - 10ms/step
# Epoch 13/250
# 1456/1456 - 16s - loss: 0.3487 - mean_squared_error: 0.3487 - mean_absolute_error: 0.4424 - root_mean_squared_error: 0.5905 - 16s/epoch - 11ms/step
# Epoch 14/250
# 1456/1456 - 15s - loss: 0.2809 - mean_squared_error: 0.2809 - mean_absolute_error: 0.3998 - root_mean_squared_error: 0.5300 - 15s/epoch - 10ms/step
# Epoch 15/250
# 1456/1456 - 15s - loss: 0.2749 - mean_squared_error: 0.2749 - mean_absolute_error: 0.3982 - root_mean_squared_error: 0.5243 - 15s/epoch - 11ms/step
# Epoch 16/250
# 1456/1456 - 15s - loss: 0.3069 - mean_squared_error: 0.3069 - mean_absolute_error: 0.4138 - root_mean_squared_error: 0.5540 - 15s/epoch - 11ms/step
# Epoch 17/250
# 1456/1456 - 16s - loss: 0.2470 - mean_squared_error: 0.2470 - mean_absolute_error: 0.3679 - root_mean_squared_error: 0.4970 - 16s/epoch - 11ms/step
# Epoch 18/250
# 1456/1456 - 17s - loss: 0.2316 - mean_squared_error: 0.2316 - mean_absolute_error: 0.3621 - root_mean_squared_error: 0.4812 - 17s/epoch - 11ms/step
# Epoch 19/250
# 1456/1456 - 18s - loss: 0.2160 - mean_squared_error: 0.2160 - mean_absolute_error: 0.3499 - root_mean_squared_error: 0.4647 - 18s/epoch - 12ms/step
# Epoch 20/250
# 1456/1456 - 18s - loss: 0.2130 - mean_squared_error: 0.2130 - mean_absolute_error: 0.3478 - root_mean_squared_error: 0.4616 - 18s/epoch - 13ms/step
# Epoch 21/250
# 1456/1456 - 18s - loss: 0.2419 - mean_squared_error: 0.2419 - mean_absolute_error: 0.3606 - root_mean_squared_error: 0.4918 - 18s/epoch - 12ms/step
# Epoch 22/250
# 1456/1456 - 19s - loss: 0.1898 - mean_squared_error: 0.1898 - mean_absolute_error: 0.3270 - root_mean_squared_error: 0.4356 - 19s/epoch - 13ms/step
# Epoch 23/250
# 1456/1456 - 19s - loss: 0.1962 - mean_squared_error: 0.1962 - mean_absolute_error: 0.3315 - root_mean_squared_error: 0.4429 - 19s/epoch - 13ms/step
# Epoch 24/250
# 1456/1456 - 18s - loss: 0.1882 - mean_squared_error: 0.1882 - mean_absolute_error: 0.3248 - root_mean_squared_error: 0.4339 - 18s/epoch - 13ms/step
# Epoch 25/250
# 1456/1456 - 18s - loss: 0.1835 - mean_squared_error: 0.1835 - mean_absolute_error: 0.3189 - root_mean_squared_error: 0.4284 - 18s/epoch - 12ms/step
# Epoch 26/250
# 1456/1456 - 18s - loss: 0.1814 - mean_squared_error: 0.1814 - mean_absolute_error: 0.3160 - root_mean_squared_error: 0.4259 - 18s/epoch - 13ms/step
# Epoch 27/250
# 1456/1456 - 18s - loss: 0.1655 - mean_squared_error: 0.1655 - mean_absolute_error: 0.3048 - root_mean_squared_error: 0.4068 - 18s/epoch - 12ms/step
# Epoch 28/250
# 1456/1456 - 17s - loss: 0.1973 - mean_squared_error: 0.1973 - mean_absolute_error: 0.3198 - root_mean_squared_error: 0.4442 - 17s/epoch - 12ms/step
# Epoch 29/250
# 1456/1456 - 17s - loss: 0.1587 - mean_squared_error: 0.1587 - mean_absolute_error: 0.2971 - root_mean_squared_error: 0.3984 - 17s/epoch - 12ms/step
# Epoch 30/250
# 1456/1456 - 18s - loss: 0.1725 - mean_squared_error: 0.1725 - mean_absolute_error: 0.3089 - root_mean_squared_error: 0.4154 - 18s/epoch - 12ms/step
# Epoch 31/250
# 1456/1456 - 16s - loss: 0.1506 - mean_squared_error: 0.1506 - mean_absolute_error: 0.2887 - root_mean_squared_error: 0.3880 - 16s/epoch - 11ms/step
# Epoch 32/250
# 1456/1456 - 17s - loss: 0.1681 - mean_squared_error: 0.1681 - mean_absolute_error: 0.3029 - root_mean_squared_error: 0.4100 - 17s/epoch - 12ms/step
# Epoch 33/250
# 1456/1456 - 17s - loss: 0.1534 - mean_squared_error: 0.1534 - mean_absolute_error: 0.2914 - root_mean_squared_error: 0.3916 - 17s/epoch - 12ms/step
# Epoch 34/250
# 1456/1456 - 20s - loss: 0.1997 - mean_squared_error: 0.1997 - mean_absolute_error: 0.3197 - root_mean_squared_error: 0.4469 - 20s/epoch - 14ms/step
# Epoch 35/250
# 1456/1456 - 23s - loss: 0.1374 - mean_squared_error: 0.1374 - mean_absolute_error: 0.2728 - root_mean_squared_error: 0.3706 - 23s/epoch - 16ms/step
# Epoch 36/250
# 1456/1456 - 24s - loss: 0.1424 - mean_squared_error: 0.1424 - mean_absolute_error: 0.2800 - root_mean_squared_error: 0.3774 - 24s/epoch - 16ms/step
# Epoch 37/250
# 1456/1456 - 23s - loss: 0.1624 - mean_squared_error: 0.1624 - mean_absolute_error: 0.2989 - root_mean_squared_error: 0.4030 - 23s/epoch - 16ms/step
# Epoch 38/250
# 1456/1456 - 22s - loss: 0.1353 - mean_squared_error: 0.1353 - mean_absolute_error: 0.2719 - root_mean_squared_error: 0.3679 - 22s/epoch - 15ms/step
# Epoch 39/250
# 1456/1456 - 23s - loss: 0.1475 - mean_squared_error: 0.1475 - mean_absolute_error: 0.2821 - root_mean_squared_error: 0.3841 - 23s/epoch - 15ms/step
# Epoch 40/250
# 1456/1456 - 23s - loss: 0.1391 - mean_squared_error: 0.1391 - mean_absolute_error: 0.2753 - root_mean_squared_error: 0.3730 - 23s/epoch - 16ms/step
# Epoch 41/250
# 1456/1456 - 23s - loss: 0.1364 - mean_squared_error: 0.1364 - mean_absolute_error: 0.2715 - root_mean_squared_error: 0.3694 - 23s/epoch - 16ms/step
# Epoch 42/250
# 1456/1456 - 23s - loss: 0.1362 - mean_squared_error: 0.1362 - mean_absolute_error: 0.2746 - root_mean_squared_error: 0.3690 - 23s/epoch - 16ms/step
# Epoch 43/250
# 1456/1456 - 24s - loss: 0.1525 - mean_squared_error: 0.1525 - mean_absolute_error: 0.2802 - root_mean_squared_error: 0.3905 - 24s/epoch - 16ms/step
# Epoch 44/250
# 1456/1456 - 23s - loss: 0.1310 - mean_squared_error: 0.1310 - mean_absolute_error: 0.2668 - root_mean_squared_error: 0.3619 - 23s/epoch - 16ms/step
# Epoch 45/250
# 1456/1456 - 22s - loss: 0.1280 - mean_squared_error: 0.1280 - mean_absolute_error: 0.2621 - root_mean_squared_error: 0.3578 - 22s/epoch - 15ms/step
# Epoch 46/250
# 1456/1456 - 22s - loss: 0.1370 - mean_squared_error: 0.1370 - mean_absolute_error: 0.2723 - root_mean_squared_error: 0.3701 - 22s/epoch - 15ms/step
# Epoch 47/250
# 1456/1456 - 23s - loss: 0.1293 - mean_squared_error: 0.1293 - mean_absolute_error: 0.2641 - root_mean_squared_error: 0.3596 - 23s/epoch - 16ms/step
# Epoch 48/250
# 1456/1456 - 22s - loss: 0.1326 - mean_squared_error: 0.1326 - mean_absolute_error: 0.2663 - root_mean_squared_error: 0.3642 - 22s/epoch - 15ms/step
# Epoch 49/250
# 1456/1456 - 23s - loss: 0.1379 - mean_squared_error: 0.1379 - mean_absolute_error: 0.2677 - root_mean_squared_error: 0.3714 - 23s/epoch - 16ms/step
# Epoch 50/250
# 1456/1456 - 23s - loss: 0.1235 - mean_squared_error: 0.1235 - mean_absolute_error: 0.2554 - root_mean_squared_error: 0.3514 - 23s/epoch - 16ms/step
# Epoch 51/250
# 1456/1456 - 23s - loss: 0.1212 - mean_squared_error: 0.1212 - mean_absolute_error: 0.2555 - root_mean_squared_error: 0.3481 - 23s/epoch - 16ms/step
# Epoch 52/250
# 1456/1456 - 23s - loss: 0.1284 - mean_squared_error: 0.1284 - mean_absolute_error: 0.2613 - root_mean_squared_error: 0.3583 - 23s/epoch - 16ms/step
# Epoch 53/250
# 1456/1456 - 23s - loss: 0.1252 - mean_squared_error: 0.1252 - mean_absolute_error: 0.2597 - root_mean_squared_error: 0.3539 - 23s/epoch - 16ms/step
# Epoch 54/250
# 1456/1456 - 23s - loss: 0.1345 - mean_squared_error: 0.1345 - mean_absolute_error: 0.2641 - root_mean_squared_error: 0.3668 - 23s/epoch - 16ms/step
# Epoch 55/250
# 1456/1456 - 23s - loss: 0.1173 - mean_squared_error: 0.1173 - mean_absolute_error: 0.2505 - root_mean_squared_error: 0.3424 - 23s/epoch - 16ms/step
# Epoch 56/250
# 1456/1456 - 23s - loss: 0.1228 - mean_squared_error: 0.1228 - mean_absolute_error: 0.2596 - root_mean_squared_error: 0.3505 - 23s/epoch - 15ms/step
# Epoch 57/250
# 1456/1456 - 22s - loss: 0.1196 - mean_squared_error: 0.1196 - mean_absolute_error: 0.2528 - root_mean_squared_error: 0.3458 - 22s/epoch - 15ms/step
# Epoch 58/250
# 1456/1456 - 18s - loss: 0.1161 - mean_squared_error: 0.1161 - mean_absolute_error: 0.2494 - root_mean_squared_error: 0.3407 - 18s/epoch - 12ms/step
# Epoch 59/250
# 1456/1456 - 17s - loss: 0.1171 - mean_squared_error: 0.1171 - mean_absolute_error: 0.2506 - root_mean_squared_error: 0.3423 - 17s/epoch - 12ms/step
# Epoch 60/250
# 1456/1456 - 18s - loss: 0.1144 - mean_squared_error: 0.1144 - mean_absolute_error: 0.2480 - root_mean_squared_error: 0.3382 - 18s/epoch - 12ms/step
# Epoch 61/250
# 1456/1456 - 18s - loss: 0.1197 - mean_squared_error: 0.1197 - mean_absolute_error: 0.2529 - root_mean_squared_error: 0.3460 - 18s/epoch - 12ms/step
# Epoch 62/250
# 1456/1456 - 18s - loss: 0.1106 - mean_squared_error: 0.1106 - mean_absolute_error: 0.2417 - root_mean_squared_error: 0.3326 - 18s/epoch - 13ms/step
# Epoch 63/250
# 1456/1456 - 19s - loss: 0.1138 - mean_squared_error: 0.1138 - mean_absolute_error: 0.2454 - root_mean_squared_error: 0.3374 - 19s/epoch - 13ms/step
# Epoch 64/250
# 1456/1456 - 23s - loss: 0.1088 - mean_squared_error: 0.1088 - mean_absolute_error: 0.2407 - root_mean_squared_error: 0.3298 - 23s/epoch - 16ms/step
# Epoch 65/250
# 1456/1456 - 23s - loss: 0.1126 - mean_squared_error: 0.1126 - mean_absolute_error: 0.2446 - root_mean_squared_error: 0.3356 - 23s/epoch - 16ms/step
# Epoch 66/250
# 1456/1456 - 22s - loss: 0.1184 - mean_squared_error: 0.1184 - mean_absolute_error: 0.2509 - root_mean_squared_error: 0.3440 - 22s/epoch - 15ms/step
# Epoch 67/250
# 1456/1456 - 23s - loss: 0.1057 - mean_squared_error: 0.1057 - mean_absolute_error: 0.2358 - root_mean_squared_error: 0.3251 - 23s/epoch - 15ms/step
# Epoch 68/250
# 1456/1456 - 23s - loss: 0.1118 - mean_squared_error: 0.1118 - mean_absolute_error: 0.2441 - root_mean_squared_error: 0.3343 - 23s/epoch - 16ms/step
# Epoch 69/250
# 1456/1456 - 23s - loss: 0.1119 - mean_squared_error: 0.1119 - mean_absolute_error: 0.2438 - root_mean_squared_error: 0.3345 - 23s/epoch - 15ms/step
# Epoch 70/250
# 1456/1456 - 23s - loss: 0.1125 - mean_squared_error: 0.1125 - mean_absolute_error: 0.2408 - root_mean_squared_error: 0.3355 - 23s/epoch - 16ms/step
# Epoch 71/250
# 1456/1456 - 23s - loss: 0.1081 - mean_squared_error: 0.1081 - mean_absolute_error: 0.2383 - root_mean_squared_error: 0.3288 - 23s/epoch - 16ms/step
# Epoch 72/250
# 1456/1456 - 23s - loss: 0.1173 - mean_squared_error: 0.1173 - mean_absolute_error: 0.2433 - root_mean_squared_error: 0.3425 - 23s/epoch - 16ms/step
# Epoch 73/250
# 1456/1456 - 24s - loss: 0.1297 - mean_squared_error: 0.1297 - mean_absolute_error: 0.2510 - root_mean_squared_error: 0.3601 - 24s/epoch - 16ms/step
# Epoch 74/250
# 1456/1456 - 24s - loss: 0.0997 - mean_squared_error: 0.0997 - mean_absolute_error: 0.2257 - root_mean_squared_error: 0.3157 - 24s/epoch - 16ms/step
# Epoch 75/250
# 1456/1456 - 23s - loss: 0.1033 - mean_squared_error: 0.1033 - mean_absolute_error: 0.2336 - root_mean_squared_error: 0.3214 - 23s/epoch - 16ms/step
# Epoch 76/250
# 1456/1456 - 23s - loss: 0.1015 - mean_squared_error: 0.1015 - mean_absolute_error: 0.2306 - root_mean_squared_error: 0.3186 - 23s/epoch - 16ms/step
# Epoch 77/250
# 1456/1456 - 24s - loss: 0.1061 - mean_squared_error: 0.1061 - mean_absolute_error: 0.2356 - root_mean_squared_error: 0.3257 - 24s/epoch - 16ms/step
# Epoch 78/250
# 1456/1456 - 23s - loss: 0.1115 - mean_squared_error: 0.1115 - mean_absolute_error: 0.2432 - root_mean_squared_error: 0.3339 - 23s/epoch - 16ms/step
# Epoch 79/250
# 1456/1456 - 23s - loss: 0.1000 - mean_squared_error: 0.1000 - mean_absolute_error: 0.2261 - root_mean_squared_error: 0.3163 - 23s/epoch - 16ms/step
# Epoch 80/250
# 1456/1456 - 23s - loss: 0.1025 - mean_squared_error: 0.1025 - mean_absolute_error: 0.2320 - root_mean_squared_error: 0.3202 - 23s/epoch - 16ms/step
# Epoch 81/250
# 1456/1456 - 24s - loss: 0.1477 - mean_squared_error: 0.1477 - mean_absolute_error: 0.2641 - root_mean_squared_error: 0.3843 - 24s/epoch - 16ms/step
# Epoch 82/250
# 1456/1456 - 23s - loss: 0.0943 - mean_squared_error: 0.0943 - mean_absolute_error: 0.2191 - root_mean_squared_error: 0.3071 - 23s/epoch - 16ms/step
# Epoch 83/250
# 1456/1456 - 23s - loss: 0.0944 - mean_squared_error: 0.0944 - mean_absolute_error: 0.2236 - root_mean_squared_error: 0.3073 - 23s/epoch - 16ms/step
# Epoch 84/250
# 1456/1456 - 23s - loss: 0.1003 - mean_squared_error: 0.1003 - mean_absolute_error: 0.2282 - root_mean_squared_error: 0.3166 - 23s/epoch - 16ms/step
# Epoch 85/250
# 1456/1456 - 23s - loss: 0.1021 - mean_squared_error: 0.1021 - mean_absolute_error: 0.2332 - root_mean_squared_error: 0.3196 - 23s/epoch - 16ms/step
# Epoch 86/250
# 1456/1456 - 23s - loss: 0.0999 - mean_squared_error: 0.0999 - mean_absolute_error: 0.2289 - root_mean_squared_error: 0.3160 - 23s/epoch - 16ms/step
# Epoch 87/250
# 1456/1456 - 23s - loss: 0.1015 - mean_squared_error: 0.1015 - mean_absolute_error: 0.2303 - root_mean_squared_error: 0.3186 - 23s/epoch - 16ms/step
# Epoch 88/250
# 1456/1456 - 23s - loss: 0.1174 - mean_squared_error: 0.1174 - mean_absolute_error: 0.2444 - root_mean_squared_error: 0.3427 - 23s/epoch - 16ms/step
# Epoch 89/250
# 1456/1456 - 23s - loss: 0.0898 - mean_squared_error: 0.0898 - mean_absolute_error: 0.2160 - root_mean_squared_error: 0.2997 - 23s/epoch - 16ms/step
# Epoch 90/250
# 1456/1456 - 23s - loss: 0.0977 - mean_squared_error: 0.0977 - mean_absolute_error: 0.2242 - root_mean_squared_error: 0.3126 - 23s/epoch - 16ms/step
# Epoch 91/250
# 1456/1456 - 23s - loss: 0.0956 - mean_squared_error: 0.0956 - mean_absolute_error: 0.2236 - root_mean_squared_error: 0.3093 - 23s/epoch - 16ms/step
# Epoch 92/250
# 1456/1456 - 23s - loss: 0.1064 - mean_squared_error: 0.1064 - mean_absolute_error: 0.2364 - root_mean_squared_error: 0.3262 - 23s/epoch - 16ms/step
# Epoch 93/250
# 1456/1456 - 23s - loss: 0.0949 - mean_squared_error: 0.0949 - mean_absolute_error: 0.2231 - root_mean_squared_error: 0.3081 - 23s/epoch - 16ms/step
# Epoch 94/250
# 1456/1456 - 23s - loss: 0.1035 - mean_squared_error: 0.1035 - mean_absolute_error: 0.2317 - root_mean_squared_error: 0.3218 - 23s/epoch - 16ms/step
# Epoch 95/250
# 1456/1456 - 23s - loss: 0.0952 - mean_squared_error: 0.0952 - mean_absolute_error: 0.2213 - root_mean_squared_error: 0.3086 - 23s/epoch - 16ms/step
# Epoch 96/250
# 1456/1456 - 23s - loss: 0.1085 - mean_squared_error: 0.1085 - mean_absolute_error: 0.2323 - root_mean_squared_error: 0.3294 - 23s/epoch - 16ms/step
# Epoch 97/250
# 1456/1456 - 23s - loss: 0.0880 - mean_squared_error: 0.0880 - mean_absolute_error: 0.2134 - root_mean_squared_error: 0.2966 - 23s/epoch - 16ms/step
# Epoch 98/250
# 1456/1456 - 23s - loss: 0.0909 - mean_squared_error: 0.0909 - mean_absolute_error: 0.2180 - root_mean_squared_error: 0.3015 - 23s/epoch - 16ms/step
# Epoch 99/250
# 1456/1456 - 23s - loss: 0.1279 - mean_squared_error: 0.1279 - mean_absolute_error: 0.2511 - root_mean_squared_error: 0.3576 - 23s/epoch - 16ms/step
# Epoch 100/250
# 1456/1456 - 29s - loss: 0.0879 - mean_squared_error: 0.0879 - mean_absolute_error: 0.2124 - root_mean_squared_error: 0.2964 - val_loss: 0.1643 - val_mean_squared_error: 0.1643 - val_mean_absolute_error: 0.2834 - val_root_mean_squared_error: 0.4054 - 29s/epoch - 20ms/step
# Epoch 101/250
# 1456/1456 - 23s - loss: 0.0940 - mean_squared_error: 0.0940 - mean_absolute_error: 0.2206 - root_mean_squared_error: 0.3066 - 23s/epoch - 16ms/step
# Epoch 102/250
# 1456/1456 - 23s - loss: 0.1337 - mean_squared_error: 0.1337 - mean_absolute_error: 0.2527 - root_mean_squared_error: 0.3656 - 23s/epoch - 16ms/step
# Epoch 103/250
# 1456/1456 - 23s - loss: 0.0860 - mean_squared_error: 0.0860 - mean_absolute_error: 0.2077 - root_mean_squared_error: 0.2932 - 23s/epoch - 16ms/step
# Epoch 104/250
# 1456/1456 - 23s - loss: 0.0885 - mean_squared_error: 0.0885 - mean_absolute_error: 0.2123 - root_mean_squared_error: 0.2975 - 23s/epoch - 16ms/step
# Epoch 105/250
# 1456/1456 - 23s - loss: 0.0933 - mean_squared_error: 0.0933 - mean_absolute_error: 0.2193 - root_mean_squared_error: 0.3055 - 23s/epoch - 16ms/step
# Epoch 106/250
# 1456/1456 - 23s - loss: 0.0917 - mean_squared_error: 0.0917 - mean_absolute_error: 0.2178 - root_mean_squared_error: 0.3029 - 23s/epoch - 16ms/step
# Epoch 107/250
# 1456/1456 - 24s - loss: 0.0919 - mean_squared_error: 0.0919 - mean_absolute_error: 0.2158 - root_mean_squared_error: 0.3032 - 24s/epoch - 17ms/step
# Epoch 108/250
# 1456/1456 - 24s - loss: 0.0915 - mean_squared_error: 0.0915 - mean_absolute_error: 0.2170 - root_mean_squared_error: 0.3025 - 24s/epoch - 16ms/step
# Epoch 109/250
# 1456/1456 - 23s - loss: 0.0918 - mean_squared_error: 0.0918 - mean_absolute_error: 0.2170 - root_mean_squared_error: 0.3030 - 23s/epoch - 16ms/step
# Epoch 110/250
# 1456/1456 - 23s - loss: 0.0956 - mean_squared_error: 0.0956 - mean_absolute_error: 0.2219 - root_mean_squared_error: 0.3091 - 23s/epoch - 16ms/step
# Epoch 111/250
# 1456/1456 - 23s - loss: 0.0904 - mean_squared_error: 0.0904 - mean_absolute_error: 0.2156 - root_mean_squared_error: 0.3006 - 23s/epoch - 16ms/step
# Epoch 112/250
# 1456/1456 - 23s - loss: 0.0915 - mean_squared_error: 0.0915 - mean_absolute_error: 0.2166 - root_mean_squared_error: 0.3025 - 23s/epoch - 16ms/step
# Epoch 113/250
# 1456/1456 - 23s - loss: 0.0854 - mean_squared_error: 0.0854 - mean_absolute_error: 0.2084 - root_mean_squared_error: 0.2922 - 23s/epoch - 16ms/step
# Epoch 114/250
# 1456/1456 - 23s - loss: 0.0936 - mean_squared_error: 0.0936 - mean_absolute_error: 0.2222 - root_mean_squared_error: 0.3059 - 23s/epoch - 16ms/step
# Epoch 115/250
# 1456/1456 - 23s - loss: 0.0887 - mean_squared_error: 0.0887 - mean_absolute_error: 0.2135 - root_mean_squared_error: 0.2979 - 23s/epoch - 16ms/step
# Epoch 116/250
# 1456/1456 - 23s - loss: 0.0889 - mean_squared_error: 0.0889 - mean_absolute_error: 0.2128 - root_mean_squared_error: 0.2981 - 23s/epoch - 16ms/step
# Epoch 117/250
# 1456/1456 - 23s - loss: 0.0940 - mean_squared_error: 0.0940 - mean_absolute_error: 0.2195 - root_mean_squared_error: 0.3066 - 23s/epoch - 16ms/step
# Epoch 118/250
# 1456/1456 - 23s - loss: 0.0894 - mean_squared_error: 0.0894 - mean_absolute_error: 0.2135 - root_mean_squared_error: 0.2989 - 23s/epoch - 16ms/step
# Epoch 119/250
# 1456/1456 - 23s - loss: 0.0879 - mean_squared_error: 0.0879 - mean_absolute_error: 0.2117 - root_mean_squared_error: 0.2964 - 23s/epoch - 16ms/step
# Epoch 120/250
# 1456/1456 - 23s - loss: 0.0854 - mean_squared_error: 0.0854 - mean_absolute_error: 0.2081 - root_mean_squared_error: 0.2922 - 23s/epoch - 16ms/step
# Epoch 121/250
# 1456/1456 - 23s - loss: 0.0893 - mean_squared_error: 0.0893 - mean_absolute_error: 0.2163 - root_mean_squared_error: 0.2989 - 23s/epoch - 16ms/step
# Epoch 122/250
# 1456/1456 - 23s - loss: 0.0894 - mean_squared_error: 0.0894 - mean_absolute_error: 0.2171 - root_mean_squared_error: 0.2989 - 23s/epoch - 16ms/step
# Epoch 123/250
# 1456/1456 - 23s - loss: 0.0878 - mean_squared_error: 0.0878 - mean_absolute_error: 0.2130 - root_mean_squared_error: 0.2963 - 23s/epoch - 16ms/step
# Epoch 124/250
# 1456/1456 - 23s - loss: 0.0856 - mean_squared_error: 0.0856 - mean_absolute_error: 0.2106 - root_mean_squared_error: 0.2926 - 23s/epoch - 16ms/step
# Epoch 125/250
# 1456/1456 - 23s - loss: 0.0933 - mean_squared_error: 0.0933 - mean_absolute_error: 0.2170 - root_mean_squared_error: 0.3054 - 23s/epoch - 16ms/step
# Epoch 126/250
# 1456/1456 - 24s - loss: 0.0852 - mean_squared_error: 0.0852 - mean_absolute_error: 0.2083 - root_mean_squared_error: 0.2919 - 24s/epoch - 16ms/step
# Epoch 127/250
# 1456/1456 - 24s - loss: 0.0859 - mean_squared_error: 0.0859 - mean_absolute_error: 0.2109 - root_mean_squared_error: 0.2931 - 24s/epoch - 16ms/step
# Epoch 128/250
# 1456/1456 - 23s - loss: 0.0836 - mean_squared_error: 0.0836 - mean_absolute_error: 0.2069 - root_mean_squared_error: 0.2891 - 23s/epoch - 16ms/step
# Epoch 129/250
# 1456/1456 - 24s - loss: 0.0887 - mean_squared_error: 0.0887 - mean_absolute_error: 0.2111 - root_mean_squared_error: 0.2979 - 24s/epoch - 16ms/step
# Epoch 130/250
# 1456/1456 - 24s - loss: 0.0898 - mean_squared_error: 0.0898 - mean_absolute_error: 0.2164 - root_mean_squared_error: 0.2996 - 24s/epoch - 16ms/step
# Epoch 131/250
# 1456/1456 - 23s - loss: 0.0813 - mean_squared_error: 0.0813 - mean_absolute_error: 0.2045 - root_mean_squared_error: 0.2851 - 23s/epoch - 16ms/step
# Epoch 132/250
# 1456/1456 - 23s - loss: 0.0866 - mean_squared_error: 0.0866 - mean_absolute_error: 0.2108 - root_mean_squared_error: 0.2943 - 23s/epoch - 16ms/step
# Epoch 133/250
# 1456/1456 - 23s - loss: 0.0889 - mean_squared_error: 0.0889 - mean_absolute_error: 0.2134 - root_mean_squared_error: 0.2982 - 23s/epoch - 16ms/step
# Epoch 134/250
# 1456/1456 - 23s - loss: 0.0854 - mean_squared_error: 0.0854 - mean_absolute_error: 0.2102 - root_mean_squared_error: 0.2922 - 23s/epoch - 16ms/step
# Epoch 135/250
# 1456/1456 - 24s - loss: 0.0848 - mean_squared_error: 0.0848 - mean_absolute_error: 0.2105 - root_mean_squared_error: 0.2912 - 24s/epoch - 16ms/step
# Epoch 136/250
# 1456/1456 - 23s - loss: 0.0834 - mean_squared_error: 0.0834 - mean_absolute_error: 0.2069 - root_mean_squared_error: 0.2888 - 23s/epoch - 16ms/step
# Epoch 137/250
# 1456/1456 - 24s - loss: 0.0860 - mean_squared_error: 0.0860 - mean_absolute_error: 0.2102 - root_mean_squared_error: 0.2933 - 24s/epoch - 16ms/step
# Epoch 138/250
# 1456/1456 - 24s - loss: 0.0846 - mean_squared_error: 0.0846 - mean_absolute_error: 0.2070 - root_mean_squared_error: 0.2909 - 24s/epoch - 16ms/step
# Epoch 139/250
# 1456/1456 - 24s - loss: 0.0838 - mean_squared_error: 0.0838 - mean_absolute_error: 0.2063 - root_mean_squared_error: 0.2895 - 24s/epoch - 16ms/step
# Epoch 140/250
# 1456/1456 - 23s - loss: 0.0863 - mean_squared_error: 0.0863 - mean_absolute_error: 0.2098 - root_mean_squared_error: 0.2938 - 23s/epoch - 16ms/step
# Epoch 141/250
# 1456/1456 - 23s - loss: 0.0802 - mean_squared_error: 0.0802 - mean_absolute_error: 0.2010 - root_mean_squared_error: 0.2832 - 23s/epoch - 16ms/step
# Epoch 142/250
# 1456/1456 - 23s - loss: 0.0927 - mean_squared_error: 0.0927 - mean_absolute_error: 0.2189 - root_mean_squared_error: 0.3045 - 23s/epoch - 16ms/step
# Epoch 143/250
# 1456/1456 - 24s - loss: 0.0805 - mean_squared_error: 0.0805 - mean_absolute_error: 0.1993 - root_mean_squared_error: 0.2837 - 24s/epoch - 16ms/step
# Epoch 144/250
# 1456/1456 - 24s - loss: 0.0776 - mean_squared_error: 0.0776 - mean_absolute_error: 0.1991 - root_mean_squared_error: 0.2786 - 24s/epoch - 17ms/step
# Epoch 145/250
# 1456/1456 - 23s - loss: 0.0850 - mean_squared_error: 0.0850 - mean_absolute_error: 0.2090 - root_mean_squared_error: 0.2915 - 23s/epoch - 16ms/step
# Epoch 146/250
# 1456/1456 - 291s - loss: 0.0835 - mean_squared_error: 0.0835 - mean_absolute_error: 0.2073 - root_mean_squared_error: 0.2890 - 291s/epoch - 200ms/step
# Epoch 147/250
# 1456/1456 - 921s - loss: 0.0890 - mean_squared_error: 0.0890 - mean_absolute_error: 0.2114 - root_mean_squared_error: 0.2983 - 921s/epoch - 633ms/step
# Epoch 148/250
# 1456/1456 - 16s - loss: 0.1098 - mean_squared_error: 0.1098 - mean_absolute_error: 0.2280 - root_mean_squared_error: 0.3313 - 16s/epoch - 11ms/step
# Epoch 149/250
# 1456/1456 - 11s - loss: 0.1019 - mean_squared_error: 0.1019 - mean_absolute_error: 0.2183 - root_mean_squared_error: 0.3193 - 11s/epoch - 8ms/step
# Epoch 150/250
# 1456/1456 - 13s - loss: 0.0773 - mean_squared_error: 0.0773 - mean_absolute_error: 0.1994 - root_mean_squared_error: 0.2781 - 13s/epoch - 9ms/step
# Epoch 151/250
# 1456/1456 - 12s - loss: 0.0784 - mean_squared_error: 0.0784 - mean_absolute_error: 0.2000 - root_mean_squared_error: 0.2800 - 12s/epoch - 8ms/step
# Epoch 152/250
# 1456/1456 - 11s - loss: 0.0827 - mean_squared_error: 0.0827 - mean_absolute_error: 0.2047 - root_mean_squared_error: 0.2875 - 11s/epoch - 8ms/step
# Epoch 153/250
# 1456/1456 - 10s - loss: 0.0793 - mean_squared_error: 0.0793 - mean_absolute_error: 0.2022 - root_mean_squared_error: 0.2817 - 10s/epoch - 7ms/step
# Epoch 154/250
# 1456/1456 - 11s - loss: 0.0812 - mean_squared_error: 0.0812 - mean_absolute_error: 0.2043 - root_mean_squared_error: 0.2850 - 11s/epoch - 8ms/step
# Epoch 155/250
# 1456/1456 - 11s - loss: 0.0819 - mean_squared_error: 0.0819 - mean_absolute_error: 0.2070 - root_mean_squared_error: 0.2862 - 11s/epoch - 7ms/step
# Epoch 156/250
# 1456/1456 - 11s - loss: 0.0794 - mean_squared_error: 0.0794 - mean_absolute_error: 0.2013 - root_mean_squared_error: 0.2817 - 11s/epoch - 7ms/step
# Epoch 157/250
# 1456/1456 - 13s - loss: 0.0876 - mean_squared_error: 0.0876 - mean_absolute_error: 0.2109 - root_mean_squared_error: 0.2961 - 13s/epoch - 9ms/step
# Epoch 158/250
# 1456/1456 - 15s - loss: 0.0772 - mean_squared_error: 0.0772 - mean_absolute_error: 0.1975 - root_mean_squared_error: 0.2778 - 15s/epoch - 11ms/step
# Epoch 159/250
# 1456/1456 - 16s - loss: 0.0814 - mean_squared_error: 0.0814 - mean_absolute_error: 0.2038 - root_mean_squared_error: 0.2852 - 16s/epoch - 11ms/step
# Epoch 160/250
# 1456/1456 - 14s - loss: 0.0899 - mean_squared_error: 0.0899 - mean_absolute_error: 0.2110 - root_mean_squared_error: 0.2998 - 14s/epoch - 9ms/step
# Epoch 161/250
# 1456/1456 - 16s - loss: 0.0773 - mean_squared_error: 0.0773 - mean_absolute_error: 0.1983 - root_mean_squared_error: 0.2781 - 16s/epoch - 11ms/step
# Epoch 162/250
# 1456/1456 - 18s - loss: 0.0806 - mean_squared_error: 0.0806 - mean_absolute_error: 0.2015 - root_mean_squared_error: 0.2838 - 18s/epoch - 12ms/step
# Epoch 163/250
# 1456/1456 - 17s - loss: 0.0799 - mean_squared_error: 0.0799 - mean_absolute_error: 0.2010 - root_mean_squared_error: 0.2826 - 17s/epoch - 12ms/step
# Epoch 164/250
# 1456/1456 - 18s - loss: 0.0821 - mean_squared_error: 0.0821 - mean_absolute_error: 0.2052 - root_mean_squared_error: 0.2865 - 18s/epoch - 12ms/step
# Epoch 165/250
# 1456/1456 - 16s - loss: 0.0906 - mean_squared_error: 0.0906 - mean_absolute_error: 0.2124 - root_mean_squared_error: 0.3009 - 16s/epoch - 11ms/step
# Epoch 166/250
# 1456/1456 - 15s - loss: 0.0741 - mean_squared_error: 0.0741 - mean_absolute_error: 0.1928 - root_mean_squared_error: 0.2722 - 15s/epoch - 11ms/step
# Epoch 167/250
# 1456/1456 - 17s - loss: 0.0738 - mean_squared_error: 0.0738 - mean_absolute_error: 0.1923 - root_mean_squared_error: 0.2716 - 17s/epoch - 11ms/step
# Epoch 168/250
# 1456/1456 - 14s - loss: 0.0803 - mean_squared_error: 0.0803 - mean_absolute_error: 0.2029 - root_mean_squared_error: 0.2833 - 14s/epoch - 10ms/step
# Epoch 169/250
# 1456/1456 - 16s - loss: 0.0816 - mean_squared_error: 0.0816 - mean_absolute_error: 0.2022 - root_mean_squared_error: 0.2856 - 16s/epoch - 11ms/step
# Epoch 170/250
# 1456/1456 - 17s - loss: 0.0761 - mean_squared_error: 0.0761 - mean_absolute_error: 0.1953 - root_mean_squared_error: 0.2758 - 17s/epoch - 12ms/step
# Epoch 171/250
# 1456/1456 - 17s - loss: 0.0787 - mean_squared_error: 0.0787 - mean_absolute_error: 0.2006 - root_mean_squared_error: 0.2805 - 17s/epoch - 12ms/step
# Epoch 172/250
# 1456/1456 - 11s - loss: 0.0808 - mean_squared_error: 0.0808 - mean_absolute_error: 0.2037 - root_mean_squared_error: 0.2842 - 11s/epoch - 8ms/step
# Epoch 173/250
# 1456/1456 - 14s - loss: 0.0757 - mean_squared_error: 0.0757 - mean_absolute_error: 0.1945 - root_mean_squared_error: 0.2752 - 14s/epoch - 10ms/step
# Epoch 174/250
# 1456/1456 - 13s - loss: 0.0793 - mean_squared_error: 0.0793 - mean_absolute_error: 0.2013 - root_mean_squared_error: 0.2816 - 13s/epoch - 9ms/step
# Epoch 175/250
# 1456/1456 - 14s - loss: 0.0759 - mean_squared_error: 0.0759 - mean_absolute_error: 0.1951 - root_mean_squared_error: 0.2756 - 14s/epoch - 10ms/step
# Epoch 176/250
# 1456/1456 - 15s - loss: 0.0760 - mean_squared_error: 0.0760 - mean_absolute_error: 0.1970 - root_mean_squared_error: 0.2757 - 15s/epoch - 10ms/step
# Epoch 177/250
# 1456/1456 - 15s - loss: 0.0796 - mean_squared_error: 0.0796 - mean_absolute_error: 0.2004 - root_mean_squared_error: 0.2821 - 15s/epoch - 10ms/step
# Epoch 178/250
# 1456/1456 - 15s - loss: 0.0759 - mean_squared_error: 0.0759 - mean_absolute_error: 0.1962 - root_mean_squared_error: 0.2754 - 15s/epoch - 10ms/step
# Epoch 179/250
# 1456/1456 - 16s - loss: 0.1004 - mean_squared_error: 0.1004 - mean_absolute_error: 0.2190 - root_mean_squared_error: 0.3169 - 16s/epoch - 11ms/step
# Epoch 180/250
# 1456/1456 - 15s - loss: 0.0751 - mean_squared_error: 0.0751 - mean_absolute_error: 0.1933 - root_mean_squared_error: 0.2740 - 15s/epoch - 10ms/step
# Epoch 181/250
# 1456/1456 - 17s - loss: 0.0719 - mean_squared_error: 0.0719 - mean_absolute_error: 0.1911 - root_mean_squared_error: 0.2681 - 17s/epoch - 12ms/step
# Epoch 182/250
# 1456/1456 - 15s - loss: 0.0731 - mean_squared_error: 0.0731 - mean_absolute_error: 0.1920 - root_mean_squared_error: 0.2703 - 15s/epoch - 10ms/step
# Epoch 183/250
# 1456/1456 - 15s - loss: 0.0799 - mean_squared_error: 0.0799 - mean_absolute_error: 0.2008 - root_mean_squared_error: 0.2826 - 15s/epoch - 11ms/step
# Epoch 184/250
# 1456/1456 - 15s - loss: 0.0765 - mean_squared_error: 0.0765 - mean_absolute_error: 0.1954 - root_mean_squared_error: 0.2765 - 15s/epoch - 10ms/step
# Epoch 185/250
# 1456/1456 - 13s - loss: 0.0779 - mean_squared_error: 0.0779 - mean_absolute_error: 0.1996 - root_mean_squared_error: 0.2791 - 13s/epoch - 9ms/step
# Epoch 186/250
# 1456/1456 - 16s - loss: 0.0770 - mean_squared_error: 0.0770 - mean_absolute_error: 0.1961 - root_mean_squared_error: 0.2775 - 16s/epoch - 11ms/step
# Epoch 187/250
# 1456/1456 - 15s - loss: 0.0790 - mean_squared_error: 0.0790 - mean_absolute_error: 0.1997 - root_mean_squared_error: 0.2811 - 15s/epoch - 11ms/step
# Epoch 188/250
# 1456/1456 - 14s - loss: 0.0772 - mean_squared_error: 0.0772 - mean_absolute_error: 0.1974 - root_mean_squared_error: 0.2779 - 14s/epoch - 10ms/step
# Epoch 189/250
# 1456/1456 - 12s - loss: 0.0757 - mean_squared_error: 0.0757 - mean_absolute_error: 0.1943 - root_mean_squared_error: 0.2752 - 12s/epoch - 8ms/step
# Epoch 190/250
# 1456/1456 - 15s - loss: 0.0758 - mean_squared_error: 0.0758 - mean_absolute_error: 0.1971 - root_mean_squared_error: 0.2753 - 15s/epoch - 10ms/step
# Epoch 191/250
# 1456/1456 - 14s - loss: 0.0768 - mean_squared_error: 0.0768 - mean_absolute_error: 0.1977 - root_mean_squared_error: 0.2771 - 14s/epoch - 10ms/step
# Epoch 192/250
# 1456/1456 - 14s - loss: 0.0742 - mean_squared_error: 0.0742 - mean_absolute_error: 0.1934 - root_mean_squared_error: 0.2725 - 14s/epoch - 10ms/step
# Epoch 193/250
# 1456/1456 - 13s - loss: 0.0852 - mean_squared_error: 0.0852 - mean_absolute_error: 0.2046 - root_mean_squared_error: 0.2919 - 13s/epoch - 9ms/step
# Epoch 194/250
# 1456/1456 - 15s - loss: 0.0742 - mean_squared_error: 0.0742 - mean_absolute_error: 0.1919 - root_mean_squared_error: 0.2724 - 15s/epoch - 10ms/step
# Epoch 195/250
# 1456/1456 - 14s - loss: 0.0759 - mean_squared_error: 0.0759 - mean_absolute_error: 0.1944 - root_mean_squared_error: 0.2756 - 14s/epoch - 10ms/step
# Epoch 196/250
# 1456/1456 - 14s - loss: 0.0747 - mean_squared_error: 0.0747 - mean_absolute_error: 0.1954 - root_mean_squared_error: 0.2733 - 14s/epoch - 10ms/step
# Epoch 197/250
# 1456/1456 - 13s - loss: 0.0809 - mean_squared_error: 0.0809 - mean_absolute_error: 0.2037 - root_mean_squared_error: 0.2845 - 13s/epoch - 9ms/step
# Epoch 198/250
# 1456/1456 - 14s - loss: 0.0685 - mean_squared_error: 0.0685 - mean_absolute_error: 0.1872 - root_mean_squared_error: 0.2618 - 14s/epoch - 10ms/step
# Epoch 199/250
# 1456/1456 - 14s - loss: 0.0749 - mean_squared_error: 0.0749 - mean_absolute_error: 0.1941 - root_mean_squared_error: 0.2737 - 14s/epoch - 10ms/step
# Epoch 200/250
# 1456/1456 - 17s - loss: 0.0782 - mean_squared_error: 0.0782 - mean_absolute_error: 0.1992 - root_mean_squared_error: 0.2796 - val_loss: 0.1530 - val_mean_squared_error: 0.1530 - val_mean_absolute_error: 0.2556 - val_root_mean_squared_error: 0.3912 - 17s/epoch - 12ms/step
# Epoch 201/250
# 1456/1456 - 13s - loss: 0.0724 - mean_squared_error: 0.0724 - mean_absolute_error: 0.1924 - root_mean_squared_error: 0.2692 - 13s/epoch - 9ms/step
# Epoch 202/250
# 1456/1456 - 15s - loss: 0.0742 - mean_squared_error: 0.0742 - mean_absolute_error: 0.1924 - root_mean_squared_error: 0.2723 - 15s/epoch - 10ms/step
# Epoch 203/250
# 1456/1456 - 14s - loss: 0.0726 - mean_squared_error: 0.0726 - mean_absolute_error: 0.1902 - root_mean_squared_error: 0.2694 - 14s/epoch - 10ms/step
# Epoch 204/250
# 1456/1456 - 15s - loss: 0.0759 - mean_squared_error: 0.0759 - mean_absolute_error: 0.1933 - root_mean_squared_error: 0.2755 - 15s/epoch - 10ms/step
# Epoch 205/250
# 1456/1456 - 14s - loss: 0.0752 - mean_squared_error: 0.0752 - mean_absolute_error: 0.1932 - root_mean_squared_error: 0.2741 - 14s/epoch - 9ms/step
# Epoch 206/250
# 1456/1456 - 14s - loss: 0.0746 - mean_squared_error: 0.0746 - mean_absolute_error: 0.1934 - root_mean_squared_error: 0.2731 - 14s/epoch - 10ms/step
# Epoch 207/250
# 1456/1456 - 14s - loss: 0.0718 - mean_squared_error: 0.0718 - mean_absolute_error: 0.1901 - root_mean_squared_error: 0.2680 - 14s/epoch - 10ms/step
# Epoch 208/250
# 1456/1456 - 14s - loss: 0.0734 - mean_squared_error: 0.0734 - mean_absolute_error: 0.1916 - root_mean_squared_error: 0.2710 - 14s/epoch - 9ms/step
# Epoch 209/250
# 1456/1456 - 13s - loss: 0.0721 - mean_squared_error: 0.0721 - mean_absolute_error: 0.1903 - root_mean_squared_error: 0.2685 - 13s/epoch - 9ms/step
# Epoch 210/250
# 1456/1456 - 11s - loss: 0.0718 - mean_squared_error: 0.0718 - mean_absolute_error: 0.1918 - root_mean_squared_error: 0.2679 - 11s/epoch - 7ms/step
# Epoch 211/250
# 1456/1456 - 14s - loss: 0.0762 - mean_squared_error: 0.0762 - mean_absolute_error: 0.1968 - root_mean_squared_error: 0.2760 - 14s/epoch - 10ms/step
# Epoch 212/250
# 1456/1456 - 15s - loss: 0.0750 - mean_squared_error: 0.0750 - mean_absolute_error: 0.1927 - root_mean_squared_error: 0.2739 - 15s/epoch - 10ms/step
# Epoch 213/250
# 1456/1456 - 14s - loss: 0.0726 - mean_squared_error: 0.0726 - mean_absolute_error: 0.1914 - root_mean_squared_error: 0.2694 - 14s/epoch - 10ms/step
# Epoch 214/250
# 1456/1456 - 14s - loss: 0.0714 - mean_squared_error: 0.0714 - mean_absolute_error: 0.1902 - root_mean_squared_error: 0.2672 - 14s/epoch - 9ms/step
# Epoch 215/250
# 1456/1456 - 15s - loss: 0.0739 - mean_squared_error: 0.0739 - mean_absolute_error: 0.1930 - root_mean_squared_error: 0.2719 - 15s/epoch - 10ms/step
# Epoch 216/250
# 1456/1456 - 15s - loss: 0.0723 - mean_squared_error: 0.0723 - mean_absolute_error: 0.1912 - root_mean_squared_error: 0.2690 - 15s/epoch - 10ms/step
# Epoch 217/250
# 1456/1456 - 15s - loss: 0.0729 - mean_squared_error: 0.0729 - mean_absolute_error: 0.1913 - root_mean_squared_error: 0.2701 - 15s/epoch - 10ms/step
# Epoch 218/250
# 1456/1456 - 14s - loss: 0.0753 - mean_squared_error: 0.0753 - mean_absolute_error: 0.1919 - root_mean_squared_error: 0.2744 - 14s/epoch - 10ms/step
# Epoch 219/250
# 1456/1456 - 15s - loss: 0.0700 - mean_squared_error: 0.0700 - mean_absolute_error: 0.1889 - root_mean_squared_error: 0.2646 - 15s/epoch - 10ms/step
# Epoch 220/250
# 1456/1456 - 15s - loss: 0.0701 - mean_squared_error: 0.0701 - mean_absolute_error: 0.1868 - root_mean_squared_error: 0.2647 - 15s/epoch - 10ms/step
# Epoch 221/250
# 1456/1456 - 15s - loss: 0.0712 - mean_squared_error: 0.0712 - mean_absolute_error: 0.1899 - root_mean_squared_error: 0.2668 - 15s/epoch - 10ms/step
# Epoch 222/250
# 1456/1456 - 14s - loss: 0.0743 - mean_squared_error: 0.0743 - mean_absolute_error: 0.1950 - root_mean_squared_error: 0.2727 - 14s/epoch - 10ms/step
# Epoch 223/250
# 1456/1456 - 17s - loss: 0.0732 - mean_squared_error: 0.0732 - mean_absolute_error: 0.1904 - root_mean_squared_error: 0.2705 - 17s/epoch - 12ms/step
# Epoch 224/250
# 1456/1456 - 16s - loss: 0.0709 - mean_squared_error: 0.0709 - mean_absolute_error: 0.1881 - root_mean_squared_error: 0.2662 - 16s/epoch - 11ms/step
# Epoch 225/250
# 1456/1456 - 15s - loss: 0.0725 - mean_squared_error: 0.0725 - mean_absolute_error: 0.1909 - root_mean_squared_error: 0.2692 - 15s/epoch - 10ms/step
# Epoch 226/250
# 1456/1456 - 15s - loss: 0.0726 - mean_squared_error: 0.0726 - mean_absolute_error: 0.1906 - root_mean_squared_error: 0.2694 - 15s/epoch - 10ms/step
# Epoch 227/250
# 1456/1456 - 15s - loss: 0.0694 - mean_squared_error: 0.0694 - mean_absolute_error: 0.1881 - root_mean_squared_error: 0.2634 - 15s/epoch - 11ms/step
# Epoch 228/250
# 1456/1456 - 15s - loss: 0.0700 - mean_squared_error: 0.0700 - mean_absolute_error: 0.1887 - root_mean_squared_error: 0.2645 - 15s/epoch - 10ms/step
# Epoch 229/250
# 1456/1456 - 15s - loss: 0.0718 - mean_squared_error: 0.0718 - mean_absolute_error: 0.1897 - root_mean_squared_error: 0.2680 - 15s/epoch - 11ms/step
# Epoch 230/250
# 1456/1456 - 16s - loss: 0.0904 - mean_squared_error: 0.0904 - mean_absolute_error: 0.2096 - root_mean_squared_error: 0.3007 - 16s/epoch - 11ms/step
# Epoch 231/250
# 1456/1456 - 20s - loss: 0.0643 - mean_squared_error: 0.0643 - mean_absolute_error: 0.1789 - root_mean_squared_error: 0.2537 - 20s/epoch - 14ms/step
# Epoch 232/250
# 1456/1456 - 21s - loss: 0.0640 - mean_squared_error: 0.0640 - mean_absolute_error: 0.1780 - root_mean_squared_error: 0.2531 - 21s/epoch - 14ms/step
# Epoch 233/250
# 1456/1456 - 22s - loss: 0.0684 - mean_squared_error: 0.0684 - mean_absolute_error: 0.1866 - root_mean_squared_error: 0.2615 - 22s/epoch - 15ms/step
# Epoch 234/250
# 1456/1456 - 21s - loss: 0.0699 - mean_squared_error: 0.0699 - mean_absolute_error: 0.1885 - root_mean_squared_error: 0.2644 - 21s/epoch - 15ms/step
# Epoch 235/250
# 1456/1456 - 19s - loss: 0.0733 - mean_squared_error: 0.0733 - mean_absolute_error: 0.1953 - root_mean_squared_error: 0.2707 - 19s/epoch - 13ms/step
# Epoch 236/250
# 1456/1456 - 19s - loss: 0.0710 - mean_squared_error: 0.0710 - mean_absolute_error: 0.1900 - root_mean_squared_error: 0.2664 - 19s/epoch - 13ms/step
# Epoch 237/250
# 1456/1456 - 18s - loss: 0.0710 - mean_squared_error: 0.0710 - mean_absolute_error: 0.1889 - root_mean_squared_error: 0.2664 - 18s/epoch - 13ms/step
# Epoch 238/250
# 1456/1456 - 19s - loss: 0.0737 - mean_squared_error: 0.0737 - mean_absolute_error: 0.1911 - root_mean_squared_error: 0.2714 - 19s/epoch - 13ms/step
# Epoch 239/250
# 1456/1456 - 19s - loss: 0.0680 - mean_squared_error: 0.0680 - mean_absolute_error: 0.1847 - root_mean_squared_error: 0.2608 - 19s/epoch - 13ms/step
# Epoch 240/250
# 1456/1456 - 18s - loss: 0.0655 - mean_squared_error: 0.0655 - mean_absolute_error: 0.1840 - root_mean_squared_error: 0.2559 - 18s/epoch - 13ms/step
# Epoch 241/250
# 1456/1456 - 19s - loss: 0.0696 - mean_squared_error: 0.0696 - mean_absolute_error: 0.1895 - root_mean_squared_error: 0.2639 - 19s/epoch - 13ms/step
# Epoch 242/250
# 1456/1456 - 19s - loss: 0.0671 - mean_squared_error: 0.0671 - mean_absolute_error: 0.1829 - root_mean_squared_error: 0.2590 - 19s/epoch - 13ms/step
# Epoch 243/250
# 1456/1456 - 19s - loss: 0.0723 - mean_squared_error: 0.0723 - mean_absolute_error: 0.1888 - root_mean_squared_error: 0.2689 - 19s/epoch - 13ms/step
# Epoch 244/250
# 1456/1456 - 19s - loss: 0.0651 - mean_squared_error: 0.0651 - mean_absolute_error: 0.1827 - root_mean_squared_error: 0.2552 - 19s/epoch - 13ms/step
# Epoch 245/250
# 1456/1456 - 19s - loss: 0.0698 - mean_squared_error: 0.0698 - mean_absolute_error: 0.1879 - root_mean_squared_error: 0.2641 - 19s/epoch - 13ms/step
# Epoch 246/250
# 1456/1456 - 19s - loss: 0.0701 - mean_squared_error: 0.0701 - mean_absolute_error: 0.1879 - root_mean_squared_error: 0.2648 - 19s/epoch - 13ms/step
# Epoch 247/250
# 1456/1456 - 19s - loss: 0.0675 - mean_squared_error: 0.0675 - mean_absolute_error: 0.1857 - root_mean_squared_error: 0.2597 - 19s/epoch - 13ms/step
# Epoch 248/250
# 1456/1456 - 19s - loss: 0.0762 - mean_squared_error: 0.0762 - mean_absolute_error: 0.1978 - root_mean_squared_error: 0.2761 - 19s/epoch - 13ms/step
# Epoch 249/250
# 1456/1456 - 19s - loss: 0.0652 - mean_squared_error: 0.0652 - mean_absolute_error: 0.1806 - root_mean_squared_error: 0.2554 - 19s/epoch - 13ms/step
# Epoch 250/250
# 1456/1456 - 18s - loss: 0.0683 - mean_squared_error: 0.0683 - mean_absolute_error: 0.1852 - root_mean_squared_error: 0.2613 - 18s/epoch - 13ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "biLSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              25728
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 10, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 10, 128)          74496
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            129
#  ed)
#
# =================================================================
# Total params: 100,353
# Trainable params: 100,353
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 0.06825198978185654
# Final mean_squared_error : 0.06825204193592072
# Final mean_absolute_error : 0.18519949913024902
# Final root_mean_squared_error : 0.26125091314315796
# Final val_loss : 0.1530420482158661
# Final val_mean_squared_error : 0.15304212272167206
# Final val_mean_absolute_error : 0.2556024193763733
# Final val_root_mean_squared_error : 0.3912059962749481
#
# -------------------- Evaluation on Test Data --------------------
# 29/29 [==============================] - 3s 8ms/step - loss: 0.0858 - mean_squared_error: 0.0858 - mean_absolute_error: 0.2151 - root_mean_squared_error: 0.2929

# %%
from keras.utils import plot_model,model_to_dot
plot_model(model2, show_shapes=True, to_file='plotmodelbilstm0810.png')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model_to_dot(model2,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model2
