# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# c:\Python\Python310\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
df=df.iloc[200000:205000]
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 35.0489          0.0    -15.8150    -3.78100         NaN
#           35.0609          0.0    -14.8850    -3.91760         NaN
#           35.0629          0.0    -14.5760    -3.74700         NaN
#           35.0649          0.0    -14.7640    -3.88940         NaN
#           35.0669          0.0    -14.4410    -3.83180         NaN
# ...                        ...         ...         ...         ...
# -120.4027 36.7274          0.0     -7.2276     0.73694      2.6327
#           36.7294          0.0     -7.3210     0.70109      2.4708
#           36.7314          0.0     -7.2388     0.46256      2.4291
#           36.7334          0.0     -7.2526     0.31420      2.0908
#           36.7394          0.0     -7.1203    -0.03439      2.3198
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 35.0489     -3.81260     -3.4671    -7.75040    -3.56890
#           35.0609     -3.91700     -3.2592    -7.92540    -3.72760
#           35.0629     -3.68630     -2.8954    -7.46720    -3.42460
#           35.0649     -3.80730     -3.1875    -7.69430    -3.64120
#           35.0669     -3.79350     -3.2384    -7.74860    -3.69970
# ...                        ...         ...         ...         ...
# -120.4027 36.7274     -0.37212      4.1269    -0.77547     1.42630
#           36.7294     -0.53777      3.9807    -0.90438     1.26980
#           36.7314     -0.72740      3.7277    -1.12300     0.91064
#           36.7334     -1.04390      3.4792    -1.13890     0.93199
#           36.7394     -0.72105      3.6205    -1.04990     0.92451
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 35.0489      -4.4897    -1.66720  ...    -10.3170     -7.5373
#           35.0609      -4.8079    -2.08030  ...    -11.7620     -8.9301
#           35.0629      -4.4473    -1.83730  ...    -13.1510    -10.2660
#           35.0649      -4.7031    -2.02100  ...    -13.0580    -10.2560
#           35.0669      -4.7355    -1.97580  ...    -13.5610    -10.7640
# ...                        ...         ...  ...         ...         ...
# -120.4027 36.7274       3.9578    -0.83484  ...     -4.7423     -1.7626
#           36.7294       3.9292    -0.64295  ...     -4.2087     -1.2368
#           36.7314       3.6537    -0.98271  ...     -4.7961     -1.8559
#           36.7334       3.3421    -1.11060  ...     -5.8926     -2.9637
#           36.7394       3.2634    -1.40170  ...     -5.4141     -2.5313
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 35.0489      -8.7209    -11.2120    -10.7480    -13.2020
#           35.0609     -10.2470    -12.6600    -12.4420    -14.9950
#           35.0629     -11.6180    -14.0450    -13.8780    -16.5090
#           35.0649     -11.5870    -14.0190    -13.8640    -16.4920
#           35.0669     -12.1090    -14.5200    -14.3170    -16.9960
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -2.7142     -3.0876     -6.2273     -5.2793
#           36.7294      -2.1775     -2.5592     -5.7036     -4.6893
#           36.7314      -2.7951     -3.1822     -6.3403     -5.3780
#           36.7334      -3.8852     -4.2657     -7.4344     -6.3047
#           36.7394      -3.4532     -3.8240     -6.9644     -6.0637
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 35.0489      -9.2688     -6.4277     -7.5077    -7.91640
#           35.0609     -10.4110     -7.9618     -8.9148    -9.43790
#           35.0629     -11.8270     -9.3040    -10.4320   -10.78100
#           35.0649     -11.8730     -9.2702    -10.3670   -10.75000
#           35.0669     -12.2140     -9.7466    -10.6810   -11.29000
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -4.3728     -2.3947     -2.9965    -1.00440
#           36.7294      -3.7768     -1.8226     -2.4654    -0.46636
#           36.7314      -4.5069     -2.6101     -3.2475    -1.26730
#           36.7334      -5.4811     -3.6036     -4.2325    -2.30970
#           36.7394      -5.2230     -3.3785     -4.0178    -2.04980
#
# [5000 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    for row in range(0,len(datain.index),1750): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model = Sequential(name="CNN-LSTM-Model")
#model.add(Masking(mask_value=-100, input_shape=(timestep, 1)))
model.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) 

model.add(Conv1D(128,1,activation='relu',padding='same'))

model.add(MaxPooling1D(1,padding='same'))
# model.add(Conv1D(16,1,activation='tanh',padding='same'))
# model.add(MaxPooling1D(1,padding='same'))
#model.add(Dense(3, activation='softmax')) 
#model.add(LSTM(units=64, activation='relu',stateful=False, return_sequences=True))
model.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))
#model.add(TimeDistributed(Dense(100)))
#model.add(Dense(3, activation='softmax')) screws it
#model.add(TimeDistributed(Dense(1)))172
model.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
model.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %% [markdown]
# ##### Train model

# %%
history = model.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 109/109 - 2s - loss: 10.6168 - mean_squared_error: 10.6168 - mean_absolute_error: 2.5826 - 2s/epoch - 14ms/step
# Epoch 2/250
# 109/109 - 0s - loss: 9.5315 - mean_squared_error: 9.5315 - mean_absolute_error: 2.3810 - 341ms/epoch - 3ms/step
# Epoch 3/250
# 109/109 - 0s - loss: 9.4318 - mean_squared_error: 9.4318 - mean_absolute_error: 2.3696 - 332ms/epoch - 3ms/step
# Epoch 4/250
# 109/109 - 0s - loss: 9.2563 - mean_squared_error: 9.2563 - mean_absolute_error: 2.3370 - 341ms/epoch - 3ms/step
# Epoch 5/250
# 109/109 - 0s - loss: 9.1269 - mean_squared_error: 9.1269 - mean_absolute_error: 2.3205 - 340ms/epoch - 3ms/step
# Epoch 6/250
# 109/109 - 0s - loss: 8.8863 - mean_squared_error: 8.8863 - mean_absolute_error: 2.2801 - 349ms/epoch - 3ms/step
# Epoch 7/250
# 109/109 - 0s - loss: 8.6635 - mean_squared_error: 8.6635 - mean_absolute_error: 2.2355 - 347ms/epoch - 3ms/step
# Epoch 8/250
# 109/109 - 0s - loss: 8.5283 - mean_squared_error: 8.5283 - mean_absolute_error: 2.2375 - 383ms/epoch - 4ms/step
# Epoch 9/250
# 109/109 - 0s - loss: 8.4230 - mean_squared_error: 8.4230 - mean_absolute_error: 2.2239 - 348ms/epoch - 3ms/step
# Epoch 10/250
# 109/109 - 0s - loss: 8.6940 - mean_squared_error: 8.6940 - mean_absolute_error: 2.2294 - 323ms/epoch - 3ms/step
# Epoch 11/250
# 109/109 - 0s - loss: 8.1995 - mean_squared_error: 8.1995 - mean_absolute_error: 2.1768 - 330ms/epoch - 3ms/step
# Epoch 12/250
# 109/109 - 0s - loss: 7.7225 - mean_squared_error: 7.7225 - mean_absolute_error: 2.1084 - 488ms/epoch - 4ms/step
# Epoch 13/250
# 109/109 - 0s - loss: 7.6066 - mean_squared_error: 7.6066 - mean_absolute_error: 2.0820 - 334ms/epoch - 3ms/step
# Epoch 14/250
# 109/109 - 0s - loss: 7.0130 - mean_squared_error: 7.0130 - mean_absolute_error: 1.9947 - 330ms/epoch - 3ms/step
# Epoch 15/250
# 109/109 - 0s - loss: 6.5336 - mean_squared_error: 6.5336 - mean_absolute_error: 1.9252 - 334ms/epoch - 3ms/step
# Epoch 16/250
# 109/109 - 0s - loss: 6.2611 - mean_squared_error: 6.2611 - mean_absolute_error: 1.8752 - 342ms/epoch - 3ms/step
# Epoch 17/250
# 109/109 - 0s - loss: 6.0049 - mean_squared_error: 6.0049 - mean_absolute_error: 1.8288 - 345ms/epoch - 3ms/step
# Epoch 18/250
# 109/109 - 0s - loss: 5.8029 - mean_squared_error: 5.8029 - mean_absolute_error: 1.7896 - 346ms/epoch - 3ms/step
# Epoch 19/250
# 109/109 - 0s - loss: 5.5490 - mean_squared_error: 5.5490 - mean_absolute_error: 1.7186 - 332ms/epoch - 3ms/step
# Epoch 20/250
# 109/109 - 0s - loss: 5.4563 - mean_squared_error: 5.4563 - mean_absolute_error: 1.6945 - 334ms/epoch - 3ms/step
# Epoch 21/250
# 109/109 - 0s - loss: 5.0370 - mean_squared_error: 5.0370 - mean_absolute_error: 1.6278 - 344ms/epoch - 3ms/step
# Epoch 22/250
# 109/109 - 0s - loss: 4.9211 - mean_squared_error: 4.9211 - mean_absolute_error: 1.5971 - 335ms/epoch - 3ms/step
# Epoch 23/250
# 109/109 - 0s - loss: 4.6556 - mean_squared_error: 4.6556 - mean_absolute_error: 1.5220 - 451ms/epoch - 4ms/step
# Epoch 24/250
# 109/109 - 0s - loss: 4.4769 - mean_squared_error: 4.4769 - mean_absolute_error: 1.4715 - 357ms/epoch - 3ms/step
# Epoch 25/250
# 109/109 - 0s - loss: 4.6477 - mean_squared_error: 4.6477 - mean_absolute_error: 1.5149 - 333ms/epoch - 3ms/step
# Epoch 26/250
# 109/109 - 0s - loss: 4.3503 - mean_squared_error: 4.3503 - mean_absolute_error: 1.4407 - 327ms/epoch - 3ms/step
# Epoch 27/250
# 109/109 - 0s - loss: 4.3758 - mean_squared_error: 4.3758 - mean_absolute_error: 1.4685 - 349ms/epoch - 3ms/step
# Epoch 28/250
# 109/109 - 0s - loss: 4.2739 - mean_squared_error: 4.2739 - mean_absolute_error: 1.4404 - 341ms/epoch - 3ms/step
# Epoch 29/250
# 109/109 - 0s - loss: 4.1796 - mean_squared_error: 4.1796 - mean_absolute_error: 1.3979 - 334ms/epoch - 3ms/step
# Epoch 30/250
# 109/109 - 0s - loss: 4.1365 - mean_squared_error: 4.1365 - mean_absolute_error: 1.3691 - 346ms/epoch - 3ms/step
# Epoch 31/250
# 109/109 - 0s - loss: 4.0992 - mean_squared_error: 4.0992 - mean_absolute_error: 1.3805 - 340ms/epoch - 3ms/step
# Epoch 32/250
# 109/109 - 0s - loss: 4.0253 - mean_squared_error: 4.0253 - mean_absolute_error: 1.3529 - 367ms/epoch - 3ms/step
# Epoch 33/250
# 109/109 - 0s - loss: 3.8504 - mean_squared_error: 3.8504 - mean_absolute_error: 1.3028 - 335ms/epoch - 3ms/step
# Epoch 34/250
# 109/109 - 0s - loss: 3.8642 - mean_squared_error: 3.8642 - mean_absolute_error: 1.3203 - 347ms/epoch - 3ms/step
# Epoch 35/250
# 109/109 - 0s - loss: 4.0556 - mean_squared_error: 4.0556 - mean_absolute_error: 1.3652 - 443ms/epoch - 4ms/step
# Epoch 36/250
# 109/109 - 0s - loss: 3.7987 - mean_squared_error: 3.7987 - mean_absolute_error: 1.2945 - 451ms/epoch - 4ms/step
# Epoch 37/250
# 109/109 - 0s - loss: 3.8766 - mean_squared_error: 3.8766 - mean_absolute_error: 1.3346 - 413ms/epoch - 4ms/step
# Epoch 38/250
# 109/109 - 0s - loss: 3.9713 - mean_squared_error: 3.9713 - mean_absolute_error: 1.3451 - 342ms/epoch - 3ms/step
# Epoch 39/250
# 109/109 - 0s - loss: 3.8304 - mean_squared_error: 3.8304 - mean_absolute_error: 1.2998 - 380ms/epoch - 3ms/step
# Epoch 40/250
# 109/109 - 0s - loss: 3.6436 - mean_squared_error: 3.6436 - mean_absolute_error: 1.2587 - 354ms/epoch - 3ms/step
# Epoch 41/250
# 109/109 - 0s - loss: 3.5884 - mean_squared_error: 3.5884 - mean_absolute_error: 1.2289 - 347ms/epoch - 3ms/step
# Epoch 42/250
# 109/109 - 0s - loss: 3.5978 - mean_squared_error: 3.5978 - mean_absolute_error: 1.2486 - 405ms/epoch - 4ms/step
# Epoch 43/250
# 109/109 - 0s - loss: 3.5131 - mean_squared_error: 3.5131 - mean_absolute_error: 1.2107 - 328ms/epoch - 3ms/step
# Epoch 44/250
# 109/109 - 0s - loss: 3.5154 - mean_squared_error: 3.5154 - mean_absolute_error: 1.2231 - 402ms/epoch - 4ms/step
# Epoch 45/250
# 109/109 - 0s - loss: 3.4685 - mean_squared_error: 3.4685 - mean_absolute_error: 1.1992 - 366ms/epoch - 3ms/step
# Epoch 46/250
# 109/109 - 0s - loss: 3.4618 - mean_squared_error: 3.4618 - mean_absolute_error: 1.2072 - 337ms/epoch - 3ms/step
# Epoch 47/250
# 109/109 - 0s - loss: 3.4389 - mean_squared_error: 3.4389 - mean_absolute_error: 1.2126 - 335ms/epoch - 3ms/step
# Epoch 48/250
# 109/109 - 0s - loss: 4.6539 - mean_squared_error: 4.6539 - mean_absolute_error: 1.3996 - 335ms/epoch - 3ms/step
# Epoch 49/250
# 109/109 - 0s - loss: 4.1847 - mean_squared_error: 4.1847 - mean_absolute_error: 1.3759 - 338ms/epoch - 3ms/step
# Epoch 50/250
# 109/109 - 0s - loss: 3.6229 - mean_squared_error: 3.6229 - mean_absolute_error: 1.2371 - 335ms/epoch - 3ms/step
# Epoch 51/250
# 109/109 - 0s - loss: 3.4352 - mean_squared_error: 3.4352 - mean_absolute_error: 1.1851 - 342ms/epoch - 3ms/step
# Epoch 52/250
# 109/109 - 0s - loss: 3.3115 - mean_squared_error: 3.3115 - mean_absolute_error: 1.1513 - 330ms/epoch - 3ms/step
# Epoch 53/250
# 109/109 - 0s - loss: 3.3371 - mean_squared_error: 3.3371 - mean_absolute_error: 1.1641 - 346ms/epoch - 3ms/step
# Epoch 54/250
# 109/109 - 0s - loss: 3.2523 - mean_squared_error: 3.2523 - mean_absolute_error: 1.1339 - 343ms/epoch - 3ms/step
# Epoch 55/250
# 109/109 - 0s - loss: 3.1657 - mean_squared_error: 3.1657 - mean_absolute_error: 1.1108 - 346ms/epoch - 3ms/step
# Epoch 56/250
# 109/109 - 0s - loss: 3.1487 - mean_squared_error: 3.1487 - mean_absolute_error: 1.0948 - 340ms/epoch - 3ms/step
# Epoch 57/250
# 109/109 - 0s - loss: 3.1045 - mean_squared_error: 3.1045 - mean_absolute_error: 1.0881 - 336ms/epoch - 3ms/step
# Epoch 58/250
# 109/109 - 0s - loss: 3.0417 - mean_squared_error: 3.0417 - mean_absolute_error: 1.0678 - 343ms/epoch - 3ms/step
# Epoch 59/250
# 109/109 - 0s - loss: 3.0759 - mean_squared_error: 3.0759 - mean_absolute_error: 1.0725 - 340ms/epoch - 3ms/step
# Epoch 60/250
# 109/109 - 0s - loss: 3.0668 - mean_squared_error: 3.0668 - mean_absolute_error: 1.0828 - 329ms/epoch - 3ms/step
# Epoch 61/250
# 109/109 - 0s - loss: 2.9945 - mean_squared_error: 2.9944 - mean_absolute_error: 1.0731 - 326ms/epoch - 3ms/step
# Epoch 62/250
# 109/109 - 0s - loss: 2.9584 - mean_squared_error: 2.9584 - mean_absolute_error: 1.0349 - 419ms/epoch - 4ms/step
# Epoch 63/250
# 109/109 - 0s - loss: 2.9892 - mean_squared_error: 2.9892 - mean_absolute_error: 1.0546 - 346ms/epoch - 3ms/step
# Epoch 64/250
# 109/109 - 0s - loss: 2.8744 - mean_squared_error: 2.8744 - mean_absolute_error: 1.0329 - 380ms/epoch - 3ms/step
# Epoch 65/250
# 109/109 - 0s - loss: 2.9976 - mean_squared_error: 2.9976 - mean_absolute_error: 1.0401 - 408ms/epoch - 4ms/step
# Epoch 66/250
# 109/109 - 0s - loss: 2.9402 - mean_squared_error: 2.9402 - mean_absolute_error: 1.0368 - 341ms/epoch - 3ms/step
# Epoch 67/250
# 109/109 - 0s - loss: 2.9122 - mean_squared_error: 2.9122 - mean_absolute_error: 1.0343 - 378ms/epoch - 3ms/step
# Epoch 68/250
# 109/109 - 0s - loss: 2.8192 - mean_squared_error: 2.8192 - mean_absolute_error: 0.9817 - 399ms/epoch - 4ms/step
# Epoch 69/250
# 109/109 - 0s - loss: 2.8105 - mean_squared_error: 2.8105 - mean_absolute_error: 0.9849 - 341ms/epoch - 3ms/step
# Epoch 70/250
# 109/109 - 0s - loss: 2.8434 - mean_squared_error: 2.8434 - mean_absolute_error: 1.0035 - 342ms/epoch - 3ms/step
# Epoch 71/250
# 109/109 - 0s - loss: 2.8055 - mean_squared_error: 2.8055 - mean_absolute_error: 0.9872 - 425ms/epoch - 4ms/step
# Epoch 72/250
# 109/109 - 0s - loss: 2.9175 - mean_squared_error: 2.9175 - mean_absolute_error: 1.0467 - 450ms/epoch - 4ms/step
# Epoch 73/250
# 109/109 - 0s - loss: 2.8341 - mean_squared_error: 2.8341 - mean_absolute_error: 1.0119 - 488ms/epoch - 4ms/step
# Epoch 74/250
# 109/109 - 1s - loss: 2.7862 - mean_squared_error: 2.7862 - mean_absolute_error: 0.9803 - 500ms/epoch - 5ms/step
# Epoch 75/250
# 109/109 - 0s - loss: 2.7597 - mean_squared_error: 2.7597 - mean_absolute_error: 0.9754 - 360ms/epoch - 3ms/step
# Epoch 76/250
# 109/109 - 0s - loss: 2.7315 - mean_squared_error: 2.7315 - mean_absolute_error: 0.9758 - 428ms/epoch - 4ms/step
# Epoch 77/250
# 109/109 - 0s - loss: 2.7620 - mean_squared_error: 2.7620 - mean_absolute_error: 0.9980 - 363ms/epoch - 3ms/step
# Epoch 78/250
# 109/109 - 0s - loss: 2.6961 - mean_squared_error: 2.6961 - mean_absolute_error: 0.9759 - 338ms/epoch - 3ms/step
# Epoch 79/250
# 109/109 - 0s - loss: 2.6467 - mean_squared_error: 2.6467 - mean_absolute_error: 0.9456 - 339ms/epoch - 3ms/step
# Epoch 80/250
# 109/109 - 0s - loss: 2.7027 - mean_squared_error: 2.7027 - mean_absolute_error: 0.9667 - 442ms/epoch - 4ms/step
# Epoch 81/250
# 109/109 - 0s - loss: 2.7156 - mean_squared_error: 2.7156 - mean_absolute_error: 0.9610 - 336ms/epoch - 3ms/step
# Epoch 82/250
# 109/109 - 0s - loss: 2.6537 - mean_squared_error: 2.6537 - mean_absolute_error: 0.9560 - 374ms/epoch - 3ms/step
# Epoch 83/250
# 109/109 - 0s - loss: 2.6550 - mean_squared_error: 2.6550 - mean_absolute_error: 0.9724 - 365ms/epoch - 3ms/step
# Epoch 84/250
# 109/109 - 0s - loss: 2.6515 - mean_squared_error: 2.6515 - mean_absolute_error: 0.9546 - 391ms/epoch - 4ms/step
# Epoch 85/250
# 109/109 - 0s - loss: 2.6877 - mean_squared_error: 2.6877 - mean_absolute_error: 0.9707 - 333ms/epoch - 3ms/step
# Epoch 86/250
# 109/109 - 0s - loss: 2.6430 - mean_squared_error: 2.6430 - mean_absolute_error: 0.9555 - 344ms/epoch - 3ms/step
# Epoch 87/250
# 109/109 - 0s - loss: 2.5725 - mean_squared_error: 2.5725 - mean_absolute_error: 0.9294 - 499ms/epoch - 5ms/step
# Epoch 88/250
# 109/109 - 0s - loss: 2.5905 - mean_squared_error: 2.5905 - mean_absolute_error: 0.9295 - 384ms/epoch - 4ms/step
# Epoch 89/250
# 109/109 - 0s - loss: 2.5522 - mean_squared_error: 2.5522 - mean_absolute_error: 0.9239 - 435ms/epoch - 4ms/step
# Epoch 90/250
# 109/109 - 0s - loss: 2.5895 - mean_squared_error: 2.5895 - mean_absolute_error: 0.9348 - 371ms/epoch - 3ms/step
# Epoch 91/250
# 109/109 - 0s - loss: 2.5266 - mean_squared_error: 2.5266 - mean_absolute_error: 0.8914 - 365ms/epoch - 3ms/step
# Epoch 92/250
# 109/109 - 0s - loss: 2.7505 - mean_squared_error: 2.7505 - mean_absolute_error: 0.9820 - 333ms/epoch - 3ms/step
# Epoch 93/250
# 109/109 - 0s - loss: 2.5743 - mean_squared_error: 2.5743 - mean_absolute_error: 0.9268 - 363ms/epoch - 3ms/step
# Epoch 94/250
# 109/109 - 0s - loss: 2.5423 - mean_squared_error: 2.5423 - mean_absolute_error: 0.9254 - 372ms/epoch - 3ms/step
# Epoch 95/250
# 109/109 - 0s - loss: 2.4850 - mean_squared_error: 2.4850 - mean_absolute_error: 0.8914 - 355ms/epoch - 3ms/step
# Epoch 96/250
# 109/109 - 0s - loss: 2.5023 - mean_squared_error: 2.5023 - mean_absolute_error: 0.8968 - 403ms/epoch - 4ms/step
# Epoch 97/250
# 109/109 - 0s - loss: 2.4696 - mean_squared_error: 2.4696 - mean_absolute_error: 0.8954 - 440ms/epoch - 4ms/step
# Epoch 98/250
# 109/109 - 0s - loss: 2.5775 - mean_squared_error: 2.5775 - mean_absolute_error: 0.9317 - 467ms/epoch - 4ms/step
# Epoch 99/250
# 109/109 - 0s - loss: 2.4893 - mean_squared_error: 2.4893 - mean_absolute_error: 0.8880 - 414ms/epoch - 4ms/step
# Epoch 100/250
# 109/109 - 1s - loss: 2.4582 - mean_squared_error: 2.4582 - mean_absolute_error: 0.8805 - val_loss: 11.5206 - val_mean_squared_error: 11.5206 - val_mean_absolute_error: 2.7581 - 946ms/epoch - 9ms/step
# Epoch 101/250
# 109/109 - 0s - loss: 2.4859 - mean_squared_error: 2.4859 - mean_absolute_error: 0.8801 - 383ms/epoch - 4ms/step
# Epoch 102/250
# 109/109 - 0s - loss: 2.4612 - mean_squared_error: 2.4612 - mean_absolute_error: 0.8795 - 445ms/epoch - 4ms/step
# Epoch 103/250
# 109/109 - 0s - loss: 2.4107 - mean_squared_error: 2.4107 - mean_absolute_error: 0.8675 - 415ms/epoch - 4ms/step
# Epoch 104/250
# 109/109 - 0s - loss: 2.5544 - mean_squared_error: 2.5544 - mean_absolute_error: 0.9054 - 368ms/epoch - 3ms/step
# Epoch 105/250
# 109/109 - 0s - loss: 2.6276 - mean_squared_error: 2.6276 - mean_absolute_error: 0.9627 - 360ms/epoch - 3ms/step
# Epoch 106/250
# 109/109 - 0s - loss: 2.4445 - mean_squared_error: 2.4445 - mean_absolute_error: 0.8633 - 382ms/epoch - 4ms/step
# Epoch 107/250
# 109/109 - 0s - loss: 2.4916 - mean_squared_error: 2.4916 - mean_absolute_error: 0.8993 - 367ms/epoch - 3ms/step
# Epoch 108/250
# 109/109 - 0s - loss: 2.4383 - mean_squared_error: 2.4383 - mean_absolute_error: 0.8867 - 397ms/epoch - 4ms/step
# Epoch 109/250
# 109/109 - 0s - loss: 2.4206 - mean_squared_error: 2.4206 - mean_absolute_error: 0.8781 - 369ms/epoch - 3ms/step
# Epoch 110/250
# 109/109 - 0s - loss: 2.3943 - mean_squared_error: 2.3943 - mean_absolute_error: 0.8711 - 356ms/epoch - 3ms/step
# Epoch 111/250
# 109/109 - 0s - loss: 2.3572 - mean_squared_error: 2.3572 - mean_absolute_error: 0.8373 - 360ms/epoch - 3ms/step
# Epoch 112/250
# 109/109 - 0s - loss: 2.3910 - mean_squared_error: 2.3910 - mean_absolute_error: 0.8580 - 351ms/epoch - 3ms/step
# Epoch 113/250
# 109/109 - 0s - loss: 2.5577 - mean_squared_error: 2.5577 - mean_absolute_error: 0.9052 - 343ms/epoch - 3ms/step
# Epoch 114/250
# 109/109 - 0s - loss: 2.3838 - mean_squared_error: 2.3838 - mean_absolute_error: 0.8643 - 344ms/epoch - 3ms/step
# Epoch 115/250
# 109/109 - 0s - loss: 2.3692 - mean_squared_error: 2.3692 - mean_absolute_error: 0.8483 - 350ms/epoch - 3ms/step
# Epoch 116/250
# 109/109 - 0s - loss: 2.3472 - mean_squared_error: 2.3472 - mean_absolute_error: 0.8370 - 343ms/epoch - 3ms/step
# Epoch 117/250
# 109/109 - 0s - loss: 2.3157 - mean_squared_error: 2.3157 - mean_absolute_error: 0.8335 - 343ms/epoch - 3ms/step
# Epoch 118/250
# 109/109 - 0s - loss: 2.3632 - mean_squared_error: 2.3632 - mean_absolute_error: 0.8559 - 358ms/epoch - 3ms/step
# Epoch 119/250
# 109/109 - 0s - loss: 2.3557 - mean_squared_error: 2.3557 - mean_absolute_error: 0.8616 - 366ms/epoch - 3ms/step
# Epoch 120/250
# 109/109 - 0s - loss: 2.3658 - mean_squared_error: 2.3658 - mean_absolute_error: 0.8692 - 337ms/epoch - 3ms/step
# Epoch 121/250
# 109/109 - 0s - loss: 2.3490 - mean_squared_error: 2.3490 - mean_absolute_error: 0.8652 - 330ms/epoch - 3ms/step
# Epoch 122/250
# 109/109 - 0s - loss: 2.3583 - mean_squared_error: 2.3583 - mean_absolute_error: 0.8675 - 422ms/epoch - 4ms/step
# Epoch 123/250
# 109/109 - 0s - loss: 2.4293 - mean_squared_error: 2.4293 - mean_absolute_error: 0.8773 - 344ms/epoch - 3ms/step
# Epoch 124/250
# 109/109 - 0s - loss: 2.3417 - mean_squared_error: 2.3417 - mean_absolute_error: 0.8321 - 372ms/epoch - 3ms/step
# Epoch 125/250
# 109/109 - 0s - loss: 2.3838 - mean_squared_error: 2.3838 - mean_absolute_error: 0.8802 - 328ms/epoch - 3ms/step
# Epoch 126/250
# 109/109 - 0s - loss: 2.3196 - mean_squared_error: 2.3196 - mean_absolute_error: 0.8581 - 337ms/epoch - 3ms/step
# Epoch 127/250
# 109/109 - 0s - loss: 2.2821 - mean_squared_error: 2.2821 - mean_absolute_error: 0.8406 - 329ms/epoch - 3ms/step
# Epoch 128/250
# 109/109 - 0s - loss: 2.3419 - mean_squared_error: 2.3419 - mean_absolute_error: 0.8632 - 342ms/epoch - 3ms/step
# Epoch 129/250
# 109/109 - 0s - loss: 2.2744 - mean_squared_error: 2.2744 - mean_absolute_error: 0.8217 - 363ms/epoch - 3ms/step
# Epoch 130/250
# 109/109 - 0s - loss: 2.2936 - mean_squared_error: 2.2936 - mean_absolute_error: 0.8266 - 350ms/epoch - 3ms/step
# Epoch 131/250
# 109/109 - 0s - loss: 2.3145 - mean_squared_error: 2.3145 - mean_absolute_error: 0.8678 - 334ms/epoch - 3ms/step
# Epoch 132/250
# 109/109 - 0s - loss: 2.2623 - mean_squared_error: 2.2623 - mean_absolute_error: 0.8312 - 339ms/epoch - 3ms/step
# Epoch 133/250
# 109/109 - 0s - loss: 2.2380 - mean_squared_error: 2.2380 - mean_absolute_error: 0.8075 - 367ms/epoch - 3ms/step
# Epoch 134/250
# 109/109 - 0s - loss: 2.2258 - mean_squared_error: 2.2258 - mean_absolute_error: 0.8061 - 330ms/epoch - 3ms/step
# Epoch 135/250
# 109/109 - 0s - loss: 2.2547 - mean_squared_error: 2.2547 - mean_absolute_error: 0.8169 - 356ms/epoch - 3ms/step
# Epoch 136/250
# 109/109 - 0s - loss: 2.2307 - mean_squared_error: 2.2307 - mean_absolute_error: 0.8256 - 373ms/epoch - 3ms/step
# Epoch 137/250
# 109/109 - 0s - loss: 2.2477 - mean_squared_error: 2.2477 - mean_absolute_error: 0.8365 - 352ms/epoch - 3ms/step
# Epoch 138/250
# 109/109 - 0s - loss: 2.2694 - mean_squared_error: 2.2694 - mean_absolute_error: 0.8425 - 341ms/epoch - 3ms/step
# Epoch 139/250
# 109/109 - 0s - loss: 2.2992 - mean_squared_error: 2.2992 - mean_absolute_error: 0.8611 - 359ms/epoch - 3ms/step
# Epoch 140/250
# 109/109 - 0s - loss: 2.2600 - mean_squared_error: 2.2600 - mean_absolute_error: 0.8079 - 344ms/epoch - 3ms/step
# Epoch 141/250
# 109/109 - 0s - loss: 2.2129 - mean_squared_error: 2.2129 - mean_absolute_error: 0.8047 - 339ms/epoch - 3ms/step
# Epoch 142/250
# 109/109 - 0s - loss: 2.2903 - mean_squared_error: 2.2903 - mean_absolute_error: 0.8540 - 335ms/epoch - 3ms/step
# Epoch 143/250
# 109/109 - 0s - loss: 2.2674 - mean_squared_error: 2.2674 - mean_absolute_error: 0.8248 - 358ms/epoch - 3ms/step
# Epoch 144/250
# 109/109 - 0s - loss: 2.2163 - mean_squared_error: 2.2163 - mean_absolute_error: 0.7933 - 409ms/epoch - 4ms/step
# Epoch 145/250
# 109/109 - 0s - loss: 2.1850 - mean_squared_error: 2.1850 - mean_absolute_error: 0.7871 - 455ms/epoch - 4ms/step
# Epoch 146/250
# 109/109 - 0s - loss: 2.1528 - mean_squared_error: 2.1528 - mean_absolute_error: 0.7845 - 433ms/epoch - 4ms/step
# Epoch 147/250
# 109/109 - 0s - loss: 2.1820 - mean_squared_error: 2.1820 - mean_absolute_error: 0.7888 - 414ms/epoch - 4ms/step
# Epoch 148/250
# 109/109 - 0s - loss: 2.2291 - mean_squared_error: 2.2291 - mean_absolute_error: 0.7982 - 346ms/epoch - 3ms/step
# Epoch 149/250
# 109/109 - 0s - loss: 2.2234 - mean_squared_error: 2.2234 - mean_absolute_error: 0.8186 - 338ms/epoch - 3ms/step
# Epoch 150/250
# 109/109 - 0s - loss: 2.1567 - mean_squared_error: 2.1567 - mean_absolute_error: 0.7828 - 323ms/epoch - 3ms/step
# Epoch 151/250
# 109/109 - 0s - loss: 2.1565 - mean_squared_error: 2.1565 - mean_absolute_error: 0.7913 - 325ms/epoch - 3ms/step
# Epoch 152/250
# 109/109 - 0s - loss: 2.1511 - mean_squared_error: 2.1511 - mean_absolute_error: 0.7870 - 329ms/epoch - 3ms/step
# Epoch 153/250
# 109/109 - 0s - loss: 2.1346 - mean_squared_error: 2.1346 - mean_absolute_error: 0.7642 - 376ms/epoch - 3ms/step
# Epoch 154/250
# 109/109 - 0s - loss: 2.1602 - mean_squared_error: 2.1602 - mean_absolute_error: 0.7889 - 455ms/epoch - 4ms/step
# Epoch 155/250
# 109/109 - 0s - loss: 2.1645 - mean_squared_error: 2.1645 - mean_absolute_error: 0.7870 - 440ms/epoch - 4ms/step
# Epoch 156/250
# 109/109 - 0s - loss: 2.1460 - mean_squared_error: 2.1460 - mean_absolute_error: 0.7843 - 368ms/epoch - 3ms/step
# Epoch 157/250
# 109/109 - 0s - loss: 2.1592 - mean_squared_error: 2.1592 - mean_absolute_error: 0.7978 - 406ms/epoch - 4ms/step
# Epoch 158/250
# 109/109 - 0s - loss: 2.1733 - mean_squared_error: 2.1733 - mean_absolute_error: 0.8086 - 398ms/epoch - 4ms/step
# Epoch 159/250
# 109/109 - 0s - loss: 2.1636 - mean_squared_error: 2.1636 - mean_absolute_error: 0.8000 - 360ms/epoch - 3ms/step
# Epoch 160/250
# 109/109 - 0s - loss: 2.1811 - mean_squared_error: 2.1811 - mean_absolute_error: 0.8232 - 374ms/epoch - 3ms/step
# Epoch 161/250
# 109/109 - 0s - loss: 2.1413 - mean_squared_error: 2.1413 - mean_absolute_error: 0.8012 - 395ms/epoch - 4ms/step
# Epoch 162/250
# 109/109 - 0s - loss: 2.1346 - mean_squared_error: 2.1346 - mean_absolute_error: 0.7811 - 396ms/epoch - 4ms/step
# Epoch 163/250
# 109/109 - 0s - loss: 2.1121 - mean_squared_error: 2.1121 - mean_absolute_error: 0.7794 - 389ms/epoch - 4ms/step
# Epoch 164/250
# 109/109 - 0s - loss: 2.1231 - mean_squared_error: 2.1231 - mean_absolute_error: 0.7741 - 492ms/epoch - 5ms/step
# Epoch 165/250
# 109/109 - 0s - loss: 2.1367 - mean_squared_error: 2.1367 - mean_absolute_error: 0.7871 - 360ms/epoch - 3ms/step
# Epoch 166/250
# 109/109 - 0s - loss: 2.1094 - mean_squared_error: 2.1094 - mean_absolute_error: 0.7761 - 354ms/epoch - 3ms/step
# Epoch 167/250
# 109/109 - 0s - loss: 2.1136 - mean_squared_error: 2.1136 - mean_absolute_error: 0.7818 - 370ms/epoch - 3ms/step
# Epoch 168/250
# 109/109 - 0s - loss: 2.0950 - mean_squared_error: 2.0950 - mean_absolute_error: 0.7761 - 398ms/epoch - 4ms/step
# Epoch 169/250
# 109/109 - 0s - loss: 2.1185 - mean_squared_error: 2.1185 - mean_absolute_error: 0.7800 - 392ms/epoch - 4ms/step
# Epoch 170/250
# 109/109 - 0s - loss: 2.0893 - mean_squared_error: 2.0893 - mean_absolute_error: 0.7745 - 372ms/epoch - 3ms/step
# Epoch 171/250
# 109/109 - 0s - loss: 2.0923 - mean_squared_error: 2.0923 - mean_absolute_error: 0.7774 - 362ms/epoch - 3ms/step
# Epoch 172/250
# 109/109 - 0s - loss: 2.0772 - mean_squared_error: 2.0772 - mean_absolute_error: 0.7673 - 361ms/epoch - 3ms/step
# Epoch 173/250
# 109/109 - 0s - loss: 2.1284 - mean_squared_error: 2.1284 - mean_absolute_error: 0.7968 - 358ms/epoch - 3ms/step
# Epoch 174/250
# 109/109 - 0s - loss: 2.1620 - mean_squared_error: 2.1620 - mean_absolute_error: 0.8266 - 364ms/epoch - 3ms/step
# Epoch 175/250
# 109/109 - 0s - loss: 2.3749 - mean_squared_error: 2.3749 - mean_absolute_error: 0.8719 - 355ms/epoch - 3ms/step
# Epoch 176/250
# 109/109 - 0s - loss: 2.1274 - mean_squared_error: 2.1274 - mean_absolute_error: 0.8008 - 385ms/epoch - 4ms/step
# Epoch 177/250
# 109/109 - 0s - loss: 2.1221 - mean_squared_error: 2.1221 - mean_absolute_error: 0.7850 - 367ms/epoch - 3ms/step
# Epoch 178/250
# 109/109 - 0s - loss: 2.0428 - mean_squared_error: 2.0428 - mean_absolute_error: 0.7509 - 370ms/epoch - 3ms/step
# Epoch 179/250
# 109/109 - 0s - loss: 2.0303 - mean_squared_error: 2.0303 - mean_absolute_error: 0.7336 - 360ms/epoch - 3ms/step
# Epoch 180/250
# 109/109 - 0s - loss: 2.0197 - mean_squared_error: 2.0197 - mean_absolute_error: 0.7360 - 371ms/epoch - 3ms/step
# Epoch 181/250
# 109/109 - 0s - loss: 2.0149 - mean_squared_error: 2.0149 - mean_absolute_error: 0.7336 - 379ms/epoch - 3ms/step
# Epoch 182/250
# 109/109 - 0s - loss: 1.9936 - mean_squared_error: 1.9936 - mean_absolute_error: 0.7201 - 373ms/epoch - 3ms/step
# Epoch 183/250
# 109/109 - 0s - loss: 2.3056 - mean_squared_error: 2.3056 - mean_absolute_error: 0.8512 - 361ms/epoch - 3ms/step
# Epoch 184/250
# 109/109 - 0s - loss: 2.0752 - mean_squared_error: 2.0752 - mean_absolute_error: 0.7734 - 358ms/epoch - 3ms/step
# Epoch 185/250
# 109/109 - 0s - loss: 2.0285 - mean_squared_error: 2.0285 - mean_absolute_error: 0.7465 - 386ms/epoch - 4ms/step
# Epoch 186/250
# 109/109 - 0s - loss: 1.9857 - mean_squared_error: 1.9857 - mean_absolute_error: 0.7241 - 480ms/epoch - 4ms/step
# Epoch 187/250
# 109/109 - 0s - loss: 1.9850 - mean_squared_error: 1.9850 - mean_absolute_error: 0.7257 - 380ms/epoch - 3ms/step
# Epoch 188/250
# 109/109 - 0s - loss: 2.0092 - mean_squared_error: 2.0092 - mean_absolute_error: 0.7281 - 367ms/epoch - 3ms/step
# Epoch 189/250
# 109/109 - 0s - loss: 1.9833 - mean_squared_error: 1.9833 - mean_absolute_error: 0.7297 - 370ms/epoch - 3ms/step
# Epoch 190/250
# 109/109 - 0s - loss: 1.9739 - mean_squared_error: 1.9739 - mean_absolute_error: 0.7324 - 375ms/epoch - 3ms/step
# Epoch 191/250
# 109/109 - 0s - loss: 1.9847 - mean_squared_error: 1.9847 - mean_absolute_error: 0.7337 - 393ms/epoch - 4ms/step
# Epoch 192/250
# 109/109 - 0s - loss: 1.9671 - mean_squared_error: 1.9671 - mean_absolute_error: 0.7229 - 361ms/epoch - 3ms/step
# Epoch 193/250
# 109/109 - 0s - loss: 2.0343 - mean_squared_error: 2.0343 - mean_absolute_error: 0.7588 - 372ms/epoch - 3ms/step
# Epoch 194/250
# 109/109 - 0s - loss: 1.9789 - mean_squared_error: 1.9789 - mean_absolute_error: 0.7439 - 390ms/epoch - 4ms/step
# Epoch 195/250
# 109/109 - 0s - loss: 1.9952 - mean_squared_error: 1.9952 - mean_absolute_error: 0.7544 - 386ms/epoch - 4ms/step
# Epoch 196/250
# 109/109 - 0s - loss: 1.9611 - mean_squared_error: 1.9611 - mean_absolute_error: 0.7302 - 357ms/epoch - 3ms/step
# Epoch 197/250
# 109/109 - 0s - loss: 2.0258 - mean_squared_error: 2.0258 - mean_absolute_error: 0.7788 - 373ms/epoch - 3ms/step
# Epoch 198/250
# 109/109 - 0s - loss: 1.9624 - mean_squared_error: 1.9624 - mean_absolute_error: 0.7334 - 361ms/epoch - 3ms/step
# Epoch 199/250
# 109/109 - 0s - loss: 1.9529 - mean_squared_error: 1.9529 - mean_absolute_error: 0.7239 - 389ms/epoch - 4ms/step
# Epoch 200/250
# 109/109 - 0s - loss: 2.0926 - mean_squared_error: 2.0926 - mean_absolute_error: 0.7857 - val_loss: 11.7222 - val_mean_squared_error: 11.7222 - val_mean_absolute_error: 2.7895 - 476ms/epoch - 4ms/step
# Epoch 201/250
# 109/109 - 0s - loss: 2.0096 - mean_squared_error: 2.0096 - mean_absolute_error: 0.7564 - 376ms/epoch - 3ms/step
# Epoch 202/250
# 109/109 - 0s - loss: 2.0603 - mean_squared_error: 2.0603 - mean_absolute_error: 0.7786 - 389ms/epoch - 4ms/step
# Epoch 203/250
# 109/109 - 0s - loss: 2.0421 - mean_squared_error: 2.0421 - mean_absolute_error: 0.7914 - 364ms/epoch - 3ms/step
# Epoch 204/250
# 109/109 - 0s - loss: 2.0655 - mean_squared_error: 2.0655 - mean_absolute_error: 0.7860 - 375ms/epoch - 3ms/step
# Epoch 205/250
# 109/109 - 0s - loss: 1.9470 - mean_squared_error: 1.9470 - mean_absolute_error: 0.7217 - 370ms/epoch - 3ms/step
# Epoch 206/250
# 109/109 - 0s - loss: 1.9631 - mean_squared_error: 1.9631 - mean_absolute_error: 0.7213 - 394ms/epoch - 4ms/step
# Epoch 207/250
# 109/109 - 0s - loss: 1.9471 - mean_squared_error: 1.9471 - mean_absolute_error: 0.7356 - 372ms/epoch - 3ms/step
# Epoch 208/250
# 109/109 - 0s - loss: 1.9043 - mean_squared_error: 1.9043 - mean_absolute_error: 0.7042 - 380ms/epoch - 3ms/step
# Epoch 209/250
# 109/109 - 0s - loss: 1.9412 - mean_squared_error: 1.9412 - mean_absolute_error: 0.7065 - 381ms/epoch - 3ms/step
# Epoch 210/250
# 109/109 - 0s - loss: 1.8816 - mean_squared_error: 1.8816 - mean_absolute_error: 0.7008 - 359ms/epoch - 3ms/step
# Epoch 211/250
# 109/109 - 0s - loss: 1.9566 - mean_squared_error: 1.9566 - mean_absolute_error: 0.7406 - 361ms/epoch - 3ms/step
# Epoch 212/250
# 109/109 - 0s - loss: 1.9107 - mean_squared_error: 1.9107 - mean_absolute_error: 0.6997 - 354ms/epoch - 3ms/step
# Epoch 213/250
# 109/109 - 0s - loss: 1.8892 - mean_squared_error: 1.8892 - mean_absolute_error: 0.6932 - 357ms/epoch - 3ms/step
# Epoch 214/250
# 109/109 - 0s - loss: 1.9109 - mean_squared_error: 1.9109 - mean_absolute_error: 0.7064 - 362ms/epoch - 3ms/step
# Epoch 215/250
# 109/109 - 0s - loss: 1.9234 - mean_squared_error: 1.9234 - mean_absolute_error: 0.7320 - 355ms/epoch - 3ms/step
# Epoch 216/250
# 109/109 - 0s - loss: 1.9367 - mean_squared_error: 1.9367 - mean_absolute_error: 0.7453 - 370ms/epoch - 3ms/step
# Epoch 217/250
# 109/109 - 0s - loss: 1.9014 - mean_squared_error: 1.9014 - mean_absolute_error: 0.7121 - 361ms/epoch - 3ms/step
# Epoch 218/250
# 109/109 - 0s - loss: 1.9057 - mean_squared_error: 1.9057 - mean_absolute_error: 0.7065 - 355ms/epoch - 3ms/step
# Epoch 219/250
# 109/109 - 0s - loss: 1.8764 - mean_squared_error: 1.8764 - mean_absolute_error: 0.6942 - 363ms/epoch - 3ms/step
# Epoch 220/250
# 109/109 - 0s - loss: 1.9032 - mean_squared_error: 1.9032 - mean_absolute_error: 0.7247 - 360ms/epoch - 3ms/step
# Epoch 221/250
# 109/109 - 0s - loss: 1.9414 - mean_squared_error: 1.9414 - mean_absolute_error: 0.7396 - 377ms/epoch - 3ms/step
# Epoch 222/250
# 109/109 - 0s - loss: 1.9096 - mean_squared_error: 1.9096 - mean_absolute_error: 0.7095 - 360ms/epoch - 3ms/step
# Epoch 223/250
# 109/109 - 0s - loss: 1.8695 - mean_squared_error: 1.8695 - mean_absolute_error: 0.6960 - 356ms/epoch - 3ms/step
# Epoch 224/250
# 109/109 - 0s - loss: 1.8860 - mean_squared_error: 1.8860 - mean_absolute_error: 0.7061 - 371ms/epoch - 3ms/step
# Epoch 225/250
# 109/109 - 0s - loss: 1.9282 - mean_squared_error: 1.9282 - mean_absolute_error: 0.7364 - 395ms/epoch - 4ms/step
# Epoch 226/250
# 109/109 - 0s - loss: 1.8998 - mean_squared_error: 1.8998 - mean_absolute_error: 0.7254 - 351ms/epoch - 3ms/step
# Epoch 227/250
# 109/109 - 0s - loss: 1.9390 - mean_squared_error: 1.9390 - mean_absolute_error: 0.7352 - 351ms/epoch - 3ms/step
# Epoch 228/250
# 109/109 - 0s - loss: 1.8729 - mean_squared_error: 1.8729 - mean_absolute_error: 0.7008 - 416ms/epoch - 4ms/step
# Epoch 229/250
# 109/109 - 0s - loss: 1.8767 - mean_squared_error: 1.8767 - mean_absolute_error: 0.6871 - 363ms/epoch - 3ms/step
# Epoch 230/250
# 109/109 - 0s - loss: 1.9419 - mean_squared_error: 1.9419 - mean_absolute_error: 0.7314 - 357ms/epoch - 3ms/step
# Epoch 231/250
# 109/109 - 0s - loss: 1.8736 - mean_squared_error: 1.8736 - mean_absolute_error: 0.7067 - 356ms/epoch - 3ms/step
# Epoch 232/250
# 109/109 - 0s - loss: 1.8621 - mean_squared_error: 1.8621 - mean_absolute_error: 0.6914 - 354ms/epoch - 3ms/step
# Epoch 233/250
# 109/109 - 0s - loss: 1.8496 - mean_squared_error: 1.8496 - mean_absolute_error: 0.7047 - 359ms/epoch - 3ms/step
# Epoch 234/250
# 109/109 - 0s - loss: 1.8421 - mean_squared_error: 1.8421 - mean_absolute_error: 0.6842 - 377ms/epoch - 3ms/step
# Epoch 235/250
# 109/109 - 0s - loss: 1.8471 - mean_squared_error: 1.8471 - mean_absolute_error: 0.7013 - 356ms/epoch - 3ms/step
# Epoch 236/250
# 109/109 - 0s - loss: 1.9306 - mean_squared_error: 1.9306 - mean_absolute_error: 0.7442 - 350ms/epoch - 3ms/step
# Epoch 237/250
# 109/109 - 0s - loss: 1.8493 - mean_squared_error: 1.8493 - mean_absolute_error: 0.7108 - 361ms/epoch - 3ms/step
# Epoch 238/250
# 109/109 - 0s - loss: 1.8343 - mean_squared_error: 1.8343 - mean_absolute_error: 0.6842 - 359ms/epoch - 3ms/step
# Epoch 239/250
# 109/109 - 0s - loss: 1.8642 - mean_squared_error: 1.8642 - mean_absolute_error: 0.7050 - 354ms/epoch - 3ms/step
# Epoch 240/250
# 109/109 - 0s - loss: 1.8585 - mean_squared_error: 1.8585 - mean_absolute_error: 0.7099 - 369ms/epoch - 3ms/step
# Epoch 241/250
# 109/109 - 0s - loss: 1.8671 - mean_squared_error: 1.8671 - mean_absolute_error: 0.7053 - 366ms/epoch - 3ms/step
# Epoch 242/250
# 109/109 - 0s - loss: 1.8626 - mean_squared_error: 1.8626 - mean_absolute_error: 0.7029 - 369ms/epoch - 3ms/step
# Epoch 243/250
# 109/109 - 0s - loss: 1.8511 - mean_squared_error: 1.8511 - mean_absolute_error: 0.6897 - 351ms/epoch - 3ms/step
# Epoch 244/250
# 109/109 - 0s - loss: 1.7937 - mean_squared_error: 1.7937 - mean_absolute_error: 0.6732 - 356ms/epoch - 3ms/step
# Epoch 245/250
# 109/109 - 0s - loss: 1.8121 - mean_squared_error: 1.8121 - mean_absolute_error: 0.6819 - 356ms/epoch - 3ms/step
# Epoch 246/250
# 109/109 - 0s - loss: 1.8377 - mean_squared_error: 1.8377 - mean_absolute_error: 0.6776 - 362ms/epoch - 3ms/step
# Epoch 247/250
# 109/109 - 0s - loss: 1.7864 - mean_squared_error: 1.7864 - mean_absolute_error: 0.6658 - 365ms/epoch - 3ms/step
# Epoch 248/250
# 109/109 - 0s - loss: 1.7789 - mean_squared_error: 1.7789 - mean_absolute_error: 0.6738 - 394ms/epoch - 4ms/step
# Epoch 249/250
# 109/109 - 0s - loss: 1.8298 - mean_squared_error: 1.8298 - mean_absolute_error: 0.6951 - 423ms/epoch - 4ms/step
# Epoch 250/250
# 109/109 - 0s - loss: 1.8670 - mean_squared_error: 1.8670 - mean_absolute_error: 0.7131 - 367ms/epoch - 3ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model.get_weights()[0]
trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model.evaluate(X_test, Y_test)
print("")
print('-------------------- Score --------------------')
# Out:
# -------------------- Model Summary --------------------
# Model: "CNN-LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 128)           256
#
#  max_pooling1d (MaxPooling1D  (None, 10, 128)          0
#  )
#
#  lstm (LSTM)                 (None, 10, 64)            49408
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            65
#  ed)
#
# =================================================================
# Total params: 49,729
# Trainable params: 49,729
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 1.8670488595962524
# Final mean_squared_error : 1.8670496940612793
# Final mean_absolute_error : 0.7131273746490479
# Final val_loss : 11.722230911254883
# Final val_mean_squared_error : 11.722230911254883
# Final val_mean_absolute_error : 2.7895123958587646
#
# -------------------- Evaluation on Test Data --------------------
# 3/3 [==============================] - 0s 6ms/step - loss: 14.3884 - mean_squared_error: 14.3884 - mean_absolute_error: 2.9930
#
# -------------------- Score --------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\DSFellowship\CNNLSTM0809.ipynb Cell 20 in <cell line: 25>()
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/CNNLSTM0809.ipynb#X25sZmlsZQ%3D%3D?line=22'>23</a> print("")
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/CNNLSTM0809.ipynb#X25sZmlsZQ%3D%3D?line=23'>24</a> print('-------------------- Score --------------------')
# ---> <a href='vscode-notebook-cell:/e%3A/DSFellowship/CNNLSTM0809.ipynb#X25sZmlsZQ%3D%3D?line=24'>25</a> history.score(X_test, Y_test)
#
# AttributeError: 'History' object has no attribute 'score'
