# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# c:\Python\Python310\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
df=df.iloc[200000:205000]
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 35.0489          0.0    -15.8150    -3.78100         NaN
#           35.0609          0.0    -14.8850    -3.91760         NaN
#           35.0629          0.0    -14.5760    -3.74700         NaN
#           35.0649          0.0    -14.7640    -3.88940         NaN
#           35.0669          0.0    -14.4410    -3.83180         NaN
# ...                        ...         ...         ...         ...
# -120.4027 36.7274          0.0     -7.2276     0.73694      2.6327
#           36.7294          0.0     -7.3210     0.70109      2.4708
#           36.7314          0.0     -7.2388     0.46256      2.4291
#           36.7334          0.0     -7.2526     0.31420      2.0908
#           36.7394          0.0     -7.1203    -0.03439      2.3198
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 35.0489     -3.81260     -3.4671    -7.75040    -3.56890
#           35.0609     -3.91700     -3.2592    -7.92540    -3.72760
#           35.0629     -3.68630     -2.8954    -7.46720    -3.42460
#           35.0649     -3.80730     -3.1875    -7.69430    -3.64120
#           35.0669     -3.79350     -3.2384    -7.74860    -3.69970
# ...                        ...         ...         ...         ...
# -120.4027 36.7274     -0.37212      4.1269    -0.77547     1.42630
#           36.7294     -0.53777      3.9807    -0.90438     1.26980
#           36.7314     -0.72740      3.7277    -1.12300     0.91064
#           36.7334     -1.04390      3.4792    -1.13890     0.93199
#           36.7394     -0.72105      3.6205    -1.04990     0.92451
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 35.0489      -4.4897    -1.66720  ...    -10.3170     -7.5373
#           35.0609      -4.8079    -2.08030  ...    -11.7620     -8.9301
#           35.0629      -4.4473    -1.83730  ...    -13.1510    -10.2660
#           35.0649      -4.7031    -2.02100  ...    -13.0580    -10.2560
#           35.0669      -4.7355    -1.97580  ...    -13.5610    -10.7640
# ...                        ...         ...  ...         ...         ...
# -120.4027 36.7274       3.9578    -0.83484  ...     -4.7423     -1.7626
#           36.7294       3.9292    -0.64295  ...     -4.2087     -1.2368
#           36.7314       3.6537    -0.98271  ...     -4.7961     -1.8559
#           36.7334       3.3421    -1.11060  ...     -5.8926     -2.9637
#           36.7394       3.2634    -1.40170  ...     -5.4141     -2.5313
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 35.0489      -8.7209    -11.2120    -10.7480    -13.2020
#           35.0609     -10.2470    -12.6600    -12.4420    -14.9950
#           35.0629     -11.6180    -14.0450    -13.8780    -16.5090
#           35.0649     -11.5870    -14.0190    -13.8640    -16.4920
#           35.0669     -12.1090    -14.5200    -14.3170    -16.9960
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -2.7142     -3.0876     -6.2273     -5.2793
#           36.7294      -2.1775     -2.5592     -5.7036     -4.6893
#           36.7314      -2.7951     -3.1822     -6.3403     -5.3780
#           36.7334      -3.8852     -4.2657     -7.4344     -6.3047
#           36.7394      -3.4532     -3.8240     -6.9644     -6.0637
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 35.0489      -9.2688     -6.4277     -7.5077    -7.91640
#           35.0609     -10.4110     -7.9618     -8.9148    -9.43790
#           35.0629     -11.8270     -9.3040    -10.4320   -10.78100
#           35.0649     -11.8730     -9.2702    -10.3670   -10.75000
#           35.0669     -12.2140     -9.7466    -10.6810   -11.29000
# ...                        ...         ...         ...         ...
# -120.4027 36.7274      -4.3728     -2.3947     -2.9965    -1.00440
#           36.7294      -3.7768     -1.8226     -2.4654    -0.46636
#           36.7314      -4.5069     -2.6101     -3.2475    -1.26730
#           36.7334      -5.4811     -3.6036     -4.2325    -2.30970
#           36.7394      -5.2230     -3.3785     -4.0178    -2.04980
#
# [5000 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    for row in range(0,len(datain.index),1750): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model = Sequential()
#model.add(Masking(mask_value=-100, input_shape=(timestep, 1)))
model.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) 

model.add(Conv1D(128,1,activation='relu',padding='same'))

model.add(MaxPooling1D(1,padding='same'))
# model.add(Conv1D(16,1,activation='tanh',padding='same'))
# model.add(MaxPooling1D(1,padding='same'))
#model.add(Dense(3, activation='softmax')) 
#model.add(LSTM(units=64, activation='relu',stateful=False, return_sequences=True))
model.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))
#model.add(TimeDistributed(Dense(100)))
#model.add(Dense(3, activation='softmax')) screws it
#model.add(TimeDistributed(Dense(1)))172
model.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
model.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %% [markdown]
# ##### Train model

# %%
history = model.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 109/109 - 2s - loss: 13.5597 - mean_squared_error: 13.5597 - mean_absolute_error: 2.8633 - 2s/epoch - 15ms/step
# Epoch 2/250
# 109/109 - 0s - loss: 8.8356 - mean_squared_error: 8.8356 - mean_absolute_error: 2.2998 - 366ms/epoch - 3ms/step
# Epoch 3/250
# 109/109 - 0s - loss: 8.2354 - mean_squared_error: 8.2354 - mean_absolute_error: 2.2316 - 368ms/epoch - 3ms/step
# Epoch 4/250
# 109/109 - 0s - loss: 7.7558 - mean_squared_error: 7.7558 - mean_absolute_error: 2.1540 - 350ms/epoch - 3ms/step
# Epoch 5/250
# 109/109 - 0s - loss: 7.6603 - mean_squared_error: 7.6603 - mean_absolute_error: 2.1373 - 359ms/epoch - 3ms/step
# Epoch 6/250
# 109/109 - 0s - loss: 7.5068 - mean_squared_error: 7.5068 - mean_absolute_error: 2.1179 - 403ms/epoch - 4ms/step
# Epoch 7/250
# 109/109 - 0s - loss: 7.2805 - mean_squared_error: 7.2805 - mean_absolute_error: 2.0828 - 351ms/epoch - 3ms/step
# Epoch 8/250
# 109/109 - 0s - loss: 7.2041 - mean_squared_error: 7.2041 - mean_absolute_error: 2.0701 - 344ms/epoch - 3ms/step
# Epoch 9/250
# 109/109 - 0s - loss: 6.9452 - mean_squared_error: 6.9452 - mean_absolute_error: 2.0327 - 346ms/epoch - 3ms/step
# Epoch 10/250
# 109/109 - 0s - loss: 6.8079 - mean_squared_error: 6.8079 - mean_absolute_error: 2.0212 - 342ms/epoch - 3ms/step
# Epoch 11/250
# 109/109 - 0s - loss: 6.8067 - mean_squared_error: 6.8067 - mean_absolute_error: 2.0198 - 347ms/epoch - 3ms/step
# Epoch 12/250
# 109/109 - 0s - loss: 6.5807 - mean_squared_error: 6.5807 - mean_absolute_error: 1.9696 - 345ms/epoch - 3ms/step
# Epoch 13/250
# 109/109 - 0s - loss: 6.5072 - mean_squared_error: 6.5072 - mean_absolute_error: 1.9679 - 344ms/epoch - 3ms/step
# Epoch 14/250
# 109/109 - 0s - loss: 6.3614 - mean_squared_error: 6.3614 - mean_absolute_error: 1.9327 - 345ms/epoch - 3ms/step
# Epoch 15/250
# 109/109 - 0s - loss: 6.2432 - mean_squared_error: 6.2432 - mean_absolute_error: 1.9172 - 341ms/epoch - 3ms/step
# Epoch 16/250
# 109/109 - 0s - loss: 6.0893 - mean_squared_error: 6.0894 - mean_absolute_error: 1.8992 - 332ms/epoch - 3ms/step
# Epoch 17/250
# 109/109 - 0s - loss: 6.1419 - mean_squared_error: 6.1419 - mean_absolute_error: 1.8907 - 344ms/epoch - 3ms/step
# Epoch 18/250
# 109/109 - 0s - loss: 5.9550 - mean_squared_error: 5.9550 - mean_absolute_error: 1.8696 - 351ms/epoch - 3ms/step
# Epoch 19/250
# 109/109 - 0s - loss: 5.7545 - mean_squared_error: 5.7545 - mean_absolute_error: 1.8230 - 360ms/epoch - 3ms/step
# Epoch 20/250
# 109/109 - 0s - loss: 5.7138 - mean_squared_error: 5.7138 - mean_absolute_error: 1.8100 - 345ms/epoch - 3ms/step
# Epoch 21/250
# 109/109 - 0s - loss: 5.7725 - mean_squared_error: 5.7725 - mean_absolute_error: 1.8281 - 338ms/epoch - 3ms/step
# Epoch 22/250
# 109/109 - 0s - loss: 5.4926 - mean_squared_error: 5.4926 - mean_absolute_error: 1.7686 - 347ms/epoch - 3ms/step
# Epoch 23/250
# 109/109 - 0s - loss: 5.2805 - mean_squared_error: 5.2805 - mean_absolute_error: 1.7299 - 345ms/epoch - 3ms/step
# Epoch 24/250
# 109/109 - 0s - loss: 5.2107 - mean_squared_error: 5.2107 - mean_absolute_error: 1.7011 - 350ms/epoch - 3ms/step
# Epoch 25/250
# 109/109 - 0s - loss: 5.0907 - mean_squared_error: 5.0907 - mean_absolute_error: 1.6743 - 366ms/epoch - 3ms/step
# Epoch 26/250
# 109/109 - 0s - loss: 5.1146 - mean_squared_error: 5.1146 - mean_absolute_error: 1.6937 - 344ms/epoch - 3ms/step
# Epoch 27/250
# 109/109 - 0s - loss: 5.3592 - mean_squared_error: 5.3592 - mean_absolute_error: 1.7201 - 342ms/epoch - 3ms/step
# Epoch 28/250
# 109/109 - 0s - loss: 4.9809 - mean_squared_error: 4.9809 - mean_absolute_error: 1.6552 - 346ms/epoch - 3ms/step
# Epoch 29/250
# 109/109 - 0s - loss: 4.8409 - mean_squared_error: 4.8409 - mean_absolute_error: 1.6180 - 346ms/epoch - 3ms/step
# Epoch 30/250
# 109/109 - 0s - loss: 4.7444 - mean_squared_error: 4.7444 - mean_absolute_error: 1.5936 - 352ms/epoch - 3ms/step
# Epoch 31/250
# 109/109 - 0s - loss: 4.7408 - mean_squared_error: 4.7408 - mean_absolute_error: 1.5918 - 362ms/epoch - 3ms/step
# Epoch 32/250
# 109/109 - 0s - loss: 4.7086 - mean_squared_error: 4.7086 - mean_absolute_error: 1.5865 - 354ms/epoch - 3ms/step
# Epoch 33/250
# 109/109 - 0s - loss: 4.6264 - mean_squared_error: 4.6264 - mean_absolute_error: 1.5745 - 365ms/epoch - 3ms/step
# Epoch 34/250
# 109/109 - 0s - loss: 4.6056 - mean_squared_error: 4.6056 - mean_absolute_error: 1.5518 - 348ms/epoch - 3ms/step
# Epoch 35/250
# 109/109 - 0s - loss: 4.4288 - mean_squared_error: 4.4288 - mean_absolute_error: 1.5252 - 382ms/epoch - 4ms/step
# Epoch 36/250
# 109/109 - 0s - loss: 4.4857 - mean_squared_error: 4.4857 - mean_absolute_error: 1.5362 - 356ms/epoch - 3ms/step
# Epoch 37/250
# 109/109 - 0s - loss: 4.4398 - mean_squared_error: 4.4398 - mean_absolute_error: 1.5361 - 343ms/epoch - 3ms/step
# Epoch 38/250
# 109/109 - 0s - loss: 4.5076 - mean_squared_error: 4.5076 - mean_absolute_error: 1.5296 - 334ms/epoch - 3ms/step
# Epoch 39/250
# 109/109 - 0s - loss: 4.2372 - mean_squared_error: 4.2372 - mean_absolute_error: 1.4949 - 345ms/epoch - 3ms/step
# Epoch 40/250
# 109/109 - 0s - loss: 4.1596 - mean_squared_error: 4.1596 - mean_absolute_error: 1.4699 - 352ms/epoch - 3ms/step
# Epoch 41/250
# 109/109 - 0s - loss: 4.2418 - mean_squared_error: 4.2417 - mean_absolute_error: 1.4898 - 341ms/epoch - 3ms/step
# Epoch 42/250
# 109/109 - 0s - loss: 3.9941 - mean_squared_error: 3.9941 - mean_absolute_error: 1.4380 - 341ms/epoch - 3ms/step
# Epoch 43/250
# 109/109 - 0s - loss: 4.1682 - mean_squared_error: 4.1682 - mean_absolute_error: 1.4653 - 338ms/epoch - 3ms/step
# Epoch 44/250
# 109/109 - 0s - loss: 3.9612 - mean_squared_error: 3.9612 - mean_absolute_error: 1.4439 - 339ms/epoch - 3ms/step
# Epoch 45/250
# 109/109 - 0s - loss: 3.9363 - mean_squared_error: 3.9363 - mean_absolute_error: 1.4135 - 349ms/epoch - 3ms/step
# Epoch 46/250
# 109/109 - 0s - loss: 3.8215 - mean_squared_error: 3.8215 - mean_absolute_error: 1.3868 - 338ms/epoch - 3ms/step
# Epoch 47/250
# 109/109 - 0s - loss: 3.7600 - mean_squared_error: 3.7600 - mean_absolute_error: 1.3706 - 346ms/epoch - 3ms/step
# Epoch 48/250
# 109/109 - 0s - loss: 3.6831 - mean_squared_error: 3.6831 - mean_absolute_error: 1.3539 - 369ms/epoch - 3ms/step
# Epoch 49/250
# 109/109 - 0s - loss: 3.6217 - mean_squared_error: 3.6217 - mean_absolute_error: 1.3397 - 346ms/epoch - 3ms/step
# Epoch 50/250
# 109/109 - 0s - loss: 3.8341 - mean_squared_error: 3.8341 - mean_absolute_error: 1.3752 - 343ms/epoch - 3ms/step
# Epoch 51/250
# 109/109 - 0s - loss: 3.7812 - mean_squared_error: 3.7812 - mean_absolute_error: 1.3870 - 357ms/epoch - 3ms/step
# Epoch 52/250
# 109/109 - 0s - loss: 3.5641 - mean_squared_error: 3.5641 - mean_absolute_error: 1.3376 - 372ms/epoch - 3ms/step
# Epoch 53/250
# 109/109 - 0s - loss: 3.7732 - mean_squared_error: 3.7732 - mean_absolute_error: 1.3669 - 355ms/epoch - 3ms/step
# Epoch 54/250
# 109/109 - 0s - loss: 3.5376 - mean_squared_error: 3.5376 - mean_absolute_error: 1.3224 - 357ms/epoch - 3ms/step
# Epoch 55/250
# 109/109 - 0s - loss: 3.4374 - mean_squared_error: 3.4374 - mean_absolute_error: 1.3072 - 353ms/epoch - 3ms/step
# Epoch 56/250
# 109/109 - 0s - loss: 3.4190 - mean_squared_error: 3.4190 - mean_absolute_error: 1.2924 - 349ms/epoch - 3ms/step
# Epoch 57/250
# 109/109 - 0s - loss: 3.4616 - mean_squared_error: 3.4616 - mean_absolute_error: 1.2940 - 375ms/epoch - 3ms/step
# Epoch 58/250
# 109/109 - 0s - loss: 3.4160 - mean_squared_error: 3.4160 - mean_absolute_error: 1.2986 - 359ms/epoch - 3ms/step
# Epoch 59/250
# 109/109 - 0s - loss: 3.2836 - mean_squared_error: 3.2836 - mean_absolute_error: 1.2543 - 369ms/epoch - 3ms/step
# Epoch 60/250
# 109/109 - 0s - loss: 3.5070 - mean_squared_error: 3.5070 - mean_absolute_error: 1.2975 - 348ms/epoch - 3ms/step
# Epoch 61/250
# 109/109 - 0s - loss: 3.1183 - mean_squared_error: 3.1183 - mean_absolute_error: 1.1995 - 352ms/epoch - 3ms/step
# Epoch 62/250
# 109/109 - 0s - loss: 3.3351 - mean_squared_error: 3.3351 - mean_absolute_error: 1.2309 - 368ms/epoch - 3ms/step
# Epoch 63/250
# 109/109 - 0s - loss: 3.5479 - mean_squared_error: 3.5479 - mean_absolute_error: 1.3038 - 385ms/epoch - 4ms/step
# Epoch 64/250
# 109/109 - 0s - loss: 3.1591 - mean_squared_error: 3.1591 - mean_absolute_error: 1.2252 - 404ms/epoch - 4ms/step
# Epoch 65/250
# 109/109 - 0s - loss: 3.1078 - mean_squared_error: 3.1078 - mean_absolute_error: 1.2017 - 336ms/epoch - 3ms/step
# Epoch 66/250
# 109/109 - 0s - loss: 3.0715 - mean_squared_error: 3.0715 - mean_absolute_error: 1.1903 - 333ms/epoch - 3ms/step
# Epoch 67/250
# 109/109 - 0s - loss: 3.0395 - mean_squared_error: 3.0395 - mean_absolute_error: 1.1859 - 352ms/epoch - 3ms/step
# Epoch 68/250
# 109/109 - 0s - loss: 3.1019 - mean_squared_error: 3.1019 - mean_absolute_error: 1.2078 - 337ms/epoch - 3ms/step
# Epoch 69/250
# 109/109 - 0s - loss: 2.9097 - mean_squared_error: 2.9097 - mean_absolute_error: 1.1542 - 329ms/epoch - 3ms/step
# Epoch 70/250
# 109/109 - 0s - loss: 2.8679 - mean_squared_error: 2.8679 - mean_absolute_error: 1.1358 - 345ms/epoch - 3ms/step
# Epoch 71/250
# 109/109 - 0s - loss: 3.1638 - mean_squared_error: 3.1638 - mean_absolute_error: 1.2116 - 345ms/epoch - 3ms/step
# Epoch 72/250
# 109/109 - 0s - loss: 2.9141 - mean_squared_error: 2.9141 - mean_absolute_error: 1.1566 - 353ms/epoch - 3ms/step
# Epoch 73/250
# 109/109 - 0s - loss: 3.3920 - mean_squared_error: 3.3920 - mean_absolute_error: 1.2821 - 346ms/epoch - 3ms/step
# Epoch 74/250
# 109/109 - 0s - loss: 2.8179 - mean_squared_error: 2.8179 - mean_absolute_error: 1.1124 - 336ms/epoch - 3ms/step
# Epoch 75/250
# 109/109 - 0s - loss: 2.8147 - mean_squared_error: 2.8147 - mean_absolute_error: 1.1027 - 339ms/epoch - 3ms/step
# Epoch 76/250
# 109/109 - 0s - loss: 2.9255 - mean_squared_error: 2.9255 - mean_absolute_error: 1.1418 - 357ms/epoch - 3ms/step
# Epoch 77/250
# 109/109 - 0s - loss: 2.8478 - mean_squared_error: 2.8478 - mean_absolute_error: 1.1371 - 377ms/epoch - 3ms/step
# Epoch 78/250
# 109/109 - 0s - loss: 2.7628 - mean_squared_error: 2.7628 - mean_absolute_error: 1.1145 - 377ms/epoch - 3ms/step
# Epoch 79/250
# 109/109 - 0s - loss: 2.8367 - mean_squared_error: 2.8367 - mean_absolute_error: 1.1215 - 357ms/epoch - 3ms/step
# Epoch 80/250
# 109/109 - 0s - loss: 2.7486 - mean_squared_error: 2.7486 - mean_absolute_error: 1.0940 - 372ms/epoch - 3ms/step
# Epoch 81/250
# 109/109 - 0s - loss: 2.6805 - mean_squared_error: 2.6805 - mean_absolute_error: 1.0721 - 356ms/epoch - 3ms/step
# Epoch 82/250
# 109/109 - 0s - loss: 2.6718 - mean_squared_error: 2.6718 - mean_absolute_error: 1.0650 - 346ms/epoch - 3ms/step
# Epoch 83/250
# 109/109 - 0s - loss: 2.6294 - mean_squared_error: 2.6294 - mean_absolute_error: 1.0650 - 355ms/epoch - 3ms/step
# Epoch 84/250
# 109/109 - 0s - loss: 2.7606 - mean_squared_error: 2.7606 - mean_absolute_error: 1.0927 - 352ms/epoch - 3ms/step
# Epoch 85/250
# 109/109 - 0s - loss: 2.6017 - mean_squared_error: 2.6017 - mean_absolute_error: 1.0550 - 345ms/epoch - 3ms/step
# Epoch 86/250
# 109/109 - 0s - loss: 2.6004 - mean_squared_error: 2.6004 - mean_absolute_error: 1.0490 - 390ms/epoch - 4ms/step
# Epoch 87/250
# 109/109 - 0s - loss: 2.5538 - mean_squared_error: 2.5538 - mean_absolute_error: 1.0314 - 380ms/epoch - 3ms/step
# Epoch 88/250
# 109/109 - 0s - loss: 2.5392 - mean_squared_error: 2.5392 - mean_absolute_error: 1.0416 - 401ms/epoch - 4ms/step
# Epoch 89/250
# 109/109 - 0s - loss: 2.6959 - mean_squared_error: 2.6959 - mean_absolute_error: 1.0894 - 409ms/epoch - 4ms/step
# Epoch 90/250
# 109/109 - 0s - loss: 2.5660 - mean_squared_error: 2.5660 - mean_absolute_error: 1.0387 - 440ms/epoch - 4ms/step
# Epoch 91/250
# 109/109 - 0s - loss: 2.5687 - mean_squared_error: 2.5687 - mean_absolute_error: 1.0387 - 382ms/epoch - 4ms/step
# Epoch 92/250
# 109/109 - 0s - loss: 2.6181 - mean_squared_error: 2.6181 - mean_absolute_error: 1.0614 - 475ms/epoch - 4ms/step
# Epoch 93/250
# 109/109 - 0s - loss: 2.5866 - mean_squared_error: 2.5866 - mean_absolute_error: 1.0427 - 451ms/epoch - 4ms/step
# Epoch 94/250
# 109/109 - 0s - loss: 2.4132 - mean_squared_error: 2.4132 - mean_absolute_error: 0.9755 - 468ms/epoch - 4ms/step
# Epoch 95/250
# 109/109 - 0s - loss: 2.4224 - mean_squared_error: 2.4224 - mean_absolute_error: 0.9806 - 392ms/epoch - 4ms/step
# Epoch 96/250
# 109/109 - 0s - loss: 2.5150 - mean_squared_error: 2.5150 - mean_absolute_error: 1.0540 - 369ms/epoch - 3ms/step
# Epoch 97/250
# 109/109 - 0s - loss: 2.5543 - mean_squared_error: 2.5543 - mean_absolute_error: 1.0700 - 366ms/epoch - 3ms/step
# Epoch 98/250
# 109/109 - 0s - loss: 2.6399 - mean_squared_error: 2.6399 - mean_absolute_error: 1.0808 - 355ms/epoch - 3ms/step
# Epoch 99/250
# 109/109 - 0s - loss: 2.4311 - mean_squared_error: 2.4311 - mean_absolute_error: 1.0072 - 359ms/epoch - 3ms/step
# Epoch 100/250
# 109/109 - 1s - loss: 2.5412 - mean_squared_error: 2.5412 - mean_absolute_error: 1.0463 - val_loss: 8.5430 - val_mean_squared_error: 8.5430 - val_mean_absolute_error: 2.2761 - 730ms/epoch - 7ms/step
# Epoch 101/250
# 109/109 - 0s - loss: 2.4102 - mean_squared_error: 2.4102 - mean_absolute_error: 1.0131 - 348ms/epoch - 3ms/step
# Epoch 102/250
# 109/109 - 0s - loss: 2.3404 - mean_squared_error: 2.3404 - mean_absolute_error: 0.9819 - 332ms/epoch - 3ms/step
# Epoch 103/250
# 109/109 - 0s - loss: 2.4294 - mean_squared_error: 2.4294 - mean_absolute_error: 1.0099 - 333ms/epoch - 3ms/step
# Epoch 104/250
# 109/109 - 0s - loss: 2.3564 - mean_squared_error: 2.3564 - mean_absolute_error: 0.9819 - 347ms/epoch - 3ms/step
# Epoch 105/250
# 109/109 - 0s - loss: 2.3330 - mean_squared_error: 2.3330 - mean_absolute_error: 0.9916 - 345ms/epoch - 3ms/step
# Epoch 106/250
# 109/109 - 0s - loss: 2.3471 - mean_squared_error: 2.3471 - mean_absolute_error: 0.9874 - 358ms/epoch - 3ms/step
# Epoch 107/250
# 109/109 - 0s - loss: 2.3292 - mean_squared_error: 2.3292 - mean_absolute_error: 0.9512 - 378ms/epoch - 3ms/step
# Epoch 108/250
# 109/109 - 0s - loss: 2.4407 - mean_squared_error: 2.4407 - mean_absolute_error: 0.9974 - 379ms/epoch - 3ms/step
# Epoch 109/250
# 109/109 - 0s - loss: 2.3915 - mean_squared_error: 2.3915 - mean_absolute_error: 0.9925 - 373ms/epoch - 3ms/step
# Epoch 110/250
# 109/109 - 0s - loss: 2.8607 - mean_squared_error: 2.8607 - mean_absolute_error: 1.1253 - 347ms/epoch - 3ms/step
# Epoch 111/250
# 109/109 - 0s - loss: 2.3155 - mean_squared_error: 2.3155 - mean_absolute_error: 0.9867 - 368ms/epoch - 3ms/step
# Epoch 112/250
# 109/109 - 0s - loss: 2.2580 - mean_squared_error: 2.2580 - mean_absolute_error: 0.9590 - 368ms/epoch - 3ms/step
# Epoch 113/250
# 109/109 - 0s - loss: 2.2820 - mean_squared_error: 2.2820 - mean_absolute_error: 0.9618 - 362ms/epoch - 3ms/step
# Epoch 114/250
# 109/109 - 0s - loss: 3.2342 - mean_squared_error: 3.2342 - mean_absolute_error: 1.2129 - 370ms/epoch - 3ms/step
# Epoch 115/250
# 109/109 - 0s - loss: 2.3206 - mean_squared_error: 2.3206 - mean_absolute_error: 0.9939 - 337ms/epoch - 3ms/step
# Epoch 116/250
# 109/109 - 0s - loss: 2.2551 - mean_squared_error: 2.2551 - mean_absolute_error: 0.9615 - 336ms/epoch - 3ms/step
# Epoch 117/250
# 109/109 - 0s - loss: 2.1774 - mean_squared_error: 2.1774 - mean_absolute_error: 0.9266 - 359ms/epoch - 3ms/step
# Epoch 118/250
# 109/109 - 0s - loss: 2.2398 - mean_squared_error: 2.2398 - mean_absolute_error: 0.9558 - 350ms/epoch - 3ms/step
# Epoch 119/250
# 109/109 - 0s - loss: 2.2203 - mean_squared_error: 2.2203 - mean_absolute_error: 0.9327 - 345ms/epoch - 3ms/step
# Epoch 120/250
# 109/109 - 0s - loss: 2.1953 - mean_squared_error: 2.1953 - mean_absolute_error: 0.9348 - 384ms/epoch - 4ms/step
# Epoch 121/250
# 109/109 - 0s - loss: 2.2728 - mean_squared_error: 2.2728 - mean_absolute_error: 0.9605 - 373ms/epoch - 3ms/step
# Epoch 122/250
# 109/109 - 0s - loss: 2.4792 - mean_squared_error: 2.4792 - mean_absolute_error: 1.0096 - 365ms/epoch - 3ms/step
# Epoch 123/250
# 109/109 - 0s - loss: 2.2297 - mean_squared_error: 2.2297 - mean_absolute_error: 0.9486 - 350ms/epoch - 3ms/step
# Epoch 124/250
# 109/109 - 0s - loss: 2.2309 - mean_squared_error: 2.2309 - mean_absolute_error: 0.9420 - 366ms/epoch - 3ms/step
# Epoch 125/250
# 109/109 - 0s - loss: 2.1458 - mean_squared_error: 2.1458 - mean_absolute_error: 0.9123 - 345ms/epoch - 3ms/step
# Epoch 126/250
# 109/109 - 0s - loss: 2.1779 - mean_squared_error: 2.1779 - mean_absolute_error: 0.9272 - 359ms/epoch - 3ms/step
# Epoch 127/250
# 109/109 - 0s - loss: 2.0539 - mean_squared_error: 2.0539 - mean_absolute_error: 0.8810 - 371ms/epoch - 3ms/step
# Epoch 128/250
# 109/109 - 0s - loss: 2.0585 - mean_squared_error: 2.0585 - mean_absolute_error: 0.8920 - 353ms/epoch - 3ms/step
# Epoch 129/250
# 109/109 - 0s - loss: 2.0905 - mean_squared_error: 2.0905 - mean_absolute_error: 0.9007 - 362ms/epoch - 3ms/step
# Epoch 130/250
# 109/109 - 0s - loss: 2.1379 - mean_squared_error: 2.1379 - mean_absolute_error: 0.9249 - 368ms/epoch - 3ms/step
# Epoch 131/250
# 109/109 - 0s - loss: 2.1015 - mean_squared_error: 2.1015 - mean_absolute_error: 0.8989 - 364ms/epoch - 3ms/step
# Epoch 132/250
# 109/109 - 0s - loss: 2.1681 - mean_squared_error: 2.1681 - mean_absolute_error: 0.9329 - 348ms/epoch - 3ms/step
# Epoch 133/250
# 109/109 - 0s - loss: 2.2407 - mean_squared_error: 2.2407 - mean_absolute_error: 0.9341 - 351ms/epoch - 3ms/step
# Epoch 134/250
# 109/109 - 0s - loss: 2.0615 - mean_squared_error: 2.0615 - mean_absolute_error: 0.8901 - 351ms/epoch - 3ms/step
# Epoch 135/250
# 109/109 - 0s - loss: 2.6060 - mean_squared_error: 2.6060 - mean_absolute_error: 1.0559 - 331ms/epoch - 3ms/step
# Epoch 136/250
# 109/109 - 0s - loss: 2.1199 - mean_squared_error: 2.1199 - mean_absolute_error: 0.9093 - 340ms/epoch - 3ms/step
# Epoch 137/250
# 109/109 - 0s - loss: 2.0448 - mean_squared_error: 2.0448 - mean_absolute_error: 0.8847 - 337ms/epoch - 3ms/step
# Epoch 138/250
# 109/109 - 0s - loss: 2.0911 - mean_squared_error: 2.0911 - mean_absolute_error: 0.9058 - 388ms/epoch - 4ms/step
# Epoch 139/250
# 109/109 - 0s - loss: 2.0656 - mean_squared_error: 2.0656 - mean_absolute_error: 0.9082 - 365ms/epoch - 3ms/step
# Epoch 140/250
# 109/109 - 0s - loss: 2.0250 - mean_squared_error: 2.0250 - mean_absolute_error: 0.8758 - 356ms/epoch - 3ms/step
# Epoch 141/250
# 109/109 - 0s - loss: 2.0193 - mean_squared_error: 2.0193 - mean_absolute_error: 0.8763 - 414ms/epoch - 4ms/step
# Epoch 142/250
# 109/109 - 0s - loss: 2.0632 - mean_squared_error: 2.0632 - mean_absolute_error: 0.8916 - 354ms/epoch - 3ms/step
# Epoch 143/250
# 109/109 - 0s - loss: 2.2374 - mean_squared_error: 2.2374 - mean_absolute_error: 0.9487 - 387ms/epoch - 4ms/step
# Epoch 144/250
# 109/109 - 0s - loss: 2.1174 - mean_squared_error: 2.1174 - mean_absolute_error: 0.9097 - 372ms/epoch - 3ms/step
# Epoch 145/250
# 109/109 - 0s - loss: 2.0355 - mean_squared_error: 2.0355 - mean_absolute_error: 0.8761 - 396ms/epoch - 4ms/step
# Epoch 146/250
# 109/109 - 0s - loss: 2.3408 - mean_squared_error: 2.3408 - mean_absolute_error: 0.9448 - 352ms/epoch - 3ms/step
# Epoch 147/250
# 109/109 - 0s - loss: 2.2171 - mean_squared_error: 2.2171 - mean_absolute_error: 0.9707 - 388ms/epoch - 4ms/step
# Epoch 148/250
# 109/109 - 0s - loss: 2.1015 - mean_squared_error: 2.1015 - mean_absolute_error: 0.9046 - 400ms/epoch - 4ms/step
# Epoch 149/250
# 109/109 - 0s - loss: 1.9607 - mean_squared_error: 1.9607 - mean_absolute_error: 0.8560 - 350ms/epoch - 3ms/step
# Epoch 150/250
# 109/109 - 0s - loss: 1.9541 - mean_squared_error: 1.9541 - mean_absolute_error: 0.8476 - 344ms/epoch - 3ms/step
# Epoch 151/250
# 109/109 - 0s - loss: 1.9129 - mean_squared_error: 1.9129 - mean_absolute_error: 0.8380 - 384ms/epoch - 4ms/step
# Epoch 152/250
# 109/109 - 0s - loss: 1.9583 - mean_squared_error: 1.9583 - mean_absolute_error: 0.8469 - 348ms/epoch - 3ms/step
# Epoch 153/250
# 109/109 - 0s - loss: 1.9351 - mean_squared_error: 1.9351 - mean_absolute_error: 0.8382 - 351ms/epoch - 3ms/step
# Epoch 154/250
# 109/109 - 0s - loss: 1.9118 - mean_squared_error: 1.9118 - mean_absolute_error: 0.8240 - 335ms/epoch - 3ms/step
# Epoch 155/250
# 109/109 - 0s - loss: 1.9066 - mean_squared_error: 1.9066 - mean_absolute_error: 0.8344 - 351ms/epoch - 3ms/step
# Epoch 156/250
# 109/109 - 0s - loss: 1.9801 - mean_squared_error: 1.9801 - mean_absolute_error: 0.8584 - 408ms/epoch - 4ms/step
# Epoch 157/250
# 109/109 - 0s - loss: 1.9551 - mean_squared_error: 1.9551 - mean_absolute_error: 0.8669 - 374ms/epoch - 3ms/step
# Epoch 158/250
# 109/109 - 0s - loss: 2.0549 - mean_squared_error: 2.0549 - mean_absolute_error: 0.8913 - 407ms/epoch - 4ms/step
# Epoch 159/250
# 109/109 - 0s - loss: 1.9982 - mean_squared_error: 1.9982 - mean_absolute_error: 0.8877 - 401ms/epoch - 4ms/step
# Epoch 160/250
# 109/109 - 0s - loss: 1.9060 - mean_squared_error: 1.9060 - mean_absolute_error: 0.8377 - 410ms/epoch - 4ms/step
# Epoch 161/250
# 109/109 - 0s - loss: 2.1178 - mean_squared_error: 2.1178 - mean_absolute_error: 0.8892 - 426ms/epoch - 4ms/step
# Epoch 162/250
# 109/109 - 0s - loss: 2.1115 - mean_squared_error: 2.1115 - mean_absolute_error: 0.9274 - 388ms/epoch - 4ms/step
# Epoch 163/250
# 109/109 - 0s - loss: 1.9229 - mean_squared_error: 1.9229 - mean_absolute_error: 0.8507 - 385ms/epoch - 4ms/step
# Epoch 164/250
# 109/109 - 0s - loss: 1.9065 - mean_squared_error: 1.9065 - mean_absolute_error: 0.8390 - 360ms/epoch - 3ms/step
# Epoch 165/250
# 109/109 - 0s - loss: 1.8675 - mean_squared_error: 1.8675 - mean_absolute_error: 0.8211 - 352ms/epoch - 3ms/step
# Epoch 166/250
# 109/109 - 0s - loss: 1.8461 - mean_squared_error: 1.8461 - mean_absolute_error: 0.8295 - 381ms/epoch - 3ms/step
# Epoch 167/250
# 109/109 - 0s - loss: 1.9733 - mean_squared_error: 1.9733 - mean_absolute_error: 0.8671 - 471ms/epoch - 4ms/step
# Epoch 168/250
# 109/109 - 0s - loss: 1.8708 - mean_squared_error: 1.8708 - mean_absolute_error: 0.8228 - 473ms/epoch - 4ms/step
# Epoch 169/250
# 109/109 - 0s - loss: 1.8814 - mean_squared_error: 1.8814 - mean_absolute_error: 0.8277 - 453ms/epoch - 4ms/step
# Epoch 170/250
# 109/109 - 0s - loss: 1.8402 - mean_squared_error: 1.8402 - mean_absolute_error: 0.8212 - 366ms/epoch - 3ms/step
# Epoch 171/250
# 109/109 - 0s - loss: 1.8305 - mean_squared_error: 1.8305 - mean_absolute_error: 0.8121 - 391ms/epoch - 4ms/step
# Epoch 172/250
# 109/109 - 0s - loss: 2.2646 - mean_squared_error: 2.2646 - mean_absolute_error: 0.9265 - 381ms/epoch - 3ms/step
# Epoch 173/250
# 109/109 - 0s - loss: 2.2343 - mean_squared_error: 2.2343 - mean_absolute_error: 0.9858 - 377ms/epoch - 3ms/step
# Epoch 174/250
# 109/109 - 0s - loss: 1.8649 - mean_squared_error: 1.8649 - mean_absolute_error: 0.8119 - 353ms/epoch - 3ms/step
# Epoch 175/250
# 109/109 - 0s - loss: 1.8027 - mean_squared_error: 1.8027 - mean_absolute_error: 0.7882 - 351ms/epoch - 3ms/step
# Epoch 176/250
# 109/109 - 0s - loss: 1.8081 - mean_squared_error: 1.8081 - mean_absolute_error: 0.7892 - 374ms/epoch - 3ms/step
# Epoch 177/250
# 109/109 - 0s - loss: 1.7837 - mean_squared_error: 1.7837 - mean_absolute_error: 0.7820 - 411ms/epoch - 4ms/step
# Epoch 178/250
# 109/109 - 0s - loss: 2.1060 - mean_squared_error: 2.1060 - mean_absolute_error: 0.8945 - 344ms/epoch - 3ms/step
# Epoch 179/250
# 109/109 - 0s - loss: 2.0268 - mean_squared_error: 2.0268 - mean_absolute_error: 0.9084 - 407ms/epoch - 4ms/step
# Epoch 180/250
# 109/109 - 0s - loss: 1.9918 - mean_squared_error: 1.9918 - mean_absolute_error: 0.8439 - 420ms/epoch - 4ms/step
# Epoch 181/250
# 109/109 - 0s - loss: 1.8387 - mean_squared_error: 1.8387 - mean_absolute_error: 0.8231 - 438ms/epoch - 4ms/step
# Epoch 182/250
# 109/109 - 0s - loss: 1.8520 - mean_squared_error: 1.8520 - mean_absolute_error: 0.8252 - 477ms/epoch - 4ms/step
# Epoch 183/250
# 109/109 - 0s - loss: 1.8091 - mean_squared_error: 1.8091 - mean_absolute_error: 0.8142 - 382ms/epoch - 4ms/step
# Epoch 184/250
# 109/109 - 0s - loss: 1.8084 - mean_squared_error: 1.8084 - mean_absolute_error: 0.8101 - 411ms/epoch - 4ms/step
# Epoch 185/250
# 109/109 - 0s - loss: 1.9126 - mean_squared_error: 1.9126 - mean_absolute_error: 0.8381 - 406ms/epoch - 4ms/step
# Epoch 186/250
# 109/109 - 0s - loss: 1.7951 - mean_squared_error: 1.7951 - mean_absolute_error: 0.8059 - 373ms/epoch - 3ms/step
# Epoch 187/250
# 109/109 - 0s - loss: 2.0495 - mean_squared_error: 2.0495 - mean_absolute_error: 0.8969 - 383ms/epoch - 4ms/step
# Epoch 188/250
# 109/109 - 0s - loss: 1.8823 - mean_squared_error: 1.8823 - mean_absolute_error: 0.8351 - 388ms/epoch - 4ms/step
# Epoch 189/250
# 109/109 - 0s - loss: 1.7577 - mean_squared_error: 1.7577 - mean_absolute_error: 0.7738 - 371ms/epoch - 3ms/step
# Epoch 190/250
# 109/109 - 0s - loss: 1.8620 - mean_squared_error: 1.8620 - mean_absolute_error: 0.8116 - 375ms/epoch - 3ms/step
# Epoch 191/250
# 109/109 - 0s - loss: 1.7608 - mean_squared_error: 1.7608 - mean_absolute_error: 0.7822 - 370ms/epoch - 3ms/step
# Epoch 192/250
# 109/109 - 0s - loss: 1.9855 - mean_squared_error: 1.9855 - mean_absolute_error: 0.8686 - 375ms/epoch - 3ms/step
# Epoch 193/250
# 109/109 - 0s - loss: 1.7666 - mean_squared_error: 1.7666 - mean_absolute_error: 0.7795 - 416ms/epoch - 4ms/step
# Epoch 194/250
# 109/109 - 0s - loss: 1.7386 - mean_squared_error: 1.7386 - mean_absolute_error: 0.7630 - 377ms/epoch - 3ms/step
# Epoch 195/250
# 109/109 - 0s - loss: 1.7462 - mean_squared_error: 1.7462 - mean_absolute_error: 0.7818 - 409ms/epoch - 4ms/step
# Epoch 196/250
# 109/109 - 0s - loss: 1.6970 - mean_squared_error: 1.6970 - mean_absolute_error: 0.7506 - 375ms/epoch - 3ms/step
# Epoch 197/250
# 109/109 - 0s - loss: 1.7449 - mean_squared_error: 1.7449 - mean_absolute_error: 0.7776 - 397ms/epoch - 4ms/step
# Epoch 198/250
# 109/109 - 0s - loss: 1.7930 - mean_squared_error: 1.7930 - mean_absolute_error: 0.8152 - 388ms/epoch - 4ms/step
# Epoch 199/250
# 109/109 - 0s - loss: 1.7760 - mean_squared_error: 1.7760 - mean_absolute_error: 0.8058 - 387ms/epoch - 4ms/step
# Epoch 200/250
# 109/109 - 0s - loss: 1.8008 - mean_squared_error: 1.8008 - mean_absolute_error: 0.8096 - val_loss: 9.3178 - val_mean_squared_error: 9.3178 - val_mean_absolute_error: 2.3554 - 466ms/epoch - 4ms/step
# Epoch 201/250
# 109/109 - 0s - loss: 1.7440 - mean_squared_error: 1.7440 - mean_absolute_error: 0.7804 - 410ms/epoch - 4ms/step
# Epoch 202/250
# 109/109 - 0s - loss: 1.9074 - mean_squared_error: 1.9074 - mean_absolute_error: 0.8516 - 383ms/epoch - 4ms/step
# Epoch 203/250
# 109/109 - 0s - loss: 1.7380 - mean_squared_error: 1.7380 - mean_absolute_error: 0.7857 - 370ms/epoch - 3ms/step
# Epoch 204/250
# 109/109 - 0s - loss: 1.7020 - mean_squared_error: 1.7020 - mean_absolute_error: 0.7654 - 377ms/epoch - 3ms/step
# Epoch 205/250
# 109/109 - 0s - loss: 1.7563 - mean_squared_error: 1.7563 - mean_absolute_error: 0.7943 - 384ms/epoch - 4ms/step
# Epoch 206/250
# 109/109 - 0s - loss: 1.7441 - mean_squared_error: 1.7441 - mean_absolute_error: 0.7821 - 387ms/epoch - 4ms/step
# Epoch 207/250
# 109/109 - 0s - loss: 1.6642 - mean_squared_error: 1.6642 - mean_absolute_error: 0.7305 - 381ms/epoch - 3ms/step
# Epoch 208/250
# 109/109 - 0s - loss: 1.6855 - mean_squared_error: 1.6855 - mean_absolute_error: 0.7480 - 376ms/epoch - 3ms/step
# Epoch 209/250
# 109/109 - 0s - loss: 1.7053 - mean_squared_error: 1.7053 - mean_absolute_error: 0.7670 - 408ms/epoch - 4ms/step
# Epoch 210/250
# 109/109 - 0s - loss: 1.7106 - mean_squared_error: 1.7106 - mean_absolute_error: 0.7875 - 393ms/epoch - 4ms/step
# Epoch 211/250
# 109/109 - 0s - loss: 1.8117 - mean_squared_error: 1.8117 - mean_absolute_error: 0.8163 - 411ms/epoch - 4ms/step
# Epoch 212/250
# 109/109 - 0s - loss: 1.8236 - mean_squared_error: 1.8236 - mean_absolute_error: 0.8009 - 410ms/epoch - 4ms/step
# Epoch 213/250
# 109/109 - 0s - loss: 1.6554 - mean_squared_error: 1.6554 - mean_absolute_error: 0.7417 - 395ms/epoch - 4ms/step
# Epoch 214/250
# 109/109 - 0s - loss: 1.7120 - mean_squared_error: 1.7120 - mean_absolute_error: 0.7652 - 419ms/epoch - 4ms/step
# Epoch 215/250
# 109/109 - 0s - loss: 1.7366 - mean_squared_error: 1.7366 - mean_absolute_error: 0.7800 - 428ms/epoch - 4ms/step
# Epoch 216/250
# 109/109 - 0s - loss: 1.6588 - mean_squared_error: 1.6588 - mean_absolute_error: 0.7486 - 393ms/epoch - 4ms/step
# Epoch 217/250
# 109/109 - 0s - loss: 1.6579 - mean_squared_error: 1.6579 - mean_absolute_error: 0.7334 - 379ms/epoch - 3ms/step
# Epoch 218/250
# 109/109 - 0s - loss: 1.6371 - mean_squared_error: 1.6371 - mean_absolute_error: 0.7395 - 372ms/epoch - 3ms/step
# Epoch 219/250
# 109/109 - 0s - loss: 1.6374 - mean_squared_error: 1.6374 - mean_absolute_error: 0.7344 - 388ms/epoch - 4ms/step
# Epoch 220/250
# 109/109 - 0s - loss: 1.7009 - mean_squared_error: 1.7009 - mean_absolute_error: 0.7723 - 397ms/epoch - 4ms/step
# Epoch 221/250
# 109/109 - 0s - loss: 1.6741 - mean_squared_error: 1.6741 - mean_absolute_error: 0.7627 - 388ms/epoch - 4ms/step
# Epoch 222/250
# 109/109 - 0s - loss: 1.6773 - mean_squared_error: 1.6773 - mean_absolute_error: 0.7747 - 385ms/epoch - 4ms/step
# Epoch 223/250
# 109/109 - 0s - loss: 1.6248 - mean_squared_error: 1.6248 - mean_absolute_error: 0.7485 - 390ms/epoch - 4ms/step
# Epoch 224/250
# 109/109 - 0s - loss: 1.9837 - mean_squared_error: 1.9837 - mean_absolute_error: 0.8682 - 371ms/epoch - 3ms/step
# Epoch 225/250
# 109/109 - 0s - loss: 1.6856 - mean_squared_error: 1.6856 - mean_absolute_error: 0.7717 - 381ms/epoch - 3ms/step
# Epoch 226/250
# 109/109 - 0s - loss: 1.6205 - mean_squared_error: 1.6205 - mean_absolute_error: 0.7390 - 384ms/epoch - 4ms/step
# Epoch 227/250
# 109/109 - 0s - loss: 1.6184 - mean_squared_error: 1.6184 - mean_absolute_error: 0.7370 - 377ms/epoch - 3ms/step
# Epoch 228/250
# 109/109 - 0s - loss: 1.6178 - mean_squared_error: 1.6178 - mean_absolute_error: 0.7405 - 379ms/epoch - 3ms/step
# Epoch 229/250
# 109/109 - 0s - loss: 1.6915 - mean_squared_error: 1.6915 - mean_absolute_error: 0.7762 - 421ms/epoch - 4ms/step
# Epoch 230/250
# 109/109 - 0s - loss: 1.6636 - mean_squared_error: 1.6636 - mean_absolute_error: 0.7529 - 375ms/epoch - 3ms/step
# Epoch 231/250
# 109/109 - 0s - loss: 1.6098 - mean_squared_error: 1.6098 - mean_absolute_error: 0.7354 - 380ms/epoch - 3ms/step
# Epoch 232/250
# 109/109 - 0s - loss: 1.5876 - mean_squared_error: 1.5876 - mean_absolute_error: 0.7175 - 348ms/epoch - 3ms/step
# Epoch 233/250
# 109/109 - 0s - loss: 1.5943 - mean_squared_error: 1.5943 - mean_absolute_error: 0.7281 - 351ms/epoch - 3ms/step
# Epoch 234/250
# 109/109 - 0s - loss: 1.6397 - mean_squared_error: 1.6397 - mean_absolute_error: 0.7419 - 369ms/epoch - 3ms/step
# Epoch 235/250
# 109/109 - 0s - loss: 1.8063 - mean_squared_error: 1.8063 - mean_absolute_error: 0.8360 - 348ms/epoch - 3ms/step
# Epoch 236/250
# 109/109 - 0s - loss: 1.5855 - mean_squared_error: 1.5855 - mean_absolute_error: 0.7252 - 357ms/epoch - 3ms/step
# Epoch 237/250
# 109/109 - 0s - loss: 1.5518 - mean_squared_error: 1.5518 - mean_absolute_error: 0.7124 - 349ms/epoch - 3ms/step
# Epoch 238/250
# 109/109 - 0s - loss: 1.5895 - mean_squared_error: 1.5895 - mean_absolute_error: 0.7183 - 334ms/epoch - 3ms/step
# Epoch 239/250
# 109/109 - 0s - loss: 1.5595 - mean_squared_error: 1.5595 - mean_absolute_error: 0.7125 - 394ms/epoch - 4ms/step
# Epoch 240/250
# 109/109 - 0s - loss: 1.5965 - mean_squared_error: 1.5965 - mean_absolute_error: 0.7356 - 349ms/epoch - 3ms/step
# Epoch 241/250
# 109/109 - 0s - loss: 1.6088 - mean_squared_error: 1.6088 - mean_absolute_error: 0.7397 - 354ms/epoch - 3ms/step
# Epoch 242/250
# 109/109 - 0s - loss: 1.6244 - mean_squared_error: 1.6244 - mean_absolute_error: 0.7512 - 380ms/epoch - 3ms/step
# Epoch 243/250
# 109/109 - 0s - loss: 1.6063 - mean_squared_error: 1.6063 - mean_absolute_error: 0.7365 - 372ms/epoch - 3ms/step
# Epoch 244/250
# 109/109 - 0s - loss: 1.6313 - mean_squared_error: 1.6313 - mean_absolute_error: 0.7549 - 360ms/epoch - 3ms/step
# Epoch 245/250
# 109/109 - 0s - loss: 1.5765 - mean_squared_error: 1.5765 - mean_absolute_error: 0.7297 - 365ms/epoch - 3ms/step
# Epoch 246/250
# 109/109 - 0s - loss: 1.5599 - mean_squared_error: 1.5599 - mean_absolute_error: 0.7106 - 415ms/epoch - 4ms/step
# Epoch 247/250
# 109/109 - 0s - loss: 1.5680 - mean_squared_error: 1.5680 - mean_absolute_error: 0.7131 - 365ms/epoch - 3ms/step
# Epoch 248/250
# 109/109 - 0s - loss: 1.5986 - mean_squared_error: 1.5986 - mean_absolute_error: 0.7334 - 427ms/epoch - 4ms/step
# Epoch 249/250
# 109/109 - 0s - loss: 1.8177 - mean_squared_error: 1.8177 - mean_absolute_error: 0.7910 - 405ms/epoch - 4ms/step
# Epoch 250/250
# 109/109 - 0s - loss: 2.2133 - mean_squared_error: 2.2133 - mean_absolute_error: 0.9629 - 393ms/epoch - 4ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model.get_weights()[0]
trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 128)           256
#
#  max_pooling1d (MaxPooling1D  (None, 10, 128)          0
#  )
#
#  lstm (LSTM)                 (None, 10, 64)            49408
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            65
#  ed)
#
# =================================================================
# Total params: 49,729
# Trainable params: 49,729
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 2.21331524848938
# Final mean_squared_error : 2.21331524848938
# Final mean_absolute_error : 0.9629140496253967
# Final val_loss : 9.317824363708496
# Final val_mean_squared_error : 9.317825317382812
# Final val_mean_absolute_error : 2.355355739593506
#
# -------------------- Evaluation on Test Data --------------------
# 3/3 [==============================] - 0s 4ms/step - loss: 85.3591 - mean_squared_error: 85.3591 - mean_absolute_error: 8.6927
