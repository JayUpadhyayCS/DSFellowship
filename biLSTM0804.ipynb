# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D # for creating layers inside the Neural Network
from keras.optimizers import Adam
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version

# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.3
# numpy: 1.23.0
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# # Read df from file

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df.dropna(axis=0, how='all')#drop full nan rows
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9146 35.4470          0.0    -13.5180    0.747460      5.0862
#           35.4490          0.0    -13.6410    0.063185      4.4150
#           35.4510          0.0    -13.6300    0.400600      4.7172
#           35.4530          0.0    -13.5690   -0.500240      4.0645
#           35.4550          0.0    -13.5060   -1.107300      2.9022
# ...                        ...         ...         ...         ...
# -117.6414 37.6236          0.0      4.8278   -1.306500         NaN
#           37.6256          0.0      4.8698   -1.213700         NaN
#           37.6276          0.0      4.8693   -1.189300         NaN
#           37.6296          0.0      4.8277   -1.190600         NaN
#           37.6316          0.0      4.8729   -1.120000         NaN
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9146 35.4470      -1.9668     1.29470     -5.1067     0.87440
#           35.4490      -2.5803     0.74781     -5.7172     0.19724
#           35.4510      -2.3308     0.99271     -5.4875     0.39402
#           35.4530      -2.8942     0.21585     -6.1191     0.00391
#           35.4550      -4.1777    -1.13510     -7.3587    -1.35330
# ...                        ...         ...         ...         ...
# -117.6414 37.6236      -4.1515    -1.99990      9.9914    -3.10550
#           37.6256      -4.1588    -1.73720     10.4130    -2.95840
#           37.6276      -4.1632    -1.71070     10.4830    -2.93180
#           37.6296      -4.1240    -1.89490     10.1870    -3.01790
#           37.6316      -4.1457    -1.70330     10.5180    -2.92690
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9146 35.4470     -5.15400     2.55900  ...     -6.5221     -3.3514
#           35.4490     -5.74300     1.93390  ...     -7.3692     -4.3340
#           35.4510     -5.48650     2.15280  ...     -6.8486     -4.0115
#           35.4530     -5.82860     1.83380  ...     -5.6745     -3.0299
#           35.4550     -7.29700     0.46061  ...     -7.9927     -5.4295
# ...                        ...         ...  ...         ...         ...
# -117.6414 37.6236     -0.32799     6.98990  ...      8.5800     11.3410
#           37.6256     -0.33838     7.34020  ...      9.2515     11.9960
#           37.6276     -0.34454     7.39780  ...      8.8321     11.5700
#           37.6296     -0.31614     7.12450  ...     10.3320     13.0730
#           37.6316     -0.33153     7.38390  ...      9.3376     12.0530
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9146 35.4470      -4.1662     -6.3219     -11.361     -9.6235
#           35.4490      -5.1182     -7.1733     -12.311    -10.5640
#           35.4510      -4.7786     -6.7119     -11.929    -10.1480
#           35.4530      -3.7675     -5.5943     -10.838     -9.0944
#           35.4550      -6.2580     -7.9820     -13.136    -11.3610
# ...                        ...         ...         ...         ...
# -117.6414 37.6236       5.5704      7.6113      17.002      9.6014
#           37.6256       6.0621      8.2387      17.526      9.5942
#           37.6276       5.5897      7.8226      17.066      9.2927
#           37.6296       7.2137      9.3699      18.582     10.8610
#           37.6316       6.0863      8.3323      17.499      9.8190
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9146 35.4470      -4.9249     -3.5976     -5.1346     -4.4193
#           35.4490      -5.7429     -4.3201     -5.8205     -5.0144
#           35.4510      -5.1576     -3.7890     -5.1048     -4.3554
#           35.4530      -3.9021     -2.8637     -3.8639     -3.1045
#           35.4550      -6.0692     -4.9656     -6.0258     -5.1433
# ...                        ...         ...         ...         ...
# -117.6414 37.6236      16.4360      8.5234     11.9040      8.8353
#           37.6256      16.7240      8.2348     11.6300      8.3278
#           37.6276      16.6410      8.2757     11.7900      8.3947
#           37.6296      17.9170      9.8912     13.3810     10.2190
#           37.6316      16.8390      8.8137     12.2150      8.8725
#
# [1657958 rows x 110 columns]

# %% [markdown]
# # Timestep and features

# %%
timestep=10
features=1

# %% [markdown]
# # Shaping function

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    
    for row in range(0,len(datain.index),10000):
    # Convert input dataframe to array and flatten
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        arr[np.isnan(arr)] = -1000
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# # Shape data

# %%
train, test = train_test_split(df, test_size=0.2)
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)
#print("Xtrain:", X_train.shape)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model1 = Sequential()
model1.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model1.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) 
model1.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))
model1.add(TimeDistributed(Dense(units=1, activation='relu'), name='Output-Layer')) # Output Layer, Linear(x) = x

model1.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %% [markdown]
# # Train model on train data

# %%
history = model1.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=300, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                    
                   )
# Out:
# Epoch 1/300
# 528/528 - 9s - loss: 5562.3628 - mean_squared_error: 9588.9248 - mean_absolute_error: 15.2254 - 9s/epoch - 16ms/step
# Epoch 2/300
# 528/528 - 5s - loss: 5562.3516 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2290 - 5s/epoch - 9ms/step
# Epoch 3/300
# 528/528 - 5s - loss: 5562.3569 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 4/300
# 528/528 - 5s - loss: 5562.3569 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 5/300
# 528/528 - 4s - loss: 5562.3560 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 9ms/step
# Epoch 6/300
# 528/528 - 4s - loss: 5562.3589 - mean_squared_error: 9588.9189 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 7/300
# 528/528 - 4s - loss: 5562.3511 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 8/300
# 528/528 - 4s - loss: 5562.3525 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 9/300
# 528/528 - 4s - loss: 5562.3521 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 10/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9189 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 11/300
# 528/528 - 4s - loss: 5562.3560 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 12/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9229 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 13/300
# 528/528 - 4s - loss: 5562.3525 - mean_squared_error: 9588.9111 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 14/300
# 528/528 - 4s - loss: 5562.3540 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 15/300
# 528/528 - 5s - loss: 5562.3545 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 16/300
# 528/528 - 5s - loss: 5562.3545 - mean_squared_error: 9588.9180 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 17/300
# 528/528 - 4s - loss: 5562.3525 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 18/300
# 528/528 - 5s - loss: 5562.3550 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2290 - 5s/epoch - 9ms/step
# Epoch 19/300
# 528/528 - 4s - loss: 5562.3555 - mean_squared_error: 9588.9092 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 20/300
# 528/528 - 4s - loss: 5562.3530 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 21/300
# 528/528 - 5s - loss: 5562.3525 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 22/300
# 528/528 - 5s - loss: 5562.3560 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 23/300
# 528/528 - 4s - loss: 5562.3545 - mean_squared_error: 9588.9189 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 24/300
# 528/528 - 5s - loss: 5562.3555 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2290 - 5s/epoch - 9ms/step
# Epoch 25/300
# 528/528 - 4s - loss: 5562.3560 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 26/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 27/300
# 528/528 - 4s - loss: 5562.3564 - mean_squared_error: 9588.9199 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 28/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9189 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 29/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9121 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 30/300
# 528/528 - 4s - loss: 5562.3521 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 31/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 32/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 33/300
# 528/528 - 4s - loss: 5562.3525 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 34/300
# 528/528 - 4s - loss: 5562.3560 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 35/300
# 528/528 - 4s - loss: 5562.3555 - mean_squared_error: 9588.9248 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 36/300
# 528/528 - 4s - loss: 5562.3530 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 37/300
# 528/528 - 5s - loss: 5562.3574 - mean_squared_error: 9588.9111 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 38/300
# 528/528 - 4s - loss: 5562.3516 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 39/300
# 528/528 - 4s - loss: 5562.3540 - mean_squared_error: 9588.9189 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 40/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 41/300
# 528/528 - 5s - loss: 5562.3555 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 42/300
# 528/528 - 4s - loss: 5562.3545 - mean_squared_error: 9588.9092 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 43/300
# 528/528 - 4s - loss: 5562.3506 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 44/300
# 528/528 - 4s - loss: 5562.3530 - mean_squared_error: 9588.9209 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 45/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 4s/epoch - 9ms/step
# Epoch 46/300
# 528/528 - 5s - loss: 5562.3521 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 5s/epoch - 10ms/step
# Epoch 47/300
# 528/528 - 6s - loss: 5562.3560 - mean_squared_error: 9588.9092 - mean_absolute_error: 15.2290 - 6s/epoch - 11ms/step
# Epoch 48/300
# 528/528 - 5s - loss: 5562.3535 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2290 - 5s/epoch - 10ms/step
# Epoch 49/300
# 528/528 - 5s - loss: 5562.3525 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 50/300
# 528/528 - 4s - loss: 5562.3555 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 51/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 52/300
# 528/528 - 5s - loss: 5562.3530 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 5s/epoch - 10ms/step
# Epoch 53/300
# 528/528 - 5s - loss: 5562.3540 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 5s/epoch - 10ms/step
# Epoch 54/300
# 528/528 - 5s - loss: 5562.3525 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 55/300
# 528/528 - 5s - loss: 5562.3525 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2290 - 5s/epoch - 10ms/step
# Epoch 56/300
# 528/528 - 4s - loss: 5562.3525 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 57/300
# 528/528 - 4s - loss: 5562.3540 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 58/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9111 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 59/300
# 528/528 - 4s - loss: 5562.3516 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 60/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 61/300
# 528/528 - 4s - loss: 5562.3545 - mean_squared_error: 9588.9111 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 62/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 63/300
# 528/528 - 4s - loss: 5562.3560 - mean_squared_error: 9588.9102 - mean_absolute_error: 15.2290 - 4s/epoch - 7ms/step
# Epoch 64/300
# 528/528 - 4s - loss: 5562.3555 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 65/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 66/300
# 528/528 - 4s - loss: 5562.3530 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 67/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 68/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 69/300
# 528/528 - 4s - loss: 5562.3516 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 70/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 71/300
# 528/528 - 4s - loss: 5562.3545 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 72/300
# 528/528 - 4s - loss: 5562.3550 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 73/300
# 528/528 - 4s - loss: 5562.3521 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 74/300
# 528/528 - 4s - loss: 5562.3545 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2290 - 4s/epoch - 7ms/step
# Epoch 75/300
# 528/528 - 4s - loss: 5562.3540 - mean_squared_error: 9588.9189 - mean_absolute_error: 15.2290 - 4s/epoch - 7ms/step
# Epoch 76/300
# 528/528 - 4s - loss: 5562.3555 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 77/300
# 528/528 - 4s - loss: 5562.3540 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 78/300
# 528/528 - 4s - loss: 5562.3555 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2290 - 4s/epoch - 7ms/step
# Epoch 79/300
# 528/528 - 4s - loss: 5562.3569 - mean_squared_error: 9588.9111 - mean_absolute_error: 15.2289 - 4s/epoch - 8ms/step
# Epoch 80/300
# 528/528 - 4s - loss: 5562.3521 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 81/300
# 528/528 - 4s - loss: 5562.3535 - mean_squared_error: 9588.9209 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 82/300
# 528/528 - 4s - loss: 5562.3521 - mean_squared_error: 9588.9062 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 83/300
# 528/528 - 4s - loss: 5562.3530 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 4s/epoch - 7ms/step
# Epoch 84/300
# 528/528 - 4s - loss: 5562.3540 - mean_squared_error: 9588.9121 - mean_absolute_error: 15.2290 - 4s/epoch - 8ms/step
# Epoch 85/300
# 528/528 - 5s - loss: 5562.3550 - mean_squared_error: 9588.9141 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 86/300
# 528/528 - 5s - loss: 5562.3540 - mean_squared_error: 9588.9131 - mean_absolute_error: 15.2289 - 5s/epoch - 10ms/step
# Epoch 87/300
# 528/528 - 6s - loss: 5562.3530 - mean_squared_error: 9588.9111 - mean_absolute_error: 15.2289 - 6s/epoch - 11ms/step
# Epoch 88/300
# 528/528 - 5s - loss: 5562.3540 - mean_squared_error: 9588.9189 - mean_absolute_error: 15.2290 - 5s/epoch - 9ms/step
# Epoch 89/300
# 528/528 - 5s - loss: 5562.3540 - mean_squared_error: 9588.9150 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 90/300
# 528/528 - 5s - loss: 5562.3545 - mean_squared_error: 9588.9170 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 91/300
# 528/528 - 5s - loss: 5562.3535 - mean_squared_error: 9588.9111 - mean_absolute_error: 15.2290 - 5s/epoch - 9ms/step
# Epoch 92/300
# 528/528 - 5s - loss: 5562.3540 - mean_squared_error: 9588.9160 - mean_absolute_error: 15.2289 - 5s/epoch - 9ms/step
# Epoch 93/300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\DSFellowship\biLSTM0804.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> history = model1.fit(X_train, # input data
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>                     Y_train, # target data
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>                     batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>                     epochs=300, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>                     verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>                     callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>                     validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch.
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a>                     #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch.
#       <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>                     shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a>                     class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>                     sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a>                     initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a>                     steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a>                     validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a>                     validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a>                     validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a>                     max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a>                     workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=18'>19</a>                     use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False.
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a>
#      <a href='vscode-notebook-cell:/d%3A/DSFellowship/biLSTM0804.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a>                    )
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\jupad\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Step 7 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model1.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model1.evaluate(X_test, Y_test)
print("hello")
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
model2 = Sequential(name="LSTM-Model") # Model
model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=5, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = hist["mean_squared_error"]

plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
##### Step 7 - Print Performance Summary
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
model3 = Sequential(name="LSTM-Model") # Model
model3.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model3.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model3.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))

#model3.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))
#model.add(LSTM(units=50, activation='relu'), name='Hidden-LSTM-Encoder-Layer') # Encoder Layer
model3.add(TimeDistributed(Dense(units=1), name='Output-Layer')) # Output Layer, Linear(x) = x
model3.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
history = model3.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=300, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
##### Step 7 - Print Performance Summary
print("")
print('-------------------- Model Summary --------------------')
model3.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model3.evaluate(X_test, Y_test)
print("")
# Out:
# Running cells with 'Python 3.7.0 ('venvLaptop': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/DSFellowship/venvLaptop/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
