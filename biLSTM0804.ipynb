# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D # for creating layers inside the Neural Network
from keras.optimizers import Adam
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version

# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# # Read df from file

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df.dropna(axis=0, how='all')#drop full nan rows
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9146 35.4470          0.0    -13.5180    0.747460      5.0862
#           35.4490          0.0    -13.6410    0.063185      4.4150
#           35.4510          0.0    -13.6300    0.400600      4.7172
#           35.4530          0.0    -13.5690   -0.500240      4.0645
#           35.4550          0.0    -13.5060   -1.107300      2.9022
# ...                        ...         ...         ...         ...
# -117.6414 37.6236          0.0      4.8278   -1.306500         NaN
#           37.6256          0.0      4.8698   -1.213700         NaN
#           37.6276          0.0      4.8693   -1.189300         NaN
#           37.6296          0.0      4.8277   -1.190600         NaN
#           37.6316          0.0      4.8729   -1.120000         NaN
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9146 35.4470      -1.9668     1.29470     -5.1067     0.87440
#           35.4490      -2.5803     0.74781     -5.7172     0.19724
#           35.4510      -2.3308     0.99271     -5.4875     0.39402
#           35.4530      -2.8942     0.21585     -6.1191     0.00391
#           35.4550      -4.1777    -1.13510     -7.3587    -1.35330
# ...                        ...         ...         ...         ...
# -117.6414 37.6236      -4.1515    -1.99990      9.9914    -3.10550
#           37.6256      -4.1588    -1.73720     10.4130    -2.95840
#           37.6276      -4.1632    -1.71070     10.4830    -2.93180
#           37.6296      -4.1240    -1.89490     10.1870    -3.01790
#           37.6316      -4.1457    -1.70330     10.5180    -2.92690
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9146 35.4470     -5.15400     2.55900  ...     -6.5221     -3.3514
#           35.4490     -5.74300     1.93390  ...     -7.3692     -4.3340
#           35.4510     -5.48650     2.15280  ...     -6.8486     -4.0115
#           35.4530     -5.82860     1.83380  ...     -5.6745     -3.0299
#           35.4550     -7.29700     0.46061  ...     -7.9927     -5.4295
# ...                        ...         ...  ...         ...         ...
# -117.6414 37.6236     -0.32799     6.98990  ...      8.5800     11.3410
#           37.6256     -0.33838     7.34020  ...      9.2515     11.9960
#           37.6276     -0.34454     7.39780  ...      8.8321     11.5700
#           37.6296     -0.31614     7.12450  ...     10.3320     13.0730
#           37.6316     -0.33153     7.38390  ...      9.3376     12.0530
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9146 35.4470      -4.1662     -6.3219     -11.361     -9.6235
#           35.4490      -5.1182     -7.1733     -12.311    -10.5640
#           35.4510      -4.7786     -6.7119     -11.929    -10.1480
#           35.4530      -3.7675     -5.5943     -10.838     -9.0944
#           35.4550      -6.2580     -7.9820     -13.136    -11.3610
# ...                        ...         ...         ...         ...
# -117.6414 37.6236       5.5704      7.6113      17.002      9.6014
#           37.6256       6.0621      8.2387      17.526      9.5942
#           37.6276       5.5897      7.8226      17.066      9.2927
#           37.6296       7.2137      9.3699      18.582     10.8610
#           37.6316       6.0863      8.3323      17.499      9.8190
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9146 35.4470      -4.9249     -3.5976     -5.1346     -4.4193
#           35.4490      -5.7429     -4.3201     -5.8205     -5.0144
#           35.4510      -5.1576     -3.7890     -5.1048     -4.3554
#           35.4530      -3.9021     -2.8637     -3.8639     -3.1045
#           35.4550      -6.0692     -4.9656     -6.0258     -5.1433
# ...                        ...         ...         ...         ...
# -117.6414 37.6236      16.4360      8.5234     11.9040      8.8353
#           37.6256      16.7240      8.2348     11.6300      8.3278
#           37.6276      16.6410      8.2757     11.7900      8.3947
#           37.6296      17.9170      9.8912     13.3810     10.2190
#           37.6316      16.8390      8.8137     12.2150      8.8725
#
# [1657958 rows x 110 columns]

# %% [markdown]
# # Timestep and features

# %%
timestep=10
features=1

# %% [markdown]
# # Shaping function

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    
    for row in range(0,len(datain.index),10000):
    # Convert input dataframe to array and flatten
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        arr[np.isnan(arr)] = -1000
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# # Shape data

# %%
train, test = train_test_split(df, test_size=0.2)
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)
#print("Xtrain:", X_train.shape)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model1 = Sequential()
model1.add(Masking(mask_value=-100, input_shape=(timestep, 1)))
model1.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) 
model1.add(Conv1D(128,1,activation='relu',padding='same'))
model1.add(MaxPooling1D(1,padding='same'))
model1.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))
model1.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x

model1.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %% [markdown]
# # Train model on train data

# %%
history = model1.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=300, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                    
                   )
# Out:
# Epoch 1/300
# 528/528 - 11s - loss: 30791.7266 - mean_squared_error: 30791.7441 - mean_absolute_error: 65.4955 - 11s/epoch - 22ms/step
# Epoch 2/300
# 528/528 - 6s - loss: 9818.8867 - mean_squared_error: 9818.8955 - mean_absolute_error: 27.9185 - 6s/epoch - 12ms/step
# Epoch 3/300
# 528/528 - 5s - loss: 9098.9941 - mean_squared_error: 9098.9912 - mean_absolute_error: 28.2442 - 5s/epoch - 10ms/step
# Epoch 4/300
# 528/528 - 5s - loss: 10952.5127 - mean_squared_error: 10952.5146 - mean_absolute_error: 31.1966 - 5s/epoch - 10ms/step
# Epoch 5/300
# 528/528 - 5s - loss: 7948.9922 - mean_squared_error: 7948.9902 - mean_absolute_error: 20.8331 - 5s/epoch - 10ms/step
# Epoch 6/300
# 528/528 - 6s - loss: 7688.6050 - mean_squared_error: 7688.6050 - mean_absolute_error: 17.3823 - 6s/epoch - 11ms/step
# Epoch 7/300
# 528/528 - 6s - loss: 7466.6660 - mean_squared_error: 7466.6626 - mean_absolute_error: 17.1192 - 6s/epoch - 11ms/step
# Epoch 8/300
# 528/528 - 6s - loss: 48058.5703 - mean_squared_error: 48058.5938 - mean_absolute_error: 55.7272 - 6s/epoch - 11ms/step
# Epoch 9/300
# 528/528 - 5s - loss: 9085.4531 - mean_squared_error: 9085.4551 - mean_absolute_error: 30.8637 - 5s/epoch - 10ms/step
# Epoch 10/300
# 528/528 - 5s - loss: 7300.2744 - mean_squared_error: 7300.2700 - mean_absolute_error: 20.3203 - 5s/epoch - 10ms/step
# Epoch 11/300
# 528/528 - 5s - loss: 7037.0347 - mean_squared_error: 7037.0352 - mean_absolute_error: 17.3793 - 5s/epoch - 10ms/step
# Epoch 12/300
# 528/528 - 5s - loss: 6938.7090 - mean_squared_error: 6938.7036 - mean_absolute_error: 16.4375 - 5s/epoch - 10ms/step
# Epoch 13/300
# 528/528 - 5s - loss: 6932.1792 - mean_squared_error: 6932.1816 - mean_absolute_error: 16.8711 - 5s/epoch - 10ms/step
# Epoch 14/300
# 528/528 - 5s - loss: 6868.4487 - mean_squared_error: 6868.4473 - mean_absolute_error: 16.2664 - 5s/epoch - 10ms/step
# Epoch 15/300
# 528/528 - 5s - loss: 6803.8062 - mean_squared_error: 6803.8091 - mean_absolute_error: 14.7974 - 5s/epoch - 10ms/step
# Epoch 16/300
# 528/528 - 5s - loss: 8354.6211 - mean_squared_error: 8354.6201 - mean_absolute_error: 23.5724 - 5s/epoch - 10ms/step
# Epoch 17/300
# 528/528 - 5s - loss: 6763.2041 - mean_squared_error: 6763.2095 - mean_absolute_error: 16.2702 - 5s/epoch - 10ms/step
# Epoch 18/300
# 528/528 - 6s - loss: 6714.2949 - mean_squared_error: 6714.2944 - mean_absolute_error: 15.7387 - 6s/epoch - 11ms/step
# Epoch 19/300
# 528/528 - 5s - loss: 6542.8003 - mean_squared_error: 6542.8018 - mean_absolute_error: 14.6628 - 5s/epoch - 10ms/step
# Epoch 20/300
# 528/528 - 5s - loss: 8407.4404 - mean_squared_error: 8407.4404 - mean_absolute_error: 21.8185 - 5s/epoch - 10ms/step
# Epoch 21/300
# 528/528 - 5s - loss: 6864.5649 - mean_squared_error: 6864.5659 - mean_absolute_error: 18.6176 - 5s/epoch - 10ms/step
# Epoch 22/300
# 528/528 - 5s - loss: 6708.8877 - mean_squared_error: 6708.8892 - mean_absolute_error: 15.5249 - 5s/epoch - 10ms/step
# Epoch 23/300
# 528/528 - 5s - loss: 10544.1055 - mean_squared_error: 10544.1006 - mean_absolute_error: 27.4030 - 5s/epoch - 10ms/step
# Epoch 24/300
# 528/528 - 5s - loss: 6712.9253 - mean_squared_error: 6712.9233 - mean_absolute_error: 14.8736 - 5s/epoch - 10ms/step
# Epoch 25/300
# 528/528 - 5s - loss: 6682.4658 - mean_squared_error: 6682.4619 - mean_absolute_error: 14.8029 - 5s/epoch - 10ms/step
# Epoch 26/300
# 528/528 - 5s - loss: 6634.9502 - mean_squared_error: 6634.9473 - mean_absolute_error: 15.0333 - 5s/epoch - 10ms/step
# Epoch 27/300
# 528/528 - 5s - loss: 6498.0557 - mean_squared_error: 6498.0571 - mean_absolute_error: 14.8631 - 5s/epoch - 10ms/step
# Epoch 28/300
# 528/528 - 5s - loss: 6528.4458 - mean_squared_error: 6528.4487 - mean_absolute_error: 14.6547 - 5s/epoch - 10ms/step
# Epoch 29/300
# 528/528 - 5s - loss: 6487.1270 - mean_squared_error: 6487.1270 - mean_absolute_error: 14.3891 - 5s/epoch - 10ms/step
# Epoch 30/300
# 528/528 - 6s - loss: 6478.4731 - mean_squared_error: 6478.4727 - mean_absolute_error: 14.3379 - 6s/epoch - 11ms/step
# Epoch 31/300
# 528/528 - 5s - loss: 6512.5942 - mean_squared_error: 6512.5957 - mean_absolute_error: 14.4452 - 5s/epoch - 10ms/step
# Epoch 32/300
# 528/528 - 5s - loss: 6655.8325 - mean_squared_error: 6655.8267 - mean_absolute_error: 14.7170 - 5s/epoch - 10ms/step
# Epoch 33/300
# 528/528 - 5s - loss: 6658.6699 - mean_squared_error: 6658.6714 - mean_absolute_error: 14.9023 - 5s/epoch - 10ms/step
# Epoch 34/300
# 528/528 - 5s - loss: 6658.1851 - mean_squared_error: 6658.1875 - mean_absolute_error: 15.0261 - 5s/epoch - 10ms/step
# Epoch 35/300
# 528/528 - 5s - loss: 6653.5269 - mean_squared_error: 6653.5322 - mean_absolute_error: 15.0322 - 5s/epoch - 10ms/step
# Epoch 36/300
# 528/528 - 5s - loss: 6648.6787 - mean_squared_error: 6648.6772 - mean_absolute_error: 15.0540 - 5s/epoch - 10ms/step
# Epoch 37/300
# 528/528 - 5s - loss: 6647.0869 - mean_squared_error: 6647.0962 - mean_absolute_error: 15.1744 - 5s/epoch - 10ms/step
# Epoch 38/300
# 528/528 - 5s - loss: 6644.9512 - mean_squared_error: 6644.9531 - mean_absolute_error: 15.4077 - 5s/epoch - 10ms/step
# Epoch 39/300
# 528/528 - 5s - loss: 9169.1777 - mean_squared_error: 9169.1807 - mean_absolute_error: 21.8413 - 5s/epoch - 10ms/step
# Epoch 40/300
# 528/528 - 5s - loss: 6649.5195 - mean_squared_error: 6649.5127 - mean_absolute_error: 17.5475 - 5s/epoch - 10ms/step
# Epoch 41/300
# 528/528 - 5s - loss: 6484.6064 - mean_squared_error: 6484.6064 - mean_absolute_error: 14.9105 - 5s/epoch - 10ms/step
# Epoch 42/300
# 528/528 - 5s - loss: 6463.6924 - mean_squared_error: 6463.6895 - mean_absolute_error: 14.5929 - 5s/epoch - 10ms/step
# Epoch 43/300
# 528/528 - 5s - loss: 6453.8062 - mean_squared_error: 6453.8032 - mean_absolute_error: 14.6783 - 5s/epoch - 10ms/step
# Epoch 44/300
# 528/528 - 5s - loss: 6448.7300 - mean_squared_error: 6448.7295 - mean_absolute_error: 14.7931 - 5s/epoch - 10ms/step
# Epoch 45/300
# 528/528 - 5s - loss: 6444.2632 - mean_squared_error: 6444.2578 - mean_absolute_error: 15.1126 - 5s/epoch - 10ms/step
# Epoch 46/300
# 528/528 - 5s - loss: 6438.0605 - mean_squared_error: 6438.0576 - mean_absolute_error: 15.0020 - 5s/epoch - 10ms/step
# Epoch 47/300
# 528/528 - 5s - loss: 6435.3804 - mean_squared_error: 6435.3823 - mean_absolute_error: 15.1415 - 5s/epoch - 10ms/step
# Epoch 48/300
# 528/528 - 5s - loss: 6437.2021 - mean_squared_error: 6437.2026 - mean_absolute_error: 15.5815 - 5s/epoch - 10ms/step
# Epoch 49/300
# 528/528 - 5s - loss: 6436.6494 - mean_squared_error: 6436.6528 - mean_absolute_error: 15.3541 - 5s/epoch - 10ms/step
# Epoch 50/300
# 528/528 - 5s - loss: 6432.2705 - mean_squared_error: 6432.2686 - mean_absolute_error: 15.4382 - 5s/epoch - 10ms/step
# Epoch 51/300
# 528/528 - 5s - loss: 6458.7812 - mean_squared_error: 6458.7803 - mean_absolute_error: 15.9402 - 5s/epoch - 10ms/step
# Epoch 52/300
# 528/528 - 5s - loss: 6435.5630 - mean_squared_error: 6435.5601 - mean_absolute_error: 15.6356 - 5s/epoch - 10ms/step
# Epoch 53/300
# 528/528 - 5s - loss: 6434.9434 - mean_squared_error: 6434.9404 - mean_absolute_error: 15.4739 - 5s/epoch - 10ms/step
# Epoch 54/300
# 528/528 - 5s - loss: 7999.8984 - mean_squared_error: 7999.9067 - mean_absolute_error: 19.8518 - 5s/epoch - 10ms/step
# Epoch 55/300
# 528/528 - 5s - loss: 9159.4648 - mean_squared_error: 9159.4609 - mean_absolute_error: 27.9422 - 5s/epoch - 10ms/step
# Epoch 56/300
# 528/528 - 5s - loss: 6502.6812 - mean_squared_error: 6502.6836 - mean_absolute_error: 15.5959 - 5s/epoch - 10ms/step
# Epoch 57/300
# 528/528 - 5s - loss: 6456.7979 - mean_squared_error: 6456.8008 - mean_absolute_error: 15.2114 - 5s/epoch - 10ms/step
# Epoch 58/300
# 528/528 - 5s - loss: 6458.2134 - mean_squared_error: 6458.2134 - mean_absolute_error: 14.8085 - 5s/epoch - 10ms/step
# Epoch 59/300
# 528/528 - 5s - loss: 6437.2524 - mean_squared_error: 6437.2495 - mean_absolute_error: 15.1595 - 5s/epoch - 10ms/step
# Epoch 60/300
# 528/528 - 5s - loss: 6569.0898 - mean_squared_error: 6569.0903 - mean_absolute_error: 16.8670 - 5s/epoch - 10ms/step
# Epoch 61/300
# 528/528 - 5s - loss: 6450.6562 - mean_squared_error: 6450.6519 - mean_absolute_error: 15.0815 - 5s/epoch - 10ms/step
# Epoch 62/300
# 528/528 - 5s - loss: 6435.9565 - mean_squared_error: 6435.9580 - mean_absolute_error: 15.3414 - 5s/epoch - 10ms/step
# Epoch 63/300
# 528/528 - 5s - loss: 6441.3130 - mean_squared_error: 6441.3164 - mean_absolute_error: 15.4146 - 5s/epoch - 10ms/step
# Epoch 64/300
# 528/528 - 5s - loss: 6415.3394 - mean_squared_error: 6415.3398 - mean_absolute_error: 15.4792 - 5s/epoch - 10ms/step
# Epoch 65/300
# 528/528 - 5s - loss: 6425.7104 - mean_squared_error: 6425.7090 - mean_absolute_error: 16.2340 - 5s/epoch - 10ms/step
# Epoch 66/300
# 528/528 - 6s - loss: 6475.6045 - mean_squared_error: 6475.6064 - mean_absolute_error: 16.8115 - 6s/epoch - 11ms/step
# Epoch 67/300
# 528/528 - 5s - loss: 6409.2319 - mean_squared_error: 6409.2358 - mean_absolute_error: 15.7828 - 5s/epoch - 10ms/step
# Epoch 68/300
# 528/528 - 5s - loss: 6400.9805 - mean_squared_error: 6400.9805 - mean_absolute_error: 15.7623 - 5s/epoch - 10ms/step
# Epoch 69/300
# 528/528 - 5s - loss: 6802.8130 - mean_squared_error: 6802.8076 - mean_absolute_error: 19.5288 - 5s/epoch - 10ms/step
# Epoch 70/300
# 528/528 - 5s - loss: 6424.5498 - mean_squared_error: 6424.5474 - mean_absolute_error: 15.8894 - 5s/epoch - 10ms/step
# Epoch 71/300
# 528/528 - 5s - loss: 8355.7256 - mean_squared_error: 8355.7197 - mean_absolute_error: 24.5523 - 5s/epoch - 10ms/step
# Epoch 72/300
# 528/528 - 5s - loss: 6777.5591 - mean_squared_error: 6777.5635 - mean_absolute_error: 18.1983 - 5s/epoch - 10ms/step
# Epoch 73/300
# 528/528 - 5s - loss: 6455.3838 - mean_squared_error: 6455.3853 - mean_absolute_error: 15.6029 - 5s/epoch - 10ms/step
# Epoch 74/300
# 528/528 - 5s - loss: 6417.3433 - mean_squared_error: 6417.3398 - mean_absolute_error: 15.2312 - 5s/epoch - 10ms/step
# Epoch 75/300
# 528/528 - 5s - loss: 6393.3071 - mean_squared_error: 6393.3110 - mean_absolute_error: 15.3377 - 5s/epoch - 10ms/step
# Epoch 76/300
# 528/528 - 5s - loss: 6392.6313 - mean_squared_error: 6392.6294 - mean_absolute_error: 15.3824 - 5s/epoch - 10ms/step
# Epoch 77/300
# 528/528 - 5s - loss: 6389.0552 - mean_squared_error: 6389.0552 - mean_absolute_error: 15.4810 - 5s/epoch - 10ms/step
# Epoch 78/300
# 528/528 - 5s - loss: 6372.8804 - mean_squared_error: 6372.8828 - mean_absolute_error: 16.0025 - 5s/epoch - 10ms/step
# Epoch 79/300
# 528/528 - 5s - loss: 6348.2344 - mean_squared_error: 6348.2363 - mean_absolute_error: 15.7165 - 5s/epoch - 10ms/step
# Epoch 80/300
# 528/528 - 5s - loss: 6658.9678 - mean_squared_error: 6658.9648 - mean_absolute_error: 18.2542 - 5s/epoch - 10ms/step
# Epoch 81/300
# 528/528 - 5s - loss: 6398.3408 - mean_squared_error: 6398.3364 - mean_absolute_error: 15.7415 - 5s/epoch - 10ms/step
# Epoch 82/300
# 528/528 - 5s - loss: 6318.0767 - mean_squared_error: 6318.0776 - mean_absolute_error: 15.9932 - 5s/epoch - 10ms/step
# Epoch 83/300
# 528/528 - 6s - loss: 6310.1001 - mean_squared_error: 6310.0986 - mean_absolute_error: 16.4807 - 6s/epoch - 10ms/step
# Epoch 84/300
# 528/528 - 6s - loss: 6327.3394 - mean_squared_error: 6327.3379 - mean_absolute_error: 15.6883 - 6s/epoch - 11ms/step
# Epoch 85/300
# 528/528 - 6s - loss: 6353.4536 - mean_squared_error: 6353.4502 - mean_absolute_error: 15.8534 - 6s/epoch - 11ms/step
# Epoch 86/300
# 528/528 - 5s - loss: 6658.4004 - mean_squared_error: 6658.4033 - mean_absolute_error: 19.1265 - 5s/epoch - 10ms/step
# Epoch 87/300
# 528/528 - 5s - loss: 6324.9663 - mean_squared_error: 6324.9722 - mean_absolute_error: 17.2751 - 5s/epoch - 10ms/step
# Epoch 88/300
# 528/528 - 5s - loss: 6301.8218 - mean_squared_error: 6301.8237 - mean_absolute_error: 15.9335 - 5s/epoch - 10ms/step
# Epoch 89/300
# 528/528 - 5s - loss: 6319.3296 - mean_squared_error: 6319.3267 - mean_absolute_error: 16.7646 - 5s/epoch - 10ms/step
# Epoch 90/300
# 528/528 - 5s - loss: 6299.6748 - mean_squared_error: 6299.6733 - mean_absolute_error: 16.4328 - 5s/epoch - 10ms/step
# Epoch 91/300
# 528/528 - 5s - loss: 6308.5537 - mean_squared_error: 6308.5566 - mean_absolute_error: 16.4414 - 5s/epoch - 10ms/step
# Epoch 92/300
# 528/528 - 5s - loss: 6264.3325 - mean_squared_error: 6264.3335 - mean_absolute_error: 16.0069 - 5s/epoch - 10ms/step
# Epoch 93/300
# 528/528 - 5s - loss: 6332.6528 - mean_squared_error: 6332.6602 - mean_absolute_error: 16.6406 - 5s/epoch - 10ms/step
# Epoch 94/300
# 528/528 - 5s - loss: 6409.0664 - mean_squared_error: 6409.0635 - mean_absolute_error: 16.5590 - 5s/epoch - 10ms/step
# Epoch 95/300
# 528/528 - 5s - loss: 6392.4346 - mean_squared_error: 6392.4409 - mean_absolute_error: 17.0820 - 5s/epoch - 10ms/step
# Epoch 96/300
# 528/528 - 5s - loss: 6337.2285 - mean_squared_error: 6337.2334 - mean_absolute_error: 16.7502 - 5s/epoch - 10ms/step
# Epoch 97/300
# 528/528 - 5s - loss: 6375.6504 - mean_squared_error: 6375.6484 - mean_absolute_error: 15.8997 - 5s/epoch - 10ms/step
# Epoch 98/300
# 528/528 - 5s - loss: 6326.1069 - mean_squared_error: 6326.1064 - mean_absolute_error: 16.9359 - 5s/epoch - 10ms/step
# Epoch 99/300
# 528/528 - 5s - loss: 6301.3447 - mean_squared_error: 6301.3438 - mean_absolute_error: 16.8324 - 5s/epoch - 10ms/step
# Epoch 100/300
# 528/528 - 6s - loss: 6230.0752 - mean_squared_error: 6230.0752 - mean_absolute_error: 17.0983 - val_loss: 5918.1812 - val_mean_squared_error: 5918.1802 - val_mean_absolute_error: 17.4077 - 6s/epoch - 12ms/step
# Epoch 101/300
# 528/528 - 5s - loss: 6332.0649 - mean_squared_error: 6332.0674 - mean_absolute_error: 19.0269 - 5s/epoch - 10ms/step
# Epoch 102/300
# 528/528 - 5s - loss: 6195.1660 - mean_squared_error: 6195.1670 - mean_absolute_error: 17.6195 - 5s/epoch - 10ms/step
# Epoch 103/300
# 528/528 - 5s - loss: 6224.8232 - mean_squared_error: 6224.8208 - mean_absolute_error: 16.8229 - 5s/epoch - 10ms/step
# Epoch 104/300
# 528/528 - 5s - loss: 6205.1118 - mean_squared_error: 6205.1089 - mean_absolute_error: 16.8395 - 5s/epoch - 10ms/step
# Epoch 105/300
# 528/528 - 5s - loss: 6122.0674 - mean_squared_error: 6122.0659 - mean_absolute_error: 16.5791 - 5s/epoch - 10ms/step
# Epoch 106/300
# 528/528 - 5s - loss: 6166.0376 - mean_squared_error: 6166.0356 - mean_absolute_error: 16.9273 - 5s/epoch - 10ms/step
# Epoch 107/300
# 528/528 - 5s - loss: 6116.2290 - mean_squared_error: 6116.2314 - mean_absolute_error: 16.5954 - 5s/epoch - 10ms/step
# Epoch 108/300
# 528/528 - 5s - loss: 6099.2949 - mean_squared_error: 6099.2900 - mean_absolute_error: 17.2827 - 5s/epoch - 10ms/step
# Epoch 109/300
# 528/528 - 5s - loss: 6102.5093 - mean_squared_error: 6102.5107 - mean_absolute_error: 16.6898 - 5s/epoch - 10ms/step
# Epoch 110/300
# 528/528 - 5s - loss: 6316.4297 - mean_squared_error: 6316.4297 - mean_absolute_error: 18.3347 - 5s/epoch - 10ms/step
# Epoch 111/300
# 528/528 - 5s - loss: 7129.8018 - mean_squared_error: 7129.8071 - mean_absolute_error: 21.6559 - 5s/epoch - 10ms/step
# Epoch 112/300
# 528/528 - 5s - loss: 6142.0762 - mean_squared_error: 6142.0786 - mean_absolute_error: 16.0331 - 5s/epoch - 10ms/step
# Epoch 113/300
# 528/528 - 5s - loss: 6076.6060 - mean_squared_error: 6076.5991 - mean_absolute_error: 16.1218 - 5s/epoch - 10ms/step
# Epoch 114/300
# 528/528 - 5s - loss: 6122.8149 - mean_squared_error: 6122.8164 - mean_absolute_error: 16.7935 - 5s/epoch - 10ms/step
# Epoch 115/300
# 528/528 - 5s - loss: 6038.1216 - mean_squared_error: 6038.1230 - mean_absolute_error: 16.1771 - 5s/epoch - 10ms/step
# Epoch 116/300
# 528/528 - 6s - loss: 6055.4043 - mean_squared_error: 6055.4014 - mean_absolute_error: 16.4264 - 6s/epoch - 11ms/step
# Epoch 117/300
# 528/528 - 5s - loss: 6069.8281 - mean_squared_error: 6069.8301 - mean_absolute_error: 16.6655 - 5s/epoch - 10ms/step
# Epoch 118/300
# 528/528 - 5s - loss: 6083.7622 - mean_squared_error: 6083.7607 - mean_absolute_error: 15.9714 - 5s/epoch - 10ms/step
# Epoch 119/300
# 528/528 - 5s - loss: 5927.4258 - mean_squared_error: 5927.4243 - mean_absolute_error: 15.8101 - 5s/epoch - 10ms/step
# Epoch 120/300
# 528/528 - 5s - loss: 6129.8159 - mean_squared_error: 6129.8228 - mean_absolute_error: 15.6134 - 5s/epoch - 10ms/step
# Epoch 121/300
# 528/528 - 5s - loss: 5984.2124 - mean_squared_error: 5984.2129 - mean_absolute_error: 16.5678 - 5s/epoch - 10ms/step
# Epoch 122/300
# 528/528 - 5s - loss: 6179.1558 - mean_squared_error: 6179.1562 - mean_absolute_error: 16.7184 - 5s/epoch - 10ms/step
# Epoch 123/300
# 528/528 - 5s - loss: 6038.2866 - mean_squared_error: 6038.2837 - mean_absolute_error: 16.5613 - 5s/epoch - 10ms/step
# Epoch 124/300
# 528/528 - 5s - loss: 5983.8896 - mean_squared_error: 5983.8892 - mean_absolute_error: 16.5406 - 5s/epoch - 10ms/step
# Epoch 125/300
# 528/528 - 5s - loss: 6317.9927 - mean_squared_error: 6317.9907 - mean_absolute_error: 18.5393 - 5s/epoch - 10ms/step
# Epoch 126/300
# 528/528 - 5s - loss: 6036.2280 - mean_squared_error: 6036.2256 - mean_absolute_error: 16.0813 - 5s/epoch - 10ms/step
# Epoch 127/300
# 528/528 - 5s - loss: 5974.8730 - mean_squared_error: 5974.8721 - mean_absolute_error: 15.7596 - 5s/epoch - 10ms/step
# Epoch 128/300
# 528/528 - 5s - loss: 5923.3115 - mean_squared_error: 5923.3091 - mean_absolute_error: 15.2895 - 5s/epoch - 10ms/step
# Epoch 129/300
# 528/528 - 5s - loss: 5922.4600 - mean_squared_error: 5922.4619 - mean_absolute_error: 15.5870 - 5s/epoch - 10ms/step
# Epoch 130/300
# 528/528 - 5s - loss: 5863.5161 - mean_squared_error: 5863.5142 - mean_absolute_error: 15.8158 - 5s/epoch - 10ms/step
# Epoch 131/300
# 528/528 - 5s - loss: 5916.3799 - mean_squared_error: 5916.3823 - mean_absolute_error: 15.8231 - 5s/epoch - 10ms/step
# Epoch 132/300
# 528/528 - 5s - loss: 5961.4634 - mean_squared_error: 5961.4658 - mean_absolute_error: 15.9976 - 5s/epoch - 10ms/step
# Epoch 133/300
# 528/528 - 5s - loss: 5908.5835 - mean_squared_error: 5908.5859 - mean_absolute_error: 15.4906 - 5s/epoch - 10ms/step
# Epoch 134/300
# 528/528 - 5s - loss: 5851.0728 - mean_squared_error: 5851.0698 - mean_absolute_error: 15.5647 - 5s/epoch - 10ms/step
# Epoch 135/300
# 528/528 - 5s - loss: 5808.7227 - mean_squared_error: 5808.7212 - mean_absolute_error: 15.8309 - 5s/epoch - 10ms/step
# Epoch 136/300
# 528/528 - 5s - loss: 5821.8965 - mean_squared_error: 5821.8955 - mean_absolute_error: 15.7177 - 5s/epoch - 10ms/step
# Epoch 137/300
# 528/528 - 5s - loss: 5878.1919 - mean_squared_error: 5878.1938 - mean_absolute_error: 16.4422 - 5s/epoch - 10ms/step
# Epoch 138/300
# 528/528 - 5s - loss: 5928.0327 - mean_squared_error: 5928.0337 - mean_absolute_error: 16.7717 - 5s/epoch - 10ms/step
# Epoch 139/300
# 528/528 - 5s - loss: 5772.6948 - mean_squared_error: 5772.6948 - mean_absolute_error: 15.2046 - 5s/epoch - 10ms/step
# Epoch 140/300
# 528/528 - 5s - loss: 5764.5054 - mean_squared_error: 5764.5059 - mean_absolute_error: 15.2584 - 5s/epoch - 10ms/step
# Epoch 141/300
# 528/528 - 5s - loss: 5743.0396 - mean_squared_error: 5743.0386 - mean_absolute_error: 15.3662 - 5s/epoch - 10ms/step
# Epoch 142/300
# 528/528 - 5s - loss: 5840.9927 - mean_squared_error: 5840.9941 - mean_absolute_error: 15.9404 - 5s/epoch - 10ms/step
# Epoch 143/300
# 528/528 - 5s - loss: 5819.7256 - mean_squared_error: 5819.7261 - mean_absolute_error: 15.1965 - 5s/epoch - 10ms/step
# Epoch 144/300
# 528/528 - 5s - loss: 5753.6338 - mean_squared_error: 5753.6387 - mean_absolute_error: 15.2314 - 5s/epoch - 10ms/step
# Epoch 145/300
# 528/528 - 5s - loss: 5730.4497 - mean_squared_error: 5730.4531 - mean_absolute_error: 15.2318 - 5s/epoch - 10ms/step
# Epoch 146/300
# 528/528 - 5s - loss: 5693.0068 - mean_squared_error: 5693.0049 - mean_absolute_error: 15.2776 - 5s/epoch - 10ms/step
# Epoch 147/300
# 528/528 - 5s - loss: 5796.7109 - mean_squared_error: 5796.7100 - mean_absolute_error: 15.9029 - 5s/epoch - 10ms/step
# Epoch 148/300
# 528/528 - 5s - loss: 5666.5205 - mean_squared_error: 5666.5259 - mean_absolute_error: 15.4513 - 5s/epoch - 10ms/step
# Epoch 149/300
# 528/528 - 5s - loss: 5733.9180 - mean_squared_error: 5733.9175 - mean_absolute_error: 15.4462 - 5s/epoch - 10ms/step
# Epoch 150/300
# 528/528 - 5s - loss: 5871.7910 - mean_squared_error: 5871.7900 - mean_absolute_error: 16.2574 - 5s/epoch - 10ms/step
# Epoch 151/300
# 528/528 - 5s - loss: 5673.7480 - mean_squared_error: 5673.7441 - mean_absolute_error: 15.1152 - 5s/epoch - 10ms/step
# Epoch 152/300
# 528/528 - 5s - loss: 5611.5176 - mean_squared_error: 5611.5186 - mean_absolute_error: 14.8599 - 5s/epoch - 10ms/step
# Epoch 153/300
# 528/528 - 5s - loss: 5678.6470 - mean_squared_error: 5678.6479 - mean_absolute_error: 14.8432 - 5s/epoch - 10ms/step
# Epoch 154/300
# 528/528 - 5s - loss: 6393.3462 - mean_squared_error: 6393.3428 - mean_absolute_error: 16.3267 - 5s/epoch - 10ms/step
# Epoch 155/300
# 528/528 - 5s - loss: 5881.3574 - mean_squared_error: 5881.3564 - mean_absolute_error: 17.6011 - 5s/epoch - 10ms/step
# Epoch 156/300
# 528/528 - 5s - loss: 5871.4312 - mean_squared_error: 5871.4316 - mean_absolute_error: 15.1799 - 5s/epoch - 10ms/step
# Epoch 157/300
# 528/528 - 5s - loss: 6052.5771 - mean_squared_error: 6052.5830 - mean_absolute_error: 16.1155 - 5s/epoch - 10ms/step
# Epoch 158/300
# 528/528 - 5s - loss: 5726.4600 - mean_squared_error: 5726.4624 - mean_absolute_error: 14.8536 - 5s/epoch - 10ms/step
# Epoch 159/300
# 528/528 - 5s - loss: 5612.7158 - mean_squared_error: 5612.7144 - mean_absolute_error: 15.0607 - 5s/epoch - 10ms/step
# Epoch 160/300
# 528/528 - 5s - loss: 5762.9390 - mean_squared_error: 5762.9404 - mean_absolute_error: 15.0944 - 5s/epoch - 10ms/step
# Epoch 161/300
# 528/528 - 5s - loss: 5709.6606 - mean_squared_error: 5709.6602 - mean_absolute_error: 15.5062 - 5s/epoch - 10ms/step
# Epoch 162/300
# 528/528 - 5s - loss: 5644.9199 - mean_squared_error: 5644.9185 - mean_absolute_error: 15.0232 - 5s/epoch - 10ms/step
# Epoch 163/300
# 528/528 - 5s - loss: 5833.6216 - mean_squared_error: 5833.6201 - mean_absolute_error: 15.6606 - 5s/epoch - 10ms/step
# Epoch 164/300
# 528/528 - 5s - loss: 5740.1660 - mean_squared_error: 5740.1655 - mean_absolute_error: 14.6572 - 5s/epoch - 10ms/step
# Epoch 165/300
# 528/528 - 6s - loss: 5714.8589 - mean_squared_error: 5714.8555 - mean_absolute_error: 15.0045 - 6s/epoch - 10ms/step
# Epoch 166/300
# 528/528 - 6s - loss: 5622.9526 - mean_squared_error: 5622.9497 - mean_absolute_error: 14.5834 - 6s/epoch - 10ms/step
# Epoch 167/300
# 528/528 - 5s - loss: 5664.4990 - mean_squared_error: 5664.4946 - mean_absolute_error: 15.1345 - 5s/epoch - 10ms/step
# Epoch 168/300
# 528/528 - 5s - loss: 5689.8960 - mean_squared_error: 5689.8936 - mean_absolute_error: 15.0891 - 5s/epoch - 10ms/step
# Epoch 169/300
# 528/528 - 5s - loss: 5856.0112 - mean_squared_error: 5856.0151 - mean_absolute_error: 16.5780 - 5s/epoch - 10ms/step
# Epoch 170/300
# 528/528 - 5s - loss: 5542.2617 - mean_squared_error: 5542.2622 - mean_absolute_error: 14.8156 - 5s/epoch - 10ms/step
# Epoch 171/300
# 528/528 - 5s - loss: 5714.6470 - mean_squared_error: 5714.6494 - mean_absolute_error: 15.2212 - 5s/epoch - 10ms/step
# Epoch 172/300
# 528/528 - 5s - loss: 5542.6152 - mean_squared_error: 5542.6133 - mean_absolute_error: 14.9115 - 5s/epoch - 10ms/step
# Epoch 173/300
# 528/528 - 5s - loss: 5500.9287 - mean_squared_error: 5500.9292 - mean_absolute_error: 14.9388 - 5s/epoch - 10ms/step
# Epoch 174/300
# 528/528 - 5s - loss: 5460.3081 - mean_squared_error: 5460.3037 - mean_absolute_error: 15.2566 - 5s/epoch - 10ms/step
# Epoch 175/300
# 528/528 - 5s - loss: 5487.7134 - mean_squared_error: 5487.7139 - mean_absolute_error: 15.0525 - 5s/epoch - 10ms/step
# Epoch 176/300
# 528/528 - 5s - loss: 5786.9233 - mean_squared_error: 5786.9219 - mean_absolute_error: 15.8513 - 5s/epoch - 10ms/step
# Epoch 177/300
# 528/528 - 5s - loss: 5728.3403 - mean_squared_error: 5728.3423 - mean_absolute_error: 16.0384 - 5s/epoch - 10ms/step
# Epoch 178/300
# 528/528 - 5s - loss: 5801.4341 - mean_squared_error: 5801.4316 - mean_absolute_error: 15.8143 - 5s/epoch - 10ms/step
# Epoch 179/300
# 528/528 - 5s - loss: 5590.7437 - mean_squared_error: 5590.7451 - mean_absolute_error: 15.4653 - 5s/epoch - 10ms/step
# Epoch 180/300
# 528/528 - 5s - loss: 5628.6475 - mean_squared_error: 5628.6450 - mean_absolute_error: 15.1776 - 5s/epoch - 10ms/step
# Epoch 181/300
# 528/528 - 5s - loss: 5591.3687 - mean_squared_error: 5591.3667 - mean_absolute_error: 14.7777 - 5s/epoch - 10ms/step
# Epoch 182/300
# 528/528 - 5s - loss: 5505.5552 - mean_squared_error: 5505.5537 - mean_absolute_error: 14.6441 - 5s/epoch - 10ms/step
# Epoch 183/300
# 528/528 - 5s - loss: 5570.0474 - mean_squared_error: 5570.0469 - mean_absolute_error: 14.7511 - 5s/epoch - 10ms/step
# Epoch 184/300
# 528/528 - 5s - loss: 5515.6938 - mean_squared_error: 5515.6914 - mean_absolute_error: 14.2586 - 5s/epoch - 10ms/step
# Epoch 185/300
# 528/528 - 5s - loss: 5457.9824 - mean_squared_error: 5457.9849 - mean_absolute_error: 14.5893 - 5s/epoch - 10ms/step
# Epoch 186/300
# 528/528 - 5s - loss: 5945.2070 - mean_squared_error: 5945.2095 - mean_absolute_error: 15.9612 - 5s/epoch - 10ms/step
# Epoch 187/300
# 528/528 - 5s - loss: 5495.0435 - mean_squared_error: 5495.0391 - mean_absolute_error: 14.2408 - 5s/epoch - 10ms/step
# Epoch 188/300
# 528/528 - 5s - loss: 5477.2529 - mean_squared_error: 5477.2529 - mean_absolute_error: 14.3645 - 5s/epoch - 10ms/step
# Epoch 189/300
# 528/528 - 5s - loss: 5433.9033 - mean_squared_error: 5433.8975 - mean_absolute_error: 14.2142 - 5s/epoch - 10ms/step
# Epoch 190/300
# 528/528 - 5s - loss: 5452.2197 - mean_squared_error: 5452.2192 - mean_absolute_error: 14.4429 - 5s/epoch - 10ms/step
# Epoch 191/300
# 528/528 - 5s - loss: 5487.6177 - mean_squared_error: 5487.6206 - mean_absolute_error: 14.5668 - 5s/epoch - 10ms/step
# Epoch 192/300
# 528/528 - 5s - loss: 5440.1934 - mean_squared_error: 5440.1938 - mean_absolute_error: 14.4893 - 5s/epoch - 10ms/step
# Epoch 193/300
# 528/528 - 5s - loss: 5436.4531 - mean_squared_error: 5436.4536 - mean_absolute_error: 14.7689 - 5s/epoch - 10ms/step
# Epoch 194/300
# 528/528 - 5s - loss: 5472.4106 - mean_squared_error: 5472.4102 - mean_absolute_error: 15.0854 - 5s/epoch - 10ms/step
# Epoch 195/300
# 528/528 - 5s - loss: 5535.7964 - mean_squared_error: 5535.7998 - mean_absolute_error: 15.0060 - 5s/epoch - 10ms/step
# Epoch 196/300
# 528/528 - 5s - loss: 5514.7729 - mean_squared_error: 5514.7681 - mean_absolute_error: 15.0333 - 5s/epoch - 10ms/step
# Epoch 197/300
# 528/528 - 5s - loss: 5514.5166 - mean_squared_error: 5514.5156 - mean_absolute_error: 14.0610 - 5s/epoch - 10ms/step
# Epoch 198/300
# 528/528 - 5s - loss: 5685.7900 - mean_squared_error: 5685.7964 - mean_absolute_error: 15.8356 - 5s/epoch - 10ms/step
# Epoch 199/300
# 528/528 - 5s - loss: 5543.8584 - mean_squared_error: 5543.8555 - mean_absolute_error: 14.9038 - 5s/epoch - 10ms/step
# Epoch 200/300
# 528/528 - 6s - loss: 5566.1406 - mean_squared_error: 5566.1401 - mean_absolute_error: 14.0709 - val_loss: 5571.3467 - val_mean_squared_error: 5571.3457 - val_mean_absolute_error: 13.6241 - 6s/epoch - 11ms/step
# Epoch 201/300
# 528/528 - 5s - loss: 5417.5278 - mean_squared_error: 5417.5288 - mean_absolute_error: 14.0242 - 5s/epoch - 10ms/step
# Epoch 202/300
# 528/528 - 5s - loss: 5365.6348 - mean_squared_error: 5365.6343 - mean_absolute_error: 13.9867 - 5s/epoch - 10ms/step
# Epoch 203/300
# 528/528 - 5s - loss: 5413.9019 - mean_squared_error: 5413.9023 - mean_absolute_error: 13.8999 - 5s/epoch - 10ms/step
# Epoch 204/300
# 528/528 - 5s - loss: 5395.6328 - mean_squared_error: 5395.6328 - mean_absolute_error: 14.4975 - 5s/epoch - 10ms/step
# Epoch 205/300
# 528/528 - 5s - loss: 5486.5835 - mean_squared_error: 5486.5859 - mean_absolute_error: 14.8700 - 5s/epoch - 10ms/step
# Epoch 206/300
# 528/528 - 5s - loss: 5376.8867 - mean_squared_error: 5376.8901 - mean_absolute_error: 14.3702 - 5s/epoch - 10ms/step
# Epoch 207/300
# 528/528 - 5s - loss: 5300.9468 - mean_squared_error: 5300.9487 - mean_absolute_error: 14.3908 - 5s/epoch - 10ms/step
# Epoch 208/300
# 528/528 - 5s - loss: 5386.9902 - mean_squared_error: 5386.9902 - mean_absolute_error: 14.5965 - 5s/epoch - 10ms/step
# Epoch 209/300
# 528/528 - 6s - loss: 5323.6318 - mean_squared_error: 5323.6367 - mean_absolute_error: 14.7794 - 6s/epoch - 10ms/step
# Epoch 210/300
# 528/528 - 5s - loss: 5290.7930 - mean_squared_error: 5290.7920 - mean_absolute_error: 13.9443 - 5s/epoch - 10ms/step
# Epoch 211/300
# 528/528 - 5s - loss: 5454.5654 - mean_squared_error: 5454.5679 - mean_absolute_error: 13.9106 - 5s/epoch - 10ms/step
# Epoch 212/300
# 528/528 - 5s - loss: 5288.2876 - mean_squared_error: 5288.2881 - mean_absolute_error: 13.3246 - 5s/epoch - 10ms/step
# Epoch 213/300
# 528/528 - 5s - loss: 5561.6851 - mean_squared_error: 5561.6875 - mean_absolute_error: 15.0337 - 5s/epoch - 10ms/step
# Epoch 214/300
# 528/528 - 5s - loss: 5330.7285 - mean_squared_error: 5330.7280 - mean_absolute_error: 13.1924 - 5s/epoch - 10ms/step
# Epoch 215/300
# 528/528 - 5s - loss: 5283.8794 - mean_squared_error: 5283.8809 - mean_absolute_error: 13.1444 - 5s/epoch - 10ms/step
# Epoch 216/300
# 528/528 - 5s - loss: 5236.9072 - mean_squared_error: 5236.9038 - mean_absolute_error: 13.3964 - 5s/epoch - 10ms/step
# Epoch 217/300
# 528/528 - 5s - loss: 5403.8740 - mean_squared_error: 5403.8687 - mean_absolute_error: 14.0170 - 5s/epoch - 10ms/step
# Epoch 218/300
# 528/528 - 5s - loss: 5301.1089 - mean_squared_error: 5301.1079 - mean_absolute_error: 13.7919 - 5s/epoch - 10ms/step
# Epoch 219/300
# 528/528 - 5s - loss: 5294.1343 - mean_squared_error: 5294.1338 - mean_absolute_error: 14.1536 - 5s/epoch - 10ms/step
# Epoch 220/300
# 528/528 - 5s - loss: 5197.5723 - mean_squared_error: 5197.5728 - mean_absolute_error: 13.4799 - 5s/epoch - 10ms/step
# Epoch 221/300
# 528/528 - 5s - loss: 5476.5532 - mean_squared_error: 5476.5479 - mean_absolute_error: 15.3442 - 5s/epoch - 10ms/step
# Epoch 222/300
# 528/528 - 5s - loss: 5238.0972 - mean_squared_error: 5238.0977 - mean_absolute_error: 13.5483 - 5s/epoch - 10ms/step
# Epoch 223/300
# 528/528 - 5s - loss: 5199.6455 - mean_squared_error: 5199.6475 - mean_absolute_error: 13.0942 - 5s/epoch - 10ms/step
# Epoch 224/300
# 528/528 - 5s - loss: 5286.1836 - mean_squared_error: 5286.1841 - mean_absolute_error: 13.4634 - 5s/epoch - 10ms/step
# Epoch 225/300
# 528/528 - 6s - loss: 5323.0610 - mean_squared_error: 5323.0601 - mean_absolute_error: 13.4903 - 6s/epoch - 11ms/step
# Epoch 226/300
# 528/528 - 5s - loss: 5242.3901 - mean_squared_error: 5242.3955 - mean_absolute_error: 13.3475 - 5s/epoch - 10ms/step
# Epoch 227/300
# 528/528 - 5s - loss: 5144.7207 - mean_squared_error: 5144.7222 - mean_absolute_error: 13.4926 - 5s/epoch - 10ms/step
# Epoch 228/300
# 528/528 - 5s - loss: 5332.4434 - mean_squared_error: 5332.4492 - mean_absolute_error: 14.1418 - 5s/epoch - 10ms/step
# Epoch 229/300
# 528/528 - 5s - loss: 5150.1191 - mean_squared_error: 5150.1240 - mean_absolute_error: 13.6425 - 5s/epoch - 10ms/step
# Epoch 230/300
# 528/528 - 5s - loss: 5096.2158 - mean_squared_error: 5096.2153 - mean_absolute_error: 13.4166 - 5s/epoch - 10ms/step
# Epoch 231/300
# 528/528 - 5s - loss: 5106.2349 - mean_squared_error: 5106.2363 - mean_absolute_error: 13.6681 - 5s/epoch - 10ms/step
# Epoch 232/300
# 528/528 - 5s - loss: 5155.3940 - mean_squared_error: 5155.3955 - mean_absolute_error: 13.7459 - 5s/epoch - 10ms/step
# Epoch 233/300
# 528/528 - 5s - loss: 5309.1987 - mean_squared_error: 5309.1982 - mean_absolute_error: 13.9220 - 5s/epoch - 10ms/step
# Epoch 234/300
# 528/528 - 5s - loss: 5278.8579 - mean_squared_error: 5278.8550 - mean_absolute_error: 14.1125 - 5s/epoch - 10ms/step
# Epoch 235/300
# 528/528 - 5s - loss: 5406.3242 - mean_squared_error: 5406.3242 - mean_absolute_error: 14.3950 - 5s/epoch - 10ms/step
# Epoch 236/300
# 528/528 - 5s - loss: 5285.8340 - mean_squared_error: 5285.8345 - mean_absolute_error: 13.8489 - 5s/epoch - 10ms/step
# Epoch 237/300
# 528/528 - 5s - loss: 5382.2930 - mean_squared_error: 5382.2930 - mean_absolute_error: 14.2334 - 5s/epoch - 10ms/step
# Epoch 238/300
# 528/528 - 5s - loss: 5315.8809 - mean_squared_error: 5315.8828 - mean_absolute_error: 13.7006 - 5s/epoch - 10ms/step
# Epoch 239/300
# 528/528 - 5s - loss: 5409.0679 - mean_squared_error: 5409.0732 - mean_absolute_error: 14.0017 - 5s/epoch - 10ms/step
# Epoch 240/300
# 528/528 - 5s - loss: 5332.4761 - mean_squared_error: 5332.4790 - mean_absolute_error: 14.1876 - 5s/epoch - 10ms/step
# Epoch 241/300
# 528/528 - 5s - loss: 5476.0557 - mean_squared_error: 5476.0566 - mean_absolute_error: 14.0164 - 5s/epoch - 10ms/step
# Epoch 242/300
# 528/528 - 5s - loss: 5287.3257 - mean_squared_error: 5287.3252 - mean_absolute_error: 14.7766 - 5s/epoch - 10ms/step
# Epoch 243/300
# 528/528 - 5s - loss: 5551.3247 - mean_squared_error: 5551.3237 - mean_absolute_error: 15.4523 - 5s/epoch - 10ms/step
# Epoch 244/300
# 528/528 - 5s - loss: 5422.3501 - mean_squared_error: 5422.3501 - mean_absolute_error: 14.1441 - 5s/epoch - 10ms/step
# Epoch 245/300
# 528/528 - 5s - loss: 5227.6743 - mean_squared_error: 5227.6699 - mean_absolute_error: 13.2251 - 5s/epoch - 10ms/step
# Epoch 246/300
# 528/528 - 5s - loss: 5116.5020 - mean_squared_error: 5116.5010 - mean_absolute_error: 12.8921 - 5s/epoch - 10ms/step
# Epoch 247/300
# 528/528 - 5s - loss: 5139.6426 - mean_squared_error: 5139.6416 - mean_absolute_error: 12.9612 - 5s/epoch - 10ms/step
# Epoch 248/300
# 528/528 - 5s - loss: 5102.6309 - mean_squared_error: 5102.6328 - mean_absolute_error: 13.0644 - 5s/epoch - 10ms/step
# Epoch 249/300
# 528/528 - 5s - loss: 5105.1860 - mean_squared_error: 5105.1821 - mean_absolute_error: 12.9419 - 5s/epoch - 10ms/step
# Epoch 250/300
# 528/528 - 5s - loss: 5263.2495 - mean_squared_error: 5263.2505 - mean_absolute_error: 12.8535 - 5s/epoch - 10ms/step
# Epoch 251/300
# 528/528 - 5s - loss: 5285.4722 - mean_squared_error: 5285.4756 - mean_absolute_error: 13.0142 - 5s/epoch - 10ms/step
# Epoch 252/300
# 528/528 - 5s - loss: 5205.5200 - mean_squared_error: 5205.5186 - mean_absolute_error: 12.9691 - 5s/epoch - 10ms/step
# Epoch 253/300
# 528/528 - 5s - loss: 5128.6836 - mean_squared_error: 5128.6846 - mean_absolute_error: 13.0916 - 5s/epoch - 10ms/step
# Epoch 254/300
# 528/528 - 5s - loss: 5073.5645 - mean_squared_error: 5073.5635 - mean_absolute_error: 12.8804 - 5s/epoch - 10ms/step
# Epoch 255/300
# 528/528 - 5s - loss: 5090.3081 - mean_squared_error: 5090.3125 - mean_absolute_error: 12.9808 - 5s/epoch - 10ms/step
# Epoch 256/300
# 528/528 - 5s - loss: 5154.3398 - mean_squared_error: 5154.3384 - mean_absolute_error: 13.1536 - 5s/epoch - 10ms/step
# Epoch 257/300
# 528/528 - 5s - loss: 5224.6694 - mean_squared_error: 5224.6660 - mean_absolute_error: 13.7346 - 5s/epoch - 10ms/step
# Epoch 258/300
# 528/528 - 5s - loss: 5095.7197 - mean_squared_error: 5095.7178 - mean_absolute_error: 13.1899 - 5s/epoch - 10ms/step
# Epoch 259/300
# 528/528 - 5s - loss: 5091.5767 - mean_squared_error: 5091.5762 - mean_absolute_error: 12.8698 - 5s/epoch - 10ms/step
# Epoch 260/300
# 528/528 - 6s - loss: 5085.1460 - mean_squared_error: 5085.1421 - mean_absolute_error: 13.2525 - 6s/epoch - 10ms/step
# Epoch 261/300
# 528/528 - 5s - loss: 5043.6675 - mean_squared_error: 5043.6675 - mean_absolute_error: 12.8936 - 5s/epoch - 10ms/step
# Epoch 262/300
# 528/528 - 5s - loss: 5167.6426 - mean_squared_error: 5167.6431 - mean_absolute_error: 13.3269 - 5s/epoch - 10ms/step
# Epoch 263/300
# 528/528 - 5s - loss: 5134.0396 - mean_squared_error: 5134.0396 - mean_absolute_error: 12.9991 - 5s/epoch - 10ms/step
# Epoch 264/300
# 528/528 - 5s - loss: 5147.7964 - mean_squared_error: 5147.8003 - mean_absolute_error: 13.2298 - 5s/epoch - 10ms/step
# Epoch 265/300
# 528/528 - 5s - loss: 5141.2881 - mean_squared_error: 5141.2920 - mean_absolute_error: 14.0063 - 5s/epoch - 10ms/step
# Epoch 266/300
# 528/528 - 5s - loss: 5024.3242 - mean_squared_error: 5024.3228 - mean_absolute_error: 12.9141 - 5s/epoch - 10ms/step
# Epoch 267/300
# 528/528 - 5s - loss: 5014.0063 - mean_squared_error: 5014.0103 - mean_absolute_error: 12.8661 - 5s/epoch - 10ms/step
# Epoch 268/300
# 528/528 - 5s - loss: 5080.5161 - mean_squared_error: 5080.5137 - mean_absolute_error: 13.1768 - 5s/epoch - 10ms/step
# Epoch 269/300
# 528/528 - 5s - loss: 4988.4814 - mean_squared_error: 4988.4810 - mean_absolute_error: 12.8198 - 5s/epoch - 10ms/step
# Epoch 270/300
# 528/528 - 5s - loss: 5069.8696 - mean_squared_error: 5069.8677 - mean_absolute_error: 13.4019 - 5s/epoch - 10ms/step
# Epoch 271/300
# 528/528 - 5s - loss: 5102.1353 - mean_squared_error: 5102.1367 - mean_absolute_error: 12.6241 - 5s/epoch - 10ms/step
# Epoch 272/300
# 528/528 - 5s - loss: 5099.8457 - mean_squared_error: 5099.8442 - mean_absolute_error: 13.0183 - 5s/epoch - 10ms/step
# Epoch 273/300
# 528/528 - 5s - loss: 5061.1226 - mean_squared_error: 5061.1196 - mean_absolute_error: 13.0576 - 5s/epoch - 10ms/step
# Epoch 274/300
# 528/528 - 5s - loss: 5008.3247 - mean_squared_error: 5008.3252 - mean_absolute_error: 12.7568 - 5s/epoch - 10ms/step
# Epoch 275/300
# 528/528 - 5s - loss: 5044.1138 - mean_squared_error: 5044.1162 - mean_absolute_error: 12.9983 - 5s/epoch - 10ms/step
# Epoch 276/300
# 528/528 - 5s - loss: 5050.0098 - mean_squared_error: 5050.0073 - mean_absolute_error: 13.0746 - 5s/epoch - 10ms/step
# Epoch 277/300
# 528/528 - 5s - loss: 5111.5327 - mean_squared_error: 5111.5322 - mean_absolute_error: 13.0955 - 5s/epoch - 10ms/step
# Epoch 278/300
# 528/528 - 5s - loss: 5086.0137 - mean_squared_error: 5086.0176 - mean_absolute_error: 13.1131 - 5s/epoch - 10ms/step
# Epoch 279/300
# 528/528 - 5s - loss: 5057.5601 - mean_squared_error: 5057.5581 - mean_absolute_error: 13.1642 - 5s/epoch - 10ms/step
# Epoch 280/300
# 528/528 - 5s - loss: 5013.5312 - mean_squared_error: 5013.5322 - mean_absolute_error: 13.2435 - 5s/epoch - 10ms/step
# Epoch 281/300
# 528/528 - 5s - loss: 5341.5640 - mean_squared_error: 5341.5698 - mean_absolute_error: 13.5362 - 5s/epoch - 10ms/step
# Epoch 282/300
# 528/528 - 5s - loss: 5144.9512 - mean_squared_error: 5144.9517 - mean_absolute_error: 13.4380 - 5s/epoch - 10ms/step
# Epoch 283/300
# 528/528 - 5s - loss: 5047.8926 - mean_squared_error: 5047.8911 - mean_absolute_error: 13.0204 - 5s/epoch - 10ms/step
# Epoch 284/300
# 528/528 - 5s - loss: 5004.8711 - mean_squared_error: 5004.8740 - mean_absolute_error: 13.1568 - 5s/epoch - 10ms/step
# Epoch 285/300
# 528/528 - 5s - loss: 4961.0562 - mean_squared_error: 4961.0601 - mean_absolute_error: 12.7008 - 5s/epoch - 10ms/step
# Epoch 286/300
# 528/528 - 5s - loss: 5009.2729 - mean_squared_error: 5009.2700 - mean_absolute_error: 12.8847 - 5s/epoch - 10ms/step
# Epoch 287/300
# 528/528 - 5s - loss: 5010.0503 - mean_squared_error: 5010.0513 - mean_absolute_error: 13.2235 - 5s/epoch - 10ms/step
# Epoch 288/300
# 528/528 - 5s - loss: 5006.2354 - mean_squared_error: 5006.2324 - mean_absolute_error: 12.9420 - 5s/epoch - 10ms/step
# Epoch 289/300
# 528/528 - 5s - loss: 5005.3555 - mean_squared_error: 5005.3530 - mean_absolute_error: 12.6787 - 5s/epoch - 10ms/step
# Epoch 290/300
# 528/528 - 5s - loss: 4977.5332 - mean_squared_error: 4977.5352 - mean_absolute_error: 12.8473 - 5s/epoch - 10ms/step
# Epoch 291/300
# 528/528 - 5s - loss: 5032.0576 - mean_squared_error: 5032.0586 - mean_absolute_error: 12.8611 - 5s/epoch - 10ms/step
# Epoch 292/300
# 528/528 - 5s - loss: 4942.6138 - mean_squared_error: 4942.6182 - mean_absolute_error: 12.5789 - 5s/epoch - 10ms/step
# Epoch 293/300
# 528/528 - 5s - loss: 4898.3286 - mean_squared_error: 4898.3286 - mean_absolute_error: 12.6541 - 5s/epoch - 10ms/step
# Epoch 294/300
# 528/528 - 5s - loss: 4961.8774 - mean_squared_error: 4961.8770 - mean_absolute_error: 12.7718 - 5s/epoch - 10ms/step
# Epoch 295/300
# 528/528 - 5s - loss: 4953.8276 - mean_squared_error: 4953.8281 - mean_absolute_error: 13.0397 - 5s/epoch - 10ms/step
# Epoch 296/300
# 528/528 - 5s - loss: 4949.1377 - mean_squared_error: 4949.1367 - mean_absolute_error: 12.7643 - 5s/epoch - 10ms/step
# Epoch 297/300
# 528/528 - 5s - loss: 4903.8926 - mean_squared_error: 4903.8916 - mean_absolute_error: 12.6312 - 5s/epoch - 10ms/step
# Epoch 298/300
# 528/528 - 5s - loss: 4953.5186 - mean_squared_error: 4953.5161 - mean_absolute_error: 12.6760 - 5s/epoch - 10ms/step
# Epoch 299/300
# 528/528 - 5s - loss: 5013.7051 - mean_squared_error: 5013.7080 - mean_absolute_error: 12.7471 - 5s/epoch - 10ms/step
# Epoch 300/300
# 528/528 - 6s - loss: 4984.0303 - mean_squared_error: 4984.0352 - mean_absolute_error: 12.7012 - val_loss: 5274.9390 - val_mean_squared_error: 5274.9399 - val_mean_absolute_error: 12.8749 - 6s/epoch - 11ms/step

# %% [markdown]
# ##### Step 7 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model1.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model1.evaluate(X_test, Y_test)
print("hello")
# Out:
# -------------------- Model Summary --------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking_3 (Masking)         (None, 10, 1)             0
#
#  Input-Layer (InputLayer)    multiple                  0
#
#  conv1d_1 (Conv1D)           (None, 10, 128)           256
#
#  max_pooling1d_1 (MaxPooling  (None, 10, 128)          0
#  1D)
#
#  lstm_4 (LSTM)               (None, 10, 64)            49408
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            65
#  ed)
#
# =================================================================
# Total params: 49,729
# Trainable params: 49,729
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 4984.0302734375
# Final mean_squared_error : 4984.03515625
# Final mean_absolute_error : 12.701224327087402
# Final val_loss : 5274.93896484375
# Final val_mean_squared_error : 5274.93994140625
# Final val_mean_absolute_error : 12.874884605407715
#
# -------------------- Evaluation on Test Data --------------------
# 165/165 [==============================] - 1s 6ms/step - loss: 4789.2808 - mean_squared_error: 4789.2803 - mean_absolute_error: 12.0479
# hello

# %%
model2 = Sequential(name="LSTM-Model") # Model
model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=5, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/5
# 528/528 - 11s - loss: 1551.5193 - mean_squared_error: 1551.5190 - mean_absolute_error: 5.3852 - 11s/epoch - 21ms/step
# Epoch 2/5
# 528/528 - 11s - loss: 1208.0607 - mean_squared_error: 1208.0616 - mean_absolute_error: 4.6873 - 11s/epoch - 21ms/step
# Epoch 3/5
# 528/528 - 11s - loss: 1059.5234 - mean_squared_error: 1059.5239 - mean_absolute_error: 4.5962 - 11s/epoch - 21ms/step
# Epoch 4/5
# 528/528 - 11s - loss: 1044.7584 - mean_squared_error: 1044.7579 - mean_absolute_error: 4.5511 - 11s/epoch - 22ms/step
# Epoch 5/5
# 528/528 - 11s - loss: 933.6141 - mean_squared_error: 933.6136 - mean_absolute_error: 4.1693 - 11s/epoch - 21ms/step

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = hist["mean_squared_error"]

plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\DSFellowship\LSTMquickmodel.ipynb Cell 19 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=11'>12</a>   # Specifically gather the model's root mean
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=12'>13</a>   # squared error at each epoch.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=13'>14</a> rmse = hist["mean_squared_error"]
# ---> <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=15'>16</a> plot_the_model(trained_weight, trained_bias, X_test, Y_train)
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=16'>17</a> plot_the_loss_curve(epochs, rmse)
#
# e:\DSFellowship\LSTMquickmodel.ipynb Cell 19 in plot_the_model(trained_weight, trained_bias, feature, label)
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=6'>7</a> plt.ylabel("label")
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=8'>9</a> # Plot the feature values vs. label values.
# ---> <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=9'>10</a> plt.scatter(feature, label)
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=11'>12</a> # Create a red line representing the model. The red line starts
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=12'>13</a> # at coordinates (x0, y0) and ends at coordinates (x1, y1).
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/LSTMquickmodel.ipynb#ch0000022?line=13'>14</a> x0 = 0
#
# File c:\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2819, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2814 @_copy_docstring_and_deprecators(Axes.scatter)
#    2815 def scatter(
#    2816         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2817         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2818         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2819     __ret = gca().scatter(
#    2820         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2821         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2822         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2823         **({"data": data} if data is not None else {}), **kwargs)
#    2824     sci(__ret)
#    2825     return __ret
#
# File c:\Python\Python310\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File c:\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:4362, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4360 y = np.ma.ravel(y)
#    4361 if x.size != y.size:
# -> 4362     raise ValueError("x and y must be the same size")
#    4364 if s is None:
#    4365     s = (20 if rcParams['_internal.classic_mode'] else
#    4366          rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
##### Step 7 - Print Performance Summary
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking_4 (Masking)         (None, 10, 1)             0
#
#  Input-Layer (InputLayer)    multiple                  0
#
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              33792
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 10, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 10, 128)          98816
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            129
#  ed)
#
# =================================================================
# Total params: 132,737
# Trainable params: 132,737
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 936.23876953125
# Final mean_squared_error : 936.2389526367188
# Final mean_absolute_error : 4.137974262237549
# Final val_loss : 3768.924560546875
# Final val_mean_squared_error : 3768.9228515625
# Final val_mean_absolute_error : 7.377276420593262
#
# -------------------- Evaluation on Test Data --------------------
# 165/165 [==============================] - 2s 9ms/step - loss: 2843.0449 - mean_squared_error: 2843.0439 - mean_absolute_error: 5.9674

# %%
model3 = Sequential(name="LSTM-Model") # Model
model3.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model3.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model3.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))

#model3.add(LSTM(units=64, recurrent_activation='sigmoid', activation='relu',stateful=False, return_sequences=True))
#model.add(LSTM(units=50, activation='relu'), name='Hidden-LSTM-Encoder-Layer') # Encoder Layer
model3.add(TimeDistributed(Dense(units=1), name='Output-Layer')) # Output Layer, Linear(x) = x
model3.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
history = model3.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=300, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/300
# 528/528 - 9s - loss: 5978.6934 - mean_squared_error: 9132.5645 - mean_absolute_error: 14.9580 - 9s/epoch - 17ms/step
# Epoch 2/300
# 528/528 - 5s - loss: 5932.4487 - mean_squared_error: 9061.9131 - mean_absolute_error: 17.2340 - 5s/epoch - 9ms/step
# Epoch 3/300
# 528/528 - 5s - loss: 5891.8936 - mean_squared_error: 8999.9736 - mean_absolute_error: 17.7861 - 5s/epoch - 9ms/step
# Epoch 4/300
# 528/528 - 5s - loss: 5819.0903 - mean_squared_error: 8888.7607 - mean_absolute_error: 17.9192 - 5s/epoch - 9ms/step
# Epoch 5/300
# 528/528 - 5s - loss: 5735.0005 - mean_squared_error: 8760.3145 - mean_absolute_error: 17.7632 - 5s/epoch - 9ms/step
# Epoch 6/300
# 528/528 - 5s - loss: 5616.0566 - mean_squared_error: 8578.6260 - mean_absolute_error: 17.6352 - 5s/epoch - 9ms/step
# Epoch 7/300
# 528/528 - 5s - loss: 5510.0542 - mean_squared_error: 8416.7148 - mean_absolute_error: 17.6336 - 5s/epoch - 9ms/step
# Epoch 8/300
# 528/528 - 5s - loss: 5436.4634 - mean_squared_error: 8304.2949 - mean_absolute_error: 17.5343 - 5s/epoch - 9ms/step
# Epoch 9/300
# 528/528 - 5s - loss: 5366.9131 - mean_squared_error: 8198.0557 - mean_absolute_error: 17.6343 - 5s/epoch - 10ms/step
# Epoch 10/300
# 528/528 - 5s - loss: 5214.5503 - mean_squared_error: 7965.3135 - mean_absolute_error: 17.6702 - 5s/epoch - 9ms/step
# Epoch 11/300
# 528/528 - 5s - loss: 5237.1055 - mean_squared_error: 7999.7700 - mean_absolute_error: 17.4307 - 5s/epoch - 10ms/step
# Epoch 12/300
# 528/528 - 5s - loss: 5228.9590 - mean_squared_error: 7987.3281 - mean_absolute_error: 17.2250 - 5s/epoch - 9ms/step
# Epoch 13/300
# 528/528 - 5s - loss: 5040.3574 - mean_squared_error: 7699.2383 - mean_absolute_error: 16.9867 - 5s/epoch - 9ms/step
# Epoch 14/300
# 528/528 - 5s - loss: 5131.8496 - mean_squared_error: 7838.9912 - mean_absolute_error: 16.8963 - 5s/epoch - 9ms/step
# Epoch 15/300
# 528/528 - 5s - loss: 5108.4331 - mean_squared_error: 7803.2197 - mean_absolute_error: 16.8165 - 5s/epoch - 9ms/step
# Epoch 16/300
# 528/528 - 5s - loss: 4959.8291 - mean_squared_error: 7576.2202 - mean_absolute_error: 16.6580 - 5s/epoch - 9ms/step
# Epoch 17/300
# 528/528 - 5s - loss: 4964.9585 - mean_squared_error: 7584.0581 - mean_absolute_error: 16.4540 - 5s/epoch - 9ms/step
# Epoch 18/300
# 528/528 - 5s - loss: 4875.2100 - mean_squared_error: 7446.9751 - mean_absolute_error: 16.1953 - 5s/epoch - 9ms/step
# Epoch 19/300
# 528/528 - 5s - loss: 4854.6519 - mean_squared_error: 7415.5728 - mean_absolute_error: 16.0120 - 5s/epoch - 9ms/step
# Epoch 20/300
# 528/528 - 5s - loss: 4890.9590 - mean_squared_error: 7471.0273 - mean_absolute_error: 16.3057 - 5s/epoch - 9ms/step
# Epoch 21/300
# 528/528 - 5s - loss: 4757.1362 - mean_squared_error: 7266.6064 - mean_absolute_error: 15.8591 - 5s/epoch - 9ms/step
# Epoch 22/300
# 528/528 - 5s - loss: 4825.8062 - mean_squared_error: 7371.5107 - mean_absolute_error: 15.9926 - 5s/epoch - 9ms/step
# Epoch 23/300
# 528/528 - 5s - loss: 4768.6284 - mean_squared_error: 7284.1621 - mean_absolute_error: 15.6351 - 5s/epoch - 10ms/step
# Epoch 24/300
# 528/528 - 5s - loss: 4843.1060 - mean_squared_error: 7397.9375 - mean_absolute_error: 15.8849 - 5s/epoch - 9ms/step
# Epoch 25/300
# 528/528 - 5s - loss: 4728.0806 - mean_squared_error: 7222.2246 - mean_absolute_error: 15.6127 - 5s/epoch - 10ms/step
# Epoch 26/300
# 528/528 - 5s - loss: 4716.8467 - mean_squared_error: 7205.0601 - mean_absolute_error: 15.5176 - 5s/epoch - 10ms/step
# Epoch 27/300
# 528/528 - 5s - loss: 4729.9160 - mean_squared_error: 7225.0337 - mean_absolute_error: 15.5393 - 5s/epoch - 10ms/step
# Epoch 28/300
# 528/528 - 5s - loss: 4709.3433 - mean_squared_error: 7193.6064 - mean_absolute_error: 15.6122 - 5s/epoch - 10ms/step
# Epoch 29/300
# 528/528 - 5s - loss: 4773.8594 - mean_squared_error: 7292.1572 - mean_absolute_error: 15.6371 - 5s/epoch - 10ms/step
# Epoch 30/300
# 528/528 - 5s - loss: 4668.6509 - mean_squared_error: 7131.4453 - mean_absolute_error: 15.5142 - 5s/epoch - 9ms/step
# Epoch 31/300
# 528/528 - 5s - loss: 4677.3584 - mean_squared_error: 7144.7520 - mean_absolute_error: 15.8126 - 5s/epoch - 9ms/step
# Epoch 32/300
# 528/528 - 5s - loss: 4648.3984 - mean_squared_error: 7100.5073 - mean_absolute_error: 15.5758 - 5s/epoch - 9ms/step
# Epoch 33/300
# 528/528 - 5s - loss: 4625.3145 - mean_squared_error: 7065.2451 - mean_absolute_error: 15.3919 - 5s/epoch - 9ms/step
# Epoch 34/300
# 528/528 - 5s - loss: 4593.6323 - mean_squared_error: 7016.8555 - mean_absolute_error: 15.5141 - 5s/epoch - 9ms/step
# Epoch 35/300
# 528/528 - 5s - loss: 4542.5288 - mean_squared_error: 6938.7959 - mean_absolute_error: 15.4352 - 5s/epoch - 10ms/step
# Epoch 36/300
# 528/528 - 5s - loss: 4613.0615 - mean_squared_error: 7046.5342 - mean_absolute_error: 15.4721 - 5s/epoch - 9ms/step
# Epoch 37/300
# 528/528 - 5s - loss: 4520.6689 - mean_squared_error: 6905.4033 - mean_absolute_error: 15.3384 - 5s/epoch - 9ms/step
# Epoch 38/300
# 528/528 - 5s - loss: 4637.7866 - mean_squared_error: 7084.3018 - mean_absolute_error: 15.5635 - 5s/epoch - 9ms/step
# Epoch 39/300
# 528/528 - 5s - loss: 4515.7930 - mean_squared_error: 6897.9556 - mean_absolute_error: 15.2940 - 5s/epoch - 9ms/step
# Epoch 40/300
# 528/528 - 5s - loss: 4570.6885 - mean_squared_error: 6981.8105 - mean_absolute_error: 15.3730 - 5s/epoch - 9ms/step
# Epoch 41/300
# 528/528 - 5s - loss: 4528.6440 - mean_squared_error: 6917.5884 - mean_absolute_error: 15.4150 - 5s/epoch - 9ms/step
# Epoch 42/300
# 528/528 - 5s - loss: 4530.7285 - mean_squared_error: 6920.7622 - mean_absolute_error: 15.2624 - 5s/epoch - 9ms/step
# Epoch 43/300
# 528/528 - 5s - loss: 4551.5952 - mean_squared_error: 6952.6421 - mean_absolute_error: 15.7661 - 5s/epoch - 9ms/step
# Epoch 44/300
# 528/528 - 5s - loss: 4612.4268 - mean_squared_error: 7045.5649 - mean_absolute_error: 15.5497 - 5s/epoch - 9ms/step
# Epoch 45/300
# 528/528 - 5s - loss: 4495.5386 - mean_squared_error: 6867.0151 - mean_absolute_error: 15.3963 - 5s/epoch - 9ms/step
# Epoch 46/300
# 528/528 - 5s - loss: 4498.4961 - mean_squared_error: 6871.5317 - mean_absolute_error: 15.3535 - 5s/epoch - 9ms/step
# Epoch 47/300
# 528/528 - 5s - loss: 4421.3931 - mean_squared_error: 6753.7534 - mean_absolute_error: 15.2864 - 5s/epoch - 9ms/step
# Epoch 48/300
# 528/528 - 5s - loss: 4521.0830 - mean_squared_error: 6906.0264 - mean_absolute_error: 14.9105 - 5s/epoch - 10ms/step
# Epoch 49/300
# 528/528 - 5s - loss: 4604.8823 - mean_squared_error: 7034.0361 - mean_absolute_error: 15.3535 - 5s/epoch - 9ms/step
# Epoch 50/300
# 528/528 - 5s - loss: 4497.3242 - mean_squared_error: 6869.7378 - mean_absolute_error: 15.7560 - 5s/epoch - 9ms/step
# Epoch 51/300
# 528/528 - 5s - loss: 4685.7646 - mean_squared_error: 7157.5942 - mean_absolute_error: 15.8416 - 5s/epoch - 9ms/step
# Epoch 52/300
# 528/528 - 5s - loss: 4562.0806 - mean_squared_error: 6968.6621 - mean_absolute_error: 15.4768 - 5s/epoch - 9ms/step
# Epoch 53/300
# 528/528 - 5s - loss: 4483.5278 - mean_squared_error: 6848.6655 - mean_absolute_error: 15.5123 - 5s/epoch - 9ms/step
# Epoch 54/300
# 528/528 - 5s - loss: 4442.3779 - mean_squared_error: 6785.8071 - mean_absolute_error: 15.4644 - 5s/epoch - 9ms/step
# Epoch 55/300
# 528/528 - 5s - loss: 4371.4048 - mean_squared_error: 6677.3901 - mean_absolute_error: 15.1646 - 5s/epoch - 9ms/step
# Epoch 56/300
# 528/528 - 5s - loss: 4384.9360 - mean_squared_error: 6698.0674 - mean_absolute_error: 15.1144 - 5s/epoch - 10ms/step
# Epoch 57/300
# 528/528 - 5s - loss: 4348.3857 - mean_squared_error: 6642.2363 - mean_absolute_error: 15.2080 - 5s/epoch - 9ms/step
# Epoch 58/300
# 528/528 - 5s - loss: 4338.4277 - mean_squared_error: 6627.0190 - mean_absolute_error: 15.3058 - 5s/epoch - 9ms/step
# Epoch 59/300
# 528/528 - 5s - loss: 4381.3286 - mean_squared_error: 6692.5562 - mean_absolute_error: 15.2939 - 5s/epoch - 9ms/step
# Epoch 60/300
# 528/528 - 5s - loss: 4280.5679 - mean_squared_error: 6538.6416 - mean_absolute_error: 15.0032 - 5s/epoch - 10ms/step
# Epoch 61/300
# 528/528 - 5s - loss: 4338.8569 - mean_squared_error: 6627.6777 - mean_absolute_error: 15.3323 - 5s/epoch - 10ms/step
# Epoch 62/300
# 528/528 - 5s - loss: 4303.4404 - mean_squared_error: 6573.5796 - mean_absolute_error: 15.2788 - 5s/epoch - 10ms/step
# Epoch 63/300
# 528/528 - 5s - loss: 4352.5537 - mean_squared_error: 6648.6045 - mean_absolute_error: 15.2200 - 5s/epoch - 9ms/step
# Epoch 64/300
# 528/528 - 5s - loss: 4208.8521 - mean_squared_error: 6429.0918 - mean_absolute_error: 14.8801 - 5s/epoch - 9ms/step
# Epoch 65/300
# 528/528 - 5s - loss: 4231.5972 - mean_squared_error: 6463.8413 - mean_absolute_error: 15.0236 - 5s/epoch - 9ms/step
# Epoch 66/300
# 528/528 - 5s - loss: 4149.8350 - mean_squared_error: 6338.9453 - mean_absolute_error: 14.8263 - 5s/epoch - 9ms/step
# Epoch 67/300
# 528/528 - 5s - loss: 4255.2686 - mean_squared_error: 6499.9976 - mean_absolute_error: 15.1180 - 5s/epoch - 9ms/step
# Epoch 68/300
# 528/528 - 5s - loss: 4262.8296 - mean_squared_error: 6511.5474 - mean_absolute_error: 15.3863 - 5s/epoch - 9ms/step
# Epoch 69/300
# 528/528 - 5s - loss: 4191.2114 - mean_squared_error: 6402.1479 - mean_absolute_error: 15.1013 - 5s/epoch - 10ms/step
# Epoch 70/300
# 528/528 - 5s - loss: 4269.4136 - mean_squared_error: 6521.6001 - mean_absolute_error: 15.0080 - 5s/epoch - 9ms/step
# Epoch 71/300
# 528/528 - 5s - loss: 4195.9360 - mean_squared_error: 6409.3677 - mean_absolute_error: 15.3090 - 5s/epoch - 10ms/step
# Epoch 72/300
# 528/528 - 5s - loss: 4214.5122 - mean_squared_error: 6437.7432 - mean_absolute_error: 15.3769 - 5s/epoch - 9ms/step
# Epoch 73/300
# 528/528 - 5s - loss: 4042.5911 - mean_squared_error: 6175.1318 - mean_absolute_error: 14.8859 - 5s/epoch - 10ms/step
# Epoch 74/300
# 528/528 - 5s - loss: 4484.1899 - mean_squared_error: 6849.6738 - mean_absolute_error: 14.9088 - 5s/epoch - 9ms/step
# Epoch 75/300
# 528/528 - 5s - loss: 4280.0137 - mean_squared_error: 6537.7969 - mean_absolute_error: 14.7637 - 5s/epoch - 9ms/step
# Epoch 76/300
# 528/528 - 5s - loss: 4190.8125 - mean_squared_error: 6401.5396 - mean_absolute_error: 15.2330 - 5s/epoch - 9ms/step
# Epoch 77/300
# 528/528 - 5s - loss: 4141.8418 - mean_squared_error: 6326.7349 - mean_absolute_error: 14.9494 - 5s/epoch - 9ms/step
# Epoch 78/300
# 528/528 - 5s - loss: 4147.8042 - mean_squared_error: 6335.8379 - mean_absolute_error: 15.2346 - 5s/epoch - 9ms/step
# Epoch 79/300
# 528/528 - 5s - loss: 4324.8242 - mean_squared_error: 6606.2476 - mean_absolute_error: 15.5577 - 5s/epoch - 9ms/step
# Epoch 80/300
# 528/528 - 5s - loss: 4269.6875 - mean_squared_error: 6522.0244 - mean_absolute_error: 15.2868 - 5s/epoch - 9ms/step
# Epoch 81/300
# 528/528 - 5s - loss: 4024.5664 - mean_squared_error: 6147.5991 - mean_absolute_error: 14.8481 - 5s/epoch - 9ms/step
# Epoch 82/300
# 528/528 - 5s - loss: 4218.3818 - mean_squared_error: 6443.6543 - mean_absolute_error: 15.0525 - 5s/epoch - 9ms/step
# Epoch 83/300
# 528/528 - 5s - loss: 4093.3450 - mean_squared_error: 6252.6548 - mean_absolute_error: 15.0006 - 5s/epoch - 10ms/step
# Epoch 84/300
# 528/528 - 5s - loss: 4048.2988 - mean_squared_error: 6183.8438 - mean_absolute_error: 14.7308 - 5s/epoch - 10ms/step
# Epoch 85/300
# 528/528 - 5s - loss: 3957.4597 - mean_squared_error: 6045.0908 - mean_absolute_error: 14.9175 - 5s/epoch - 10ms/step
# Epoch 86/300
# 528/528 - 5s - loss: 3957.4565 - mean_squared_error: 6045.0864 - mean_absolute_error: 14.7462 - 5s/epoch - 9ms/step
# Epoch 87/300
# 528/528 - 5s - loss: 3991.2917 - mean_squared_error: 6096.7690 - mean_absolute_error: 14.7657 - 5s/epoch - 9ms/step
# Epoch 88/300
# 528/528 - 5s - loss: 4078.0447 - mean_squared_error: 6229.2817 - mean_absolute_error: 14.7455 - 5s/epoch - 10ms/step
# Epoch 89/300
# 528/528 - 5s - loss: 4015.2278 - mean_squared_error: 6133.3291 - mean_absolute_error: 14.5866 - 5s/epoch - 9ms/step
# Epoch 90/300
# 528/528 - 5s - loss: 4072.3838 - mean_squared_error: 6220.6372 - mean_absolute_error: 14.8073 - 5s/epoch - 10ms/step
# Epoch 91/300
# 528/528 - 5s - loss: 3959.7815 - mean_squared_error: 6048.6421 - mean_absolute_error: 14.6173 - 5s/epoch - 9ms/step
# Epoch 92/300
# 528/528 - 5s - loss: 3909.8059 - mean_squared_error: 5972.2964 - mean_absolute_error: 14.4324 - 5s/epoch - 9ms/step
# Epoch 93/300
# 528/528 - 5s - loss: 4025.2520 - mean_squared_error: 6148.6475 - mean_absolute_error: 14.9143 - 5s/epoch - 9ms/step
# Epoch 94/300
# 528/528 - 5s - loss: 3956.7437 - mean_squared_error: 6043.9956 - mean_absolute_error: 14.6094 - 5s/epoch - 9ms/step
# Epoch 95/300
# 528/528 - 5s - loss: 4065.0374 - mean_squared_error: 6209.4175 - mean_absolute_error: 14.5514 - 5s/epoch - 9ms/step
# Epoch 96/300
# 528/528 - 5s - loss: 4027.5835 - mean_squared_error: 6152.2114 - mean_absolute_error: 14.5512 - 5s/epoch - 9ms/step
# Epoch 97/300
# 528/528 - 5s - loss: 3882.5012 - mean_squared_error: 5930.5898 - mean_absolute_error: 14.5131 - 5s/epoch - 9ms/step
# Epoch 98/300
# 528/528 - 5s - loss: 3999.4756 - mean_squared_error: 6109.2671 - mean_absolute_error: 14.7108 - 5s/epoch - 10ms/step
# Epoch 99/300
# 528/528 - 5s - loss: 4001.2334 - mean_squared_error: 6111.9556 - mean_absolute_error: 14.7233 - 5s/epoch - 9ms/step
# Epoch 100/300
# 528/528 - 7s - loss: 4054.4629 - mean_squared_error: 6193.2666 - mean_absolute_error: 14.6334 - val_loss: 5072.4155 - val_mean_squared_error: 7548.1187 - val_mean_absolute_error: 16.4296 - 7s/epoch - 13ms/step
# Epoch 101/300
# 528/528 - 6s - loss: 4084.6738 - mean_squared_error: 6239.4092 - mean_absolute_error: 14.8915 - 6s/epoch - 10ms/step
# Epoch 102/300
# 528/528 - 5s - loss: 3908.9292 - mean_squared_error: 5970.9541 - mean_absolute_error: 14.5669 - 5s/epoch - 10ms/step
# Epoch 103/300
# 528/528 - 5s - loss: 3825.1018 - mean_squared_error: 5842.9116 - mean_absolute_error: 14.4906 - 5s/epoch - 10ms/step
# Epoch 104/300
# 528/528 - 6s - loss: 3938.0989 - mean_squared_error: 6015.5132 - mean_absolute_error: 14.3163 - 6s/epoch - 11ms/step
# Epoch 105/300
# 528/528 - 6s - loss: 3869.2686 - mean_squared_error: 5910.3745 - mean_absolute_error: 14.6167 - 6s/epoch - 11ms/step
# Epoch 106/300
# 528/528 - 6s - loss: 3839.8198 - mean_squared_error: 5865.3975 - mean_absolute_error: 14.6179 - 6s/epoch - 11ms/step
# Epoch 107/300
# 528/528 - 5s - loss: 3903.0391 - mean_squared_error: 5961.9580 - mean_absolute_error: 14.6107 - 5s/epoch - 10ms/step
# Epoch 108/300
# 528/528 - 5s - loss: 4108.1372 - mean_squared_error: 6275.2539 - mean_absolute_error: 14.8893 - 5s/epoch - 10ms/step
# Epoch 109/300
# 528/528 - 6s - loss: 3900.7981 - mean_squared_error: 5958.5342 - mean_absolute_error: 14.4604 - 6s/epoch - 10ms/step
# Epoch 110/300
# 528/528 - 5s - loss: 3823.9207 - mean_squared_error: 5841.1045 - mean_absolute_error: 14.3225 - 5s/epoch - 10ms/step
# Epoch 111/300
# 528/528 - 5s - loss: 4003.1624 - mean_squared_error: 6114.9028 - mean_absolute_error: 15.0410 - 5s/epoch - 9ms/step
# Epoch 112/300
# 528/528 - 5s - loss: 3868.5862 - mean_squared_error: 5909.3335 - mean_absolute_error: 14.4506 - 5s/epoch - 9ms/step
# Epoch 113/300
# 528/528 - 5s - loss: 3828.5039 - mean_squared_error: 5848.1079 - mean_absolute_error: 14.5333 - 5s/epoch - 9ms/step
# Epoch 114/300
# 528/528 - 5s - loss: 3871.7141 - mean_squared_error: 5914.1099 - mean_absolute_error: 14.5681 - 5s/epoch - 10ms/step
# Epoch 115/300
# 528/528 - 5s - loss: 3801.4951 - mean_squared_error: 5806.8472 - mean_absolute_error: 14.5434 - 5s/epoch - 9ms/step
# Epoch 116/300
# 528/528 - 5s - loss: 4029.1697 - mean_squared_error: 6154.6274 - mean_absolute_error: 14.9878 - 5s/epoch - 9ms/step
# Epoch 117/300
# 528/528 - 5s - loss: 3986.3542 - mean_squared_error: 6089.2227 - mean_absolute_error: 14.8836 - 5s/epoch - 9ms/step
# Epoch 118/300
# 528/528 - 5s - loss: 3827.9033 - mean_squared_error: 5847.1895 - mean_absolute_error: 14.3334 - 5s/epoch - 9ms/step
# Epoch 119/300
# 528/528 - 5s - loss: 3865.1223 - mean_squared_error: 5904.0415 - mean_absolute_error: 14.4491 - 5s/epoch - 9ms/step
# Epoch 120/300
# 528/528 - 5s - loss: 3822.6052 - mean_squared_error: 5839.0903 - mean_absolute_error: 14.4692 - 5s/epoch - 9ms/step
# Epoch 121/300
# 528/528 - 5s - loss: 3868.1016 - mean_squared_error: 5908.5913 - mean_absolute_error: 14.5804 - 5s/epoch - 10ms/step
# Epoch 122/300
# 528/528 - 5s - loss: 3783.7141 - mean_squared_error: 5779.6860 - mean_absolute_error: 14.3835 - 5s/epoch - 9ms/step
# Epoch 123/300
# 528/528 - 5s - loss: 3839.6082 - mean_squared_error: 5865.0713 - mean_absolute_error: 14.4410 - 5s/epoch - 9ms/step
# Epoch 124/300
# 528/528 - 5s - loss: 4014.1062 - mean_squared_error: 6131.6216 - mean_absolute_error: 14.8523 - 5s/epoch - 10ms/step
# Epoch 125/300
# 528/528 - 5s - loss: 3918.3257 - mean_squared_error: 5985.3135 - mean_absolute_error: 14.4702 - 5s/epoch - 9ms/step
# Epoch 126/300
# 528/528 - 5s - loss: 3895.2170 - mean_squared_error: 5950.0146 - mean_absolute_error: 14.4101 - 5s/epoch - 10ms/step
# Epoch 127/300
# 528/528 - 5s - loss: 3767.1174 - mean_squared_error: 5754.3374 - mean_absolute_error: 14.3719 - 5s/epoch - 9ms/step
# Epoch 128/300
# 528/528 - 5s - loss: 3725.3821 - mean_squared_error: 5690.5854 - mean_absolute_error: 14.3078 - 5s/epoch - 9ms/step
# Epoch 129/300
# 528/528 - 5s - loss: 3720.7568 - mean_squared_error: 5683.5186 - mean_absolute_error: 14.1817 - 5s/epoch - 10ms/step
# Epoch 130/300
# 528/528 - 5s - loss: 3759.9746 - mean_squared_error: 5743.4292 - mean_absolute_error: 14.2096 - 5s/epoch - 9ms/step
# Epoch 131/300
# 528/528 - 5s - loss: 3890.2485 - mean_squared_error: 5942.4229 - mean_absolute_error: 14.7624 - 5s/epoch - 9ms/step
# Epoch 132/300
# 528/528 - 5s - loss: 4037.2332 - mean_squared_error: 6166.9419 - mean_absolute_error: 14.7040 - 5s/epoch - 9ms/step
# Epoch 133/300
# 528/528 - 5s - loss: 3827.9778 - mean_squared_error: 5847.3013 - mean_absolute_error: 14.8088 - 5s/epoch - 10ms/step
# Epoch 134/300
# 528/528 - 5s - loss: 3749.4673 - mean_squared_error: 5727.3799 - mean_absolute_error: 14.1943 - 5s/epoch - 9ms/step
# Epoch 135/300
# 528/528 - 5s - loss: 3794.0107 - mean_squared_error: 5795.4121 - mean_absolute_error: 14.2428 - 5s/epoch - 9ms/step
# Epoch 136/300
# 528/528 - 5s - loss: 3692.8738 - mean_squared_error: 5640.9258 - mean_absolute_error: 14.1290 - 5s/epoch - 9ms/step
# Epoch 137/300
# 528/528 - 5s - loss: 3749.5459 - mean_squared_error: 5727.4971 - mean_absolute_error: 14.4326 - 5s/epoch - 9ms/step
# Epoch 138/300
# 528/528 - 5s - loss: 3787.6069 - mean_squared_error: 5785.6338 - mean_absolute_error: 14.2620 - 5s/epoch - 9ms/step
# Epoch 139/300
# 528/528 - 5s - loss: 3704.4490 - mean_squared_error: 5658.6162 - mean_absolute_error: 14.1387 - 5s/epoch - 9ms/step
# Epoch 140/300
# 528/528 - 5s - loss: 3926.4414 - mean_squared_error: 5997.7148 - mean_absolute_error: 14.4036 - 5s/epoch - 9ms/step
# Epoch 141/300
# 528/528 - 5s - loss: 3729.8157 - mean_squared_error: 5697.3545 - mean_absolute_error: 13.8034 - 5s/epoch - 9ms/step
# Epoch 142/300
# 528/528 - 5s - loss: 3679.3127 - mean_squared_error: 5620.2158 - mean_absolute_error: 13.8508 - 5s/epoch - 10ms/step
# Epoch 143/300
# 528/528 - 5s - loss: 3660.6050 - mean_squared_error: 5591.6343 - mean_absolute_error: 13.9687 - 5s/epoch - 9ms/step
# Epoch 144/300
# 528/528 - 5s - loss: 3688.4333 - mean_squared_error: 5634.1509 - mean_absolute_error: 14.2151 - 5s/epoch - 10ms/step
# Epoch 145/300
# 528/528 - 5s - loss: 3822.1653 - mean_squared_error: 5838.4277 - mean_absolute_error: 14.2658 - 5s/epoch - 9ms/step
# Epoch 146/300
# 528/528 - 5s - loss: 3688.8301 - mean_squared_error: 5634.7568 - mean_absolute_error: 14.0958 - 5s/epoch - 9ms/step
# Epoch 147/300
# 528/528 - 5s - loss: 3729.2188 - mean_squared_error: 5696.4468 - mean_absolute_error: 14.1682 - 5s/epoch - 9ms/step
# Epoch 148/300
# 528/528 - 5s - loss: 4011.9141 - mean_squared_error: 6128.2686 - mean_absolute_error: 14.8129 - 5s/epoch - 9ms/step
# Epoch 149/300
# 528/528 - 5s - loss: 3773.4629 - mean_squared_error: 5764.0298 - mean_absolute_error: 14.7490 - 5s/epoch - 10ms/step
# Epoch 150/300
# 528/528 - 5s - loss: 3995.1448 - mean_squared_error: 6102.6567 - mean_absolute_error: 14.7343 - 5s/epoch - 10ms/step
# Epoch 151/300
# 528/528 - 5s - loss: 3809.0339 - mean_squared_error: 5818.3672 - mean_absolute_error: 14.7492 - 5s/epoch - 9ms/step
# Epoch 152/300
# 528/528 - 5s - loss: 3792.0081 - mean_squared_error: 5792.3584 - mean_absolute_error: 14.7634 - 5s/epoch - 9ms/step
# Epoch 153/300
# 528/528 - 5s - loss: 3830.0833 - mean_squared_error: 5850.5239 - mean_absolute_error: 14.5808 - 5s/epoch - 9ms/step
# Epoch 154/300
# 528/528 - 5s - loss: 3685.9861 - mean_squared_error: 5630.4072 - mean_absolute_error: 14.1689 - 5s/epoch - 9ms/step
# Epoch 155/300
# 528/528 - 5s - loss: 3657.5659 - mean_squared_error: 5586.9956 - mean_absolute_error: 14.3787 - 5s/epoch - 9ms/step
# Epoch 156/300
# 528/528 - 5s - loss: 3646.3237 - mean_squared_error: 5569.8257 - mean_absolute_error: 14.3502 - 5s/epoch - 9ms/step
# Epoch 157/300
# 528/528 - 5s - loss: 3644.5249 - mean_squared_error: 5567.0771 - mean_absolute_error: 14.2418 - 5s/epoch - 10ms/step
# Epoch 158/300
# 528/528 - 5s - loss: 3643.3237 - mean_squared_error: 5565.2412 - mean_absolute_error: 14.1363 - 5s/epoch - 9ms/step
# Epoch 159/300
# 528/528 - 5s - loss: 3697.0781 - mean_squared_error: 5647.3550 - mean_absolute_error: 14.0592 - 5s/epoch - 9ms/step
# Epoch 160/300
# 528/528 - 5s - loss: 3650.0017 - mean_squared_error: 5575.4414 - mean_absolute_error: 14.1627 - 5s/epoch - 9ms/step
# Epoch 161/300
# 528/528 - 5s - loss: 3677.2441 - mean_squared_error: 5617.0532 - mean_absolute_error: 14.2430 - 5s/epoch - 9ms/step
# Epoch 162/300
# 528/528 - 5s - loss: 3659.6699 - mean_squared_error: 5590.2085 - mean_absolute_error: 14.4307 - 5s/epoch - 9ms/step
# Epoch 163/300
# 528/528 - 5s - loss: 3613.3455 - mean_squared_error: 5519.4565 - mean_absolute_error: 14.2125 - 5s/epoch - 9ms/step
# Epoch 164/300
# 528/528 - 5s - loss: 3697.9058 - mean_squared_error: 5648.6177 - mean_absolute_error: 14.2052 - 5s/epoch - 10ms/step
# Epoch 165/300
# 528/528 - 5s - loss: 3575.7190 - mean_squared_error: 5461.9736 - mean_absolute_error: 14.0624 - 5s/epoch - 9ms/step
# Epoch 166/300
# 528/528 - 5s - loss: 3730.9778 - mean_squared_error: 5699.1313 - mean_absolute_error: 14.5424 - 5s/epoch - 9ms/step
# Epoch 167/300
# 528/528 - 5s - loss: 3655.3845 - mean_squared_error: 5583.6660 - mean_absolute_error: 14.2458 - 5s/epoch - 10ms/step
# Epoch 168/300
# 528/528 - 5s - loss: 3690.0469 - mean_squared_error: 5636.6138 - mean_absolute_error: 14.3915 - 5s/epoch - 9ms/step
# Epoch 169/300
# 528/528 - 5s - loss: 3619.3657 - mean_squared_error: 5528.6455 - mean_absolute_error: 14.3927 - 5s/epoch - 10ms/step
# Epoch 170/300
# 528/528 - 5s - loss: 3653.4072 - mean_squared_error: 5580.6445 - mean_absolute_error: 14.3783 - 5s/epoch - 9ms/step
# Epoch 171/300
# 528/528 - 5s - loss: 3606.8096 - mean_squared_error: 5509.4673 - mean_absolute_error: 13.9371 - 5s/epoch - 9ms/step
# Epoch 172/300
# 528/528 - 5s - loss: 3612.8462 - mean_squared_error: 5518.6870 - mean_absolute_error: 13.8204 - 5s/epoch - 9ms/step
# Epoch 173/300
# 528/528 - 5s - loss: 3518.2002 - mean_squared_error: 5374.1138 - mean_absolute_error: 13.7597 - 5s/epoch - 10ms/step
# Epoch 174/300
# 528/528 - 5s - loss: 3605.2285 - mean_squared_error: 5507.0547 - mean_absolute_error: 14.0064 - 5s/epoch - 9ms/step
# Epoch 175/300
# 528/528 - 5s - loss: 3636.6086 - mean_squared_error: 5554.9868 - mean_absolute_error: 14.3947 - 5s/epoch - 9ms/step
# Epoch 176/300
# 528/528 - 5s - loss: 3556.4058 - mean_squared_error: 5432.4756 - mean_absolute_error: 14.1509 - 5s/epoch - 9ms/step
# Epoch 177/300
# 528/528 - 5s - loss: 3731.6082 - mean_squared_error: 5700.0947 - mean_absolute_error: 14.5112 - 5s/epoch - 9ms/step
# Epoch 178/300
# 528/528 - 5s - loss: 3721.7908 - mean_squared_error: 5685.1060 - mean_absolute_error: 14.1847 - 5s/epoch - 10ms/step
# Epoch 179/300
# 528/528 - 5s - loss: 4135.4360 - mean_squared_error: 6316.9492 - mean_absolute_error: 16.0050 - 5s/epoch - 9ms/step
# Epoch 180/300
# 528/528 - 5s - loss: 3844.8013 - mean_squared_error: 5873.0034 - mean_absolute_error: 14.9285 - 5s/epoch - 10ms/step
# Epoch 181/300
# 528/528 - 5s - loss: 3791.4392 - mean_squared_error: 5791.4893 - mean_absolute_error: 14.6990 - 5s/epoch - 10ms/step
# Epoch 182/300
# 528/528 - 5s - loss: 3705.0581 - mean_squared_error: 5659.5454 - mean_absolute_error: 14.4072 - 5s/epoch - 9ms/step
# Epoch 183/300
# 528/528 - 5s - loss: 3613.4111 - mean_squared_error: 5519.5542 - mean_absolute_error: 14.2277 - 5s/epoch - 10ms/step
# Epoch 184/300
# 528/528 - 5s - loss: 3723.8162 - mean_squared_error: 5688.1982 - mean_absolute_error: 14.5515 - 5s/epoch - 9ms/step
# Epoch 185/300
# 528/528 - 5s - loss: 3786.6187 - mean_squared_error: 5784.1343 - mean_absolute_error: 14.3168 - 5s/epoch - 9ms/step
# Epoch 186/300
# 528/528 - 5s - loss: 3573.3118 - mean_squared_error: 5458.2954 - mean_absolute_error: 13.9718 - 5s/epoch - 10ms/step
# Epoch 187/300
# 528/528 - 5s - loss: 3613.5430 - mean_squared_error: 5519.7529 - mean_absolute_error: 14.4556 - 5s/epoch - 9ms/step
# Epoch 188/300
# 528/528 - 5s - loss: 3520.2966 - mean_squared_error: 5377.3135 - mean_absolute_error: 13.9774 - 5s/epoch - 9ms/step
# Epoch 189/300
# 528/528 - 5s - loss: 3498.9473 - mean_squared_error: 5344.7046 - mean_absolute_error: 13.8729 - 5s/epoch - 10ms/step
# Epoch 190/300
# 528/528 - 5s - loss: 3495.0337 - mean_squared_error: 5338.7261 - mean_absolute_error: 13.9131 - 5s/epoch - 10ms/step
# Epoch 191/300
# 528/528 - 5s - loss: 3771.8840 - mean_squared_error: 5761.6230 - mean_absolute_error: 14.3906 - 5s/epoch - 10ms/step
# Epoch 192/300
# 528/528 - 5s - loss: 3765.6802 - mean_squared_error: 5752.1421 - mean_absolute_error: 14.3513 - 5s/epoch - 10ms/step
# Epoch 193/300
# 528/528 - 5s - loss: 3622.3206 - mean_squared_error: 5533.1592 - mean_absolute_error: 13.7505 - 5s/epoch - 10ms/step
# Epoch 194/300
# 528/528 - 5s - loss: 3567.9944 - mean_squared_error: 5450.1729 - mean_absolute_error: 13.8276 - 5s/epoch - 10ms/step
# Epoch 195/300
# 528/528 - 5s - loss: 3579.8484 - mean_squared_error: 5468.2842 - mean_absolute_error: 14.1994 - 5s/epoch - 9ms/step
# Epoch 196/300
# 528/528 - 5s - loss: 3558.8936 - mean_squared_error: 5436.2764 - mean_absolute_error: 14.0679 - 5s/epoch - 10ms/step
# Epoch 197/300
# 528/528 - 5s - loss: 3599.5996 - mean_squared_error: 5498.4512 - mean_absolute_error: 14.3914 - 5s/epoch - 10ms/step
# Epoch 198/300
# 528/528 - 5s - loss: 3500.9436 - mean_squared_error: 5347.7510 - mean_absolute_error: 14.0236 - 5s/epoch - 10ms/step
# Epoch 199/300
# 528/528 - 5s - loss: 3507.0823 - mean_squared_error: 5357.1313 - mean_absolute_error: 13.9227 - 5s/epoch - 10ms/step
# Epoch 200/300
# 528/528 - 6s - loss: 3795.5483 - mean_squared_error: 5797.7661 - mean_absolute_error: 14.1368 - val_loss: 5118.2837 - val_mean_squared_error: 7616.3770 - val_mean_absolute_error: 17.1423 - 6s/epoch - 11ms/step
# Epoch 201/300
# 528/528 - 5s - loss: 3632.7393 - mean_squared_error: 5549.0688 - mean_absolute_error: 13.9029 - 5s/epoch - 10ms/step
# Epoch 202/300
# 528/528 - 6s - loss: 3555.2424 - mean_squared_error: 5430.7051 - mean_absolute_error: 13.9456 - 6s/epoch - 10ms/step
# Epoch 203/300
# 528/528 - 5s - loss: 3571.3950 - mean_squared_error: 5455.3677 - mean_absolute_error: 13.9440 - 5s/epoch - 10ms/step
# Epoch 204/300
# 528/528 - 5s - loss: 3635.0261 - mean_squared_error: 5552.5723 - mean_absolute_error: 13.8482 - 5s/epoch - 10ms/step
# Epoch 205/300
# 528/528 - 5s - loss: 3508.8367 - mean_squared_error: 5359.8086 - mean_absolute_error: 13.8079 - 5s/epoch - 10ms/step
# Epoch 206/300
# 528/528 - 5s - loss: 3459.9565 - mean_squared_error: 5285.1484 - mean_absolute_error: 13.7544 - 5s/epoch - 10ms/step
# Epoch 207/300
# 528/528 - 5s - loss: 3503.9341 - mean_squared_error: 5352.3208 - mean_absolute_error: 13.9955 - 5s/epoch - 10ms/step
# Epoch 208/300
# 528/528 - 5s - loss: 3506.3716 - mean_squared_error: 5356.0449 - mean_absolute_error: 13.8409 - 5s/epoch - 9ms/step
# Epoch 209/300
# 528/528 - 5s - loss: 3461.7126 - mean_squared_error: 5287.8296 - mean_absolute_error: 13.5932 - 5s/epoch - 9ms/step
# Epoch 210/300
# 528/528 - 5s - loss: 3444.9517 - mean_squared_error: 5262.2251 - mean_absolute_error: 13.7279 - 5s/epoch - 10ms/step
# Epoch 211/300
# 528/528 - 5s - loss: 3501.6335 - mean_squared_error: 5348.8081 - mean_absolute_error: 13.8673 - 5s/epoch - 10ms/step
# Epoch 212/300
# 528/528 - 5s - loss: 3520.7915 - mean_squared_error: 5378.0684 - mean_absolute_error: 13.7902 - 5s/epoch - 10ms/step
# Epoch 213/300
# 528/528 - 5s - loss: 3484.9595 - mean_squared_error: 5323.3350 - mean_absolute_error: 13.7290 - 5s/epoch - 10ms/step
# Epoch 214/300
# 528/528 - 5s - loss: 3426.6306 - mean_squared_error: 5234.2368 - mean_absolute_error: 13.6355 - 5s/epoch - 10ms/step
# Epoch 215/300
# 528/528 - 5s - loss: 3423.8296 - mean_squared_error: 5229.9595 - mean_absolute_error: 13.5964 - 5s/epoch - 9ms/step
# Epoch 216/300
# 528/528 - 5s - loss: 3484.9731 - mean_squared_error: 5323.3560 - mean_absolute_error: 13.6539 - 5s/epoch - 10ms/step
# Epoch 217/300
# 528/528 - 5s - loss: 3482.7629 - mean_squared_error: 5319.9824 - mean_absolute_error: 13.8300 - 5s/epoch - 10ms/step
# Epoch 218/300
# 528/528 - 5s - loss: 3528.1191 - mean_squared_error: 5389.2617 - mean_absolute_error: 13.9176 - 5s/epoch - 10ms/step
# Epoch 219/300
# 528/528 - 5s - loss: 3438.0146 - mean_squared_error: 5251.6260 - mean_absolute_error: 13.5588 - 5s/epoch - 9ms/step
# Epoch 220/300
# 528/528 - 5s - loss: 3371.7102 - mean_squared_error: 5150.3442 - mean_absolute_error: 13.5577 - 5s/epoch - 10ms/step
# Epoch 221/300
# 528/528 - 5s - loss: 3438.0945 - mean_squared_error: 5251.7485 - mean_absolute_error: 13.8989 - 5s/epoch - 9ms/step
# Epoch 222/300
# 528/528 - 5s - loss: 3522.0813 - mean_squared_error: 5380.0425 - mean_absolute_error: 13.9801 - 5s/epoch - 9ms/step
# Epoch 223/300
# 528/528 - 5s - loss: 3483.3984 - mean_squared_error: 5320.9541 - mean_absolute_error: 13.8730 - 5s/epoch - 10ms/step
# Epoch 224/300
# 528/528 - 5s - loss: 3898.8608 - mean_squared_error: 5955.5791 - mean_absolute_error: 14.4153 - 5s/epoch - 10ms/step
# Epoch 225/300
# 528/528 - 5s - loss: 3859.1736 - mean_squared_error: 5894.9531 - mean_absolute_error: 14.5646 - 5s/epoch - 10ms/step
# Epoch 226/300
# 528/528 - 5s - loss: 3503.6523 - mean_squared_error: 5351.8950 - mean_absolute_error: 13.9530 - 5s/epoch - 10ms/step
# Epoch 227/300
# 528/528 - 5s - loss: 3437.1677 - mean_squared_error: 5250.3350 - mean_absolute_error: 13.8432 - 5s/epoch - 10ms/step
# Epoch 228/300
# 528/528 - 5s - loss: 3399.3511 - mean_squared_error: 5192.5732 - mean_absolute_error: 13.9567 - 5s/epoch - 10ms/step
# Epoch 229/300
# 528/528 - 5s - loss: 3401.1233 - mean_squared_error: 5195.2764 - mean_absolute_error: 13.7234 - 5s/epoch - 10ms/step
# Epoch 230/300
# 528/528 - 5s - loss: 3395.9038 - mean_squared_error: 5187.3018 - mean_absolute_error: 13.9215 - 5s/epoch - 9ms/step
# Epoch 231/300
# 528/528 - 5s - loss: 3786.6929 - mean_squared_error: 5784.2451 - mean_absolute_error: 15.3666 - 5s/epoch - 9ms/step
# Epoch 232/300
# 528/528 - 5s - loss: 3451.0034 - mean_squared_error: 5271.4692 - mean_absolute_error: 14.0808 - 5s/epoch - 10ms/step
# Epoch 233/300
# 528/528 - 5s - loss: 3385.6372 - mean_squared_error: 5171.6157 - mean_absolute_error: 13.9757 - 5s/epoch - 9ms/step
# Epoch 234/300
# 528/528 - 5s - loss: 3534.3127 - mean_squared_error: 5398.7236 - mean_absolute_error: 14.3237 - 5s/epoch - 9ms/step
# Epoch 235/300
# 528/528 - 5s - loss: 3829.0500 - mean_squared_error: 5848.9409 - mean_absolute_error: 14.2517 - 5s/epoch - 10ms/step
# Epoch 236/300
# 528/528 - 5s - loss: 3587.0964 - mean_squared_error: 5479.3525 - mean_absolute_error: 14.4359 - 5s/epoch - 9ms/step
# Epoch 237/300
# 528/528 - 5s - loss: 3422.7786 - mean_squared_error: 5228.3564 - mean_absolute_error: 13.9535 - 5s/epoch - 9ms/step
# Epoch 238/300
# 528/528 - 5s - loss: 3386.8970 - mean_squared_error: 5173.5469 - mean_absolute_error: 13.8850 - 5s/epoch - 10ms/step
# Epoch 239/300
# 528/528 - 5s - loss: 3360.0383 - mean_squared_error: 5132.5186 - mean_absolute_error: 13.7427 - 5s/epoch - 10ms/step
# Epoch 240/300
# 528/528 - 5s - loss: 3389.5486 - mean_squared_error: 5177.5972 - mean_absolute_error: 13.7184 - 5s/epoch - 10ms/step
# Epoch 241/300
# 528/528 - 5s - loss: 3435.3342 - mean_squared_error: 5247.5337 - mean_absolute_error: 13.7272 - 5s/epoch - 9ms/step
# Epoch 242/300
# 528/528 - 5s - loss: 3482.9246 - mean_squared_error: 5320.2354 - mean_absolute_error: 13.7629 - 5s/epoch - 10ms/step
# Epoch 243/300
# 528/528 - 5s - loss: 3412.8362 - mean_squared_error: 5213.1641 - mean_absolute_error: 13.8510 - 5s/epoch - 10ms/step
# Epoch 244/300
# 528/528 - 5s - loss: 3301.0742 - mean_squared_error: 5042.4521 - mean_absolute_error: 13.5831 - 5s/epoch - 10ms/step
# Epoch 245/300
# 528/528 - 5s - loss: 3443.5227 - mean_squared_error: 5260.0439 - mean_absolute_error: 13.9154 - 5s/epoch - 10ms/step
# Epoch 246/300
# 528/528 - 5s - loss: 3360.0635 - mean_squared_error: 5132.5596 - mean_absolute_error: 13.7330 - 5s/epoch - 10ms/step
# Epoch 247/300
# 528/528 - 5s - loss: 3400.2285 - mean_squared_error: 5193.9111 - mean_absolute_error: 13.8117 - 5s/epoch - 10ms/step
# Epoch 248/300
# 528/528 - 5s - loss: 3477.2039 - mean_squared_error: 5311.4902 - mean_absolute_error: 14.0225 - 5s/epoch - 9ms/step
# Epoch 249/300
# 528/528 - 5s - loss: 3358.0271 - mean_squared_error: 5129.4409 - mean_absolute_error: 13.5617 - 5s/epoch - 10ms/step
# Epoch 250/300
# 528/528 - 5s - loss: 3406.2271 - mean_squared_error: 5203.0708 - mean_absolute_error: 13.7710 - 5s/epoch - 10ms/step
# Epoch 251/300
# 528/528 - 5s - loss: 3300.5593 - mean_squared_error: 5041.6650 - mean_absolute_error: 13.5957 - 5s/epoch - 9ms/step
# Epoch 252/300
# 528/528 - 5s - loss: 3576.1340 - mean_squared_error: 5462.6084 - mean_absolute_error: 14.0216 - 5s/epoch - 10ms/step
# Epoch 253/300
# 528/528 - 5s - loss: 3516.8726 - mean_squared_error: 5372.0820 - mean_absolute_error: 13.7633 - 5s/epoch - 10ms/step
# Epoch 254/300
# 528/528 - 5s - loss: 3440.3005 - mean_squared_error: 5255.1157 - mean_absolute_error: 13.9093 - 5s/epoch - 10ms/step
# Epoch 255/300
# 528/528 - 5s - loss: 3436.4556 - mean_squared_error: 5249.2495 - mean_absolute_error: 13.9521 - 5s/epoch - 10ms/step
# Epoch 256/300
# 528/528 - 5s - loss: 3353.5010 - mean_squared_error: 5122.5322 - mean_absolute_error: 13.5732 - 5s/epoch - 10ms/step
# Epoch 257/300
# 528/528 - 5s - loss: 3338.5261 - mean_squared_error: 5099.6543 - mean_absolute_error: 13.5392 - 5s/epoch - 10ms/step
# Epoch 258/300
# 528/528 - 5s - loss: 3343.8647 - mean_squared_error: 5107.8140 - mean_absolute_error: 13.4310 - 5s/epoch - 10ms/step
# Epoch 259/300
# 528/528 - 5s - loss: 3301.1396 - mean_squared_error: 5042.5488 - mean_absolute_error: 13.5715 - 5s/epoch - 10ms/step
# Epoch 260/300
# 528/528 - 5s - loss: 3369.7268 - mean_squared_error: 5147.3164 - mean_absolute_error: 13.5594 - 5s/epoch - 10ms/step
# Epoch 261/300
# 528/528 - 5s - loss: 3376.4028 - mean_squared_error: 5157.5181 - mean_absolute_error: 13.7156 - 5s/epoch - 10ms/step
# Epoch 262/300
# 528/528 - 5s - loss: 3348.8311 - mean_squared_error: 5115.4023 - mean_absolute_error: 13.5458 - 5s/epoch - 10ms/step
# Epoch 263/300
# 528/528 - 5s - loss: 3332.3303 - mean_squared_error: 5090.1934 - mean_absolute_error: 13.6234 - 5s/epoch - 9ms/step
# Epoch 264/300
# 528/528 - 5s - loss: 3328.7786 - mean_squared_error: 5084.7695 - mean_absolute_error: 13.6273 - 5s/epoch - 10ms/step
# Epoch 265/300
# 528/528 - 5s - loss: 3287.9756 - mean_squared_error: 5022.4360 - mean_absolute_error: 13.4951 - 5s/epoch - 9ms/step
# Epoch 266/300
# 528/528 - 5s - loss: 3236.7798 - mean_squared_error: 4944.2368 - mean_absolute_error: 13.4081 - 5s/epoch - 9ms/step
# Epoch 267/300
# 528/528 - 5s - loss: 3351.8643 - mean_squared_error: 5120.0322 - mean_absolute_error: 13.7176 - 5s/epoch - 9ms/step
# Epoch 268/300
# 528/528 - 5s - loss: 3388.6167 - mean_squared_error: 5176.1724 - mean_absolute_error: 13.4532 - 5s/epoch - 10ms/step
# Epoch 269/300
# 528/528 - 5s - loss: 3284.4866 - mean_squared_error: 5017.1128 - mean_absolute_error: 13.4593 - 5s/epoch - 10ms/step
# Epoch 270/300
# 528/528 - 5s - loss: 3300.2637 - mean_squared_error: 5041.2158 - mean_absolute_error: 13.6059 - 5s/epoch - 10ms/step
# Epoch 271/300
# 528/528 - 5s - loss: 3223.4639 - mean_squared_error: 4923.8970 - mean_absolute_error: 13.3458 - 5s/epoch - 10ms/step
# Epoch 272/300
# 528/528 - 5s - loss: 3362.1248 - mean_squared_error: 5135.7046 - mean_absolute_error: 13.6231 - 5s/epoch - 10ms/step
# Epoch 273/300
# 528/528 - 5s - loss: 3248.6267 - mean_squared_error: 4962.3350 - mean_absolute_error: 13.3505 - 5s/epoch - 10ms/step
# Epoch 274/300
# 528/528 - 5s - loss: 3226.8489 - mean_squared_error: 4929.0684 - mean_absolute_error: 13.3745 - 5s/epoch - 10ms/step
# Epoch 275/300
# 528/528 - 5s - loss: 3364.2356 - mean_squared_error: 5138.9292 - mean_absolute_error: 13.5395 - 5s/epoch - 10ms/step
# Epoch 276/300
# 528/528 - 5s - loss: 3311.8269 - mean_squared_error: 5058.8735 - mean_absolute_error: 13.2795 - 5s/epoch - 9ms/step
# Epoch 277/300
# 528/528 - 5s - loss: 3272.7075 - mean_squared_error: 4999.1191 - mean_absolute_error: 13.5231 - 5s/epoch - 10ms/step
# Epoch 278/300
# 528/528 - 5s - loss: 3244.1191 - mean_squared_error: 4955.4482 - mean_absolute_error: 13.3574 - 5s/epoch - 9ms/step
# Epoch 279/300
# 528/528 - 5s - loss: 3276.9624 - mean_squared_error: 5005.6177 - mean_absolute_error: 13.4457 - 5s/epoch - 9ms/step
# Epoch 280/300
# 528/528 - 5s - loss: 3267.4402 - mean_squared_error: 4991.0713 - mean_absolute_error: 13.2956 - 5s/epoch - 9ms/step
# Epoch 281/300
# 528/528 - 5s - loss: 3246.0837 - mean_squared_error: 4958.4502 - mean_absolute_error: 13.2395 - 5s/epoch - 10ms/step
# Epoch 282/300
# 528/528 - 5s - loss: 3203.3384 - mean_squared_error: 4893.1519 - mean_absolute_error: 13.1413 - 5s/epoch - 9ms/step
# Epoch 283/300
# 528/528 - 5s - loss: 3231.1846 - mean_squared_error: 4935.6919 - mean_absolute_error: 13.1662 - 5s/epoch - 10ms/step
# Epoch 284/300
# 528/528 - 5s - loss: 3258.9512 - mean_squared_error: 4978.1021 - mean_absolute_error: 13.3372 - 5s/epoch - 10ms/step
# Epoch 285/300
# 528/528 - 5s - loss: 3368.6348 - mean_squared_error: 5145.6479 - mean_absolute_error: 13.4887 - 5s/epoch - 10ms/step
# Epoch 286/300
# 528/528 - 5s - loss: 3192.4260 - mean_squared_error: 4876.4888 - mean_absolute_error: 13.1952 - 5s/epoch - 10ms/step
# Epoch 287/300
# 528/528 - 5s - loss: 3294.2637 - mean_squared_error: 5032.0459 - mean_absolute_error: 13.3783 - 5s/epoch - 10ms/step
# Epoch 288/300
# 528/528 - 5s - loss: 3331.7507 - mean_squared_error: 5089.3071 - mean_absolute_error: 13.3601 - 5s/epoch - 9ms/step
# Epoch 289/300
# 528/528 - 5s - loss: 3215.6343 - mean_squared_error: 4911.9380 - mean_absolute_error: 13.2259 - 5s/epoch - 9ms/step
# Epoch 290/300
# 528/528 - 5s - loss: 3204.8970 - mean_squared_error: 4895.5356 - mean_absolute_error: 13.1028 - 5s/epoch - 10ms/step
# Epoch 291/300
# 528/528 - 5s - loss: 3194.8362 - mean_squared_error: 4880.1660 - mean_absolute_error: 13.2530 - 5s/epoch - 10ms/step
# Epoch 292/300
# 528/528 - 5s - loss: 3366.3984 - mean_squared_error: 5142.2319 - mean_absolute_error: 13.1355 - 5s/epoch - 9ms/step
# Epoch 293/300
# 528/528 - 5s - loss: 3215.8315 - mean_squared_error: 4912.2393 - mean_absolute_error: 13.2975 - 5s/epoch - 10ms/step
# Epoch 294/300
# 528/528 - 5s - loss: 3288.0032 - mean_squared_error: 5022.4844 - mean_absolute_error: 13.4338 - 5s/epoch - 9ms/step
# Epoch 295/300
# 528/528 - 5s - loss: 3323.4858 - mean_squared_error: 5076.6816 - mean_absolute_error: 13.1886 - 5s/epoch - 10ms/step
# Epoch 296/300
# 528/528 - 5s - loss: 3225.1421 - mean_squared_error: 4926.4614 - mean_absolute_error: 13.1234 - 5s/epoch - 10ms/step
# Epoch 297/300
# 528/528 - 5s - loss: 3150.4597 - mean_squared_error: 4812.3838 - mean_absolute_error: 13.1583 - 5s/epoch - 10ms/step
# Epoch 298/300
# 528/528 - 5s - loss: 3204.1492 - mean_squared_error: 4894.3936 - mean_absolute_error: 13.0337 - 5s/epoch - 10ms/step
# Epoch 299/300
# 528/528 - 5s - loss: 3332.1479 - mean_squared_error: 5089.9150 - mean_absolute_error: 13.2749 - 5s/epoch - 10ms/step
# Epoch 300/300
# 528/528 - 6s - loss: 3287.1079 - mean_squared_error: 5021.1123 - mean_absolute_error: 13.3670 - val_loss: 5413.7549 - val_mean_squared_error: 8056.0625 - val_mean_absolute_error: 17.4239 - 6s/epoch - 11ms/step

# %%
##### Step 7 - Print Performance Summary
print("")
print('-------------------- Model Summary --------------------')
model3.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model3.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking_5 (Masking)         (None, 10, 1)             0
#
#  Input-Layer (InputLayer)    multiple                  0
#
#  lstm_7 (LSTM)               (None, 10, 64)            16896
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            65
#  ed)
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 3427.38037109375
# Final mean_squared_error : 5235.3818359375
# Final mean_absolute_error : 13.499950408935547
# Final val_loss : 5081.2626953125
# Final val_mean_squared_error : 7561.287109375
# Final val_mean_absolute_error : 15.989761352539062
#
# -------------------- Evaluation on Test Data --------------------
# 165/165 [==============================] - 1s 5ms/step - loss: 4544.6763 - mean_squared_error: 7812.2725 - mean_absolute_error: 15.8989
