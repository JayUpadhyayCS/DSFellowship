# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D, GRU # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
from keras import metrics
from keras.utils import plot_model
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# c:\Python\Python310\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
df=df.iloc[100000:110000] #cuts data to long 120-119 approx
#df=df.iloc[200000:200050]

df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.5647 36.5493          0.0     -7.3675     0.30839     0.80180
#           36.5513          0.0     -7.3700     0.31268     0.82006
#           36.5533          0.0     -7.3592     0.30634     0.82830
#           36.5553          0.0     -7.3665     0.35908     0.90634
#           36.5573          0.0     -7.3835     0.32145     0.88016
# ...                        ...         ...         ...         ...
# -120.5467 36.1392          0.0     -6.7349     2.40710     2.85140
#           36.1412          0.0     -6.7453     2.63630     3.04850
#           36.1432          0.0     -6.7055     2.79770     3.09930
#           36.1452          0.0     -6.7150     2.21260     2.47580
#           36.1472          0.0     -6.7302     2.22740     2.54680
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.5647 36.5493     -0.63115      2.5428    -0.24366      3.4140
#           36.5513     -0.64685      2.6231    -0.26206      3.4478
#           36.5533     -0.63582      2.6812    -0.23859      3.4578
#           36.5553     -0.54705      2.8056    -0.18348      3.5216
#           36.5573     -0.57876      2.8102    -0.21554      3.4643
# ...                        ...         ...         ...         ...
# -120.5467 36.1392      0.38623      3.2585     1.71470      3.3583
#           36.1412      0.56905      3.3954     1.87500      3.5058
#           36.1432      0.74636      3.4873     2.05990      3.6655
#           36.1452      0.20854      2.9320     1.52920      3.1147
#           36.1472      0.22233      2.9343     1.55280      3.1405
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.5647 36.5493       5.4440      2.4632  ...     1.20690      4.3263
#           36.5513       5.4326      2.4627  ...     1.32300      4.4486
#           36.5533       5.4391      2.4596  ...     1.07790      4.2094
#           36.5553       5.5039      2.4920  ...     1.06510      4.2107
#           36.5573       5.4821      2.4405  ...     0.87105      4.0221
# ...                        ...         ...  ...         ...         ...
# -120.5467 36.1392       4.2311      3.7578  ...     1.66470      4.8441
#           36.1412       4.4219      3.9316  ...     1.73040      4.9441
#           36.1432       4.6330      4.1155  ...     2.10000      5.3758
#           36.1452       4.0955      3.5745  ...     1.35300      4.6658
#           36.1472       4.2582      3.6408  ...     0.64879      4.0606
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.5647 36.5493       3.5896      3.4860    0.532130    0.047884
#           36.5513       3.7292      3.6155    0.579940    0.109060
#           36.5533       3.5008      3.3752    0.287090   -0.170190
#           36.5553       3.5187      3.3801    0.233830   -0.222880
#           36.5573       3.3311      3.1918   -0.020346   -0.439840
# ...                        ...         ...         ...         ...
# -120.5467 36.1392       2.8380      3.0063    1.659200    1.047100
#           36.1412       2.8932      3.0792    1.764600    1.150200
#           36.1432       3.2651      3.4616    2.189400    1.607100
#           36.1452       2.5222      2.7271    1.468100    0.939230
#           36.1472       1.8318      2.0204    0.876000    0.154330
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.5647 36.5493       2.6626      3.7143      3.9473      5.4460
#           36.5513       2.7313      3.7821      4.0031      5.5203
#           36.5533       2.4374      3.5238      3.6948      5.2294
#           36.5553       2.4229      3.4780      3.6477      5.1809
#           36.5573       2.2142      3.2586      3.4167      4.9589
# ...                        ...         ...         ...         ...
# -120.5467 36.1392       5.6025      4.0580      5.9485      6.3554
#           36.1412       5.7057      4.1147      6.0727      6.4494
#           36.1432       6.1494      4.4999      6.5251      6.8550
#           36.1452       5.4550      3.7812      5.8741      6.1301
#           36.1472       4.7631      3.0400      5.0847      5.2687
#
# [10000 rows x 110 columns]

# %%
df2=pd.read_csv('InSAR_data_south/displacement/groundwater.csv')
df2=df2.set_index([df2.columns[0],df2.columns[1]])
df2.columns=pd.to_datetime(df2.columns, format='%Y-%m-%d')
df2=df2.dropna(axis=0, how='all')#drop full nan rows
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != df2.columns[y]: #if column is misssing insert it
        df2.insert(loc=y,column=df.columns[y],value=np.nan*11286,allow_duplicates=False)
df2.index[0]
type(df2.index[0])
# Out:
# tuple

# %%
df2.index.get_level_values
# Out:
# <bound method MultiIndex.get_level_values of MultiIndex([(-120.9486, 37.6316),
#             (-120.8926, 36.7114),
#             (-120.8846, 36.6994),
#             (-120.8746, 36.6874),
#             (-120.1368, 35.6991),
#             (-120.1268, 35.6871),
#             (-120.1168, 35.6751),
#             (-120.0988, 35.6491),
#             (-120.8966, 36.7434),
#             (-120.8866, 36.7314),
#             ...
#             (-119.0431, 36.3733),
#             ( -119.109, 36.4913),
#             (-119.0811, 36.4553),
#             (-119.0731, 36.4433),
#             (-119.0451, 36.4053),
#             (-119.0351, 36.3933),
#             (-119.0271, 36.3793),
#             (-119.0571, 36.4493),
#             (-119.0211, 36.3993),
#             (-119.0111, 36.3873)],
#            names=['Longitude', 'Latitude'], length=11286)>

# %%
# names=df2.columns.values
# df_temp=df2.unstack().reset_index()
# df_temp.columns=['Longitude','Latitude',names]
# #print(df1.head())
# #put it onto the main'
# df1=pd.DataFrame(data=df_temp.iloc[:,2:3])
# df1=df_temp.set_index([df_temp.columns[0],df_temp.columns[1]])


# df4=pd.concat([df,df1], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\DSFellowship\biLSTMshapingP2.ipynb Cell 9 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> names=df2.columns.values
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a> df_temp=df2.unstack().reset_index()
# ----> <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X50sZmlsZQ%3D%3D?line=2'>3</a> df_temp.columns=['Longitude','Latitude',names]
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X50sZmlsZQ%3D%3D?line=3'>4</a> #print(df1.head())
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X50sZmlsZQ%3D%3D?line=4'>5</a> #put it onto the main'
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X50sZmlsZQ%3D%3D?line=5'>6</a> df1=pd.DataFrame(data=df_temp.iloc[:,2:3])
#
# File c:\Python\Python310\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File c:\Python\Python310\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Python\Python310\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File c:\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File c:\Python\Python310\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 148501 elements, new values have 3 elements

# %%
for x in range(df2.index.size): #for each row
    curr=np.nan
    for y in range(df2.columns.size): #for each value in the row
        n=0
        while np.isnan(curr): # if saved value is empty
            curr=df2.iloc[x].values[n] #look for next actual value
            n+=1
        if np.isnan(df2.iloc[x].values[y]):#if data is nan then replace with previous curr value
            df2.iat[x,y]=curr
            #df2.iloc[x].values[y]=curr
        else:
            curr= df2.iloc[x].values[y]
                

df2
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    81.000000   81.000000  ...   75.653992   75.813688
# -120.8926 36.7114    72.248964   72.248964  ...   75.200000   75.200000
# -120.8846 36.6994    72.248964   72.248964  ...   75.200000   75.200000
# -120.8746 36.6874    72.248964   72.248964  ...   75.200000   75.200000
# -120.1368 35.6991   141.123387  141.123387  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091  ...   16.978182   17.000000
# -119.0271 36.3793    17.409091   17.409091  ...   16.978182   17.000000
# -119.0571 36.4493    17.409091   17.409091  ...   16.978182   17.000000
# -119.0211 36.3993    17.409091   17.409091  ...   16.978182   17.000000
# -119.0111 36.3873    17.409091   17.409091  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0        76.0        76.0
# -120.8926 36.7114    75.200000        75.2        75.2        75.2
# -120.8846 36.6994    75.200000        75.2        75.2        75.2
# -120.8746 36.6874    75.200000        75.2        75.2        75.2
# -120.1368 35.6991   151.000000       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.000000        17.0        17.0        17.0
# -119.0271 36.3793    17.000000        17.0        17.0        17.0
# -119.0571 36.4493    17.000000        17.0        17.0        17.0
# -119.0211 36.3993    17.000000        17.0        17.0        17.0
# -119.0111 36.3873    17.000000        17.0        17.0        17.0
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316         76.0        76.0        76.0        76.0
# -120.8926 36.7114         75.2        75.2        75.2        75.2
# -120.8846 36.6994         75.2        75.2        75.2        75.2
# -120.8746 36.6874         75.2        75.2        75.2        75.2
# -120.1368 35.6991        151.0       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933         17.0        17.0        17.0        17.0
# -119.0271 36.3793         17.0        17.0        17.0        17.0
# -119.0571 36.4493         17.0        17.0        17.0        17.0
# -119.0211 36.3993         17.0        17.0        17.0        17.0
# -119.0111 36.3873         17.0        17.0        17.0        17.0
#
# [11286 rows x 110 columns]

# %%
arr3[:0,Y_start:Y_end])

# %% [markdown]
# # Timestep

# %%
timestep=10
# 1 2 3 4 5 6 7 ...
# w/ timestep of 2
# [[1,2][2,3][3,4]

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping2(datain,datain2, timestep):
    #print(arr)
    cnt=0
    for row in range(len(datain2.index)): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()

        if df2.index[row] not in df.index:
            continue
        
        
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        arr2=datain2.iloc[row].to_numpy().flatten()
        arr3=np.concatenate((arr,arr2)).reshape(2,110)
        
        
        for mth in range(0, len(datain2.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr3[X_start:X_end]
                Y_comb=arr3[0][Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr3[:,X_start:X_end])
                Y_comb=np.append(Y_comb, arr3[:0,Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 2))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 2))
    return X_out, Y_out

# %%
# print(df2.index.values[0])
# #arr=df.loc[df.index[0]]
for row in df2.index.values:
    if row in df.index:
        print(df.loc[row])
# if df2.index[0] in df.index.values:
#     print(True)
# else:
#     print(False)
# Out:
# 2014-11-08    0.00000
# 2014-12-02   -8.48790
# 2014-12-26    1.26460
# 2015-02-12    2.37070
# 2015-03-08   -1.46300
#                ...
# 2018-12-05   -2.04740
# 2018-12-17    0.48609
# 2018-12-29    2.36160
# 2019-01-10    1.59020
# 2019-01-22    2.60350
# Name: (-120.1368, 35.6991), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.00290
# 2014-12-26    1.66570
# 2015-02-12    2.35930
# 2015-03-08   -1.07480
#                ...
# 2018-12-05    0.17534
# 2018-12-17    2.44180
# 2018-12-29    4.34250
# 2019-01-10    3.32730
# 2019-01-22    4.52070
# Name: (-120.1268, 35.6871), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.63890
# 2014-12-26    1.78230
# 2015-02-12    3.10300
# 2015-03-08   -0.18659
#                ...
# 2018-12-05    2.46260
# 2018-12-17    4.74350
# 2018-12-29    6.64500
# 2019-01-10    5.91260
# 2019-01-22    7.12480
# Name: (-120.1168, 35.6751), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.12860
# 2014-12-26    1.59620
# 2015-02-12    2.20610
# 2015-03-08   -1.02220
#                ...
# 2018-12-05   -0.17141
# 2018-12-17    2.26000
# 2018-12-29    3.94130
# 2019-01-10    3.11530
# 2019-01-22    4.28520
# Name: (-120.0988, 35.6491), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.28340
# 2014-12-26    1.45710
# 2015-02-12    2.53300
# 2015-03-08   -1.24940
#                ...
# 2018-12-05   -0.21525
# 2018-12-17    2.70900
# 2018-12-29    4.35760
# 2019-01-10    3.78680
# 2019-01-22    4.53150
# Name: (-120.1208, 35.7071), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.05090
# 2014-12-26    1.74490
# 2015-02-12    2.62880
# 2015-03-08   -1.10240
#                ...
# 2018-12-05    0.31428
# 2018-12-17    2.69410
# 2018-12-29    4.51960
# 2019-01-10    3.71060
# 2019-01-22    4.64340
# Name: (-120.1108, 35.6951), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.93410
# 2014-12-26    1.88500
# 2015-02-12    3.41850
# 2015-03-08   -0.19142
#                ...
# 2018-12-05    3.27110
# 2018-12-17    5.42350
# 2018-12-29    7.41570
# 2019-01-10    6.58100
# 2019-01-22    7.75040
# Name: (-120.1028, 35.6811), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.91550
# 2014-12-26    1.90980
# 2015-02-12    3.57570
# 2015-03-08    0.10617
#                ...
# 2018-12-05    0.96687
# 2018-12-17    3.38250
# 2018-12-29    5.30620
# 2019-01-10    4.54730
# 2019-01-22    5.82190
# Name: (-120.0928, 35.6691), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.06250
# 2014-12-26    1.64510
# 2015-02-12    2.46280
# 2015-03-08   -1.01160
#                ...
# 2018-12-05    0.62814
# 2018-12-17    3.10770
# 2018-12-29    4.91050
# 2019-01-10    4.02190
# 2019-01-22    5.19110
# Name: (-120.0848, 35.6571), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -7.6731
# 2014-12-26    1.0629
# 2015-02-12    1.8452
# 2015-03-08   -1.4503
#                ...
# 2018-12-05   -1.2780
# 2018-12-17    1.9706
# 2018-12-29    3.7137
# 2019-01-10    2.9607
# 2019-01-22    3.3058
# Name: (-120.0208, 35.5711), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.860200
# 2014-12-26    1.954100
# 2015-02-12    3.651200
# 2015-03-08   -0.068145
#                 ...
# 2018-12-05    3.439800
# 2018-12-17    5.902900
# 2018-12-29    7.950600
# 2019-01-10    7.140100
# 2019-01-22    8.354000
# Name: (-120.0768, 35.6771), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.97580
# 2014-12-26    1.83140
# 2015-02-12    3.13350
# 2015-03-08   -0.81282
#                ...
# 2018-12-05    0.85167
# 2018-12-17    3.03200
# 2018-12-29    5.06820
# 2019-01-10    4.08740
# 2019-01-22    5.10860
# Name: (-120.0688, 35.6651), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.02330
# 2014-12-26    1.78090
# 2015-02-12    2.85230
# 2015-03-08   -0.91758
#                ...
# 2018-12-05    0.20250
# 2018-12-17    2.51260
# 2018-12-29    4.39010
# 2019-01-10    3.33570
# 2019-01-22    4.28320
# Name: (-120.0588, 35.6531), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.48150
# 2014-12-26    1.14230
# 2015-02-12    2.03280
# 2015-03-08   -1.25850
#                ...
# 2018-12-05   -0.81042
# 2018-12-17    2.00770
# 2018-12-29    3.89040
# 2019-01-10    3.20410
# 2019-01-22    3.56720
# Name: (-120.0048, 35.5771), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.72580
# 2014-12-26    1.95120
# 2015-02-12    2.82770
# 2015-03-08   -0.78562
#                ...
# 2018-12-05    0.21293
# 2018-12-17    2.81130
# 2018-12-29    4.52720
# 2019-01-10    3.62560
# 2019-01-22    4.66760
# Name: (-120.0708, 35.6971), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.83340
# 2014-12-26    2.07840
# 2015-02-12    3.28820
# 2015-03-08   -0.63148
#                ...
# 2018-12-05    0.71442
# 2018-12-17    3.24650
# 2018-12-29    5.05530
# 2019-01-10    4.18990
# 2019-01-22    5.14910
# Name: (-120.0628, 35.6851), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.81380
# 2014-12-26    1.98420
# 2015-02-12    3.36810
# 2015-03-08   -0.55814
#                ...
# 2018-12-05   -0.72408
# 2018-12-17    2.24640
# 2018-12-29    3.82040
# 2019-01-10    2.96650
# 2019-01-22    3.71330
# Name: (-120.0448, 35.6591), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.85910
# 2014-12-26    1.86560
# 2015-02-12    3.01830
# 2015-03-08   -0.75902
#                ...
# 2018-12-05    0.34354
# 2018-12-17    3.45210
# 2018-12-29    4.97420
# 2019-01-10    4.10050
# 2019-01-22    4.73440
# Name: (-120.0348, 35.6471), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -7.2769
# 2014-12-26    1.0922
# 2015-02-12    2.3526
# 2015-03-08   -1.1407
#                ...
# 2018-12-05   -0.5100
# 2018-12-17    2.2989
# 2018-12-29    4.2375
# 2019-01-10    3.5403
# 2019-01-22    3.8392
# Name: (-119.9888, 35.5851), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.10420
# 2014-12-26    1.17980
# 2015-02-12    2.32490
# 2015-03-08   -1.14690
#                ...
# 2018-12-05   -0.33605
# 2018-12-17    2.48960
# 2018-12-29    4.41080
# 2019-01-10    3.59500
# 2019-01-22    3.83320
# Name: (-119.9808, 35.5731), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.15130
# 2014-12-26    1.15470
# 2015-02-12    2.24900
# 2015-03-08   -1.19320
#                ...
# 2018-12-05   -0.27157
# 2018-12-17    2.66310
# 2018-12-29    4.53010
# 2019-01-10    3.82210
# 2019-01-22    3.91370
# Name: (-119.9708, 35.5611), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.15180
# 2014-12-26    1.04540
# 2015-02-12    2.00330
# 2015-03-08   -1.40760
#                ...
# 2018-12-05   -0.32167
# 2018-12-17    2.45320
# 2018-12-29    4.32880
# 2019-01-10    3.70100
# 2019-01-22    3.69570
# Name: (-119.9628, 35.5471), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.12270
# 2014-12-26    1.03580
# 2015-02-12    1.92900
# 2015-03-08   -1.55370
#                ...
# 2018-12-05    0.21586
# 2018-12-17    2.84000
# 2018-12-29    4.70180
# 2019-01-10    4.04270
# 2019-01-22    4.01480
# Name: (-119.9528, 35.5351), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.39890
# 2014-12-26    2.02080
# 2015-02-12    2.19180
# 2015-03-08   -0.42141
#                ...
# 2018-12-05    0.99613
# 2018-12-17    3.85150
# 2018-12-29    4.44920
# 2019-01-10    5.11970
# 2019-01-22    7.28910
# Name: (-120.4227, 36.1992), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -6.240900
# 2014-12-26    2.278600
# 2015-02-12    2.335600
# 2015-03-08    0.062222
#                 ...
# 2018-12-05    0.418380
# 2018-12-17    3.546900
# 2018-12-29    4.162500
# 2019-01-10    4.751800
# 2019-01-22    5.526000
# Name: (-120.3947, 36.1612), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.42190
# 2014-12-26    2.14690
# 2015-02-12    1.84290
# 2015-03-08   -0.15900
#                ...
# 2018-12-05   -0.79218
# 2018-12-17    2.48290
# 2018-12-29    3.03190
# 2019-01-10    3.34560
# 2019-01-22    4.77740
# Name: (-120.3847, 36.1492), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.54900
# 2014-12-26    2.04490
# 2015-02-12    1.53260
# 2015-03-08   -0.35576
#                ...
# 2018-12-05   -0.93712
# 2018-12-17    2.34110
# 2018-12-29    2.91660
# 2019-01-10    3.29420
# 2019-01-22    5.24360
# Name: (-120.3767, 36.1372), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.49150
# 2014-12-26    1.77460
# 2015-02-12    1.61080
# 2015-03-08   -0.45542
#                ...
# 2018-12-05   -1.45030
# 2018-12-17    1.67610
# 2018-12-29    2.31850
# 2019-01-10    2.69750
# 2019-01-22    4.65350
# Name: (-120.3667, 36.1252), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.58510
# 2014-12-26    2.00850
# 2015-02-12    1.90220
# 2015-03-08   -0.51446
#                ...
# 2018-12-05   -0.86353
# 2018-12-17    2.40980
# 2018-12-29    3.13730
# 2019-01-10    3.51550
# 2019-01-22    5.26620
# Name: (-120.3587, 36.1132), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.64610
# 2014-12-26    1.93500
# 2015-02-12    3.08490
# 2015-03-08   -0.56401
#                ...
# 2018-12-05    1.71670
# 2018-12-17    4.23770
# 2018-12-29    5.79530
# 2019-01-10    4.98300
# 2019-01-22    6.01250
# Name: (-120.0568, 35.7031), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.68770
# 2014-12-26    2.16640
# 2015-02-12    3.33980
# 2015-03-08   -0.53938
#                ...
# 2018-12-05    3.00540
# 2018-12-17    5.60980
# 2018-12-29    7.19720
# 2019-01-10    6.26580
# 2019-01-22    7.40160
# Name: (-120.0468, 35.6911), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.65830
# 2014-12-26    2.12690
# 2015-02-12    3.90240
# 2015-03-08    0.20628
#                ...
# 2018-12-05    1.76100
# 2018-12-17    4.95160
# 2018-12-29    6.70350
# 2019-01-10    5.78520
# 2019-01-22    6.91660
# Name: (-120.0368, 35.6791), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.62930
# 2014-12-26    1.86980
# 2015-02-12    3.26510
# 2015-03-08   -0.60372
#                ...
# 2018-12-05   -0.80356
# 2018-12-17    2.34830
# 2018-12-29    3.92930
# 2019-01-10    2.99890
# 2019-01-22    3.91720
# Name: (-120.0288, 35.6671), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.77130
# 2014-12-26    2.10480
# 2015-02-12    3.13010
# 2015-03-08   -0.82247
#                ...
# 2018-12-05    1.49480
# 2018-12-17    4.39640
# 2018-12-29    5.90170
# 2019-01-10    4.89650
# 2019-01-22    5.85520
# Name: (-120.0188, 35.6551), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.77010
# 2014-12-26    1.67010
# 2015-02-12    3.10620
# 2015-03-08   -0.73258
#                ...
# 2018-12-05   -1.13750
# 2018-12-17    1.80960
# 2018-12-29    3.42800
# 2019-01-10    2.52080
# 2019-01-22    3.16150
# Name: (-120.0108, 35.6411), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.75270
# 2014-12-26    1.40700
# 2015-02-12    2.81420
# 2015-03-08   -0.85899
#                ...
# 2018-12-05   -0.17311
# 2018-12-17    2.82330
# 2018-12-29    4.57650
# 2019-01-10    3.60820
# 2019-01-22    4.22880
# Name: (-120.0008, 35.6291), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.60160
# 2014-12-26    1.42140
# 2015-02-12    2.62040
# 2015-03-08   -0.87866
#                ...
# 2018-12-05    0.51575
# 2018-12-17    3.21050
# 2018-12-29    5.04600
# 2019-01-10    4.12390
# 2019-01-22    4.77330
# Name: (-119.9928, 35.6171), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -7.0654
# 2014-12-26    1.2113
# 2015-02-12    2.4645
# 2015-03-08   -1.1854
#                ...
# 2018-12-05   -0.3089
# 2018-12-17    2.7292
# 2018-12-29    4.4589
# 2019-01-10    3.6141
# 2019-01-22    3.9007
# Name: (-119.9648, 35.5791), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.00880
# 2014-12-26    1.20350
# 2015-02-12    2.44690
# 2015-03-08   -1.13440
#                ...
# 2018-12-05   -0.23711
# 2018-12-17    3.00850
# 2018-12-29    4.67930
# 2019-01-10    3.81070
# 2019-01-22    4.05260
# Name: (-119.9568, 35.5671), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.96510
# 2014-12-26    1.23680
# 2015-02-12    2.38550
# 2015-03-08   -1.21450
#                ...
# 2018-12-05   -0.21027
# 2018-12-17    2.99270
# 2018-12-29    4.68430
# 2019-01-10    3.80750
# 2019-01-22    3.96980
# Name: (-119.9468, 35.5551), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.93970
# 2014-12-26    1.28450
# 2015-02-12    2.39170
# 2015-03-08   -1.26870
#                ...
# 2018-12-05    0.15031
# 2018-12-17    3.19000
# 2018-12-29    4.91810
# 2019-01-10    4.05570
# 2019-01-22    4.12090
# Name: (-119.9388, 35.5431), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.95730
# 2014-12-26    1.36430
# 2015-02-12    2.46440
# 2015-03-08   -1.34460
#                ...
# 2018-12-05    0.24099
# 2018-12-17    3.02780
# 2018-12-29    4.80810
# 2019-01-10    3.94280
# 2019-01-22    3.91250
# Name: (-119.9288, 35.5311), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.12130
# 2014-12-26    1.07660
# 2015-02-12    2.22530
# 2015-03-08   -1.63240
#                ...
# 2018-12-05   -0.41527
# 2018-12-17    2.03030
# 2018-12-29    3.96750
# 2019-01-10    2.98940
# 2019-01-22    2.95430
# Name: (-119.9188, 35.5171), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.171600
# 2014-12-26    0.912970
# 2015-02-12    2.182200
# 2015-03-08   -1.815300
#                 ...
# 2018-12-05   -0.050751
# 2018-12-17    2.468000
# 2018-12-29    4.265600
# 2019-01-10    3.358500
# 2019-01-22    3.233300
# Name: (-119.9109, 35.5051), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.43210
# 2014-12-26    1.96490
# 2015-02-12    2.48310
# 2015-03-08   -0.57245
#                ...
# 2018-12-05    1.49250
# 2018-12-17    3.98010
# 2018-12-29    4.66070
# 2019-01-10    5.39060
# 2019-01-22    7.64410
# Name: (-120.4067, 36.2052), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.30990
# 2014-12-26    1.95410
# 2015-02-12    2.53260
# 2015-03-08   -0.26671
#                ...
# 2018-12-05    0.44310
# 2018-12-17    3.59580
# 2018-12-29    4.17390
# 2019-01-10    4.98810
# 2019-01-22    6.91830
# Name: (-120.3967, 36.1932), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.23040
# 2014-12-26    1.99330
# 2015-02-12    2.41170
# 2015-03-08   -0.18018
#                ...
# 2018-12-05   -0.24010
# 2018-12-17    3.02520
# 2018-12-29    3.60780
# 2019-01-10    4.31280
# 2019-01-22    5.80630
# Name: (-120.3887, 36.1812), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.34870
# 2014-12-26    1.91370
# 2015-02-12    2.21960
# 2015-03-08   -0.30157
#                ...
# 2018-12-05   -0.20960
# 2018-12-17    2.99380
# 2018-12-29    3.61410
# 2019-01-10    4.08300
# 2019-01-22    5.40110
# Name: (-120.3787, 36.1692), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.46930
# 2014-12-26    1.77660
# 2015-02-12    1.91240
# 2015-03-08   -0.48145
#                ...
# 2018-12-05   -1.58450
# 2018-12-17    1.41830
# 2018-12-29    2.01150
# 2019-01-10    2.36870
# 2019-01-22    3.47910
# Name: (-120.3707, 36.1572), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.50100
# 2014-12-26    1.68450
# 2015-02-12    1.49430
# 2015-03-08   -0.50771
#                ...
# 2018-12-05   -1.56940
# 2018-12-17    1.89430
# 2018-12-29    2.48400
# 2019-01-10    2.92360
# 2019-01-22    4.37970
# Name: (-120.3607, 36.1452), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.59250
# 2014-12-26    1.78100
# 2015-02-12    1.48600
# 2015-03-08   -0.48319
#                ...
# 2018-12-05   -1.99280
# 2018-12-17    1.50740
# 2018-12-29    2.02990
# 2019-01-10    2.45020
# 2019-01-22    4.27420
# Name: (-120.3507, 36.1312), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.68120
# 2014-12-26    1.90660
# 2015-02-12    1.85430
# 2015-03-08   -0.58637
#                ...
# 2018-12-05   -2.70660
# 2018-12-17    0.62181
# 2018-12-29    1.28770
# 2019-01-10    1.62700
# 2019-01-22    3.41870
# Name: (-120.3427, 36.1192), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.38520
# 2014-12-26    1.84830
# 2015-02-12    1.99100
# 2015-03-08   -0.55321
#                ...
# 2018-12-05   -3.56590
# 2018-12-17   -0.45285
# 2018-12-29    0.44900
# 2019-01-10    0.76994
# 2019-01-22    2.52070
# Name: (-120.3327, 36.1072), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.52860
# 2014-12-26    1.57160
# 2015-02-12    2.65800
# 2015-03-08   -0.74626
#                ...
# 2018-12-05    0.51274
# 2018-12-17    3.00710
# 2018-12-29    5.03730
# 2019-01-10    4.17020
# 2019-01-22    5.40640
# Name: (-120.1128, 35.8111), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.44100
# 2014-12-26    1.65370
# 2015-02-12    2.46480
# 2015-03-08   -0.84325
#                ...
# 2018-12-05   -0.46837
# 2018-12-17    2.76000
# 2018-12-29    4.71630
# 2019-01-10    3.70510
# 2019-01-22    5.17230
# Name: (-120.1048, 35.7971), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.31430
# 2014-12-26    1.78440
# 2015-02-12    2.60470
# 2015-03-08   -0.67253
#                ...
# 2018-12-05   -1.17020
# 2018-12-17    2.69260
# 2018-12-29    4.81000
# 2019-01-10    3.86770
# 2019-01-22    5.39540
# Name: (-120.0948, 35.7851), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.38630
# 2014-12-26    1.88720
# 2015-02-12    2.34360
# 2015-03-08   -0.56009
#                ...
# 2018-12-05   -1.54900
# 2018-12-17    2.37180
# 2018-12-29    4.47740
# 2019-01-10    3.30320
# 2019-01-22    4.94400
# Name: (-120.0868, 35.7731), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.39420
# 2014-12-26    1.85750
# 2015-02-12    2.77710
# 2015-03-08   -0.44897
#                ...
# 2018-12-05    0.56245
# 2018-12-17    3.52060
# 2018-12-29    5.57130
# 2019-01-10    4.41320
# 2019-01-22    5.85920
# Name: (-120.0668, 35.7491), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.51820
# 2014-12-26    1.74390
# 2015-02-12    3.10870
# 2015-03-08   -0.73974
#                ...
# 2018-12-05    1.31470
# 2018-12-17    3.67550
# 2018-12-29    5.49130
# 2019-01-10    4.51530
# 2019-01-22    5.57680
# Name: (-120.0308, 35.6991), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -7.4638
# 2014-12-26    2.0320
# 2015-02-12    3.4509
# 2015-03-08   -0.5245
#                ...
# 2018-12-05    2.5330
# 2018-12-17    4.9901
# 2018-12-29    6.7243
# 2019-01-10    5.7502
# 2019-01-22    6.7971
# Name: (-120.0228, 35.6871), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.562800
# 2014-12-26    1.911900
# 2015-02-12    3.723100
# 2015-03-08    0.045921
#                 ...
# 2018-12-05    2.894500
# 2018-12-17    5.650400
# 2018-12-29    7.528200
# 2019-01-10    6.632100
# 2019-01-22    7.733600
# Name: (-120.0128, 35.6731), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.64700
# 2014-12-26    1.96300
# 2015-02-12    3.24960
# 2015-03-08   -0.82084
#                ...
# 2018-12-05    0.65232
# 2018-12-17    3.34840
# 2018-12-29    5.11020
# 2019-01-10    4.13640
# 2019-01-22    5.05740
# Name: (-120.0048, 35.6611), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.39990
# 2014-12-26    1.56410
# 2015-02-12    3.06860
# 2015-03-08   -0.47821
#                ...
# 2018-12-05    1.39200
# 2018-12-17    4.11060
# 2018-12-29    6.03940
# 2019-01-10    5.07720
# 2019-01-22    5.94730
# Name: (-119.9768, 35.6251), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.29880
# 2014-12-26    1.45100
# 2015-02-12    2.79900
# 2015-03-08   -0.52687
#                ...
# 2018-12-05    2.71250
# 2018-12-17    5.46130
# 2018-12-29    7.13750
# 2019-01-10    6.38120
# 2019-01-22    7.17420
# Name: (-119.9668, 35.6111), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -7.2612
# 2014-12-26    1.4017
# 2015-02-12    2.5445
# 2015-03-08   -1.0101
#                ...
# 2018-12-05    1.0426
# 2018-12-17    4.0269
# 2018-12-29    5.4889
# 2019-01-10    4.7073
# 2019-01-22    5.3411
# Name: (-119.9588, 35.5991), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.022400
# 2014-12-26    1.316400
# 2015-02-12    2.538900
# 2015-03-08   -1.133800
#                 ...
# 2018-12-05    0.033626
# 2018-12-17    3.149900
# 2018-12-29    4.526000
# 2019-01-10    3.648800
# 2019-01-22    4.101100
# Name: (-119.9488, 35.5871), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.94930
# 2014-12-26    1.25840
# 2015-02-12    2.75180
# 2015-03-08   -1.07530
#                ...
# 2018-12-05    0.43053
# 2018-12-17    3.68080
# 2018-12-29    5.12270
# 2019-01-10    4.14130
# 2019-01-22    4.46420
# Name: (-119.9408, 35.5751), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.027700
# 2014-12-26    1.368300
# 2015-02-12    2.801300
# 2015-03-08   -1.145500
#                 ...
# 2018-12-05   -0.018432
# 2018-12-17    3.468200
# 2018-12-29    4.906800
# 2019-01-10    3.819200
# 2019-01-22    4.047200
# Name: (-119.9308, 35.5631), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.90110
# 2014-12-26    1.38000
# 2015-02-12    2.68550
# 2015-03-08   -1.21920
#                ...
# 2018-12-05    0.36848
# 2018-12-17    3.60430
# 2018-12-29    5.16530
# 2019-01-10    4.04530
# 2019-01-22    4.23250
# Name: (-119.9228, 35.5491), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.88980
# 2014-12-26    1.31110
# 2015-02-12    2.60070
# 2015-03-08   -1.26110
#                ...
# 2018-12-05    0.29419
# 2018-12-17    3.30830
# 2018-12-29    5.01680
# 2019-01-10    3.90520
# 2019-01-22    4.03100
# Name: (-119.9129, 35.5371), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.89200
# 2014-12-26    1.20750
# 2015-02-12    2.43200
# 2015-03-08   -1.52970
#                ...
# 2018-12-05   -0.15896
# 2018-12-17    2.72490
# 2018-12-29    4.38840
# 2019-01-10    3.23190
# 2019-01-22    3.31110
# Name: (-119.9049, 35.5251), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -6.896000
# 2014-12-26    1.132700
# 2015-02-12    2.465700
# 2015-03-08   -1.685400
#                 ...
# 2018-12-05   -0.098789
# 2018-12-17    2.964300
# 2018-12-29    4.390100
# 2019-01-10    3.311000
# 2019-01-22    3.312900
# Name: (-119.8949, 35.5131), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.02910
# 2014-12-26    0.88750
# 2015-02-12    2.15380
# 2015-03-08   -1.79920
#                ...
# 2018-12-05   -0.41997
# 2018-12-17    2.69110
# 2018-12-29    3.89880
# 2019-01-10    2.97200
# 2019-01-22    2.75870
# Name: (-119.8869, 35.5011), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.07670
# 2014-12-26    0.75469
# 2015-02-12    1.91840
# 2015-03-08   -1.95230
#                ...
# 2018-12-05   -0.66936
# 2018-12-17    2.31320
# 2018-12-29    3.57040
# 2019-01-10    2.54960
# 2019-01-22    2.40770
# Name: (-119.8769, 35.489), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.20730
# 2014-12-26    0.47376
# 2015-02-12    1.39820
# 2015-03-08   -2.25070
#                ...
# 2018-12-05   -0.69591
# 2018-12-17    2.27620
# 2018-12-29    3.43030
# 2019-01-10    2.37910
# 2019-01-22    2.48210
# Name: (-119.8689, 35.475), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.53640
# 2014-12-26   -2.20250
# 2015-02-12   -1.09430
# 2015-03-08   -4.58530
#                ...
# 2018-12-05   -4.03520
# 2018-12-17    0.67478
# 2018-12-29    1.20750
# 2019-01-10    0.52673
# 2019-01-22   -0.21697
# Name: (-119.7509, 35.315), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.45000
# 2014-12-26    1.59720
# 2015-02-12    2.25730
# 2015-03-08   -0.62307
#                ...
# 2018-12-05    1.28290
# 2018-12-17    4.20970
# 2018-12-29    4.42000
# 2019-01-10    5.10880
# 2019-01-22    6.87750
# Name: (-120.3827, 36.2012), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.36000
# 2014-12-26    1.85760
# 2015-02-12    2.56930
# 2015-03-08   -0.12685
#                ...
# 2018-12-05   -0.44518
# 2018-12-17    2.71520
# 2018-12-29    2.95480
# 2019-01-10    3.50470
# 2019-01-22    5.48940
# Name: (-120.3727, 36.1892), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.24640
# 2014-12-26    1.42110
# 2015-02-12    2.11320
# 2015-03-08   -0.45231
#                ...
# 2018-12-05   -0.16323
# 2018-12-17    2.83620
# 2018-12-29    3.21880
# 2019-01-10    3.80090
# 2019-01-22    5.97730
# Name: (-120.3627, 36.1772), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.46950
# 2014-12-26    1.64040
# 2015-02-12    1.96660
# 2015-03-08   -0.51309
#                ...
# 2018-12-05   -1.62040
# 2018-12-17    1.34670
# 2018-12-29    1.85660
# 2019-01-10    2.32420
# 2019-01-22    3.83640
# Name: (-120.3547, 36.1632), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.51940
# 2014-12-26    1.68910
# 2015-02-12    1.73840
# 2015-03-08   -0.65219
#                ...
# 2018-12-05   -2.47380
# 2018-12-17    0.78197
# 2018-12-29    1.38010
# 2019-01-10    1.80130
# 2019-01-22    3.20040
# Name: (-120.3447, 36.1512), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.70080
# 2014-12-26    1.45900
# 2015-02-12    1.57780
# 2015-03-08   -0.82869
#                ...
# 2018-12-05   -4.97780
# 2018-12-17   -2.06650
# 2018-12-29   -1.59740
# 2019-01-10   -1.17650
# 2019-01-22    0.17556
# Name: (-120.3367, 36.1392), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.56950
# 2014-12-26    1.61240
# 2015-02-12    1.66090
# 2015-03-08   -0.81701
#                ...
# 2018-12-05   -4.15760
# 2018-12-17   -1.01160
# 2018-12-29   -0.43734
# 2019-01-10   -0.17696
# 2019-01-22    1.36940
# Name: (-120.3268, 36.1272), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.32710
# 2014-12-26    1.99760
# 2015-02-12    2.05900
# 2015-03-08   -0.46713
#                ...
# 2018-12-05   -4.41440
# 2018-12-17   -1.17530
# 2018-12-29   -0.37708
# 2019-01-10   -0.19748
# 2019-01-22    1.63470
# Name: (-120.3168, 36.1152), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.25310
# 2014-12-26    1.73960
# 2015-02-12    2.08260
# 2015-03-08   -0.42629
#                ...
# 2018-12-05   -1.89030
# 2018-12-17    0.98837
# 2018-12-29    1.96540
# 2019-01-10    2.03230
# 2019-01-22    3.88080
# Name: (-120.3088, 36.1032), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.575900
# 2014-12-26    1.951100
# 2015-02-12    2.298300
# 2015-03-08   -0.874770
#                 ...
# 2018-12-05    0.057092
# 2018-12-17    3.888900
# 2018-12-29    5.787000
# 2019-01-10    4.666400
# 2019-01-22    6.030600
# Name: (-120.1348, 35.8671), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.57250
# 2014-12-26    1.94790
# 2015-02-12    2.31110
# 2015-03-08   -0.83709
#                ...
# 2018-12-05    0.80834
# 2018-12-17    4.47420
# 2018-12-29    6.38880
# 2019-01-10    5.12690
# 2019-01-22    6.42600
# Name: (-120.1248, 35.8551), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.52830
# 2014-12-26    1.77970
# 2015-02-12    2.31490
# 2015-03-08   -0.76843
#                ...
# 2018-12-05    0.00425
# 2018-12-17    2.97680
# 2018-12-29    5.20500
# 2019-01-10    4.02920
# 2019-01-22    5.50170
# Name: (-120.1168, 35.8431), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.514600
# 2014-12-26    1.614900
# 2015-02-12    2.571200
# 2015-03-08   -0.711300
#                 ...
# 2018-12-05   -0.074399
# 2018-12-17    2.753300
# 2018-12-29    4.814900
# 2019-01-10    3.626000
# 2019-01-22    5.089300
# Name: (-120.1068, 35.8291), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.441300
# 2014-12-26    1.611600
# 2015-02-12    2.867000
# 2015-03-08   -0.631830
#                 ...
# 2018-12-05    0.041718
# 2018-12-17    3.058200
# 2018-12-29    4.927300
# 2019-01-10    3.905700
# 2019-01-22    5.353100
# Name: (-120.0988, 35.8171), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.44260
# 2014-12-26    1.58440
# 2015-02-12    2.89080
# 2015-03-08   -0.80854
#                ...
# 2018-12-05   -0.84764
# 2018-12-17    2.19610
# 2018-12-29    4.18610
# 2019-01-10    3.28220
# 2019-01-22    4.70470
# Name: (-120.0888, 35.8051), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.28910
# 2014-12-26    1.77870
# 2015-02-12    2.80770
# 2015-03-08   -0.68596
#                ...
# 2018-12-05   -0.92072
# 2018-12-17    2.24640
# 2018-12-29    4.46350
# 2019-01-10    3.50110
# 2019-01-22    4.98460
# Name: (-120.0788, 35.7931), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.33650
# 2014-12-26    2.02280
# 2015-02-12    3.05240
# 2015-03-08   -0.41108
#                ...
# 2018-12-05   -2.69090
# 2018-12-17    0.81871
# 2018-12-29    2.95670
# 2019-01-10    1.80880
# 2019-01-22    3.44900
# Name: (-120.0708, 35.7811), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.31250
# 2014-12-26    2.12740
# 2015-02-12    3.57680
# 2015-03-08    0.48426
#                ...
# 2018-12-05   -3.00830
# 2018-12-17    0.81572
# 2018-12-29    2.89020
# 2019-01-10    1.74140
# 2019-01-22    3.44970
# Name: (-120.0608, 35.7671), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.43710
# 2014-12-26    1.88110
# 2015-02-12    2.78140
# 2015-03-08   -0.37575
#                ...
# 2018-12-05    1.25480
# 2018-12-17    4.12230
# 2018-12-29    6.24240
# 2019-01-10    4.81680
# 2019-01-22    6.44470
# Name: (-120.0528, 35.7551), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -7.3256
# 2014-12-26    1.5486
# 2015-02-12    2.9350
# 2015-03-08   -0.7674
#                ...
# 2018-12-05    1.2032
# 2018-12-17    3.7333
# 2018-12-29    5.5626
# 2019-01-10    4.7198
# 2019-01-22    5.7166
# Name: (-119.9968, 35.6811), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.344400
# 2014-12-26    1.990400
# 2015-02-12    3.814500
# 2015-03-08    0.004537
#                 ...
# 2018-12-05   -0.660600
# 2018-12-17    2.172300
# 2018-12-29    4.242300
# 2019-01-10    3.482400
# 2019-01-22    4.519300
# Name: (-119.9888, 35.6691), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.17450
# 2014-12-26    2.19170
# 2015-02-12    3.94110
# 2015-03-08    0.23865
#                ...
# 2018-12-05    1.16920
# 2018-12-17    4.13600
# 2018-12-29    6.24060
# 2019-01-10    5.37910
# 2019-01-22    6.46960
# Name: (-119.9788, 35.6571), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -6.942200
# 2014-12-26    1.586500
# 2015-02-12    3.282000
# 2015-03-08   -0.070006
#                 ...
# 2018-12-05    0.535730
# 2018-12-17    3.601500
# 2018-12-29    5.463300
# 2019-01-10    4.791000
# 2019-01-22    5.796600
# Name: (-119.9528, 35.6191), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.09670
# 2014-12-26    1.42960
# 2015-02-12    2.74690
# 2015-03-08   -0.87722
#                ...
# 2018-12-05    1.35010
# 2018-12-17    4.62370
# 2018-12-29    6.05580
# 2019-01-10    5.25180
# 2019-01-22    5.99720
# Name: (-119.9428, 35.6071), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.05610
# 2014-12-26    1.42000
# 2015-02-12    2.74090
# 2015-03-08   -1.08080
#                ...
# 2018-12-05    0.46365
# 2018-12-17    4.01520
# 2018-12-29    5.21060
# 2019-01-10    4.30240
# 2019-01-22    4.92760
# Name: (-119.9348, 35.5951), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.92360
# 2014-12-26    1.33260
# 2015-02-12    2.90370
# 2015-03-08   -1.08000
#                ...
# 2018-12-05    0.37899
# 2018-12-17    4.00660
# 2018-12-29    5.30630
# 2019-01-10    4.30000
# 2019-01-22    4.62430
# Name: (-119.9248, 35.5831), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.92550
# 2014-12-26    1.30690
# 2015-02-12    2.83440
# 2015-03-08   -1.13440
#                ...
# 2018-12-05    0.56872
# 2018-12-17    4.08470
# 2018-12-29    5.58410
# 2019-01-10    4.40890
# 2019-01-22    4.71950
# Name: (-119.9168, 35.5691), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.86800
# 2014-12-26    1.29190
# 2015-02-12    2.84110
# 2015-03-08   -1.24750
#                ...
# 2018-12-05   -0.10368
# 2018-12-17    3.24560
# 2018-12-29    4.89230
# 2019-01-10    3.53860
# 2019-01-22    3.84580
# Name: (-119.9069, 35.5571), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -6.7694
# 2014-12-26    1.3065
# 2015-02-12    2.7833
# 2015-03-08   -1.2762
#                ...
# 2018-12-05    0.3675
# 2018-12-17    3.5684
# 2018-12-29    5.1752
# 2019-01-10    3.8290
# 2019-01-22    4.1128
# Name: (-119.8989, 35.5451), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -6.784300
# 2014-12-26    1.280400
# 2015-02-12    2.664200
# 2015-03-08   -1.388700
#                 ...
# 2018-12-05    0.049572
# 2018-12-17    3.085700
# 2018-12-29    4.697300
# 2019-01-10    3.432100
# 2019-01-22    3.671600
# Name: (-119.8889, 35.5331), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.75980
# 2014-12-26    1.31670
# 2015-02-12    2.73270
# 2015-03-08   -1.45530
#                ...
# 2018-12-05   -0.12624
# 2018-12-17    2.42860
# 2018-12-29    4.33870
# 2019-01-10    3.00760
# 2019-01-22    3.24270
# Name: (-119.8789, 35.5211), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.84710
# 2014-12-26    1.20510
# 2015-02-12    2.52660
# 2015-03-08   -1.53650
#                ...
# 2018-12-05   -0.22844
# 2018-12-17    2.04780
# 2018-12-29    4.14960
# 2019-01-10    3.01560
# 2019-01-22    3.07030
# Name: (-119.8709, 35.5071), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.97910
# 2014-12-26    0.98508
# 2015-02-12    2.19850
# 2015-03-08   -1.82510
#                ...
# 2018-12-05   -0.60426
# 2018-12-17    1.83880
# 2018-12-29    3.61630
# 2019-01-10    2.40770
# 2019-01-22    2.52150
# Name: (-119.8609, 35.495), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.15740
# 2014-12-26    0.69196
# 2015-02-12    1.88450
# 2015-03-08   -2.03630
#                ...
# 2018-12-05   -0.54428
# 2018-12-17    1.92020
# 2018-12-29    3.44920
# 2019-01-10    2.20440
# 2019-01-22    2.49730
# Name: (-119.8529, 35.483), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.18490
# 2014-12-26    0.56869
# 2015-02-12    1.72690
# 2015-03-08   -2.16460
#                ...
# 2018-12-05   -0.57253
# 2018-12-17    2.08690
# 2018-12-29    3.36790
# 2019-01-10    2.22470
# 2019-01-22    2.44510
# Name: (-119.8429, 35.471), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.26010
# 2014-12-26    0.38125
# 2015-02-12    1.54860
# 2015-03-08   -2.34630
#                ...
# 2018-12-05   -1.08120
# 2018-12-17    2.14730
# 2018-12-29    3.10590
# 2019-01-10    1.87170
# 2019-01-22    2.01170
# Name: (-119.8349, 35.459), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.590200
# 2014-12-26   -0.064864
# 2015-02-12    0.920620
# 2015-03-08   -2.682000
#                 ...
# 2018-12-05   -0.872410
# 2018-12-17    2.059700
# 2018-12-29    3.341600
# 2019-01-10    2.220400
# 2019-01-22    2.184100
# Name: (-119.8249, 35.445), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.29720
# 2014-12-26   -1.74490
# 2015-02-12   -0.69188
# 2015-03-08   -4.26350
#                ...
# 2018-12-05   -2.64460
# 2018-12-17    0.72551
# 2018-12-29    1.71090
# 2019-01-10    1.17970
# 2019-01-22    0.49610
# Name: (-119.7349, 35.321), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.10810
# 2014-12-26   -1.86170
# 2015-02-12   -0.58807
# 2015-03-08   -4.28570
#                ...
# 2018-12-05   -3.35210
# 2018-12-17    0.10369
# 2018-12-29    1.08620
# 2019-01-10    0.39002
# 2019-01-22   -0.14523
# Name: (-119.7269, 35.309), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -7.668800
# 2014-12-26    0.069347
# 2015-02-12    1.249600
# 2015-03-08   -0.756750
#                 ...
# 2018-12-05   -0.633830
# 2018-12-17    2.994800
# 2018-12-29    3.003100
# 2019-01-10    3.626400
# 2019-01-22    5.006100
# Name: (-120.6527, 36.5913), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.60190
# 2014-12-26    1.64370
# 2015-02-12    1.92370
# 2015-03-08   -0.89133
#                ...
# 2018-12-05   -1.07240
# 2018-12-17    1.76150
# 2018-12-29    1.85340
# 2019-01-10    2.47750
# 2019-01-22    4.03820
# Name: (-120.3667, 36.2092), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.56230
# 2014-12-26    1.30000
# 2015-02-12    1.45820
# 2015-03-08   -1.01040
#                ...
# 2018-12-05   -2.81460
# 2018-12-17    0.48307
# 2018-12-29    0.58490
# 2019-01-10    1.12560
# 2019-01-22    2.97050
# Name: (-120.3567, 36.1952), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.50190
# 2014-12-26    1.43240
# 2015-02-12    2.15460
# 2015-03-08   -0.14556
#                ...
# 2018-12-05    0.12365
# 2018-12-17    2.85320
# 2018-12-29    3.00840
# 2019-01-10    3.53720
# 2019-01-22    5.61590
# Name: (-120.3487, 36.1832), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.52790
# 2014-12-26    1.43070
# 2015-02-12    2.01890
# 2015-03-08   -0.85984
#                ...
# 2018-12-05   -2.30240
# 2018-12-17    0.15167
# 2018-12-29    0.54314
# 2019-01-10    1.01590
# 2019-01-22    3.27120
# Name: (-120.3387, 36.1712), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.56000
# 2014-12-26    1.71170
# 2015-02-12    2.49780
# 2015-03-08    0.15223
#                ...
# 2018-12-05   -2.46160
# 2018-12-17    0.26363
# 2018-12-29    0.84429
# 2019-01-10    1.33270
# 2019-01-22    3.57590
# Name: (-120.3288, 36.1592), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.47840
# 2014-12-26    1.54820
# 2015-02-12    1.60030
# 2015-03-08   -0.75649
#                ...
# 2018-12-05   -5.13180
# 2018-12-17   -2.81640
# 2018-12-29   -2.35210
# 2019-01-10   -1.99310
# 2019-01-22   -0.58258
# Name: (-120.3208, 36.1472), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.37780
# 2014-12-26    1.78910
# 2015-02-12    1.91650
# 2015-03-08   -0.31726
#                ...
# 2018-12-05   -5.56660
# 2018-12-17   -2.76110
# 2018-12-29   -1.93920
# 2019-01-10   -1.65350
# 2019-01-22   -0.13730
# Name: (-120.3108, 36.1352), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.27280
# 2014-12-26    1.61330
# 2015-02-12    1.80100
# 2015-03-08   -0.29122
#                ...
# 2018-12-05   -7.06130
# 2018-12-17   -4.05790
# 2018-12-29   -3.08030
# 2019-01-10   -2.98470
# 2019-01-22   -1.31280
# Name: (-120.3028, 36.1212), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.12080
# 2014-12-26    1.53690
# 2015-02-12    1.45000
# 2015-03-08   -0.71152
#                ...
# 2018-12-05   -7.58090
# 2018-12-17   -4.58260
# 2018-12-29   -3.73390
# 2019-01-10   -3.69610
# 2019-01-22   -1.68440
# Name: (-120.2928, 36.1092), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -6.1240
# 2014-12-26    1.3360
# 2015-02-12    1.5989
# 2015-03-08   -0.9141
#                ...
# 2018-12-05   -6.7898
# 2018-12-17   -3.4246
# 2018-12-29   -2.9181
# 2019-01-10   -3.0505
# 2019-01-22   -1.1070
# Name: (-120.2828, 36.0972), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.08100
# 2014-12-26    1.51080
# 2015-02-12    2.20570
# 2015-03-08   -0.53858
#                ...
# 2018-12-05   -0.80579
# 2018-12-17    2.98360
# 2018-12-29    3.55640
# 2019-01-10    3.51320
# 2019-01-22    5.18570
# Name: (-120.2748, 36.0852), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -5.99250
# 2014-12-26    1.43620
# 2015-02-12    2.50250
# 2015-03-08   -0.45561
#                ...
# 2018-12-05   -0.61042
# 2018-12-17    4.08980
# 2018-12-29    4.65520
# 2019-01-10    4.64630
# 2019-01-22    5.95570
# Name: (-120.2648, 36.0732), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.51210
# 2014-12-26    1.47700
# 2015-02-12    2.83780
# 2015-03-08   -0.63197
#                ...
# 2018-12-05    0.88102
# 2018-12-17    3.98730
# 2018-12-29    4.76460
# 2019-01-10    4.24840
# 2019-01-22    6.13230
# Name: (-120.2288, 36.0232), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.74900
# 2014-12-26    1.53800
# 2015-02-12    2.67200
# 2015-03-08   -0.77953
#                ...
# 2018-12-05    0.91558
# 2018-12-17    3.24080
# 2018-12-29    4.18120
# 2019-01-10    3.51640
# 2019-01-22    5.30580
# Name: (-120.2188, 36.0112), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.98430
# 2014-12-26    1.39880
# 2015-02-12    2.48660
# 2015-03-08   -0.86188
#                ...
# 2018-12-05    0.59612
# 2018-12-17    3.20700
# 2018-12-29    4.04380
# 2019-01-10    3.50830
# 2019-01-22    5.19540
# Name: (-120.2108, 35.9972), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.46360
# 2014-12-26    1.65380
# 2015-02-12    2.98600
# 2015-03-08   -0.99143
#                ...
# 2018-12-05   -0.23247
# 2018-12-17    4.20320
# 2018-12-29    5.60810
# 2019-01-10    4.46980
# 2019-01-22    5.71540
# Name: (-120.1188, 35.8751), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.43370
# 2014-12-26    1.74880
# 2015-02-12    2.21960
# 2015-03-08   -0.82661
#                ...
# 2018-12-05   -0.48453
# 2018-12-17    3.24940
# 2018-12-29    5.30810
# 2019-01-10    3.96840
# 2019-01-22    5.36240
# Name: (-120.1008, 35.8491), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.38510
# 2014-12-26    1.59360
# 2015-02-12    2.22140
# 2015-03-08   -0.88843
#                ...
# 2018-12-05    1.46690
# 2018-12-17    4.28320
# 2018-12-29    6.61510
# 2019-01-10    5.33280
# 2019-01-22    6.80740
# Name: (-120.0908, 35.8371), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.39580
# 2014-12-26    1.59860
# 2015-02-12    2.98680
# 2015-03-08   -0.80933
#                ...
# 2018-12-05   -0.70677
# 2018-12-17    2.08510
# 2018-12-29    4.45150
# 2019-01-10    3.18700
# 2019-01-22    4.76000
# Name: (-120.0828, 35.8251), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.27580
# 2014-12-26    1.66330
# 2015-02-12    2.85790
# 2015-03-08   -0.69954
#                ...
# 2018-12-05   -3.19670
# 2018-12-17   -0.50382
# 2018-12-29    1.60270
# 2019-01-10    0.73562
# 2019-01-22    1.91690
# Name: (-120.0728, 35.8131), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.20390
# 2014-12-26    1.61550
# 2015-02-12    2.84410
# 2015-03-08   -0.78362
#                ...
# 2018-12-05   -2.91620
# 2018-12-17    0.26700
# 2018-12-29    2.45870
# 2019-01-10    1.39670
# 2019-01-22    2.85280
# Name: (-120.0648, 35.7991), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -7.1472
# 2014-12-26    1.7174
# 2015-02-12    2.9957
# 2015-03-08   -0.5174
#                ...
# 2018-12-05   -2.1148
# 2018-12-17    1.2233
# 2018-12-29    3.3861
# 2019-01-10    2.4467
# 2019-01-22    3.9671
# Name: (-120.0548, 35.7871), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.23430
# 2014-12-26    2.19560
# 2015-02-12    3.84590
# 2015-03-08    0.63892
#                ...
# 2018-12-05   -1.56310
# 2018-12-17    1.67180
# 2018-12-29    3.91190
# 2019-01-10    2.91210
# 2019-01-22    4.65400
# Name: (-120.0468, 35.7751), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.40610
# 2014-12-26    2.07770
# 2015-02-12    3.28720
# 2015-03-08   -0.13062
#                ...
# 2018-12-05    0.49897
# 2018-12-17    3.18070
# 2018-12-29    5.45880
# 2019-01-10    4.15070
# 2019-01-22    5.76870
# Name: (-120.0368, 35.7631), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.55350
# 2014-12-26    1.58610
# 2015-02-12    2.66490
# 2015-03-08   -0.72964
#                ...
# 2018-12-05    1.13580
# 2018-12-17    2.98320
# 2018-12-29    4.76050
# 2019-01-10    3.77850
# 2019-01-22    5.02060
# Name: (-120.0088, 35.7251), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.55540
# 2014-12-26    1.66320
# 2015-02-12    2.93030
# 2015-03-08   -0.61197
#                ...
# 2018-12-05    1.51790
# 2018-12-17    3.63380
# 2018-12-29    5.37330
# 2019-01-10    4.51950
# 2019-01-22    5.82620
# Name: (-120.0008, 35.7131), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.28750
# 2014-12-26    1.84140
# 2015-02-12    2.96450
# 2015-03-08   -0.77229
#                ...
# 2018-12-05    1.74520
# 2018-12-17    4.23920
# 2018-12-29    5.98940
# 2019-01-10    5.31210
# 2019-01-22    6.44930
# Name: (-119.9828, 35.6891), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.29740
# 2014-12-26    1.85420
# 2015-02-12    3.67590
# 2015-03-08   -0.35302
#                ...
# 2018-12-05    3.39130
# 2018-12-17    5.85380
# 2018-12-29    7.51010
# 2019-01-10    6.93130
# 2019-01-22    8.00180
# Name: (-119.9728, 35.6771), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.49000
# 2014-12-26    1.74760
# 2015-02-12    3.25340
# 2015-03-08   -0.85857
#                ...
# 2018-12-05    1.58570
# 2018-12-17    4.33700
# 2018-12-29    5.99870
# 2019-01-10    5.29360
# 2019-01-22    6.23330
# Name: (-119.9648, 35.6631), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -6.879100
# 2014-12-26    1.757700
# 2015-02-12    3.498700
# 2015-03-08   -0.083126
#                 ...
# 2018-12-05   -1.434500
# 2018-12-17    2.328700
# 2018-12-29    3.979400
# 2019-01-10    3.147200
# 2019-01-22    4.239300
# Name: (-119.9268, 35.6151), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.09200
# 2014-12-26    1.39970
# 2015-02-12    2.84620
# 2015-03-08   -0.99386
#                ...
# 2018-12-05    0.48432
# 2018-12-17    4.04690
# 2018-12-29    5.55950
# 2019-01-10    4.68590
# 2019-01-22    5.28230
# Name: (-119.9188, 35.6011), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.99170
# 2014-12-26    1.33690
# 2015-02-12    2.70330
# 2015-03-08   -1.06210
#                ...
# 2018-12-05    0.17456
# 2018-12-17    3.80720
# 2018-12-29    5.41920
# 2019-01-10    4.42980
# 2019-01-22    4.87880
# Name: (-119.9089, 35.5891), Length: 110, dtype: float64
# 2014-11-08    0.0000
# 2014-12-02   -6.8534
# 2014-12-26    1.2482
# 2015-02-12    2.7036
# 2015-03-08   -1.1012
#                ...
# 2018-12-05    0.4372
# 2018-12-17    4.1938
# 2018-12-29    5.9954
# 2019-01-10    4.9129
# 2019-01-22    5.2522
# Name: (-119.9009, 35.5771), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.75990
# 2014-12-26    1.25880
# 2015-02-12    2.74310
# 2015-03-08   -1.22450
#                ...
# 2018-12-05    0.14795
# 2018-12-17    3.46690
# 2018-12-29    5.24820
# 2019-01-10    3.98350
# 2019-01-22    4.28230
# Name: (-119.8909, 35.5651), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -6.683300
# 2014-12-26    1.243800
# 2015-02-12    2.682000
# 2015-03-08   -1.293500
#                 ...
# 2018-12-05    0.091176
# 2018-12-17    3.172400
# 2018-12-29    4.876300
# 2019-01-10    3.590600
# 2019-01-22    3.913100
# Name: (-119.8829, 35.5531), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.62160
# 2014-12-26    1.24280
# 2015-02-12    2.54500
# 2015-03-08   -1.32810
#                ...
# 2018-12-05    0.57735
# 2018-12-17    3.40590
# 2018-12-29    5.04010
# 2019-01-10    3.80150
# 2019-01-22    4.14330
# Name: (-119.8729, 35.5391), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.64740
# 2014-12-26    1.30620
# 2015-02-12    2.58960
# 2015-03-08   -1.35390
#                ...
# 2018-12-05    0.37513
# 2018-12-17    3.11260
# 2018-12-29    4.64660
# 2019-01-10    3.43750
# 2019-01-22    3.69690
# Name: (-119.8649, 35.5271), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -6.72630
# 2014-12-26    1.29670
# 2015-02-12    2.38360
# 2015-03-08   -1.42020
#                ...
# 2018-12-05    0.26503
# 2018-12-17    2.73620
# 2018-12-29    4.42880
# 2019-01-10    3.26720
# 2019-01-22    3.51230
# Name: (-119.8549, 35.5151), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02   -6.878100
# 2014-12-26    1.106700
# 2015-02-12    2.191600
# 2015-03-08   -1.681100
#                 ...
# 2018-12-05   -0.057408
# 2018-12-17    2.260100
# 2018-12-29    4.037800
# 2019-01-10    2.829600
# 2019-01-22    3.079300
# Name: (-119.8469, 35.5031), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.11950
# 2014-12-26    0.84295
# 2015-02-12    2.00060
# 2015-03-08   -1.90540
#                ...
# 2018-12-05   -0.20761
# 2018-12-17    1.79500
# 2018-12-29    3.86380
# 2019-01-10    2.66230
# 2019-01-22    2.93040
# Name: (-119.8369, 35.491), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.20510
# 2014-12-26    0.70231
# 2015-02-12    1.88580
# 2015-03-08   -2.05880
#                ...
# 2018-12-05   -0.35672
# 2018-12-17    1.32240
# 2018-12-29    3.46240
# 2019-01-10    2.34040
# 2019-01-22    2.60050
# Name: (-119.8289, 35.477), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.27060
# 2014-12-26    0.59645
# 2015-02-12    1.80080
# 2015-03-08   -2.15750
#                ...
# 2018-12-05   -0.33386
# 2018-12-17    1.57510
# 2018-12-29    3.70250
# 2019-01-10    2.43020
# 2019-01-22    2.54350
# Name: (-119.8189, 35.465), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.45510
# 2014-12-26    0.27838
# 2015-02-12    1.41590
# 2015-03-08   -2.36540
#                ...
# 2018-12-05   -0.43837
# 2018-12-17    1.88590
# 2018-12-29    3.94630
# 2019-01-10    2.67110
# 2019-01-22    2.68580
# Name: (-119.8109, 35.453), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -7.85940
# 2014-12-26   -0.58469
# 2015-02-12    0.58392
# 2015-03-08   -3.26260
#                ...
# 2018-12-05   -1.20170
# 2018-12-17    1.47350
# 2018-12-29    2.96320
# 2019-01-10    1.88090
# 2019-01-22    1.82070
# Name: (-119.7749, 35.403), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02   -8.00200
# 2014-12-26   -0.73673
# 2015-02-12    0.29073
# 2015-03-08   -3.32350
#                ...
# 2018-12-05   -1.68420
# 2018-12-17    1.15410
# 2018-12-29    2.60570
# 2019-01-10    1.59990
# 2019-01-22    1.57320
# ...
# Name: (-119.099, 36.3633), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.414500
# 2014-12-26   -0.113620
# 2015-02-12   -0.685120
# 2015-03-08   -0.011887
#                 ...
# 2018-12-05    1.029100
# 2018-12-17    1.892800
# 2018-12-29    1.537700
# 2019-01-10    0.754650
# 2019-01-22    0.975410
# Name: (-119.089, 36.3513), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.33750
# 2014-12-26   -0.13157
# 2015-02-12   -0.69538
# 2015-03-08   -0.35439
#                ...
# 2018-12-05    3.29360
# 2018-12-17    4.36390
# 2018-12-29    4.05170
# 2019-01-10    3.11490
# 2019-01-22    3.30670
# Name: (-119.0811, 36.3393), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.29930
# 2014-12-26   -0.11360
# 2015-02-12   -0.90702
# 2015-03-08   -0.52018
#                ...
# 2018-12-05    2.35320
# 2018-12-17    3.34930
# 2018-12-29    3.26060
# 2019-01-10    2.11870
# 2019-01-22    2.45020
# Name: (-119.0711, 36.3273), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    3.28200
# 2014-12-26    0.60602
# 2015-02-12   -0.11014
# 2015-03-08    0.14354
#                ...
# 2018-12-05    2.97710
# 2018-12-17    3.28710
# 2018-12-29    3.49140
# 2019-01-10    5.35720
# 2019-01-22    4.28150
# Name: (-119.365, 36.7574), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    3.176400
# 2014-12-26    0.452230
# 2015-02-12   -0.141990
# 2015-03-08   -0.035214
#                 ...
# 2018-12-05    2.650800
# 2018-12-17    2.897500
# 2018-12-29    3.003200
# 2019-01-10    4.887800
# 2019-01-22    3.705000
# Name: (-119.355, 36.7454), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.80950
# 2014-12-26    0.25734
# 2015-02-12   -0.24727
# 2015-03-08    0.24997
#                ...
# 2018-12-05    1.61000
# 2018-12-17    2.06530
# 2018-12-29    1.91520
# 2019-01-10    2.99160
# 2019-01-22    2.39610
# Name: (-119.309, 36.6814), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.618000
# 2014-12-26   -0.009499
# 2015-02-12   -0.498000
# 2015-03-08   -0.140900
#                 ...
# 2018-12-05    0.320230
# 2018-12-17    0.543910
# 2018-12-29    0.475530
# 2019-01-10    1.403400
# 2019-01-22    0.995960
# Name: (-119.301, 36.6694), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.72190
# 2014-12-26   -0.25240
# 2015-02-12   -0.80588
# 2015-03-08   -0.34858
#                ...
# 2018-12-05   -1.97940
# 2018-12-17   -1.81600
# 2018-12-29   -1.82070
# 2019-01-10   -0.92409
# 2019-01-22   -1.21450
# Name: (-119.291, 36.6573), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.825900
# 2014-12-26   -0.303930
# 2015-02-12   -0.778020
# 2015-03-08   -0.070248
#                 ...
# 2018-12-05    1.149200
# 2018-12-17    1.412100
# 2018-12-29    1.292400
# 2019-01-10    2.292200
# 2019-01-22    1.939500
# Name: (-119.283, 36.6453), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.79490
# 2014-12-26   -0.38472
# 2015-02-12   -0.81838
# 2015-03-08   -0.16261
#                ...
# 2018-12-05    2.01990
# 2018-12-17    2.29950
# 2018-12-29    2.11620
# 2019-01-10    2.92150
# 2019-01-22    2.78080
# Name: (-119.273, 36.6333), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.59110
# 2014-12-26   -0.51575
# 2015-02-12   -0.89691
# 2015-03-08   -0.38419
#                ...
# 2018-12-05    2.02760
# 2018-12-17    1.98970
# 2018-12-29    1.98710
# 2019-01-10    2.49790
# 2019-01-22    2.57870
# Name: (-119.265, 36.6193), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.54770
# 2014-12-26   -0.22718
# 2015-02-12   -0.41977
# 2015-03-08   -0.00420
#                ...
# 2018-12-05    1.53440
# 2018-12-17    1.44250
# 2018-12-29    1.62920
# 2019-01-10    1.99030
# 2019-01-22    2.21930
# Name: (-119.255, 36.6073), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.30850
# 2014-12-26   -0.25060
# 2015-02-12   -1.09190
# 2015-03-08   -0.36483
#                ...
# 2018-12-05    2.63580
# 2018-12-17    2.49420
# 2018-12-29    2.68810
# 2019-01-10    2.76290
# 2019-01-22    3.16390
# Name: (-119.219, 36.5573), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.06580
# 2014-12-26    0.10511
# 2015-02-12   -1.05120
# 2015-03-08   -0.01836
#                ...
# 2018-12-05    2.54640
# 2018-12-17    2.17860
# 2018-12-29    2.61640
# 2019-01-10    2.63030
# 2019-01-22    3.22440
# Name: (-119.209, 36.5453), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.64170
# 2014-12-26    0.57690
# 2015-02-12   -0.56252
# 2015-03-08   -0.19693
#                ...
# 2018-12-05    5.94440
# 2018-12-17    6.10970
# 2018-12-29    6.19840
# 2019-01-10    6.27450
# 2019-01-22    6.74880
# Name: (-119.183, 36.5073), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    1.563700
# 2014-12-26   -0.068679
# 2015-02-12   -0.984220
# 2015-03-08   -0.349650
#                 ...
# 2018-12-05    2.247600
# 2018-12-17    2.453600
# 2018-12-29    2.580800
# 2019-01-10    2.600700
# 2019-01-22    3.004300
# Name: (-119.173, 36.4953), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    1.362700
# 2014-12-26   -0.097826
# 2015-02-12   -1.108300
# 2015-03-08   -0.402150
#                 ...
# 2018-12-05    2.057100
# 2018-12-17    2.182400
# 2018-12-29    2.412500
# 2019-01-10    2.344200
# 2019-01-22    2.774600
# Name: (-119.165, 36.4833), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.16990
# 2014-12-26   -0.32705
# 2015-02-12   -1.00040
# 2015-03-08   -0.44799
#                ...
# 2018-12-05    3.25130
# 2018-12-17    3.72600
# 2018-12-29    3.81860
# 2019-01-10    3.12540
# 2019-01-22    3.84290
# Name: (-119.119, 36.4213), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.05430
# 2014-12-26   -0.24071
# 2015-02-12   -0.81482
# 2015-03-08   -0.21651
#                ...
# 2018-12-05    3.80700
# 2018-12-17    4.48590
# 2018-12-29    4.47730
# 2019-01-10    3.78270
# 2019-01-22    4.50990
# Name: (-119.111, 36.4093), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    1.069300
# 2014-12-26   -0.345540
# 2015-02-12   -0.638420
# 2015-03-08   -0.067998
#                 ...
# 2018-12-05    3.730400
# 2018-12-17    4.636000
# 2018-12-29    4.644100
# 2019-01-10    3.801700
# 2019-01-22    4.516900
# Name: (-119.101, 36.3953), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.73980
# 2014-12-26   -0.51510
# 2015-02-12   -1.00060
# 2015-03-08   -0.30346
#                ...
# 2018-12-05    1.92450
# 2018-12-17    2.80930
# 2018-12-29    2.80870
# 2019-01-10    1.89790
# 2019-01-22    2.43040
# Name: (-119.093, 36.3833), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.074100
# 2014-12-26   -1.142000
# 2015-02-12   -2.223700
# 2015-03-08   -1.516600
#                 ...
# 2018-12-05   -1.033900
# 2018-12-17   -0.053266
# 2018-12-29   -0.106480
# 2019-01-10   -0.978030
# 2019-01-22   -0.531330
# Name: (-119.0831, 36.3713), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.304600
# 2014-12-26   -0.170550
# 2015-02-12   -0.762970
# 2015-03-08    0.054744
#                 ...
# 2018-12-05    2.406500
# 2018-12-17    3.462000
# 2018-12-29    3.388500
# 2019-01-10    2.492500
# 2019-01-22    2.713500
# Name: (-119.0751, 36.3593), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.240500
# 2014-12-26   -0.170660
# 2015-02-12   -0.862350
# 2015-03-08    0.032077
#                 ...
# 2018-12-05    1.676300
# 2018-12-17    2.881500
# 2018-12-29    2.749200
# 2019-01-10    1.706000
# 2019-01-22    1.867900
# Name: (-119.0651, 36.3453), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.36160
# 2014-12-26   -0.35955
# 2015-02-12   -0.48388
# 2015-03-08   -0.67782
#                ...
# 2018-12-05    5.52660
# 2018-12-17    5.75740
# 2018-12-29    5.57220
# 2019-01-10    6.17530
# 2019-01-22    6.49100
# Name: (-119.239, 36.6153), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.247000
# 2014-12-26   -0.092324
# 2015-02-12   -0.718620
# 2015-03-08   -0.304250
#                 ...
# 2018-12-05    3.999600
# 2018-12-17    4.181500
# 2018-12-29    4.256600
# 2019-01-10    4.479600
# 2019-01-22    4.820300
# Name: (-119.195, 36.5533), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.55600
# 2014-12-26   -0.19779
# 2015-02-12   -1.05040
# 2015-03-08   -0.66455
#                ...
# 2018-12-05    3.09190
# 2018-12-17    3.29200
# 2018-12-29    3.84850
# 2019-01-10    3.48640
# 2019-01-22    3.79220
# Name: (-119.131, 36.4653), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.37610
# 2014-12-26   -0.27975
# 2015-02-12   -1.26650
# 2015-03-08   -0.73836
#                ...
# 2018-12-05    2.18660
# 2018-12-17    2.39780
# 2018-12-29    2.95030
# 2019-01-10    2.46860
# 2019-01-22    2.89930
# Name: (-119.121, 36.4533), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.36490
# 2014-12-26   -0.41312
# 2015-02-12   -1.23900
# 2015-03-08   -0.68897
#                ...
# 2018-12-05    2.71290
# 2018-12-17    3.01190
# 2018-12-29    3.42860
# 2019-01-10    2.83510
# 2019-01-22    3.42810
# Name: (-119.113, 36.4413), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.13600
# 2014-12-26   -0.23627
# 2015-02-12   -0.97420
# 2015-03-08   -0.37127
#                ...
# 2018-12-05    2.92020
# 2018-12-17    3.27920
# 2018-12-29    3.47290
# 2019-01-10    2.84360
# 2019-01-22    3.49230
# Name: (-119.103, 36.4273), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    0.97246
# 2014-12-26   -0.23085
# 2015-02-12   -0.82375
# 2015-03-08   -0.30025
#                ...
# 2018-12-05    4.27600
# 2018-12-17    4.82720
# 2018-12-29    4.95700
# 2019-01-10    4.30180
# 2019-01-22    4.99610
# Name: (-119.095, 36.4153), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    1.131900
# 2014-12-26   -0.462710
# 2015-02-12   -0.964060
# 2015-03-08    0.069145
#                 ...
# 2018-12-05    2.040300
# 2018-12-17    2.937600
# 2018-12-29    2.984400
# 2019-01-10    2.166700
# 2019-01-22    2.662600
# Name: (-119.0771, 36.3913), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    1.894100
# 2014-12-26   -0.533690
# 2015-02-12   -1.326900
# 2015-03-08    0.086378
#                 ...
# 2018-12-05    0.392170
# 2018-12-17    1.305500
# 2018-12-29    1.395300
# 2019-01-10    0.509920
# 2019-01-22    0.808140
# Name: (-119.0671, 36.3773), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.96910
# 2014-12-26   -0.29967
# 2015-02-12   -1.10880
# 2015-03-08    0.30345
#                ...
# 2018-12-05    2.99890
# 2018-12-17    4.21760
# 2018-12-29    4.28850
# 2019-01-10    3.29820
# 2019-01-22    3.58780
# Name: (-119.0591, 36.3653), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    2.23750
# 2014-12-26   -0.28642
# 2015-02-12   -0.87542
# 2015-03-08    0.45048
#                ...
# 2018-12-05    3.29830
# 2018-12-17    4.98690
# 2018-12-29    4.73710
# 2019-01-10    3.91680
# 2019-01-22    3.86810
# Name: (-119.0491, 36.3533), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    2.307500
# 2014-12-26   -0.304370
# 2015-02-12   -1.007600
# 2015-03-08   -0.062509
#                 ...
# 2018-12-05    3.541600
# 2018-12-17    5.099100
# 2018-12-29    5.025700
# 2019-01-10    3.960300
# 2019-01-22    3.943600
# Name: (-119.0411, 36.3413), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.69430
# 2014-12-26   -0.28271
# 2015-02-12   -1.02750
# 2015-03-08   -0.84999
#                ...
# 2018-12-05    3.65960
# 2018-12-17    3.76840
# 2018-12-29    4.57940
# 2019-01-10    4.09930
# 2019-01-22    4.35840
# Name: (-119.123, 36.4853), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.53620
# 2014-12-26   -0.34690
# 2015-02-12   -1.19990
# 2015-03-08   -0.87802
#                ...
# 2018-12-05    1.93520
# 2018-12-17    1.93760
# 2018-12-29    2.73480
# 2019-01-10    2.20110
# 2019-01-22    2.50190
# Name: (-119.115, 36.4733), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.43480
# 2014-12-26   -0.55832
# 2015-02-12   -1.41800
# 2015-03-08   -0.90070
#                ...
# 2018-12-05    4.01690
# 2018-12-17    4.12990
# 2018-12-29    4.73950
# 2019-01-10    4.13520
# 2019-01-22    4.61010
# Name: (-119.097, 36.4473), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.31000
# 2014-12-26   -0.23915
# 2015-02-12   -1.04380
# 2015-03-08   -0.52652
#                ...
# 2018-12-05    3.09230
# 2018-12-17    3.25290
# 2018-12-29    3.73920
# 2019-01-10    3.14380
# 2019-01-22    3.79090
# Name: (-119.0871, 36.4353), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.16070
# 2014-12-26   -0.47312
# 2015-02-12   -1.10630
# 2015-03-08   -0.18794
#                ...
# 2018-12-05    1.33450
# 2018-12-17    2.02160
# 2018-12-29    2.14200
# 2019-01-10    1.41810
# 2019-01-22    2.04760
# Name: (-119.0691, 36.4113), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.33270
# 2014-12-26   -0.35799
# 2015-02-12   -0.99281
# 2015-03-08    0.21843
#                ...
# 2018-12-05    3.00820
# 2018-12-17    3.94420
# 2018-12-29    4.06750
# 2019-01-10    3.32740
# 2019-01-22    3.89570
# Name: (-119.0611, 36.3973), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.46590
# 2014-12-26   -0.48958
# 2015-02-12   -0.89463
# 2015-03-08    0.28766
#                ...
# 2018-12-05    2.51320
# 2018-12-17    3.55430
# 2018-12-29    3.82010
# 2019-01-10    2.85580
# 2019-01-22    3.36830
# Name: (-119.0511, 36.3853), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.92640
# 2014-12-26   -0.22695
# 2015-02-12   -0.94327
# 2015-03-08    0.76424
#                ...
# 2018-12-05    2.95280
# 2018-12-17    4.24310
# 2018-12-29    4.57470
# 2019-01-10    3.55080
# 2019-01-22    3.81200
# Name: (-119.0431, 36.3733), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.72180
# 2014-12-26   -0.23678
# 2015-02-12   -0.88616
# 2015-03-08   -0.82128
#                ...
# 2018-12-05    2.90330
# 2018-12-17    3.07920
# 2018-12-29    3.96650
# 2019-01-10    3.48570
# 2019-01-22    3.75810
# Name: (-119.109, 36.4913), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.60010
# 2014-12-26   -0.41287
# 2015-02-12   -1.19720
# 2015-03-08   -0.96169
#                ...
# 2018-12-05    4.04860
# 2018-12-17    4.12890
# 2018-12-29    4.86030
# 2019-01-10    4.30440
# 2019-01-22    4.87360
# Name: (-119.0811, 36.4553), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.45560
# 2014-12-26   -0.29822
# 2015-02-12   -0.88345
# 2015-03-08   -0.83602
#                ...
# 2018-12-05    3.07440
# 2018-12-17    3.41150
# 2018-12-29    3.91950
# 2019-01-10    3.30750
# 2019-01-22    3.92080
# Name: (-119.0731, 36.4433), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.30080
# 2014-12-26   -0.68062
# 2015-02-12   -1.04390
# 2015-03-08   -0.31639
#                ...
# 2018-12-05    2.24970
# 2018-12-17    3.23790
# 2018-12-29    3.68200
# 2019-01-10    2.82560
# 2019-01-22    3.27260
# Name: (-119.0451, 36.4053), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.38790
# 2014-12-26   -0.49323
# 2015-02-12   -0.86442
# 2015-03-08    0.38054
#                ...
# 2018-12-05    3.54790
# 2018-12-17    4.63990
# 2018-12-29    5.26010
# 2019-01-10    4.43960
# 2019-01-22    4.75940
# Name: (-119.0351, 36.3933), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.11820
# 2014-12-26   -0.56541
# 2015-02-12   -1.14170
# 2015-03-08    0.56859
#                ...
# 2018-12-05    3.44920
# 2018-12-17    4.75920
# 2018-12-29    5.19120
# 2019-01-10    4.30130
# 2019-01-22    4.46810
# Name: (-119.0271, 36.3793), Length: 110, dtype: float64
# 2014-11-08    0.00000
# 2014-12-02    1.63280
# 2014-12-26   -0.60332
# 2015-02-12   -1.12060
# 2015-03-08   -0.92446
#                ...
# 2018-12-05    2.60670
# 2018-12-17    2.92650
# 2018-12-29    3.69740
# 2019-01-10    2.87390
# 2019-01-22    3.43180
# Name: (-119.0571, 36.4493), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    1.400900
# 2014-12-26   -0.876770
# 2015-02-12   -1.224800
# 2015-03-08    0.077378
#                 ...
# 2018-12-05    2.786900
# 2018-12-17    3.996300
# 2018-12-29    4.377000
# 2019-01-10    3.497900
# 2019-01-22    3.681600
# Name: (-119.0211, 36.3993), Length: 110, dtype: float64
# 2014-11-08    0.000000
# 2014-12-02    1.314100
# 2014-12-26   -0.995850
# 2015-02-12   -1.195000
# 2015-03-08   -0.045293
#                 ...
# 2018-12-05    2.950600
# 2018-12-17    4.264200
# 2018-12-29    4.761900
# 2019-01-10    3.917000
# 2019-01-22    3.709600
# Name: (-119.0111, 36.3873), Length: 110, dtype: float64

# %%
# print(df2.index.values[0])
# #arr=df.loc[df.index[0]]
# if df2.index.values in df.index.values:
#     print(True)
train, test = train_test_split(df, test_size=0.2, random_state=64, shuffle=False)
train2, test2 = train_test_split(df2, test_size=0.2, random_state=64, shuffle=False)
X_train, Y_train=shaping2(datain=train,datain2=train2, timestep= timestep )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\DSFellowship\biLSTMshapingP2.ipynb Cell 17 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> train, test = train_test_split(df, test_size=0.2, random_state=64, shuffle=False)
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> train2, test2 = train_test_split(df2, test_size=0.2, random_state=64, shuffle=False)
# ----> <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> X_train, Y_train=shaping2(datain=train,datain2=train2, timestep= timestep )
#
# e:\DSFellowship\biLSTMshapingP2.ipynb Cell 17 in shaping2(datain, datain2, timestep)
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=30'>31</a>             Y_comb=np.append(Y_comb, arr3[:0,Y_start:Y_end])
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=32'>33</a> # Reshape input and target arrays
# ---> <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=33'>34</a> X_out=np.reshape(X_comb, (cnt, timestep, 2))
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=34'>35</a> Y_out=np.reshape(Y_comb, (cnt, timestep, 2))
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMshapingP2.ipynb#X21sZmlsZQ%3D%3D?line=35'>36</a> return X_out, Y_out
#
# File <__array_function__ internals>:180, in reshape(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File c:\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 54800 into shape (2730,10,2)

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
train, test = train_test_split(df, test_size=0.2, random_state=64, shuffle=False)
train, test = train_test_split(df, test_size=0.2, random_state=64, shuffle=False)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)

# %%
X_train, Y_train = shaping(datain=train,datain2=train2,timestep= timestep )

# %%
X_train, Y_train = shaping(datain=train, timestep= timestep )
# Out:
# (36400,)

# %%
X_train.shape
# Out:
# (3640, 10, 1)

# %%
Y_train[0]
# Out:
# array([[-14.835 ],
#        [ -4.9789],
#        [ -8.3433],
#        [ -6.4837],
#        [ -2.683 ],
#        [ -7.6971],
#        [ -5.2953],
#        [ -8.3121],
#        [ -5.591 ],
#        [ -2.2111]])

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model2 = Sequential(name="biLSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'accuracy'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 1456/1456 - 14s - loss: 6.8468 - mean_squared_error: 6.8468 - mean_absolute_error: 2.0178 - root_mean_squared_error: 2.6166 - 14s/epoch - 9ms/step
# Epoch 2/250
# 1456/1456 - 10s - loss: 5.2589 - mean_squared_error: 5.2589 - mean_absolute_error: 1.8092 - root_mean_squared_error: 2.2932 - 10s/epoch - 7ms/step
# Epoch 3/250
# 1456/1456 - 10s - loss: 4.6169 - mean_squared_error: 4.6169 - mean_absolute_error: 1.7040 - root_mean_squared_error: 2.1487 - 10s/epoch - 7ms/step
# Epoch 4/250
# 1456/1456 - 10s - loss: 3.8951 - mean_squared_error: 3.8951 - mean_absolute_error: 1.5620 - root_mean_squared_error: 1.9736 - 10s/epoch - 7ms/step
# Epoch 5/250
# 1456/1456 - 10s - loss: 3.3274 - mean_squared_error: 3.3274 - mean_absolute_error: 1.4265 - root_mean_squared_error: 1.8241 - 10s/epoch - 7ms/step
# Epoch 6/250
# 1456/1456 - 10s - loss: 2.7016 - mean_squared_error: 2.7016 - mean_absolute_error: 1.2646 - root_mean_squared_error: 1.6437 - 10s/epoch - 7ms/step
# Epoch 7/250
# 1456/1456 - 9s - loss: 2.1352 - mean_squared_error: 2.1352 - mean_absolute_error: 1.1109 - root_mean_squared_error: 1.4612 - 9s/epoch - 6ms/step
# Epoch 8/250
# 1456/1456 - 9s - loss: 1.7162 - mean_squared_error: 1.7162 - mean_absolute_error: 0.9927 - root_mean_squared_error: 1.3100 - 9s/epoch - 6ms/step
# Epoch 9/250
# 1456/1456 - 10s - loss: 1.2481 - mean_squared_error: 1.2481 - mean_absolute_error: 0.8274 - root_mean_squared_error: 1.1172 - 10s/epoch - 7ms/step
# Epoch 10/250
# 1456/1456 - 10s - loss: 0.9346 - mean_squared_error: 0.9346 - mean_absolute_error: 0.7082 - root_mean_squared_error: 0.9667 - 10s/epoch - 7ms/step
# Epoch 11/250
# 1456/1456 - 10s - loss: 0.7123 - mean_squared_error: 0.7123 - mean_absolute_error: 0.6218 - root_mean_squared_error: 0.8440 - 10s/epoch - 7ms/step
# Epoch 12/250
# 1456/1456 - 9s - loss: 0.5992 - mean_squared_error: 0.5992 - mean_absolute_error: 0.5728 - root_mean_squared_error: 0.7741 - 9s/epoch - 6ms/step
# Epoch 13/250
# 1456/1456 - 10s - loss: 0.5211 - mean_squared_error: 0.5211 - mean_absolute_error: 0.5297 - root_mean_squared_error: 0.7219 - 10s/epoch - 7ms/step
# Epoch 14/250
# 1456/1456 - 10s - loss: 0.3996 - mean_squared_error: 0.3996 - mean_absolute_error: 0.4685 - root_mean_squared_error: 0.6321 - 10s/epoch - 7ms/step
# Epoch 15/250
# 1456/1456 - 10s - loss: 0.4275 - mean_squared_error: 0.4275 - mean_absolute_error: 0.4779 - root_mean_squared_error: 0.6538 - 10s/epoch - 7ms/step
# Epoch 16/250
# 1456/1456 - 10s - loss: 0.3015 - mean_squared_error: 0.3015 - mean_absolute_error: 0.4080 - root_mean_squared_error: 0.5491 - 10s/epoch - 7ms/step
# Epoch 17/250
# 1456/1456 - 10s - loss: 0.3784 - mean_squared_error: 0.3784 - mean_absolute_error: 0.4450 - root_mean_squared_error: 0.6152 - 10s/epoch - 7ms/step
# Epoch 18/250
# 1456/1456 - 10s - loss: 0.3103 - mean_squared_error: 0.3103 - mean_absolute_error: 0.4038 - root_mean_squared_error: 0.5571 - 10s/epoch - 7ms/step
# Epoch 19/250
# 1456/1456 - 10s - loss: 0.2717 - mean_squared_error: 0.2717 - mean_absolute_error: 0.3838 - root_mean_squared_error: 0.5213 - 10s/epoch - 7ms/step
# Epoch 20/250
# 1456/1456 - 10s - loss: 0.2895 - mean_squared_error: 0.2895 - mean_absolute_error: 0.3868 - root_mean_squared_error: 0.5380 - 10s/epoch - 7ms/step
# Epoch 21/250
# 1456/1456 - 11s - loss: 0.2503 - mean_squared_error: 0.2503 - mean_absolute_error: 0.3703 - root_mean_squared_error: 0.5003 - 11s/epoch - 7ms/step
# Epoch 22/250
# 1456/1456 - 9s - loss: 0.2999 - mean_squared_error: 0.2999 - mean_absolute_error: 0.3789 - root_mean_squared_error: 0.5476 - 9s/epoch - 6ms/step
# Epoch 23/250
# 1456/1456 - 10s - loss: 0.2389 - mean_squared_error: 0.2389 - mean_absolute_error: 0.3533 - root_mean_squared_error: 0.4888 - 10s/epoch - 7ms/step
# Epoch 24/250
# 1456/1456 - 10s - loss: 0.2009 - mean_squared_error: 0.2009 - mean_absolute_error: 0.3378 - root_mean_squared_error: 0.4483 - 10s/epoch - 7ms/step
# Epoch 25/250
# 1456/1456 - 10s - loss: 0.2721 - mean_squared_error: 0.2721 - mean_absolute_error: 0.3708 - root_mean_squared_error: 0.5216 - 10s/epoch - 7ms/step
# Epoch 26/250
# 1456/1456 - 10s - loss: 0.1776 - mean_squared_error: 0.1776 - mean_absolute_error: 0.3143 - root_mean_squared_error: 0.4215 - 10s/epoch - 7ms/step
# Epoch 27/250
# 1456/1456 - 10s - loss: 0.1862 - mean_squared_error: 0.1862 - mean_absolute_error: 0.3219 - root_mean_squared_error: 0.4315 - 10s/epoch - 7ms/step
# Epoch 28/250
# 1456/1456 - 10s - loss: 0.2514 - mean_squared_error: 0.2514 - mean_absolute_error: 0.3602 - root_mean_squared_error: 0.5014 - 10s/epoch - 7ms/step
# Epoch 29/250
# 1456/1456 - 10s - loss: 0.1732 - mean_squared_error: 0.1732 - mean_absolute_error: 0.3099 - root_mean_squared_error: 0.4161 - 10s/epoch - 7ms/step
# Epoch 30/250
# 1456/1456 - 10s - loss: 0.1848 - mean_squared_error: 0.1848 - mean_absolute_error: 0.3168 - root_mean_squared_error: 0.4299 - 10s/epoch - 7ms/step
# Epoch 31/250
# 1456/1456 - 10s - loss: 0.1756 - mean_squared_error: 0.1756 - mean_absolute_error: 0.3109 - root_mean_squared_error: 0.4191 - 10s/epoch - 7ms/step
# Epoch 32/250
# 1456/1456 - 11s - loss: 0.1914 - mean_squared_error: 0.1914 - mean_absolute_error: 0.3190 - root_mean_squared_error: 0.4375 - 11s/epoch - 7ms/step
# Epoch 33/250
# 1456/1456 - 10s - loss: 0.1878 - mean_squared_error: 0.1878 - mean_absolute_error: 0.3109 - root_mean_squared_error: 0.4334 - 10s/epoch - 7ms/step
# Epoch 34/250
# 1456/1456 - 9s - loss: 0.1524 - mean_squared_error: 0.1524 - mean_absolute_error: 0.2887 - root_mean_squared_error: 0.3903 - 9s/epoch - 6ms/step
# Epoch 35/250
# 1456/1456 - 10s - loss: 0.1585 - mean_squared_error: 0.1585 - mean_absolute_error: 0.2932 - root_mean_squared_error: 0.3981 - 10s/epoch - 7ms/step
# Epoch 36/250
# 1456/1456 - 10s - loss: 0.1682 - mean_squared_error: 0.1682 - mean_absolute_error: 0.2984 - root_mean_squared_error: 0.4102 - 10s/epoch - 7ms/step
# Epoch 37/250
# 1456/1456 - 10s - loss: 0.2509 - mean_squared_error: 0.2509 - mean_absolute_error: 0.3394 - root_mean_squared_error: 0.5009 - 10s/epoch - 7ms/step
# Epoch 38/250
# 1456/1456 - 10s - loss: 0.1316 - mean_squared_error: 0.1316 - mean_absolute_error: 0.2653 - root_mean_squared_error: 0.3627 - 10s/epoch - 7ms/step
# Epoch 39/250
# 1456/1456 - 10s - loss: 0.1599 - mean_squared_error: 0.1599 - mean_absolute_error: 0.2919 - root_mean_squared_error: 0.3998 - 10s/epoch - 7ms/step
# Epoch 40/250
# 1456/1456 - 10s - loss: 0.1418 - mean_squared_error: 0.1418 - mean_absolute_error: 0.2753 - root_mean_squared_error: 0.3766 - 10s/epoch - 7ms/step
# Epoch 41/250
# 1456/1456 - 10s - loss: 0.1806 - mean_squared_error: 0.1806 - mean_absolute_error: 0.3049 - root_mean_squared_error: 0.4250 - 10s/epoch - 7ms/step
# Epoch 42/250
# 1456/1456 - 10s - loss: 0.1341 - mean_squared_error: 0.1341 - mean_absolute_error: 0.2683 - root_mean_squared_error: 0.3661 - 10s/epoch - 7ms/step
# Epoch 43/250
# 1456/1456 - 10s - loss: 0.1602 - mean_squared_error: 0.1602 - mean_absolute_error: 0.2857 - root_mean_squared_error: 0.4002 - 10s/epoch - 7ms/step
# Epoch 44/250
# 1456/1456 - 10s - loss: 0.1319 - mean_squared_error: 0.1319 - mean_absolute_error: 0.2656 - root_mean_squared_error: 0.3632 - 10s/epoch - 7ms/step
# Epoch 45/250
# 1456/1456 - 10s - loss: 0.1385 - mean_squared_error: 0.1385 - mean_absolute_error: 0.2726 - root_mean_squared_error: 0.3721 - 10s/epoch - 7ms/step
# Epoch 46/250
# 1456/1456 - 10s - loss: 0.1355 - mean_squared_error: 0.1355 - mean_absolute_error: 0.2706 - root_mean_squared_error: 0.3681 - 10s/epoch - 7ms/step
# Epoch 47/250
# 1456/1456 - 10s - loss: 0.1384 - mean_squared_error: 0.1384 - mean_absolute_error: 0.2744 - root_mean_squared_error: 0.3721 - 10s/epoch - 7ms/step
# Epoch 48/250
# 1456/1456 - 10s - loss: 0.1418 - mean_squared_error: 0.1418 - mean_absolute_error: 0.2712 - root_mean_squared_error: 0.3765 - 10s/epoch - 7ms/step
# Epoch 49/250
# 1456/1456 - 10s - loss: 0.1262 - mean_squared_error: 0.1262 - mean_absolute_error: 0.2592 - root_mean_squared_error: 0.3553 - 10s/epoch - 7ms/step
# Epoch 50/250
# 1456/1456 - 10s - loss: 0.1247 - mean_squared_error: 0.1247 - mean_absolute_error: 0.2565 - root_mean_squared_error: 0.3532 - 10s/epoch - 7ms/step
# Epoch 51/250
# 1456/1456 - 9s - loss: 0.1344 - mean_squared_error: 0.1344 - mean_absolute_error: 0.2660 - root_mean_squared_error: 0.3666 - 9s/epoch - 6ms/step
# Epoch 52/250
# 1456/1456 - 10s - loss: 0.1237 - mean_squared_error: 0.1237 - mean_absolute_error: 0.2567 - root_mean_squared_error: 0.3516 - 10s/epoch - 7ms/step
# Epoch 53/250
# 1456/1456 - 10s - loss: 0.1357 - mean_squared_error: 0.1357 - mean_absolute_error: 0.2680 - root_mean_squared_error: 0.3684 - 10s/epoch - 7ms/step
# Epoch 54/250
# 1456/1456 - 10s - loss: 0.1188 - mean_squared_error: 0.1188 - mean_absolute_error: 0.2516 - root_mean_squared_error: 0.3447 - 10s/epoch - 7ms/step
# Epoch 55/250
# 1456/1456 - 10s - loss: 0.1248 - mean_squared_error: 0.1248 - mean_absolute_error: 0.2570 - root_mean_squared_error: 0.3532 - 10s/epoch - 7ms/step
# Epoch 56/250
# 1456/1456 - 10s - loss: 0.1185 - mean_squared_error: 0.1185 - mean_absolute_error: 0.2527 - root_mean_squared_error: 0.3443 - 10s/epoch - 7ms/step
# Epoch 57/250
# 1456/1456 - 10s - loss: 0.1246 - mean_squared_error: 0.1246 - mean_absolute_error: 0.2570 - root_mean_squared_error: 0.3530 - 10s/epoch - 7ms/step
# Epoch 58/250
# 1456/1456 - 10s - loss: 0.1125 - mean_squared_error: 0.1125 - mean_absolute_error: 0.2443 - root_mean_squared_error: 0.3354 - 10s/epoch - 7ms/step
# Epoch 59/250
# 1456/1456 - 10s - loss: 0.1138 - mean_squared_error: 0.1138 - mean_absolute_error: 0.2449 - root_mean_squared_error: 0.3374 - 10s/epoch - 7ms/step
# Epoch 60/250
# 1456/1456 - 10s - loss: 0.1356 - mean_squared_error: 0.1356 - mean_absolute_error: 0.2647 - root_mean_squared_error: 0.3683 - 10s/epoch - 7ms/step
# Epoch 61/250
# 1456/1456 - 10s - loss: 0.1097 - mean_squared_error: 0.1097 - mean_absolute_error: 0.2410 - root_mean_squared_error: 0.3312 - 10s/epoch - 7ms/step
# Epoch 62/250
# 1456/1456 - 10s - loss: 0.1139 - mean_squared_error: 0.1139 - mean_absolute_error: 0.2441 - root_mean_squared_error: 0.3375 - 10s/epoch - 7ms/step
# Epoch 63/250
# 1456/1456 - 10s - loss: 0.1341 - mean_squared_error: 0.1341 - mean_absolute_error: 0.2546 - root_mean_squared_error: 0.3662 - 10s/epoch - 7ms/step
# Epoch 64/250
# 1456/1456 - 10s - loss: 0.1071 - mean_squared_error: 0.1071 - mean_absolute_error: 0.2370 - root_mean_squared_error: 0.3273 - 10s/epoch - 7ms/step
# Epoch 65/250
# 1456/1456 - 10s - loss: 0.1079 - mean_squared_error: 0.1079 - mean_absolute_error: 0.2380 - root_mean_squared_error: 0.3285 - 10s/epoch - 7ms/step
# Epoch 66/250
# 1456/1456 - 10s - loss: 0.1127 - mean_squared_error: 0.1127 - mean_absolute_error: 0.2446 - root_mean_squared_error: 0.3356 - 10s/epoch - 7ms/step
# Epoch 67/250
# 1456/1456 - 10s - loss: 0.1098 - mean_squared_error: 0.1098 - mean_absolute_error: 0.2398 - root_mean_squared_error: 0.3314 - 10s/epoch - 7ms/step
# Epoch 68/250
# 1456/1456 - 10s - loss: 0.1065 - mean_squared_error: 0.1065 - mean_absolute_error: 0.2366 - root_mean_squared_error: 0.3263 - 10s/epoch - 7ms/step
# Epoch 69/250
# 1456/1456 - 10s - loss: 0.1131 - mean_squared_error: 0.1131 - mean_absolute_error: 0.2441 - root_mean_squared_error: 0.3363 - 10s/epoch - 7ms/step
# Epoch 70/250
# 1456/1456 - 10s - loss: 0.1080 - mean_squared_error: 0.1080 - mean_absolute_error: 0.2377 - root_mean_squared_error: 0.3287 - 10s/epoch - 7ms/step
# Epoch 71/250
# 1456/1456 - 9s - loss: 0.1104 - mean_squared_error: 0.1104 - mean_absolute_error: 0.2404 - root_mean_squared_error: 0.3322 - 9s/epoch - 6ms/step
# Epoch 72/250
# 1456/1456 - 11s - loss: 0.1078 - mean_squared_error: 0.1078 - mean_absolute_error: 0.2380 - root_mean_squared_error: 0.3283 - 11s/epoch - 8ms/step
# Epoch 73/250
# 1456/1456 - 11s - loss: 0.1009 - mean_squared_error: 0.1009 - mean_absolute_error: 0.2279 - root_mean_squared_error: 0.3177 - 11s/epoch - 7ms/step
# Epoch 74/250
# 1456/1456 - 9s - loss: 0.1070 - mean_squared_error: 0.1070 - mean_absolute_error: 0.2367 - root_mean_squared_error: 0.3272 - 9s/epoch - 6ms/step
# Epoch 75/250
# 1456/1456 - 9s - loss: 0.1021 - mean_squared_error: 0.1021 - mean_absolute_error: 0.2294 - root_mean_squared_error: 0.3195 - 9s/epoch - 6ms/step
# Epoch 76/250
# 1456/1456 - 10s - loss: 0.1018 - mean_squared_error: 0.1018 - mean_absolute_error: 0.2278 - root_mean_squared_error: 0.3191 - 10s/epoch - 7ms/step
# Epoch 77/250
# 1456/1456 - 10s - loss: 0.1049 - mean_squared_error: 0.1049 - mean_absolute_error: 0.2332 - root_mean_squared_error: 0.3239 - 10s/epoch - 7ms/step
# Epoch 78/250
# 1456/1456 - 10s - loss: 0.1040 - mean_squared_error: 0.1040 - mean_absolute_error: 0.2328 - root_mean_squared_error: 0.3224 - 10s/epoch - 7ms/step
# Epoch 79/250
# 1456/1456 - 10s - loss: 0.1005 - mean_squared_error: 0.1005 - mean_absolute_error: 0.2289 - root_mean_squared_error: 0.3170 - 10s/epoch - 7ms/step
# Epoch 80/250
# 1456/1456 - 10s - loss: 0.0992 - mean_squared_error: 0.0992 - mean_absolute_error: 0.2271 - root_mean_squared_error: 0.3150 - 10s/epoch - 7ms/step
# Epoch 81/250
# 1456/1456 - 10s - loss: 0.1008 - mean_squared_error: 0.1008 - mean_absolute_error: 0.2310 - root_mean_squared_error: 0.3175 - 10s/epoch - 7ms/step
# Epoch 82/250
# 1456/1456 - 10s - loss: 0.0965 - mean_squared_error: 0.0965 - mean_absolute_error: 0.2233 - root_mean_squared_error: 0.3107 - 10s/epoch - 7ms/step
# Epoch 83/250
# 1456/1456 - 10s - loss: 0.0995 - mean_squared_error: 0.0995 - mean_absolute_error: 0.2271 - root_mean_squared_error: 0.3155 - 10s/epoch - 7ms/step
# Epoch 84/250
# 1456/1456 - 10s - loss: 0.0985 - mean_squared_error: 0.0985 - mean_absolute_error: 0.2259 - root_mean_squared_error: 0.3139 - 10s/epoch - 7ms/step
# Epoch 85/250
# 1456/1456 - 10s - loss: 0.0943 - mean_squared_error: 0.0943 - mean_absolute_error: 0.2215 - root_mean_squared_error: 0.3071 - 10s/epoch - 7ms/step
# Epoch 86/250
# 1456/1456 - 10s - loss: 0.0952 - mean_squared_error: 0.0952 - mean_absolute_error: 0.2218 - root_mean_squared_error: 0.3086 - 10s/epoch - 7ms/step
# Epoch 87/250
# 1456/1456 - 10s - loss: 0.0976 - mean_squared_error: 0.0976 - mean_absolute_error: 0.2242 - root_mean_squared_error: 0.3125 - 10s/epoch - 7ms/step
# Epoch 88/250
# 1456/1456 - 10s - loss: 0.0931 - mean_squared_error: 0.0931 - mean_absolute_error: 0.2187 - root_mean_squared_error: 0.3051 - 10s/epoch - 7ms/step
# Epoch 89/250
# 1456/1456 - 10s - loss: 0.0926 - mean_squared_error: 0.0926 - mean_absolute_error: 0.2176 - root_mean_squared_error: 0.3044 - 10s/epoch - 7ms/step
# Epoch 90/250
# 1456/1456 - 10s - loss: 0.1046 - mean_squared_error: 0.1046 - mean_absolute_error: 0.2292 - root_mean_squared_error: 0.3235 - 10s/epoch - 7ms/step
# Epoch 91/250
# 1456/1456 - 10s - loss: 0.0914 - mean_squared_error: 0.0914 - mean_absolute_error: 0.2173 - root_mean_squared_error: 0.3023 - 10s/epoch - 7ms/step
# Epoch 92/250
# 1456/1456 - 11s - loss: 0.0940 - mean_squared_error: 0.0940 - mean_absolute_error: 0.2195 - root_mean_squared_error: 0.3066 - 11s/epoch - 7ms/step
# Epoch 93/250
# 1456/1456 - 10s - loss: 0.0994 - mean_squared_error: 0.0994 - mean_absolute_error: 0.2256 - root_mean_squared_error: 0.3152 - 10s/epoch - 7ms/step
# Epoch 94/250
# 1456/1456 - 10s - loss: 0.0924 - mean_squared_error: 0.0924 - mean_absolute_error: 0.2181 - root_mean_squared_error: 0.3040 - 10s/epoch - 7ms/step
# Epoch 95/250
# 1456/1456 - 10s - loss: 0.0897 - mean_squared_error: 0.0897 - mean_absolute_error: 0.2129 - root_mean_squared_error: 0.2996 - 10s/epoch - 7ms/step
# Epoch 96/250
# 1456/1456 - 9s - loss: 0.0985 - mean_squared_error: 0.0985 - mean_absolute_error: 0.2231 - root_mean_squared_error: 0.3139 - 9s/epoch - 6ms/step
# Epoch 97/250
# 1456/1456 - 10s - loss: 0.0875 - mean_squared_error: 0.0875 - mean_absolute_error: 0.2098 - root_mean_squared_error: 0.2958 - 10s/epoch - 7ms/step
# Epoch 98/250
# 1456/1456 - 10s - loss: 0.0900 - mean_squared_error: 0.0900 - mean_absolute_error: 0.2145 - root_mean_squared_error: 0.3001 - 10s/epoch - 7ms/step
# Epoch 99/250
# 1456/1456 - 10s - loss: 0.0901 - mean_squared_error: 0.0901 - mean_absolute_error: 0.2121 - root_mean_squared_error: 0.3002 - 10s/epoch - 7ms/step
# Epoch 100/250
# 1456/1456 - 11s - loss: 0.1102 - mean_squared_error: 0.1102 - mean_absolute_error: 0.2273 - root_mean_squared_error: 0.3320 - val_loss: 0.1404 - val_mean_squared_error: 0.1404 - val_mean_absolute_error: 0.2391 - val_root_mean_squared_error: 0.3747 - 11s/epoch - 8ms/step
# Epoch 101/250
# 1456/1456 - 11s - loss: 0.0822 - mean_squared_error: 0.0822 - mean_absolute_error: 0.2030 - root_mean_squared_error: 0.2867 - 11s/epoch - 7ms/step
# Epoch 102/250
# 1456/1456 - 11s - loss: 0.0898 - mean_squared_error: 0.0898 - mean_absolute_error: 0.2124 - root_mean_squared_error: 0.2996 - 11s/epoch - 7ms/step
# Epoch 103/250
# 1456/1456 - 10s - loss: 0.0889 - mean_squared_error: 0.0889 - mean_absolute_error: 0.2113 - root_mean_squared_error: 0.2982 - 10s/epoch - 7ms/step
# Epoch 104/250
# 1456/1456 - 10s - loss: 0.0884 - mean_squared_error: 0.0884 - mean_absolute_error: 0.2132 - root_mean_squared_error: 0.2974 - 10s/epoch - 7ms/step
# Epoch 105/250
# 1456/1456 - 10s - loss: 0.0872 - mean_squared_error: 0.0872 - mean_absolute_error: 0.2096 - root_mean_squared_error: 0.2953 - 10s/epoch - 7ms/step
# Epoch 106/250
# 1456/1456 - 10s - loss: 0.0876 - mean_squared_error: 0.0876 - mean_absolute_error: 0.2115 - root_mean_squared_error: 0.2960 - 10s/epoch - 7ms/step
# Epoch 107/250
# 1456/1456 - 10s - loss: 0.0891 - mean_squared_error: 0.0891 - mean_absolute_error: 0.2115 - root_mean_squared_error: 0.2985 - 10s/epoch - 7ms/step
# Epoch 108/250
# 1456/1456 - 10s - loss: 0.0819 - mean_squared_error: 0.0819 - mean_absolute_error: 0.2037 - root_mean_squared_error: 0.2862 - 10s/epoch - 7ms/step
# Epoch 109/250
# 1456/1456 - 10s - loss: 0.0872 - mean_squared_error: 0.0872 - mean_absolute_error: 0.2099 - root_mean_squared_error: 0.2953 - 10s/epoch - 7ms/step
# Epoch 110/250
# 1456/1456 - 10s - loss: 0.1028 - mean_squared_error: 0.1028 - mean_absolute_error: 0.2192 - root_mean_squared_error: 0.3206 - 10s/epoch - 7ms/step
# Epoch 111/250
# 1456/1456 - 9s - loss: 0.0820 - mean_squared_error: 0.0820 - mean_absolute_error: 0.2026 - root_mean_squared_error: 0.2864 - 9s/epoch - 6ms/step
# Epoch 112/250
# 1456/1456 - 9s - loss: 0.0862 - mean_squared_error: 0.0862 - mean_absolute_error: 0.2085 - root_mean_squared_error: 0.2936 - 9s/epoch - 7ms/step
# Epoch 113/250
# 1456/1456 - 9s - loss: 0.0832 - mean_squared_error: 0.0832 - mean_absolute_error: 0.2032 - root_mean_squared_error: 0.2884 - 9s/epoch - 6ms/step
# Epoch 114/250
# 1456/1456 - 10s - loss: 0.0852 - mean_squared_error: 0.0852 - mean_absolute_error: 0.2053 - root_mean_squared_error: 0.2919 - 10s/epoch - 7ms/step
# Epoch 115/250
# 1456/1456 - 10s - loss: 0.0793 - mean_squared_error: 0.0793 - mean_absolute_error: 0.1993 - root_mean_squared_error: 0.2816 - 10s/epoch - 7ms/step
# Epoch 116/250
# 1456/1456 - 9s - loss: 0.0873 - mean_squared_error: 0.0873 - mean_absolute_error: 0.2096 - root_mean_squared_error: 0.2955 - 9s/epoch - 6ms/step
# Epoch 117/250
# 1456/1456 - 10s - loss: 0.0850 - mean_squared_error: 0.0850 - mean_absolute_error: 0.2077 - root_mean_squared_error: 0.2916 - 10s/epoch - 7ms/step
# Epoch 118/250
# 1456/1456 - 10s - loss: 0.0842 - mean_squared_error: 0.0842 - mean_absolute_error: 0.2068 - root_mean_squared_error: 0.2901 - 10s/epoch - 7ms/step
# Epoch 119/250
# 1456/1456 - 11s - loss: 0.0828 - mean_squared_error: 0.0828 - mean_absolute_error: 0.2037 - root_mean_squared_error: 0.2878 - 11s/epoch - 7ms/step
# Epoch 120/250
# 1456/1456 - 10s - loss: 0.1089 - mean_squared_error: 0.1089 - mean_absolute_error: 0.2243 - root_mean_squared_error: 0.3301 - 10s/epoch - 7ms/step
# Epoch 121/250
# 1456/1456 - 9s - loss: 0.0800 - mean_squared_error: 0.0800 - mean_absolute_error: 0.1990 - root_mean_squared_error: 0.2829 - 9s/epoch - 6ms/step
# Epoch 122/250
# 1456/1456 - 10s - loss: 0.0790 - mean_squared_error: 0.0790 - mean_absolute_error: 0.1980 - root_mean_squared_error: 0.2811 - 10s/epoch - 7ms/step
# Epoch 123/250
# 1456/1456 - 10s - loss: 0.0843 - mean_squared_error: 0.0843 - mean_absolute_error: 0.2064 - root_mean_squared_error: 0.2903 - 10s/epoch - 7ms/step
# Epoch 124/250
# 1456/1456 - 10s - loss: 0.0782 - mean_squared_error: 0.0782 - mean_absolute_error: 0.1975 - root_mean_squared_error: 0.2796 - 10s/epoch - 7ms/step
# Epoch 125/250
# 1456/1456 - 10s - loss: 0.0837 - mean_squared_error: 0.0837 - mean_absolute_error: 0.2064 - root_mean_squared_error: 0.2894 - 10s/epoch - 7ms/step
# Epoch 126/250
# 1456/1456 - 11s - loss: 0.0805 - mean_squared_error: 0.0805 - mean_absolute_error: 0.2012 - root_mean_squared_error: 0.2837 - 11s/epoch - 7ms/step
# Epoch 127/250
# 1456/1456 - 10s - loss: 0.0803 - mean_squared_error: 0.0803 - mean_absolute_error: 0.2008 - root_mean_squared_error: 0.2834 - 10s/epoch - 7ms/step
# Epoch 128/250
# 1456/1456 - 9s - loss: 0.0768 - mean_squared_error: 0.0768 - mean_absolute_error: 0.1960 - root_mean_squared_error: 0.2771 - 9s/epoch - 6ms/step
# Epoch 129/250
# 1456/1456 - 10s - loss: 0.0838 - mean_squared_error: 0.0838 - mean_absolute_error: 0.2039 - root_mean_squared_error: 0.2895 - 10s/epoch - 7ms/step
# Epoch 130/250
# 1456/1456 - 10s - loss: 0.0801 - mean_squared_error: 0.0801 - mean_absolute_error: 0.2023 - root_mean_squared_error: 0.2831 - 10s/epoch - 7ms/step
# Epoch 131/250
# 1456/1456 - 10s - loss: 0.0784 - mean_squared_error: 0.0784 - mean_absolute_error: 0.1966 - root_mean_squared_error: 0.2800 - 10s/epoch - 7ms/step
# Epoch 132/250
# 1456/1456 - 11s - loss: 0.0834 - mean_squared_error: 0.0834 - mean_absolute_error: 0.2040 - root_mean_squared_error: 0.2888 - 11s/epoch - 7ms/step
# Epoch 133/250
# 1456/1456 - 11s - loss: 0.0777 - mean_squared_error: 0.0777 - mean_absolute_error: 0.1952 - root_mean_squared_error: 0.2788 - 11s/epoch - 7ms/step
# Epoch 134/250
# 1456/1456 - 11s - loss: 0.0795 - mean_squared_error: 0.0795 - mean_absolute_error: 0.1986 - root_mean_squared_error: 0.2820 - 11s/epoch - 7ms/step
# Epoch 135/250
# 1456/1456 - 11s - loss: 0.0790 - mean_squared_error: 0.0790 - mean_absolute_error: 0.1979 - root_mean_squared_error: 0.2810 - 11s/epoch - 7ms/step
# Epoch 136/250
# 1456/1456 - 10s - loss: 0.0779 - mean_squared_error: 0.0779 - mean_absolute_error: 0.1956 - root_mean_squared_error: 0.2791 - 10s/epoch - 7ms/step
# Epoch 137/250
# 1456/1456 - 10s - loss: 0.0782 - mean_squared_error: 0.0782 - mean_absolute_error: 0.1969 - root_mean_squared_error: 0.2797 - 10s/epoch - 7ms/step
# Epoch 138/250
# 1456/1456 - 10s - loss: 0.0839 - mean_squared_error: 0.0839 - mean_absolute_error: 0.2044 - root_mean_squared_error: 0.2896 - 10s/epoch - 7ms/step
# Epoch 139/250
# 1456/1456 - 10s - loss: 0.0775 - mean_squared_error: 0.0775 - mean_absolute_error: 0.1936 - root_mean_squared_error: 0.2785 - 10s/epoch - 7ms/step
# Epoch 140/250
# 1456/1456 - 11s - loss: 0.0746 - mean_squared_error: 0.0746 - mean_absolute_error: 0.1918 - root_mean_squared_error: 0.2732 - 11s/epoch - 7ms/step
# Epoch 141/250
# 1456/1456 - 10s - loss: 0.0765 - mean_squared_error: 0.0765 - mean_absolute_error: 0.1965 - root_mean_squared_error: 0.2766 - 10s/epoch - 7ms/step
# Epoch 142/250
# 1456/1456 - 10s - loss: 0.0742 - mean_squared_error: 0.0742 - mean_absolute_error: 0.1915 - root_mean_squared_error: 0.2724 - 10s/epoch - 7ms/step
# Epoch 143/250
# 1456/1456 - 10s - loss: 0.0751 - mean_squared_error: 0.0751 - mean_absolute_error: 0.1925 - root_mean_squared_error: 0.2740 - 10s/epoch - 7ms/step
# Epoch 144/250
# 1456/1456 - 10s - loss: 0.0741 - mean_squared_error: 0.0741 - mean_absolute_error: 0.1914 - root_mean_squared_error: 0.2722 - 10s/epoch - 7ms/step
# Epoch 145/250
# 1456/1456 - 11s - loss: 0.0787 - mean_squared_error: 0.0787 - mean_absolute_error: 0.1967 - root_mean_squared_error: 0.2806 - 11s/epoch - 7ms/step
# Epoch 146/250
# 1456/1456 - 10s - loss: 0.0729 - mean_squared_error: 0.0729 - mean_absolute_error: 0.1905 - root_mean_squared_error: 0.2700 - 10s/epoch - 7ms/step
# Epoch 147/250
# 1456/1456 - 10s - loss: 0.0940 - mean_squared_error: 0.0940 - mean_absolute_error: 0.2073 - root_mean_squared_error: 0.3067 - 10s/epoch - 7ms/step
# Epoch 148/250
# 1456/1456 - 10s - loss: 0.0717 - mean_squared_error: 0.0717 - mean_absolute_error: 0.1854 - root_mean_squared_error: 0.2678 - 10s/epoch - 7ms/step
# Epoch 149/250
# 1456/1456 - 10s - loss: 0.0718 - mean_squared_error: 0.0718 - mean_absolute_error: 0.1872 - root_mean_squared_error: 0.2679 - 10s/epoch - 7ms/step
# Epoch 150/250
# 1456/1456 - 10s - loss: 0.0885 - mean_squared_error: 0.0885 - mean_absolute_error: 0.2074 - root_mean_squared_error: 0.2976 - 10s/epoch - 7ms/step
# Epoch 151/250
# 1456/1456 - 10s - loss: 0.0689 - mean_squared_error: 0.0689 - mean_absolute_error: 0.1816 - root_mean_squared_error: 0.2625 - 10s/epoch - 7ms/step
# Epoch 152/250
# 1456/1456 - 10s - loss: 0.0727 - mean_squared_error: 0.0727 - mean_absolute_error: 0.1906 - root_mean_squared_error: 0.2696 - 10s/epoch - 7ms/step
# Epoch 153/250
# 1456/1456 - 10s - loss: 0.0756 - mean_squared_error: 0.0756 - mean_absolute_error: 0.1943 - root_mean_squared_error: 0.2749 - 10s/epoch - 7ms/step
# Epoch 154/250
# 1456/1456 - 10s - loss: 0.0714 - mean_squared_error: 0.0714 - mean_absolute_error: 0.1872 - root_mean_squared_error: 0.2672 - 10s/epoch - 7ms/step
# Epoch 155/250
# 1456/1456 - 10s - loss: 0.0722 - mean_squared_error: 0.0722 - mean_absolute_error: 0.1910 - root_mean_squared_error: 0.2686 - 10s/epoch - 7ms/step
# Epoch 156/250
# 1456/1456 - 10s - loss: 0.0726 - mean_squared_error: 0.0726 - mean_absolute_error: 0.1890 - root_mean_squared_error: 0.2695 - 10s/epoch - 7ms/step
# Epoch 157/250
# 1456/1456 - 10s - loss: 0.0759 - mean_squared_error: 0.0759 - mean_absolute_error: 0.1925 - root_mean_squared_error: 0.2755 - 10s/epoch - 7ms/step
# Epoch 158/250
# 1456/1456 - 11s - loss: 0.0731 - mean_squared_error: 0.0731 - mean_absolute_error: 0.1874 - root_mean_squared_error: 0.2703 - 11s/epoch - 7ms/step
# Epoch 159/250
# 1456/1456 - 10s - loss: 0.0712 - mean_squared_error: 0.0712 - mean_absolute_error: 0.1873 - root_mean_squared_error: 0.2668 - 10s/epoch - 7ms/step
# Epoch 160/250
# 1456/1456 - 10s - loss: 0.1107 - mean_squared_error: 0.1107 - mean_absolute_error: 0.2225 - root_mean_squared_error: 0.3327 - 10s/epoch - 7ms/step
# Epoch 161/250
# 1456/1456 - 10s - loss: 0.0691 - mean_squared_error: 0.0691 - mean_absolute_error: 0.1824 - root_mean_squared_error: 0.2629 - 10s/epoch - 7ms/step
# Epoch 162/250
# 1456/1456 - 10s - loss: 0.0676 - mean_squared_error: 0.0676 - mean_absolute_error: 0.1803 - root_mean_squared_error: 0.2599 - 10s/epoch - 7ms/step
# Epoch 163/250
# 1456/1456 - 10s - loss: 0.0717 - mean_squared_error: 0.0717 - mean_absolute_error: 0.1878 - root_mean_squared_error: 0.2677 - 10s/epoch - 7ms/step
# Epoch 164/250
# 1456/1456 - 10s - loss: 0.0718 - mean_squared_error: 0.0718 - mean_absolute_error: 0.1877 - root_mean_squared_error: 0.2679 - 10s/epoch - 7ms/step
# Epoch 165/250
# 1456/1456 - 10s - loss: 0.0756 - mean_squared_error: 0.0756 - mean_absolute_error: 0.1920 - root_mean_squared_error: 0.2750 - 10s/epoch - 7ms/step
# Epoch 166/250
# 1456/1456 - 10s - loss: 0.0724 - mean_squared_error: 0.0724 - mean_absolute_error: 0.1879 - root_mean_squared_error: 0.2691 - 10s/epoch - 7ms/step
# Epoch 167/250
# 1456/1456 - 10s - loss: 0.0758 - mean_squared_error: 0.0758 - mean_absolute_error: 0.1911 - root_mean_squared_error: 0.2753 - 10s/epoch - 7ms/step
# Epoch 168/250
# 1456/1456 - 9s - loss: 0.0738 - mean_squared_error: 0.0738 - mean_absolute_error: 0.1906 - root_mean_squared_error: 0.2717 - 9s/epoch - 6ms/step
# Epoch 169/250
# 1456/1456 - 10s - loss: 0.0714 - mean_squared_error: 0.0714 - mean_absolute_error: 0.1877 - root_mean_squared_error: 0.2672 - 10s/epoch - 7ms/step
# Epoch 170/250
# 1456/1456 - 10s - loss: 0.0710 - mean_squared_error: 0.0710 - mean_absolute_error: 0.1849 - root_mean_squared_error: 0.2665 - 10s/epoch - 7ms/step
# Epoch 171/250
# 1456/1456 - 10s - loss: 0.0717 - mean_squared_error: 0.0717 - mean_absolute_error: 0.1865 - root_mean_squared_error: 0.2677 - 10s/epoch - 7ms/step
# Epoch 172/250
# 1456/1456 - 10s - loss: 0.0728 - mean_squared_error: 0.0728 - mean_absolute_error: 0.1875 - root_mean_squared_error: 0.2698 - 10s/epoch - 7ms/step
# Epoch 173/250
# 1456/1456 - 10s - loss: 0.0941 - mean_squared_error: 0.0941 - mean_absolute_error: 0.2094 - root_mean_squared_error: 0.3067 - 10s/epoch - 7ms/step
# Epoch 174/250
# 1456/1456 - 10s - loss: 0.0642 - mean_squared_error: 0.0642 - mean_absolute_error: 0.1755 - root_mean_squared_error: 0.2533 - 10s/epoch - 7ms/step
# Epoch 175/250
# 1456/1456 - 10s - loss: 0.0656 - mean_squared_error: 0.0656 - mean_absolute_error: 0.1763 - root_mean_squared_error: 0.2561 - 10s/epoch - 7ms/step
# Epoch 176/250
# 1456/1456 - 10s - loss: 0.0667 - mean_squared_error: 0.0667 - mean_absolute_error: 0.1801 - root_mean_squared_error: 0.2583 - 10s/epoch - 7ms/step
# Epoch 177/250
# 1456/1456 - 10s - loss: 0.0697 - mean_squared_error: 0.0697 - mean_absolute_error: 0.1844 - root_mean_squared_error: 0.2640 - 10s/epoch - 7ms/step
# Epoch 178/250
# 1456/1456 - 10s - loss: 0.0709 - mean_squared_error: 0.0709 - mean_absolute_error: 0.1871 - root_mean_squared_error: 0.2664 - 10s/epoch - 7ms/step
# Epoch 179/250
# 1456/1456 - 10s - loss: 0.0681 - mean_squared_error: 0.0681 - mean_absolute_error: 0.1825 - root_mean_squared_error: 0.2609 - 10s/epoch - 7ms/step
# Epoch 180/250
# 1456/1456 - 10s - loss: 0.0671 - mean_squared_error: 0.0671 - mean_absolute_error: 0.1809 - root_mean_squared_error: 0.2590 - 10s/epoch - 7ms/step
# Epoch 181/250
# 1456/1456 - 10s - loss: 0.0703 - mean_squared_error: 0.0703 - mean_absolute_error: 0.1866 - root_mean_squared_error: 0.2651 - 10s/epoch - 7ms/step
# Epoch 182/250
# 1456/1456 - 9s - loss: 0.0686 - mean_squared_error: 0.0686 - mean_absolute_error: 0.1842 - root_mean_squared_error: 0.2618 - 9s/epoch - 6ms/step
# Epoch 183/250
# 1456/1456 - 9s - loss: 0.0695 - mean_squared_error: 0.0695 - mean_absolute_error: 0.1822 - root_mean_squared_error: 0.2636 - 9s/epoch - 6ms/step
# Epoch 184/250
# 1456/1456 - 10s - loss: 0.0698 - mean_squared_error: 0.0698 - mean_absolute_error: 0.1829 - root_mean_squared_error: 0.2643 - 10s/epoch - 7ms/step
# Epoch 185/250
# 1456/1456 - 10s - loss: 0.0658 - mean_squared_error: 0.0658 - mean_absolute_error: 0.1789 - root_mean_squared_error: 0.2566 - 10s/epoch - 7ms/step
# Epoch 186/250
# 1456/1456 - 10s - loss: 0.0690 - mean_squared_error: 0.0690 - mean_absolute_error: 0.1822 - root_mean_squared_error: 0.2627 - 10s/epoch - 7ms/step
# Epoch 187/250
# 1456/1456 - 10s - loss: 0.0662 - mean_squared_error: 0.0662 - mean_absolute_error: 0.1818 - root_mean_squared_error: 0.2573 - 10s/epoch - 7ms/step
# Epoch 188/250
# 1456/1456 - 10s - loss: 0.0697 - mean_squared_error: 0.0697 - mean_absolute_error: 0.1825 - root_mean_squared_error: 0.2640 - 10s/epoch - 7ms/step
# Epoch 189/250
# 1456/1456 - 10s - loss: 0.0652 - mean_squared_error: 0.0652 - mean_absolute_error: 0.1781 - root_mean_squared_error: 0.2553 - 10s/epoch - 7ms/step
# Epoch 190/250
# 1456/1456 - 10s - loss: 0.0677 - mean_squared_error: 0.0677 - mean_absolute_error: 0.1813 - root_mean_squared_error: 0.2602 - 10s/epoch - 7ms/step
# Epoch 191/250
# 1456/1456 - 10s - loss: 0.0670 - mean_squared_error: 0.0670 - mean_absolute_error: 0.1810 - root_mean_squared_error: 0.2588 - 10s/epoch - 7ms/step
# Epoch 192/250
# 1456/1456 - 10s - loss: 0.0650 - mean_squared_error: 0.0650 - mean_absolute_error: 0.1784 - root_mean_squared_error: 0.2550 - 10s/epoch - 7ms/step
# Epoch 193/250
# 1456/1456 - 10s - loss: 0.0671 - mean_squared_error: 0.0671 - mean_absolute_error: 0.1811 - root_mean_squared_error: 0.2590 - 10s/epoch - 7ms/step
# Epoch 194/250
# 1456/1456 - 10s - loss: 0.0646 - mean_squared_error: 0.0646 - mean_absolute_error: 0.1772 - root_mean_squared_error: 0.2542 - 10s/epoch - 7ms/step
# Epoch 195/250
# 1456/1456 - 10s - loss: 0.0768 - mean_squared_error: 0.0768 - mean_absolute_error: 0.1865 - root_mean_squared_error: 0.2772 - 10s/epoch - 7ms/step
# Epoch 196/250
# 1456/1456 - 10s - loss: 0.0660 - mean_squared_error: 0.0660 - mean_absolute_error: 0.1768 - root_mean_squared_error: 0.2569 - 10s/epoch - 7ms/step
# Epoch 197/250
# 1456/1456 - 10s - loss: 0.0638 - mean_squared_error: 0.0638 - mean_absolute_error: 0.1739 - root_mean_squared_error: 0.2526 - 10s/epoch - 7ms/step
# Epoch 198/250
# 1456/1456 - 10s - loss: 0.0679 - mean_squared_error: 0.0679 - mean_absolute_error: 0.1811 - root_mean_squared_error: 0.2606 - 10s/epoch - 7ms/step
# Epoch 199/250
# 1456/1456 - 10s - loss: 0.0659 - mean_squared_error: 0.0659 - mean_absolute_error: 0.1775 - root_mean_squared_error: 0.2568 - 10s/epoch - 7ms/step
# Epoch 200/250
# 1456/1456 - 11s - loss: 0.0671 - mean_squared_error: 0.0671 - mean_absolute_error: 0.1805 - root_mean_squared_error: 0.2591 - val_loss: 0.1441 - val_mean_squared_error: 0.1441 - val_mean_absolute_error: 0.2408 - val_root_mean_squared_error: 0.3796 - 11s/epoch - 7ms/step
# Epoch 201/250
# 1456/1456 - 10s - loss: 0.0652 - mean_squared_error: 0.0652 - mean_absolute_error: 0.1786 - root_mean_squared_error: 0.2553 - 10s/epoch - 7ms/step
# Epoch 202/250
# 1456/1456 - 10s - loss: 0.0815 - mean_squared_error: 0.0815 - mean_absolute_error: 0.1916 - root_mean_squared_error: 0.2854 - 10s/epoch - 7ms/step
# Epoch 203/250
# 1456/1456 - 10s - loss: 0.0580 - mean_squared_error: 0.0580 - mean_absolute_error: 0.1659 - root_mean_squared_error: 0.2408 - 10s/epoch - 7ms/step
# Epoch 204/250
# 1456/1456 - 10s - loss: 0.0710 - mean_squared_error: 0.0710 - mean_absolute_error: 0.1830 - root_mean_squared_error: 0.2664 - 10s/epoch - 7ms/step
# Epoch 205/250
# 1456/1456 - 9s - loss: 0.0606 - mean_squared_error: 0.0606 - mean_absolute_error: 0.1692 - root_mean_squared_error: 0.2462 - 9s/epoch - 6ms/step
# Epoch 206/250
# 1456/1456 - 9s - loss: 0.0628 - mean_squared_error: 0.0628 - mean_absolute_error: 0.1751 - root_mean_squared_error: 0.2507 - 9s/epoch - 6ms/step
# Epoch 207/250
# 1456/1456 - 9s - loss: 0.0685 - mean_squared_error: 0.0685 - mean_absolute_error: 0.1794 - root_mean_squared_error: 0.2617 - 9s/epoch - 6ms/step
# Epoch 208/250
# 1456/1456 - 9s - loss: 0.0651 - mean_squared_error: 0.0651 - mean_absolute_error: 0.1764 - root_mean_squared_error: 0.2551 - 9s/epoch - 6ms/step
# Epoch 209/250
# 1456/1456 - 10s - loss: 0.0629 - mean_squared_error: 0.0629 - mean_absolute_error: 0.1748 - root_mean_squared_error: 0.2507 - 10s/epoch - 7ms/step
# Epoch 210/250
# 1456/1456 - 10s - loss: 0.0668 - mean_squared_error: 0.0668 - mean_absolute_error: 0.1791 - root_mean_squared_error: 0.2584 - 10s/epoch - 7ms/step
# Epoch 211/250
# 1456/1456 - 10s - loss: 0.0636 - mean_squared_error: 0.0636 - mean_absolute_error: 0.1739 - root_mean_squared_error: 0.2522 - 10s/epoch - 7ms/step
# Epoch 212/250
# 1456/1456 - 10s - loss: 0.0809 - mean_squared_error: 0.0809 - mean_absolute_error: 0.1913 - root_mean_squared_error: 0.2845 - 10s/epoch - 7ms/step
# Epoch 213/250
# 1456/1456 - 10s - loss: 0.0591 - mean_squared_error: 0.0591 - mean_absolute_error: 0.1657 - root_mean_squared_error: 0.2431 - 10s/epoch - 7ms/step
# Epoch 214/250
# 1456/1456 - 10s - loss: 0.0643 - mean_squared_error: 0.0643 - mean_absolute_error: 0.1764 - root_mean_squared_error: 0.2535 - 10s/epoch - 7ms/step
# Epoch 215/250
# 1456/1456 - 11s - loss: 0.0608 - mean_squared_error: 0.0608 - mean_absolute_error: 0.1722 - root_mean_squared_error: 0.2466 - 11s/epoch - 7ms/step
# Epoch 216/250
# 1456/1456 - 10s - loss: 0.0620 - mean_squared_error: 0.0620 - mean_absolute_error: 0.1742 - root_mean_squared_error: 0.2490 - 10s/epoch - 7ms/step
# Epoch 217/250
# 1456/1456 - 9s - loss: 0.0652 - mean_squared_error: 0.0652 - mean_absolute_error: 0.1778 - root_mean_squared_error: 0.2553 - 9s/epoch - 6ms/step
# Epoch 218/250
# 1456/1456 - 10s - loss: 0.0649 - mean_squared_error: 0.0649 - mean_absolute_error: 0.1765 - root_mean_squared_error: 0.2548 - 10s/epoch - 7ms/step
# Epoch 219/250
# 1456/1456 - 10s - loss: 0.0626 - mean_squared_error: 0.0626 - mean_absolute_error: 0.1719 - root_mean_squared_error: 0.2503 - 10s/epoch - 7ms/step
# Epoch 220/250
# 1456/1456 - 9s - loss: 0.0611 - mean_squared_error: 0.0611 - mean_absolute_error: 0.1740 - root_mean_squared_error: 0.2472 - 9s/epoch - 6ms/step
# Epoch 221/250
# 1456/1456 - 9s - loss: 0.0688 - mean_squared_error: 0.0688 - mean_absolute_error: 0.1826 - root_mean_squared_error: 0.2623 - 9s/epoch - 6ms/step
# Epoch 222/250
# 1456/1456 - 10s - loss: 0.0639 - mean_squared_error: 0.0639 - mean_absolute_error: 0.1747 - root_mean_squared_error: 0.2528 - 10s/epoch - 7ms/step
# Epoch 223/250
# 1456/1456 - 10s - loss: 0.0614 - mean_squared_error: 0.0614 - mean_absolute_error: 0.1712 - root_mean_squared_error: 0.2477 - 10s/epoch - 7ms/step
# Epoch 224/250
# 1456/1456 - 10s - loss: 0.0606 - mean_squared_error: 0.0606 - mean_absolute_error: 0.1723 - root_mean_squared_error: 0.2461 - 10s/epoch - 7ms/step
# Epoch 225/250
# 1456/1456 - 10s - loss: 0.0730 - mean_squared_error: 0.0730 - mean_absolute_error: 0.1842 - root_mean_squared_error: 0.2702 - 10s/epoch - 7ms/step
# Epoch 226/250
# 1456/1456 - 10s - loss: 0.0630 - mean_squared_error: 0.0630 - mean_absolute_error: 0.1728 - root_mean_squared_error: 0.2511 - 10s/epoch - 7ms/step
# Epoch 227/250
# 1456/1456 - 10s - loss: 0.0601 - mean_squared_error: 0.0601 - mean_absolute_error: 0.1693 - root_mean_squared_error: 0.2452 - 10s/epoch - 7ms/step
# Epoch 228/250
# 1456/1456 - 11s - loss: 0.0632 - mean_squared_error: 0.0632 - mean_absolute_error: 0.1759 - root_mean_squared_error: 0.2514 - 11s/epoch - 7ms/step
# Epoch 229/250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\DSFellowship\biLSTM0810.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> history = model2.fit(X_train, # input data
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>                     Y_train, # target data
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>                     batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a>                     epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a>                     verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a>                     callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a>                     validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch.
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a>                     #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch.
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a>                     shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a>                     class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=10'>11</a>                     sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=11'>12</a>                     initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=12'>13</a>                     steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=13'>14</a>                     validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=14'>15</a>                     validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=15'>16</a>                     validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=16'>17</a>                     max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=17'>18</a>                     workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=18'>19</a>                     use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False.
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=19'>20</a>
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTM0810.ipynb#X26sZmlsZQ%3D%3D?line=20'>21</a>                    )
#
# File c:\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python310\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "biLSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              33792
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 10, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 10, 128)          98816
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            129
#  ed)
#
# =================================================================
# Total params: 132,737
# Trainable params: 132,737
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 0.04931638389825821
# Final mean_squared_error : 0.04931638389825821
# Final mean_absolute_error : 0.15887321531772614
# Final root_mean_squared_error : 0.22207292914390564
# Final val_loss : 0.16691668331623077
# Final val_mean_squared_error : 0.1669166386127472
# Final val_mean_absolute_error : 0.26060813665390015
# Final val_root_mean_squared_error : 0.4085543155670166
#
# -------------------- Evaluation on Test Data --------------------
# 57/57 [==============================] - 1s 8ms/step - loss: 0.0976 - mean_squared_error: 0.0976 - mean_absolute_error: 0.1997 - root_mean_squared_error: 0.3124

# %%
from keras.utils import plot_model,model_to_dot
plot_model(model2, show_shapes=True, to_file='plotmodelbilstm0810.png')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model_to_dot(model2,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model2
# Out:
# [<keras.metrics.base_metric.Mean at 0x202331d3b50>,
#  <keras.metrics.metrics.MeanSquaredError at 0x2023367e800>,
#  <keras.metrics.metrics.MeanAbsoluteError at 0x2023367d450>,
#  <keras.metrics.metrics.RootMeanSquaredError at 0x20233119b40>]
