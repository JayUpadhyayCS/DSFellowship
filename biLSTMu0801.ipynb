# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed # for creating layers inside the Neural Network
from keras.optimizers import Adam
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version

# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#df=pd.read_csv('InSAR_data_south/displacement/export_dataframe.csv')
#df

# %%
#get displacement for one dot over the whole time 60 20 20
#open file by file
CSVpath="InSAR_data_south/displacement/CSV/test/"
dir_list=[]
lon_south=pd.read_csv('InSAR_data_south/longitude.csv')
lat_south=pd.read_csv('InSAR_data_south/latitude.csv')
for f in os.listdir(CSVpath):
    name, ext=os.path.splitext(f)
    if(ext=='.csv'):
        dir_list.append(f)

dir_list.sort()
print(dir_list)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# e:\DSFellowship\biLSTMu0801.ipynb Cell 3 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000002?line=2'>3</a> CSVpath="InSAR_data_south/displacement/CSV/test/"
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000002?line=3'>4</a> dir_list=[]
# ----> <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000002?line=4'>5</a> lon_south=pd.read_csv('InSAR_data_south/longitude.csv')
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000002?line=5'>6</a> lat_south=pd.read_csv('InSAR_data_south/latitude.csv')
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000002?line=6'>7</a> for f in os.listdir(CSVpath):
#
# File c:\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Python\Python310\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: 'InSAR_data_south/longitude.csv'

# %%
# df=pd.DataFrame()
# for f in dir_list:
#     name, ext=os.path.splitext(f)
#     if(ext=='.csv'):
#         print(CSVpath+f)
#         df_temp=pd.read_csv(CSVpath+f)
#         df_temp.columns=lon_south.columns
#         df_temp.index=lat_south.columns[:-1]
#         df_temp=df_temp.unstack().reset_index()
#         df_temp.columns=['Longitude','Latitude',name]
#         #print(df1.head())
#         #put it onto the main'
#         df1=pd.DataFrame(data=df_temp.iloc[:,2:3])
#         df1=df_temp.set_index([df_temp.columns[0],df_temp.columns[1]])
        
        
#         df=pd.concat([df,df1], axis=1)
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')

# %%
# Convert dates to year-months
#df['Year-Month']= (pd.to_datetime(df['Date'], yearfirst=True)).dt.strftime('%Y-%m')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
dftest=df
timestep=11
#dftest

# %%
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 34.1347          NaN         NaN         NaN         NaN
#           34.1367          NaN         NaN         NaN         NaN
#           34.1387          NaN         NaN         NaN         NaN
#           34.1407          NaN         NaN         NaN         NaN
#           34.1427          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -117.6414 37.6236          0.0      4.8278     -1.3065         NaN
#           37.6256          0.0      4.8698     -1.2137         NaN
#           37.6276          0.0      4.8693     -1.1893         NaN
#           37.6296          0.0      4.8277     -1.1906         NaN
#           37.6316          0.0      4.8729     -1.1200         NaN
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 34.1347          NaN         NaN         NaN         NaN
#           34.1367          NaN         NaN         NaN         NaN
#           34.1387          NaN         NaN         NaN         NaN
#           34.1407          NaN         NaN         NaN         NaN
#           34.1427          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -117.6414 37.6236      -4.1515     -1.9999      9.9914     -3.1055
#           37.6256      -4.1588     -1.7372     10.4130     -2.9584
#           37.6276      -4.1632     -1.7107     10.4830     -2.9318
#           37.6296      -4.1240     -1.8949     10.1870     -3.0179
#           37.6316      -4.1457     -1.7033     10.5180     -2.9269
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 34.1347          NaN         NaN  ...         NaN         NaN
#           34.1367          NaN         NaN  ...         NaN         NaN
#           34.1387          NaN         NaN  ...         NaN         NaN
#           34.1407          NaN         NaN  ...         NaN         NaN
#           34.1427          NaN         NaN  ...         NaN         NaN
# ...                        ...         ...  ...         ...         ...
# -117.6414 37.6236     -0.32799      6.9899  ...      8.5800      11.341
#           37.6256     -0.33838      7.3402  ...      9.2515      11.996
#           37.6276     -0.34454      7.3978  ...      8.8321      11.570
#           37.6296     -0.31614      7.1245  ...     10.3320      13.073
#           37.6316     -0.33153      7.3839  ...      9.3376      12.053
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 34.1347          NaN         NaN         NaN         NaN
#           34.1367          NaN         NaN         NaN         NaN
#           34.1387          NaN         NaN         NaN         NaN
#           34.1407          NaN         NaN         NaN         NaN
#           34.1427          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -117.6414 37.6236       5.5704      7.6113      17.002      9.6014
#           37.6256       6.0621      8.2387      17.526      9.5942
#           37.6276       5.5897      7.8226      17.066      9.2927
#           37.6296       7.2137      9.3699      18.582     10.8610
#           37.6316       6.0863      8.3323      17.499      9.8190
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 34.1347          NaN         NaN         NaN         NaN
#           34.1367          NaN         NaN         NaN         NaN
#           34.1387          NaN         NaN         NaN         NaN
#           34.1407          NaN         NaN         NaN         NaN
#           34.1427          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -117.6414 37.6236       16.436      8.5234      11.904      8.8353
#           37.6256       16.724      8.2348      11.630      8.3278
#           37.6276       16.641      8.2757      11.790      8.3947
#           37.6296       17.917      9.8912      13.381     10.2190
#           37.6316       16.839      8.8137      12.215      8.8725
#
# [2894595 rows x 110 columns]

# %%
#df.query("Longitude==-117.6414 and Latitude==37.6236")
# print(dftest.query('20141108'))
#df

# %%
#tup=(-119.9588,35.185)
tup=(-119.2990,35.8852)
#tup=(-120.2888,34.8349)
#tup=(-117.6414,37.6236)
#print(dftest.loc[tup])

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    
    for row in range(0,len(datain.index),20000):
    # Convert input dataframe to array and flatten
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        arr[np.isnan(arr)] = -1000
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %%
##### Step 2 - Prepare data
df.dropna(axis=0, how='all')
train, test = train_test_split(df, test_size=0.2)
X_train, Y_train = shaping(datain=train, timestep= timestep)
X_test, Y_test = shaping(datain=test, timestep=timestep)
# # Split data into train and test dataframes
# df_train_temp=dftest.iloc[:, :88].copy()
# df_test_temp=dftest.iloc[:, 88:110].copy()
# #pick a location to test
# df_train = df_train_temp[df_train_temp.index==tup].copy() 
# df_test = df_test_temp[df_test_temp.index==tup].copy()

# print(df_test.columns)
# #print(df_test)
# #df_train.columns=['Date','Disp']
# #df_test.columns=['Date','Disp']


# # # Split data into train and test dataframes
# # df_train=df2_pivot.iloc[:, 0:-2*timestep].copy()
# # df_test=df2_pivot.iloc[:, -2*timestep:].copy()

# # # Select one location
# # dfloc_train = df_train[df_train.index==location].copy()
# # dfloc_test = df_test[df_test.index==location].copy()
# # #print(df_test.columns)
# # Select one location
# #dfloc_train = df_train[df_train.index==location].copy()
# #dfloc_test = df_test[df_test.index==location].copy()

# # Use previously defined shaping function to reshape the data for LSTM

# X_train, Y_train = shaping(datain=df_train, timestep= timestep)
# X_test, Y_test = shaping(datain=df_test, timestep=timestep)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\DSFellowship\biLSTMu0801.ipynb Cell 10 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=1'>2</a> df.dropna(axis=0, how='all')
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=2'>3</a> train, test = train_test_split(df, test_size=0.2)
# ----> <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=3'>4</a> X_train, Y_train = shaping(datain=train, timestep= timestep)
#       <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=4'>5</a> X_test, Y_test = shaping(datain=test, timestep=timestep)
#
# e:\DSFellowship\biLSTMu0801.ipynb Cell 10 in shaping(datain, timestep)
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=19'>20</a>         else:
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=20'>21</a>             X_comb=np.append(X_comb, arr[X_start:X_end])
# ---> <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=21'>22</a>             Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=23'>24</a> # Reshape input and target arrays
#      <a href='vscode-notebook-cell:/e%3A/DSFellowship/biLSTMu0801.ipynb#ch0000009?line=24'>25</a> X_out=np.reshape(X_comb, (cnt, timestep, 1))
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\numpy\lib\function_base.py:5392, in append(arr, values, axis)
#    5390     values = ravel(values)
#    5391     axis = arr.ndim-1
# -> 5392 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
#print("dftrain:", df_train)

#print("dftest:", df_test)

#print("Xtrain:", X_train)

#print("Ytrain:", Y_train.shape[2])

#print("Xtrain:", X_train.size)

# %%
##### Step 3 - Specify the structure of a Neural Network
model = Sequential(name="LSTM-Model") # Model
model.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x

# %%
##### Step 4 - Compile the model
#from keras.optimizers import adam_v2
#optimizer = adam_v2.Adam(learning_rate=1)
#optimizer=Adam( 0.001)

model.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
##### Step 5 - Fit the model on the dataset
history = model.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=None, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=50, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/500
# 2/2 - 13s - loss: 617.1445 - mean_squared_error: 617.1446 - mean_absolute_error: 24.0136 - 13s/epoch - 6s/step
# Epoch 2/500
# 2/2 - 0s - loss: 205.0633 - mean_squared_error: 205.0633 - mean_absolute_error: 12.5993 - 36ms/epoch - 18ms/step
# Epoch 3/500
# 2/2 - 0s - loss: 116.9348 - mean_squared_error: 116.9348 - mean_absolute_error: 9.3999 - 37ms/epoch - 18ms/step
# Epoch 4/500
# 2/2 - 0s - loss: 107.0597 - mean_squared_error: 107.0597 - mean_absolute_error: 8.4623 - 34ms/epoch - 17ms/step
# Epoch 5/500
# 2/2 - 0s - loss: 41.5294 - mean_squared_error: 41.5294 - mean_absolute_error: 5.1132 - 36ms/epoch - 18ms/step
# Epoch 6/500
# 2/2 - 0s - loss: 26.8364 - mean_squared_error: 26.8364 - mean_absolute_error: 3.9619 - 41ms/epoch - 20ms/step
# Epoch 7/500
# 2/2 - 0s - loss: 31.7807 - mean_squared_error: 31.7807 - mean_absolute_error: 4.4156 - 39ms/epoch - 19ms/step
# Epoch 8/500
# 2/2 - 0s - loss: 28.1729 - mean_squared_error: 28.1729 - mean_absolute_error: 4.2659 - 37ms/epoch - 18ms/step
# Epoch 9/500
# 2/2 - 0s - loss: 20.5380 - mean_squared_error: 20.5380 - mean_absolute_error: 3.6717 - 36ms/epoch - 18ms/step
# Epoch 10/500
# 2/2 - 0s - loss: 18.1009 - mean_squared_error: 18.1009 - mean_absolute_error: 3.4509 - 36ms/epoch - 18ms/step
# Epoch 11/500
# 2/2 - 0s - loss: 16.5374 - mean_squared_error: 16.5374 - mean_absolute_error: 3.3025 - 38ms/epoch - 19ms/step
# Epoch 12/500
# 2/2 - 0s - loss: 14.2488 - mean_squared_error: 14.2488 - mean_absolute_error: 3.0506 - 39ms/epoch - 19ms/step
# Epoch 13/500
# 2/2 - 0s - loss: 13.2602 - mean_squared_error: 13.2602 - mean_absolute_error: 2.9254 - 38ms/epoch - 19ms/step
# Epoch 14/500
# 2/2 - 0s - loss: 11.7083 - mean_squared_error: 11.7083 - mean_absolute_error: 2.7891 - 35ms/epoch - 17ms/step
# Epoch 15/500
# 2/2 - 0s - loss: 11.1140 - mean_squared_error: 11.1140 - mean_absolute_error: 2.7140 - 36ms/epoch - 18ms/step
# Epoch 16/500
# 2/2 - 0s - loss: 10.0919 - mean_squared_error: 10.0919 - mean_absolute_error: 2.5811 - 37ms/epoch - 18ms/step
# Epoch 17/500
# 2/2 - 0s - loss: 9.5568 - mean_squared_error: 9.5568 - mean_absolute_error: 2.5190 - 37ms/epoch - 18ms/step
# Epoch 18/500
# 2/2 - 0s - loss: 9.0591 - mean_squared_error: 9.0591 - mean_absolute_error: 2.4520 - 35ms/epoch - 18ms/step
# Epoch 19/500
# 2/2 - 0s - loss: 8.9002 - mean_squared_error: 8.9002 - mean_absolute_error: 2.4163 - 37ms/epoch - 18ms/step
# Epoch 20/500
# 2/2 - 0s - loss: 8.7319 - mean_squared_error: 8.7319 - mean_absolute_error: 2.4274 - 35ms/epoch - 17ms/step
# Epoch 21/500
# 2/2 - 0s - loss: 8.4366 - mean_squared_error: 8.4366 - mean_absolute_error: 2.4151 - 34ms/epoch - 17ms/step
# Epoch 22/500
# 2/2 - 0s - loss: 8.3469 - mean_squared_error: 8.3469 - mean_absolute_error: 2.3899 - 37ms/epoch - 18ms/step
# Epoch 23/500
# 2/2 - 0s - loss: 8.0258 - mean_squared_error: 8.0258 - mean_absolute_error: 2.3145 - 37ms/epoch - 18ms/step
# Epoch 24/500
# 2/2 - 0s - loss: 8.1144 - mean_squared_error: 8.1144 - mean_absolute_error: 2.3160 - 35ms/epoch - 17ms/step
# Epoch 25/500
# 2/2 - 0s - loss: 7.9856 - mean_squared_error: 7.9856 - mean_absolute_error: 2.3089 - 37ms/epoch - 18ms/step
# Epoch 26/500
# 2/2 - 0s - loss: 7.6959 - mean_squared_error: 7.6959 - mean_absolute_error: 2.3079 - 36ms/epoch - 18ms/step
# Epoch 27/500
# 2/2 - 0s - loss: 7.6624 - mean_squared_error: 7.6624 - mean_absolute_error: 2.2747 - 36ms/epoch - 18ms/step
# Epoch 28/500
# 2/2 - 0s - loss: 7.5519 - mean_squared_error: 7.5519 - mean_absolute_error: 2.2503 - 38ms/epoch - 19ms/step
# Epoch 29/500
# 2/2 - 0s - loss: 7.4505 - mean_squared_error: 7.4505 - mean_absolute_error: 2.2412 - 36ms/epoch - 18ms/step
# Epoch 30/500
# 2/2 - 0s - loss: 7.3715 - mean_squared_error: 7.3715 - mean_absolute_error: 2.1903 - 35ms/epoch - 17ms/step
# Epoch 31/500
# 2/2 - 0s - loss: 7.0629 - mean_squared_error: 7.0629 - mean_absolute_error: 2.1374 - 40ms/epoch - 20ms/step
# Epoch 32/500
# 2/2 - 0s - loss: 7.5364 - mean_squared_error: 7.5364 - mean_absolute_error: 2.2570 - 48ms/epoch - 24ms/step
# Epoch 33/500
# 2/2 - 0s - loss: 7.6799 - mean_squared_error: 7.6799 - mean_absolute_error: 2.2379 - 37ms/epoch - 18ms/step
# Epoch 34/500
# 2/2 - 0s - loss: 6.8982 - mean_squared_error: 6.8982 - mean_absolute_error: 2.1180 - 41ms/epoch - 20ms/step
# Epoch 35/500
# 2/2 - 0s - loss: 7.8542 - mean_squared_error: 7.8542 - mean_absolute_error: 2.2593 - 39ms/epoch - 19ms/step
# Epoch 36/500
# 2/2 - 0s - loss: 6.3686 - mean_squared_error: 6.3686 - mean_absolute_error: 2.0475 - 43ms/epoch - 21ms/step
# Epoch 37/500
# 2/2 - 0s - loss: 7.8936 - mean_squared_error: 7.8936 - mean_absolute_error: 2.2178 - 36ms/epoch - 18ms/step
# Epoch 38/500
# 2/2 - 0s - loss: 6.6791 - mean_squared_error: 6.6791 - mean_absolute_error: 2.0621 - 37ms/epoch - 18ms/step
# Epoch 39/500
# 2/2 - 0s - loss: 7.3563 - mean_squared_error: 7.3563 - mean_absolute_error: 2.1939 - 36ms/epoch - 18ms/step
# Epoch 40/500
# 2/2 - 0s - loss: 6.7669 - mean_squared_error: 6.7669 - mean_absolute_error: 2.1073 - 37ms/epoch - 18ms/step
# Epoch 41/500
# 2/2 - 0s - loss: 6.9497 - mean_squared_error: 6.9497 - mean_absolute_error: 2.1056 - 36ms/epoch - 18ms/step
# Epoch 42/500
# 2/2 - 0s - loss: 6.2254 - mean_squared_error: 6.2254 - mean_absolute_error: 2.0277 - 35ms/epoch - 17ms/step
# Epoch 43/500
# 2/2 - 0s - loss: 6.9592 - mean_squared_error: 6.9592 - mean_absolute_error: 2.1430 - 40ms/epoch - 20ms/step
# Epoch 44/500
# 2/2 - 0s - loss: 6.4783 - mean_squared_error: 6.4783 - mean_absolute_error: 2.0553 - 35ms/epoch - 17ms/step
# Epoch 45/500
# 2/2 - 0s - loss: 6.3359 - mean_squared_error: 6.3359 - mean_absolute_error: 2.0180 - 34ms/epoch - 17ms/step
# Epoch 46/500
# 2/2 - 0s - loss: 6.2922 - mean_squared_error: 6.2922 - mean_absolute_error: 2.0402 - 37ms/epoch - 18ms/step
# Epoch 47/500
# 2/2 - 0s - loss: 6.1963 - mean_squared_error: 6.1963 - mean_absolute_error: 1.9907 - 37ms/epoch - 18ms/step
# Epoch 48/500
# 2/2 - 0s - loss: 5.9547 - mean_squared_error: 5.9547 - mean_absolute_error: 1.9425 - 37ms/epoch - 18ms/step
# Epoch 49/500
# 2/2 - 0s - loss: 5.9347 - mean_squared_error: 5.9347 - mean_absolute_error: 1.9425 - 38ms/epoch - 19ms/step
# Epoch 50/500
# 2/2 - 0s - loss: 5.6745 - mean_squared_error: 5.6745 - mean_absolute_error: 1.9090 - 40ms/epoch - 20ms/step
# Epoch 51/500
# 2/2 - 0s - loss: 5.7289 - mean_squared_error: 5.7289 - mean_absolute_error: 1.9119 - 40ms/epoch - 20ms/step
# Epoch 52/500
# 2/2 - 0s - loss: 5.8395 - mean_squared_error: 5.8395 - mean_absolute_error: 1.9045 - 39ms/epoch - 20ms/step
# Epoch 53/500
# 2/2 - 0s - loss: 5.7207 - mean_squared_error: 5.7207 - mean_absolute_error: 1.8785 - 37ms/epoch - 18ms/step
# Epoch 54/500
# 2/2 - 0s - loss: 5.7680 - mean_squared_error: 5.7680 - mean_absolute_error: 1.9041 - 36ms/epoch - 18ms/step
# Epoch 55/500
# 2/2 - 0s - loss: 5.7102 - mean_squared_error: 5.7102 - mean_absolute_error: 1.9148 - 34ms/epoch - 17ms/step
# Epoch 56/500
# 2/2 - 0s - loss: 5.6616 - mean_squared_error: 5.6616 - mean_absolute_error: 1.8926 - 39ms/epoch - 19ms/step
# Epoch 57/500
# 2/2 - 0s - loss: 5.5148 - mean_squared_error: 5.5148 - mean_absolute_error: 1.8563 - 39ms/epoch - 19ms/step
# Epoch 58/500
# 2/2 - 0s - loss: 5.8026 - mean_squared_error: 5.8026 - mean_absolute_error: 1.9221 - 36ms/epoch - 18ms/step
# Epoch 59/500
# 2/2 - 0s - loss: 5.7825 - mean_squared_error: 5.7825 - mean_absolute_error: 1.8818 - 38ms/epoch - 19ms/step
# Epoch 60/500
# 2/2 - 0s - loss: 5.4755 - mean_squared_error: 5.4755 - mean_absolute_error: 1.8455 - 37ms/epoch - 18ms/step
# Epoch 61/500
# 2/2 - 0s - loss: 5.5807 - mean_squared_error: 5.5807 - mean_absolute_error: 1.8549 - 39ms/epoch - 19ms/step
# Epoch 62/500
# 2/2 - 0s - loss: 5.2028 - mean_squared_error: 5.2028 - mean_absolute_error: 1.8046 - 41ms/epoch - 20ms/step
# Epoch 63/500
# 2/2 - 0s - loss: 5.1848 - mean_squared_error: 5.1848 - mean_absolute_error: 1.7942 - 38ms/epoch - 19ms/step
# Epoch 64/500
# 2/2 - 0s - loss: 5.2332 - mean_squared_error: 5.2332 - mean_absolute_error: 1.8002 - 40ms/epoch - 20ms/step
# Epoch 65/500
# 2/2 - 0s - loss: 5.1703 - mean_squared_error: 5.1703 - mean_absolute_error: 1.7890 - 42ms/epoch - 21ms/step
# Epoch 66/500
# 2/2 - 0s - loss: 5.1349 - mean_squared_error: 5.1349 - mean_absolute_error: 1.7837 - 40ms/epoch - 20ms/step
# Epoch 67/500
# 2/2 - 0s - loss: 5.1306 - mean_squared_error: 5.1306 - mean_absolute_error: 1.7773 - 37ms/epoch - 18ms/step
# Epoch 68/500
# 2/2 - 0s - loss: 5.1760 - mean_squared_error: 5.1760 - mean_absolute_error: 1.7808 - 36ms/epoch - 18ms/step
# Epoch 69/500
# 2/2 - 0s - loss: 5.6889 - mean_squared_error: 5.6889 - mean_absolute_error: 1.8800 - 34ms/epoch - 17ms/step
# Epoch 70/500
# 2/2 - 0s - loss: 4.9959 - mean_squared_error: 4.9959 - mean_absolute_error: 1.7558 - 36ms/epoch - 18ms/step
# Epoch 71/500
# 2/2 - 0s - loss: 5.4203 - mean_squared_error: 5.4203 - mean_absolute_error: 1.8404 - 35ms/epoch - 17ms/step
# Epoch 72/500
# 2/2 - 0s - loss: 5.8006 - mean_squared_error: 5.8006 - mean_absolute_error: 1.8867 - 36ms/epoch - 18ms/step
# Epoch 73/500
# 2/2 - 0s - loss: 5.4537 - mean_squared_error: 5.4537 - mean_absolute_error: 1.8242 - 36ms/epoch - 18ms/step
# Epoch 74/500
# 2/2 - 0s - loss: 5.1753 - mean_squared_error: 5.1753 - mean_absolute_error: 1.8114 - 38ms/epoch - 19ms/step
# Epoch 75/500
# 2/2 - 0s - loss: 4.8943 - mean_squared_error: 4.8943 - mean_absolute_error: 1.7394 - 34ms/epoch - 17ms/step
# Epoch 76/500
# 2/2 - 0s - loss: 4.9525 - mean_squared_error: 4.9525 - mean_absolute_error: 1.7453 - 37ms/epoch - 18ms/step
# Epoch 77/500
# 2/2 - 0s - loss: 5.6377 - mean_squared_error: 5.6377 - mean_absolute_error: 1.8673 - 34ms/epoch - 17ms/step
# Epoch 78/500
# 2/2 - 0s - loss: 5.2541 - mean_squared_error: 5.2541 - mean_absolute_error: 1.7995 - 37ms/epoch - 18ms/step
# Epoch 79/500
# 2/2 - 0s - loss: 5.2007 - mean_squared_error: 5.2007 - mean_absolute_error: 1.7656 - 41ms/epoch - 20ms/step
# Epoch 80/500
# 2/2 - 0s - loss: 4.9374 - mean_squared_error: 4.9374 - mean_absolute_error: 1.7236 - 38ms/epoch - 19ms/step
# Epoch 81/500
# 2/2 - 0s - loss: 4.6381 - mean_squared_error: 4.6381 - mean_absolute_error: 1.6839 - 40ms/epoch - 20ms/step
# Epoch 82/500
# 2/2 - 0s - loss: 4.6580 - mean_squared_error: 4.6580 - mean_absolute_error: 1.6878 - 37ms/epoch - 18ms/step
# Epoch 83/500
# 2/2 - 0s - loss: 4.9138 - mean_squared_error: 4.9138 - mean_absolute_error: 1.7452 - 37ms/epoch - 18ms/step
# Epoch 84/500
# 2/2 - 0s - loss: 4.6102 - mean_squared_error: 4.6102 - mean_absolute_error: 1.6801 - 37ms/epoch - 18ms/step
# Epoch 85/500
# 2/2 - 0s - loss: 4.7839 - mean_squared_error: 4.7839 - mean_absolute_error: 1.7173 - 38ms/epoch - 19ms/step
# Epoch 86/500
# 2/2 - 0s - loss: 4.5775 - mean_squared_error: 4.5775 - mean_absolute_error: 1.6536 - 37ms/epoch - 18ms/step
# Epoch 87/500
# 2/2 - 0s - loss: 4.4998 - mean_squared_error: 4.4998 - mean_absolute_error: 1.6558 - 36ms/epoch - 18ms/step
# Epoch 88/500
# 2/2 - 0s - loss: 4.8890 - mean_squared_error: 4.8890 - mean_absolute_error: 1.7200 - 36ms/epoch - 18ms/step
# Epoch 89/500
# 2/2 - 0s - loss: 4.7384 - mean_squared_error: 4.7384 - mean_absolute_error: 1.7226 - 36ms/epoch - 18ms/step
# Epoch 90/500
# 2/2 - 0s - loss: 4.4593 - mean_squared_error: 4.4593 - mean_absolute_error: 1.6406 - 36ms/epoch - 18ms/step
# Epoch 91/500
# 2/2 - 0s - loss: 5.0769 - mean_squared_error: 5.0769 - mean_absolute_error: 1.7668 - 37ms/epoch - 18ms/step
# Epoch 92/500
# 2/2 - 0s - loss: 4.5765 - mean_squared_error: 4.5765 - mean_absolute_error: 1.6669 - 36ms/epoch - 18ms/step
# Epoch 93/500
# 2/2 - 0s - loss: 4.4421 - mean_squared_error: 4.4421 - mean_absolute_error: 1.6587 - 36ms/epoch - 18ms/step
# Epoch 94/500
# 2/2 - 0s - loss: 4.5788 - mean_squared_error: 4.5788 - mean_absolute_error: 1.6771 - 36ms/epoch - 18ms/step
# Epoch 95/500
# 2/2 - 0s - loss: 4.5646 - mean_squared_error: 4.5646 - mean_absolute_error: 1.6725 - 38ms/epoch - 19ms/step
# Epoch 96/500
# 2/2 - 0s - loss: 4.5247 - mean_squared_error: 4.5247 - mean_absolute_error: 1.6538 - 38ms/epoch - 19ms/step
# Epoch 97/500
# 2/2 - 0s - loss: 4.5682 - mean_squared_error: 4.5682 - mean_absolute_error: 1.6576 - 37ms/epoch - 18ms/step
# Epoch 98/500
# 2/2 - 0s - loss: 4.5122 - mean_squared_error: 4.5122 - mean_absolute_error: 1.6546 - 38ms/epoch - 19ms/step
# Epoch 99/500
# 2/2 - 0s - loss: 4.3047 - mean_squared_error: 4.3047 - mean_absolute_error: 1.6057 - 37ms/epoch - 18ms/step
# Epoch 100/500
# 2/2 - 1s - loss: 4.4078 - mean_squared_error: 4.4078 - mean_absolute_error: 1.6204 - val_loss: 26.3338 - val_mean_squared_error: 26.3338 - val_mean_absolute_error: 4.3726 - 950ms/epoch - 475ms/step
# Epoch 101/500
# 2/2 - 0s - loss: 4.1809 - mean_squared_error: 4.1809 - mean_absolute_error: 1.5817 - 34ms/epoch - 17ms/step
# Epoch 102/500
# 2/2 - 0s - loss: 4.2439 - mean_squared_error: 4.2439 - mean_absolute_error: 1.5938 - 34ms/epoch - 17ms/step
# Epoch 103/500
# 2/2 - 0s - loss: 4.4922 - mean_squared_error: 4.4922 - mean_absolute_error: 1.6438 - 33ms/epoch - 16ms/step
# Epoch 104/500
# 2/2 - 0s - loss: 5.0306 - mean_squared_error: 5.0306 - mean_absolute_error: 1.7469 - 37ms/epoch - 18ms/step
# Epoch 105/500
# 2/2 - 0s - loss: 4.2064 - mean_squared_error: 4.2064 - mean_absolute_error: 1.5861 - 36ms/epoch - 18ms/step
# Epoch 106/500
# 2/2 - 0s - loss: 5.1042 - mean_squared_error: 5.1042 - mean_absolute_error: 1.7655 - 37ms/epoch - 18ms/step
# Epoch 107/500
# 2/2 - 0s - loss: 4.5638 - mean_squared_error: 4.5638 - mean_absolute_error: 1.6658 - 38ms/epoch - 19ms/step
# Epoch 108/500
# 2/2 - 0s - loss: 4.1379 - mean_squared_error: 4.1379 - mean_absolute_error: 1.5740 - 35ms/epoch - 17ms/step
# Epoch 109/500
# 2/2 - 0s - loss: 4.1571 - mean_squared_error: 4.1571 - mean_absolute_error: 1.5708 - 36ms/epoch - 18ms/step
# Epoch 110/500
# 2/2 - 0s - loss: 4.0013 - mean_squared_error: 4.0013 - mean_absolute_error: 1.5441 - 34ms/epoch - 17ms/step
# Epoch 111/500
# 2/2 - 0s - loss: 4.0540 - mean_squared_error: 4.0540 - mean_absolute_error: 1.5604 - 35ms/epoch - 17ms/step
# Epoch 112/500
# 2/2 - 0s - loss: 3.9946 - mean_squared_error: 3.9946 - mean_absolute_error: 1.5338 - 35ms/epoch - 17ms/step
# Epoch 113/500
# 2/2 - 0s - loss: 4.0531 - mean_squared_error: 4.0531 - mean_absolute_error: 1.5578 - 36ms/epoch - 18ms/step
# Epoch 114/500
# 2/2 - 0s - loss: 4.1201 - mean_squared_error: 4.1201 - mean_absolute_error: 1.5920 - 36ms/epoch - 18ms/step
# Epoch 115/500
# 2/2 - 0s - loss: 4.0477 - mean_squared_error: 4.0477 - mean_absolute_error: 1.5519 - 36ms/epoch - 18ms/step
# Epoch 116/500
# 2/2 - 0s - loss: 4.0349 - mean_squared_error: 4.0349 - mean_absolute_error: 1.5502 - 37ms/epoch - 18ms/step
# Epoch 117/500
# 2/2 - 0s - loss: 4.5089 - mean_squared_error: 4.5089 - mean_absolute_error: 1.6374 - 36ms/epoch - 18ms/step
# Epoch 118/500
# 2/2 - 0s - loss: 4.3604 - mean_squared_error: 4.3604 - mean_absolute_error: 1.6144 - 36ms/epoch - 18ms/step
# Epoch 119/500
# 2/2 - 0s - loss: 4.0197 - mean_squared_error: 4.0197 - mean_absolute_error: 1.5535 - 37ms/epoch - 18ms/step
# Epoch 120/500
# 2/2 - 0s - loss: 4.2011 - mean_squared_error: 4.2011 - mean_absolute_error: 1.5778 - 35ms/epoch - 17ms/step
# Epoch 121/500
# 2/2 - 0s - loss: 4.5430 - mean_squared_error: 4.5430 - mean_absolute_error: 1.6890 - 38ms/epoch - 19ms/step
# Epoch 122/500
# 2/2 - 0s - loss: 4.0561 - mean_squared_error: 4.0561 - mean_absolute_error: 1.5404 - 36ms/epoch - 18ms/step
# Epoch 123/500
# 2/2 - 0s - loss: 3.9825 - mean_squared_error: 3.9825 - mean_absolute_error: 1.5419 - 33ms/epoch - 16ms/step
# Epoch 124/500
# 2/2 - 0s - loss: 4.1529 - mean_squared_error: 4.1529 - mean_absolute_error: 1.6054 - 35ms/epoch - 17ms/step
# Epoch 125/500
# 2/2 - 0s - loss: 4.1584 - mean_squared_error: 4.1584 - mean_absolute_error: 1.5821 - 36ms/epoch - 18ms/step
# Epoch 126/500
# 2/2 - 0s - loss: 4.4636 - mean_squared_error: 4.4636 - mean_absolute_error: 1.6214 - 37ms/epoch - 18ms/step
# Epoch 127/500
# 2/2 - 0s - loss: 3.8376 - mean_squared_error: 3.8376 - mean_absolute_error: 1.5176 - 38ms/epoch - 19ms/step
# Epoch 128/500
# 2/2 - 0s - loss: 4.9298 - mean_squared_error: 4.9298 - mean_absolute_error: 1.7141 - 37ms/epoch - 18ms/step
# Epoch 129/500
# 2/2 - 0s - loss: 4.0254 - mean_squared_error: 4.0254 - mean_absolute_error: 1.5581 - 39ms/epoch - 19ms/step
# Epoch 130/500
# 2/2 - 0s - loss: 4.5653 - mean_squared_error: 4.5653 - mean_absolute_error: 1.6378 - 35ms/epoch - 17ms/step
# Epoch 131/500
# 2/2 - 0s - loss: 3.8608 - mean_squared_error: 3.8608 - mean_absolute_error: 1.5335 - 41ms/epoch - 20ms/step
# Epoch 132/500
# 2/2 - 0s - loss: 3.8736 - mean_squared_error: 3.8736 - mean_absolute_error: 1.5506 - 39ms/epoch - 19ms/step
# Epoch 133/500
# 2/2 - 0s - loss: 4.1446 - mean_squared_error: 4.1446 - mean_absolute_error: 1.5481 - 37ms/epoch - 18ms/step
# Epoch 134/500
# 2/2 - 0s - loss: 4.6784 - mean_squared_error: 4.6784 - mean_absolute_error: 1.6794 - 37ms/epoch - 18ms/step
# Epoch 135/500
# 2/2 - 0s - loss: 3.7254 - mean_squared_error: 3.7254 - mean_absolute_error: 1.4970 - 34ms/epoch - 17ms/step
# Epoch 136/500
# 2/2 - 0s - loss: 4.3645 - mean_squared_error: 4.3645 - mean_absolute_error: 1.6094 - 37ms/epoch - 18ms/step
# Epoch 137/500
# 2/2 - 0s - loss: 3.9731 - mean_squared_error: 3.9731 - mean_absolute_error: 1.5693 - 35ms/epoch - 17ms/step
# Epoch 138/500
# 2/2 - 0s - loss: 3.8164 - mean_squared_error: 3.8164 - mean_absolute_error: 1.5089 - 36ms/epoch - 18ms/step
# Epoch 139/500
# 2/2 - 0s - loss: 3.9149 - mean_squared_error: 3.9149 - mean_absolute_error: 1.5201 - 36ms/epoch - 18ms/step
# Epoch 140/500
# 2/2 - 0s - loss: 3.7744 - mean_squared_error: 3.7744 - mean_absolute_error: 1.5366 - 35ms/epoch - 17ms/step
# Epoch 141/500
# 2/2 - 0s - loss: 3.9818 - mean_squared_error: 3.9818 - mean_absolute_error: 1.5407 - 37ms/epoch - 18ms/step
# Epoch 142/500
# 2/2 - 0s - loss: 3.8994 - mean_squared_error: 3.8994 - mean_absolute_error: 1.5112 - 36ms/epoch - 18ms/step
# Epoch 143/500
# 2/2 - 0s - loss: 4.0911 - mean_squared_error: 4.0911 - mean_absolute_error: 1.5675 - 36ms/epoch - 18ms/step
# Epoch 144/500
# 2/2 - 0s - loss: 3.5938 - mean_squared_error: 3.5938 - mean_absolute_error: 1.4757 - 38ms/epoch - 19ms/step
# Epoch 145/500
# 2/2 - 0s - loss: 4.5158 - mean_squared_error: 4.5158 - mean_absolute_error: 1.6703 - 38ms/epoch - 19ms/step
# Epoch 146/500
# 2/2 - 0s - loss: 4.2270 - mean_squared_error: 4.2270 - mean_absolute_error: 1.5640 - 37ms/epoch - 18ms/step
# Epoch 147/500
# 2/2 - 0s - loss: 3.8915 - mean_squared_error: 3.8915 - mean_absolute_error: 1.5251 - 34ms/epoch - 17ms/step
# Epoch 148/500
# 2/2 - 0s - loss: 4.0309 - mean_squared_error: 4.0309 - mean_absolute_error: 1.5643 - 35ms/epoch - 18ms/step
# Epoch 149/500
# 2/2 - 0s - loss: 3.8877 - mean_squared_error: 3.8877 - mean_absolute_error: 1.5265 - 36ms/epoch - 18ms/step
# Epoch 150/500
# 2/2 - 0s - loss: 4.0605 - mean_squared_error: 4.0605 - mean_absolute_error: 1.5616 - 35ms/epoch - 17ms/step
# Epoch 151/500
# 2/2 - 0s - loss: 3.6430 - mean_squared_error: 3.6430 - mean_absolute_error: 1.4590 - 34ms/epoch - 17ms/step
# Epoch 152/500
# 2/2 - 0s - loss: 3.9933 - mean_squared_error: 3.9933 - mean_absolute_error: 1.5338 - 38ms/epoch - 19ms/step
# Epoch 153/500
# 2/2 - 0s - loss: 3.6235 - mean_squared_error: 3.6235 - mean_absolute_error: 1.4963 - 35ms/epoch - 17ms/step
# Epoch 154/500
# 2/2 - 0s - loss: 3.8671 - mean_squared_error: 3.8671 - mean_absolute_error: 1.5092 - 36ms/epoch - 18ms/step
# Epoch 155/500
# 2/2 - 0s - loss: 3.8844 - mean_squared_error: 3.8844 - mean_absolute_error: 1.5070 - 35ms/epoch - 17ms/step
# Epoch 156/500
# 2/2 - 0s - loss: 3.7914 - mean_squared_error: 3.7914 - mean_absolute_error: 1.4760 - 40ms/epoch - 20ms/step
# Epoch 157/500
# 2/2 - 0s - loss: 3.6867 - mean_squared_error: 3.6867 - mean_absolute_error: 1.4867 - 43ms/epoch - 21ms/step
# Epoch 158/500
# 2/2 - 0s - loss: 3.5036 - mean_squared_error: 3.5036 - mean_absolute_error: 1.4563 - 43ms/epoch - 21ms/step
# Epoch 159/500
# 2/2 - 0s - loss: 3.7230 - mean_squared_error: 3.7230 - mean_absolute_error: 1.4745 - 46ms/epoch - 23ms/step
# Epoch 160/500
# 2/2 - 0s - loss: 3.7946 - mean_squared_error: 3.7946 - mean_absolute_error: 1.5164 - 45ms/epoch - 22ms/step
# Epoch 161/500
# 2/2 - 0s - loss: 3.3746 - mean_squared_error: 3.3746 - mean_absolute_error: 1.4041 - 41ms/epoch - 21ms/step
# Epoch 162/500
# 2/2 - 0s - loss: 3.6580 - mean_squared_error: 3.6580 - mean_absolute_error: 1.4662 - 40ms/epoch - 20ms/step
# Epoch 163/500
# 2/2 - 0s - loss: 4.2279 - mean_squared_error: 4.2279 - mean_absolute_error: 1.6094 - 37ms/epoch - 18ms/step
# Epoch 164/500
# 2/2 - 0s - loss: 3.7039 - mean_squared_error: 3.7039 - mean_absolute_error: 1.4653 - 34ms/epoch - 17ms/step
# Epoch 165/500
# 2/2 - 0s - loss: 4.0450 - mean_squared_error: 4.0450 - mean_absolute_error: 1.5556 - 37ms/epoch - 18ms/step
# Epoch 166/500
# 2/2 - 0s - loss: 3.8395 - mean_squared_error: 3.8395 - mean_absolute_error: 1.4797 - 37ms/epoch - 18ms/step
# Epoch 167/500
# 2/2 - 0s - loss: 4.0466 - mean_squared_error: 4.0466 - mean_absolute_error: 1.5346 - 41ms/epoch - 20ms/step
# Epoch 168/500
# 2/2 - 0s - loss: 3.7836 - mean_squared_error: 3.7836 - mean_absolute_error: 1.5000 - 38ms/epoch - 19ms/step
# Epoch 169/500
# 2/2 - 0s - loss: 3.9359 - mean_squared_error: 3.9359 - mean_absolute_error: 1.5433 - 37ms/epoch - 18ms/step
# Epoch 170/500
# 2/2 - 0s - loss: 3.8105 - mean_squared_error: 3.8105 - mean_absolute_error: 1.5117 - 35ms/epoch - 17ms/step
# Epoch 171/500
# 2/2 - 0s - loss: 3.5048 - mean_squared_error: 3.5048 - mean_absolute_error: 1.4450 - 36ms/epoch - 18ms/step
# Epoch 172/500
# 2/2 - 0s - loss: 3.8564 - mean_squared_error: 3.8564 - mean_absolute_error: 1.5291 - 38ms/epoch - 19ms/step
# Epoch 173/500
# 2/2 - 0s - loss: 3.8602 - mean_squared_error: 3.8602 - mean_absolute_error: 1.4792 - 39ms/epoch - 19ms/step
# Epoch 174/500
# 2/2 - 0s - loss: 4.0894 - mean_squared_error: 4.0894 - mean_absolute_error: 1.5557 - 37ms/epoch - 18ms/step
# Epoch 175/500
# 2/2 - 0s - loss: 3.4321 - mean_squared_error: 3.4321 - mean_absolute_error: 1.4232 - 36ms/epoch - 18ms/step
# Epoch 176/500
# 2/2 - 0s - loss: 3.7327 - mean_squared_error: 3.7327 - mean_absolute_error: 1.4827 - 32ms/epoch - 16ms/step
# Epoch 177/500
# 2/2 - 0s - loss: 3.6210 - mean_squared_error: 3.6210 - mean_absolute_error: 1.4723 - 32ms/epoch - 16ms/step
# Epoch 178/500
# 2/2 - 0s - loss: 3.6932 - mean_squared_error: 3.6932 - mean_absolute_error: 1.4519 - 36ms/epoch - 18ms/step
# Epoch 179/500
# 2/2 - 0s - loss: 3.5570 - mean_squared_error: 3.5570 - mean_absolute_error: 1.4580 - 37ms/epoch - 18ms/step
# Epoch 180/500
# 2/2 - 0s - loss: 3.3671 - mean_squared_error: 3.3671 - mean_absolute_error: 1.4041 - 34ms/epoch - 17ms/step
# Epoch 181/500
# 2/2 - 0s - loss: 3.3497 - mean_squared_error: 3.3497 - mean_absolute_error: 1.3901 - 34ms/epoch - 17ms/step
# Epoch 182/500
# 2/2 - 0s - loss: 3.8058 - mean_squared_error: 3.8058 - mean_absolute_error: 1.4981 - 36ms/epoch - 18ms/step
# Epoch 183/500
# 2/2 - 0s - loss: 3.3033 - mean_squared_error: 3.3033 - mean_absolute_error: 1.3966 - 37ms/epoch - 18ms/step
# Epoch 184/500
# 2/2 - 0s - loss: 3.2734 - mean_squared_error: 3.2734 - mean_absolute_error: 1.3864 - 35ms/epoch - 17ms/step
# Epoch 185/500
# 2/2 - 0s - loss: 3.2497 - mean_squared_error: 3.2497 - mean_absolute_error: 1.3670 - 36ms/epoch - 18ms/step
# Epoch 186/500
# 2/2 - 0s - loss: 3.3173 - mean_squared_error: 3.3173 - mean_absolute_error: 1.4003 - 38ms/epoch - 19ms/step
# Epoch 187/500
# 2/2 - 0s - loss: 3.6526 - mean_squared_error: 3.6526 - mean_absolute_error: 1.4600 - 36ms/epoch - 18ms/step
# Epoch 188/500
# 2/2 - 0s - loss: 3.5949 - mean_squared_error: 3.5949 - mean_absolute_error: 1.4251 - 35ms/epoch - 17ms/step
# Epoch 189/500
# 2/2 - 0s - loss: 3.2147 - mean_squared_error: 3.2147 - mean_absolute_error: 1.3688 - 38ms/epoch - 19ms/step
# Epoch 190/500
# 2/2 - 0s - loss: 3.2583 - mean_squared_error: 3.2583 - mean_absolute_error: 1.3852 - 37ms/epoch - 18ms/step
# Epoch 191/500
# 2/2 - 0s - loss: 3.3328 - mean_squared_error: 3.3328 - mean_absolute_error: 1.3759 - 34ms/epoch - 17ms/step
# Epoch 192/500
# 2/2 - 0s - loss: 3.1710 - mean_squared_error: 3.1710 - mean_absolute_error: 1.3566 - 39ms/epoch - 19ms/step
# Epoch 193/500
# 2/2 - 0s - loss: 3.4405 - mean_squared_error: 3.4405 - mean_absolute_error: 1.4000 - 35ms/epoch - 17ms/step
# Epoch 194/500
# 2/2 - 0s - loss: 3.6088 - mean_squared_error: 3.6088 - mean_absolute_error: 1.4727 - 36ms/epoch - 18ms/step
# Epoch 195/500
# 2/2 - 0s - loss: 3.2461 - mean_squared_error: 3.2461 - mean_absolute_error: 1.3607 - 35ms/epoch - 17ms/step
# Epoch 196/500
# 2/2 - 0s - loss: 3.1815 - mean_squared_error: 3.1815 - mean_absolute_error: 1.3527 - 37ms/epoch - 18ms/step
# Epoch 197/500
# 2/2 - 0s - loss: 3.2520 - mean_squared_error: 3.2520 - mean_absolute_error: 1.3853 - 36ms/epoch - 18ms/step
# Epoch 198/500
# 2/2 - 0s - loss: 3.3712 - mean_squared_error: 3.3712 - mean_absolute_error: 1.3919 - 38ms/epoch - 19ms/step
# Epoch 199/500
# 2/2 - 0s - loss: 3.7509 - mean_squared_error: 3.7509 - mean_absolute_error: 1.4544 - 37ms/epoch - 18ms/step
# Epoch 200/500
# 2/2 - 0s - loss: 3.7861 - mean_squared_error: 3.7861 - mean_absolute_error: 1.4884 - val_loss: 15.7812 - val_mean_squared_error: 15.7812 - val_mean_absolute_error: 3.3484 - 68ms/epoch - 34ms/step
# Epoch 201/500
# 2/2 - 0s - loss: 3.8625 - mean_squared_error: 3.8625 - mean_absolute_error: 1.5148 - 35ms/epoch - 17ms/step
# Epoch 202/500
# 2/2 - 0s - loss: 4.8562 - mean_squared_error: 4.8562 - mean_absolute_error: 1.6769 - 40ms/epoch - 20ms/step
# Epoch 203/500
# 2/2 - 0s - loss: 3.6532 - mean_squared_error: 3.6532 - mean_absolute_error: 1.4285 - 40ms/epoch - 20ms/step
# Epoch 204/500
# 2/2 - 0s - loss: 4.2551 - mean_squared_error: 4.2551 - mean_absolute_error: 1.5604 - 41ms/epoch - 20ms/step
# Epoch 205/500
# 2/2 - 0s - loss: 4.3906 - mean_squared_error: 4.3906 - mean_absolute_error: 1.6513 - 38ms/epoch - 19ms/step
# Epoch 206/500
# 2/2 - 0s - loss: 5.0113 - mean_squared_error: 5.0113 - mean_absolute_error: 1.7429 - 39ms/epoch - 19ms/step
# Epoch 207/500
# 2/2 - 0s - loss: 4.2136 - mean_squared_error: 4.2136 - mean_absolute_error: 1.5834 - 35ms/epoch - 17ms/step
# Epoch 208/500
# 2/2 - 0s - loss: 4.3531 - mean_squared_error: 4.3531 - mean_absolute_error: 1.6391 - 36ms/epoch - 18ms/step
# Epoch 209/500
# 2/2 - 0s - loss: 4.2766 - mean_squared_error: 4.2766 - mean_absolute_error: 1.5637 - 36ms/epoch - 18ms/step
# Epoch 210/500
# 2/2 - 0s - loss: 3.4741 - mean_squared_error: 3.4741 - mean_absolute_error: 1.4398 - 34ms/epoch - 17ms/step
# Epoch 211/500
# 2/2 - 0s - loss: 3.8508 - mean_squared_error: 3.8508 - mean_absolute_error: 1.5511 - 36ms/epoch - 18ms/step
# Epoch 212/500
# 2/2 - 0s - loss: 3.7014 - mean_squared_error: 3.7014 - mean_absolute_error: 1.4650 - 38ms/epoch - 19ms/step
# Epoch 213/500
# 2/2 - 0s - loss: 3.4471 - mean_squared_error: 3.4471 - mean_absolute_error: 1.4045 - 35ms/epoch - 17ms/step
# Epoch 214/500
# 2/2 - 0s - loss: 3.6212 - mean_squared_error: 3.6212 - mean_absolute_error: 1.4559 - 34ms/epoch - 17ms/step
# Epoch 215/500
# 2/2 - 0s - loss: 3.9195 - mean_squared_error: 3.9195 - mean_absolute_error: 1.5028 - 36ms/epoch - 18ms/step
# Epoch 216/500
# 2/2 - 0s - loss: 3.3240 - mean_squared_error: 3.3240 - mean_absolute_error: 1.4124 - 36ms/epoch - 18ms/step
# Epoch 217/500
# 2/2 - 0s - loss: 3.2276 - mean_squared_error: 3.2276 - mean_absolute_error: 1.3913 - 36ms/epoch - 18ms/step
# Epoch 218/500
# 2/2 - 0s - loss: 4.2247 - mean_squared_error: 4.2247 - mean_absolute_error: 1.5142 - 36ms/epoch - 18ms/step
# Epoch 219/500
# 2/2 - 0s - loss: 3.7096 - mean_squared_error: 3.7096 - mean_absolute_error: 1.4816 - 38ms/epoch - 19ms/step
# Epoch 220/500
# 2/2 - 0s - loss: 3.9426 - mean_squared_error: 3.9426 - mean_absolute_error: 1.4947 - 36ms/epoch - 18ms/step
# Epoch 221/500
# 2/2 - 0s - loss: 3.4456 - mean_squared_error: 3.4456 - mean_absolute_error: 1.4071 - 37ms/epoch - 18ms/step
# Epoch 222/500
# 2/2 - 0s - loss: 3.5502 - mean_squared_error: 3.5502 - mean_absolute_error: 1.4517 - 37ms/epoch - 18ms/step
# Epoch 223/500
# 2/2 - 0s - loss: 4.0474 - mean_squared_error: 4.0474 - mean_absolute_error: 1.5197 - 35ms/epoch - 17ms/step
# Epoch 224/500
# 2/2 - 0s - loss: 3.8914 - mean_squared_error: 3.8914 - mean_absolute_error: 1.4985 - 36ms/epoch - 18ms/step
# Epoch 225/500
# 2/2 - 0s - loss: 3.9981 - mean_squared_error: 3.9981 - mean_absolute_error: 1.5099 - 37ms/epoch - 18ms/step
# Epoch 226/500
# 2/2 - 0s - loss: 3.5129 - mean_squared_error: 3.5129 - mean_absolute_error: 1.4044 - 35ms/epoch - 17ms/step
# Epoch 227/500
# 2/2 - 0s - loss: 3.4095 - mean_squared_error: 3.4095 - mean_absolute_error: 1.4212 - 33ms/epoch - 16ms/step
# Epoch 228/500
# 2/2 - 0s - loss: 3.2933 - mean_squared_error: 3.2933 - mean_absolute_error: 1.3790 - 40ms/epoch - 20ms/step
# Epoch 229/500
# 2/2 - 0s - loss: 3.3426 - mean_squared_error: 3.3426 - mean_absolute_error: 1.3671 - 36ms/epoch - 18ms/step
# Epoch 230/500
# 2/2 - 0s - loss: 3.2825 - mean_squared_error: 3.2825 - mean_absolute_error: 1.3887 - 39ms/epoch - 19ms/step
# Epoch 231/500
# 2/2 - 0s - loss: 3.6296 - mean_squared_error: 3.6296 - mean_absolute_error: 1.4251 - 39ms/epoch - 19ms/step
# Epoch 232/500
# 2/2 - 0s - loss: 3.0984 - mean_squared_error: 3.0984 - mean_absolute_error: 1.3392 - 36ms/epoch - 18ms/step
# Epoch 233/500
# 2/2 - 0s - loss: 3.2922 - mean_squared_error: 3.2922 - mean_absolute_error: 1.4071 - 38ms/epoch - 19ms/step
# Epoch 234/500
# 2/2 - 0s - loss: 3.3978 - mean_squared_error: 3.3978 - mean_absolute_error: 1.3783 - 37ms/epoch - 18ms/step
# Epoch 235/500
# 2/2 - 0s - loss: 3.2173 - mean_squared_error: 3.2173 - mean_absolute_error: 1.3601 - 38ms/epoch - 19ms/step
# Epoch 236/500
# 2/2 - 0s - loss: 3.5857 - mean_squared_error: 3.5857 - mean_absolute_error: 1.4402 - 38ms/epoch - 19ms/step
# Epoch 237/500
# 2/2 - 0s - loss: 3.0842 - mean_squared_error: 3.0842 - mean_absolute_error: 1.3040 - 36ms/epoch - 18ms/step
# Epoch 238/500
# 2/2 - 0s - loss: 4.3411 - mean_squared_error: 4.3411 - mean_absolute_error: 1.5781 - 36ms/epoch - 18ms/step
# Epoch 239/500
# 2/2 - 0s - loss: 5.4239 - mean_squared_error: 5.4239 - mean_absolute_error: 1.6697 - 36ms/epoch - 18ms/step
# Epoch 240/500
# 2/2 - 0s - loss: 3.2648 - mean_squared_error: 3.2648 - mean_absolute_error: 1.3923 - 36ms/epoch - 18ms/step
# Epoch 241/500
# 2/2 - 0s - loss: 4.9810 - mean_squared_error: 4.9810 - mean_absolute_error: 1.6820 - 33ms/epoch - 16ms/step
# Epoch 242/500
# 2/2 - 0s - loss: 5.1836 - mean_squared_error: 5.1836 - mean_absolute_error: 1.8036 - 41ms/epoch - 20ms/step
# Epoch 243/500
# 2/2 - 0s - loss: 4.9629 - mean_squared_error: 4.9629 - mean_absolute_error: 1.7205 - 37ms/epoch - 18ms/step
# Epoch 244/500
# 2/2 - 0s - loss: 4.5866 - mean_squared_error: 4.5866 - mean_absolute_error: 1.7276 - 36ms/epoch - 18ms/step
# Epoch 245/500
# 2/2 - 0s - loss: 4.4954 - mean_squared_error: 4.4954 - mean_absolute_error: 1.6659 - 39ms/epoch - 19ms/step
# Epoch 246/500
# 2/2 - 0s - loss: 4.7414 - mean_squared_error: 4.7414 - mean_absolute_error: 1.7353 - 35ms/epoch - 17ms/step
# Epoch 247/500
# 2/2 - 0s - loss: 3.9148 - mean_squared_error: 3.9148 - mean_absolute_error: 1.5577 - 39ms/epoch - 19ms/step
# Epoch 248/500
# 2/2 - 0s - loss: 4.5830 - mean_squared_error: 4.5830 - mean_absolute_error: 1.6848 - 39ms/epoch - 19ms/step
# Epoch 249/500
# 2/2 - 0s - loss: 3.9920 - mean_squared_error: 3.9920 - mean_absolute_error: 1.5463 - 34ms/epoch - 17ms/step
# Epoch 250/500
# 2/2 - 0s - loss: 3.7074 - mean_squared_error: 3.7074 - mean_absolute_error: 1.4849 - 35ms/epoch - 17ms/step
# Epoch 251/500
# 2/2 - 0s - loss: 3.6858 - mean_squared_error: 3.6858 - mean_absolute_error: 1.4675 - 36ms/epoch - 18ms/step
# Epoch 252/500
# 2/2 - 0s - loss: 3.3771 - mean_squared_error: 3.3771 - mean_absolute_error: 1.3937 - 39ms/epoch - 19ms/step
# Epoch 253/500
# 2/2 - 0s - loss: 3.6647 - mean_squared_error: 3.6647 - mean_absolute_error: 1.4455 - 48ms/epoch - 24ms/step
# Epoch 254/500
# 2/2 - 0s - loss: 3.4836 - mean_squared_error: 3.4836 - mean_absolute_error: 1.4243 - 42ms/epoch - 21ms/step
# Epoch 255/500
# 2/2 - 0s - loss: 3.6958 - mean_squared_error: 3.6958 - mean_absolute_error: 1.4786 - 36ms/epoch - 18ms/step
# Epoch 256/500
# 2/2 - 0s - loss: 3.3243 - mean_squared_error: 3.3243 - mean_absolute_error: 1.3909 - 36ms/epoch - 18ms/step
# Epoch 257/500
# 2/2 - 0s - loss: 3.9626 - mean_squared_error: 3.9626 - mean_absolute_error: 1.5144 - 33ms/epoch - 17ms/step
# Epoch 258/500
# 2/2 - 0s - loss: 3.4967 - mean_squared_error: 3.4967 - mean_absolute_error: 1.4143 - 38ms/epoch - 19ms/step
# Epoch 259/500
# 2/2 - 0s - loss: 3.6575 - mean_squared_error: 3.6575 - mean_absolute_error: 1.4777 - 38ms/epoch - 19ms/step
# Epoch 260/500
# 2/2 - 0s - loss: 3.3924 - mean_squared_error: 3.3924 - mean_absolute_error: 1.4192 - 34ms/epoch - 17ms/step
# Epoch 261/500
# 2/2 - 0s - loss: 3.4903 - mean_squared_error: 3.4903 - mean_absolute_error: 1.4212 - 37ms/epoch - 18ms/step
# Epoch 262/500
# 2/2 - 0s - loss: 3.4190 - mean_squared_error: 3.4190 - mean_absolute_error: 1.4000 - 37ms/epoch - 18ms/step
# Epoch 263/500
# 2/2 - 0s - loss: 3.1677 - mean_squared_error: 3.1677 - mean_absolute_error: 1.3379 - 36ms/epoch - 18ms/step
# Epoch 264/500
# 2/2 - 0s - loss: 3.3679 - mean_squared_error: 3.3679 - mean_absolute_error: 1.3985 - 36ms/epoch - 18ms/step
# Epoch 265/500
# 2/2 - 0s - loss: 3.2279 - mean_squared_error: 3.2279 - mean_absolute_error: 1.3687 - 35ms/epoch - 18ms/step
# Epoch 266/500
# 2/2 - 0s - loss: 3.3880 - mean_squared_error: 3.3880 - mean_absolute_error: 1.3930 - 38ms/epoch - 19ms/step
# Epoch 267/500
# 2/2 - 0s - loss: 3.1788 - mean_squared_error: 3.1788 - mean_absolute_error: 1.3406 - 37ms/epoch - 18ms/step
# Epoch 268/500
# 2/2 - 0s - loss: 3.1023 - mean_squared_error: 3.1023 - mean_absolute_error: 1.3424 - 37ms/epoch - 18ms/step
# Epoch 269/500
# 2/2 - 0s - loss: 3.1033 - mean_squared_error: 3.1033 - mean_absolute_error: 1.3240 - 34ms/epoch - 17ms/step
# Epoch 270/500
# 2/2 - 0s - loss: 3.1620 - mean_squared_error: 3.1620 - mean_absolute_error: 1.3282 - 36ms/epoch - 18ms/step
# Epoch 271/500
# 2/2 - 0s - loss: 3.2653 - mean_squared_error: 3.2653 - mean_absolute_error: 1.3602 - 34ms/epoch - 17ms/step
# Epoch 272/500
# 2/2 - 0s - loss: 3.3477 - mean_squared_error: 3.3477 - mean_absolute_error: 1.3398 - 33ms/epoch - 16ms/step
# Epoch 273/500
# 2/2 - 0s - loss: 3.3551 - mean_squared_error: 3.3551 - mean_absolute_error: 1.3835 - 35ms/epoch - 17ms/step
# Epoch 274/500
# 2/2 - 0s - loss: 3.0816 - mean_squared_error: 3.0816 - mean_absolute_error: 1.3119 - 39ms/epoch - 19ms/step
# Epoch 275/500
# 2/2 - 0s - loss: 3.5964 - mean_squared_error: 3.5964 - mean_absolute_error: 1.3822 - 36ms/epoch - 18ms/step
# Epoch 276/500
# 2/2 - 0s - loss: 3.0857 - mean_squared_error: 3.0857 - mean_absolute_error: 1.3246 - 36ms/epoch - 18ms/step
# Epoch 277/500
# 2/2 - 0s - loss: 3.0921 - mean_squared_error: 3.0921 - mean_absolute_error: 1.3151 - 40ms/epoch - 20ms/step
# Epoch 278/500
# 2/2 - 0s - loss: 2.9634 - mean_squared_error: 2.9634 - mean_absolute_error: 1.2844 - 38ms/epoch - 19ms/step
# Epoch 279/500
# 2/2 - 0s - loss: 2.9684 - mean_squared_error: 2.9684 - mean_absolute_error: 1.2907 - 40ms/epoch - 20ms/step
# Epoch 280/500
# 2/2 - 0s - loss: 3.0145 - mean_squared_error: 3.0145 - mean_absolute_error: 1.2957 - 41ms/epoch - 20ms/step
# Epoch 281/500
# 2/2 - 0s - loss: 3.0379 - mean_squared_error: 3.0379 - mean_absolute_error: 1.2868 - 39ms/epoch - 19ms/step
# Epoch 282/500
# 2/2 - 0s - loss: 3.0368 - mean_squared_error: 3.0368 - mean_absolute_error: 1.3116 - 38ms/epoch - 19ms/step
# Epoch 283/500
# 2/2 - 0s - loss: 2.9280 - mean_squared_error: 2.9280 - mean_absolute_error: 1.2680 - 36ms/epoch - 18ms/step
# Epoch 284/500
# 2/2 - 0s - loss: 2.9304 - mean_squared_error: 2.9304 - mean_absolute_error: 1.2723 - 36ms/epoch - 18ms/step
# Epoch 285/500
# 2/2 - 0s - loss: 3.0669 - mean_squared_error: 3.0669 - mean_absolute_error: 1.3288 - 36ms/epoch - 18ms/step
# Epoch 286/500
# 2/2 - 0s - loss: 3.0952 - mean_squared_error: 3.0952 - mean_absolute_error: 1.3047 - 37ms/epoch - 18ms/step
# Epoch 287/500
# 2/2 - 0s - loss: 2.9140 - mean_squared_error: 2.9140 - mean_absolute_error: 1.2946 - 38ms/epoch - 19ms/step
# Epoch 288/500
# 2/2 - 0s - loss: 2.9327 - mean_squared_error: 2.9327 - mean_absolute_error: 1.2826 - 39ms/epoch - 19ms/step
# Epoch 289/500
# 2/2 - 0s - loss: 2.9593 - mean_squared_error: 2.9593 - mean_absolute_error: 1.2753 - 35ms/epoch - 17ms/step
# Epoch 290/500
# 2/2 - 0s - loss: 3.0177 - mean_squared_error: 3.0177 - mean_absolute_error: 1.3011 - 36ms/epoch - 18ms/step
# Epoch 291/500
# 2/2 - 0s - loss: 2.9230 - mean_squared_error: 2.9230 - mean_absolute_error: 1.2778 - 38ms/epoch - 19ms/step
# Epoch 292/500
# 2/2 - 0s - loss: 3.0284 - mean_squared_error: 3.0284 - mean_absolute_error: 1.2964 - 40ms/epoch - 20ms/step
# Epoch 293/500
# 2/2 - 0s - loss: 3.1977 - mean_squared_error: 3.1977 - mean_absolute_error: 1.3524 - 42ms/epoch - 21ms/step
# Epoch 294/500
# 2/2 - 0s - loss: 2.8958 - mean_squared_error: 2.8958 - mean_absolute_error: 1.2521 - 39ms/epoch - 19ms/step
# Epoch 295/500
# 2/2 - 0s - loss: 3.1212 - mean_squared_error: 3.1212 - mean_absolute_error: 1.3345 - 37ms/epoch - 18ms/step
# Epoch 296/500
# 2/2 - 0s - loss: 3.0512 - mean_squared_error: 3.0512 - mean_absolute_error: 1.3087 - 44ms/epoch - 22ms/step
# Epoch 297/500
# 2/2 - 0s - loss: 2.9083 - mean_squared_error: 2.9083 - mean_absolute_error: 1.2850 - 40ms/epoch - 20ms/step
# Epoch 298/500
# 2/2 - 0s - loss: 2.9735 - mean_squared_error: 2.9735 - mean_absolute_error: 1.2792 - 34ms/epoch - 17ms/step
# Epoch 299/500
# 2/2 - 0s - loss: 3.1770 - mean_squared_error: 3.1770 - mean_absolute_error: 1.3529 - 35ms/epoch - 17ms/step
# Epoch 300/500
# 2/2 - 0s - loss: 3.5040 - mean_squared_error: 3.5040 - mean_absolute_error: 1.3565 - val_loss: 23.8826 - val_mean_squared_error: 23.8826 - val_mean_absolute_error: 4.2508 - 67ms/epoch - 33ms/step
# Epoch 301/500
# 2/2 - 0s - loss: 3.8639 - mean_squared_error: 3.8639 - mean_absolute_error: 1.4442 - 36ms/epoch - 18ms/step
# Epoch 302/500
# 2/2 - 0s - loss: 4.1234 - mean_squared_error: 4.1234 - mean_absolute_error: 1.4796 - 36ms/epoch - 18ms/step
# Epoch 303/500
# 2/2 - 0s - loss: 4.2848 - mean_squared_error: 4.2848 - mean_absolute_error: 1.5632 - 37ms/epoch - 18ms/step
# Epoch 304/500
# 2/2 - 0s - loss: 4.0175 - mean_squared_error: 4.0175 - mean_absolute_error: 1.4890 - 37ms/epoch - 18ms/step
# Epoch 305/500
# 2/2 - 0s - loss: 4.3359 - mean_squared_error: 4.3359 - mean_absolute_error: 1.6312 - 37ms/epoch - 18ms/step
# Epoch 306/500
# 2/2 - 0s - loss: 3.8339 - mean_squared_error: 3.8339 - mean_absolute_error: 1.4847 - 35ms/epoch - 17ms/step
# Epoch 307/500
# 2/2 - 0s - loss: 3.8106 - mean_squared_error: 3.8106 - mean_absolute_error: 1.4848 - 37ms/epoch - 18ms/step
# Epoch 308/500
# 2/2 - 0s - loss: 3.6740 - mean_squared_error: 3.6740 - mean_absolute_error: 1.4330 - 37ms/epoch - 18ms/step
# Epoch 309/500
# 2/2 - 0s - loss: 3.3891 - mean_squared_error: 3.3891 - mean_absolute_error: 1.4121 - 33ms/epoch - 16ms/step
# Epoch 310/500
# 2/2 - 0s - loss: 3.1872 - mean_squared_error: 3.1872 - mean_absolute_error: 1.3461 - 34ms/epoch - 17ms/step
# Epoch 311/500
# 2/2 - 0s - loss: 3.0662 - mean_squared_error: 3.0662 - mean_absolute_error: 1.2963 - 38ms/epoch - 19ms/step
# Epoch 312/500
# 2/2 - 0s - loss: 3.1696 - mean_squared_error: 3.1696 - mean_absolute_error: 1.3381 - 37ms/epoch - 18ms/step
# Epoch 313/500
# 2/2 - 0s - loss: 2.9279 - mean_squared_error: 2.9279 - mean_absolute_error: 1.2824 - 34ms/epoch - 17ms/step
# Epoch 314/500
# 2/2 - 0s - loss: 3.0292 - mean_squared_error: 3.0292 - mean_absolute_error: 1.2792 - 38ms/epoch - 19ms/step
# Epoch 315/500
# 2/2 - 0s - loss: 3.2060 - mean_squared_error: 3.2060 - mean_absolute_error: 1.3587 - 39ms/epoch - 19ms/step
# Epoch 316/500
# 2/2 - 0s - loss: 3.6046 - mean_squared_error: 3.6046 - mean_absolute_error: 1.3517 - 37ms/epoch - 18ms/step
# Epoch 317/500
# 2/2 - 0s - loss: 3.6557 - mean_squared_error: 3.6557 - mean_absolute_error: 1.4581 - 36ms/epoch - 18ms/step
# Epoch 318/500
# 2/2 - 0s - loss: 2.8232 - mean_squared_error: 2.8232 - mean_absolute_error: 1.2720 - 36ms/epoch - 18ms/step
# Epoch 319/500
# 2/2 - 0s - loss: 4.3022 - mean_squared_error: 4.3022 - mean_absolute_error: 1.5555 - 33ms/epoch - 16ms/step
# Epoch 320/500
# 2/2 - 0s - loss: 3.7075 - mean_squared_error: 3.7075 - mean_absolute_error: 1.4903 - 36ms/epoch - 18ms/step
# Epoch 321/500
# 2/2 - 0s - loss: 3.4075 - mean_squared_error: 3.4075 - mean_absolute_error: 1.3927 - 38ms/epoch - 19ms/step
# Epoch 322/500
# 2/2 - 0s - loss: 4.3311 - mean_squared_error: 4.3311 - mean_absolute_error: 1.5702 - 35ms/epoch - 17ms/step
# Epoch 323/500
# 2/2 - 0s - loss: 3.9255 - mean_squared_error: 3.9255 - mean_absolute_error: 1.5259 - 34ms/epoch - 17ms/step
# Epoch 324/500
# 2/2 - 0s - loss: 3.4588 - mean_squared_error: 3.4588 - mean_absolute_error: 1.4376 - 36ms/epoch - 18ms/step
# Epoch 325/500
# 2/2 - 0s - loss: 4.4575 - mean_squared_error: 4.4575 - mean_absolute_error: 1.6170 - 36ms/epoch - 18ms/step
# Epoch 326/500
# 2/2 - 0s - loss: 3.0265 - mean_squared_error: 3.0265 - mean_absolute_error: 1.3386 - 36ms/epoch - 18ms/step
# Epoch 327/500
# 2/2 - 0s - loss: 4.2964 - mean_squared_error: 4.2964 - mean_absolute_error: 1.6029 - 36ms/epoch - 18ms/step
# Epoch 328/500
# 2/2 - 0s - loss: 3.4290 - mean_squared_error: 3.4290 - mean_absolute_error: 1.3856 - 39ms/epoch - 19ms/step
# Epoch 329/500
# 2/2 - 0s - loss: 3.6007 - mean_squared_error: 3.6007 - mean_absolute_error: 1.4235 - 37ms/epoch - 18ms/step
# Epoch 330/500
# 2/2 - 0s - loss: 3.1227 - mean_squared_error: 3.1227 - mean_absolute_error: 1.3425 - 37ms/epoch - 18ms/step
# Epoch 331/500
# 2/2 - 0s - loss: 2.9782 - mean_squared_error: 2.9782 - mean_absolute_error: 1.2967 - 37ms/epoch - 18ms/step
# Epoch 332/500
# 2/2 - 0s - loss: 3.1517 - mean_squared_error: 3.1517 - mean_absolute_error: 1.3293 - 37ms/epoch - 18ms/step
# Epoch 333/500
# 2/2 - 0s - loss: 3.2442 - mean_squared_error: 3.2442 - mean_absolute_error: 1.3309 - 36ms/epoch - 18ms/step
# Epoch 334/500
# 2/2 - 0s - loss: 2.7211 - mean_squared_error: 2.7211 - mean_absolute_error: 1.2462 - 36ms/epoch - 18ms/step
# Epoch 335/500
# 2/2 - 0s - loss: 3.6952 - mean_squared_error: 3.6952 - mean_absolute_error: 1.4020 - 39ms/epoch - 19ms/step
# Epoch 336/500
# 2/2 - 0s - loss: 4.2372 - mean_squared_error: 4.2372 - mean_absolute_error: 1.5200 - 40ms/epoch - 20ms/step
# Epoch 337/500
# 2/2 - 0s - loss: 3.5365 - mean_squared_error: 3.5365 - mean_absolute_error: 1.4075 - 37ms/epoch - 18ms/step
# Epoch 338/500
# 2/2 - 0s - loss: 2.9051 - mean_squared_error: 2.9051 - mean_absolute_error: 1.2730 - 38ms/epoch - 19ms/step
# Epoch 339/500
# 2/2 - 0s - loss: 3.4470 - mean_squared_error: 3.4470 - mean_absolute_error: 1.3943 - 35ms/epoch - 17ms/step
# Epoch 340/500
# 2/2 - 0s - loss: 3.3075 - mean_squared_error: 3.3075 - mean_absolute_error: 1.3971 - 35ms/epoch - 17ms/step
# Epoch 341/500
# 2/2 - 0s - loss: 3.0135 - mean_squared_error: 3.0135 - mean_absolute_error: 1.3308 - 34ms/epoch - 17ms/step
# Epoch 342/500
# 2/2 - 0s - loss: 3.0773 - mean_squared_error: 3.0773 - mean_absolute_error: 1.2928 - 35ms/epoch - 17ms/step
# Epoch 343/500
# 2/2 - 0s - loss: 3.0290 - mean_squared_error: 3.0290 - mean_absolute_error: 1.3272 - 35ms/epoch - 17ms/step
# Epoch 344/500
# 2/2 - 0s - loss: 2.8170 - mean_squared_error: 2.8170 - mean_absolute_error: 1.2418 - 35ms/epoch - 17ms/step
# Epoch 345/500
# 2/2 - 0s - loss: 2.9816 - mean_squared_error: 2.9816 - mean_absolute_error: 1.2657 - 35ms/epoch - 17ms/step
# Epoch 346/500
# 2/2 - 0s - loss: 3.0827 - mean_squared_error: 3.0827 - mean_absolute_error: 1.3367 - 37ms/epoch - 18ms/step
# Epoch 347/500
# 2/2 - 0s - loss: 2.8572 - mean_squared_error: 2.8572 - mean_absolute_error: 1.2463 - 37ms/epoch - 18ms/step
# Epoch 348/500
# 2/2 - 0s - loss: 2.7298 - mean_squared_error: 2.7298 - mean_absolute_error: 1.2326 - 36ms/epoch - 18ms/step
# Epoch 349/500
# 2/2 - 0s - loss: 3.1475 - mean_squared_error: 3.1475 - mean_absolute_error: 1.3403 - 36ms/epoch - 18ms/step
# Epoch 350/500
# 2/2 - 0s - loss: 2.8113 - mean_squared_error: 2.8113 - mean_absolute_error: 1.2232 - 38ms/epoch - 19ms/step
# Epoch 351/500
# 2/2 - 0s - loss: 3.0981 - mean_squared_error: 3.0981 - mean_absolute_error: 1.3108 - 42ms/epoch - 21ms/step
# Epoch 352/500
# 2/2 - 0s - loss: 2.8409 - mean_squared_error: 2.8409 - mean_absolute_error: 1.2222 - 38ms/epoch - 19ms/step
# Epoch 353/500
# 2/2 - 0s - loss: 2.9175 - mean_squared_error: 2.9175 - mean_absolute_error: 1.2561 - 36ms/epoch - 18ms/step
# Epoch 354/500
# 2/2 - 0s - loss: 2.9457 - mean_squared_error: 2.9457 - mean_absolute_error: 1.2430 - 39ms/epoch - 19ms/step
# Epoch 355/500
# 2/2 - 0s - loss: 2.7384 - mean_squared_error: 2.7384 - mean_absolute_error: 1.2449 - 35ms/epoch - 17ms/step
# Epoch 356/500
# 2/2 - 0s - loss: 3.0848 - mean_squared_error: 3.0848 - mean_absolute_error: 1.3059 - 37ms/epoch - 18ms/step
# Epoch 357/500
# 2/2 - 0s - loss: 2.6355 - mean_squared_error: 2.6355 - mean_absolute_error: 1.1962 - 42ms/epoch - 21ms/step
# Epoch 358/500
# 2/2 - 0s - loss: 3.2668 - mean_squared_error: 3.2668 - mean_absolute_error: 1.3225 - 39ms/epoch - 19ms/step
# Epoch 359/500
# 2/2 - 0s - loss: 2.8555 - mean_squared_error: 2.8555 - mean_absolute_error: 1.2515 - 38ms/epoch - 19ms/step
# Epoch 360/500
# 2/2 - 0s - loss: 2.8565 - mean_squared_error: 2.8565 - mean_absolute_error: 1.2634 - 37ms/epoch - 18ms/step
# Epoch 361/500
# 2/2 - 0s - loss: 2.9795 - mean_squared_error: 2.9795 - mean_absolute_error: 1.2575 - 38ms/epoch - 19ms/step
# Epoch 362/500
# 2/2 - 0s - loss: 2.5525 - mean_squared_error: 2.5525 - mean_absolute_error: 1.1808 - 37ms/epoch - 18ms/step
# Epoch 363/500
# 2/2 - 0s - loss: 2.5286 - mean_squared_error: 2.5286 - mean_absolute_error: 1.1848 - 38ms/epoch - 19ms/step
# Epoch 364/500
# 2/2 - 0s - loss: 2.7762 - mean_squared_error: 2.7762 - mean_absolute_error: 1.1915 - 38ms/epoch - 19ms/step
# Epoch 365/500
# 2/2 - 0s - loss: 3.1196 - mean_squared_error: 3.1196 - mean_absolute_error: 1.3009 - 37ms/epoch - 18ms/step
# Epoch 366/500
# 2/2 - 0s - loss: 2.5736 - mean_squared_error: 2.5736 - mean_absolute_error: 1.1840 - 38ms/epoch - 19ms/step
# Epoch 367/500
# 2/2 - 0s - loss: 2.5474 - mean_squared_error: 2.5474 - mean_absolute_error: 1.1838 - 34ms/epoch - 17ms/step
# Epoch 368/500
# 2/2 - 0s - loss: 2.6390 - mean_squared_error: 2.6390 - mean_absolute_error: 1.1884 - 36ms/epoch - 18ms/step
# Epoch 369/500
# 2/2 - 0s - loss: 3.2788 - mean_squared_error: 3.2788 - mean_absolute_error: 1.3320 - 35ms/epoch - 17ms/step
# Epoch 370/500
# 2/2 - 0s - loss: 4.0224 - mean_squared_error: 4.0224 - mean_absolute_error: 1.4215 - 37ms/epoch - 18ms/step
# Epoch 371/500
# 2/2 - 0s - loss: 3.7430 - mean_squared_error: 3.7430 - mean_absolute_error: 1.4209 - 37ms/epoch - 18ms/step
# Epoch 372/500
# 2/2 - 0s - loss: 3.9341 - mean_squared_error: 3.9341 - mean_absolute_error: 1.4777 - 36ms/epoch - 18ms/step
# Epoch 373/500
# 2/2 - 0s - loss: 4.1724 - mean_squared_error: 4.1724 - mean_absolute_error: 1.5514 - 36ms/epoch - 18ms/step
# Epoch 374/500
# 2/2 - 0s - loss: 4.4219 - mean_squared_error: 4.4219 - mean_absolute_error: 1.6497 - 40ms/epoch - 20ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 3.5915 - mean_squared_error: 3.5915 - mean_absolute_error: 1.4754 - 35ms/epoch - 17ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 4.0845 - mean_squared_error: 4.0845 - mean_absolute_error: 1.5276 - 36ms/epoch - 18ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 4.1989 - mean_squared_error: 4.1989 - mean_absolute_error: 1.5834 - 37ms/epoch - 18ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 3.2531 - mean_squared_error: 3.2531 - mean_absolute_error: 1.3846 - 41ms/epoch - 20ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 4.6733 - mean_squared_error: 4.6733 - mean_absolute_error: 1.6175 - 37ms/epoch - 18ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 3.4810 - mean_squared_error: 3.4810 - mean_absolute_error: 1.4530 - 40ms/epoch - 20ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 4.0956 - mean_squared_error: 4.0956 - mean_absolute_error: 1.5465 - 36ms/epoch - 18ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 3.8968 - mean_squared_error: 3.8968 - mean_absolute_error: 1.5134 - 36ms/epoch - 18ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 4.3805 - mean_squared_error: 4.3805 - mean_absolute_error: 1.5911 - 37ms/epoch - 18ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 3.2901 - mean_squared_error: 3.2901 - mean_absolute_error: 1.3733 - 35ms/epoch - 17ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 4.4613 - mean_squared_error: 4.4613 - mean_absolute_error: 1.5171 - 37ms/epoch - 18ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 4.1642 - mean_squared_error: 4.1642 - mean_absolute_error: 1.5928 - 35ms/epoch - 17ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 3.2711 - mean_squared_error: 3.2711 - mean_absolute_error: 1.3795 - 37ms/epoch - 18ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 3.5147 - mean_squared_error: 3.5147 - mean_absolute_error: 1.4338 - 37ms/epoch - 18ms/step
# Epoch 389/500
# 2/2 - 0s - loss: 3.1950 - mean_squared_error: 3.1950 - mean_absolute_error: 1.3728 - 40ms/epoch - 20ms/step
# Epoch 390/500
# 2/2 - 0s - loss: 3.1020 - mean_squared_error: 3.1020 - mean_absolute_error: 1.3496 - 35ms/epoch - 17ms/step
# Epoch 391/500
# 2/2 - 0s - loss: 3.2858 - mean_squared_error: 3.2858 - mean_absolute_error: 1.3137 - 35ms/epoch - 17ms/step
# Epoch 392/500
# 2/2 - 0s - loss: 3.1738 - mean_squared_error: 3.1738 - mean_absolute_error: 1.3567 - 35ms/epoch - 17ms/step
# Epoch 393/500
# 2/2 - 0s - loss: 2.7832 - mean_squared_error: 2.7832 - mean_absolute_error: 1.2397 - 34ms/epoch - 17ms/step
# Epoch 394/500
# 2/2 - 0s - loss: 2.8438 - mean_squared_error: 2.8438 - mean_absolute_error: 1.2472 - 35ms/epoch - 17ms/step
# Epoch 395/500
# 2/2 - 0s - loss: 2.8999 - mean_squared_error: 2.8999 - mean_absolute_error: 1.2878 - 36ms/epoch - 18ms/step
# Epoch 396/500
# 2/2 - 0s - loss: 2.8911 - mean_squared_error: 2.8911 - mean_absolute_error: 1.2444 - 33ms/epoch - 16ms/step
# Epoch 397/500
# 2/2 - 0s - loss: 2.6547 - mean_squared_error: 2.6547 - mean_absolute_error: 1.2202 - 37ms/epoch - 18ms/step
# Epoch 398/500
# 2/2 - 0s - loss: 2.9684 - mean_squared_error: 2.9684 - mean_absolute_error: 1.2840 - 36ms/epoch - 18ms/step
# Epoch 399/500
# 2/2 - 0s - loss: 2.9954 - mean_squared_error: 2.9954 - mean_absolute_error: 1.2830 - 34ms/epoch - 17ms/step
# Epoch 400/500
# 2/2 - 0s - loss: 2.6864 - mean_squared_error: 2.6864 - mean_absolute_error: 1.2203 - val_loss: 22.7171 - val_mean_squared_error: 22.7171 - val_mean_absolute_error: 4.2262 - 68ms/epoch - 34ms/step
# Epoch 401/500
# 2/2 - 0s - loss: 2.6541 - mean_squared_error: 2.6541 - mean_absolute_error: 1.2158 - 34ms/epoch - 17ms/step
# Epoch 402/500
# 2/2 - 0s - loss: 2.5829 - mean_squared_error: 2.5829 - mean_absolute_error: 1.1686 - 37ms/epoch - 18ms/step
# Epoch 403/500
# 2/2 - 0s - loss: 2.8688 - mean_squared_error: 2.8688 - mean_absolute_error: 1.2579 - 38ms/epoch - 19ms/step
# Epoch 404/500
# 2/2 - 0s - loss: 3.1948 - mean_squared_error: 3.1948 - mean_absolute_error: 1.2582 - 37ms/epoch - 18ms/step
# Epoch 405/500
# 2/2 - 0s - loss: 2.8772 - mean_squared_error: 2.8772 - mean_absolute_error: 1.2769 - 37ms/epoch - 18ms/step
# Epoch 406/500
# 2/2 - 0s - loss: 3.0370 - mean_squared_error: 3.0370 - mean_absolute_error: 1.2659 - 34ms/epoch - 17ms/step
# Epoch 407/500
# 2/2 - 0s - loss: 2.4843 - mean_squared_error: 2.4843 - mean_absolute_error: 1.1583 - 36ms/epoch - 18ms/step
# Epoch 408/500
# 2/2 - 0s - loss: 3.1960 - mean_squared_error: 3.1960 - mean_absolute_error: 1.3708 - 35ms/epoch - 17ms/step
# Epoch 409/500
# 2/2 - 0s - loss: 2.6676 - mean_squared_error: 2.6676 - mean_absolute_error: 1.1855 - 36ms/epoch - 18ms/step
# Epoch 410/500
# 2/2 - 0s - loss: 2.6042 - mean_squared_error: 2.6042 - mean_absolute_error: 1.2012 - 36ms/epoch - 18ms/step
# Epoch 411/500
# 2/2 - 0s - loss: 3.2384 - mean_squared_error: 3.2384 - mean_absolute_error: 1.2687 - 37ms/epoch - 18ms/step
# Epoch 412/500
# 2/2 - 0s - loss: 3.6021 - mean_squared_error: 3.6021 - mean_absolute_error: 1.3893 - 38ms/epoch - 19ms/step
# Epoch 413/500
# 2/2 - 0s - loss: 3.1498 - mean_squared_error: 3.1498 - mean_absolute_error: 1.3552 - 35ms/epoch - 17ms/step
# Epoch 414/500
# 2/2 - 0s - loss: 3.6437 - mean_squared_error: 3.6437 - mean_absolute_error: 1.4032 - 32ms/epoch - 16ms/step
# Epoch 415/500
# 2/2 - 0s - loss: 3.8038 - mean_squared_error: 3.8038 - mean_absolute_error: 1.5894 - 34ms/epoch - 17ms/step
# Epoch 416/500
# 2/2 - 0s - loss: 3.2038 - mean_squared_error: 3.2038 - mean_absolute_error: 1.3721 - 35ms/epoch - 17ms/step
# Epoch 417/500
# 2/2 - 0s - loss: 3.6208 - mean_squared_error: 3.6208 - mean_absolute_error: 1.4658 - 35ms/epoch - 17ms/step
# Epoch 418/500
# 2/2 - 0s - loss: 3.1186 - mean_squared_error: 3.1186 - mean_absolute_error: 1.3738 - 36ms/epoch - 18ms/step
# Epoch 419/500
# 2/2 - 0s - loss: 3.1648 - mean_squared_error: 3.1648 - mean_absolute_error: 1.3649 - 36ms/epoch - 18ms/step
# Epoch 420/500
# 2/2 - 0s - loss: 3.3786 - mean_squared_error: 3.3786 - mean_absolute_error: 1.3463 - 36ms/epoch - 18ms/step
# Epoch 421/500
# 2/2 - 0s - loss: 3.3705 - mean_squared_error: 3.3705 - mean_absolute_error: 1.4298 - 35ms/epoch - 17ms/step
# Epoch 422/500
# 2/2 - 0s - loss: 2.6480 - mean_squared_error: 2.6480 - mean_absolute_error: 1.2440 - 37ms/epoch - 18ms/step
# Epoch 423/500
# 2/2 - 0s - loss: 4.1982 - mean_squared_error: 4.1982 - mean_absolute_error: 1.4670 - 38ms/epoch - 19ms/step
# Epoch 424/500
# 2/2 - 0s - loss: 5.2852 - mean_squared_error: 5.2852 - mean_absolute_error: 1.7145 - 37ms/epoch - 18ms/step
# Epoch 425/500
# 2/2 - 0s - loss: 4.6245 - mean_squared_error: 4.6245 - mean_absolute_error: 1.6186 - 37ms/epoch - 18ms/step
# Epoch 426/500
# 2/2 - 0s - loss: 3.8670 - mean_squared_error: 3.8670 - mean_absolute_error: 1.5352 - 37ms/epoch - 18ms/step
# Epoch 427/500
# 2/2 - 0s - loss: 3.9531 - mean_squared_error: 3.9531 - mean_absolute_error: 1.5655 - 37ms/epoch - 18ms/step
# Epoch 428/500
# 2/2 - 0s - loss: 3.1038 - mean_squared_error: 3.1038 - mean_absolute_error: 1.3647 - 37ms/epoch - 18ms/step
# Epoch 429/500
# 2/2 - 0s - loss: 4.2873 - mean_squared_error: 4.2873 - mean_absolute_error: 1.6025 - 34ms/epoch - 17ms/step
# Epoch 430/500
# 2/2 - 0s - loss: 3.7130 - mean_squared_error: 3.7130 - mean_absolute_error: 1.5051 - 35ms/epoch - 17ms/step
# Epoch 431/500
# 2/2 - 0s - loss: 3.6189 - mean_squared_error: 3.6189 - mean_absolute_error: 1.5035 - 37ms/epoch - 18ms/step
# Epoch 432/500
# 2/2 - 0s - loss: 3.6298 - mean_squared_error: 3.6298 - mean_absolute_error: 1.3902 - 37ms/epoch - 18ms/step
# Epoch 433/500
# 2/2 - 0s - loss: 2.9387 - mean_squared_error: 2.9387 - mean_absolute_error: 1.2982 - 36ms/epoch - 18ms/step
# Epoch 434/500
# 2/2 - 0s - loss: 3.1705 - mean_squared_error: 3.1705 - mean_absolute_error: 1.3622 - 39ms/epoch - 19ms/step
# Epoch 435/500
# 2/2 - 0s - loss: 2.9267 - mean_squared_error: 2.9267 - mean_absolute_error: 1.2724 - 38ms/epoch - 19ms/step
# Epoch 436/500
# 2/2 - 0s - loss: 2.6513 - mean_squared_error: 2.6513 - mean_absolute_error: 1.2063 - 39ms/epoch - 19ms/step
# Epoch 437/500
# 2/2 - 0s - loss: 3.0037 - mean_squared_error: 3.0037 - mean_absolute_error: 1.3314 - 36ms/epoch - 18ms/step
# Epoch 438/500
# 2/2 - 0s - loss: 3.6348 - mean_squared_error: 3.6348 - mean_absolute_error: 1.3514 - 37ms/epoch - 18ms/step
# Epoch 439/500
# 2/2 - 0s - loss: 3.5117 - mean_squared_error: 3.5117 - mean_absolute_error: 1.4293 - 38ms/epoch - 19ms/step
# Epoch 440/500
# 2/2 - 0s - loss: 3.1621 - mean_squared_error: 3.1621 - mean_absolute_error: 1.3523 - 37ms/epoch - 19ms/step
# Epoch 441/500
# 2/2 - 0s - loss: 3.9545 - mean_squared_error: 3.9545 - mean_absolute_error: 1.4610 - 36ms/epoch - 18ms/step
# Epoch 442/500
# 2/2 - 0s - loss: 2.9437 - mean_squared_error: 2.9437 - mean_absolute_error: 1.3170 - 35ms/epoch - 17ms/step
# Epoch 443/500
# 2/2 - 0s - loss: 3.1673 - mean_squared_error: 3.1673 - mean_absolute_error: 1.3245 - 35ms/epoch - 17ms/step
# Epoch 444/500
# 2/2 - 0s - loss: 2.7975 - mean_squared_error: 2.7975 - mean_absolute_error: 1.2460 - 35ms/epoch - 17ms/step
# Epoch 445/500
# 2/2 - 0s - loss: 3.3010 - mean_squared_error: 3.3010 - mean_absolute_error: 1.3828 - 34ms/epoch - 17ms/step
# Epoch 446/500
# 2/2 - 0s - loss: 3.1400 - mean_squared_error: 3.1400 - mean_absolute_error: 1.2914 - 36ms/epoch - 18ms/step
# Epoch 447/500
# 2/2 - 0s - loss: 4.0440 - mean_squared_error: 4.0440 - mean_absolute_error: 1.4529 - 37ms/epoch - 18ms/step
# Epoch 448/500
# 2/2 - 0s - loss: 3.6451 - mean_squared_error: 3.6451 - mean_absolute_error: 1.4341 - 35ms/epoch - 17ms/step
# Epoch 449/500
# 2/2 - 0s - loss: 3.1486 - mean_squared_error: 3.1486 - mean_absolute_error: 1.3077 - 34ms/epoch - 17ms/step
# Epoch 450/500
# 2/2 - 0s - loss: 3.4319 - mean_squared_error: 3.4319 - mean_absolute_error: 1.4022 - 37ms/epoch - 18ms/step
# Epoch 451/500
# 2/2 - 0s - loss: 2.8527 - mean_squared_error: 2.8527 - mean_absolute_error: 1.2529 - 36ms/epoch - 18ms/step
# Epoch 452/500
# 2/2 - 0s - loss: 3.4945 - mean_squared_error: 3.4945 - mean_absolute_error: 1.3734 - 39ms/epoch - 19ms/step
# Epoch 453/500
# 2/2 - 0s - loss: 2.9207 - mean_squared_error: 2.9207 - mean_absolute_error: 1.3083 - 47ms/epoch - 23ms/step
# Epoch 454/500
# 2/2 - 0s - loss: 2.7632 - mean_squared_error: 2.7632 - mean_absolute_error: 1.1971 - 41ms/epoch - 20ms/step
# Epoch 455/500
# 2/2 - 0s - loss: 2.5770 - mean_squared_error: 2.5770 - mean_absolute_error: 1.1873 - 38ms/epoch - 19ms/step
# Epoch 456/500
# 2/2 - 0s - loss: 2.8630 - mean_squared_error: 2.8630 - mean_absolute_error: 1.2644 - 36ms/epoch - 18ms/step
# Epoch 457/500
# 2/2 - 0s - loss: 3.1062 - mean_squared_error: 3.1062 - mean_absolute_error: 1.2881 - 38ms/epoch - 19ms/step
# Epoch 458/500
# 2/2 - 0s - loss: 2.5474 - mean_squared_error: 2.5474 - mean_absolute_error: 1.2235 - 36ms/epoch - 18ms/step
# Epoch 459/500
# 2/2 - 0s - loss: 2.6586 - mean_squared_error: 2.6586 - mean_absolute_error: 1.2436 - 37ms/epoch - 18ms/step
# Epoch 460/500
# 2/2 - 0s - loss: 2.7224 - mean_squared_error: 2.7224 - mean_absolute_error: 1.2072 - 38ms/epoch - 19ms/step
# Epoch 461/500
# 2/2 - 0s - loss: 2.4016 - mean_squared_error: 2.4016 - mean_absolute_error: 1.1604 - 38ms/epoch - 19ms/step
# Epoch 462/500
# 2/2 - 0s - loss: 2.5720 - mean_squared_error: 2.5720 - mean_absolute_error: 1.2292 - 37ms/epoch - 18ms/step
# Epoch 463/500
# 2/2 - 0s - loss: 2.5379 - mean_squared_error: 2.5379 - mean_absolute_error: 1.1450 - 39ms/epoch - 19ms/step
# Epoch 464/500
# 2/2 - 0s - loss: 2.7384 - mean_squared_error: 2.7384 - mean_absolute_error: 1.2371 - 33ms/epoch - 16ms/step
# Epoch 465/500
# 2/2 - 0s - loss: 2.5038 - mean_squared_error: 2.5038 - mean_absolute_error: 1.1675 - 35ms/epoch - 17ms/step
# Epoch 466/500
# 2/2 - 0s - loss: 2.6050 - mean_squared_error: 2.6050 - mean_absolute_error: 1.1821 - 37ms/epoch - 18ms/step
# Epoch 467/500
# 2/2 - 0s - loss: 2.3624 - mean_squared_error: 2.3624 - mean_absolute_error: 1.1465 - 38ms/epoch - 19ms/step
# Epoch 468/500
# 2/2 - 0s - loss: 2.8891 - mean_squared_error: 2.8891 - mean_absolute_error: 1.2839 - 36ms/epoch - 18ms/step
# Epoch 469/500
# 2/2 - 0s - loss: 2.6461 - mean_squared_error: 2.6461 - mean_absolute_error: 1.2193 - 38ms/epoch - 19ms/step
# Epoch 470/500
# 2/2 - 0s - loss: 2.5637 - mean_squared_error: 2.5637 - mean_absolute_error: 1.1752 - 36ms/epoch - 18ms/step
# Epoch 471/500
# 2/2 - 0s - loss: 2.6941 - mean_squared_error: 2.6941 - mean_absolute_error: 1.2101 - 39ms/epoch - 19ms/step
# Epoch 472/500
# 2/2 - 0s - loss: 2.4626 - mean_squared_error: 2.4626 - mean_absolute_error: 1.1585 - 36ms/epoch - 18ms/step
# Epoch 473/500
# 2/2 - 0s - loss: 2.3678 - mean_squared_error: 2.3678 - mean_absolute_error: 1.1299 - 37ms/epoch - 18ms/step
# Epoch 474/500
# 2/2 - 0s - loss: 2.2657 - mean_squared_error: 2.2657 - mean_absolute_error: 1.0943 - 34ms/epoch - 17ms/step
# Epoch 475/500
# 2/2 - 0s - loss: 2.2609 - mean_squared_error: 2.2609 - mean_absolute_error: 1.1048 - 34ms/epoch - 17ms/step
# Epoch 476/500
# 2/2 - 0s - loss: 2.2811 - mean_squared_error: 2.2811 - mean_absolute_error: 1.0923 - 34ms/epoch - 17ms/step
# Epoch 477/500
# 2/2 - 0s - loss: 2.2633 - mean_squared_error: 2.2633 - mean_absolute_error: 1.1101 - 39ms/epoch - 19ms/step
# Epoch 478/500
# 2/2 - 0s - loss: 2.3873 - mean_squared_error: 2.3873 - mean_absolute_error: 1.1099 - 35ms/epoch - 17ms/step
# Epoch 479/500
# 2/2 - 0s - loss: 2.4500 - mean_squared_error: 2.4500 - mean_absolute_error: 1.1631 - 34ms/epoch - 17ms/step
# Epoch 480/500
# 2/2 - 0s - loss: 2.1991 - mean_squared_error: 2.1991 - mean_absolute_error: 1.0965 - 35ms/epoch - 17ms/step
# Epoch 481/500
# 2/2 - 0s - loss: 2.1383 - mean_squared_error: 2.1383 - mean_absolute_error: 1.0745 - 39ms/epoch - 19ms/step
# Epoch 482/500
# 2/2 - 0s - loss: 2.1081 - mean_squared_error: 2.1081 - mean_absolute_error: 1.0582 - 36ms/epoch - 18ms/step
# Epoch 483/500
# 2/2 - 0s - loss: 2.0942 - mean_squared_error: 2.0942 - mean_absolute_error: 1.0546 - 38ms/epoch - 19ms/step
# Epoch 484/500
# 2/2 - 0s - loss: 2.1911 - mean_squared_error: 2.1911 - mean_absolute_error: 1.1060 - 35ms/epoch - 17ms/step
# Epoch 485/500
# 2/2 - 0s - loss: 2.1845 - mean_squared_error: 2.1845 - mean_absolute_error: 1.0669 - 38ms/epoch - 19ms/step
# Epoch 486/500
# 2/2 - 0s - loss: 2.3654 - mean_squared_error: 2.3654 - mean_absolute_error: 1.1036 - 36ms/epoch - 18ms/step
# Epoch 487/500
# 2/2 - 0s - loss: 2.9095 - mean_squared_error: 2.9095 - mean_absolute_error: 1.2292 - 37ms/epoch - 18ms/step
# Epoch 488/500
# 2/2 - 0s - loss: 2.8370 - mean_squared_error: 2.8370 - mean_absolute_error: 1.2432 - 35ms/epoch - 17ms/step
# Epoch 489/500
# 2/2 - 0s - loss: 2.6812 - mean_squared_error: 2.6812 - mean_absolute_error: 1.2065 - 35ms/epoch - 17ms/step
# Epoch 490/500
# 2/2 - 0s - loss: 2.5759 - mean_squared_error: 2.5759 - mean_absolute_error: 1.1834 - 37ms/epoch - 18ms/step
# Epoch 491/500
# 2/2 - 0s - loss: 2.5582 - mean_squared_error: 2.5582 - mean_absolute_error: 1.1765 - 35ms/epoch - 17ms/step
# Epoch 492/500
# 2/2 - 0s - loss: 2.8555 - mean_squared_error: 2.8555 - mean_absolute_error: 1.2329 - 34ms/epoch - 17ms/step
# Epoch 493/500
# 2/2 - 0s - loss: 2.4070 - mean_squared_error: 2.4070 - mean_absolute_error: 1.1412 - 34ms/epoch - 17ms/step
# Epoch 494/500
# 2/2 - 0s - loss: 2.3703 - mean_squared_error: 2.3703 - mean_absolute_error: 1.1171 - 37ms/epoch - 18ms/step
# Epoch 495/500
# 2/2 - 0s - loss: 2.2997 - mean_squared_error: 2.2997 - mean_absolute_error: 1.1352 - 34ms/epoch - 17ms/step
# Epoch 496/500
# 2/2 - 0s - loss: 3.2325 - mean_squared_error: 3.2325 - mean_absolute_error: 1.2567 - 35ms/epoch - 17ms/step
# Epoch 497/500
# 2/2 - 0s - loss: 4.6968 - mean_squared_error: 4.6968 - mean_absolute_error: 1.5369 - 35ms/epoch - 17ms/step
# Epoch 498/500
# 2/2 - 0s - loss: 4.2894 - mean_squared_error: 4.2894 - mean_absolute_error: 1.5985 - 38ms/epoch - 19ms/step
# Epoch 499/500
# 2/2 - 0s - loss: 4.7913 - mean_squared_error: 4.7913 - mean_absolute_error: 1.6534 - 37ms/epoch - 18ms/step
# Epoch 500/500
# 2/2 - 0s - loss: 4.7567 - mean_squared_error: 4.7567 - mean_absolute_error: 1.7651 - val_loss: 14.9640 - val_mean_squared_error: 14.9640 - val_mean_absolute_error: 3.1838 - 67ms/epoch - 33ms/step

# %%
##### Step 6 - Use model to make predictions
# Predict results on training data
pred_train = model.predict(X_train)
# Predict esults on test data
pred_test = model.predict(X_test)
# Out:
# 3/3 [==============================] - 1s 12ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
##### Step 7 - Print Performance Summary
print("")
print('-------------------- Model Summary --------------------')
model.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking_4 (Masking)         (None, 11, 1)             0
#
#  Input-Layer (InputLayer)    multiple                  0
#
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              33792
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 11, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 11, 128)          98816
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 11, 1)            129
#  ed)
#
# =================================================================
# Total params: 132,737
# Trainable params: 132,737
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 4.756666660308838
# Final mean_squared_error : 4.75666618347168
# Final mean_absolute_error : 1.7650755643844604
# Final val_loss : 14.96403694152832
# Final val_mean_squared_error : 14.96403694152832
# Final val_mean_absolute_error : 3.1837892532348633
#
# -------------------- Evaluation on Test Data --------------------
# 1/1 [==============================] - 0s 26ms/step - loss: 101.8140 - mean_squared_error: 101.8140 - mean_absolute_error: 9.9123

# %%
# Plot average monthly temperatures (actual and predicted) for test (out of time) data
fig = go.Figure()
fig.add_trace(go.Scatter(x=np.array(df_train.columns),
                         y=np.array(df_train.values).flatten(),
                         mode='lines',
                         name='Subsidence - Actual (Train)',
                         opacity=0.8,
                         line=dict(color='blue', width=1)
                        ))

#Trace for actual temperatures
fig.add_trace(go.Scatter(x=np.array(df_test.columns),
                         y=np.array(df_test.values).flatten(),
                         mode='lines',
                         name='Subsidence - Actual (Test)',
                         opacity=0.8,
                         line=dict(color='green', width=1)
                        ))

# Trace for predicted temperatures
fig.add_trace(go.Scatter(x=np.array(df_test.columns[-timestep:]),
                         y=pred_test.flatten(),
                         mode='lines',
                         name='Subsidence - Predicted (Test)',
                         opacity=0.8,
                         line=dict(color='red', width=1)
                        ))
fig.add_trace(go.Scatter(x=np.array(df_train.columns),
                         y=np.array(df_train.values).flatten(),
                         mode='lines',
                         name='Subsidence - Actual (Train)',
                         opacity=0.8,
                         line=dict(color='blue', width=1)
                        ))
# Change chart background color
fig.update_layout(dict(plot_bgcolor = 'white'))

# Update axes lines
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Month-Year'
                )

fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Subsidence'
                )

# Set figure title
fig.update_layout(title=dict(text="Subsidence", font=dict(color='black')),
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
                 )
fig.show()
