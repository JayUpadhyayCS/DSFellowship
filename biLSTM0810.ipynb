# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D, GRU # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
from keras import metrics
from keras.utils import plot_model
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
#df=df.iloc[200000:200050]
df=df.iloc[121000:122000]

df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 36.7274          0.0     -7.2490    1.302700      3.3471
#           36.7294          0.0     -7.2853    0.556740      2.6414
#           36.7314          0.0     -7.2516    0.725010      3.1202
#           36.7334          0.0     -7.2281    0.096472      2.6289
#           36.7354          0.0     -7.2193    0.017607      2.5645
# ...                        ...         ...         ...         ...
#           36.9514          0.0     -7.3948   -1.156800      1.4848
#           36.9534          0.0     -7.4457   -1.220300      1.4798
#           36.9554          0.0     -7.5344   -1.301900      1.3754
#           36.9574          0.0     -7.4291   -1.205400      1.5147
#           36.9594          0.0     -7.4860   -1.265200      1.5029
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 36.7274     0.559450      4.9899    0.097604     2.43740
#           36.7294    -0.087468      4.4041   -0.425990     1.85160
#           36.7314     0.332020      4.7691   -0.113410     2.06200
#           36.7334    -0.236170      4.1671   -0.710090     1.29160
#           36.7354    -0.348470      4.0190   -0.700280     1.28920
# ...                        ...         ...         ...         ...
#           36.9514    -2.145500      2.1998   -3.253100    -0.66425
#           36.9534    -2.235700      2.0776   -3.358200    -0.81047
#           36.9554    -2.262900      2.0024   -3.521800    -0.91746
#           36.9574    -2.208300      2.1260   -3.330000    -0.80230
#           36.9594    -2.282700      1.9995   -3.545700    -0.95399
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 36.7274      4.88720    0.456220  ...     -3.5142     0.22057
#           36.7294      3.98820   -0.430640  ...     -4.8468    -1.33030
#           36.7314      4.53310    0.058487  ...     -4.3295    -1.15050
#           36.7334      3.67920   -0.670650  ...     -4.9279    -2.22810
#           36.7354      3.51050   -0.810160  ...     -5.1372    -2.18040
# ...                        ...         ...  ...         ...         ...
#           36.9514     -0.20888   -3.667700  ...    -36.1600   -33.40300
#           36.9534     -0.47350   -3.933800  ...    -36.7660   -33.95500
#           36.9554     -0.80308   -4.120000  ...    -37.7410   -34.89400
#           36.9574     -0.81612   -4.259100  ...    -38.3520   -35.53700
#           36.9594     -1.09090   -4.474900  ...    -38.0100   -35.13400
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 36.7274     -0.75692     -1.1566     -4.3719     -3.4757
#           36.7294     -2.28430     -2.7012     -5.9231     -5.0010
#           36.7314     -2.07920     -2.4924     -5.7231     -4.7722
#           36.7334     -3.12990     -3.5177     -6.7513     -5.8016
#           36.7354     -3.07510     -3.4345     -6.6559     -5.7015
# ...                        ...         ...         ...         ...
#           36.9514    -34.18600    -34.9080    -38.0880    -38.6990
#           36.9534    -34.75000    -35.4730    -38.6430    -39.2620
#           36.9554    -35.72300    -36.4550    -39.6440    -40.2500
#           36.9574    -36.37800    -37.1280    -40.3540    -40.9600
#           36.9594    -35.98600    -36.7380    -39.9750    -40.5770
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 36.7274      -2.4292    -0.40118     -1.0285     1.10940
#           36.7294      -3.9947    -2.00780     -2.6674    -0.49823
#           36.7314      -3.8035    -1.86670     -2.4927    -0.35814
#           36.7334      -4.8616    -2.96420     -3.6058    -1.50490
#           36.7354      -4.8013    -2.90890     -3.5570    -1.45940
# ...                        ...         ...         ...         ...
#           36.9514     -36.9030   -35.25700    -36.0210   -33.29200
#           36.9534     -37.4540   -35.78200    -36.5210   -33.80600
#           36.9554     -38.4620   -36.79700    -37.5290   -34.80800
#           36.9574     -39.1770   -37.49900    -38.2370   -35.52500
#           36.9594     -38.7820   -37.08400    -37.8090   -35.11900
#
# [100 rows x 110 columns]

# %%
df2=pd.read_csv('InSAR_data_south/displacement/groundwater.csv')
df2=df2.set_index([df2.columns[0],df2.columns[1]])
df2.columns=pd.to_datetime(df2.columns, format='%Y-%m-%d')
df2=df2.dropna(axis=0, how='all')#drop full nan rows
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != df2.columns[y]: #if column is misssing insert it
        df2.insert(loc=y,column=df.columns[y],value=np.nan*11286,allow_duplicates=False)
df2.index[0]
type(df2.index[0])
# Out:
# tuple

# %%
df2.index.size
# Out:
# 11286

# %%
for x in range(df2.index.size): #for each row
    curr=np.nan
    for y in range(df2.columns.size): #for each value in the row
        n=0
        while np.isnan(curr): # if saved value is empty
            curr=df2.iloc[x].values[n] #look for next actual value
            n+=1
        if np.isnan(df2.iloc[x].values[y]):#if data is nan then replace with previous curr value
            df2.iat[x,y]=curr
            #df2.iloc[x].values[y]=curr
        else:
            curr= df2.iloc[x].values[y]
                

df2
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    81.000000   81.000000  ...   75.653992   75.813688
# -120.8926 36.7114    72.248964   72.248964  ...   75.200000   75.200000
# -120.8846 36.6994    72.248964   72.248964  ...   75.200000   75.200000
# -120.8746 36.6874    72.248964   72.248964  ...   75.200000   75.200000
# -120.1368 35.6991   141.123387  141.123387  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091  ...   16.978182   17.000000
# -119.0271 36.3793    17.409091   17.409091  ...   16.978182   17.000000
# -119.0571 36.4493    17.409091   17.409091  ...   16.978182   17.000000
# -119.0211 36.3993    17.409091   17.409091  ...   16.978182   17.000000
# -119.0111 36.3873    17.409091   17.409091  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0        76.0        76.0
# -120.8926 36.7114    75.200000        75.2        75.2        75.2
# -120.8846 36.6994    75.200000        75.2        75.2        75.2
# -120.8746 36.6874    75.200000        75.2        75.2        75.2
# -120.1368 35.6991   151.000000       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.000000        17.0        17.0        17.0
# -119.0271 36.3793    17.000000        17.0        17.0        17.0
# -119.0571 36.4493    17.000000        17.0        17.0        17.0
# -119.0211 36.3993    17.000000        17.0        17.0        17.0
# -119.0111 36.3873    17.000000        17.0        17.0        17.0
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316         76.0        76.0        76.0        76.0
# -120.8926 36.7114         75.2        75.2        75.2        75.2
# -120.8846 36.6994         75.2        75.2        75.2        75.2
# -120.8746 36.6874         75.2        75.2        75.2        75.2
# -120.1368 35.6991        151.0       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933         17.0        17.0        17.0        17.0
# -119.0271 36.3793         17.0        17.0        17.0        17.0
# -119.0571 36.4493         17.0        17.0        17.0        17.0
# -119.0211 36.3993         17.0        17.0        17.0        17.0
# -119.0111 36.3873         17.0        17.0        17.0        17.0
#
# [11286 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10
# 1 2 3 4 5 6 7 ...
# w/ timestep of 2
# [[1,2][2,3][3,4]

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    for row in range(len(datain.index)): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    print(X_comb.shape)
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %%
def shaping2(datain,datain2, timestep):
    #print(arr)
    cnt=0
    for row in datain2.index: #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        arr=datain.loc[row].to_numpy().flatten() # flatten row
        arr2=datain2.loc[row].to_numpy().flatten()
        arr3=np.concatenate((arr,arr2)).reshape(2,110)
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[0][Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[0][Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 2))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 2))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing

train, test = train_test_split(df, test_size=0.2, random_state=64, shuffle=False)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)
# Out:
# (72800,)
# (18200,)

# %%
scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
Y_train = scaler.fit_transform(Y_train.reshape(-1, Y_train.shape[-1])).reshape(Y_train.shape)
Y_test = scaler.transform(Y_test.reshape(-1, Y_test.shape[-1])).reshape(Y_test.shape)

# %%
X_train
# Out:
# array([[[0.75760676],
#         [0.52939602],
#         [0.79861795],
#         ...,
#         [0.83434022],
#         [0.91146406],
#         [0.77196934]],
#
#        [[0.52939602],
#         [0.79861795],
#         [0.86297911],
#         ...,
#         [0.91146406],
#         [0.77196934],
#         [0.78179194]],
#
#        [[0.79861795],
#         [0.86297911],
#         [0.77521919],
#         ...,
#         [0.77196934],
#         [0.78179194],
#         [0.66143336]],
#
#        ...,
#
#        [[0.07986904],
#         [0.1849549 ],
#         [0.09812841],
#         ...,
#         [0.05292071],
#         [0.03774654],
#         [0.02210014]],
#
#        [[0.1849549 ],
#         [0.09812841],
#         [0.1400935 ],
#         ...,
#         [0.03774654],
#         [0.02210014],
#         [0.06655228]],
#
#        [[0.09812841],
#         [0.1400935 ],
#         [0.07810606],
#         ...,
#         [0.02210014],
#         [0.06655228],
#         [0.        ]]])

# %%
X_train[0]
# Out:
# array([[0.75760676],
#        [0.52939602],
#        [0.79861795],
#        [0.86297911],
#        [0.77521919],
#        [0.91469722],
#        [0.7606795 ],
#        [0.83434022],
#        [0.91146406],
#        [0.77196934]])

# %%
X_train[1]
# Out:
# array([[0.52939602],
#        [0.79861795],
#        [0.86297911],
#        [0.77521919],
#        [0.91469722],
#        [0.7606795 ],
#        [0.83434022],
#        [0.91146406],
#        [0.77196934],
#        [0.78179194]])

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model2 = Sequential(name="biLSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'accuracy'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=50, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 2912/2912 - 20s - loss: 0.0085 - mean_squared_error: 0.0085 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 2/250
# 2912/2912 - 17s - loss: 0.0061 - mean_squared_error: 0.0061 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 3/250
# 2912/2912 - 18s - loss: 0.0057 - mean_squared_error: 0.0057 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 4/250
# 2912/2912 - 18s - loss: 0.0056 - mean_squared_error: 0.0056 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 5/250
# 2912/2912 - 18s - loss: 0.0055 - mean_squared_error: 0.0055 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 6/250
# 2912/2912 - 18s - loss: 0.0054 - mean_squared_error: 0.0054 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 7/250
# 2912/2912 - 18s - loss: 0.0054 - mean_squared_error: 0.0054 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 8/250
# 2912/2912 - 19s - loss: 0.0053 - mean_squared_error: 0.0053 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 9/250
# 2912/2912 - 19s - loss: 0.0052 - mean_squared_error: 0.0052 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 10/250
# 2912/2912 - 20s - loss: 0.0051 - mean_squared_error: 0.0051 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 11/250
# 2912/2912 - 19s - loss: 0.0050 - mean_squared_error: 0.0050 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 12/250
# 2912/2912 - 20s - loss: 0.0049 - mean_squared_error: 0.0049 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 13/250
# 2912/2912 - 21s - loss: 0.0048 - mean_squared_error: 0.0048 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 14/250
# 2912/2912 - 26s - loss: 0.0047 - mean_squared_error: 0.0047 - accuracy: 1.7170e-04 - 26s/epoch - 9ms/step
# Epoch 15/250
# 2912/2912 - 26s - loss: 0.0046 - mean_squared_error: 0.0046 - accuracy: 1.7170e-04 - 26s/epoch - 9ms/step
# Epoch 16/250
# 2912/2912 - 24s - loss: 0.0045 - mean_squared_error: 0.0045 - accuracy: 1.7170e-04 - 24s/epoch - 8ms/step
# Epoch 17/250
# 2912/2912 - 24s - loss: 0.0044 - mean_squared_error: 0.0044 - accuracy: 1.7170e-04 - 24s/epoch - 8ms/step
# Epoch 18/250
# 2912/2912 - 24s - loss: 0.0042 - mean_squared_error: 0.0042 - accuracy: 1.7170e-04 - 24s/epoch - 8ms/step
# Epoch 19/250
# 2912/2912 - 25s - loss: 0.0041 - mean_squared_error: 0.0041 - accuracy: 1.7170e-04 - 25s/epoch - 8ms/step
# Epoch 20/250
# 2912/2912 - 20s - loss: 0.0040 - mean_squared_error: 0.0040 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 21/250
# 2912/2912 - 20s - loss: 0.0038 - mean_squared_error: 0.0038 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 22/250
# 2912/2912 - 20s - loss: 0.0036 - mean_squared_error: 0.0036 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 23/250
# 2912/2912 - 19s - loss: 0.0033 - mean_squared_error: 0.0033 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 24/250
# 2912/2912 - 19s - loss: 0.0032 - mean_squared_error: 0.0032 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 25/250
# 2912/2912 - 19s - loss: 0.0030 - mean_squared_error: 0.0030 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 26/250
# 2912/2912 - 19s - loss: 0.0029 - mean_squared_error: 0.0029 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 27/250
# 2912/2912 - 19s - loss: 0.0028 - mean_squared_error: 0.0028 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 28/250
# 2912/2912 - 20s - loss: 0.0027 - mean_squared_error: 0.0027 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 29/250
# 2912/2912 - 19s - loss: 0.0026 - mean_squared_error: 0.0026 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 30/250
# 2912/2912 - 19s - loss: 0.0026 - mean_squared_error: 0.0026 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 31/250
# 2912/2912 - 19s - loss: 0.0024 - mean_squared_error: 0.0024 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 32/250
# 2912/2912 - 19s - loss: 0.0024 - mean_squared_error: 0.0024 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 33/250
# 2912/2912 - 19s - loss: 0.0023 - mean_squared_error: 0.0023 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 34/250
# 2912/2912 - 19s - loss: 0.0023 - mean_squared_error: 0.0023 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 35/250
# 2912/2912 - 19s - loss: 0.0022 - mean_squared_error: 0.0022 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 36/250
# 2912/2912 - 19s - loss: 0.0021 - mean_squared_error: 0.0021 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 37/250
# 2912/2912 - 19s - loss: 0.0020 - mean_squared_error: 0.0020 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 38/250
# 2912/2912 - 19s - loss: 0.0020 - mean_squared_error: 0.0020 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 39/250
# 2912/2912 - 19s - loss: 0.0019 - mean_squared_error: 0.0019 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 40/250
# 2912/2912 - 20s - loss: 0.0019 - mean_squared_error: 0.0019 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 41/250
# 2912/2912 - 20s - loss: 0.0018 - mean_squared_error: 0.0018 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 42/250
# 2912/2912 - 19s - loss: 0.0018 - mean_squared_error: 0.0018 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 43/250
# 2912/2912 - 19s - loss: 0.0017 - mean_squared_error: 0.0017 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 44/250
# 2912/2912 - 19s - loss: 0.0016 - mean_squared_error: 0.0016 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 45/250
# 2912/2912 - 19s - loss: 0.0016 - mean_squared_error: 0.0016 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 46/250
# 2912/2912 - 19s - loss: 0.0016 - mean_squared_error: 0.0016 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 47/250
# 2912/2912 - 19s - loss: 0.0015 - mean_squared_error: 0.0015 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 48/250
# 2912/2912 - 19s - loss: 0.0015 - mean_squared_error: 0.0015 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 49/250
# 2912/2912 - 19s - loss: 0.0014 - mean_squared_error: 0.0014 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 50/250
# 2912/2912 - 20s - loss: 0.0014 - mean_squared_error: 0.0014 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 51/250
# 2912/2912 - 19s - loss: 0.0013 - mean_squared_error: 0.0013 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 52/250
# 2912/2912 - 20s - loss: 0.0013 - mean_squared_error: 0.0013 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 53/250
# 2912/2912 - 19s - loss: 0.0012 - mean_squared_error: 0.0012 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 54/250
# 2912/2912 - 19s - loss: 0.0012 - mean_squared_error: 0.0012 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 55/250
# 2912/2912 - 20s - loss: 0.0012 - mean_squared_error: 0.0012 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 56/250
# 2912/2912 - 19s - loss: 0.0011 - mean_squared_error: 0.0011 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 57/250
# 2912/2912 - 19s - loss: 0.0011 - mean_squared_error: 0.0011 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 58/250
# 2912/2912 - 19s - loss: 0.0011 - mean_squared_error: 0.0011 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 59/250
# 2912/2912 - 20s - loss: 0.0010 - mean_squared_error: 0.0010 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 60/250
# 2912/2912 - 19s - loss: 0.0010 - mean_squared_error: 0.0010 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 61/250
# 2912/2912 - 20s - loss: 9.7288e-04 - mean_squared_error: 9.7289e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 62/250
# 2912/2912 - 20s - loss: 9.8041e-04 - mean_squared_error: 9.8041e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 63/250
# 2912/2912 - 20s - loss: 9.4198e-04 - mean_squared_error: 9.4198e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 64/250
# 2912/2912 - 20s - loss: 9.4598e-04 - mean_squared_error: 9.4598e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 65/250
# 2912/2912 - 19s - loss: 9.1493e-04 - mean_squared_error: 9.1493e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 66/250
# 2912/2912 - 20s - loss: 8.7917e-04 - mean_squared_error: 8.7917e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 67/250
# 2912/2912 - 23s - loss: 8.7080e-04 - mean_squared_error: 8.7080e-04 - accuracy: 1.7170e-04 - 23s/epoch - 8ms/step
# Epoch 68/250
# 2912/2912 - 25s - loss: 8.4705e-04 - mean_squared_error: 8.4705e-04 - accuracy: 1.7170e-04 - 25s/epoch - 9ms/step
# Epoch 69/250
# 2912/2912 - 25s - loss: 8.7583e-04 - mean_squared_error: 8.7583e-04 - accuracy: 1.7170e-04 - 25s/epoch - 9ms/step
# Epoch 70/250
# 2912/2912 - 28s - loss: 8.0098e-04 - mean_squared_error: 8.0098e-04 - accuracy: 1.7170e-04 - 28s/epoch - 10ms/step
# Epoch 71/250
# 2912/2912 - 31s - loss: 7.9363e-04 - mean_squared_error: 7.9363e-04 - accuracy: 1.7170e-04 - 31s/epoch - 11ms/step
# Epoch 72/250
# 2912/2912 - 29s - loss: 7.8854e-04 - mean_squared_error: 7.8855e-04 - accuracy: 1.7170e-04 - 29s/epoch - 10ms/step
# Epoch 73/250
# 2912/2912 - 23s - loss: 7.5154e-04 - mean_squared_error: 7.5154e-04 - accuracy: 1.7170e-04 - 23s/epoch - 8ms/step
# Epoch 74/250
# 2912/2912 - 23s - loss: 7.3204e-04 - mean_squared_error: 7.3204e-04 - accuracy: 1.7170e-04 - 23s/epoch - 8ms/step
# Epoch 75/250
# 2912/2912 - 23s - loss: 7.2530e-04 - mean_squared_error: 7.2530e-04 - accuracy: 1.7170e-04 - 23s/epoch - 8ms/step
# Epoch 76/250
# 2912/2912 - 23s - loss: 7.1288e-04 - mean_squared_error: 7.1288e-04 - accuracy: 1.7170e-04 - 23s/epoch - 8ms/step
# Epoch 77/250
# 2912/2912 - 23s - loss: 7.3120e-04 - mean_squared_error: 7.3120e-04 - accuracy: 1.7170e-04 - 23s/epoch - 8ms/step
# Epoch 78/250
# 2912/2912 - 24s - loss: 6.6814e-04 - mean_squared_error: 6.6814e-04 - accuracy: 1.7170e-04 - 24s/epoch - 8ms/step
# Epoch 79/250
# 2912/2912 - 21s - loss: 6.7356e-04 - mean_squared_error: 6.7356e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 80/250
# 2912/2912 - 18s - loss: 6.5375e-04 - mean_squared_error: 6.5375e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 81/250
# 2912/2912 - 19s - loss: 6.5322e-04 - mean_squared_error: 6.5322e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 82/250
# 2912/2912 - 18s - loss: 6.4257e-04 - mean_squared_error: 6.4257e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 83/250
# 2912/2912 - 18s - loss: 6.0010e-04 - mean_squared_error: 6.0010e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 84/250
# 2912/2912 - 17s - loss: 6.0316e-04 - mean_squared_error: 6.0316e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 85/250
# 2912/2912 - 18s - loss: 5.9124e-04 - mean_squared_error: 5.9124e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 86/250
# 2912/2912 - 17s - loss: 5.7892e-04 - mean_squared_error: 5.7892e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 87/250
# 2912/2912 - 19s - loss: 5.5513e-04 - mean_squared_error: 5.5513e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 88/250
# 2912/2912 - 19s - loss: 5.8706e-04 - mean_squared_error: 5.8706e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 89/250
# 2912/2912 - 19s - loss: 5.2981e-04 - mean_squared_error: 5.2981e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 90/250
# 2912/2912 - 19s - loss: 5.6578e-04 - mean_squared_error: 5.6578e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 91/250
# 2912/2912 - 19s - loss: 5.0822e-04 - mean_squared_error: 5.0822e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 92/250
# 2912/2912 - 19s - loss: 5.2388e-04 - mean_squared_error: 5.2388e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 93/250
# 2912/2912 - 19s - loss: 5.2125e-04 - mean_squared_error: 5.2125e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 94/250
# 2912/2912 - 19s - loss: 4.9553e-04 - mean_squared_error: 4.9553e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 95/250
# 2912/2912 - 19s - loss: 5.3952e-04 - mean_squared_error: 5.3952e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 96/250
# 2912/2912 - 19s - loss: 4.8633e-04 - mean_squared_error: 4.8633e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 97/250
# 2912/2912 - 19s - loss: 4.7817e-04 - mean_squared_error: 4.7817e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 98/250
# 2912/2912 - 19s - loss: 4.5714e-04 - mean_squared_error: 4.5714e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 99/250
# 2912/2912 - 19s - loss: 4.7760e-04 - mean_squared_error: 4.7760e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 100/250
# 2912/2912 - 21s - loss: 4.5613e-04 - mean_squared_error: 4.5613e-04 - accuracy: 1.7170e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - val_accuracy: 3.4341e-04 - 21s/epoch - 7ms/step
# Epoch 101/250
# 2912/2912 - 18s - loss: 4.4877e-04 - mean_squared_error: 4.4877e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 102/250
# 2912/2912 - 18s - loss: 4.4607e-04 - mean_squared_error: 4.4607e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 103/250
# 2912/2912 - 18s - loss: 4.3587e-04 - mean_squared_error: 4.3587e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 104/250
# 2912/2912 - 18s - loss: 4.4029e-04 - mean_squared_error: 4.4029e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 105/250
# 2912/2912 - 18s - loss: 4.3311e-04 - mean_squared_error: 4.3311e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 106/250
# 2912/2912 - 18s - loss: 4.3940e-04 - mean_squared_error: 4.3940e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 107/250
# 2912/2912 - 18s - loss: 4.2986e-04 - mean_squared_error: 4.2985e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 108/250
# 2912/2912 - 18s - loss: 4.1684e-04 - mean_squared_error: 4.1684e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 109/250
# 2912/2912 - 18s - loss: 4.0681e-04 - mean_squared_error: 4.0681e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 110/250
# 2912/2912 - 18s - loss: 3.9568e-04 - mean_squared_error: 3.9569e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 111/250
# 2912/2912 - 17s - loss: 4.1452e-04 - mean_squared_error: 4.1452e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 112/250
# 2912/2912 - 19s - loss: 3.9798e-04 - mean_squared_error: 3.9798e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 113/250
# 2912/2912 - 18s - loss: 3.9892e-04 - mean_squared_error: 3.9892e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 114/250
# 2912/2912 - 19s - loss: 4.4102e-04 - mean_squared_error: 4.4102e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 115/250
# 2912/2912 - 18s - loss: 3.6378e-04 - mean_squared_error: 3.6378e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 116/250
# 2912/2912 - 17s - loss: 3.8092e-04 - mean_squared_error: 3.8092e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 117/250
# 2912/2912 - 17s - loss: 3.7338e-04 - mean_squared_error: 3.7338e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 118/250
# 2912/2912 - 18s - loss: 3.8910e-04 - mean_squared_error: 3.8910e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 119/250
# 2912/2912 - 18s - loss: 3.7361e-04 - mean_squared_error: 3.7361e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 120/250
# 2912/2912 - 18s - loss: 3.6299e-04 - mean_squared_error: 3.6299e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 121/250
# 2912/2912 - 18s - loss: 3.6087e-04 - mean_squared_error: 3.6087e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 122/250
# 2912/2912 - 18s - loss: 3.5453e-04 - mean_squared_error: 3.5453e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 123/250
# 2912/2912 - 18s - loss: 3.4384e-04 - mean_squared_error: 3.4384e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 124/250
# 2912/2912 - 19s - loss: 3.4642e-04 - mean_squared_error: 3.4642e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 125/250
# 2912/2912 - 18s - loss: 3.4224e-04 - mean_squared_error: 3.4224e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 126/250
# 2912/2912 - 18s - loss: 3.5466e-04 - mean_squared_error: 3.5465e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 127/250
# 2912/2912 - 17s - loss: 3.3620e-04 - mean_squared_error: 3.3620e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 128/250
# 2912/2912 - 17s - loss: 3.3281e-04 - mean_squared_error: 3.3281e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 129/250
# 2912/2912 - 18s - loss: 3.2437e-04 - mean_squared_error: 3.2437e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 130/250
# 2912/2912 - 17s - loss: 3.3002e-04 - mean_squared_error: 3.3001e-04 - accuracy: 1.7170e-04 - 17s/epoch - 6ms/step
# Epoch 131/250
# 2912/2912 - 18s - loss: 3.6729e-04 - mean_squared_error: 3.6728e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 132/250
# 2912/2912 - 18s - loss: 3.2264e-04 - mean_squared_error: 3.2264e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 133/250
# 2912/2912 - 18s - loss: 3.3439e-04 - mean_squared_error: 3.3439e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 134/250
# 2912/2912 - 18s - loss: 3.1218e-04 - mean_squared_error: 3.1219e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 135/250
# 2912/2912 - 18s - loss: 3.2823e-04 - mean_squared_error: 3.2823e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 136/250
# 2912/2912 - 18s - loss: 3.1668e-04 - mean_squared_error: 3.1668e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 137/250
# 2912/2912 - 18s - loss: 3.0426e-04 - mean_squared_error: 3.0426e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 138/250
# 2912/2912 - 19s - loss: 3.1786e-04 - mean_squared_error: 3.1786e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 139/250
# 2912/2912 - 19s - loss: 3.0936e-04 - mean_squared_error: 3.0936e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 140/250
# 2912/2912 - 19s - loss: 3.2463e-04 - mean_squared_error: 3.2463e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 141/250
# 2912/2912 - 19s - loss: 3.0050e-04 - mean_squared_error: 3.0050e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 142/250
# 2912/2912 - 18s - loss: 2.9695e-04 - mean_squared_error: 2.9695e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 143/250
# 2912/2912 - 18s - loss: 2.9191e-04 - mean_squared_error: 2.9191e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 144/250
# 2912/2912 - 18s - loss: 2.9832e-04 - mean_squared_error: 2.9832e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 145/250
# 2912/2912 - 18s - loss: 3.1274e-04 - mean_squared_error: 3.1274e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 146/250
# 2912/2912 - 18s - loss: 3.1765e-04 - mean_squared_error: 3.1765e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 147/250
# 2912/2912 - 18s - loss: 2.8907e-04 - mean_squared_error: 2.8907e-04 - accuracy: 1.7170e-04 - 18s/epoch - 6ms/step
# Epoch 148/250
# 2912/2912 - 19s - loss: 3.0917e-04 - mean_squared_error: 3.0917e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 149/250
# 2912/2912 - 19s - loss: 2.7437e-04 - mean_squared_error: 2.7437e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 150/250
# 2912/2912 - 19s - loss: 2.8057e-04 - mean_squared_error: 2.8057e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 151/250
# 2912/2912 - 19s - loss: 2.8842e-04 - mean_squared_error: 2.8842e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 152/250
# 2912/2912 - 19s - loss: 2.9428e-04 - mean_squared_error: 2.9429e-04 - accuracy: 1.7170e-04 - 19s/epoch - 6ms/step
# Epoch 153/250
# 2912/2912 - 19s - loss: 2.7794e-04 - mean_squared_error: 2.7794e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 154/250
# 2912/2912 - 20s - loss: 2.7876e-04 - mean_squared_error: 2.7876e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 155/250
# 2912/2912 - 19s - loss: 2.7563e-04 - mean_squared_error: 2.7563e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 156/250
# 2912/2912 - 20s - loss: 2.7268e-04 - mean_squared_error: 2.7268e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 157/250
# 2912/2912 - 20s - loss: 2.7820e-04 - mean_squared_error: 2.7820e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 158/250
# 2912/2912 - 21s - loss: 2.6257e-04 - mean_squared_error: 2.6257e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 159/250
# 2912/2912 - 21s - loss: 2.6195e-04 - mean_squared_error: 2.6195e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 160/250
# 2912/2912 - 21s - loss: 2.7133e-04 - mean_squared_error: 2.7133e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 161/250
# 2912/2912 - 22s - loss: 2.6108e-04 - mean_squared_error: 2.6108e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 162/250
# 2912/2912 - 19s - loss: 2.6690e-04 - mean_squared_error: 2.6690e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 163/250
# 2912/2912 - 20s - loss: 2.5553e-04 - mean_squared_error: 2.5553e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 164/250
# 2912/2912 - 20s - loss: 2.6278e-04 - mean_squared_error: 2.6278e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 165/250
# 2912/2912 - 20s - loss: 2.5857e-04 - mean_squared_error: 2.5857e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 166/250
# 2912/2912 - 19s - loss: 2.5206e-04 - mean_squared_error: 2.5206e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 167/250
# 2912/2912 - 20s - loss: 2.7288e-04 - mean_squared_error: 2.7288e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 168/250
# 2912/2912 - 20s - loss: 2.4644e-04 - mean_squared_error: 2.4644e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 169/250
# 2912/2912 - 20s - loss: 2.7128e-04 - mean_squared_error: 2.7128e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 170/250
# 2912/2912 - 20s - loss: 2.4792e-04 - mean_squared_error: 2.4792e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 171/250
# 2912/2912 - 20s - loss: 2.4528e-04 - mean_squared_error: 2.4528e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 172/250
# 2912/2912 - 20s - loss: 2.5255e-04 - mean_squared_error: 2.5255e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 173/250
# 2912/2912 - 20s - loss: 2.4712e-04 - mean_squared_error: 2.4712e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 174/250
# 2912/2912 - 20s - loss: 2.7615e-04 - mean_squared_error: 2.7615e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 175/250
# 2912/2912 - 20s - loss: 2.3202e-04 - mean_squared_error: 2.3202e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 176/250
# 2912/2912 - 19s - loss: 2.4408e-04 - mean_squared_error: 2.4408e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 177/250
# 2912/2912 - 20s - loss: 2.4059e-04 - mean_squared_error: 2.4059e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 178/250
# 2912/2912 - 20s - loss: 2.3678e-04 - mean_squared_error: 2.3678e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 179/250
# 2912/2912 - 20s - loss: 2.3853e-04 - mean_squared_error: 2.3853e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 180/250
# 2912/2912 - 20s - loss: 2.4004e-04 - mean_squared_error: 2.4004e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 181/250
# 2912/2912 - 19s - loss: 2.5377e-04 - mean_squared_error: 2.5377e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 182/250
# 2912/2912 - 20s - loss: 2.3938e-04 - mean_squared_error: 2.3938e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 183/250
# 2912/2912 - 19s - loss: 2.2957e-04 - mean_squared_error: 2.2957e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 184/250
# 2912/2912 - 20s - loss: 2.3866e-04 - mean_squared_error: 2.3865e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 185/250
# 2912/2912 - 20s - loss: 2.3332e-04 - mean_squared_error: 2.3332e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 186/250
# 2912/2912 - 22s - loss: 2.3578e-04 - mean_squared_error: 2.3578e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 187/250
# 2912/2912 - 22s - loss: 2.5203e-04 - mean_squared_error: 2.5203e-04 - accuracy: 1.7170e-04 - 22s/epoch - 8ms/step
# Epoch 188/250
# 2912/2912 - 21s - loss: 2.2454e-04 - mean_squared_error: 2.2454e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 189/250
# 2912/2912 - 22s - loss: 2.2295e-04 - mean_squared_error: 2.2295e-04 - accuracy: 1.7170e-04 - 22s/epoch - 8ms/step
# Epoch 190/250
# 2912/2912 - 22s - loss: 2.2730e-04 - mean_squared_error: 2.2730e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 191/250
# 2912/2912 - 22s - loss: 2.2435e-04 - mean_squared_error: 2.2435e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 192/250
# 2912/2912 - 22s - loss: 2.2175e-04 - mean_squared_error: 2.2175e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 193/250
# 2912/2912 - 22s - loss: 2.3080e-04 - mean_squared_error: 2.3080e-04 - accuracy: 1.7170e-04 - 22s/epoch - 8ms/step
# Epoch 194/250
# 2912/2912 - 22s - loss: 2.2444e-04 - mean_squared_error: 2.2444e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 195/250
# 2912/2912 - 21s - loss: 2.1842e-04 - mean_squared_error: 2.1842e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 196/250
# 2912/2912 - 21s - loss: 2.2565e-04 - mean_squared_error: 2.2565e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 197/250
# 2912/2912 - 22s - loss: 2.2850e-04 - mean_squared_error: 2.2850e-04 - accuracy: 1.7170e-04 - 22s/epoch - 8ms/step
# Epoch 198/250
# 2912/2912 - 22s - loss: 2.1128e-04 - mean_squared_error: 2.1128e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 199/250
# 2912/2912 - 22s - loss: 2.3265e-04 - mean_squared_error: 2.3265e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 200/250
# 2912/2912 - 24s - loss: 2.1007e-04 - mean_squared_error: 2.1007e-04 - accuracy: 1.7170e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - val_accuracy: 3.4341e-04 - 24s/epoch - 8ms/step
# Epoch 201/250
# 2912/2912 - 21s - loss: 2.2312e-04 - mean_squared_error: 2.2312e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 202/250
# 2912/2912 - 22s - loss: 2.1400e-04 - mean_squared_error: 2.1400e-04 - accuracy: 1.7170e-04 - 22s/epoch - 8ms/step
# Epoch 203/250
# 2912/2912 - 21s - loss: 2.1542e-04 - mean_squared_error: 2.1542e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 204/250
# 2912/2912 - 21s - loss: 2.1262e-04 - mean_squared_error: 2.1262e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 205/250
# 2912/2912 - 21s - loss: 2.0896e-04 - mean_squared_error: 2.0896e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 206/250
# 2912/2912 - 20s - loss: 2.1303e-04 - mean_squared_error: 2.1303e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 207/250
# 2912/2912 - 23s - loss: 2.0977e-04 - mean_squared_error: 2.0977e-04 - accuracy: 1.7170e-04 - 23s/epoch - 8ms/step
# Epoch 208/250
# 2912/2912 - 25s - loss: 2.1074e-04 - mean_squared_error: 2.1074e-04 - accuracy: 1.7170e-04 - 25s/epoch - 9ms/step
# Epoch 209/250
# 2912/2912 - 26s - loss: 2.4182e-04 - mean_squared_error: 2.4182e-04 - accuracy: 1.7170e-04 - 26s/epoch - 9ms/step
# Epoch 210/250
# 2912/2912 - 26s - loss: 1.9557e-04 - mean_squared_error: 1.9557e-04 - accuracy: 1.7170e-04 - 26s/epoch - 9ms/step
# Epoch 211/250
# 2912/2912 - 25s - loss: 2.2229e-04 - mean_squared_error: 2.2229e-04 - accuracy: 1.7170e-04 - 25s/epoch - 8ms/step
# Epoch 212/250
# 2912/2912 - 26s - loss: 1.9865e-04 - mean_squared_error: 1.9865e-04 - accuracy: 1.7170e-04 - 26s/epoch - 9ms/step
# Epoch 213/250
# 2912/2912 - 26s - loss: 2.0570e-04 - mean_squared_error: 2.0570e-04 - accuracy: 1.7170e-04 - 26s/epoch - 9ms/step
# Epoch 214/250
# 2912/2912 - 26s - loss: 2.0584e-04 - mean_squared_error: 2.0584e-04 - accuracy: 1.7170e-04 - 26s/epoch - 9ms/step
# Epoch 215/250
# 2912/2912 - 25s - loss: 2.0105e-04 - mean_squared_error: 2.0105e-04 - accuracy: 1.7170e-04 - 25s/epoch - 9ms/step
# Epoch 216/250
# 2912/2912 - 22s - loss: 2.1002e-04 - mean_squared_error: 2.1002e-04 - accuracy: 1.7170e-04 - 22s/epoch - 7ms/step
# Epoch 217/250
# 2912/2912 - 20s - loss: 2.0101e-04 - mean_squared_error: 2.0101e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 218/250
# 2912/2912 - 21s - loss: 2.0052e-04 - mean_squared_error: 2.0052e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 219/250
# 2912/2912 - 21s - loss: 2.0028e-04 - mean_squared_error: 2.0028e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 220/250
# 2912/2912 - 20s - loss: 2.1227e-04 - mean_squared_error: 2.1227e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 221/250
# 2912/2912 - 21s - loss: 1.9106e-04 - mean_squared_error: 1.9106e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 222/250
# 2912/2912 - 20s - loss: 2.0287e-04 - mean_squared_error: 2.0287e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 223/250
# 2912/2912 - 21s - loss: 1.9487e-04 - mean_squared_error: 1.9487e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 224/250
# 2912/2912 - 20s - loss: 1.9148e-04 - mean_squared_error: 1.9148e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 225/250
# 2912/2912 - 20s - loss: 1.9541e-04 - mean_squared_error: 1.9541e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 226/250
# 2912/2912 - 20s - loss: 2.0348e-04 - mean_squared_error: 2.0348e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 227/250
# 2912/2912 - 21s - loss: 1.8929e-04 - mean_squared_error: 1.8929e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 228/250
# 2912/2912 - 21s - loss: 1.9021e-04 - mean_squared_error: 1.9021e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 229/250
# 2912/2912 - 21s - loss: 1.9241e-04 - mean_squared_error: 1.9241e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 230/250
# 2912/2912 - 20s - loss: 1.8903e-04 - mean_squared_error: 1.8903e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 231/250
# 2912/2912 - 19s - loss: 2.0167e-04 - mean_squared_error: 2.0167e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 232/250
# 2912/2912 - 20s - loss: 1.9200e-04 - mean_squared_error: 1.9200e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 233/250
# 2912/2912 - 20s - loss: 1.9829e-04 - mean_squared_error: 1.9829e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 234/250
# 2912/2912 - 21s - loss: 2.0375e-04 - mean_squared_error: 2.0375e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 235/250
# 2912/2912 - 21s - loss: 1.8050e-04 - mean_squared_error: 1.8050e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 236/250
# 2912/2912 - 20s - loss: 1.9321e-04 - mean_squared_error: 1.9321e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 237/250
# 2912/2912 - 20s - loss: 1.8567e-04 - mean_squared_error: 1.8567e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 238/250
# 2912/2912 - 19s - loss: 1.9181e-04 - mean_squared_error: 1.9181e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 239/250
# 2912/2912 - 19s - loss: 2.0441e-04 - mean_squared_error: 2.0441e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 240/250
# 2912/2912 - 20s - loss: 1.8160e-04 - mean_squared_error: 1.8160e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 241/250
# 2912/2912 - 20s - loss: 1.8124e-04 - mean_squared_error: 1.8124e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 242/250
# 2912/2912 - 20s - loss: 1.9990e-04 - mean_squared_error: 1.9990e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 243/250
# 2912/2912 - 20s - loss: 1.7665e-04 - mean_squared_error: 1.7665e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 244/250
# 2912/2912 - 21s - loss: 1.9155e-04 - mean_squared_error: 1.9155e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step
# Epoch 245/250
# 2912/2912 - 20s - loss: 1.8567e-04 - mean_squared_error: 1.8567e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 246/250
# 2912/2912 - 19s - loss: 1.8496e-04 - mean_squared_error: 1.8496e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 247/250
# 2912/2912 - 19s - loss: 1.8680e-04 - mean_squared_error: 1.8680e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 248/250
# 2912/2912 - 19s - loss: 1.8396e-04 - mean_squared_error: 1.8396e-04 - accuracy: 1.7170e-04 - 19s/epoch - 7ms/step
# Epoch 249/250
# 2912/2912 - 20s - loss: 1.7997e-04 - mean_squared_error: 1.7997e-04 - accuracy: 1.7170e-04 - 20s/epoch - 7ms/step
# Epoch 250/250
# 2912/2912 - 21s - loss: 1.8648e-04 - mean_squared_error: 1.8648e-04 - accuracy: 1.7170e-04 - 21s/epoch - 7ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "biLSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              33792
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 10, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 10, 128)          98816
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            129
#  ed)
#
# =================================================================
# Total params: 132,737
# Trainable params: 132,737
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 0.00018648288096301258
# Final mean_squared_error : 0.00018648315744940192
# Final accuracy : 0.00017170330102089792
# Final val_loss : 0.0013570700539276004
# Final val_mean_squared_error : 0.001357070286758244
# Final val_accuracy : 0.00034340660204179585
#
# -------------------- Evaluation on Test Data --------------------
# 57/57 [==============================] - 1s 6ms/step - loss: 0.0479 - mean_squared_error: 0.0479 - accuracy: 0.0000e+00

# %%
from keras.utils import plot_model,model_to_dot
plot_model(model2, show_shapes=True, to_file='plotmodelbilstm0810.png')

# %%
model_to_dot(model2,show_shapes=True)

# %%
model2
