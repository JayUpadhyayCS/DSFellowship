# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D, GRU # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
from keras import metrics
from keras.utils import plot_model
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
df=df.iloc[200000:200100]
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 35.0489          0.0     -15.815     -3.7810         NaN
#           35.0609          0.0     -14.885     -3.9176         NaN
#           35.0629          0.0     -14.576     -3.7470         NaN
#           35.0649          0.0     -14.764     -3.8894         NaN
#           35.0669          0.0     -14.441     -3.8318         NaN
# ...                        ...         ...         ...         ...
#           35.3010          0.0     -10.993     -1.5223    -0.61787
#           35.3030          0.0     -11.082     -1.5695    -0.65993
#           35.3050          0.0     -11.026     -1.6299    -0.76057
#           35.3070          0.0     -11.008     -1.4717    -0.36651
#           35.3090          0.0     -11.054     -1.4561    -0.30866
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 35.0489      -3.8126     -3.4671     -7.7504     -3.5689
#           35.0609      -3.9170     -3.2592     -7.9254     -3.7276
#           35.0629      -3.6863     -2.8954     -7.4672     -3.4246
#           35.0649      -3.8073     -3.1875     -7.6943     -3.6412
#           35.0669      -3.7935     -3.2384     -7.7486     -3.6997
# ...                        ...         ...         ...         ...
#           35.3010      -2.7928     -2.4784     -5.0656     -1.7310
#           35.3030      -2.8381     -2.5210     -5.1308     -1.8460
#           35.3050      -2.8187     -2.5419     -5.1671     -1.8006
#           35.3070      -2.6968     -2.3218     -4.8882     -1.6257
#           35.3090      -2.7556     -2.3999     -4.9168     -1.7117
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 35.0489      -4.4897    -1.66720  ...    -10.3170     -7.5373
#           35.0609      -4.8079    -2.08030  ...    -11.7620     -8.9301
#           35.0629      -4.4473    -1.83730  ...    -13.1510    -10.2660
#           35.0649      -4.7031    -2.02100  ...    -13.0580    -10.2560
#           35.0669      -4.7355    -1.97580  ...    -13.5610    -10.7640
# ...                        ...         ...  ...         ...         ...
#           35.3010      -2.9244    -0.40943  ...     -7.5053     -5.1406
#           35.3030      -3.0506    -0.47859  ...     -7.0155     -4.5895
#           35.3050      -2.9697    -0.47912  ...     -7.8523     -5.3342
#           35.3070      -2.8141    -0.28644  ...     -7.4010     -4.7793
#           35.3090      -2.9235    -0.32021  ...     -8.2743     -5.5983
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 35.0489      -8.7209    -11.2120    -10.7480     -13.202
#           35.0609     -10.2470    -12.6600    -12.4420     -14.995
#           35.0629     -11.6180    -14.0450    -13.8780     -16.509
#           35.0649     -11.5870    -14.0190    -13.8640     -16.492
#           35.0669     -12.1090    -14.5200    -14.3170     -16.996
# ...                        ...         ...         ...         ...
#           35.3010      -5.7373     -6.9000     -7.9634     -10.810
#           35.3030      -5.2402     -6.4208     -7.5040     -10.375
#           35.3050      -6.0511     -7.2497     -8.3122     -11.216
#           35.3070      -5.6253     -6.7976     -7.7932     -10.671
#           35.3090      -6.5188     -7.6459     -8.6643     -11.546
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 35.0489      -9.2688     -6.4277     -7.5077     -7.9164
#           35.0609     -10.4110     -7.9618     -8.9148     -9.4379
#           35.0629     -11.8270     -9.3040    -10.4320    -10.7810
#           35.0649     -11.8730     -9.2702    -10.3670    -10.7500
#           35.0669     -12.2140     -9.7466    -10.6810    -11.2900
# ...                        ...         ...         ...         ...
#           35.3010      -5.6904     -4.5350     -4.5168     -4.9078
#           35.3030      -5.2086     -4.0038     -4.0553     -4.4438
#           35.3050      -6.1116     -4.8418     -4.9757     -5.3581
#           35.3070      -5.4460     -4.3086     -4.3150     -4.6278
#           35.3090      -6.3161     -5.1663     -5.3073     -5.6300
#
# [100 rows x 110 columns]

# %%
df2=pd.read_csv('InSAR_data_south/displacement/groundwater.csv')
df2=df2.set_index([df2.columns[0],df2.columns[1]])
df2.columns=pd.to_datetime(df2.columns, format='%Y-%m-%d')
df2=df2.dropna(axis=0, how='all')#drop full nan rows
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != df2.columns[y]: #if column is misssing insert it
        df2.insert(loc=y,column=df.columns[y],value=np.nan*11286,allow_duplicates=False)
df2
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316          NaN         NaN  ...   75.653992   75.813688
# -120.8926 36.7114          NaN         NaN  ...         NaN         NaN
# -120.8846 36.6994          NaN         NaN  ...         NaN         NaN
# -120.8746 36.6874          NaN         NaN  ...         NaN         NaN
# -120.1368 35.6991          NaN         NaN  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933          NaN         NaN  ...   16.978182   17.000000
# -119.0271 36.3793          NaN         NaN  ...   16.978182   17.000000
# -119.0571 36.4493          NaN         NaN  ...   16.978182   17.000000
# -119.0211 36.3993          NaN         NaN  ...   16.978182   17.000000
# -119.0111 36.3873          NaN         NaN  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
# [11286 rows x 110 columns]

# %%
df2.index.size
# Out:
# 11286

# %%
for x in range(df2.index.size): #for each row
    curr=np.nan
    for y in range(df2.columns.size): #for each value in the row
        n=0
        while np.isnan(curr): # if saved value is empty
            curr=df2.iloc[x].values[n] #look for next actual value
            n+=1
        if np.isnan(df2.iloc[x].values[y]):#if data is nan then replace with previous curr value
            df2.iat[x,y]=curr
            #df2.iloc[x].values[y]=curr
        else:
            curr= df2.iloc[x].values[y]
                

df2
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    81.000000   81.000000  ...   75.653992   75.813688
# -120.8926 36.7114    72.248964   72.248964  ...   75.200000   75.200000
# -120.8846 36.6994    72.248964   72.248964  ...   75.200000   75.200000
# -120.8746 36.6874    72.248964   72.248964  ...   75.200000   75.200000
# -120.1368 35.6991   141.123387  141.123387  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091  ...   16.978182   17.000000
# -119.0271 36.3793    17.409091   17.409091  ...   16.978182   17.000000
# -119.0571 36.4493    17.409091   17.409091  ...   16.978182   17.000000
# -119.0211 36.3993    17.409091   17.409091  ...   16.978182   17.000000
# -119.0111 36.3873    17.409091   17.409091  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0        76.0        76.0
# -120.8926 36.7114    75.200000        75.2        75.2        75.2
# -120.8846 36.6994    75.200000        75.2        75.2        75.2
# -120.8746 36.6874    75.200000        75.2        75.2        75.2
# -120.1368 35.6991   151.000000       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.000000        17.0        17.0        17.0
# -119.0271 36.3793    17.000000        17.0        17.0        17.0
# -119.0571 36.4493    17.000000        17.0        17.0        17.0
# -119.0211 36.3993    17.000000        17.0        17.0        17.0
# -119.0111 36.3873    17.000000        17.0        17.0        17.0
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316         76.0        76.0        76.0        76.0
# -120.8926 36.7114         75.2        75.2        75.2        75.2
# -120.8846 36.6994         75.2        75.2        75.2        75.2
# -120.8746 36.6874         75.2        75.2        75.2        75.2
# -120.1368 35.6991        151.0       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933         17.0        17.0        17.0        17.0
# -119.0271 36.3793         17.0        17.0        17.0        17.0
# -119.0571 36.4493         17.0        17.0        17.0        17.0
# -119.0211 36.3993         17.0        17.0        17.0        17.0
# -119.0111 36.3873         17.0        17.0        17.0        17.0
#
# [11286 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10
# 1 2 3 4 5 6 7 ...
# w/ timestep of 2
# [[1,2][2,3][3,4]

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    for row in range(len(datain.index)): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
train, test = train_test_split(df, test_size=0.2, random_state=64)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)

# %%
X_train[0]
# Out:
# array([[  0.     ],
#        [-11.082  ],
#        [ -1.5695 ],
#        [ -0.65993],
#        [ -2.8381 ],
#        [ -2.521  ],
#        [ -5.1308 ],
#        [ -1.846  ],
#        [ -3.0506 ],
#        [ -0.47859]])

# %%
Y_train[0]
# Out:
# array([[-9.0874 ],
#        [-2.8981 ],
#        [-5.8769 ],
#        [-3.9115 ],
#        [-0.91731],
#        [-5.759  ],
#        [-2.9992 ],
#        [-5.5867 ],
#        [-4.1644 ],
#        [-1.1265 ]])

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model2 = Sequential(name="biLSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError', metrics.RootMeanSquaredError()], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/250
# 2912/2912 - 25s - loss: 5.8701 - mean_squared_error: 5.8701 - mean_absolute_error: 1.8831 - root_mean_squared_error: 2.4228 - 25s/epoch - 9ms/step
# Epoch 2/250
# 2912/2912 - 20s - loss: 4.3339 - mean_squared_error: 4.3339 - mean_absolute_error: 1.6414 - root_mean_squared_error: 2.0818 - 20s/epoch - 7ms/step
# Epoch 3/250
# 2912/2912 - 21s - loss: 3.4330 - mean_squared_error: 3.4330 - mean_absolute_error: 1.4624 - root_mean_squared_error: 1.8528 - 21s/epoch - 7ms/step
# Epoch 4/250
# 2912/2912 - 21s - loss: 2.5879 - mean_squared_error: 2.5879 - mean_absolute_error: 1.2468 - root_mean_squared_error: 1.6087 - 21s/epoch - 7ms/step
# Epoch 5/250
# 2912/2912 - 21s - loss: 1.6684 - mean_squared_error: 1.6684 - mean_absolute_error: 0.9755 - root_mean_squared_error: 1.2917 - 21s/epoch - 7ms/step
# Epoch 6/250
# 2912/2912 - 21s - loss: 1.1119 - mean_squared_error: 1.1119 - mean_absolute_error: 0.7897 - root_mean_squared_error: 1.0545 - 21s/epoch - 7ms/step
# Epoch 7/250
# 2912/2912 - 23s - loss: 0.7345 - mean_squared_error: 0.7345 - mean_absolute_error: 0.6408 - root_mean_squared_error: 0.8570 - 23s/epoch - 8ms/step
# Epoch 8/250
# 2912/2912 - 22s - loss: 0.5318 - mean_squared_error: 0.5318 - mean_absolute_error: 0.5485 - root_mean_squared_error: 0.7292 - 22s/epoch - 7ms/step
# Epoch 9/250
# 2912/2912 - 22s - loss: 0.4588 - mean_squared_error: 0.4588 - mean_absolute_error: 0.5092 - root_mean_squared_error: 0.6773 - 22s/epoch - 7ms/step
# Epoch 10/250
# 2912/2912 - 21s - loss: 0.3968 - mean_squared_error: 0.3968 - mean_absolute_error: 0.4734 - root_mean_squared_error: 0.6299 - 21s/epoch - 7ms/step
# Epoch 11/250
# 2912/2912 - 23s - loss: 0.3390 - mean_squared_error: 0.3390 - mean_absolute_error: 0.4381 - root_mean_squared_error: 0.5822 - 23s/epoch - 8ms/step
# Epoch 12/250
# 2912/2912 - 22s - loss: 0.3017 - mean_squared_error: 0.3017 - mean_absolute_error: 0.4128 - root_mean_squared_error: 0.5492 - 22s/epoch - 7ms/step
# Epoch 13/250
# 2912/2912 - 21s - loss: 0.3084 - mean_squared_error: 0.3084 - mean_absolute_error: 0.4100 - root_mean_squared_error: 0.5553 - 21s/epoch - 7ms/step
# Epoch 14/250
# 2912/2912 - 20s - loss: 0.2588 - mean_squared_error: 0.2588 - mean_absolute_error: 0.3802 - root_mean_squared_error: 0.5087 - 20s/epoch - 7ms/step
# Epoch 15/250
# 2912/2912 - 20s - loss: 0.2680 - mean_squared_error: 0.2680 - mean_absolute_error: 0.3843 - root_mean_squared_error: 0.5177 - 20s/epoch - 7ms/step
# Epoch 16/250
# 2912/2912 - 20s - loss: 0.2464 - mean_squared_error: 0.2464 - mean_absolute_error: 0.3644 - root_mean_squared_error: 0.4964 - 20s/epoch - 7ms/step
# Epoch 17/250
# 2912/2912 - 20s - loss: 0.2612 - mean_squared_error: 0.2612 - mean_absolute_error: 0.3732 - root_mean_squared_error: 0.5111 - 20s/epoch - 7ms/step
# Epoch 18/250
# 2912/2912 - 20s - loss: 0.2073 - mean_squared_error: 0.2073 - mean_absolute_error: 0.3390 - root_mean_squared_error: 0.4553 - 20s/epoch - 7ms/step
# Epoch 19/250
# 2912/2912 - 20s - loss: 0.2141 - mean_squared_error: 0.2141 - mean_absolute_error: 0.3429 - root_mean_squared_error: 0.4628 - 20s/epoch - 7ms/step
# Epoch 20/250
# 2912/2912 - 21s - loss: 0.1974 - mean_squared_error: 0.1974 - mean_absolute_error: 0.3295 - root_mean_squared_error: 0.4443 - 21s/epoch - 7ms/step
# Epoch 21/250
# 2912/2912 - 21s - loss: 0.1961 - mean_squared_error: 0.1961 - mean_absolute_error: 0.3290 - root_mean_squared_error: 0.4428 - 21s/epoch - 7ms/step
# Epoch 22/250
# 2912/2912 - 21s - loss: 0.1966 - mean_squared_error: 0.1966 - mean_absolute_error: 0.3259 - root_mean_squared_error: 0.4434 - 21s/epoch - 7ms/step
# Epoch 23/250
# 2912/2912 - 20s - loss: 0.1775 - mean_squared_error: 0.1775 - mean_absolute_error: 0.3097 - root_mean_squared_error: 0.4214 - 20s/epoch - 7ms/step
# Epoch 24/250
# 2912/2912 - 22s - loss: 0.1710 - mean_squared_error: 0.1710 - mean_absolute_error: 0.3070 - root_mean_squared_error: 0.4135 - 22s/epoch - 8ms/step
# Epoch 25/250
# 2912/2912 - 22s - loss: 0.1704 - mean_squared_error: 0.1704 - mean_absolute_error: 0.3054 - root_mean_squared_error: 0.4128 - 22s/epoch - 8ms/step
# Epoch 26/250
# 2912/2912 - 23s - loss: 0.1673 - mean_squared_error: 0.1673 - mean_absolute_error: 0.3029 - root_mean_squared_error: 0.4091 - 23s/epoch - 8ms/step
# Epoch 27/250
# 2912/2912 - 22s - loss: 0.1560 - mean_squared_error: 0.1560 - mean_absolute_error: 0.2920 - root_mean_squared_error: 0.3950 - 22s/epoch - 7ms/step
# Epoch 28/250
# 2912/2912 - 20s - loss: 0.1610 - mean_squared_error: 0.1610 - mean_absolute_error: 0.2941 - root_mean_squared_error: 0.4012 - 20s/epoch - 7ms/step
# Epoch 29/250
# 2912/2912 - 20s - loss: 0.1466 - mean_squared_error: 0.1466 - mean_absolute_error: 0.2804 - root_mean_squared_error: 0.3829 - 20s/epoch - 7ms/step
# Epoch 30/250
# 2912/2912 - 20s - loss: 0.1495 - mean_squared_error: 0.1495 - mean_absolute_error: 0.2848 - root_mean_squared_error: 0.3866 - 20s/epoch - 7ms/step
# Epoch 31/250
# 2912/2912 - 20s - loss: 0.1489 - mean_squared_error: 0.1489 - mean_absolute_error: 0.2832 - root_mean_squared_error: 0.3858 - 20s/epoch - 7ms/step
# Epoch 32/250
# 2912/2912 - 20s - loss: 0.1552 - mean_squared_error: 0.1552 - mean_absolute_error: 0.2864 - root_mean_squared_error: 0.3940 - 20s/epoch - 7ms/step
# Epoch 33/250
# 2912/2912 - 20s - loss: 0.1361 - mean_squared_error: 0.1361 - mean_absolute_error: 0.2707 - root_mean_squared_error: 0.3690 - 20s/epoch - 7ms/step
# Epoch 34/250
# 2912/2912 - 20s - loss: 0.1382 - mean_squared_error: 0.1382 - mean_absolute_error: 0.2722 - root_mean_squared_error: 0.3717 - 20s/epoch - 7ms/step
# Epoch 35/250
# 2912/2912 - 20s - loss: 0.1375 - mean_squared_error: 0.1375 - mean_absolute_error: 0.2723 - root_mean_squared_error: 0.3708 - 20s/epoch - 7ms/step
# Epoch 36/250
# 2912/2912 - 20s - loss: 0.1386 - mean_squared_error: 0.1386 - mean_absolute_error: 0.2695 - root_mean_squared_error: 0.3723 - 20s/epoch - 7ms/step
# Epoch 37/250
# 2912/2912 - 21s - loss: 0.1333 - mean_squared_error: 0.1333 - mean_absolute_error: 0.2662 - root_mean_squared_error: 0.3652 - 21s/epoch - 7ms/step
# Epoch 38/250
# 2912/2912 - 21s - loss: 0.1292 - mean_squared_error: 0.1292 - mean_absolute_error: 0.2627 - root_mean_squared_error: 0.3595 - 21s/epoch - 7ms/step
# Epoch 39/250
# 2912/2912 - 21s - loss: 0.1309 - mean_squared_error: 0.1309 - mean_absolute_error: 0.2628 - root_mean_squared_error: 0.3619 - 21s/epoch - 7ms/step
# Epoch 40/250
# 2912/2912 - 22s - loss: 0.1260 - mean_squared_error: 0.1260 - mean_absolute_error: 0.2601 - root_mean_squared_error: 0.3550 - 22s/epoch - 8ms/step
# Epoch 41/250
# 2912/2912 - 22s - loss: 0.1252 - mean_squared_error: 0.1252 - mean_absolute_error: 0.2582 - root_mean_squared_error: 0.3538 - 22s/epoch - 8ms/step
# Epoch 42/250
# 2912/2912 - 21s - loss: 0.1208 - mean_squared_error: 0.1208 - mean_absolute_error: 0.2523 - root_mean_squared_error: 0.3475 - 21s/epoch - 7ms/step
# Epoch 43/250
# 2912/2912 - 23s - loss: 0.1193 - mean_squared_error: 0.1193 - mean_absolute_error: 0.2508 - root_mean_squared_error: 0.3454 - 23s/epoch - 8ms/step
# Epoch 44/250
# 2912/2912 - 22s - loss: 0.1192 - mean_squared_error: 0.1192 - mean_absolute_error: 0.2510 - root_mean_squared_error: 0.3452 - 22s/epoch - 7ms/step
# Epoch 45/250
# 2912/2912 - 21s - loss: 0.1158 - mean_squared_error: 0.1158 - mean_absolute_error: 0.2466 - root_mean_squared_error: 0.3403 - 21s/epoch - 7ms/step
# Epoch 46/250
# 2912/2912 - 22s - loss: 0.1171 - mean_squared_error: 0.1171 - mean_absolute_error: 0.2489 - root_mean_squared_error: 0.3422 - 22s/epoch - 8ms/step
# Epoch 47/250
# 2912/2912 - 23s - loss: 0.1155 - mean_squared_error: 0.1155 - mean_absolute_error: 0.2457 - root_mean_squared_error: 0.3399 - 23s/epoch - 8ms/step
# Epoch 48/250
# 2912/2912 - 23s - loss: 0.1346 - mean_squared_error: 0.1346 - mean_absolute_error: 0.2605 - root_mean_squared_error: 0.3669 - 23s/epoch - 8ms/step
# Epoch 49/250
# 2912/2912 - 22s - loss: 0.1023 - mean_squared_error: 0.1023 - mean_absolute_error: 0.2310 - root_mean_squared_error: 0.3198 - 22s/epoch - 7ms/step
# Epoch 50/250
# 2912/2912 - 22s - loss: 0.1305 - mean_squared_error: 0.1305 - mean_absolute_error: 0.2549 - root_mean_squared_error: 0.3613 - 22s/epoch - 8ms/step
# Epoch 51/250
# 2912/2912 - 23s - loss: 0.1038 - mean_squared_error: 0.1038 - mean_absolute_error: 0.2335 - root_mean_squared_error: 0.3222 - 23s/epoch - 8ms/step
# Epoch 52/250
# 2912/2912 - 24s - loss: 0.1081 - mean_squared_error: 0.1081 - mean_absolute_error: 0.2380 - root_mean_squared_error: 0.3288 - 24s/epoch - 8ms/step
# Epoch 53/250
# 2912/2912 - 24s - loss: 0.1080 - mean_squared_error: 0.1080 - mean_absolute_error: 0.2383 - root_mean_squared_error: 0.3286 - 24s/epoch - 8ms/step
# Epoch 54/250
# 2912/2912 - 25s - loss: 0.1058 - mean_squared_error: 0.1058 - mean_absolute_error: 0.2350 - root_mean_squared_error: 0.3252 - 25s/epoch - 9ms/step
# Epoch 55/250
# 2912/2912 - 22s - loss: 0.1073 - mean_squared_error: 0.1073 - mean_absolute_error: 0.2379 - root_mean_squared_error: 0.3276 - 22s/epoch - 8ms/step
# Epoch 56/250
# 2912/2912 - 23s - loss: 0.1078 - mean_squared_error: 0.1078 - mean_absolute_error: 0.2379 - root_mean_squared_error: 0.3284 - 23s/epoch - 8ms/step
# Epoch 57/250
# 2912/2912 - 24s - loss: 0.1011 - mean_squared_error: 0.1011 - mean_absolute_error: 0.2299 - root_mean_squared_error: 0.3179 - 24s/epoch - 8ms/step
# Epoch 58/250
# 2912/2912 - 22s - loss: 0.1028 - mean_squared_error: 0.1028 - mean_absolute_error: 0.2326 - root_mean_squared_error: 0.3207 - 22s/epoch - 8ms/step
# Epoch 59/250
# 2912/2912 - 24s - loss: 0.1013 - mean_squared_error: 0.1013 - mean_absolute_error: 0.2298 - root_mean_squared_error: 0.3182 - 24s/epoch - 8ms/step
# Epoch 60/250
# 2912/2912 - 23s - loss: 0.1092 - mean_squared_error: 0.1092 - mean_absolute_error: 0.2359 - root_mean_squared_error: 0.3304 - 23s/epoch - 8ms/step
# Epoch 61/250
# 2912/2912 - 22s - loss: 0.0959 - mean_squared_error: 0.0959 - mean_absolute_error: 0.2224 - root_mean_squared_error: 0.3096 - 22s/epoch - 8ms/step
# Epoch 62/250
# 2912/2912 - 23s - loss: 0.0998 - mean_squared_error: 0.0998 - mean_absolute_error: 0.2283 - root_mean_squared_error: 0.3159 - 23s/epoch - 8ms/step
# Epoch 63/250
# 2912/2912 - 23s - loss: 0.0989 - mean_squared_error: 0.0989 - mean_absolute_error: 0.2279 - root_mean_squared_error: 0.3145 - 23s/epoch - 8ms/step
# Epoch 64/250
# 2912/2912 - 24s - loss: 0.0967 - mean_squared_error: 0.0967 - mean_absolute_error: 0.2245 - root_mean_squared_error: 0.3110 - 24s/epoch - 8ms/step
# Epoch 65/250
# 2912/2912 - 22s - loss: 0.0957 - mean_squared_error: 0.0957 - mean_absolute_error: 0.2225 - root_mean_squared_error: 0.3094 - 22s/epoch - 8ms/step
# Epoch 66/250
# 2912/2912 - 24s - loss: 0.0944 - mean_squared_error: 0.0944 - mean_absolute_error: 0.2223 - root_mean_squared_error: 0.3072 - 24s/epoch - 8ms/step
# Epoch 67/250
# 2912/2912 - 23s - loss: 0.0962 - mean_squared_error: 0.0962 - mean_absolute_error: 0.2244 - root_mean_squared_error: 0.3102 - 23s/epoch - 8ms/step
# Epoch 68/250
# 2912/2912 - 23s - loss: 0.0953 - mean_squared_error: 0.0953 - mean_absolute_error: 0.2224 - root_mean_squared_error: 0.3087 - 23s/epoch - 8ms/step
# Epoch 69/250
# 2912/2912 - 23s - loss: 0.0949 - mean_squared_error: 0.0949 - mean_absolute_error: 0.2217 - root_mean_squared_error: 0.3080 - 23s/epoch - 8ms/step
# Epoch 70/250
# 2912/2912 - 24s - loss: 0.0917 - mean_squared_error: 0.0917 - mean_absolute_error: 0.2185 - root_mean_squared_error: 0.3029 - 24s/epoch - 8ms/step
# Epoch 71/250
# 2912/2912 - 22s - loss: 0.0916 - mean_squared_error: 0.0916 - mean_absolute_error: 0.2177 - root_mean_squared_error: 0.3026 - 22s/epoch - 8ms/step
# Epoch 72/250
# 2912/2912 - 22s - loss: 0.0935 - mean_squared_error: 0.0935 - mean_absolute_error: 0.2210 - root_mean_squared_error: 0.3059 - 22s/epoch - 7ms/step
# Epoch 73/250
# 2912/2912 - 23s - loss: 0.0913 - mean_squared_error: 0.0913 - mean_absolute_error: 0.2187 - root_mean_squared_error: 0.3022 - 23s/epoch - 8ms/step
# Epoch 74/250
# 2912/2912 - 24s - loss: 0.0894 - mean_squared_error: 0.0894 - mean_absolute_error: 0.2146 - root_mean_squared_error: 0.2989 - 24s/epoch - 8ms/step
# Epoch 75/250
# 2912/2912 - 24s - loss: 0.0887 - mean_squared_error: 0.0887 - mean_absolute_error: 0.2152 - root_mean_squared_error: 0.2978 - 24s/epoch - 8ms/step
# Epoch 76/250
# 2912/2912 - 24s - loss: 0.0881 - mean_squared_error: 0.0881 - mean_absolute_error: 0.2126 - root_mean_squared_error: 0.2968 - 24s/epoch - 8ms/step
# Epoch 77/250
# 2912/2912 - 26s - loss: 0.0909 - mean_squared_error: 0.0909 - mean_absolute_error: 0.2177 - root_mean_squared_error: 0.3016 - 26s/epoch - 9ms/step
# Epoch 78/250
# 2912/2912 - 23s - loss: 0.0865 - mean_squared_error: 0.0865 - mean_absolute_error: 0.2112 - root_mean_squared_error: 0.2942 - 23s/epoch - 8ms/step
# Epoch 79/250
# 2912/2912 - 23s - loss: 0.0983 - mean_squared_error: 0.0983 - mean_absolute_error: 0.2181 - root_mean_squared_error: 0.3136 - 23s/epoch - 8ms/step
# Epoch 80/250
# 2912/2912 - 24s - loss: 0.0875 - mean_squared_error: 0.0875 - mean_absolute_error: 0.2123 - root_mean_squared_error: 0.2959 - 24s/epoch - 8ms/step
# Epoch 81/250
# 2912/2912 - 24s - loss: 0.0849 - mean_squared_error: 0.0849 - mean_absolute_error: 0.2093 - root_mean_squared_error: 0.2914 - 24s/epoch - 8ms/step
# Epoch 82/250
# 2912/2912 - 25s - loss: 0.0924 - mean_squared_error: 0.0924 - mean_absolute_error: 0.2161 - root_mean_squared_error: 0.3040 - 25s/epoch - 8ms/step
# Epoch 83/250
# 2912/2912 - 24s - loss: 0.0838 - mean_squared_error: 0.0838 - mean_absolute_error: 0.2065 - root_mean_squared_error: 0.2894 - 24s/epoch - 8ms/step
# Epoch 84/250
# 2912/2912 - 25s - loss: 0.0828 - mean_squared_error: 0.0828 - mean_absolute_error: 0.2070 - root_mean_squared_error: 0.2877 - 25s/epoch - 8ms/step
# Epoch 85/250
# 2912/2912 - 24s - loss: 0.0841 - mean_squared_error: 0.0841 - mean_absolute_error: 0.2080 - root_mean_squared_error: 0.2899 - 24s/epoch - 8ms/step
# Epoch 86/250
# 2912/2912 - 23s - loss: 0.0855 - mean_squared_error: 0.0855 - mean_absolute_error: 0.2102 - root_mean_squared_error: 0.2924 - 23s/epoch - 8ms/step
# Epoch 87/250
# 2912/2912 - 23s - loss: 0.0831 - mean_squared_error: 0.0831 - mean_absolute_error: 0.2066 - root_mean_squared_error: 0.2883 - 23s/epoch - 8ms/step
# Epoch 88/250
# 2912/2912 - 23s - loss: 0.0825 - mean_squared_error: 0.0825 - mean_absolute_error: 0.2067 - root_mean_squared_error: 0.2873 - 23s/epoch - 8ms/step
# Epoch 89/250
# 2912/2912 - 24s - loss: 0.0829 - mean_squared_error: 0.0829 - mean_absolute_error: 0.2068 - root_mean_squared_error: 0.2878 - 24s/epoch - 8ms/step
# Epoch 90/250
# 2912/2912 - 24s - loss: 0.0831 - mean_squared_error: 0.0831 - mean_absolute_error: 0.2064 - root_mean_squared_error: 0.2883 - 24s/epoch - 8ms/step
# Epoch 91/250
# 2912/2912 - 24s - loss: 0.0999 - mean_squared_error: 0.0999 - mean_absolute_error: 0.2201 - root_mean_squared_error: 0.3161 - 24s/epoch - 8ms/step
# Epoch 92/250
# 2912/2912 - 23s - loss: 0.0780 - mean_squared_error: 0.0780 - mean_absolute_error: 0.1978 - root_mean_squared_error: 0.2792 - 23s/epoch - 8ms/step
# Epoch 93/250
# 2912/2912 - 22s - loss: 0.0803 - mean_squared_error: 0.0803 - mean_absolute_error: 0.2027 - root_mean_squared_error: 0.2833 - 22s/epoch - 8ms/step
# Epoch 94/250
# 2912/2912 - 22s - loss: 0.0817 - mean_squared_error: 0.0817 - mean_absolute_error: 0.2061 - root_mean_squared_error: 0.2859 - 22s/epoch - 8ms/step
# Epoch 95/250
# 2912/2912 - 22s - loss: 0.0801 - mean_squared_error: 0.0801 - mean_absolute_error: 0.2035 - root_mean_squared_error: 0.2830 - 22s/epoch - 8ms/step
# Epoch 96/250
# 2912/2912 - 23s - loss: 0.0807 - mean_squared_error: 0.0807 - mean_absolute_error: 0.2038 - root_mean_squared_error: 0.2841 - 23s/epoch - 8ms/step
# Epoch 97/250
# 2912/2912 - 23s - loss: 0.0798 - mean_squared_error: 0.0798 - mean_absolute_error: 0.2022 - root_mean_squared_error: 0.2824 - 23s/epoch - 8ms/step
# Epoch 98/250
# 2912/2912 - 23s - loss: 0.0785 - mean_squared_error: 0.0785 - mean_absolute_error: 0.2001 - root_mean_squared_error: 0.2802 - 23s/epoch - 8ms/step
# Epoch 99/250
# 2912/2912 - 23s - loss: 0.0770 - mean_squared_error: 0.0770 - mean_absolute_error: 0.1996 - root_mean_squared_error: 0.2775 - 23s/epoch - 8ms/step
# Epoch 100/250
# 2912/2912 - 26s - loss: 0.0786 - mean_squared_error: 0.0786 - mean_absolute_error: 0.2017 - root_mean_squared_error: 0.2803 - val_loss: 0.1735 - val_mean_squared_error: 0.1735 - val_mean_absolute_error: 0.2924 - val_root_mean_squared_error: 0.4165 - 26s/epoch - 9ms/step
# Epoch 101/250
# 2912/2912 - 22s - loss: 0.0771 - mean_squared_error: 0.0771 - mean_absolute_error: 0.1979 - root_mean_squared_error: 0.2776 - 22s/epoch - 8ms/step
# Epoch 102/250
# 2912/2912 - 23s - loss: 0.0760 - mean_squared_error: 0.0760 - mean_absolute_error: 0.1985 - root_mean_squared_error: 0.2757 - 23s/epoch - 8ms/step
# Epoch 103/250
# 2912/2912 - 22s - loss: 0.0777 - mean_squared_error: 0.0777 - mean_absolute_error: 0.1976 - root_mean_squared_error: 0.2787 - 22s/epoch - 8ms/step
# Epoch 104/250
# 2912/2912 - 24s - loss: 0.0790 - mean_squared_error: 0.0790 - mean_absolute_error: 0.2010 - root_mean_squared_error: 0.2812 - 24s/epoch - 8ms/step
# Epoch 105/250
# 2912/2912 - 23s - loss: 0.0717 - mean_squared_error: 0.0717 - mean_absolute_error: 0.1914 - root_mean_squared_error: 0.2677 - 23s/epoch - 8ms/step
# Epoch 106/250
# 2912/2912 - 21s - loss: 0.0758 - mean_squared_error: 0.0758 - mean_absolute_error: 0.1982 - root_mean_squared_error: 0.2754 - 21s/epoch - 7ms/step
# Epoch 107/250
# 2912/2912 - 22s - loss: 0.0860 - mean_squared_error: 0.0860 - mean_absolute_error: 0.2022 - root_mean_squared_error: 0.2932 - 22s/epoch - 7ms/step
# Epoch 108/250
# 2912/2912 - 22s - loss: 0.0717 - mean_squared_error: 0.0717 - mean_absolute_error: 0.1917 - root_mean_squared_error: 0.2678 - 22s/epoch - 8ms/step
# Epoch 109/250
# 2912/2912 - 23s - loss: 0.0748 - mean_squared_error: 0.0748 - mean_absolute_error: 0.1950 - root_mean_squared_error: 0.2734 - 23s/epoch - 8ms/step
# Epoch 110/250
# 2912/2912 - 22s - loss: 0.0755 - mean_squared_error: 0.0755 - mean_absolute_error: 0.1971 - root_mean_squared_error: 0.2748 - 22s/epoch - 8ms/step
# Epoch 111/250
# 2912/2912 - 22s - loss: 0.0706 - mean_squared_error: 0.0706 - mean_absolute_error: 0.1902 - root_mean_squared_error: 0.2658 - 22s/epoch - 8ms/step
# Epoch 112/250
# 2912/2912 - 23s - loss: 0.0752 - mean_squared_error: 0.0752 - mean_absolute_error: 0.1953 - root_mean_squared_error: 0.2743 - 23s/epoch - 8ms/step
# Epoch 113/250
# 2912/2912 - 22s - loss: 0.0757 - mean_squared_error: 0.0757 - mean_absolute_error: 0.1945 - root_mean_squared_error: 0.2751 - 22s/epoch - 7ms/step
# Epoch 114/250
# 2912/2912 - 22s - loss: 0.0721 - mean_squared_error: 0.0721 - mean_absolute_error: 0.1924 - root_mean_squared_error: 0.2685 - 22s/epoch - 7ms/step
# Epoch 115/250
# 2912/2912 - 22s - loss: 0.0715 - mean_squared_error: 0.0715 - mean_absolute_error: 0.1910 - root_mean_squared_error: 0.2675 - 22s/epoch - 7ms/step
# Epoch 116/250
# 2912/2912 - 22s - loss: 0.0724 - mean_squared_error: 0.0724 - mean_absolute_error: 0.1920 - root_mean_squared_error: 0.2691 - 22s/epoch - 8ms/step
# Epoch 117/250
# 2912/2912 - 22s - loss: 0.0759 - mean_squared_error: 0.0759 - mean_absolute_error: 0.1972 - root_mean_squared_error: 0.2756 - 22s/epoch - 7ms/step
# Epoch 118/250
# 2912/2912 - 22s - loss: 0.0698 - mean_squared_error: 0.0698 - mean_absolute_error: 0.1886 - root_mean_squared_error: 0.2642 - 22s/epoch - 8ms/step
# Epoch 119/250
# 2912/2912 - 22s - loss: 0.0725 - mean_squared_error: 0.0725 - mean_absolute_error: 0.1914 - root_mean_squared_error: 0.2692 - 22s/epoch - 7ms/step
# Epoch 120/250
# 2912/2912 - 22s - loss: 0.0749 - mean_squared_error: 0.0749 - mean_absolute_error: 0.1953 - root_mean_squared_error: 0.2736 - 22s/epoch - 8ms/step
# Epoch 121/250
# 2912/2912 - 22s - loss: 0.0702 - mean_squared_error: 0.0702 - mean_absolute_error: 0.1894 - root_mean_squared_error: 0.2650 - 22s/epoch - 8ms/step
# Epoch 122/250
# 2912/2912 - 22s - loss: 0.0697 - mean_squared_error: 0.0697 - mean_absolute_error: 0.1894 - root_mean_squared_error: 0.2640 - 22s/epoch - 8ms/step
# Epoch 123/250
# 2912/2912 - 22s - loss: 0.0709 - mean_squared_error: 0.0709 - mean_absolute_error: 0.1909 - root_mean_squared_error: 0.2663 - 22s/epoch - 8ms/step
# Epoch 124/250
# 2912/2912 - 23s - loss: 0.0683 - mean_squared_error: 0.0683 - mean_absolute_error: 0.1875 - root_mean_squared_error: 0.2614 - 23s/epoch - 8ms/step
# Epoch 125/250
# 2912/2912 - 22s - loss: 0.0737 - mean_squared_error: 0.0737 - mean_absolute_error: 0.1926 - root_mean_squared_error: 0.2715 - 22s/epoch - 8ms/step
# Epoch 126/250
# 2912/2912 - 22s - loss: 0.0689 - mean_squared_error: 0.0689 - mean_absolute_error: 0.1876 - root_mean_squared_error: 0.2625 - 22s/epoch - 8ms/step
# Epoch 127/250
# 2912/2912 - 23s - loss: 0.0681 - mean_squared_error: 0.0681 - mean_absolute_error: 0.1871 - root_mean_squared_error: 0.2610 - 23s/epoch - 8ms/step
# Epoch 128/250
# 2912/2912 - 24s - loss: 0.0698 - mean_squared_error: 0.0698 - mean_absolute_error: 0.1898 - root_mean_squared_error: 0.2643 - 24s/epoch - 8ms/step
# Epoch 129/250
# 2912/2912 - 24s - loss: 0.0700 - mean_squared_error: 0.0700 - mean_absolute_error: 0.1877 - root_mean_squared_error: 0.2645 - 24s/epoch - 8ms/step
# Epoch 130/250
# 2912/2912 - 24s - loss: 0.0676 - mean_squared_error: 0.0676 - mean_absolute_error: 0.1868 - root_mean_squared_error: 0.2600 - 24s/epoch - 8ms/step
# Epoch 131/250
# 2912/2912 - 23s - loss: 0.0680 - mean_squared_error: 0.0680 - mean_absolute_error: 0.1877 - root_mean_squared_error: 0.2607 - 23s/epoch - 8ms/step
# Epoch 132/250
# 2912/2912 - 24s - loss: 0.0683 - mean_squared_error: 0.0683 - mean_absolute_error: 0.1861 - root_mean_squared_error: 0.2614 - 24s/epoch - 8ms/step
# Epoch 133/250
# 2912/2912 - 23s - loss: 0.0659 - mean_squared_error: 0.0659 - mean_absolute_error: 0.1841 - root_mean_squared_error: 0.2567 - 23s/epoch - 8ms/step
# Epoch 134/250
# 2912/2912 - 23s - loss: 0.0680 - mean_squared_error: 0.0680 - mean_absolute_error: 0.1864 - root_mean_squared_error: 0.2608 - 23s/epoch - 8ms/step
# Epoch 135/250
# 2912/2912 - 22s - loss: 0.0841 - mean_squared_error: 0.0841 - mean_absolute_error: 0.1996 - root_mean_squared_error: 0.2900 - 22s/epoch - 8ms/step
# Epoch 136/250
# 2912/2912 - 23s - loss: 0.0603 - mean_squared_error: 0.0603 - mean_absolute_error: 0.1734 - root_mean_squared_error: 0.2456 - 23s/epoch - 8ms/step
# Epoch 137/250
# 2912/2912 - 22s - loss: 0.0660 - mean_squared_error: 0.0660 - mean_absolute_error: 0.1841 - root_mean_squared_error: 0.2570 - 22s/epoch - 8ms/step
# Epoch 138/250
# 2912/2912 - 22s - loss: 0.0646 - mean_squared_error: 0.0646 - mean_absolute_error: 0.1823 - root_mean_squared_error: 0.2542 - 22s/epoch - 8ms/step
# Epoch 139/250
# 2912/2912 - 22s - loss: 0.0667 - mean_squared_error: 0.0667 - mean_absolute_error: 0.1850 - root_mean_squared_error: 0.2583 - 22s/epoch - 8ms/step
# Epoch 140/250
# 2912/2912 - 22s - loss: 0.0669 - mean_squared_error: 0.0669 - mean_absolute_error: 0.1852 - root_mean_squared_error: 0.2586 - 22s/epoch - 8ms/step
# Epoch 141/250
# 2912/2912 - 22s - loss: 0.0641 - mean_squared_error: 0.0641 - mean_absolute_error: 0.1819 - root_mean_squared_error: 0.2532 - 22s/epoch - 8ms/step
# Epoch 142/250
# 2912/2912 - 22s - loss: 0.0674 - mean_squared_error: 0.0674 - mean_absolute_error: 0.1857 - root_mean_squared_error: 0.2595 - 22s/epoch - 8ms/step
# Epoch 143/250
# 2912/2912 - 22s - loss: 0.0726 - mean_squared_error: 0.0726 - mean_absolute_error: 0.1896 - root_mean_squared_error: 0.2694 - 22s/epoch - 8ms/step
# Epoch 144/250
# 2912/2912 - 23s - loss: 0.0632 - mean_squared_error: 0.0632 - mean_absolute_error: 0.1786 - root_mean_squared_error: 0.2515 - 23s/epoch - 8ms/step
# Epoch 145/250
# 2912/2912 - 23s - loss: 0.0683 - mean_squared_error: 0.0683 - mean_absolute_error: 0.1839 - root_mean_squared_error: 0.2613 - 23s/epoch - 8ms/step
# Epoch 146/250
# 2912/2912 - 22s - loss: 0.0645 - mean_squared_error: 0.0645 - mean_absolute_error: 0.1810 - root_mean_squared_error: 0.2540 - 22s/epoch - 8ms/step
# Epoch 147/250
# 2912/2912 - 22s - loss: 0.0644 - mean_squared_error: 0.0644 - mean_absolute_error: 0.1808 - root_mean_squared_error: 0.2538 - 22s/epoch - 8ms/step
# Epoch 148/250
# 2912/2912 - 22s - loss: 0.0698 - mean_squared_error: 0.0698 - mean_absolute_error: 0.1875 - root_mean_squared_error: 0.2641 - 22s/epoch - 8ms/step
# Epoch 149/250
# 2912/2912 - 22s - loss: 0.0595 - mean_squared_error: 0.0595 - mean_absolute_error: 0.1750 - root_mean_squared_error: 0.2440 - 22s/epoch - 8ms/step
# Epoch 150/250
# 2912/2912 - 22s - loss: 0.0644 - mean_squared_error: 0.0644 - mean_absolute_error: 0.1813 - root_mean_squared_error: 0.2537 - 22s/epoch - 8ms/step
# Epoch 151/250
# 2912/2912 - 22s - loss: 0.0640 - mean_squared_error: 0.0640 - mean_absolute_error: 0.1800 - root_mean_squared_error: 0.2530 - 22s/epoch - 8ms/step
# Epoch 152/250
# 2912/2912 - 23s - loss: 0.0654 - mean_squared_error: 0.0654 - mean_absolute_error: 0.1827 - root_mean_squared_error: 0.2556 - 23s/epoch - 8ms/step
# Epoch 153/250
# 2912/2912 - 23s - loss: 0.0635 - mean_squared_error: 0.0635 - mean_absolute_error: 0.1801 - root_mean_squared_error: 0.2520 - 23s/epoch - 8ms/step
# Epoch 154/250
# 2912/2912 - 22s - loss: 0.0611 - mean_squared_error: 0.0611 - mean_absolute_error: 0.1756 - root_mean_squared_error: 0.2471 - 22s/epoch - 8ms/step
# Epoch 155/250
# 2912/2912 - 22s - loss: 0.0673 - mean_squared_error: 0.0673 - mean_absolute_error: 0.1834 - root_mean_squared_error: 0.2594 - 22s/epoch - 8ms/step
# Epoch 156/250
# 2912/2912 - 22s - loss: 0.0624 - mean_squared_error: 0.0624 - mean_absolute_error: 0.1773 - root_mean_squared_error: 0.2497 - 22s/epoch - 8ms/step
# Epoch 157/250
# 2912/2912 - 22s - loss: 0.0614 - mean_squared_error: 0.0614 - mean_absolute_error: 0.1776 - root_mean_squared_error: 0.2478 - 22s/epoch - 8ms/step
# Epoch 158/250
# 2912/2912 - 23s - loss: 0.0598 - mean_squared_error: 0.0598 - mean_absolute_error: 0.1755 - root_mean_squared_error: 0.2445 - 23s/epoch - 8ms/step
# Epoch 159/250
# 2912/2912 - 22s - loss: 0.0617 - mean_squared_error: 0.0617 - mean_absolute_error: 0.1772 - root_mean_squared_error: 0.2485 - 22s/epoch - 8ms/step
# Epoch 160/250
# 2912/2912 - 22s - loss: 0.0593 - mean_squared_error: 0.0593 - mean_absolute_error: 0.1753 - root_mean_squared_error: 0.2436 - 22s/epoch - 8ms/step
# Epoch 161/250
# 2912/2912 - 23s - loss: 0.0639 - mean_squared_error: 0.0639 - mean_absolute_error: 0.1800 - root_mean_squared_error: 0.2528 - 23s/epoch - 8ms/step
# Epoch 162/250
# 2912/2912 - 22s - loss: 0.0615 - mean_squared_error: 0.0615 - mean_absolute_error: 0.1757 - root_mean_squared_error: 0.2479 - 22s/epoch - 8ms/step
# Epoch 163/250
# 2912/2912 - 22s - loss: 0.0585 - mean_squared_error: 0.0585 - mean_absolute_error: 0.1728 - root_mean_squared_error: 0.2419 - 22s/epoch - 8ms/step
# Epoch 164/250
# 2912/2912 - 22s - loss: 0.0633 - mean_squared_error: 0.0633 - mean_absolute_error: 0.1800 - root_mean_squared_error: 0.2516 - 22s/epoch - 8ms/step
# Epoch 165/250
# 2912/2912 - 22s - loss: 0.0590 - mean_squared_error: 0.0590 - mean_absolute_error: 0.1724 - root_mean_squared_error: 0.2428 - 22s/epoch - 8ms/step
# Epoch 166/250
# 2912/2912 - 22s - loss: 0.0581 - mean_squared_error: 0.0581 - mean_absolute_error: 0.1726 - root_mean_squared_error: 0.2410 - 22s/epoch - 8ms/step
# Epoch 167/250
# 2912/2912 - 22s - loss: 0.0623 - mean_squared_error: 0.0623 - mean_absolute_error: 0.1771 - root_mean_squared_error: 0.2497 - 22s/epoch - 8ms/step
# Epoch 168/250
# 2912/2912 - 23s - loss: 0.0572 - mean_squared_error: 0.0572 - mean_absolute_error: 0.1719 - root_mean_squared_error: 0.2392 - 23s/epoch - 8ms/step
# Epoch 169/250
# 2912/2912 - 23s - loss: 0.0589 - mean_squared_error: 0.0589 - mean_absolute_error: 0.1741 - root_mean_squared_error: 0.2427 - 23s/epoch - 8ms/step
# Epoch 170/250
# 2912/2912 - 22s - loss: 0.0580 - mean_squared_error: 0.0580 - mean_absolute_error: 0.1729 - root_mean_squared_error: 0.2408 - 22s/epoch - 8ms/step
# Epoch 171/250
# 2912/2912 - 22s - loss: 0.0828 - mean_squared_error: 0.0828 - mean_absolute_error: 0.1876 - root_mean_squared_error: 0.2878 - 22s/epoch - 8ms/step
# Epoch 172/250
# 2912/2912 - 22s - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1662 - root_mean_squared_error: 0.2336 - 22s/epoch - 8ms/step
# Epoch 173/250
# 2912/2912 - 22s - loss: 0.0571 - mean_squared_error: 0.0571 - mean_absolute_error: 0.1731 - root_mean_squared_error: 0.2389 - 22s/epoch - 8ms/step
# Epoch 174/250
# 2912/2912 - 22s - loss: 0.0588 - mean_squared_error: 0.0588 - mean_absolute_error: 0.1731 - root_mean_squared_error: 0.2425 - 22s/epoch - 8ms/step
# Epoch 175/250
# 2912/2912 - 22s - loss: 0.0575 - mean_squared_error: 0.0575 - mean_absolute_error: 0.1720 - root_mean_squared_error: 0.2399 - 22s/epoch - 8ms/step
# Epoch 176/250
# 2912/2912 - 22s - loss: 0.0618 - mean_squared_error: 0.0618 - mean_absolute_error: 0.1767 - root_mean_squared_error: 0.2486 - 22s/epoch - 8ms/step
# Epoch 177/250
# 2912/2912 - 23s - loss: 0.0573 - mean_squared_error: 0.0573 - mean_absolute_error: 0.1705 - root_mean_squared_error: 0.2394 - 23s/epoch - 8ms/step
# Epoch 178/250
# 2912/2912 - 23s - loss: 0.0575 - mean_squared_error: 0.0575 - mean_absolute_error: 0.1717 - root_mean_squared_error: 0.2398 - 23s/epoch - 8ms/step
# Epoch 179/250
# 2912/2912 - 23s - loss: 0.0744 - mean_squared_error: 0.0744 - mean_absolute_error: 0.1873 - root_mean_squared_error: 0.2728 - 23s/epoch - 8ms/step
# Epoch 180/250
# 2912/2912 - 22s - loss: 0.0550 - mean_squared_error: 0.0550 - mean_absolute_error: 0.1646 - root_mean_squared_error: 0.2346 - 22s/epoch - 8ms/step
# Epoch 181/250
# 2912/2912 - 22s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1695 - root_mean_squared_error: 0.2368 - 22s/epoch - 8ms/step
# Epoch 182/250
# 2912/2912 - 23s - loss: 0.0577 - mean_squared_error: 0.0577 - mean_absolute_error: 0.1716 - root_mean_squared_error: 0.2401 - 23s/epoch - 8ms/step
# Epoch 183/250
# 2912/2912 - 23s - loss: 0.0581 - mean_squared_error: 0.0581 - mean_absolute_error: 0.1730 - root_mean_squared_error: 0.2411 - 23s/epoch - 8ms/step
# Epoch 184/250
# 2912/2912 - 23s - loss: 0.0551 - mean_squared_error: 0.0551 - mean_absolute_error: 0.1682 - root_mean_squared_error: 0.2346 - 23s/epoch - 8ms/step
# Epoch 185/250
# 2912/2912 - 23s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1713 - root_mean_squared_error: 0.2383 - 23s/epoch - 8ms/step
# Epoch 186/250
# 2912/2912 - 23s - loss: 0.0580 - mean_squared_error: 0.0580 - mean_absolute_error: 0.1724 - root_mean_squared_error: 0.2408 - 23s/epoch - 8ms/step
# Epoch 187/250
# 2912/2912 - 23s - loss: 0.0604 - mean_squared_error: 0.0604 - mean_absolute_error: 0.1735 - root_mean_squared_error: 0.2459 - 23s/epoch - 8ms/step
# Epoch 188/250
# 2912/2912 - 23s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1690 - root_mean_squared_error: 0.2357 - 23s/epoch - 8ms/step
# Epoch 189/250
# 2912/2912 - 24s - loss: 0.0545 - mean_squared_error: 0.0545 - mean_absolute_error: 0.1678 - root_mean_squared_error: 0.2333 - 24s/epoch - 8ms/step
# Epoch 190/250
# 2912/2912 - 24s - loss: 0.0597 - mean_squared_error: 0.0597 - mean_absolute_error: 0.1728 - root_mean_squared_error: 0.2444 - 24s/epoch - 8ms/step
# Epoch 191/250
# 2912/2912 - 24s - loss: 0.0562 - mean_squared_error: 0.0562 - mean_absolute_error: 0.1695 - root_mean_squared_error: 0.2370 - 24s/epoch - 8ms/step
# Epoch 192/250
# 2912/2912 - 25s - loss: 0.0559 - mean_squared_error: 0.0559 - mean_absolute_error: 0.1695 - root_mean_squared_error: 0.2364 - 25s/epoch - 9ms/step
# Epoch 193/250
# 2912/2912 - 24s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1667 - root_mean_squared_error: 0.2312 - 24s/epoch - 8ms/step
# Epoch 194/250
# 2912/2912 - 24s - loss: 0.0573 - mean_squared_error: 0.0573 - mean_absolute_error: 0.1710 - root_mean_squared_error: 0.2394 - 24s/epoch - 8ms/step
# Epoch 195/250
# 2912/2912 - 25s - loss: 0.0642 - mean_squared_error: 0.0642 - mean_absolute_error: 0.1753 - root_mean_squared_error: 0.2533 - 25s/epoch - 8ms/step
# Epoch 196/250
# 2912/2912 - 24s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1622 - root_mean_squared_error: 0.2286 - 24s/epoch - 8ms/step
# Epoch 197/250
# 2912/2912 - 25s - loss: 0.0581 - mean_squared_error: 0.0581 - mean_absolute_error: 0.1711 - root_mean_squared_error: 0.2410 - 25s/epoch - 8ms/step
# Epoch 198/250
# 2912/2912 - 25s - loss: 0.0578 - mean_squared_error: 0.0578 - mean_absolute_error: 0.1701 - root_mean_squared_error: 0.2405 - 25s/epoch - 8ms/step
# Epoch 199/250
# 2912/2912 - 25s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1662 - root_mean_squared_error: 0.2342 - 25s/epoch - 8ms/step
# Epoch 200/250
# 2912/2912 - 28s - loss: 0.0552 - mean_squared_error: 0.0552 - mean_absolute_error: 0.1665 - root_mean_squared_error: 0.2350 - val_loss: 0.1669 - val_mean_squared_error: 0.1669 - val_mean_absolute_error: 0.2606 - val_root_mean_squared_error: 0.4086 - 28s/epoch - 10ms/step
# Epoch 201/250
# 2912/2912 - 25s - loss: 0.0547 - mean_squared_error: 0.0547 - mean_absolute_error: 0.1663 - root_mean_squared_error: 0.2339 - 25s/epoch - 9ms/step
# Epoch 202/250
# 2912/2912 - 25s - loss: 0.0548 - mean_squared_error: 0.0548 - mean_absolute_error: 0.1683 - root_mean_squared_error: 0.2341 - 25s/epoch - 9ms/step
# Epoch 203/250
# 2912/2912 - 25s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1662 - root_mean_squared_error: 0.2299 - 25s/epoch - 9ms/step
# Epoch 204/250
# 2912/2912 - 25s - loss: 0.0560 - mean_squared_error: 0.0560 - mean_absolute_error: 0.1686 - root_mean_squared_error: 0.2367 - 25s/epoch - 9ms/step
# Epoch 205/250
# 2912/2912 - 25s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1643 - root_mean_squared_error: 0.2285 - 25s/epoch - 9ms/step
# Epoch 206/250
# 2912/2912 - 25s - loss: 0.0643 - mean_squared_error: 0.0643 - mean_absolute_error: 0.1760 - root_mean_squared_error: 0.2535 - 25s/epoch - 8ms/step
# Epoch 207/250
# 2912/2912 - 25s - loss: 0.0484 - mean_squared_error: 0.0484 - mean_absolute_error: 0.1575 - root_mean_squared_error: 0.2201 - 25s/epoch - 9ms/step
# Epoch 208/250
# 2912/2912 - 25s - loss: 0.0534 - mean_squared_error: 0.0534 - mean_absolute_error: 0.1655 - root_mean_squared_error: 0.2310 - 25s/epoch - 9ms/step
# Epoch 209/250
# 2912/2912 - 26s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1636 - root_mean_squared_error: 0.2276 - 26s/epoch - 9ms/step
# Epoch 210/250
# 2912/2912 - 25s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1643 - root_mean_squared_error: 0.2296 - 25s/epoch - 9ms/step
# Epoch 211/250
# 2912/2912 - 25s - loss: 0.0570 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1695 - root_mean_squared_error: 0.2387 - 25s/epoch - 8ms/step
# Epoch 212/250
# 2912/2912 - 25s - loss: 0.0543 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1653 - root_mean_squared_error: 0.2329 - 25s/epoch - 9ms/step
# Epoch 213/250
# 2912/2912 - 25s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1611 - root_mean_squared_error: 0.2227 - 25s/epoch - 9ms/step
# Epoch 214/250
# 2912/2912 - 25s - loss: 0.0525 - mean_squared_error: 0.0525 - mean_absolute_error: 0.1637 - root_mean_squared_error: 0.2291 - 25s/epoch - 8ms/step
# Epoch 215/250
# 2912/2912 - 26s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1631 - root_mean_squared_error: 0.2262 - 26s/epoch - 9ms/step
# Epoch 216/250
# 2912/2912 - 25s - loss: 0.0538 - mean_squared_error: 0.0538 - mean_absolute_error: 0.1648 - root_mean_squared_error: 0.2319 - 25s/epoch - 8ms/step
# Epoch 217/250
# 2912/2912 - 25s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1633 - root_mean_squared_error: 0.2283 - 25s/epoch - 9ms/step
# Epoch 218/250
# 2912/2912 - 25s - loss: 0.0506 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1608 - root_mean_squared_error: 0.2248 - 25s/epoch - 9ms/step
# Epoch 219/250
# 2912/2912 - 25s - loss: 0.0597 - mean_squared_error: 0.0597 - mean_absolute_error: 0.1697 - root_mean_squared_error: 0.2443 - 25s/epoch - 9ms/step
# Epoch 220/250
# 2912/2912 - 25s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1553 - root_mean_squared_error: 0.2177 - 25s/epoch - 9ms/step
# Epoch 221/250
# 2912/2912 - 25s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1632 - root_mean_squared_error: 0.2285 - 25s/epoch - 9ms/step
# Epoch 222/250
# 2912/2912 - 25s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1596 - root_mean_squared_error: 0.2220 - 25s/epoch - 9ms/step
# Epoch 223/250
# 2912/2912 - 25s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1629 - root_mean_squared_error: 0.2289 - 25s/epoch - 9ms/step
# Epoch 224/250
# 2912/2912 - 25s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1591 - root_mean_squared_error: 0.2214 - 25s/epoch - 9ms/step
# Epoch 225/250
# 2912/2912 - 25s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1612 - root_mean_squared_error: 0.2225 - 25s/epoch - 9ms/step
# Epoch 226/250
# 2912/2912 - 26s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1608 - root_mean_squared_error: 0.2239 - 26s/epoch - 9ms/step
# Epoch 227/250
# 2912/2912 - 25s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1600 - root_mean_squared_error: 0.2225 - 25s/epoch - 9ms/step
# Epoch 228/250
# 2912/2912 - 25s - loss: 0.0475 - mean_squared_error: 0.0475 - mean_absolute_error: 0.1580 - root_mean_squared_error: 0.2180 - 25s/epoch - 9ms/step
# Epoch 229/250
# 2912/2912 - 26s - loss: 0.0695 - mean_squared_error: 0.0695 - mean_absolute_error: 0.1795 - root_mean_squared_error: 0.2636 - 26s/epoch - 9ms/step
# Epoch 230/250
# 2912/2912 - 26s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1531 - root_mean_squared_error: 0.2136 - 26s/epoch - 9ms/step
# Epoch 231/250
# 2912/2912 - 26s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1577 - root_mean_squared_error: 0.2197 - 26s/epoch - 9ms/step
# Epoch 232/250
# 2912/2912 - 25s - loss: 0.0504 - mean_squared_error: 0.0504 - mean_absolute_error: 0.1616 - root_mean_squared_error: 0.2245 - 25s/epoch - 9ms/step
# Epoch 233/250
# 2912/2912 - 26s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1610 - root_mean_squared_error: 0.2221 - 26s/epoch - 9ms/step
# Epoch 234/250
# 2912/2912 - 25s - loss: 0.0547 - mean_squared_error: 0.0547 - mean_absolute_error: 0.1633 - root_mean_squared_error: 0.2340 - 25s/epoch - 9ms/step
# Epoch 235/250
# 2912/2912 - 25s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1558 - root_mean_squared_error: 0.2169 - 25s/epoch - 9ms/step
# Epoch 236/250
# 2912/2912 - 25s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1581 - root_mean_squared_error: 0.2177 - 25s/epoch - 9ms/step
# Epoch 237/250
# 2912/2912 - 25s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1600 - root_mean_squared_error: 0.2216 - 25s/epoch - 9ms/step
# Epoch 238/250
# 2912/2912 - 25s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1593 - root_mean_squared_error: 0.2238 - 25s/epoch - 9ms/step
# Epoch 239/250
# 2912/2912 - 26s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1575 - root_mean_squared_error: 0.2197 - 26s/epoch - 9ms/step
# Epoch 240/250
# 2912/2912 - 26s - loss: 0.0509 - mean_squared_error: 0.0509 - mean_absolute_error: 0.1609 - root_mean_squared_error: 0.2255 - 26s/epoch - 9ms/step
# Epoch 241/250
# 2912/2912 - 26s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1598 - root_mean_squared_error: 0.2233 - 26s/epoch - 9ms/step
# Epoch 242/250
# 2912/2912 - 26s - loss: 0.0676 - mean_squared_error: 0.0676 - mean_absolute_error: 0.1765 - root_mean_squared_error: 0.2600 - 26s/epoch - 9ms/step
# Epoch 243/250
# 2912/2912 - 25s - loss: 0.0447 - mean_squared_error: 0.0447 - mean_absolute_error: 0.1497 - root_mean_squared_error: 0.2114 - 25s/epoch - 9ms/step
# Epoch 244/250
# 2912/2912 - 25s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1581 - root_mean_squared_error: 0.2228 - 25s/epoch - 9ms/step
# Epoch 245/250
# 2912/2912 - 25s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1579 - root_mean_squared_error: 0.2218 - 25s/epoch - 9ms/step
# Epoch 246/250
# 2912/2912 - 26s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1589 - root_mean_squared_error: 0.2223 - 26s/epoch - 9ms/step
# Epoch 247/250
# 2912/2912 - 26s - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1534 - root_mean_squared_error: 0.2133 - 26s/epoch - 9ms/step
# Epoch 248/250
# 2912/2912 - 26s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1630 - root_mean_squared_error: 0.2316 - 26s/epoch - 9ms/step
# Epoch 249/250
# 2912/2912 - 25s - loss: 0.0449 - mean_squared_error: 0.0449 - mean_absolute_error: 0.1518 - root_mean_squared_error: 0.2119 - 25s/epoch - 9ms/step
# Epoch 250/250
# 2912/2912 - 25s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1589 - root_mean_squared_error: 0.2221 - 25s/epoch - 9ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "biLSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              33792
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 10, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 10, 128)          98816
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            129
#  ed)
#
# =================================================================
# Total params: 132,737
# Trainable params: 132,737
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 0.04931638389825821
# Final mean_squared_error : 0.04931638389825821
# Final mean_absolute_error : 0.15887321531772614
# Final root_mean_squared_error : 0.22207292914390564
# Final val_loss : 0.16691668331623077
# Final val_mean_squared_error : 0.1669166386127472
# Final val_mean_absolute_error : 0.26060813665390015
# Final val_root_mean_squared_error : 0.4085543155670166
#
# -------------------- Evaluation on Test Data --------------------
# 57/57 [==============================] - 1s 8ms/step - loss: 0.0976 - mean_squared_error: 0.0976 - mean_absolute_error: 0.1997 - root_mean_squared_error: 0.3124

# %%
from keras.utils import plot_model,model_to_dot
plot_model(model2, show_shapes=True, to_file='plotmodelbilstm0810.png')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model_to_dot(model2,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model2
# Out:
# [<keras.metrics.base_metric.Mean at 0x202331d3b50>,
#  <keras.metrics.metrics.MeanSquaredError at 0x2023367e800>,
#  <keras.metrics.metrics.MeanAbsoluteError at 0x2023367d450>,
#  <keras.metrics.metrics.RootMeanSquaredError at 0x20233119b40>]
