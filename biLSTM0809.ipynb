# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([min(rmse)*0.97, max(rmse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('InSAR_data_south/displacement/export_dataframe1.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y%m%d')
df=df.dropna(axis=0, how='all')#drop full nan rows

# %% [markdown]
# ##### Remove next line to include all data

# %%
#df=df.iloc[100000:500000] #cuts data to long 120-119 approx
df=df.iloc[200000:200100]
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.4087 35.0489          0.0     -15.815     -3.7810         NaN
#           35.0609          0.0     -14.885     -3.9176         NaN
#           35.0629          0.0     -14.576     -3.7470         NaN
#           35.0649          0.0     -14.764     -3.8894         NaN
#           35.0669          0.0     -14.441     -3.8318         NaN
# ...                        ...         ...         ...         ...
#           35.3010          0.0     -10.993     -1.5223    -0.61787
#           35.3030          0.0     -11.082     -1.5695    -0.65993
#           35.3050          0.0     -11.026     -1.6299    -0.76057
#           35.3070          0.0     -11.008     -1.4717    -0.36651
#           35.3090          0.0     -11.054     -1.4561    -0.30866
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.4087 35.0489      -3.8126     -3.4671     -7.7504     -3.5689
#           35.0609      -3.9170     -3.2592     -7.9254     -3.7276
#           35.0629      -3.6863     -2.8954     -7.4672     -3.4246
#           35.0649      -3.8073     -3.1875     -7.6943     -3.6412
#           35.0669      -3.7935     -3.2384     -7.7486     -3.6997
# ...                        ...         ...         ...         ...
#           35.3010      -2.7928     -2.4784     -5.0656     -1.7310
#           35.3030      -2.8381     -2.5210     -5.1308     -1.8460
#           35.3050      -2.8187     -2.5419     -5.1671     -1.8006
#           35.3070      -2.6968     -2.3218     -4.8882     -1.6257
#           35.3090      -2.7556     -2.3999     -4.9168     -1.7117
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.4087 35.0489      -4.4897    -1.66720  ...    -10.3170     -7.5373
#           35.0609      -4.8079    -2.08030  ...    -11.7620     -8.9301
#           35.0629      -4.4473    -1.83730  ...    -13.1510    -10.2660
#           35.0649      -4.7031    -2.02100  ...    -13.0580    -10.2560
#           35.0669      -4.7355    -1.97580  ...    -13.5610    -10.7640
# ...                        ...         ...  ...         ...         ...
#           35.3010      -2.9244    -0.40943  ...     -7.5053     -5.1406
#           35.3030      -3.0506    -0.47859  ...     -7.0155     -4.5895
#           35.3050      -2.9697    -0.47912  ...     -7.8523     -5.3342
#           35.3070      -2.8141    -0.28644  ...     -7.4010     -4.7793
#           35.3090      -2.9235    -0.32021  ...     -8.2743     -5.5983
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.4087 35.0489      -8.7209    -11.2120    -10.7480     -13.202
#           35.0609     -10.2470    -12.6600    -12.4420     -14.995
#           35.0629     -11.6180    -14.0450    -13.8780     -16.509
#           35.0649     -11.5870    -14.0190    -13.8640     -16.492
#           35.0669     -12.1090    -14.5200    -14.3170     -16.996
# ...                        ...         ...         ...         ...
#           35.3010      -5.7373     -6.9000     -7.9634     -10.810
#           35.3030      -5.2402     -6.4208     -7.5040     -10.375
#           35.3050      -6.0511     -7.2497     -8.3122     -11.216
#           35.3070      -5.6253     -6.7976     -7.7932     -10.671
#           35.3090      -6.5188     -7.6459     -8.6643     -11.546
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.4087 35.0489      -9.2688     -6.4277     -7.5077     -7.9164
#           35.0609     -10.4110     -7.9618     -8.9148     -9.4379
#           35.0629     -11.8270     -9.3040    -10.4320    -10.7810
#           35.0649     -11.8730     -9.2702    -10.3670    -10.7500
#           35.0669     -12.2140     -9.7466    -10.6810    -11.2900
# ...                        ...         ...         ...         ...
#           35.3010      -5.6904     -4.5350     -4.5168     -4.9078
#           35.3030      -5.2086     -4.0038     -4.0553     -4.4438
#           35.3050      -6.1116     -4.8418     -4.9757     -5.3581
#           35.3070      -5.4460     -4.3086     -4.3150     -4.6278
#           35.3090      -6.3161     -5.1663     -5.3073     -5.6300
#
# [100 rows x 110 columns]

# %% [markdown]
# # Timestep

# %%
timestep=10

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping(datain, timestep):
    #print(arr)
    cnt=0
    for row in range(len(datain.index)): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten
        #datain.iloc[row].fillna(datain.iloc[row].mean).to_numpy().flatten()
        arr=datain.iloc[row].to_numpy().flatten() # flatten row
        #arr=arr.fillna(arr.mean)
        arr=np.where(np.isnan(arr), ma.array(arr, mask=np.isnan(arr)).mean(), arr) 
        for mth in range(0, len(datain.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr[X_start:X_end]
                Y_comb=arr[Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr[X_start:X_end])
                Y_comb=np.append(Y_comb, arr[Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, 1))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
X_train, Y_train = shaping(datain=train, timestep= timestep )
X_test, Y_test = shaping(datain=test, timestep=timestep)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
model2 = Sequential(name="LSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))
model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
              metrics=['MeanSquaredError', 'MeanAbsoluteError'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
        
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=2, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=250, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.2, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=100, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/500
# 2912/2912 - 30s - loss: 6.2511 - mean_squared_error: 6.2511 - mean_absolute_error: 1.9427 - 30s/epoch - 10ms/step
# Epoch 2/500
# 2912/2912 - 23s - loss: 4.7479 - mean_squared_error: 4.7479 - mean_absolute_error: 1.7194 - 23s/epoch - 8ms/step
# Epoch 3/500
# 2912/2912 - 24s - loss: 3.8689 - mean_squared_error: 3.8689 - mean_absolute_error: 1.5567 - 24s/epoch - 8ms/step
# Epoch 4/500
# 2912/2912 - 24s - loss: 3.1939 - mean_squared_error: 3.1939 - mean_absolute_error: 1.3986 - 24s/epoch - 8ms/step
# Epoch 5/500
# 2912/2912 - 23s - loss: 2.7227 - mean_squared_error: 2.7227 - mean_absolute_error: 1.2726 - 23s/epoch - 8ms/step
# Epoch 6/500
# 2912/2912 - 23s - loss: 1.8746 - mean_squared_error: 1.8746 - mean_absolute_error: 1.0383 - 23s/epoch - 8ms/step
# Epoch 7/500
# 2912/2912 - 23s - loss: 1.2369 - mean_squared_error: 1.2369 - mean_absolute_error: 0.8309 - 23s/epoch - 8ms/step
# Epoch 8/500
# 2912/2912 - 23s - loss: 1.0077 - mean_squared_error: 1.0077 - mean_absolute_error: 0.7437 - 23s/epoch - 8ms/step
# Epoch 9/500
# 2912/2912 - 23s - loss: 0.6553 - mean_squared_error: 0.6553 - mean_absolute_error: 0.6040 - 23s/epoch - 8ms/step
# Epoch 10/500
# 2912/2912 - 23s - loss: 0.5358 - mean_squared_error: 0.5358 - mean_absolute_error: 0.5476 - 23s/epoch - 8ms/step
# Epoch 11/500
# 2912/2912 - 23s - loss: 0.4502 - mean_squared_error: 0.4502 - mean_absolute_error: 0.5024 - 23s/epoch - 8ms/step
# Epoch 12/500
# 2912/2912 - 23s - loss: 0.3996 - mean_squared_error: 0.3996 - mean_absolute_error: 0.4713 - 23s/epoch - 8ms/step
# Epoch 13/500
# 2912/2912 - 23s - loss: 0.4007 - mean_squared_error: 0.4007 - mean_absolute_error: 0.4639 - 23s/epoch - 8ms/step
# Epoch 14/500
# 2912/2912 - 23s - loss: 0.2929 - mean_squared_error: 0.2929 - mean_absolute_error: 0.4062 - 23s/epoch - 8ms/step
# Epoch 15/500
# 2912/2912 - 23s - loss: 0.2881 - mean_squared_error: 0.2881 - mean_absolute_error: 0.4026 - 23s/epoch - 8ms/step
# Epoch 16/500
# 2912/2912 - 23s - loss: 0.3073 - mean_squared_error: 0.3073 - mean_absolute_error: 0.4012 - 23s/epoch - 8ms/step
# Epoch 17/500
# 2912/2912 - 23s - loss: 0.2548 - mean_squared_error: 0.2548 - mean_absolute_error: 0.3770 - 23s/epoch - 8ms/step
# Epoch 18/500
# 2912/2912 - 24s - loss: 0.2825 - mean_squared_error: 0.2825 - mean_absolute_error: 0.3846 - 24s/epoch - 8ms/step
# Epoch 19/500
# 2912/2912 - 25s - loss: 0.2376 - mean_squared_error: 0.2376 - mean_absolute_error: 0.3621 - 25s/epoch - 8ms/step
# Epoch 20/500
# 2912/2912 - 25s - loss: 0.2219 - mean_squared_error: 0.2219 - mean_absolute_error: 0.3495 - 25s/epoch - 8ms/step
# Epoch 21/500
# 2912/2912 - 23s - loss: 0.2321 - mean_squared_error: 0.2321 - mean_absolute_error: 0.3558 - 23s/epoch - 8ms/step
# Epoch 22/500
# 2912/2912 - 24s - loss: 0.2067 - mean_squared_error: 0.2067 - mean_absolute_error: 0.3370 - 24s/epoch - 8ms/step
# Epoch 23/500
# 2912/2912 - 25s - loss: 0.2164 - mean_squared_error: 0.2164 - mean_absolute_error: 0.3405 - 25s/epoch - 9ms/step
# Epoch 24/500
# 2912/2912 - 27s - loss: 0.1922 - mean_squared_error: 0.1922 - mean_absolute_error: 0.3249 - 27s/epoch - 9ms/step
# Epoch 25/500
# 2912/2912 - 27s - loss: 0.1891 - mean_squared_error: 0.1891 - mean_absolute_error: 0.3248 - 27s/epoch - 9ms/step
# Epoch 26/500
# 2912/2912 - 27s - loss: 0.1843 - mean_squared_error: 0.1843 - mean_absolute_error: 0.3183 - 27s/epoch - 9ms/step
# Epoch 27/500
# 2912/2912 - 26s - loss: 0.1766 - mean_squared_error: 0.1766 - mean_absolute_error: 0.3114 - 26s/epoch - 9ms/step
# Epoch 28/500
# 2912/2912 - 27s - loss: 0.1897 - mean_squared_error: 0.1897 - mean_absolute_error: 0.3171 - 27s/epoch - 9ms/step
# Epoch 29/500
# 2912/2912 - 26s - loss: 0.1626 - mean_squared_error: 0.1626 - mean_absolute_error: 0.2965 - 26s/epoch - 9ms/step
# Epoch 30/500
# 2912/2912 - 26s - loss: 0.1619 - mean_squared_error: 0.1619 - mean_absolute_error: 0.2973 - 26s/epoch - 9ms/step
# Epoch 31/500
# 2912/2912 - 26s - loss: 0.1608 - mean_squared_error: 0.1608 - mean_absolute_error: 0.2977 - 26s/epoch - 9ms/step
# Epoch 32/500
# 2912/2912 - 28s - loss: 0.2036 - mean_squared_error: 0.2036 - mean_absolute_error: 0.3171 - 28s/epoch - 10ms/step
# Epoch 33/500
# 2912/2912 - 27s - loss: 0.1421 - mean_squared_error: 0.1421 - mean_absolute_error: 0.2777 - 27s/epoch - 9ms/step
# Epoch 34/500
# 2912/2912 - 27s - loss: 0.1458 - mean_squared_error: 0.1458 - mean_absolute_error: 0.2825 - 27s/epoch - 9ms/step
# Epoch 35/500
# 2912/2912 - 27s - loss: 0.1452 - mean_squared_error: 0.1452 - mean_absolute_error: 0.2811 - 27s/epoch - 9ms/step
# Epoch 36/500
# 2912/2912 - 27s - loss: 0.1652 - mean_squared_error: 0.1652 - mean_absolute_error: 0.2922 - 27s/epoch - 9ms/step
# Epoch 37/500
# 2912/2912 - 26s - loss: 0.1391 - mean_squared_error: 0.1391 - mean_absolute_error: 0.2725 - 26s/epoch - 9ms/step
# Epoch 38/500
# 2912/2912 - 27s - loss: 0.1351 - mean_squared_error: 0.1351 - mean_absolute_error: 0.2721 - 27s/epoch - 9ms/step
# Epoch 39/500
# 2912/2912 - 27s - loss: 0.1378 - mean_squared_error: 0.1378 - mean_absolute_error: 0.2727 - 27s/epoch - 9ms/step
# Epoch 40/500
# 2912/2912 - 27s - loss: 0.1342 - mean_squared_error: 0.1342 - mean_absolute_error: 0.2700 - 27s/epoch - 9ms/step
# Epoch 41/500
# 2912/2912 - 27s - loss: 0.1351 - mean_squared_error: 0.1351 - mean_absolute_error: 0.2713 - 27s/epoch - 9ms/step
# Epoch 42/500
# 2912/2912 - 26s - loss: 0.1320 - mean_squared_error: 0.1320 - mean_absolute_error: 0.2668 - 26s/epoch - 9ms/step
# Epoch 43/500
# 2912/2912 - 28s - loss: 0.1297 - mean_squared_error: 0.1297 - mean_absolute_error: 0.2642 - 28s/epoch - 10ms/step
# Epoch 44/500
# 2912/2912 - 28s - loss: 0.1431 - mean_squared_error: 0.1431 - mean_absolute_error: 0.2723 - 28s/epoch - 10ms/step
# Epoch 45/500
# 2912/2912 - 26s - loss: 0.1178 - mean_squared_error: 0.1178 - mean_absolute_error: 0.2516 - 26s/epoch - 9ms/step
# Epoch 46/500
# 2912/2912 - 27s - loss: 0.1323 - mean_squared_error: 0.1323 - mean_absolute_error: 0.2620 - 27s/epoch - 9ms/step
# Epoch 47/500
# 2912/2912 - 24s - loss: 0.1150 - mean_squared_error: 0.1150 - mean_absolute_error: 0.2491 - 24s/epoch - 8ms/step
# Epoch 48/500
# 2912/2912 - 24s - loss: 0.1550 - mean_squared_error: 0.1550 - mean_absolute_error: 0.2725 - 24s/epoch - 8ms/step
# Epoch 49/500
# 2912/2912 - 25s - loss: 0.1116 - mean_squared_error: 0.1116 - mean_absolute_error: 0.2430 - 25s/epoch - 9ms/step
# Epoch 50/500
# 2912/2912 - 27s - loss: 0.1160 - mean_squared_error: 0.1160 - mean_absolute_error: 0.2486 - 27s/epoch - 9ms/step
# Epoch 51/500
# 2912/2912 - 27s - loss: 0.1164 - mean_squared_error: 0.1164 - mean_absolute_error: 0.2504 - 27s/epoch - 9ms/step
# Epoch 52/500
# 2912/2912 - 27s - loss: 0.1155 - mean_squared_error: 0.1155 - mean_absolute_error: 0.2480 - 27s/epoch - 9ms/step
# Epoch 53/500
# 2912/2912 - 27s - loss: 0.1133 - mean_squared_error: 0.1133 - mean_absolute_error: 0.2458 - 27s/epoch - 9ms/step
# Epoch 54/500
# 2912/2912 - 27s - loss: 0.1121 - mean_squared_error: 0.1121 - mean_absolute_error: 0.2446 - 27s/epoch - 9ms/step
# Epoch 55/500
# 2912/2912 - 27s - loss: 0.1106 - mean_squared_error: 0.1106 - mean_absolute_error: 0.2423 - 27s/epoch - 9ms/step
# Epoch 56/500
# 2912/2912 - 27s - loss: 0.1129 - mean_squared_error: 0.1129 - mean_absolute_error: 0.2449 - 27s/epoch - 9ms/step
# Epoch 57/500
# 2912/2912 - 23s - loss: 0.1081 - mean_squared_error: 0.1081 - mean_absolute_error: 0.2392 - 23s/epoch - 8ms/step
# Epoch 58/500
# 2912/2912 - 25s - loss: 0.1125 - mean_squared_error: 0.1125 - mean_absolute_error: 0.2435 - 25s/epoch - 9ms/step
# Epoch 59/500
# 2912/2912 - 27s - loss: 0.1193 - mean_squared_error: 0.1193 - mean_absolute_error: 0.2461 - 27s/epoch - 9ms/step
# Epoch 60/500
# 2912/2912 - 26s - loss: 0.1029 - mean_squared_error: 0.1029 - mean_absolute_error: 0.2328 - 26s/epoch - 9ms/step
# Epoch 61/500
# 2912/2912 - 25s - loss: 0.1033 - mean_squared_error: 0.1033 - mean_absolute_error: 0.2329 - 25s/epoch - 8ms/step
# Epoch 62/500
# 2912/2912 - 24s - loss: 0.1073 - mean_squared_error: 0.1073 - mean_absolute_error: 0.2374 - 24s/epoch - 8ms/step
# Epoch 63/500
# 2912/2912 - 25s - loss: 0.1041 - mean_squared_error: 0.1041 - mean_absolute_error: 0.2357 - 25s/epoch - 9ms/step
# Epoch 64/500
# 2912/2912 - 26s - loss: 0.1038 - mean_squared_error: 0.1038 - mean_absolute_error: 0.2347 - 26s/epoch - 9ms/step
# Epoch 65/500
# 2912/2912 - 25s - loss: 0.1026 - mean_squared_error: 0.1026 - mean_absolute_error: 0.2335 - 25s/epoch - 8ms/step
# Epoch 66/500
# 2912/2912 - 25s - loss: 0.1110 - mean_squared_error: 0.1110 - mean_absolute_error: 0.2366 - 25s/epoch - 9ms/step
# Epoch 67/500
# 2912/2912 - 25s - loss: 0.0954 - mean_squared_error: 0.0954 - mean_absolute_error: 0.2223 - 25s/epoch - 9ms/step
# Epoch 68/500
# 2912/2912 - 23s - loss: 0.0991 - mean_squared_error: 0.0991 - mean_absolute_error: 0.2279 - 23s/epoch - 8ms/step
# Epoch 69/500
# 2912/2912 - 23s - loss: 0.1007 - mean_squared_error: 0.1007 - mean_absolute_error: 0.2291 - 23s/epoch - 8ms/step
# Epoch 70/500
# 2912/2912 - 23s - loss: 0.0995 - mean_squared_error: 0.0995 - mean_absolute_error: 0.2284 - 23s/epoch - 8ms/step
# Epoch 71/500
# 2912/2912 - 24s - loss: 0.0970 - mean_squared_error: 0.0970 - mean_absolute_error: 0.2241 - 24s/epoch - 8ms/step
# Epoch 72/500
# 2912/2912 - 23s - loss: 0.0947 - mean_squared_error: 0.0947 - mean_absolute_error: 0.2233 - 23s/epoch - 8ms/step
# Epoch 73/500
# 2912/2912 - 23s - loss: 0.0957 - mean_squared_error: 0.0957 - mean_absolute_error: 0.2247 - 23s/epoch - 8ms/step
# Epoch 74/500
# 2912/2912 - 23s - loss: 0.0977 - mean_squared_error: 0.0977 - mean_absolute_error: 0.2253 - 23s/epoch - 8ms/step
# Epoch 75/500
# 2912/2912 - 24s - loss: 0.0930 - mean_squared_error: 0.0930 - mean_absolute_error: 0.2220 - 24s/epoch - 8ms/step
# Epoch 76/500
# 2912/2912 - 23s - loss: 0.0939 - mean_squared_error: 0.0939 - mean_absolute_error: 0.2214 - 23s/epoch - 8ms/step
# Epoch 77/500
# 2912/2912 - 23s - loss: 0.0925 - mean_squared_error: 0.0925 - mean_absolute_error: 0.2201 - 23s/epoch - 8ms/step
# Epoch 78/500
# 2912/2912 - 23s - loss: 0.0918 - mean_squared_error: 0.0918 - mean_absolute_error: 0.2206 - 23s/epoch - 8ms/step
# Epoch 79/500
# 2912/2912 - 23s - loss: 0.0896 - mean_squared_error: 0.0896 - mean_absolute_error: 0.2152 - 23s/epoch - 8ms/step
# Epoch 80/500
# 2912/2912 - 23s - loss: 0.0915 - mean_squared_error: 0.0915 - mean_absolute_error: 0.2182 - 23s/epoch - 8ms/step
# Epoch 81/500
# 2912/2912 - 23s - loss: 0.0894 - mean_squared_error: 0.0894 - mean_absolute_error: 0.2154 - 23s/epoch - 8ms/step
# Epoch 82/500
# 2912/2912 - 23s - loss: 0.0916 - mean_squared_error: 0.0916 - mean_absolute_error: 0.2179 - 23s/epoch - 8ms/step
# Epoch 83/500
# 2912/2912 - 23s - loss: 0.0958 - mean_squared_error: 0.0958 - mean_absolute_error: 0.2203 - 23s/epoch - 8ms/step
# Epoch 84/500
# 2912/2912 - 23s - loss: 0.0970 - mean_squared_error: 0.0970 - mean_absolute_error: 0.2205 - 23s/epoch - 8ms/step
# Epoch 85/500
# 2912/2912 - 24s - loss: 0.0867 - mean_squared_error: 0.0867 - mean_absolute_error: 0.2106 - 24s/epoch - 8ms/step
# Epoch 86/500
# 2912/2912 - 24s - loss: 0.0876 - mean_squared_error: 0.0876 - mean_absolute_error: 0.2131 - 24s/epoch - 8ms/step
# Epoch 87/500
# 2912/2912 - 25s - loss: 0.0900 - mean_squared_error: 0.0900 - mean_absolute_error: 0.2129 - 25s/epoch - 9ms/step
# Epoch 88/500
# 2912/2912 - 25s - loss: 0.0864 - mean_squared_error: 0.0864 - mean_absolute_error: 0.2111 - 25s/epoch - 9ms/step
# Epoch 89/500
# 2912/2912 - 25s - loss: 0.0864 - mean_squared_error: 0.0864 - mean_absolute_error: 0.2111 - 25s/epoch - 8ms/step
# Epoch 90/500
# 2912/2912 - 34s - loss: 0.0866 - mean_squared_error: 0.0866 - mean_absolute_error: 0.2118 - 34s/epoch - 12ms/step
# Epoch 91/500
# 2912/2912 - 47s - loss: 0.0861 - mean_squared_error: 0.0861 - mean_absolute_error: 0.2108 - 47s/epoch - 16ms/step
# Epoch 92/500
# 2912/2912 - 50s - loss: 0.0830 - mean_squared_error: 0.0830 - mean_absolute_error: 0.2067 - 50s/epoch - 17ms/step
# Epoch 93/500
# 2912/2912 - 46s - loss: 0.0845 - mean_squared_error: 0.0845 - mean_absolute_error: 0.2078 - 46s/epoch - 16ms/step
# Epoch 94/500
# 2912/2912 - 48s - loss: 0.0850 - mean_squared_error: 0.0850 - mean_absolute_error: 0.2077 - 48s/epoch - 16ms/step
# Epoch 95/500
# 2912/2912 - 48s - loss: 0.0920 - mean_squared_error: 0.0920 - mean_absolute_error: 0.2170 - 48s/epoch - 17ms/step
# Epoch 96/500
# 2912/2912 - 48s - loss: 0.0800 - mean_squared_error: 0.0800 - mean_absolute_error: 0.2020 - 48s/epoch - 16ms/step
# Epoch 97/500
# 2912/2912 - 49s - loss: 0.0834 - mean_squared_error: 0.0834 - mean_absolute_error: 0.2066 - 49s/epoch - 17ms/step
# Epoch 98/500
# 2912/2912 - 50s - loss: 0.0904 - mean_squared_error: 0.0904 - mean_absolute_error: 0.2134 - 50s/epoch - 17ms/step
# Epoch 99/500
# 2912/2912 - 48s - loss: 0.0780 - mean_squared_error: 0.0780 - mean_absolute_error: 0.1995 - 48s/epoch - 17ms/step
# Epoch 100/500
# 2912/2912 - 59s - loss: 0.0800 - mean_squared_error: 0.0800 - mean_absolute_error: 0.2026 - val_loss: 0.1216 - val_mean_squared_error: 0.1216 - val_mean_absolute_error: 0.2371 - 59s/epoch - 20ms/step
# Epoch 101/500
# 2912/2912 - 49s - loss: 0.0808 - mean_squared_error: 0.0808 - mean_absolute_error: 0.2037 - 49s/epoch - 17ms/step
# Epoch 102/500
# 2912/2912 - 49s - loss: 0.0801 - mean_squared_error: 0.0801 - mean_absolute_error: 0.2030 - 49s/epoch - 17ms/step
# Epoch 103/500
# 2912/2912 - 191s - loss: 0.0823 - mean_squared_error: 0.0823 - mean_absolute_error: 0.2039 - 191s/epoch - 66ms/step
# Epoch 104/500
# 2912/2912 - 217s - loss: 0.0792 - mean_squared_error: 0.0792 - mean_absolute_error: 0.2009 - 217s/epoch - 75ms/step
# Epoch 105/500
# 2912/2912 - 219s - loss: 0.0782 - mean_squared_error: 0.0782 - mean_absolute_error: 0.2003 - 219s/epoch - 75ms/step
# Epoch 106/500
# 2912/2912 - 240s - loss: 0.0794 - mean_squared_error: 0.0794 - mean_absolute_error: 0.2011 - 240s/epoch - 82ms/step
# Epoch 107/500
# 2912/2912 - 231s - loss: 0.0779 - mean_squared_error: 0.0779 - mean_absolute_error: 0.1997 - 231s/epoch - 79ms/step
# Epoch 108/500
# 2912/2912 - 225s - loss: 0.0784 - mean_squared_error: 0.0784 - mean_absolute_error: 0.1992 - 225s/epoch - 77ms/step
# Epoch 109/500
# 2912/2912 - 199s - loss: 0.0773 - mean_squared_error: 0.0773 - mean_absolute_error: 0.1975 - 199s/epoch - 68ms/step
# Epoch 110/500
# 2912/2912 - 208s - loss: 0.1312 - mean_squared_error: 0.1312 - mean_absolute_error: 0.2421 - 208s/epoch - 72ms/step
# Epoch 111/500
# 2912/2912 - 223s - loss: 0.0711 - mean_squared_error: 0.0711 - mean_absolute_error: 0.1895 - 223s/epoch - 77ms/step
# Epoch 112/500
# 2912/2912 - 207s - loss: 0.0743 - mean_squared_error: 0.0743 - mean_absolute_error: 0.1942 - 207s/epoch - 71ms/step
# Epoch 113/500
# 2912/2912 - 189s - loss: 0.0783 - mean_squared_error: 0.0783 - mean_absolute_error: 0.2003 - 189s/epoch - 65ms/step
# Epoch 114/500
# 2912/2912 - 220s - loss: 0.0755 - mean_squared_error: 0.0755 - mean_absolute_error: 0.1968 - 220s/epoch - 76ms/step
# Epoch 115/500
# 2912/2912 - 217s - loss: 0.0771 - mean_squared_error: 0.0771 - mean_absolute_error: 0.1980 - 217s/epoch - 75ms/step
# Epoch 116/500
# 2912/2912 - 211s - loss: 0.0762 - mean_squared_error: 0.0762 - mean_absolute_error: 0.1959 - 211s/epoch - 72ms/step
# Epoch 117/500
# 2912/2912 - 217s - loss: 0.0746 - mean_squared_error: 0.0746 - mean_absolute_error: 0.1948 - 217s/epoch - 75ms/step
# Epoch 118/500
# 2912/2912 - 209s - loss: 0.0778 - mean_squared_error: 0.0778 - mean_absolute_error: 0.1986 - 209s/epoch - 72ms/step
# Epoch 119/500
# 2912/2912 - 225s - loss: 0.0777 - mean_squared_error: 0.0777 - mean_absolute_error: 0.1985 - 225s/epoch - 77ms/step
# Epoch 120/500
# 2912/2912 - 225s - loss: 0.0741 - mean_squared_error: 0.0741 - mean_absolute_error: 0.1923 - 225s/epoch - 77ms/step
# Epoch 121/500
# 2912/2912 - 244s - loss: 0.0738 - mean_squared_error: 0.0738 - mean_absolute_error: 0.1937 - 244s/epoch - 84ms/step
# Epoch 122/500
# 2912/2912 - 224s - loss: 0.0749 - mean_squared_error: 0.0749 - mean_absolute_error: 0.1961 - 224s/epoch - 77ms/step
# Epoch 123/500
# 2912/2912 - 238s - loss: 0.0744 - mean_squared_error: 0.0744 - mean_absolute_error: 0.1928 - 238s/epoch - 82ms/step
# Epoch 124/500
# 2912/2912 - 209s - loss: 0.0744 - mean_squared_error: 0.0744 - mean_absolute_error: 0.1932 - 209s/epoch - 72ms/step
# Epoch 125/500
# 2912/2912 - 214s - loss: 0.0753 - mean_squared_error: 0.0753 - mean_absolute_error: 0.1941 - 214s/epoch - 73ms/step
# Epoch 126/500
# 2912/2912 - 228s - loss: 0.0731 - mean_squared_error: 0.0731 - mean_absolute_error: 0.1920 - 228s/epoch - 78ms/step
# Epoch 127/500
# 2912/2912 - 212s - loss: 0.0725 - mean_squared_error: 0.0725 - mean_absolute_error: 0.1908 - 212s/epoch - 73ms/step
# Epoch 128/500
# 2912/2912 - 219s - loss: 0.0716 - mean_squared_error: 0.0716 - mean_absolute_error: 0.1903 - 219s/epoch - 75ms/step
# Epoch 129/500
# 2912/2912 - 227s - loss: 0.0734 - mean_squared_error: 0.0734 - mean_absolute_error: 0.1920 - 227s/epoch - 78ms/step
# Epoch 130/500
# 2912/2912 - 224s - loss: 0.0705 - mean_squared_error: 0.0705 - mean_absolute_error: 0.1882 - 224s/epoch - 77ms/step
# Epoch 131/500
# 2912/2912 - 274s - loss: 0.0728 - mean_squared_error: 0.0728 - mean_absolute_error: 0.1910 - 274s/epoch - 94ms/step
# Epoch 132/500
# 2912/2912 - 215s - loss: 0.0744 - mean_squared_error: 0.0744 - mean_absolute_error: 0.1910 - 215s/epoch - 74ms/step
# Epoch 133/500
# 2912/2912 - 215s - loss: 0.0713 - mean_squared_error: 0.0713 - mean_absolute_error: 0.1891 - 215s/epoch - 74ms/step
# Epoch 134/500
# 2912/2912 - 224s - loss: 0.0776 - mean_squared_error: 0.0776 - mean_absolute_error: 0.1977 - 224s/epoch - 77ms/step
# Epoch 135/500
# 2912/2912 - 210s - loss: 0.0682 - mean_squared_error: 0.0682 - mean_absolute_error: 0.1835 - 210s/epoch - 72ms/step
# Epoch 136/500
# 2912/2912 - 216s - loss: 0.0711 - mean_squared_error: 0.0711 - mean_absolute_error: 0.1883 - 216s/epoch - 74ms/step
# Epoch 137/500
# 2912/2912 - 194s - loss: 0.0704 - mean_squared_error: 0.0704 - mean_absolute_error: 0.1882 - 194s/epoch - 67ms/step
# Epoch 138/500
# 2912/2912 - 181s - loss: 0.0690 - mean_squared_error: 0.0690 - mean_absolute_error: 0.1863 - 181s/epoch - 62ms/step
# Epoch 139/500
# 2912/2912 - 30s - loss: 0.0700 - mean_squared_error: 0.0700 - mean_absolute_error: 0.1872 - 30s/epoch - 10ms/step
# Epoch 140/500
# 2912/2912 - 25s - loss: 0.0713 - mean_squared_error: 0.0713 - mean_absolute_error: 0.1898 - 25s/epoch - 8ms/step
# Epoch 141/500
# 2912/2912 - 24s - loss: 0.0686 - mean_squared_error: 0.0686 - mean_absolute_error: 0.1853 - 24s/epoch - 8ms/step
# Epoch 142/500
# 2912/2912 - 25s - loss: 0.0707 - mean_squared_error: 0.0707 - mean_absolute_error: 0.1871 - 25s/epoch - 9ms/step
# Epoch 143/500
# 2912/2912 - 25s - loss: 0.0697 - mean_squared_error: 0.0697 - mean_absolute_error: 0.1867 - 25s/epoch - 8ms/step
# Epoch 144/500
# 2912/2912 - 25s - loss: 0.0685 - mean_squared_error: 0.0685 - mean_absolute_error: 0.1846 - 25s/epoch - 9ms/step
# Epoch 145/500
# 2912/2912 - 25s - loss: 0.0783 - mean_squared_error: 0.0783 - mean_absolute_error: 0.1936 - 25s/epoch - 8ms/step
# Epoch 146/500
# 2912/2912 - 24s - loss: 0.0637 - mean_squared_error: 0.0637 - mean_absolute_error: 0.1768 - 24s/epoch - 8ms/step
# Epoch 147/500
# 2912/2912 - 24s - loss: 0.0685 - mean_squared_error: 0.0685 - mean_absolute_error: 0.1857 - 24s/epoch - 8ms/step
# Epoch 148/500
# 2912/2912 - 25s - loss: 0.0686 - mean_squared_error: 0.0686 - mean_absolute_error: 0.1844 - 25s/epoch - 8ms/step
# Epoch 149/500
# 2912/2912 - 25s - loss: 0.0711 - mean_squared_error: 0.0711 - mean_absolute_error: 0.1872 - 25s/epoch - 8ms/step
# Epoch 150/500
# 2912/2912 - 25s - loss: 0.0678 - mean_squared_error: 0.0678 - mean_absolute_error: 0.1835 - 25s/epoch - 8ms/step
# Epoch 151/500
# 2912/2912 - 25s - loss: 0.0688 - mean_squared_error: 0.0688 - mean_absolute_error: 0.1859 - 25s/epoch - 8ms/step
# Epoch 152/500
# 2912/2912 - 25s - loss: 0.0701 - mean_squared_error: 0.0701 - mean_absolute_error: 0.1864 - 25s/epoch - 9ms/step
# Epoch 153/500
# 2912/2912 - 25s - loss: 0.0663 - mean_squared_error: 0.0663 - mean_absolute_error: 0.1816 - 25s/epoch - 8ms/step
# Epoch 154/500
# 2912/2912 - 25s - loss: 0.0667 - mean_squared_error: 0.0667 - mean_absolute_error: 0.1824 - 25s/epoch - 8ms/step
# Epoch 155/500
# 2912/2912 - 25s - loss: 0.0763 - mean_squared_error: 0.0763 - mean_absolute_error: 0.1924 - 25s/epoch - 8ms/step
# Epoch 156/500
# 2912/2912 - 25s - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1779 - 25s/epoch - 8ms/step
# Epoch 157/500
# 2912/2912 - 25s - loss: 0.0675 - mean_squared_error: 0.0675 - mean_absolute_error: 0.1829 - 25s/epoch - 9ms/step
# Epoch 158/500
# 2912/2912 - 25s - loss: 0.0661 - mean_squared_error: 0.0661 - mean_absolute_error: 0.1821 - 25s/epoch - 9ms/step
# Epoch 159/500
# 2912/2912 - 25s - loss: 0.0688 - mean_squared_error: 0.0688 - mean_absolute_error: 0.1854 - 25s/epoch - 8ms/step
# Epoch 160/500
# 2912/2912 - 25s - loss: 0.0661 - mean_squared_error: 0.0661 - mean_absolute_error: 0.1815 - 25s/epoch - 9ms/step
# Epoch 161/500
# 2912/2912 - 25s - loss: 0.0664 - mean_squared_error: 0.0664 - mean_absolute_error: 0.1813 - 25s/epoch - 9ms/step
# Epoch 162/500
# 2912/2912 - 25s - loss: 0.0663 - mean_squared_error: 0.0663 - mean_absolute_error: 0.1811 - 25s/epoch - 9ms/step
# Epoch 163/500
# 2912/2912 - 25s - loss: 0.0662 - mean_squared_error: 0.0662 - mean_absolute_error: 0.1821 - 25s/epoch - 9ms/step
# Epoch 164/500
# 2912/2912 - 25s - loss: 0.0644 - mean_squared_error: 0.0644 - mean_absolute_error: 0.1800 - 25s/epoch - 9ms/step
# Epoch 165/500
# 2912/2912 - 25s - loss: 0.0655 - mean_squared_error: 0.0655 - mean_absolute_error: 0.1802 - 25s/epoch - 9ms/step
# Epoch 166/500
# 2912/2912 - 25s - loss: 0.0652 - mean_squared_error: 0.0652 - mean_absolute_error: 0.1794 - 25s/epoch - 9ms/step
# Epoch 167/500
# 2912/2912 - 25s - loss: 0.0666 - mean_squared_error: 0.0666 - mean_absolute_error: 0.1815 - 25s/epoch - 9ms/step
# Epoch 168/500
# 2912/2912 - 25s - loss: 0.0639 - mean_squared_error: 0.0639 - mean_absolute_error: 0.1780 - 25s/epoch - 9ms/step
# Epoch 169/500
# 2912/2912 - 25s - loss: 0.0649 - mean_squared_error: 0.0649 - mean_absolute_error: 0.1791 - 25s/epoch - 9ms/step
# Epoch 170/500
# 2912/2912 - 26s - loss: 0.0643 - mean_squared_error: 0.0643 - mean_absolute_error: 0.1783 - 26s/epoch - 9ms/step
# Epoch 171/500
# 2912/2912 - 25s - loss: 0.0637 - mean_squared_error: 0.0637 - mean_absolute_error: 0.1794 - 25s/epoch - 9ms/step
# Epoch 172/500
# 2912/2912 - 26s - loss: 0.0646 - mean_squared_error: 0.0646 - mean_absolute_error: 0.1776 - 26s/epoch - 9ms/step
# Epoch 173/500
# 2912/2912 - 25s - loss: 0.0639 - mean_squared_error: 0.0639 - mean_absolute_error: 0.1785 - 25s/epoch - 9ms/step
# Epoch 174/500
# 2912/2912 - 25s - loss: 0.0646 - mean_squared_error: 0.0646 - mean_absolute_error: 0.1786 - 25s/epoch - 9ms/step
# Epoch 175/500
# 2912/2912 - 25s - loss: 0.0623 - mean_squared_error: 0.0623 - mean_absolute_error: 0.1752 - 25s/epoch - 9ms/step
# Epoch 176/500
# 2912/2912 - 26s - loss: 0.0633 - mean_squared_error: 0.0633 - mean_absolute_error: 0.1782 - 26s/epoch - 9ms/step
# Epoch 177/500
# 2912/2912 - 26s - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1767 - 26s/epoch - 9ms/step
# Epoch 178/500
# 2912/2912 - 26s - loss: 0.0643 - mean_squared_error: 0.0643 - mean_absolute_error: 0.1772 - 26s/epoch - 9ms/step
# Epoch 179/500
# 2912/2912 - 26s - loss: 0.0618 - mean_squared_error: 0.0618 - mean_absolute_error: 0.1758 - 26s/epoch - 9ms/step
# Epoch 180/500
# 2912/2912 - 26s - loss: 0.0630 - mean_squared_error: 0.0630 - mean_absolute_error: 0.1767 - 26s/epoch - 9ms/step
# Epoch 181/500
# 2912/2912 - 26s - loss: 0.0784 - mean_squared_error: 0.0784 - mean_absolute_error: 0.1905 - 26s/epoch - 9ms/step
# Epoch 182/500
# 2912/2912 - 26s - loss: 0.0581 - mean_squared_error: 0.0581 - mean_absolute_error: 0.1680 - 26s/epoch - 9ms/step
# Epoch 183/500
# 2912/2912 - 26s - loss: 0.0610 - mean_squared_error: 0.0610 - mean_absolute_error: 0.1723 - 26s/epoch - 9ms/step
# Epoch 184/500
# 2912/2912 - 26s - loss: 0.0637 - mean_squared_error: 0.0637 - mean_absolute_error: 0.1769 - 26s/epoch - 9ms/step
# Epoch 185/500
# 2912/2912 - 26s - loss: 0.0625 - mean_squared_error: 0.0625 - mean_absolute_error: 0.1753 - 26s/epoch - 9ms/step
# Epoch 186/500
# 2912/2912 - 26s - loss: 0.0632 - mean_squared_error: 0.0632 - mean_absolute_error: 0.1750 - 26s/epoch - 9ms/step
# Epoch 187/500
# 2912/2912 - 26s - loss: 0.0622 - mean_squared_error: 0.0622 - mean_absolute_error: 0.1742 - 26s/epoch - 9ms/step
# Epoch 188/500
# 2912/2912 - 26s - loss: 0.0603 - mean_squared_error: 0.0603 - mean_absolute_error: 0.1728 - 26s/epoch - 9ms/step
# Epoch 189/500
# 2912/2912 - 27s - loss: 0.0623 - mean_squared_error: 0.0623 - mean_absolute_error: 0.1745 - 27s/epoch - 9ms/step
# Epoch 190/500
# 2912/2912 - 26s - loss: 0.0613 - mean_squared_error: 0.0613 - mean_absolute_error: 0.1732 - 26s/epoch - 9ms/step
# Epoch 191/500
# 2912/2912 - 26s - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1721 - 26s/epoch - 9ms/step
# Epoch 192/500
# 2912/2912 - 26s - loss: 0.0608 - mean_squared_error: 0.0608 - mean_absolute_error: 0.1746 - 26s/epoch - 9ms/step
# Epoch 193/500
# 2912/2912 - 26s - loss: 0.0850 - mean_squared_error: 0.0850 - mean_absolute_error: 0.1948 - 26s/epoch - 9ms/step
# Epoch 194/500
# 2912/2912 - 26s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1651 - 26s/epoch - 9ms/step
# Epoch 195/500
# 2912/2912 - 27s - loss: 0.0594 - mean_squared_error: 0.0594 - mean_absolute_error: 0.1705 - 27s/epoch - 9ms/step
# Epoch 196/500
# 2912/2912 - 26s - loss: 0.0606 - mean_squared_error: 0.0606 - mean_absolute_error: 0.1726 - 26s/epoch - 9ms/step
# Epoch 197/500
# 2912/2912 - 26s - loss: 0.0613 - mean_squared_error: 0.0613 - mean_absolute_error: 0.1742 - 26s/epoch - 9ms/step
# Epoch 198/500
# 2912/2912 - 26s - loss: 0.0604 - mean_squared_error: 0.0604 - mean_absolute_error: 0.1717 - 26s/epoch - 9ms/step
# Epoch 199/500
# 2912/2912 - 27s - loss: 0.0599 - mean_squared_error: 0.0599 - mean_absolute_error: 0.1716 - 27s/epoch - 9ms/step
# Epoch 200/500
# 2912/2912 - 28s - loss: 0.0610 - mean_squared_error: 0.0610 - mean_absolute_error: 0.1721 - val_loss: 0.1125 - val_mean_squared_error: 0.1125 - val_mean_absolute_error: 0.2146 - 28s/epoch - 10ms/step
# Epoch 201/500
# 2912/2912 - 27s - loss: 0.0599 - mean_squared_error: 0.0599 - mean_absolute_error: 0.1715 - 27s/epoch - 9ms/step
# Epoch 202/500
# 2912/2912 - 27s - loss: 0.0591 - mean_squared_error: 0.0591 - mean_absolute_error: 0.1705 - 27s/epoch - 9ms/step
# Epoch 203/500
# 2912/2912 - 27s - loss: 0.0605 - mean_squared_error: 0.0605 - mean_absolute_error: 0.1720 - 27s/epoch - 9ms/step
# Epoch 204/500
# 2912/2912 - 27s - loss: 0.0604 - mean_squared_error: 0.0604 - mean_absolute_error: 0.1730 - 27s/epoch - 9ms/step
# Epoch 205/500
# 2912/2912 - 26s - loss: 0.0675 - mean_squared_error: 0.0675 - mean_absolute_error: 0.1782 - 26s/epoch - 9ms/step
# Epoch 206/500
# 2912/2912 - 26s - loss: 0.0580 - mean_squared_error: 0.0580 - mean_absolute_error: 0.1685 - 26s/epoch - 9ms/step
# Epoch 207/500
# 2912/2912 - 26s - loss: 0.0597 - mean_squared_error: 0.0597 - mean_absolute_error: 0.1713 - 26s/epoch - 9ms/step
# Epoch 208/500
# 2912/2912 - 27s - loss: 0.0587 - mean_squared_error: 0.0587 - mean_absolute_error: 0.1704 - 27s/epoch - 9ms/step
# Epoch 209/500
# 2912/2912 - 27s - loss: 0.0600 - mean_squared_error: 0.0600 - mean_absolute_error: 0.1702 - 27s/epoch - 9ms/step
# Epoch 210/500
# 2912/2912 - 27s - loss: 0.0595 - mean_squared_error: 0.0595 - mean_absolute_error: 0.1703 - 27s/epoch - 9ms/step
# Epoch 211/500
# 2912/2912 - 27s - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1684 - 27s/epoch - 9ms/step
# Epoch 212/500
# 2912/2912 - 27s - loss: 0.0603 - mean_squared_error: 0.0603 - mean_absolute_error: 0.1717 - 27s/epoch - 9ms/step
# Epoch 213/500
# 2912/2912 - 27s - loss: 0.0579 - mean_squared_error: 0.0579 - mean_absolute_error: 0.1687 - 27s/epoch - 9ms/step
# Epoch 214/500
# 2912/2912 - 27s - loss: 0.0597 - mean_squared_error: 0.0597 - mean_absolute_error: 0.1712 - 27s/epoch - 9ms/step
# Epoch 215/500
# 2912/2912 - 27s - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1671 - 27s/epoch - 9ms/step
# Epoch 216/500
# 2912/2912 - 27s - loss: 0.0584 - mean_squared_error: 0.0584 - mean_absolute_error: 0.1681 - 27s/epoch - 9ms/step
# Epoch 217/500
# 2912/2912 - 27s - loss: 0.0592 - mean_squared_error: 0.0592 - mean_absolute_error: 0.1718 - 27s/epoch - 9ms/step
# Epoch 218/500
# 2912/2912 - 27s - loss: 0.0564 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1665 - 27s/epoch - 9ms/step
# Epoch 219/500
# 2912/2912 - 27s - loss: 0.0586 - mean_squared_error: 0.0586 - mean_absolute_error: 0.1689 - 27s/epoch - 9ms/step
# Epoch 220/500
# 2912/2912 - 27s - loss: 0.0582 - mean_squared_error: 0.0582 - mean_absolute_error: 0.1698 - 27s/epoch - 9ms/step
# Epoch 221/500
# 2912/2912 - 27s - loss: 0.0560 - mean_squared_error: 0.0560 - mean_absolute_error: 0.1657 - 27s/epoch - 9ms/step
# Epoch 222/500
# 2912/2912 - 27s - loss: 0.0614 - mean_squared_error: 0.0614 - mean_absolute_error: 0.1720 - 27s/epoch - 9ms/step
# Epoch 223/500
# 2912/2912 - 27s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1649 - 27s/epoch - 9ms/step
# Epoch 224/500
# 2912/2912 - 27s - loss: 0.0578 - mean_squared_error: 0.0578 - mean_absolute_error: 0.1685 - 27s/epoch - 9ms/step
# Epoch 225/500
# 2912/2912 - 26s - loss: 0.0559 - mean_squared_error: 0.0559 - mean_absolute_error: 0.1659 - 26s/epoch - 9ms/step
# Epoch 226/500
# 2912/2912 - 25s - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1699 - 25s/epoch - 9ms/step
# Epoch 227/500
# 2912/2912 - 25s - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1662 - 25s/epoch - 9ms/step
# Epoch 228/500
# 2912/2912 - 25s - loss: 0.0578 - mean_squared_error: 0.0578 - mean_absolute_error: 0.1661 - 25s/epoch - 9ms/step
# Epoch 229/500
# 2912/2912 - 25s - loss: 0.0562 - mean_squared_error: 0.0562 - mean_absolute_error: 0.1657 - 25s/epoch - 9ms/step
# Epoch 230/500
# 2912/2912 - 25s - loss: 0.0565 - mean_squared_error: 0.0565 - mean_absolute_error: 0.1654 - 25s/epoch - 9ms/step
# Epoch 231/500
# 2912/2912 - 25s - loss: 0.0598 - mean_squared_error: 0.0598 - mean_absolute_error: 0.1702 - 25s/epoch - 9ms/step
# Epoch 232/500
# 2912/2912 - 25s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1639 - 25s/epoch - 9ms/step
# Epoch 233/500
# 2912/2912 - 25s - loss: 0.0548 - mean_squared_error: 0.0548 - mean_absolute_error: 0.1627 - 25s/epoch - 9ms/step
# Epoch 234/500
# 2912/2912 - 25s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1636 - 25s/epoch - 9ms/step
# Epoch 235/500
# 2912/2912 - 25s - loss: 0.0565 - mean_squared_error: 0.0565 - mean_absolute_error: 0.1657 - 25s/epoch - 9ms/step
# Epoch 236/500
# 2912/2912 - 25s - loss: 0.0569 - mean_squared_error: 0.0569 - mean_absolute_error: 0.1677 - 25s/epoch - 9ms/step
# Epoch 237/500
# 2912/2912 - 25s - loss: 0.0572 - mean_squared_error: 0.0572 - mean_absolute_error: 0.1666 - 25s/epoch - 9ms/step
# Epoch 238/500
# 2912/2912 - 25s - loss: 0.0545 - mean_squared_error: 0.0545 - mean_absolute_error: 0.1638 - 25s/epoch - 9ms/step
# Epoch 239/500
# 2912/2912 - 25s - loss: 0.0550 - mean_squared_error: 0.0550 - mean_absolute_error: 0.1642 - 25s/epoch - 9ms/step
# Epoch 240/500
# 2912/2912 - 25s - loss: 0.0552 - mean_squared_error: 0.0552 - mean_absolute_error: 0.1657 - 25s/epoch - 9ms/step
# Epoch 241/500
# 2912/2912 - 25s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1637 - 25s/epoch - 9ms/step
# Epoch 242/500
# 2912/2912 - 25s - loss: 0.0599 - mean_squared_error: 0.0599 - mean_absolute_error: 0.1701 - 25s/epoch - 9ms/step
# Epoch 243/500
# 2912/2912 - 25s - loss: 0.0532 - mean_squared_error: 0.0532 - mean_absolute_error: 0.1609 - 25s/epoch - 9ms/step
# Epoch 244/500
# 2912/2912 - 25s - loss: 0.0583 - mean_squared_error: 0.0583 - mean_absolute_error: 0.1672 - 25s/epoch - 9ms/step
# Epoch 245/500
# 2912/2912 - 25s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1653 - 25s/epoch - 9ms/step
# Epoch 246/500
# 2912/2912 - 26s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1655 - 26s/epoch - 9ms/step
# Epoch 247/500
# 2912/2912 - 26s - loss: 0.0551 - mean_squared_error: 0.0551 - mean_absolute_error: 0.1632 - 26s/epoch - 9ms/step
# Epoch 248/500
# 2912/2912 - 25s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1628 - 25s/epoch - 9ms/step
# Epoch 249/500
# 2912/2912 - 25s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1646 - 25s/epoch - 8ms/step
# Epoch 250/500
# 2912/2912 - 26s - loss: 0.0530 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1616 - 26s/epoch - 9ms/step
# Epoch 251/500
# 2912/2912 - 28s - loss: 0.0620 - mean_squared_error: 0.0620 - mean_absolute_error: 0.1702 - 28s/epoch - 10ms/step
# Epoch 252/500
# 2912/2912 - 26s - loss: 0.0525 - mean_squared_error: 0.0525 - mean_absolute_error: 0.1586 - 26s/epoch - 9ms/step
# Epoch 253/500
# 2912/2912 - 26s - loss: 0.0570 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1666 - 26s/epoch - 9ms/step
# Epoch 254/500
# 2912/2912 - 26s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1603 - 26s/epoch - 9ms/step
# Epoch 255/500
# 2912/2912 - 25s - loss: 0.0562 - mean_squared_error: 0.0562 - mean_absolute_error: 0.1641 - 25s/epoch - 9ms/step
# Epoch 256/500
# 2912/2912 - 26s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1619 - 26s/epoch - 9ms/step
# Epoch 257/500
# 2912/2912 - 26s - loss: 0.0541 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1629 - 26s/epoch - 9ms/step
# Epoch 258/500
# 2912/2912 - 28s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1614 - 28s/epoch - 9ms/step
# Epoch 259/500
# 2912/2912 - 26s - loss: 0.0567 - mean_squared_error: 0.0567 - mean_absolute_error: 0.1634 - 26s/epoch - 9ms/step
# Epoch 260/500
# 2912/2912 - 27s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1618 - 27s/epoch - 9ms/step
# Epoch 261/500
# 2912/2912 - 25s - loss: 0.0530 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1608 - 25s/epoch - 9ms/step
# Epoch 262/500
# 2912/2912 - 27s - loss: 0.0528 - mean_squared_error: 0.0528 - mean_absolute_error: 0.1619 - 27s/epoch - 9ms/step
# Epoch 263/500
# 2912/2912 - 25s - loss: 0.0543 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1609 - 25s/epoch - 9ms/step
# Epoch 264/500
# 2912/2912 - 26s - loss: 0.0576 - mean_squared_error: 0.0576 - mean_absolute_error: 0.1663 - 26s/epoch - 9ms/step
# Epoch 265/500
# 2912/2912 - 27s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1560 - 27s/epoch - 9ms/step
# Epoch 266/500
# 2912/2912 - 27s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1623 - 27s/epoch - 9ms/step
# Epoch 267/500
# 2912/2912 - 27s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1632 - 27s/epoch - 9ms/step
# Epoch 268/500
# 2912/2912 - 26s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1621 - 26s/epoch - 9ms/step
# Epoch 269/500
# 2912/2912 - 26s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1644 - 26s/epoch - 9ms/step
# Epoch 270/500
# 2912/2912 - 26s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1590 - 26s/epoch - 9ms/step
# Epoch 271/500
# 2912/2912 - 28s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1595 - 28s/epoch - 10ms/step
# Epoch 272/500
# 2912/2912 - 28s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1593 - 28s/epoch - 10ms/step
# Epoch 273/500
# 2912/2912 - 27s - loss: 0.0558 - mean_squared_error: 0.0558 - mean_absolute_error: 0.1651 - 27s/epoch - 9ms/step
# Epoch 274/500
# 2912/2912 - 28s - loss: 0.0532 - mean_squared_error: 0.0532 - mean_absolute_error: 0.1607 - 28s/epoch - 9ms/step
# Epoch 275/500
# 2912/2912 - 28s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1588 - 28s/epoch - 10ms/step
# Epoch 276/500
# 2912/2912 - 27s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1598 - 27s/epoch - 9ms/step
# Epoch 277/500
# 2912/2912 - 27s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1580 - 27s/epoch - 9ms/step
# Epoch 278/500
# 2912/2912 - 26s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1590 - 26s/epoch - 9ms/step
# Epoch 279/500
# 2912/2912 - 26s - loss: 0.0543 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1625 - 26s/epoch - 9ms/step
# Epoch 280/500
# 2912/2912 - 26s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1571 - 26s/epoch - 9ms/step
# Epoch 281/500
# 2912/2912 - 26s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1596 - 26s/epoch - 9ms/step
# Epoch 282/500
# 2912/2912 - 26s - loss: 0.0537 - mean_squared_error: 0.0537 - mean_absolute_error: 0.1605 - 26s/epoch - 9ms/step
# Epoch 283/500
# 2912/2912 - 26s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1588 - 26s/epoch - 9ms/step
# Epoch 284/500
# 2912/2912 - 27s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1583 - 27s/epoch - 9ms/step
# Epoch 285/500
# 2912/2912 - 29s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1595 - 29s/epoch - 10ms/step
# Epoch 286/500
# 2912/2912 - 27s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1561 - 27s/epoch - 9ms/step
# Epoch 287/500
# 2912/2912 - 27s - loss: 0.0571 - mean_squared_error: 0.0571 - mean_absolute_error: 0.1654 - 27s/epoch - 9ms/step
# Epoch 288/500
# 2912/2912 - 27s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1517 - 27s/epoch - 9ms/step
# Epoch 289/500
# 2912/2912 - 28s - loss: 43.7926 - mean_squared_error: 43.7927 - mean_absolute_error: 0.3225 - 28s/epoch - 10ms/step
# Epoch 290/500
# 2912/2912 - 26s - loss: 0.0691 - mean_squared_error: 0.0691 - mean_absolute_error: 0.1882 - 26s/epoch - 9ms/step
# Epoch 291/500
# 2912/2912 - 26s - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1702 - 26s/epoch - 9ms/step
# Epoch 292/500
# 2912/2912 - 28s - loss: 0.0554 - mean_squared_error: 0.0554 - mean_absolute_error: 0.1662 - 28s/epoch - 10ms/step
# Epoch 293/500
# 2912/2912 - 26s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1618 - 26s/epoch - 9ms/step
# Epoch 294/500
# 2912/2912 - 26s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1628 - 26s/epoch - 9ms/step
# Epoch 295/500
# 2912/2912 - 27s - loss: 0.0615 - mean_squared_error: 0.0615 - mean_absolute_error: 0.1706 - 27s/epoch - 9ms/step
# Epoch 296/500
# 2912/2912 - 26s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1542 - 26s/epoch - 9ms/step
# Epoch 297/500
# 2912/2912 - 26s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1583 - 26s/epoch - 9ms/step
# Epoch 298/500
# 2912/2912 - 27s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1582 - 27s/epoch - 9ms/step
# Epoch 299/500
# 2912/2912 - 27s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1628 - 27s/epoch - 9ms/step
# Epoch 300/500
# 2912/2912 - 28s - loss: 0.0525 - mean_squared_error: 0.0525 - mean_absolute_error: 0.1606 - val_loss: 0.1199 - val_mean_squared_error: 0.1199 - val_mean_absolute_error: 0.2262 - 28s/epoch - 10ms/step
# Epoch 301/500
# 2912/2912 - 26s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1604 - 26s/epoch - 9ms/step
# Epoch 302/500
# 2912/2912 - 26s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1606 - 26s/epoch - 9ms/step
# Epoch 303/500
# 2912/2912 - 29s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1608 - 29s/epoch - 10ms/step
# Epoch 304/500
# 2912/2912 - 29s - loss: 0.0542 - mean_squared_error: 0.0542 - mean_absolute_error: 0.1622 - 29s/epoch - 10ms/step
# Epoch 305/500
# 2912/2912 - 28s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1569 - 28s/epoch - 10ms/step
# Epoch 306/500
# 2912/2912 - 28s - loss: 0.0593 - mean_squared_error: 0.0593 - mean_absolute_error: 0.1681 - 28s/epoch - 10ms/step
# Epoch 307/500
# 2912/2912 - 28s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1545 - 28s/epoch - 9ms/step
# Epoch 308/500
# 2912/2912 - 28s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1576 - 28s/epoch - 9ms/step
# Epoch 309/500
# 2912/2912 - 28s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1591 - 28s/epoch - 10ms/step
# Epoch 310/500
# 2912/2912 - 28s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1625 - 28s/epoch - 10ms/step
# Epoch 311/500
# 2912/2912 - 28s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1544 - 28s/epoch - 10ms/step
# Epoch 312/500
# 2912/2912 - 30s - loss: 0.0578 - mean_squared_error: 0.0578 - mean_absolute_error: 0.1636 - 30s/epoch - 10ms/step
# Epoch 313/500
# 2912/2912 - 30s - loss: 0.0530 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1579 - 30s/epoch - 10ms/step
# Epoch 314/500
# 2912/2912 - 30s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1590 - 30s/epoch - 10ms/step
# Epoch 315/500
# 2912/2912 - 29s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1549 - 29s/epoch - 10ms/step
# Epoch 316/500
# 2912/2912 - 30s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1586 - 30s/epoch - 10ms/step
# Epoch 317/500
# 2912/2912 - 28s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1570 - 28s/epoch - 10ms/step
# Epoch 318/500
# 2912/2912 - 28s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1585 - 28s/epoch - 10ms/step
# Epoch 319/500
# 2912/2912 - 28s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1555 - 28s/epoch - 10ms/step
# Epoch 320/500
# 2912/2912 - 27s - loss: 0.0487 - mean_squared_error: 0.0487 - mean_absolute_error: 0.1548 - 27s/epoch - 9ms/step
# Epoch 321/500
# 2912/2912 - 28s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1542 - 28s/epoch - 9ms/step
# Epoch 322/500
# 2912/2912 - 27s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1583 - 27s/epoch - 9ms/step
# Epoch 323/500
# 2912/2912 - 28s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1627 - 28s/epoch - 10ms/step
# Epoch 324/500
# 2912/2912 - 28s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1533 - 28s/epoch - 10ms/step
# Epoch 325/500
# 2912/2912 - 27s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1570 - 27s/epoch - 9ms/step
# Epoch 326/500
# 2912/2912 - 27s - loss: 0.0488 - mean_squared_error: 0.0488 - mean_absolute_error: 0.1543 - 27s/epoch - 9ms/step
# Epoch 327/500
# 2912/2912 - 28s - loss: 0.0480 - mean_squared_error: 0.0480 - mean_absolute_error: 0.1535 - 28s/epoch - 10ms/step
# Epoch 328/500
# 2912/2912 - 27s - loss: 0.0476 - mean_squared_error: 0.0476 - mean_absolute_error: 0.1535 - 27s/epoch - 9ms/step
# Epoch 329/500
# 2912/2912 - 28s - loss: 0.0479 - mean_squared_error: 0.0479 - mean_absolute_error: 0.1536 - 28s/epoch - 10ms/step
# Epoch 330/500
# 2912/2912 - 28s - loss: 0.0484 - mean_squared_error: 0.0484 - mean_absolute_error: 0.1558 - 28s/epoch - 10ms/step
# Epoch 331/500
# 2912/2912 - 28s - loss: 0.0467 - mean_squared_error: 0.0467 - mean_absolute_error: 0.1523 - 28s/epoch - 10ms/step
# Epoch 332/500
# 2912/2912 - 29s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1557 - 29s/epoch - 10ms/step
# Epoch 333/500
# 2912/2912 - 30s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1546 - 30s/epoch - 10ms/step
# Epoch 334/500
# 2912/2912 - 28s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1519 - 28s/epoch - 10ms/step
# Epoch 335/500
# 2912/2912 - 28s - loss: 0.0475 - mean_squared_error: 0.0475 - mean_absolute_error: 0.1536 - 28s/epoch - 9ms/step
# Epoch 336/500
# 2912/2912 - 27s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1561 - 27s/epoch - 9ms/step
# Epoch 337/500
# 2912/2912 - 27s - loss: 0.0590 - mean_squared_error: 0.0590 - mean_absolute_error: 0.1630 - 27s/epoch - 9ms/step
# Epoch 338/500
# 2912/2912 - 27s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1501 - 27s/epoch - 9ms/step
# Epoch 339/500
# 2912/2912 - 27s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1541 - 27s/epoch - 9ms/step
# Epoch 340/500
# 2912/2912 - 27s - loss: 0.0482 - mean_squared_error: 0.0482 - mean_absolute_error: 0.1531 - 27s/epoch - 9ms/step
# Epoch 341/500
# 2912/2912 - 27s - loss: 0.0488 - mean_squared_error: 0.0488 - mean_absolute_error: 0.1543 - 27s/epoch - 9ms/step
# Epoch 342/500
# 2912/2912 - 27s - loss: 0.0475 - mean_squared_error: 0.0475 - mean_absolute_error: 0.1535 - 27s/epoch - 9ms/step
# Epoch 343/500
# 2912/2912 - 27s - loss: 0.0478 - mean_squared_error: 0.0478 - mean_absolute_error: 0.1522 - 27s/epoch - 9ms/step
# Epoch 344/500
# 2912/2912 - 27s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1536 - 27s/epoch - 9ms/step
# Epoch 345/500
# 2912/2912 - 28s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1526 - 28s/epoch - 10ms/step
# Epoch 346/500
# 2912/2912 - 28s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1525 - 28s/epoch - 10ms/step
# Epoch 347/500
# 2912/2912 - 28s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1503 - 28s/epoch - 10ms/step
# Epoch 348/500
# 2912/2912 - 27s - loss: 0.0860 - mean_squared_error: 0.0860 - mean_absolute_error: 0.1925 - 27s/epoch - 9ms/step
# Epoch 349/500
# 2912/2912 - 29s - loss: 0.0465 - mean_squared_error: 0.0465 - mean_absolute_error: 0.1501 - 29s/epoch - 10ms/step
# Epoch 350/500
# 2912/2912 - 28s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1526 - 28s/epoch - 9ms/step
# Epoch 351/500
# 2912/2912 - 28s - loss: 0.0442 - mean_squared_error: 0.0442 - mean_absolute_error: 0.1492 - 28s/epoch - 9ms/step
# Epoch 352/500
# 2912/2912 - 27s - loss: 0.0482 - mean_squared_error: 0.0482 - mean_absolute_error: 0.1534 - 27s/epoch - 9ms/step
# Epoch 353/500
# 2912/2912 - 28s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1505 - 28s/epoch - 10ms/step
# Epoch 354/500
# 2912/2912 - 28s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1555 - 28s/epoch - 10ms/step
# Epoch 355/500
# 2912/2912 - 28s - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1518 - 28s/epoch - 10ms/step
# Epoch 356/500
# 2912/2912 - 28s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1536 - 28s/epoch - 10ms/step
# Epoch 357/500
# 2912/2912 - 28s - loss: 0.0448 - mean_squared_error: 0.0448 - mean_absolute_error: 0.1488 - 28s/epoch - 10ms/step
# Epoch 358/500
# 2912/2912 - 29s - loss: 0.0485 - mean_squared_error: 0.0485 - mean_absolute_error: 0.1526 - 29s/epoch - 10ms/step
# Epoch 359/500
# 2912/2912 - 28s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1610 - 28s/epoch - 10ms/step
# Epoch 360/500
# 2912/2912 - 28s - loss: 0.0445 - mean_squared_error: 0.0445 - mean_absolute_error: 0.1470 - 28s/epoch - 10ms/step
# Epoch 361/500
# 2912/2912 - 28s - loss: 0.0486 - mean_squared_error: 0.0486 - mean_absolute_error: 0.1552 - 28s/epoch - 10ms/step
# Epoch 362/500
# 2912/2912 - 27s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1509 - 27s/epoch - 9ms/step
# Epoch 363/500
# 2912/2912 - 28s - loss: 0.0462 - mean_squared_error: 0.0462 - mean_absolute_error: 0.1501 - 28s/epoch - 9ms/step
# Epoch 364/500
# 2912/2912 - 28s - loss: 0.0486 - mean_squared_error: 0.0486 - mean_absolute_error: 0.1542 - 28s/epoch - 10ms/step
# Epoch 365/500
# 2912/2912 - 29s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1495 - 29s/epoch - 10ms/step
# Epoch 366/500
# 2912/2912 - 30s - loss: 0.6290 - mean_squared_error: 0.6290 - mean_absolute_error: 0.3105 - 30s/epoch - 10ms/step
# Epoch 367/500
# 2912/2912 - 30s - loss: 0.0788 - mean_squared_error: 0.0788 - mean_absolute_error: 0.1964 - 30s/epoch - 10ms/step
# Epoch 368/500
# 2912/2912 - 29s - loss: 0.0570 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1699 - 29s/epoch - 10ms/step
# Epoch 369/500
# 2912/2912 - 31s - loss: 0.0648 - mean_squared_error: 0.0648 - mean_absolute_error: 0.1768 - 31s/epoch - 11ms/step
# Epoch 370/500
# 2912/2912 - 34s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1513 - 34s/epoch - 12ms/step
# Epoch 371/500
# 2912/2912 - 31s - loss: 0.0476 - mean_squared_error: 0.0476 - mean_absolute_error: 0.1547 - 31s/epoch - 11ms/step
# Epoch 372/500
# 2912/2912 - 31s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1564 - 31s/epoch - 11ms/step
# Epoch 373/500
# 2912/2912 - 29s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1543 - 29s/epoch - 10ms/step
# Epoch 374/500
# 2912/2912 - 29s - loss: 0.0467 - mean_squared_error: 0.0467 - mean_absolute_error: 0.1517 - 29s/epoch - 10ms/step
# Epoch 375/500
# 2912/2912 - 30s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1568 - 30s/epoch - 10ms/step
# Epoch 376/500
# ...
# Epoch 380/500
# 2912/2912 - 31s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1574 - 31s/epoch - 11ms/step
# Epoch 381/500
# 2912/2912 - 31s - loss: 0.0558 - mean_squared_error: 0.0558 - mean_absolute_error: 0.1588 - 31s/epoch - 11ms/step
# Epoch 382/500
# 2912/2912 - 44s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1502 - 44s/epoch - 15ms/step
# Epoch 383/500
# 2912/2912 - 39s - loss: 16392079.0000 - mean_squared_error: 16392078.0000 - mean_absolute_error: 74.4092 - 39s/epoch - 13ms/step
# Epoch 384/500
# 2912/2912 - 31s - loss: 54602.1758 - mean_squared_error: 54601.5664 - mean_absolute_error: 16.4011 - 31s/epoch - 10ms/step
# Epoch 385/500
# 2912/2912 - 31s - loss: 1913518.7500 - mean_squared_error: 1913519.1250 - mean_absolute_error: 29.8431 - 31s/epoch - 11ms/step
# Epoch 386/500
# 2912/2912 - 29s - loss: 14135.1494 - mean_squared_error: 14135.1318 - mean_absolute_error: 8.7523 - 29s/epoch - 10ms/step
# Epoch 387/500
# 2912/2912 - 31s - loss: 268034.7812 - mean_squared_error: 268035.1875 - mean_absolute_error: 93.2388 - 31s/epoch - 11ms/step
# Epoch 388/500
# 2912/2912 - 31s - loss: 3641621.5000 - mean_squared_error: 3641627.5000 - mean_absolute_error: 111.1045 - 31s/epoch - 11ms/step
# Epoch 389/500
# 2912/2912 - 31s - loss: 52953.5938 - mean_squared_error: 52953.6211 - mean_absolute_error: 59.1300 - 31s/epoch - 10ms/step
# Epoch 390/500
# 2912/2912 - 30s - loss: 11117.6074 - mean_squared_error: 11117.6162 - mean_absolute_error: 35.5749 - 30s/epoch - 10ms/step
# Epoch 391/500
# 2912/2912 - 30s - loss: 27978.9395 - mean_squared_error: 27978.9004 - mean_absolute_error: 27.3720 - 30s/epoch - 10ms/step
# Epoch 392/500
# 2912/2912 - 29s - loss: 8314.6104 - mean_squared_error: 8314.6045 - mean_absolute_error: 11.9699 - 29s/epoch - 10ms/step
# Epoch 393/500
# 2912/2912 - 29s - loss: 114.9875 - mean_squared_error: 114.9873 - mean_absolute_error: 5.9099 - 29s/epoch - 10ms/step
# Epoch 394/500
# 2912/2912 - 30s - loss: 195.5883 - mean_squared_error: 195.5884 - mean_absolute_error: 6.2874 - 30s/epoch - 10ms/step
# Epoch 395/500
# 2912/2912 - 29s - loss: 152.2522 - mean_squared_error: 152.2519 - mean_absolute_error: 6.3152 - 29s/epoch - 10ms/step
# Epoch 396/500
# 2912/2912 - 29s - loss: 55922.5508 - mean_squared_error: 55922.6641 - mean_absolute_error: 12.8072 - 29s/epoch - 10ms/step
# Epoch 397/500
# 2912/2912 - 28s - loss: 3560.9746 - mean_squared_error: 3560.9700 - mean_absolute_error: 8.0505 - 28s/epoch - 10ms/step
# Epoch 398/500
# 2912/2912 - 28s - loss: 18.8390 - mean_squared_error: 18.8391 - mean_absolute_error: 2.7272 - 28s/epoch - 10ms/step
# Epoch 399/500
# 2912/2912 - 32s - loss: 501.4955 - mean_squared_error: 501.4950 - mean_absolute_error: 4.1345 - 32s/epoch - 11ms/step
# Epoch 400/500
# 2912/2912 - 34s - loss: 76.4396 - mean_squared_error: 76.4397 - mean_absolute_error: 2.7553 - val_loss: 7.2030 - val_mean_squared_error: 7.2030 - val_mean_absolute_error: 2.0737 - 34s/epoch - 12ms/step
# Epoch 401/500
# 2912/2912 - 30s - loss: 8.6621 - mean_squared_error: 8.6621 - mean_absolute_error: 2.1129 - 30s/epoch - 10ms/step
# Epoch 402/500
# 2912/2912 - 28s - loss: 11807.1455 - mean_squared_error: 11807.1768 - mean_absolute_error: 14.9682 - 28s/epoch - 10ms/step
# Epoch 403/500
# 2912/2912 - 29s - loss: 11188.1963 - mean_squared_error: 11188.1875 - mean_absolute_error: 19.7644 - 29s/epoch - 10ms/step
# Epoch 404/500
# 2912/2912 - 29s - loss: 815.3730 - mean_squared_error: 815.3741 - mean_absolute_error: 5.9700 - 29s/epoch - 10ms/step
# Epoch 405/500
# 2912/2912 - 29s - loss: 2177.8186 - mean_squared_error: 2177.8174 - mean_absolute_error: 9.8170 - 29s/epoch - 10ms/step
# Epoch 406/500
# 2912/2912 - 29s - loss: 1720.6196 - mean_squared_error: 1720.6155 - mean_absolute_error: 11.5397 - 29s/epoch - 10ms/step
# Epoch 407/500
# 2912/2912 - 29s - loss: 191.7981 - mean_squared_error: 191.7979 - mean_absolute_error: 4.1481 - 29s/epoch - 10ms/step
# Epoch 408/500
# 2912/2912 - 29s - loss: 383.2599 - mean_squared_error: 383.2599 - mean_absolute_error: 8.4649 - 29s/epoch - 10ms/step
# Epoch 409/500
# 2912/2912 - 30s - loss: 239.0733 - mean_squared_error: 239.0733 - mean_absolute_error: 6.5793 - 30s/epoch - 10ms/step
# Epoch 410/500
# 2912/2912 - 29s - loss: 73.8460 - mean_squared_error: 73.8461 - mean_absolute_error: 4.2991 - 29s/epoch - 10ms/step
# Epoch 411/500
# 2912/2912 - 29s - loss: 2831.7485 - mean_squared_error: 2831.7512 - mean_absolute_error: 18.2544 - 29s/epoch - 10ms/step
# Epoch 412/500
# 2912/2912 - 28s - loss: 1158.1600 - mean_squared_error: 1158.1599 - mean_absolute_error: 13.0846 - 28s/epoch - 9ms/step
# Epoch 413/500
# 2912/2912 - 29s - loss: 3113.3606 - mean_squared_error: 3113.3572 - mean_absolute_error: 18.4282 - 29s/epoch - 10ms/step
# Epoch 414/500
# 2912/2912 - 28s - loss: 1646.0369 - mean_squared_error: 1646.0359 - mean_absolute_error: 9.0565 - 28s/epoch - 10ms/step
# Epoch 415/500
# 2912/2912 - 30s - loss: 1637.8252 - mean_squared_error: 1637.8280 - mean_absolute_error: 12.7695 - 30s/epoch - 10ms/step
# Epoch 416/500
# 2912/2912 - 30s - loss: 860.1617 - mean_squared_error: 860.1617 - mean_absolute_error: 11.0641 - 30s/epoch - 10ms/step
# Epoch 417/500
# 2912/2912 - 29s - loss: 2189.5598 - mean_squared_error: 2189.5610 - mean_absolute_error: 10.6486 - 29s/epoch - 10ms/step
# Epoch 418/500
# 2912/2912 - 30s - loss: 197.1465 - mean_squared_error: 197.1464 - mean_absolute_error: 5.6427 - 30s/epoch - 10ms/step
# Epoch 419/500
# 2912/2912 - 31s - loss: 74.2534 - mean_squared_error: 74.2534 - mean_absolute_error: 3.9474 - 31s/epoch - 10ms/step
# Epoch 420/500
# 2912/2912 - 29s - loss: 26.8155 - mean_squared_error: 26.8155 - mean_absolute_error: 2.7648 - 29s/epoch - 10ms/step
# Epoch 421/500
# 2912/2912 - 28s - loss: 84.7186 - mean_squared_error: 84.7186 - mean_absolute_error: 3.0778 - 28s/epoch - 10ms/step
# Epoch 422/500
# 2912/2912 - 30s - loss: 21.3698 - mean_squared_error: 21.3698 - mean_absolute_error: 2.4440 - 30s/epoch - 10ms/step
# Epoch 423/500
# 2912/2912 - 30s - loss: 8.2220 - mean_squared_error: 8.2220 - mean_absolute_error: 2.2356 - 30s/epoch - 10ms/step
# Epoch 424/500
# 2912/2912 - 31s - loss: 8.1928 - mean_squared_error: 8.1928 - mean_absolute_error: 2.2323 - 31s/epoch - 11ms/step
# Epoch 425/500
# 2912/2912 - 29s - loss: 8.1879 - mean_squared_error: 8.1879 - mean_absolute_error: 2.2313 - 29s/epoch - 10ms/step
# Epoch 426/500
# 2912/2912 - 29s - loss: 8.1995 - mean_squared_error: 8.1995 - mean_absolute_error: 2.2345 - 29s/epoch - 10ms/step
# Epoch 427/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 428/500
# 2912/2912 - 29s - loss: 8.1978 - mean_squared_error: 8.1978 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 429/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2343 - 29s/epoch - 10ms/step
# Epoch 430/500
# 2912/2912 - 29s - loss: 8.1975 - mean_squared_error: 8.1975 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 431/500
# 2912/2912 - 29s - loss: 8.1976 - mean_squared_error: 8.1976 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 432/500
# 2912/2912 - 29s - loss: 8.1977 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2332 - 29s/epoch - 10ms/step
# Epoch 433/500
# 2912/2912 - 29s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 434/500
# 2912/2912 - 29s - loss: 8.1977 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2344 - 29s/epoch - 10ms/step
# Epoch 435/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2337 - 29s/epoch - 10ms/step
# Epoch 436/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 437/500
# 2912/2912 - 29s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2338 - 29s/epoch - 10ms/step
# Epoch 438/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 439/500
# 2912/2912 - 28s - loss: 8.1982 - mean_squared_error: 8.1982 - mean_absolute_error: 2.2341 - 28s/epoch - 10ms/step
# Epoch 440/500
# 2912/2912 - 28s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2342 - 28s/epoch - 10ms/step
# Epoch 441/500
# 2912/2912 - 28s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2336 - 28s/epoch - 10ms/step
# Epoch 442/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2341 - 29s/epoch - 10ms/step
# Epoch 443/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2339 - 29s/epoch - 10ms/step
# Epoch 444/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2338 - 29s/epoch - 10ms/step
# Epoch 445/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2341 - 29s/epoch - 10ms/step
# Epoch 446/500
# 2912/2912 - 29s - loss: 8.1978 - mean_squared_error: 8.1978 - mean_absolute_error: 2.2343 - 29s/epoch - 10ms/step
# Epoch 447/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2339 - 29s/epoch - 10ms/step
# Epoch 448/500
# 2912/2912 - 29s - loss: 8.1983 - mean_squared_error: 8.1983 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 449/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 450/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2343 - 29s/epoch - 10ms/step
# Epoch 451/500
# 2912/2912 - 29s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2338 - 29s/epoch - 10ms/step
# Epoch 452/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2337 - 29s/epoch - 10ms/step
# Epoch 453/500
# 2912/2912 - 29s - loss: 8.1982 - mean_squared_error: 8.1982 - mean_absolute_error: 2.2342 - 29s/epoch - 10ms/step
# Epoch 454/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 455/500
# 2912/2912 - 29s - loss: 8.1973 - mean_squared_error: 8.1973 - mean_absolute_error: 2.2347 - 29s/epoch - 10ms/step
# Epoch 456/500
# 2912/2912 - 29s - loss: 8.1982 - mean_squared_error: 8.1982 - mean_absolute_error: 2.2334 - 29s/epoch - 10ms/step
# Epoch 457/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 458/500
# 2912/2912 - 29s - loss: 8.1978 - mean_squared_error: 8.1978 - mean_absolute_error: 2.2334 - 29s/epoch - 10ms/step
# Epoch 459/500
# 2912/2912 - 29s - loss: 8.1978 - mean_squared_error: 8.1978 - mean_absolute_error: 2.2342 - 29s/epoch - 10ms/step
# Epoch 460/500
# 2912/2912 - 28s - loss: 8.1962 - mean_squared_error: 8.1962 - mean_absolute_error: 2.2328 - 28s/epoch - 10ms/step
# Epoch 461/500
# 2912/2912 - 28s - loss: 8.1984 - mean_squared_error: 8.1984 - mean_absolute_error: 2.2343 - 28s/epoch - 10ms/step
# Epoch 462/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2337 - 29s/epoch - 10ms/step
# Epoch 463/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2347 - 29s/epoch - 10ms/step
# Epoch 464/500
# 2912/2912 - 29s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2338 - 29s/epoch - 10ms/step
# Epoch 465/500
# 2912/2912 - 29s - loss: 8.1976 - mean_squared_error: 8.1976 - mean_absolute_error: 2.2333 - 29s/epoch - 10ms/step
# Epoch 466/500
# 2912/2912 - 29s - loss: 8.1977 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2346 - 29s/epoch - 10ms/step
# Epoch 467/500
# 2912/2912 - 29s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2335 - 29s/epoch - 10ms/step
# Epoch 468/500
# 2912/2912 - 29s - loss: 8.1976 - mean_squared_error: 8.1976 - mean_absolute_error: 2.2343 - 29s/epoch - 10ms/step
# Epoch 469/500
# 2912/2912 - 29s - loss: 8.1976 - mean_squared_error: 8.1976 - mean_absolute_error: 2.2334 - 29s/epoch - 10ms/step
# Epoch 470/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 471/500
# 2912/2912 - 29s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2338 - 29s/epoch - 10ms/step
# Epoch 472/500
# 2912/2912 - 29s - loss: 8.1982 - mean_squared_error: 8.1982 - mean_absolute_error: 2.2341 - 29s/epoch - 10ms/step
# Epoch 473/500
# 2912/2912 - 29s - loss: 8.1976 - mean_squared_error: 8.1976 - mean_absolute_error: 2.2345 - 29s/epoch - 10ms/step
# Epoch 474/500
# 2912/2912 - 29s - loss: 8.1982 - mean_squared_error: 8.1982 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 475/500
# 2912/2912 - 29s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2339 - 29s/epoch - 10ms/step
# Epoch 476/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2339 - 29s/epoch - 10ms/step
# Epoch 477/500
# 2912/2912 - 29s - loss: 8.1974 - mean_squared_error: 8.1974 - mean_absolute_error: 2.2335 - 29s/epoch - 10ms/step
# Epoch 478/500
# 2912/2912 - 30s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2345 - 30s/epoch - 10ms/step
# Epoch 479/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 480/500
# 2912/2912 - 29s - loss: 8.1978 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2333 - 29s/epoch - 10ms/step
# Epoch 481/500
# 2912/2912 - 28s - loss: 8.1980 - mean_squared_error: 8.1980 - mean_absolute_error: 2.2343 - 28s/epoch - 10ms/step
# Epoch 482/500
# 2912/2912 - 29s - loss: 8.1982 - mean_squared_error: 8.1982 - mean_absolute_error: 2.2338 - 29s/epoch - 10ms/step
# Epoch 483/500
# 2912/2912 - 29s - loss: 8.1968 - mean_squared_error: 8.1968 - mean_absolute_error: 2.2346 - 29s/epoch - 10ms/step
# Epoch 484/500
# 2912/2912 - 29s - loss: 8.1981 - mean_squared_error: 8.1981 - mean_absolute_error: 2.2330 - 29s/epoch - 10ms/step
# Epoch 485/500
# 2912/2912 - 29s - loss: 8.1984 - mean_squared_error: 8.1983 - mean_absolute_error: 2.2340 - 29s/epoch - 10ms/step
# Epoch 486/500
# 2912/2912 - 29s - loss: 8.1977 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2335 - 29s/epoch - 10ms/step
# Epoch 487/500
# 2912/2912 - 29s - loss: 8.1982 - mean_squared_error: 8.1982 - mean_absolute_error: 2.2343 - 29s/epoch - 10ms/step
# Epoch 488/500
# 2912/2912 - 29s - loss: 8.1975 - mean_squared_error: 8.1975 - mean_absolute_error: 2.2344 - 29s/epoch - 10ms/step
# Epoch 489/500
# 2912/2912 - 29s - loss: 8.1984 - mean_squared_error: 8.1984 - mean_absolute_error: 2.2337 - 29s/epoch - 10ms/step
# Epoch 490/500
# 2912/2912 - 29s - loss: 8.1979 - mean_squared_error: 8.1979 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 491/500
# 2912/2912 - 29s - loss: 8.1977 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2345 - 29s/epoch - 10ms/step
# Epoch 492/500
# 2912/2912 - 28s - loss: 8.1965 - mean_squared_error: 8.1965 - mean_absolute_error: 2.2329 - 28s/epoch - 10ms/step
# Epoch 493/500
# 2912/2912 - 29s - loss: 8.1974 - mean_squared_error: 8.1974 - mean_absolute_error: 2.2348 - 29s/epoch - 10ms/step
# Epoch 494/500
# 2912/2912 - 29s - loss: 8.1977 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2330 - 29s/epoch - 10ms/step
# Epoch 495/500
# 2912/2912 - 29s - loss: 8.1983 - mean_squared_error: 8.1983 - mean_absolute_error: 2.2341 - 29s/epoch - 10ms/step
# Epoch 496/500
# 2912/2912 - 29s - loss: 8.1974 - mean_squared_error: 8.1974 - mean_absolute_error: 2.2346 - 29s/epoch - 10ms/step
# Epoch 497/500
# 2912/2912 - 29s - loss: 8.1982 - mean_squared_error: 8.1983 - mean_absolute_error: 2.2332 - 29s/epoch - 10ms/step
# Epoch 498/500
# 2912/2912 - 29s - loss: 8.1978 - mean_squared_error: 8.1978 - mean_absolute_error: 2.2336 - 29s/epoch - 10ms/step
# Epoch 499/500
# 2912/2912 - 29s - loss: 8.1977 - mean_squared_error: 8.1977 - mean_absolute_error: 2.2338 - 29s/epoch - 10ms/step
# Epoch 500/500
# 2912/2912 - 31s - loss: 8.1974 - mean_squared_error: 8.1974 - mean_absolute_error: 2.2337 - val_loss: 8.1873 - val_mean_squared_error: 8.1873 - val_mean_absolute_error: 2.2715 - 31s/epoch - 11ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
rmse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, rmse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              33792
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 10, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 10, 128)          98816
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            129
#  ed)
#
# =================================================================
# Total params: 132,737
# Trainable params: 132,737
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 8.197379112243652
# Final mean_squared_error : 8.197375297546387
# Final mean_absolute_error : 2.2336719036102295
# Final val_loss : 8.187335968017578
# Final val_mean_squared_error : 8.187335968017578
# Final val_mean_absolute_error : 2.271524667739868
#
# -------------------- Evaluation on Test Data --------------------
# 57/57 [==============================] - 1s 9ms/step - loss: 8.3761 - mean_squared_error: 8.3761 - mean_absolute_error: 2.2667
