# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D, GRU, ConvLSTM2D, ConvLSTM1D # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
from keras import metrics
from keras.utils import plot_model
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
dfull=pd.read_csv('../InSAR_data_south/displacement/export_dataframe1.csv')
dfull=dfull.set_index([dfull.columns[0],dfull.columns[1]])
dfull.columns=pd.to_datetime(dfull.columns, format='%Y%m%d')
tup=(-119.401,36.2192)
df_train = dfull[dfull.index==tup].copy()

# %%
df_train.mean(axis=1)
# Out:
# Longitude  Latitude
# -119.401   36.2192    -40.316353
# dtype: float64

# %%
#df_train.values[0]
snippet=df_train.values[0][-17]
arr=[]
arr2=[]
arr3=[]
arr.append(df_train.values[0][-18])
arr.append(-40.316353)
arr.append(df_train.values[0][-16])
arr

arr2.append(df_train.values[0][-18])
arr2.append(0)
arr2.append(df_train.values[0][-16])
 
arr3.append(df_train.values[0][-18])
arr3.append(-56.878)
arr3.append(df_train.values[0][-16])

# %%
df_train.iloc[0].interpolate(inplace=True)
df_train.iloc[0].values

#df_train.iloc[0].values
# Out:
# array([  0.     ,  -3.0761 ,  -0.90288,  -3.443  ,  -5.0788 ,  -5.3658 ,
#         -7.1638 ,  -8.6951 , -11.341  , -13.722  , -14.641  , -17.971  ,
#        -20.663  , -20.359  , -21.663  , -22.275  , -22.814  , -21.652  ,
#        -24.161  , -23.008  , -23.086  , -22.998  , -25.673  , -25.026  ,
#        -25.945  , -24.682  , -26.643  , -27.633  , -28.513  , -30.15   ,
#        -29.81   , -31.861  , -34.277  , -35.242  , -37.468  , -38.35   ,
#        -39.428  , -38.379  , -41.652  , -40.26   , -40.269  , -40.055  ,
#        -41.521  , -41.145  , -42.044  , -42.67   , -42.706  , -42.166  ,
#        -42.817  , -42.409  , -43.221  , -43.172  , -42.194  , -44.541  ,
#        -44.658  , -43.787  , -43.497  , -44.512  , -44.592  , -45.894  ,
#        -46.708  , -46.699  , -46.923  , -46.659  , -47.884  , -47.392  ,
#        -46.431  , -47.977  , -49.072  , -48.645  , -49.752  , -50.458  ,
#        -48.999  , -48.427  , -50.15   , -50.186  , -49.764  , -49.404  ,
# ...

# %%
fig = go.Figure()

#Trace for actual 
fig.add_trace(go.Scatter(x=np.array(df_train.columns[92:]),
                         y=np.array(arr),
                         mode='lines',
                         name='Mean',
                         opacity=0.8,
                         line=dict(color='red', width=1)
                        ))
fig.add_trace(go.Scatter(x=np.array(df_train.columns[92:]),
                         y=np.array(arr2),
                         mode='lines',
                         name='Zero',
                         opacity=0.8,
                         line=dict(color='dodgerblue', width=1)
                        ))
fig.add_trace(go.Scatter(x=np.array(df_train.columns[92:]),
                         y=np.array(arr3),
                         mode='lines',
                         name='Linear Interpolation',
                         opacity=0.8,
                         line=dict(color='seagreen', width=5)
                        ))
fig.add_trace(go.Scatter(x=np.array(df_train.columns),
                         y=np.array(df_train.values).flatten(),
                         mode='lines',
                         name='Subsidence - Actual (Test)',
                         opacity=0.8,
                         line=dict(color='black', width=1)
                        ))

# Change chart background color
fig.update_layout(dict(plot_bgcolor = 'white'))

# Update axes lines
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Month-Year'
                )

fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Subsidence'
                )

# Set figure title
fig.update_layout(title=dict(text="Subsidence", font=dict(color='black')),
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
                 )
fig.show()
# Out:
# <div>                            <div id="59a8a8bc-9f8f-4d36-912e-245cf89be38d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59a8a8bc-9f8f-4d36-912e-245cf89be38d")) {                    Plotly.newPlot(                        "59a8a8bc-9f8f-4d36-912e-245cf89be38d",                        [{"line":{"color":"red","width":1},"mode":"lines","name":"Mean","opacity":0.8,"x":["2018-07-14T00:00:00.000000000","2018-07-26T00:00:00.000000000","2018-08-07T00:00:00.000000000","2018-08-19T00:00:00.000000000","2018-08-31T00:00:00.000000000","2018-09-12T00:00:00.000000000","2018-09-24T00:00:00.000000000","2018-10-06T00:00:00.000000000","2018-10-18T00:00:00.000000000","2018-10-30T00:00:00.000000000","2018-11-11T00:00:00.000000000","2018-11-17T00:00:00.000000000","
# ...

# %%
#df_train=df_train.transpose()
tup=(-120.1488,36.1352)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
tup=(-119.9588,35.185)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
tup=(-118.3092,36.9354)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)

tup=(-120.8566,36.6611
)

    
# df_train = dfull[dfull.index==tup].copy()
# tup=(-120.0048,35.6611
# )
# df_train2 = dfull[dfull.index==tup].copy()
# df_train=df_train.append(df_train2)
# tup=(-119.6729,36.2332
# )
# df_train2 = dfull[dfull.index==tup].copy()
# df_train=df_train.append(df_train2)
# tup=(-119.357,35.8311
# )
# df_train2 = dfull[dfull.index==tup].copy()
# df_train=df_train.append(df_train2)
# dftest=dftest.append(dftest6)
for x in range(len(df_train.index)):
    df_train.iloc[x].interpolate(inplace=True)
df_train
# dftest=dftest.append(dftest6)
for x in range(len(df_train.index)):
    df_train.iloc[x].interpolate(inplace=True)
# Out:
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\550644474.py:4: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\550644474.py:7: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\550644474.py:10: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df_train
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -119.4010 36.2192          0.0     -3.0761    -0.90288     -3.4430
# -120.1488 36.1352          0.0     -6.1831     1.95150      4.2595
# -119.9588 35.1850          0.0    -11.2250    -2.98830     -2.1471
# -118.3092 36.9354          0.0      1.1889    -0.40826     -1.2696
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -119.4010 36.2192     -5.07880    -5.36580     -7.1638    -8.69510
# -120.1488 36.1352      0.42735     5.40830      2.0974     1.96240
# -119.9588 35.1850     -4.93480    -4.85500     -5.1682    -3.33110
# -118.3092 36.9354     -3.81600    -0.49596      8.0118    -0.18363
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -119.4010 36.2192     -11.3410    -13.7220  ...    -61.7430   -61.87200
# ...

# %%
num_partitions = 2
df_train=df_train.transpose()
partition_length = int(len(df_train) / num_partitions)

partition1_mean = df_train.head(partition_length).mean()
partition1_var = df_train.head(partition_length).var()
partition2_mean = df_train.tail(partition_length).mean()
partition2_var = df_train.tail(partition_length).var()

# %%
stationarity_test = pd.concat([partition1_mean, partition2_mean, partition1_var, partition2_var], axis=1)
stationarity_test.columns = ['Partition 1 Mean', 'Partition 2 Mean', 'Partition 1 Variance', 'Partition 2 Variance']

def highlight_greater(x):
    temp = x.copy()
    temp = temp.round(0).astype(int)
    m1 = (temp['Partition 1 Mean'] == temp['Partition 2 Mean'])
    m2 = (temp['Partition 1 Variance'] == temp['Partition 2 Variance'])
    m3 = (temp['Partition 1 Mean'] < temp['Partition 2 Mean']+4) & (temp['Partition 1 Mean'] > temp['Partition 2 Mean']-4)
    m4 = (temp['Partition 1 Variance'] < temp['Partition 2 Variance']+4) & (temp['Partition 1 Variance'] > temp['Partition 2 Variance']-4)

    df1 = pd.DataFrame('background-color: ', index=x.index, columns=x.columns)
    #rewrite values by boolean masks
    df1['Partition 1 Mean'] = np.where(~m1, 'background-color: {}'.format('red'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(~m1, 'background-color: {}'.format('red'), df1['Partition 2 Mean'])
    df1['Partition 1 Mean'] = np.where(m3, 'background-color: {}'.format('gold'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(m3, 'background-color: {}'.format('gold'), df1['Partition 2 Mean'])
    df1['Partition 1 Mean'] = np.where(m1, 'background-color: {}'.format('mediumseagreen'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(m1, 'background-color: {}'.format('mediumseagreen'), df1['Partition 2 Mean'])

    df1['Partition 1 Variance'] = np.where(~m2, 'background-color: {}'.format('red'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(~m2, 'background-color: {}'.format('red'), df1['Partition 2 Variance'])
    df1['Partition 1 Variance'] = np.where(m4, 'background-color: {}'.format('gold'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(m4, 'background-color: {}'.format('gold'), df1['Partition 2 Variance'])
    df1['Partition 1 Variance'] = np.where(m2, 'background-color: {}'.format('mediumseagreen'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(m2, 'background-color: {}'.format('mediumseagreen'), df1['Partition 2 Variance'])

    return df1


stationarity_test.style.apply(highlight_greater, axis=None).format("{:20,.0f}")
# Out:
# <style type="text/css">
# #T_621f8_row0_col0, #T_621f8_row0_col1, #T_621f8_row0_col2, #T_621f8_row0_col3, #T_621f8_row3_col2, #T_621f8_row3_col3 {
#   background-color: red;
# }
# #T_621f8_row1_col0, #T_621f8_row1_col1, #T_621f8_row1_col2, #T_621f8_row1_col3, #T_621f8_row3_col0, #T_621f8_row3_col1 {
#   background-color: gold;
# }
# #T_621f8_row2_col0, #T_621f8_row2_col1, #T_621f8_row2_col2, #T_621f8_row2_col3 {
#   background-color: mediumseagreen;
# }
# </style>
# <table id="T_621f8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_621f8_level0_col0" class="col_heading level0 col0" >Partition 1 Mean</th>
#       <th id="T_621f8_level0_col1" class="col_heading level0 col1" >Partition 2 Mean</th>
#       <th id="T_621f8_level0_col2" class="col_heading level0 col2" >Partition 1 Variance</th>
#       <th id="T_621f8_level0_col3" class="col_heading level0 col3" >Partition 2 Variance</th>
#     </tr>
# ...

# %%
#df_train=df_train.transpose()
dfull=pd.read_csv('../InSAR_data_south/displacement/rainfall.csv')
dfull=dfull.set_index([dfull.columns[0],dfull.columns[1]])
dfull.columns=pd.to_datetime(dfull.columns, format='%Y-%m-%d')

tup=(-120.8566,36.7474
)

    
df_train = dfull[dfull.index==tup].copy()
tup=(-120.0048,35.6611
)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
tup=(-119.6729,36.2332
)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
tup=(-119.357,35.8311
)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
# dftest=dftest.append(dftest6)
for x in range(len(df_train.index)):
    df_train.iloc[x].interpolate(inplace=True)
df_train
# Out:
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\1322832563.py:14: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\1322832563.py:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\1322832563.py:22: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                     2016-01-14  2016-01-26  2016-02-07  2016-02-19  \
# Longitude Latitude
# -120.8566 36.7474    57.238960   69.901381   13.273167    6.312694
# -120.0048 35.6611    49.347188   87.453745   47.853390   32.530293
# -119.6729 36.2332    93.658530  135.777936   68.852972   37.402367
# -119.3570 35.8311    17.750034   68.288574   45.122915   31.593514
#
# ...

# %%
num_partitions = 2
df_train=df_train.transpose()
partition_length = int(len(df_train) / num_partitions)

partition1_mean = df_train.head(partition_length).mean()
partition1_var = df_train.head(partition_length).var()
partition2_mean = df_train.tail(partition_length).mean()
partition2_var = df_train.tail(partition_length).var()

# %%
stationarity_test = pd.concat([partition1_mean, partition2_mean, partition1_var, partition2_var], axis=1)
stationarity_test.columns = ['Partition 1 Mean', 'Partition 2 Mean', 'Partition 1 Variance', 'Partition 2 Variance']
stationarity_test.style.set_caption("Rainfall Data")
def highlight_greater(x):
    temp = x.copy()
    temp = temp.round(0).astype(int)
    m1 = (temp['Partition 1 Mean'] == temp['Partition 2 Mean'])
    m2 = (temp['Partition 1 Variance'] == temp['Partition 2 Variance'])
    m3 = (temp['Partition 1 Mean'] < temp['Partition 2 Mean']+4) & (temp['Partition 1 Mean'] > temp['Partition 2 Mean']-4)
    m4 = (temp['Partition 1 Variance'] < temp['Partition 2 Variance']+4) & (temp['Partition 1 Variance'] > temp['Partition 2 Variance']-4)

    df1 = pd.DataFrame('background-color: ', index=x.index, columns=x.columns)
    #rewrite values by boolean masks
    df1['Partition 1 Mean'] = np.where(~m1, 'background-color: {}'.format('red'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(~m1, 'background-color: {}'.format('red'), df1['Partition 2 Mean'])
    df1['Partition 1 Mean'] = np.where(m3, 'background-color: {}'.format('gold'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(m3, 'background-color: {}'.format('gold'), df1['Partition 2 Mean'])
    df1['Partition 1 Mean'] = np.where(m1, 'background-color: {}'.format('mediumseagreen'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(m1, 'background-color: {}'.format('mediumseagreen'), df1['Partition 2 Mean'])

    df1['Partition 1 Variance'] = np.where(~m2, 'background-color: {}'.format('red'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(~m2, 'background-color: {}'.format('red'), df1['Partition 2 Variance'])
    df1['Partition 1 Variance'] = np.where(m4, 'background-color: {}'.format('gold'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(m4, 'background-color: {}'.format('gold'), df1['Partition 2 Variance'])
    df1['Partition 1 Variance'] = np.where(m2, 'background-color: {}'.format('mediumseagreen'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(m2, 'background-color: {}'.format('mediumseagreen'), df1['Partition 2 Variance'])

    return df1


stationarity_test.style.apply(highlight_greater, axis=None).format("{:20,.0f}")
# Out:
# <style type="text/css">
# #T_ea651_row0_col0, #T_ea651_row0_col1, #T_ea651_row0_col2, #T_ea651_row0_col3, #T_ea651_row1_col0, #T_ea651_row1_col1, #T_ea651_row1_col2, #T_ea651_row1_col3, #T_ea651_row2_col0, #T_ea651_row2_col1, #T_ea651_row2_col2, #T_ea651_row2_col3, #T_ea651_row3_col0, #T_ea651_row3_col1, #T_ea651_row3_col2, #T_ea651_row3_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_ea651">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea651_level0_col0" class="col_heading level0 col0" >Partition 1 Mean</th>
#       <th id="T_ea651_level0_col1" class="col_heading level0 col1" >Partition 2 Mean</th>
#       <th id="T_ea651_level0_col2" class="col_heading level0 col2" >Partition 1 Variance</th>
#       <th id="T_ea651_level0_col3" class="col_heading level0 col3" >Partition 2 Variance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Longitude</th>
# ...

# %%
#df_train=df_train.transpose()
dfull=pd.read_csv('../InSAR_data_south/displacement/groundwater.csv')
dfull=dfull.set_index([dfull.columns[0],dfull.columns[1]])
dfull.columns=pd.to_datetime(dfull.columns, format='%Y-%m-%d')

tup=(-120.8566,36.7474
)

    
df_train = dfull[dfull.index==tup].copy()
tup=(-120.0048,35.6611
)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
tup=(-119.6729,36.2332
)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
tup=(-119.357,35.8311
)
df_train2 = dfull[dfull.index==tup].copy()
df_train=df_train.append(df_train2)
# dftest=dftest.append(dftest6)
for x in range(len(df_train.index)):
    df_train.iloc[x].interpolate(inplace=True)
    df_train.iloc[x].ffill(inplace=True)
    df_train.iloc[x].bfill(inplace=True)
df_train
# Out:
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\2690885346.py:14: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\2690885346.py:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\jupad\AppData\Local\Temp\ipykernel_14452\2690885346.py:22: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                     2016-01-14  2016-01-26  2016-02-07  2016-02-19  \
# Longitude Latitude
# -120.8566 36.7474    72.248964   72.248964   72.248964   72.248964
# -120.0048 35.6611    45.600000   45.600000   45.600000   45.600000
# -119.6729 36.2332    26.300000   26.300000   26.300000   26.300000
# -119.3570 35.8311   179.730035  179.730035  179.730035  179.730035
#
# ...

# %%
num_partitions = 2
df_train=df_train.transpose()
partition_length = int(len(df_train) / num_partitions)

partition1_mean = df_train.head(partition_length).mean()
partition1_var = df_train.head(partition_length).var()
partition2_mean = df_train.tail(partition_length).mean()
partition2_var = df_train.tail(partition_length).var()

# %%
stationarity_test = pd.concat([partition1_mean, partition2_mean, partition1_var, partition2_var], axis=1)
stationarity_test.columns = ['Partition 1 Mean', 'Partition 2 Mean', 'Partition 1 Variance', 'Partition 2 Variance']
stationarity_test.style.set_caption("Displacement Data")
def highlight_greater(x):
    temp = x.copy()
    temp = temp.round(0).astype(int)
    m1 = (temp['Partition 1 Mean'] == temp['Partition 2 Mean'])
    m2 = (temp['Partition 1 Variance'] == temp['Partition 2 Variance'])
    m3 = (temp['Partition 1 Mean'] < temp['Partition 2 Mean']+4) & (temp['Partition 1 Mean'] > temp['Partition 2 Mean']-4)
    m4 = (temp['Partition 1 Variance'] < temp['Partition 2 Variance']+4) & (temp['Partition 1 Variance'] > temp['Partition 2 Variance']-4)

    df1 = pd.DataFrame('background-color: ', index=x.index, columns=x.columns)
    #rewrite values by boolean masks
    df1['Partition 1 Mean'] = np.where(~m1, 'background-color: {}'.format('red'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(~m1, 'background-color: {}'.format('red'), df1['Partition 2 Mean'])
    df1['Partition 1 Mean'] = np.where(m3, 'background-color: {}'.format('gold'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(m3, 'background-color: {}'.format('gold'), df1['Partition 2 Mean'])
    df1['Partition 1 Mean'] = np.where(m1, 'background-color: {}'.format('mediumseagreen'), df1['Partition 1 Mean'])
    df1['Partition 2 Mean'] = np.where(m1, 'background-color: {}'.format('mediumseagreen'), df1['Partition 2 Mean'])

    df1['Partition 1 Variance'] = np.where(~m2, 'background-color: {}'.format('red'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(~m2, 'background-color: {}'.format('red'), df1['Partition 2 Variance'])
    df1['Partition 1 Variance'] = np.where(m4, 'background-color: {}'.format('gold'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(m4, 'background-color: {}'.format('gold'), df1['Partition 2 Variance'])
    df1['Partition 1 Variance'] = np.where(m2, 'background-color: {}'.format('mediumseagreen'), df1['Partition 1 Variance'])
    df1['Partition 2 Variance'] = np.where(m2, 'background-color: {}'.format('mediumseagreen'), df1['Partition 2 Variance'])

    return df1


stationarity_test.style.apply(highlight_greater, axis=None).format("{:20,.0f}")
# Out:
# <style type="text/css">
# #T_7ce2e_row0_col0, #T_7ce2e_row0_col1, #T_7ce2e_row0_col2, #T_7ce2e_row0_col3 {
#   background-color: gold;
# }
# #T_7ce2e_row1_col0, #T_7ce2e_row1_col1, #T_7ce2e_row1_col2, #T_7ce2e_row1_col3, #T_7ce2e_row2_col0, #T_7ce2e_row2_col1, #T_7ce2e_row2_col2, #T_7ce2e_row2_col3 {
#   background-color: mediumseagreen;
# }
# #T_7ce2e_row3_col0, #T_7ce2e_row3_col1, #T_7ce2e_row3_col2, #T_7ce2e_row3_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_7ce2e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ce2e_level0_col0" class="col_heading level0 col0" >Partition 1 Mean</th>
#       <th id="T_7ce2e_level0_col1" class="col_heading level0 col1" >Partition 2 Mean</th>
#       <th id="T_7ce2e_level0_col2" class="col_heading level0 col2" >Partition 1 Variance</th>
#       <th id="T_7ce2e_level0_col3" class="col_heading level0 col3" >Partition 2 Variance</th>
#     </tr>
# ...
